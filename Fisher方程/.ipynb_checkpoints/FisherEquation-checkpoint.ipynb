# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import seaborn as sns
from pyDOE import lhs
import random
import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
#     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
#     torch.use_deterministic_algorithms(True)  # 有检查操作，看下文区别
 
seed_torch(314)

# %%
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
# data = scipy.io.loadmat('./three-state(0.05-0.1-0.2-0.1-0.05).mat')
t = data['t'].flatten()
x = data['x'].flatten()
u_data = data['solution']
# 生成网格
TT, XX = np.meshgrid(t, x)
# 画图
fig = plt.figure(figsize=(6, 5))
plt.subplot(111)
plt.pcolor(TT, XX, u_data, cmap='jet')
plt.colorbar()
plt.xlim([0, 10])
plt.ylim([-6, 6])
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Reference $u(t,x)$')
plt.tight_layout()
plt.show()

data
x.shape
# Out:
# (201,)

# %% [markdown]
# ## 超参数

# %%
domain = (0, 10, -6, 6)
tmin, tmax, xmin, xmax = domain
backbone_layers = [2] + [40]*3 + [1]
nn_lam_layers = [1] + [40]*3 + [1]
adam_iters = 50000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class DatasetBurgers:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, verbose=None):
        tmin, tmax, xmin, xmax = self.domain
        # 内部点采样
        t_res = np.linspace(tmin, tmax, 50)
        x_res = np.linspace(xmin, xmax, 80)
        X_res = self.sample_xy(t_res, x_res)
        # 真实数据
        X_data, u_data = self.added_data()
        
        return X_res, X_data, u_data
    
    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X
    
    def added_data(self):
        data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
        u_data = data['solution']
        t = data['t']
        x = data['x']
        
        TT, XX = np.meshgrid(t, x)  # meshgrid之后的数组shape为(nx, nt)
        
        X_data = np.concatenate([TT.reshape(-1, 1), XX.reshape(-1, 1)], axis=1)
        u_data = u_data.reshape(-1, 1)
        
        # 随机采样一小批数据 用以反演
        idx = np.random.permutation(range(X_data.shape[0]))
        idx = idx[:4000]  # 采样4000个真实数据点
        return X_data[idx, :], u_data[idx, :]
    

dataset = DatasetBurgers(domain)
X_res, X_data, u_data = dataset.train_data()
print(X_res.shape, X_data.shape, u_data.shape)
# Out:
# (4000, 2) (4000, 2) (4000, 1)

# %%
# 随即采样真实数据
plt.scatter(X_data[:, 0], X_data[:, 1], c=u_data[:, 0], s=5, cmap='jet')
plt.colorbar()

# %% [markdown]
# ## 主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)
    
backbone = MLP(backbone_layers)
nn_lam = MLP(nn_lam_layers)

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True, 
                               retain_graph=True)

# %%
class PINNFisher(nn.Module):
    def __init__(self, backbone, nn_lam, mu=None, sigma=None):
        super(PINNFisher, self).__init__()
        self.backbone = backbone
        self.nn_lam = nn_lam
        self.bound = 1.
        if mu is not None and sigma is not None:
            self.is_inputs_normalization = True
            self.mu = mu
            self.sigma = sigma
            print(f'forward with normalization, mu={self.mu.tolist()}, sigma={self.sigma.tolist()}')
        else:
            self.is_inputs_normalization = False
    
    def forward(self, X_res, X_data, u_data):
        loss_res = torch.mean(self.net_f(X_res)**2)
        loss_data = torch.mean(self.net_data(X_data, u_data)**2)
        return loss_res, loss_data
    
    def net_M(self, t):
        if self.is_inputs_normalization == True:
            t = (t - self.mu[0]) / self.sigma[0]
        M_t = self.nn_lam(t)
        M_t = M_t[:, [0]]
        return M_t * self.bound
    
    def net_u(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.backbone(X)
    
    def net_f(self, X_res):
        X_res.requires_grad_(True)
        u = self.net_u(X_res)
        
        grad_u = grad(u, X_res)[0]
        u_t = grad_u[:,[0]] 
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, X_res)[0][:,[1]]
        
        M = self.net_M(X_res[:, [0]])

        f = u_t - M*u_xx - u + u**2
        return f
    
    def net_data(self, X_data, u_data):
        u_data_pred = self.net_u(X_data)
        data = u_data_pred - u_data
        return data
    

pinn = PINNFisher(backbone, nn_lam)

# %% [markdown]
# ## Adams

# %%
dataset = DatasetBurgers(domain)  # 生成训练数据
X_res, X_data, u_data = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_data = torch.from_numpy(X_data).float().to(device)
u_data = torch.from_numpy(u_data).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma).to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=1e-3)
optimizer_adam_lam = optim.Adam(pinn.nn_lam.parameters(), lr=1e-3)

lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=0.8)  # 指数衰减学习率
lr_sche_lam = optim.lr_scheduler.ExponentialLR(optimizer_adam_lam, gamma=0.9)
logger = {
    "loss": [], 
    "loss_res": [],
    "loss_data": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
best_loss = 1e9

# 训练
start_time = time.time()
for it in range(adam_iters):
    # 计算loss并更新网络 -------
    pinn.train()
    pinn.zero_grad()
    
    loss_res, loss_data = pinn(X_res, X_data, u_data)
    loss = 1000 * loss_res + 100 * loss_data
    
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_lam.step()
    # 计算loss并更新网络 -------
    
    if (it + 1) % 100 == 0:
        # 保存loss信息
        pinn.train(False)
        loss_res_valid, loss_data_valid = pinn(X_res, X_data, u_data)
        loss_valid = loss_res_valid + loss_data_valid
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res"].append(loss_res_valid.item())
        logger["loss_data"].append(loss_data_valid.item())
        logger["iter"].append(it+1)
        
        # 保存训练loss最低的模型
        if loss_valid.item() < best_loss:
            model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(), 'nn_lam_state': pinn.nn_lam.state_dict()}
            torch.save(model_state, os.path.join(model_path, 'pinn_adam.pth'))
            best_loss = loss_valid.item()
        
        if (it + 1) % 500 == 0:
            # 保存并打印训练日志
            info = f'Iter # {it+1:6d}/{adam_iters}\t' + \
                f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_d:{loss_data.item():.2e}  ' + \
                f'Valid # loss:{loss_valid.item():.2e}, loss_r:{loss_res_valid.item():.2e}, loss_d:{loss_data_valid.item():.2e}'
            with open(train_info_path + 'train_info.txt', 'a') as f:
                f.write(info + '\n')
            print(info)
            
        # 衰减学习率
        if (it + 1) % 4000 == 0:
            lr_sche.step()
            lr_sche_lam.step()
# Out:
# forward with normalization, mu=[5.0, 6.103515914901436e-08], sigma=[2.945443630218506, 3.508115530014038]
# Iter #    500/50000	loss:7.40e-01, loss_r:1.26e-03, loss_d:6.14e-03  Valid # loss:7.37e-03, loss_r:1.25e-03, loss_d:6.11e-03
# Iter #   1000/50000	loss:3.00e-01, loss_r:5.25e-04, loss_d:2.47e-03  Valid # loss:2.99e-03, loss_r:5.27e-04, loss_d:2.46e-03
# Iter #   1500/50000	loss:1.65e-01, loss_r:3.01e-04, loss_d:1.34e-03  Valid # loss:1.64e-03, loss_r:3.00e-04, loss_d:1.34e-03
# Iter #   2000/50000	loss:1.01e-01, loss_r:1.93e-04, loss_d:8.15e-04  Valid # loss:1.01e-03, loss_r:1.93e-04, loss_d:8.14e-04
# Iter #   2500/50000	loss:5.81e-02, loss_r:1.19e-04, loss_d:4.62e-04  Valid # loss:5.80e-04, loss_r:1.19e-04, loss_d:4.62e-04
# Iter #   3000/50000	loss:3.69e-02, loss_r:8.51e-05, loss_d:2.84e-04  Valid # loss:3.70e-04, loss_r:8.21e-05, loss_d:2.88e-04
# Iter #   3500/50000	loss:2.54e-02, loss_r:5.83e-05, loss_d:1.96e-04  Valid # loss:2.54e-04, loss_r:5.81e-05, loss_d:1.95e-04
# Iter #   4000/50000	loss:1.93e-02, loss_r:4.38e-05, loss_d:1.49e-04  Valid # loss:1.93e-04, loss_r:4.38e-05, loss_d:1.49e-04
# Iter #   4500/50000	loss:1.59e-02, loss_r:3.55e-05, loss_d:1.24e-04  Valid # loss:1.59e-04, loss_r:3.55e-05, loss_d:1.24e-04
# Iter #   5000/50000	loss:1.38e-02, loss_r:2.97e-05, loss_d:1.08e-04  Valid # loss:1.38e-04, loss_r:2.97e-05, loss_d:1.08e-04
# Iter #   5500/50000	loss:1.25e-02, loss_r:2.59e-05, loss_d:9.91e-05  Valid # loss:1.28e-04, loss_r:2.66e-05, loss_d:1.02e-04
# Iter #   6000/50000	loss:1.14e-02, loss_r:2.24e-05, loss_d:9.13e-05  Valid # loss:1.14e-04, loss_r:2.24e-05, loss_d:9.13e-05
# Iter #   6500/50000	loss:1.07e-02, loss_r:2.00e-05, loss_d:8.67e-05  Valid # loss:1.07e-04, loss_r:2.00e-05, loss_d:8.67e-05
# Iter #   7000/50000	loss:1.05e-02, loss_r:2.08e-05, loss_d:8.42e-05  Valid # loss:1.04e-04, loss_r:1.93e-05, loss_d:8.48e-05
# Iter #   7500/50000	loss:9.72e-03, loss_r:1.66e-05, loss_d:8.06e-05  Valid # loss:9.68e-05, loss_r:1.64e-05, loss_d:8.04e-05
# Iter #   8000/50000	loss:9.32e-03, loss_r:1.52e-05, loss_d:7.80e-05  Valid # loss:9.32e-05, loss_r:1.52e-05, loss_d:7.80e-05
# Iter #   8500/50000	loss:9.66e-03, loss_r:1.66e-05, loss_d:8.00e-05  Valid # loss:1.11e-04, loss_r:2.26e-05, loss_d:8.88e-05
# Iter #   9000/50000	loss:8.93e-03, loss_r:1.40e-05, loss_d:7.53e-05  Valid # loss:8.97e-05, loss_r:1.42e-05, loss_d:7.56e-05
# Iter #   9500/50000	loss:8.57e-03, loss_r:1.29e-05, loss_d:7.28e-05  Valid # loss:8.58e-05, loss_r:1.29e-05, loss_d:7.29e-05
# Iter #  10000/50000	loss:8.67e-03, loss_r:1.36e-05, loss_d:7.31e-05  Valid # loss:8.43e-05, loss_r:1.27e-05, loss_d:7.17e-05
# Iter #  10500/50000	loss:8.20e-03, loss_r:1.20e-05, loss_d:7.00e-05  Valid # loss:8.21e-05, loss_r:1.21e-05, loss_d:7.00e-05
# Iter #  11000/50000	loss:8.02e-03, loss_r:1.17e-05, loss_d:6.84e-05  Valid # loss:8.02e-05, loss_r:1.17e-05, loss_d:6.84e-05
# Iter #  11500/50000	loss:7.86e-03, loss_r:1.15e-05, loss_d:6.71e-05  Valid # loss:7.86e-05, loss_r:1.15e-05, loss_d:6.71e-05
# Iter #  12000/50000	loss:7.71e-03, loss_r:1.13e-05, loss_d:6.57e-05  Valid # loss:7.71e-05, loss_r:1.13e-05, loss_d:6.57e-05
# Iter #  12500/50000	loss:8.58e-03, loss_r:1.48e-05, loss_d:7.10e-05  Valid # loss:9.22e-05, loss_r:1.74e-05, loss_d:7.48e-05
# Iter #  13000/50000	loss:7.43e-03, loss_r:1.12e-05, loss_d:6.31e-05  Valid # loss:7.43e-05, loss_r:1.12e-05, loss_d:6.31e-05
# Iter #  13500/50000	loss:7.29e-03, loss_r:1.12e-05, loss_d:6.18e-05  Valid # loss:7.29e-05, loss_r:1.12e-05, loss_d:6.18e-05
# Iter #  14000/50000	loss:7.16e-03, loss_r:1.11e-05, loss_d:6.05e-05  Valid # loss:7.16e-05, loss_r:1.12e-05, loss_d:6.04e-05
# Iter #  14500/50000	loss:1.33e-02, loss_r:3.37e-05, loss_d:9.91e-05  Valid # loss:1.48e-04, loss_r:4.01e-05, loss_d:1.08e-04
# Iter #  15000/50000	loss:7.02e-03, loss_r:1.16e-05, loss_d:5.85e-05  Valid # loss:6.97e-05, loss_r:1.15e-05, loss_d:5.83e-05
# Iter #  15500/50000	loss:6.78e-03, loss_r:1.13e-05, loss_d:5.65e-05  Valid # loss:6.79e-05, loss_r:1.12e-05, loss_d:5.67e-05
# Iter #  16000/50000	loss:6.61e-03, loss_r:1.11e-05, loss_d:5.51e-05  Valid # loss:6.61e-05, loss_r:1.11e-05, loss_d:5.50e-05
# Iter #  16500/50000	loss:9.05e-03, loss_r:2.11e-05, loss_d:6.94e-05  Valid # loss:9.36e-05, loss_r:2.15e-05, loss_d:7.21e-05
# Iter #  17000/50000	loss:6.38e-03, loss_r:1.11e-05, loss_d:5.27e-05  Valid # loss:6.38e-05, loss_r:1.11e-05, loss_d:5.26e-05
# Iter #  17500/50000	loss:6.22e-03, loss_r:1.10e-05, loss_d:5.12e-05  Valid # loss:6.21e-05, loss_r:1.09e-05, loss_d:5.12e-05
# Iter #  18000/50000	loss:6.15e-03, loss_r:1.11e-05, loss_d:5.04e-05  Valid # loss:6.13e-05, loss_r:1.12e-05, loss_d:5.02e-05
# Iter #  18500/50000	loss:6.05e-03, loss_r:1.12e-05, loss_d:4.92e-05  Valid # loss:6.03e-05, loss_r:1.11e-05, loss_d:4.92e-05
# Iter #  19000/50000	loss:7.71e-03, loss_r:1.80e-05, loss_d:5.91e-05  Valid # loss:8.22e-05, loss_r:1.91e-05, loss_d:6.31e-05
# Iter #  19500/50000	loss:5.67e-03, loss_r:1.06e-05, loss_d:4.61e-05  Valid # loss:5.72e-05, loss_r:1.08e-05, loss_d:4.64e-05
# Iter #  20000/50000	loss:5.45e-03, loss_r:1.02e-05, loss_d:4.43e-05  Valid # loss:5.50e-05, loss_r:1.04e-05, loss_d:4.46e-05
# Iter #  20500/50000	loss:5.38e-03, loss_r:1.04e-05, loss_d:4.34e-05  Valid # loss:5.39e-05, loss_r:1.05e-05, loss_d:4.34e-05
# Iter #  21000/50000	loss:5.20e-03, loss_r:9.84e-06, loss_d:4.22e-05  Valid # loss:5.12e-05, loss_r:9.64e-06, loss_d:4.16e-05
# Iter #  21500/50000	loss:4.90e-03, loss_r:9.12e-06, loss_d:3.99e-05  Valid # loss:4.90e-05, loss_r:9.12e-06, loss_d:3.99e-05
# Iter #  22000/50000	loss:5.51e-03, loss_r:1.15e-05, loss_d:4.36e-05  Valid # loss:5.83e-05, loss_r:1.29e-05, loss_d:4.53e-05
# Iter #  22500/50000	loss:4.57e-03, loss_r:8.52e-06, loss_d:3.71e-05  Valid # loss:4.57e-05, loss_r:8.52e-06, loss_d:3.71e-05
# Iter #  23000/50000	loss:4.45e-03, loss_r:8.42e-06, loss_d:3.61e-05  Valid # loss:4.42e-05, loss_r:8.29e-06, loss_d:3.60e-05
# Iter #  23500/50000	loss:4.32e-03, loss_r:8.25e-06, loss_d:3.50e-05  Valid # loss:4.31e-05, loss_r:8.21e-06, loss_d:3.49e-05
# Iter #  24000/50000	loss:4.25e-03, loss_r:8.19e-06, loss_d:3.43e-05  Valid # loss:4.29e-05, loss_r:8.44e-06, loss_d:3.45e-05
# Iter #  24500/50000	loss:4.05e-03, loss_r:7.74e-06, loss_d:3.27e-05  Valid # loss:4.05e-05, loss_r:7.80e-06, loss_d:3.27e-05
# Iter #  25000/50000	loss:3.89e-03, loss_r:7.44e-06, loss_d:3.14e-05  Valid # loss:3.88e-05, loss_r:7.38e-06, loss_d:3.14e-05
# Iter #  25500/50000	loss:3.76e-03, loss_r:7.19e-06, loss_d:3.04e-05  Valid # loss:3.76e-05, loss_r:7.20e-06, loss_d:3.04e-05
# Iter #  26000/50000	loss:3.65e-03, loss_r:7.00e-06, loss_d:2.95e-05  Valid # loss:3.65e-05, loss_r:7.00e-06, loss_d:2.95e-05
# Iter #  26500/50000	loss:3.54e-03, loss_r:6.81e-06, loss_d:2.86e-05  Valid # loss:3.54e-05, loss_r:6.81e-06, loss_d:2.86e-05
# Iter #  27000/50000	loss:3.44e-03, loss_r:6.63e-06, loss_d:2.77e-05  Valid # loss:3.44e-05, loss_r:6.63e-06, loss_d:2.77e-05
# Iter #  27500/50000	loss:3.35e-03, loss_r:6.51e-06, loss_d:2.70e-05  Valid # loss:3.34e-05, loss_r:6.49e-06, loss_d:2.70e-05
# Iter #  28000/50000	loss:3.28e-03, loss_r:6.44e-06, loss_d:2.64e-05  Valid # loss:3.29e-05, loss_r:6.48e-06, loss_d:2.64e-05
# Iter #  28500/50000	loss:3.17e-03, loss_r:6.17e-06, loss_d:2.55e-05  Valid # loss:3.17e-05, loss_r:6.18e-06, loss_d:2.55e-05
# Iter #  29000/50000	loss:3.08e-03, loss_r:6.03e-06, loss_d:2.48e-05  Valid # loss:3.08e-05, loss_r:6.02e-06, loss_d:2.48e-05
# Iter #  29500/50000	loss:3.06e-03, loss_r:6.11e-06, loss_d:2.45e-05  Valid # loss:3.04e-05, loss_r:6.02e-06, loss_d:2.44e-05
# Iter #  30000/50000	loss:3.03e-03, loss_r:6.15e-06, loss_d:2.42e-05  Valid # loss:3.00e-05, loss_r:6.02e-06, loss_d:2.40e-05
# Iter #  30500/50000	loss:3.05e-03, loss_r:6.64e-06, loss_d:2.39e-05  Valid # loss:3.13e-05, loss_r:6.97e-06, loss_d:2.43e-05
# Iter #  31000/50000	loss:2.79e-03, loss_r:5.50e-06, loss_d:2.24e-05  Valid # loss:2.79e-05, loss_r:5.50e-06, loss_d:2.24e-05
# Iter #  31500/50000	loss:2.73e-03, loss_r:5.40e-06, loss_d:2.19e-05  Valid # loss:2.73e-05, loss_r:5.40e-06, loss_d:2.19e-05
# Iter #  32000/50000	loss:2.67e-03, loss_r:5.32e-06, loss_d:2.14e-05  Valid # loss:2.68e-05, loss_r:5.30e-06, loss_d:2.14e-05
# Iter #  32500/50000	loss:2.63e-03, loss_r:5.24e-06, loss_d:2.11e-05  Valid # loss:2.63e-05, loss_r:5.28e-06, loss_d:2.10e-05
# Iter #  33000/50000	loss:3.00e-03, loss_r:6.74e-06, loss_d:2.32e-05  Valid # loss:2.99e-05, loss_r:6.64e-06, loss_d:2.32e-05
# Iter #  33500/50000	loss:2.53e-03, loss_r:5.06e-06, loss_d:2.02e-05  Valid # loss:2.53e-05, loss_r:5.06e-06, loss_d:2.02e-05
# Iter #  34000/50000	loss:2.51e-03, loss_r:5.13e-06, loss_d:2.00e-05  Valid # loss:2.52e-05, loss_r:5.10e-06, loss_d:2.00e-05
# Iter #  34500/50000	loss:2.44e-03, loss_r:4.91e-06, loss_d:1.95e-05  Valid # loss:2.44e-05, loss_r:4.91e-06, loss_d:1.95e-05
# Iter #  35000/50000	loss:2.40e-03, loss_r:4.88e-06, loss_d:1.92e-05  Valid # loss:2.40e-05, loss_r:4.88e-06, loss_d:1.92e-05
# Iter #  35500/50000	loss:2.45e-03, loss_r:5.52e-06, loss_d:1.90e-05  Valid # loss:2.46e-05, loss_r:5.67e-06, loss_d:1.90e-05
# Iter #  36000/50000	loss:2.32e-03, loss_r:4.71e-06, loss_d:1.85e-05  Valid # loss:2.32e-05, loss_r:4.71e-06, loss_d:1.85e-05
# Iter #  36500/50000	loss:2.31e-03, loss_r:4.77e-06, loss_d:1.83e-05  Valid # loss:2.32e-05, loss_r:4.80e-06, loss_d:1.84e-05
# Iter #  37000/50000	loss:2.27e-03, loss_r:4.64e-06, loss_d:1.81e-05  Valid # loss:2.27e-05, loss_r:4.64e-06, loss_d:1.81e-05
# Iter #  37500/50000	loss:2.23e-03, loss_r:4.54e-06, loss_d:1.78e-05  Valid # loss:2.23e-05, loss_r:4.56e-06, loss_d:1.78e-05
# Iter #  38000/50000	loss:2.20e-03, loss_r:4.50e-06, loss_d:1.75e-05  Valid # loss:2.20e-05, loss_r:4.46e-06, loss_d:1.75e-05
# Iter #  38500/50000	loss:2.16e-03, loss_r:4.39e-06, loss_d:1.72e-05  Valid # loss:2.16e-05, loss_r:4.39e-06, loss_d:1.72e-05
# Iter #  39000/50000	loss:2.42e-03, loss_r:5.43e-06, loss_d:1.88e-05  Valid # loss:2.50e-05, loss_r:5.72e-06, loss_d:1.92e-05
# Iter #  39500/50000	loss:2.56e-03, loss_r:6.35e-06, loss_d:1.92e-05  Valid # loss:2.45e-05, loss_r:5.81e-06, loss_d:1.87e-05
# Iter #  40000/50000	loss:2.08e-03, loss_r:4.24e-06, loss_d:1.66e-05  Valid # loss:2.08e-05, loss_r:4.24e-06, loss_d:1.66e-05
# Iter #  40500/50000	loss:2.05e-03, loss_r:4.17e-06, loss_d:1.64e-05  Valid # loss:2.05e-05, loss_r:4.18e-06, loss_d:1.63e-05
# Iter #  41000/50000	loss:2.03e-03, loss_r:4.12e-06, loss_d:1.61e-05  Valid # loss:2.02e-05, loss_r:4.12e-06, loss_d:1.61e-05
# Iter #  41500/50000	loss:2.00e-03, loss_r:4.07e-06, loss_d:1.59e-05  Valid # loss:2.00e-05, loss_r:4.06e-06, loss_d:1.59e-05
# Iter #  42000/50000	loss:2.02e-03, loss_r:4.22e-06, loss_d:1.60e-05  Valid # loss:2.03e-05, loss_r:4.25e-06, loss_d:1.61e-05
# Iter #  42500/50000	loss:1.95e-03, loss_r:3.97e-06, loss_d:1.55e-05  Valid # loss:1.95e-05, loss_r:3.97e-06, loss_d:1.55e-05
# Iter #  43000/50000	loss:1.93e-03, loss_r:3.94e-06, loss_d:1.53e-05  Valid # loss:1.93e-05, loss_r:3.93e-06, loss_d:1.53e-05
# Iter #  43500/50000	loss:1.91e-03, loss_r:3.93e-06, loss_d:1.52e-05  Valid # loss:1.91e-05, loss_r:3.95e-06, loss_d:1.52e-05
# Iter #  44000/50000	loss:1.88e-03, loss_r:3.83e-06, loss_d:1.49e-05  Valid # loss:1.88e-05, loss_r:3.83e-06, loss_d:1.49e-05
# Iter #  44500/50000	loss:1.86e-03, loss_r:3.79e-06, loss_d:1.48e-05  Valid # loss:1.86e-05, loss_r:3.80e-06, loss_d:1.48e-05
# Iter #  45000/50000	loss:1.86e-03, loss_r:3.93e-06, loss_d:1.47e-05  Valid # loss:1.87e-05, loss_r:3.94e-06, loss_d:1.47e-05
# Iter #  45500/50000	loss:1.81e-03, loss_r:3.72e-06, loss_d:1.44e-05  Valid # loss:1.81e-05, loss_r:3.72e-06, loss_d:1.44e-05
# Iter #  46000/50000	loss:1.79e-03, loss_r:3.68e-06, loss_d:1.42e-05  Valid # loss:1.79e-05, loss_r:3.67e-06, loss_d:1.42e-05
# Iter #  46500/50000	loss:1.78e-03, loss_r:3.66e-06, loss_d:1.41e-05  Valid # loss:1.78e-05, loss_r:3.67e-06, loss_d:1.41e-05
# Iter #  47000/50000	loss:1.75e-03, loss_r:3.60e-06, loss_d:1.39e-05  Valid # loss:1.75e-05, loss_r:3.60e-06, loss_d:1.39e-05
# Iter #  47500/50000	loss:1.76e-03, loss_r:3.67e-06, loss_d:1.39e-05  Valid # loss:1.77e-05, loss_r:3.73e-06, loss_d:1.40e-05
# Iter #  48000/50000	loss:1.72e-03, loss_r:3.55e-06, loss_d:1.36e-05  Valid # loss:1.72e-05, loss_r:3.55e-06, loss_d:1.36e-05
# Iter #  48500/50000	loss:1.69e-03, loss_r:3.50e-06, loss_d:1.35e-05  Valid # loss:1.70e-05, loss_r:3.50e-06, loss_d:1.35e-05
# Iter #  49000/50000	loss:1.68e-03, loss_r:3.47e-06, loss_d:1.33e-05  Valid # loss:1.68e-05, loss_r:3.47e-06, loss_d:1.33e-05
# Iter #  49500/50000	loss:1.68e-03, loss_r:3.55e-06, loss_d:1.32e-05  Valid # loss:1.69e-05, loss_r:3.59e-06, loss_d:1.33e-05
# Iter #  50000/50000	loss:1.64e-03, loss_r:3.40e-06, loss_d:1.30e-05  Valid # loss:1.64e-05, loss_r:3.41e-06, loss_d:1.30e-05

# %%
np.save("./logger.npy", logger)

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
logger = np.load("./logger.npy", allow_pickle=True).item()
k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_data"][::k], label=r"$\mathcal{L}_{data}$", linewidth=3)
    plt.legend()
    plt.xticks([0, 5000, 10000, 15000, 20000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('loss.png', dpi=100)
    plt.show()

# %%
# 导入模型参数
mu = logger["mu"].cpu()
sigma = logger["sigma"].cpu()

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma)

model_state = torch.load(os.path.join(model_path, 'pinn_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_lam.load_state_dict(model_state['nn_lam_state'])
pinn.eval()

# 导入数据
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
u_star = data['solution']
t = data['t'].flatten()
x = data['x'].flatten()
# 生成网格
TT, XX = np.meshgrid(t, x)
TX = np.concatenate([TT.reshape(-1,1), XX.reshape(-1,1)], axis=1)
TX = torch.from_numpy(TX).double()

pinn = pinn.cpu().double()
u_pred = pinn.net_u(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

u_error = np.linalg.norm(u_pred - u_star) / np.linalg.norm(u_star) 
print('Relative l2 error of u: {:.3e}'.format(u_error))
# Out:
# forward with normalization, mu=[5.0, 6.103515914901436e-08], sigma=[2.945443630218506, 3.508115530014038]
# Relative l2 error of u: 6.523e-03

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

plt.subplot(1,3,1)
cax1 = axes[0].pcolor(TT, XX, u_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u(t,x)$')
axes[0].set_xlim([0, 10])
axes[0].set_ylim([-6, 6])
axes[0].set_xticks(np.arange(0, 10.1, 2.))
axes[0].set_yticks(np.arange(-6, 6.1, 4.))
axes[0].set_aspect(1./axes[0].get_data_ratio())

plt.subplot(1,3,2)
cax2 = axes[1].pcolor(TT, XX, u_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u(t,x)$')
axes[1].set_xlim([0, 10])
axes[1].set_ylim([-6, 6])
axes[1].set_xticks(np.arange(0, 10.1, 2.))
axes[1].set_yticks(np.arange(-6, 6.1, 4.))
axes[1].set_aspect(1./axes[1].get_data_ratio())

plt.subplot(1,3,3)
cax3 = axes[2].pcolor(TT, XX, np.abs(u_star - u_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([0, 10])
axes[2].set_ylim([-6, 6])
axes[2].set_xticks(np.arange(0, 10.1, 2.))
axes[2].set_yticks(np.arange(-6, 6.1, 4.))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Fisher_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size':18})

fig, ax = plt.subplots(figsize=(9, 7), dpi=100)
# lines = ax.plot(t[:-1].reshape(5, -1).T, lam2_sol[:-1].reshape(5, -1).T, 
#                 linewidth=3, color='k', label="True")
# plt.setp(lines[1:], label="_")

t = torch.tensor(t.reshape(-1,1))  # 1001,1
M = pinn.net_M(t).detach().numpy()  # 1001,1
t = np.array(t)

ax.plot(t, M, linewidth=3, linestyle='--', color='blue', label='cS-PINN')
ax.scatter(t[::20], M[::20], marker='^', s=120, color='blue', label='cS-PINN')
ax.set_xlim([0, 10])
ax.set_xticks(np.arange(0, 10.1, 2))
ax.set_xlabel('$t$')
ax.set_ylim([-0.5, 0.5])
ax.set_yticks(np.arange(-0.5, 0.6, 0.5))
ax.set_ylabel('$M_t$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("./M.png", dpi=100)
plt.show()
