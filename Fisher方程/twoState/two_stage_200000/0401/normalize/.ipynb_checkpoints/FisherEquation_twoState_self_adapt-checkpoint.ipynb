# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /tmp/ipykernel_733321/82325636.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import seaborn as sns
from pyDOE import lhs
import random
import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
#     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
#     torch.use_deterministic_algorithms(True)  # 有检查操作，看下文区别
 
seed_torch(314)

# %%
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
# data = scipy.io.loadmat('./three-state(0.05-0.1-0.2-0.1-0.05).mat')
t = data['t'].flatten()
x = data['x'].flatten()
u_data = data['solution']
# 生成网格
TT, XX = np.meshgrid(t, x)
# 画图
fig = plt.figure(figsize=(6, 5))
plt.subplot(111)
plt.pcolor(TT, XX, u_data, cmap='jet')
plt.colorbar()
plt.xlim([0, 10])
plt.ylim([-6, 6])
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Reference $u(t,x)$')
plt.tight_layout()
plt.show()

data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Mar 21 12:11:16 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'C': array([[1, 2]], dtype=uint8),
#  'C_t': array([[ 0.2,  1. , -1. ],
#         [ 0.1,  1. , -1. ]]),
#  'T': array([[10]], dtype=uint8),
#  'Time': array([[10]], dtype=uint8),
#  'a': array([[-6]], dtype=int16),
#  'b': array([[6]], dtype=uint8),
#  'h': array([[0.06]]),
#  'jump_time_point': array([[ 0],
#         [ 5],
#         [10]], dtype=uint8),
#  'solution': array([[1.92874985e-22, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.51441136e-22, 3.84751374e-22, 4.31921353e-22, ...,
#          9.90659535e-02, 9.91484454e-02, 9.92303005e-02],
#         [6.40367501e-22, 7.89693237e-22, 9.66503734e-22, ...,
#          1.95288538e-01, 1.95448948e-01, 1.95608117e-01],
#         ...,
#         [1.31989579e-30, 1.62767908e-30, 1.99211267e-30, ...,
#          1.91905731e-01, 1.92091981e-01, 1.92276833e-01],
#         [7.24374170e-31, 7.93031688e-31, 8.90256261e-31, ...,
#          9.73265838e-02, 9.74223299e-02, 9.75173589e-02],
#         [3.97544974e-31, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  't': array([[ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ]]),
#  'tau0': array([[0.01]]),
#  'x': array([[-6.  , -5.94, -5.88, -5.82, -5.76, -5.7 , -5.64, -5.58, -5.52,
#          -5.46, -5.4 , -5.34, -5.28, -5.22, -5.16, -5.1 , -5.04, -4.98,
#          -4.92, -4.86, -4.8 , -4.74, -4.68, -4.62, -4.56, -4.5 , -4.44,
#          -4.38, -4.32, -4.26, -4.2 , -4.14, -4.08, -4.02, -3.96, -3.9 ,
#          -3.84, -3.78, -3.72, -3.66, -3.6 , -3.54, -3.48, -3.42, -3.36,
#          -3.3 , -3.24, -3.18, -3.12, -3.06, -3.  , -2.94, -2.88, -2.82,
#          -2.76, -2.7 , -2.64, -2.58, -2.52, -2.46, -2.4 , -2.34, -2.28,
#          -2.22, -2.16, -2.1 , -2.04, -1.98, -1.92, -1.86, -1.8 , -1.74,
#          -1.68, -1.62, -1.56, -1.5 , -1.44, -1.38, -1.32, -1.26, -1.2 ,
#          -1.14, -1.08, -1.02, -0.96, -0.9 , -0.84, -0.78, -0.72, -0.66,
#          -0.6 , -0.54, -0.48, -0.42, -0.36, -0.3 , -0.24, -0.18, -0.12,
#          -0.06,  0.  ,  0.06,  0.12,  0.18,  0.24,  0.3 ,  0.36,  0.42,
#           0.48,  0.54,  0.6 ,  0.66,  0.72,  0.78,  0.84,  0.9 ,  0.96,
#           1.02,  1.08,  1.14,  1.2 ,  1.26,  1.32,  1.38,  1.44,  1.5 ,
#           1.56,  1.62,  1.68,  1.74,  1.8 ,  1.86,  1.92,  1.98,  2.04,
#           2.1 ,  2.16,  2.22,  2.28,  2.34,  2.4 ,  2.46,  2.52,  2.58,
#           2.64,  2.7 ,  2.76,  2.82,  2.88,  2.94,  3.  ,  3.06,  3.12,
#           3.18,  3.24,  3.3 ,  3.36,  3.42,  3.48,  3.54,  3.6 ,  3.66,
#           3.72,  3.78,  3.84,  3.9 ,  3.96,  4.02,  4.08,  4.14,  4.2 ,
#           4.26,  4.32,  4.38,  4.44,  4.5 ,  4.56,  4.62,  4.68,  4.74,
#           4.8 ,  4.86,  4.92,  4.98,  5.04,  5.1 ,  5.16,  5.22,  5.28,
#           5.34,  5.4 ,  5.46,  5.52,  5.58,  5.64,  5.7 ,  5.76,  5.82,
#           5.88,  5.94,  6.  ]])}

# %% [markdown]
# ## 超参数

# %%
domain = (0, 10, -6, 6)
tmin, tmax, xmin, xmax = domain
backbone_layers = [2] + [40]*4 + [1]
nn_lam_layers = [1] + [20]*4 + [1]
adam_iters = 200000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class DatasetBurgers:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, verbose=None):
        tmin, tmax, xmin, xmax = self.domain
        # 内部点采样
        t_res = np.linspace(tmin, tmax, 50)
        x_res = np.linspace(xmin, xmax, 80)
        X_res = self.sample_xy(t_res, x_res)
        # 真实数据
        X_data, u_data = self.added_data()
        
        return X_res, X_data, u_data
    
    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X
    
    def added_data(self):
        data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
        u_data = data['solution']
        t = data['t']
        x = data['x']
        
        TT, XX = np.meshgrid(t, x)  # meshgrid之后的数组shape为(nx, nt)
        
        X_data = np.concatenate([TT.reshape(-1, 1), XX.reshape(-1, 1)], axis=1)
        u_data = u_data.reshape(-1, 1)
        
        # 随机采样一小批数据 用以反演
        idx = np.random.permutation(range(X_data.shape[0]))
        idx = idx[:4000]  # 采样4000个真实数据点
        return X_data[idx, :], u_data[idx, :]
    

dataset = DatasetBurgers(domain)
X_res, X_data, u_data = dataset.train_data()
print(X_res.shape, X_data.shape, u_data.shape)
# Out:
# (4000, 2) (4000, 2) (4000, 1)

# %%
# 随即采样真实数据
plt.scatter(X_data[:, 0], X_data[:, 1], c=u_data[:, 0], s=5, cmap='jet')
plt.colorbar()

# %% [markdown]
# ## 主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
        for param in self.parameters():
            if len(param.shape) > 1:
                nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)
    

backbone = MLP(backbone_layers)
nn_lam = MLP(nn_lam_layers)

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True, 
                               retain_graph=True)

# %%
class PINNFisher(nn.Module):
    def __init__(self, backbone, nn_lam, mu=None, sigma=None):
        super(PINNFisher, self).__init__()
        self.backbone = backbone
        self.nn_lam = nn_lam
        
        self.bound = 0.15
        if mu is not None and sigma is not None:
            self.is_inputs_normalization = True
            self.mu = mu
            self.sigma = sigma
            print(f'forward with normalization, mu={self.mu.tolist()}, sigma={self.sigma.tolist()}')
        else:
            self.is_inputs_normalization = False
    
    def forward(self, X_res, X_data, u_data):
        loss_res = torch.mean(self.net_f(X_res)**2)
        loss_data = torch.mean(self.net_data(X_data, u_data)**2)
        return loss_res, loss_data
    
    def net_M(self, t):
        if self.is_inputs_normalization == True:
            t = (t - self.mu[0]) / self.sigma[0]
        M_t = self.nn_lam(t)
        return M_t * self.bound
    
    def net_u(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.backbone(X)
    
    def net_f(self, X_res):
        X_res.requires_grad_(True)
        u = self.net_u(X_res)
        
        grad_u = grad(u, X_res)[0]
        u_t = grad_u[:,[0]] 
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, X_res)[0][:,[1]]
        
        M = self.net_M(X_res[:, [0]])

        f = u_t + M*u_xx - u + u**2
        return f
    
    def net_data(self, X_data, u_data):
        u_data_pred = self.net_u(X_data)
        data = u_data_pred - u_data
        return data
    
pinn = PINNFisher(backbone, nn_lam)

# %% [markdown]
# ## Adams

# %%
dataset = DatasetBurgers(domain)  # 生成训练数据
X_res, X_data, u_data = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_data = torch.from_numpy(X_data).float().to(device)
u_data = torch.from_numpy(u_data).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma).to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=1e-3)
optimizer_adam_lam = optim.Adam(pinn.nn_lam.parameters(), lr=1e-3)

lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=0.9)  # 指数衰减学习率
lr_sche_lam = optim.lr_scheduler.ExponentialLR(optimizer_adam_lam, gamma=0.9)

# 自适应
# w_res = torch.cat((torch.ones(1500,1 ),100 * torch.ones(1000,1 ),torch.ones(1500,1 )),dim=0).float().to(device)  # 权重
# # # w_data = (100 * torch.ones(X_data.shape[0],1 )).float().to(device)
# w_data = torch.cat((torch.ones(1500,1 ),100 * torch.ones(1000,1 ),torch.ones(1500,1 )),dim=0).float().to(device)
# print(w_res.shape)

# w_res.requires_grad = True
# w_data.requires_grad = True

# optimizer_w_res = optim.Adam([w_res], lr=1e-3, betas=(0.9, 0.999))  # 权重优化器
# optimizer_w_data = optim.Adam([w_data], lr=1e-3, betas=(0.9, 0.999))


logger = {
    "loss": [], 
    "loss_res": [],
    "loss_data": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
best_loss = 1e9

# 训练
start_time = time.time()
for it in range(adam_iters):
    # 计算loss并更新网络 -------
    pinn.train()
    pinn.zero_grad()
    
    loss_res, loss_data = pinn(X_res, X_data, u_data)
#     loss_res = torch.mean(w_res * pinn.net_f(X_res)**2)
#     loss_data = torch.mean(w_data * pinn.net_data(X_data, u_data)**2)
    loss = 1000*(loss_res +  loss_data)
    
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_lam.step()
    # 计算loss并更新网络 -------
    
#     for w in [w_res,w_data]:
#         w.grad *= -1.
#     optimizer_w_res.step()
#     optimizer_w_data.step()
    
    if (it + 1) % 100 == 0:
        # 保存loss信息
        pinn.train(False)
        loss_res_valid, loss_data_valid = pinn(X_res, X_data, u_data)
        loss_valid = loss_res_valid + loss_data_valid
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res"].append(loss_res_valid.item())
        logger["loss_data"].append(loss_data_valid.item())
        logger["iter"].append(it+1)
        
        # 保存训练loss最低的模型
        if loss_valid.item() < best_loss:
            model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(), 'nn_lam_state': pinn.nn_lam.state_dict()}
            torch.save(model_state, os.path.join(model_path, 'pinn_adam.pth'))
            best_loss = loss_valid.item()
        
        if (it + 1) % 500 == 0:
            # 保存并打印训练日志
            info = f'Iter # {it+1:6d}/{adam_iters}\t' + \
                f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_d:{loss_data.item():.2e}  ' + \
                f'Valid # loss:{loss_valid.item():.2e}, loss_r:{loss_res_valid.item():.2e}, loss_d:{loss_data_valid.item():.2e}'
            with open(train_info_path + 'train_info.txt', 'a') as f:
                f.write(info + '\n')
            print(info)
            
        # 衰减学习率
        if (it + 1) % 5000 == 0:
            lr_sche.step()
            lr_sche_lam.step()
# Out:
# forward with normalization, mu=[5.0, -2.5033952688602312e-09], sigma=[2.9454433917999268, 3.508115530014038]
# Iter #    500/200000	loss:4.15e+00, loss_r:8.35e-04, loss_d:3.31e-03  Valid # loss:4.14e-03, loss_r:8.34e-04, loss_d:3.31e-03
# Iter #   1000/200000	loss:2.01e+00, loss_r:4.84e-04, loss_d:1.52e-03  Valid # loss:2.01e-03, loss_r:4.84e-04, loss_d:1.52e-03
# Iter #   1500/200000	loss:1.20e+00, loss_r:3.24e-04, loss_d:8.75e-04  Valid # loss:1.20e-03, loss_r:3.24e-04, loss_d:8.74e-04
# Iter #   2000/200000	loss:7.20e-01, loss_r:2.07e-04, loss_d:5.14e-04  Valid # loss:7.20e-04, loss_r:2.07e-04, loss_d:5.13e-04
# Iter #   2500/200000	loss:4.21e-01, loss_r:1.22e-04, loss_d:2.99e-04  Valid # loss:4.20e-04, loss_r:1.22e-04, loss_d:2.98e-04
# Iter #   3000/200000	loss:2.54e-01, loss_r:7.42e-05, loss_d:1.80e-04  Valid # loss:2.55e-04, loss_r:7.33e-05, loss_d:1.82e-04
# Iter #   3500/200000	loss:1.74e-01, loss_r:4.96e-05, loss_d:1.25e-04  Valid # loss:1.74e-04, loss_r:4.83e-05, loss_d:1.26e-04
# Iter #   4000/200000	loss:1.48e-01, loss_r:4.17e-05, loss_d:1.07e-04  Valid # loss:1.58e-04, loss_r:4.70e-05, loss_d:1.11e-04
# Iter #   4500/200000	loss:1.23e-01, loss_r:3.30e-05, loss_d:9.02e-05  Valid # loss:1.14e-04, loss_r:2.82e-05, loss_d:8.63e-05
# Iter #   5000/200000	loss:9.82e-02, loss_r:2.29e-05, loss_d:7.53e-05  Valid # loss:9.80e-05, loss_r:2.28e-05, loss_d:7.52e-05
# Iter #   5500/200000	loss:1.28e-01, loss_r:3.67e-05, loss_d:9.13e-05  Valid # loss:1.32e-04, loss_r:3.78e-05, loss_d:9.46e-05
# Iter #   6000/200000	loss:8.37e-02, loss_r:1.80e-05, loss_d:6.57e-05  Valid # loss:8.36e-05, loss_r:1.79e-05, loss_d:6.57e-05
# Iter #   6500/200000	loss:7.86e-02, loss_r:1.63e-05, loss_d:6.23e-05  Valid # loss:7.86e-05, loss_r:1.62e-05, loss_d:6.23e-05
# Iter #   7000/200000	loss:7.47e-02, loss_r:1.49e-05, loss_d:5.98e-05  Valid # loss:7.47e-05, loss_r:1.51e-05, loss_d:5.96e-05
# Iter #   7500/200000	loss:7.54e-02, loss_r:1.54e-05, loss_d:6.01e-05  Valid # loss:7.51e-05, loss_r:1.58e-05, loss_d:5.93e-05
# Iter #   8000/200000	loss:6.74e-02, loss_r:1.27e-05, loss_d:5.47e-05  Valid # loss:6.73e-05, loss_r:1.28e-05, loss_d:5.45e-05
# Iter #   8500/200000	loss:6.79e-02, loss_r:1.36e-05, loss_d:5.43e-05  Valid # loss:6.77e-05, loss_r:1.30e-05, loss_d:5.46e-05
# Iter #   9000/200000	loss:6.14e-02, loss_r:1.13e-05, loss_d:5.01e-05  Valid # loss:6.14e-05, loss_r:1.12e-05, loss_d:5.01e-05
# Iter #   9500/200000	loss:5.91e-02, loss_r:1.09e-05, loss_d:4.82e-05  Valid # loss:5.93e-05, loss_r:1.09e-05, loss_d:4.84e-05
# Iter #  10000/200000	loss:7.45e-02, loss_r:1.92e-05, loss_d:5.52e-05  Valid # loss:9.20e-05, loss_r:2.76e-05, loss_d:6.44e-05
# Iter #  10500/200000	loss:5.36e-02, loss_r:9.85e-06, loss_d:4.37e-05  Valid # loss:5.36e-05, loss_r:9.84e-06, loss_d:4.37e-05
# Iter #  11000/200000	loss:6.26e-02, loss_r:1.36e-05, loss_d:4.90e-05  Valid # loss:6.90e-05, loss_r:1.76e-05, loss_d:5.14e-05
# Iter #  11500/200000	loss:6.22e-02, loss_r:1.46e-05, loss_d:4.76e-05  Valid # loss:7.04e-05, loss_r:1.70e-05, loss_d:5.34e-05
# Iter #  12000/200000	loss:5.02e-02, loss_r:1.15e-05, loss_d:3.87e-05  Valid # loss:5.23e-05, loss_r:1.20e-05, loss_d:4.03e-05
# Iter #  12500/200000	loss:4.25e-02, loss_r:8.50e-06, loss_d:3.40e-05  Valid # loss:4.25e-05, loss_r:8.50e-06, loss_d:3.40e-05
# Iter #  13000/200000	loss:3.99e-02, loss_r:8.28e-06, loss_d:3.16e-05  Valid # loss:3.99e-05, loss_r:8.24e-06, loss_d:3.17e-05
# Iter #  13500/200000	loss:3.87e-02, loss_r:8.41e-06, loss_d:3.03e-05  Valid # loss:3.90e-05, loss_r:8.85e-06, loss_d:3.01e-05
# Iter #  14000/200000	loss:3.76e-01, loss_r:1.30e-04, loss_d:2.45e-04  Valid # loss:2.58e-04, loss_r:9.26e-05, loss_d:1.66e-04
# Iter #  14500/200000	loss:3.32e-02, loss_r:7.39e-06, loss_d:2.58e-05  Valid # loss:3.32e-05, loss_r:7.39e-06, loss_d:2.58e-05
# Iter #  15000/200000	loss:3.15e-02, loss_r:7.24e-06, loss_d:2.43e-05  Valid # loss:3.18e-05, loss_r:7.44e-06, loss_d:2.44e-05
# Iter #  15500/200000	loss:2.96e-02, loss_r:6.86e-06, loss_d:2.28e-05  Valid # loss:2.96e-05, loss_r:6.86e-06, loss_d:2.28e-05
# Iter #  16000/200000	loss:2.83e-02, loss_r:6.75e-06, loss_d:2.15e-05  Valid # loss:2.84e-05, loss_r:6.91e-06, loss_d:2.15e-05
# Iter #  16500/200000	loss:2.85e-02, loss_r:7.16e-06, loss_d:2.14e-05  Valid # loss:3.06e-05, loss_r:8.21e-06, loss_d:2.24e-05
# Iter #  17000/200000	loss:1.41e-01, loss_r:5.35e-05, loss_d:8.75e-05  Valid # loss:1.85e-04, loss_r:7.16e-05, loss_d:1.13e-04
# Iter #  17500/200000	loss:2.39e-02, loss_r:6.04e-06, loss_d:1.78e-05  Valid # loss:2.39e-05, loss_r:6.03e-06, loss_d:1.78e-05
# Iter #  18000/200000	loss:2.27e-02, loss_r:5.88e-06, loss_d:1.68e-05  Valid # loss:2.27e-05, loss_r:5.89e-06, loss_d:1.68e-05
# Iter #  18500/200000	loss:2.16e-02, loss_r:5.75e-06, loss_d:1.58e-05  Valid # loss:2.19e-05, loss_r:5.84e-06, loss_d:1.61e-05
# Iter #  19000/200000	loss:2.06e-02, loss_r:5.64e-06, loss_d:1.50e-05  Valid # loss:2.06e-05, loss_r:5.61e-06, loss_d:1.50e-05
# Iter #  19500/200000	loss:2.01e-02, loss_r:5.65e-06, loss_d:1.44e-05  Valid # loss:2.55e-05, loss_r:7.50e-06, loss_d:1.80e-05
# Iter #  20000/200000	loss:8.40e-02, loss_r:3.08e-05, loss_d:5.32e-05  Valid # loss:1.21e-04, loss_r:4.57e-05, loss_d:7.49e-05
# Iter #  20500/200000	loss:2.04e-02, loss_r:5.96e-06, loss_d:1.44e-05  Valid # loss:2.00e-05, loss_r:5.95e-06, loss_d:1.41e-05
# Iter #  21000/200000	loss:2.51e-02, loss_r:7.94e-06, loss_d:1.72e-05  Valid # loss:1.98e-05, loss_r:6.26e-06, loss_d:1.36e-05
# Iter #  21500/200000	loss:1.63e-02, loss_r:4.75e-06, loss_d:1.15e-05  Valid # loss:1.63e-05, loss_r:4.75e-06, loss_d:1.15e-05
# Iter #  22000/200000	loss:1.56e-02, loss_r:4.59e-06, loss_d:1.11e-05  Valid # loss:1.57e-05, loss_r:4.60e-06, loss_d:1.11e-05
# Iter #  22500/200000	loss:1.51e-02, loss_r:4.43e-06, loss_d:1.06e-05  Valid # loss:1.51e-05, loss_r:4.43e-06, loss_d:1.06e-05
# Iter #  23000/200000	loss:8.42e-02, loss_r:2.93e-05, loss_d:5.49e-05  Valid # loss:1.11e-04, loss_r:4.01e-05, loss_d:7.09e-05
# Iter #  23500/200000	loss:1.40e-02, loss_r:4.13e-06, loss_d:9.86e-06  Valid # loss:1.40e-05, loss_r:4.13e-06, loss_d:9.86e-06
# Iter #  24000/200000	loss:4.60e-02, loss_r:1.59e-05, loss_d:3.01e-05  Valid # loss:5.96e-05, loss_r:2.12e-05, loss_d:3.84e-05
# Iter #  24500/200000	loss:1.36e-02, loss_r:4.07e-06, loss_d:9.57e-06  Valid # loss:1.33e-05, loss_r:3.94e-06, loss_d:9.34e-06
# Iter #  25000/200000	loss:1.27e-02, loss_r:3.73e-06, loss_d:8.95e-06  Valid # loss:1.27e-05, loss_r:3.73e-06, loss_d:8.95e-06
# Iter #  25500/200000	loss:1.23e-02, loss_r:3.60e-06, loss_d:8.68e-06  Valid # loss:1.23e-05, loss_r:3.60e-06, loss_d:8.68e-06
# Iter #  26000/200000	loss:1.20e-02, loss_r:3.54e-06, loss_d:8.50e-06  Valid # loss:1.25e-05, loss_r:3.70e-06, loss_d:8.80e-06
# Iter #  26500/200000	loss:1.18e-02, loss_r:3.46e-06, loss_d:8.30e-06  Valid # loss:1.17e-05, loss_r:3.42e-06, loss_d:8.27e-06
# Iter #  27000/200000	loss:1.13e-02, loss_r:3.32e-06, loss_d:8.02e-06  Valid # loss:1.30e-05, loss_r:3.84e-06, loss_d:9.11e-06
# Iter #  27500/200000	loss:1.09e-02, loss_r:3.18e-06, loss_d:7.76e-06  Valid # loss:1.09e-05, loss_r:3.19e-06, loss_d:7.76e-06
# Iter #  28000/200000	loss:1.07e-02, loss_r:3.11e-06, loss_d:7.59e-06  Valid # loss:1.07e-05, loss_r:3.11e-06, loss_d:7.61e-06
# Iter #  28500/200000	loss:1.07e-02, loss_r:3.14e-06, loss_d:7.54e-06  Valid # loss:1.05e-05, loss_r:3.08e-06, loss_d:7.42e-06
# Iter #  29000/200000	loss:1.01e-02, loss_r:2.94e-06, loss_d:7.20e-06  Valid # loss:1.01e-05, loss_r:2.93e-06, loss_d:7.21e-06
# Iter #  29500/200000	loss:9.88e-03, loss_r:2.86e-06, loss_d:7.02e-06  Valid # loss:9.88e-06, loss_r:2.85e-06, loss_d:7.02e-06
# Iter #  30000/200000	loss:9.64e-03, loss_r:2.78e-06, loss_d:6.87e-06  Valid # loss:9.64e-06, loss_r:2.78e-06, loss_d:6.86e-06
# Iter #  30500/200000	loss:1.29e-02, loss_r:3.98e-06, loss_d:8.97e-06  Valid # loss:2.75e-05, loss_r:9.13e-06, loss_d:1.84e-05
# Iter #  31000/200000	loss:9.25e-03, loss_r:2.65e-06, loss_d:6.59e-06  Valid # loss:9.57e-06, loss_r:2.75e-06, loss_d:6.82e-06
# Iter #  31500/200000	loss:8.98e-03, loss_r:2.56e-06, loss_d:6.43e-06  Valid # loss:8.98e-06, loss_r:2.56e-06, loss_d:6.43e-06
# Iter #  32000/200000	loss:8.78e-03, loss_r:2.49e-06, loss_d:6.29e-06  Valid # loss:8.78e-06, loss_r:2.49e-06, loss_d:6.29e-06
# Iter #  32500/200000	loss:8.59e-03, loss_r:2.42e-06, loss_d:6.17e-06  Valid # loss:8.59e-06, loss_r:2.42e-06, loss_d:6.17e-06
# Iter #  33000/200000	loss:8.52e-03, loss_r:2.40e-06, loss_d:6.11e-06  Valid # loss:8.59e-06, loss_r:2.42e-06, loss_d:6.17e-06
# Iter #  33500/200000	loss:2.36e-02, loss_r:7.18e-06, loss_d:1.64e-05  Valid # loss:2.22e-05, loss_r:6.68e-06, loss_d:1.55e-05
# Iter #  34000/200000	loss:8.05e-03, loss_r:2.24e-06, loss_d:5.81e-06  Valid # loss:8.06e-06, loss_r:2.24e-06, loss_d:5.82e-06
# Iter #  34500/200000	loss:9.58e-02, loss_r:3.05e-05, loss_d:6.53e-05  Valid # loss:7.46e-05, loss_r:2.30e-05, loss_d:5.16e-05
# Iter #  35000/200000	loss:7.70e-03, loss_r:2.12e-06, loss_d:5.58e-06  Valid # loss:7.70e-06, loss_r:2.12e-06, loss_d:5.58e-06
# Iter #  35500/200000	loss:8.73e-03, loss_r:2.46e-06, loss_d:6.27e-06  Valid # loss:9.27e-06, loss_r:2.65e-06, loss_d:6.62e-06
# Iter #  36000/200000	loss:7.41e-03, loss_r:2.01e-06, loss_d:5.39e-06  Valid # loss:7.42e-06, loss_r:2.02e-06, loss_d:5.39e-06
# Iter #  36500/200000	loss:7.24e-03, loss_r:1.96e-06, loss_d:5.27e-06  Valid # loss:7.24e-06, loss_r:1.96e-06, loss_d:5.27e-06
# Iter #  37000/200000	loss:7.57e-03, loss_r:2.07e-06, loss_d:5.50e-06  Valid # loss:7.88e-06, loss_r:2.20e-06, loss_d:5.68e-06
# Iter #  37500/200000	loss:6.96e-03, loss_r:1.87e-06, loss_d:5.09e-06  Valid # loss:6.96e-06, loss_r:1.87e-06, loss_d:5.09e-06
# Iter #  38000/200000	loss:7.69e-03, loss_r:2.13e-06, loss_d:5.55e-06  Valid # loss:7.08e-06, loss_r:2.00e-06, loss_d:5.08e-06
# Iter #  38500/200000	loss:7.12e-03, loss_r:1.93e-06, loss_d:5.19e-06  Valid # loss:7.41e-06, loss_r:2.01e-06, loss_d:5.40e-06
# Iter #  39000/200000	loss:5.84e-02, loss_r:1.87e-05, loss_d:3.97e-05  Valid # loss:5.65e-05, loss_r:1.77e-05, loss_d:3.87e-05
# Iter #  39500/200000	loss:6.53e-03, loss_r:1.75e-06, loss_d:4.78e-06  Valid # loss:6.65e-06, loss_r:1.81e-06, loss_d:4.84e-06
# Iter #  40000/200000	loss:6.80e-03, loss_r:1.85e-06, loss_d:4.95e-06  Valid # loss:7.27e-06, loss_r:2.05e-06, loss_d:5.22e-06
# Iter #  40500/200000	loss:6.22e-03, loss_r:1.66e-06, loss_d:4.56e-06  Valid # loss:6.22e-06, loss_r:1.65e-06, loss_d:4.57e-06
# Iter #  41000/200000	loss:6.31e-03, loss_r:1.68e-06, loss_d:4.63e-06  Valid # loss:6.40e-06, loss_r:1.75e-06, loss_d:4.65e-06
# Iter #  41500/200000	loss:6.10e-03, loss_r:1.67e-06, loss_d:4.42e-06  Valid # loss:6.16e-06, loss_r:1.73e-06, loss_d:4.43e-06
# Iter #  42000/200000	loss:5.91e-03, loss_r:1.57e-06, loss_d:4.34e-06  Valid # loss:5.91e-06, loss_r:1.58e-06, loss_d:4.34e-06
# Iter #  42500/200000	loss:5.86e-03, loss_r:1.56e-06, loss_d:4.30e-06  Valid # loss:6.02e-06, loss_r:1.63e-06, loss_d:4.39e-06
# Iter #  43000/200000	loss:7.01e-03, loss_r:2.07e-06, loss_d:4.94e-06  Valid # loss:1.30e-05, loss_r:4.42e-06, loss_d:8.60e-06
# Iter #  43500/200000	loss:6.39e-03, loss_r:1.81e-06, loss_d:4.59e-06  Valid # loss:5.87e-06, loss_r:1.65e-06, loss_d:4.22e-06
# Iter #  44000/200000	loss:6.20e-03, loss_r:1.74e-06, loss_d:4.46e-06  Valid # loss:6.60e-06, loss_r:1.86e-06, loss_d:4.74e-06
# Iter #  44500/200000	loss:5.48e-03, loss_r:1.47e-06, loss_d:4.01e-06  Valid # loss:5.49e-06, loss_r:1.47e-06, loss_d:4.02e-06
# Iter #  45000/200000	loss:5.54e-03, loss_r:1.48e-06, loss_d:4.06e-06  Valid # loss:5.84e-06, loss_r:1.59e-06, loss_d:4.25e-06
# Iter #  45500/200000	loss:5.36e-03, loss_r:1.46e-06, loss_d:3.89e-06  Valid # loss:5.42e-06, loss_r:1.51e-06, loss_d:3.90e-06
# Iter #  46000/200000	loss:9.52e-03, loss_r:3.02e-06, loss_d:6.50e-06  Valid # loss:1.04e-05, loss_r:3.24e-06, loss_d:7.21e-06
# Iter #  46500/200000	loss:5.23e-03, loss_r:1.42e-06, loss_d:3.81e-06  Valid # loss:5.96e-06, loss_r:1.65e-06, loss_d:4.31e-06
# Iter #  47000/200000	loss:7.50e-03, loss_r:2.14e-06, loss_d:5.35e-06  Valid # loss:8.65e-06, loss_r:2.55e-06, loss_d:6.09e-06
# Iter #  47500/200000	loss:1.25e-02, loss_r:3.95e-06, loss_d:8.54e-06  Valid # loss:1.34e-05, loss_r:4.19e-06, loss_d:9.22e-06
# Iter #  48000/200000	loss:5.34e-03, loss_r:1.50e-06, loss_d:3.85e-06  Valid # loss:5.02e-06, loss_r:1.37e-06, loss_d:3.65e-06
# Iter #  48500/200000	loss:6.05e-03, loss_r:1.75e-06, loss_d:4.30e-06  Valid # loss:5.11e-06, loss_r:1.44e-06, loss_d:3.67e-06
# Iter #  49000/200000	loss:5.56e-03, loss_r:1.57e-06, loss_d:3.99e-06  Valid # loss:6.25e-06, loss_r:1.86e-06, loss_d:4.39e-06
# Iter #  49500/200000	loss:4.71e-03, loss_r:1.29e-06, loss_d:3.42e-06  Valid # loss:4.69e-06, loss_r:1.28e-06, loss_d:3.41e-06
# Iter #  50000/200000	loss:4.64e-03, loss_r:1.27e-06, loss_d:3.36e-06  Valid # loss:4.63e-06, loss_r:1.27e-06, loss_d:3.36e-06
# Iter #  50500/200000	loss:4.65e-03, loss_r:1.30e-06, loss_d:3.35e-06  Valid # loss:4.59e-06, loss_r:1.27e-06, loss_d:3.32e-06
# Iter #  51000/200000	loss:4.48e-03, loss_r:1.23e-06, loss_d:3.25e-06  Valid # loss:4.48e-06, loss_r:1.24e-06, loss_d:3.25e-06
# Iter #  51500/200000	loss:4.43e-03, loss_r:1.22e-06, loss_d:3.21e-06  Valid # loss:4.43e-06, loss_r:1.23e-06, loss_d:3.20e-06
# Iter #  52000/200000	loss:4.35e-03, loss_r:1.21e-06, loss_d:3.15e-06  Valid # loss:4.38e-06, loss_r:1.22e-06, loss_d:3.16e-06
# Iter #  52500/200000	loss:5.78e-03, loss_r:1.71e-06, loss_d:4.08e-06  Valid # loss:6.09e-06, loss_r:1.85e-06, loss_d:4.24e-06
# Iter #  53000/200000	loss:4.23e-03, loss_r:1.18e-06, loss_d:3.05e-06  Valid # loss:4.23e-06, loss_r:1.18e-06, loss_d:3.05e-06
# Iter #  53500/200000	loss:4.96e-03, loss_r:1.41e-06, loss_d:3.55e-06  Valid # loss:4.85e-06, loss_r:1.39e-06, loss_d:3.46e-06
# Iter #  54000/200000	loss:4.19e-03, loss_r:1.18e-06, loss_d:3.01e-06  Valid # loss:4.21e-06, loss_r:1.19e-06, loss_d:3.02e-06
# Iter #  54500/200000	loss:4.14e-03, loss_r:1.17e-06, loss_d:2.97e-06  Valid # loss:4.14e-06, loss_r:1.18e-06, loss_d:2.96e-06
# Iter #  55000/200000	loss:4.09e-03, loss_r:1.16e-06, loss_d:2.93e-06  Valid # loss:4.09e-06, loss_r:1.17e-06, loss_d:2.92e-06
# Iter #  55500/200000	loss:3.94e-03, loss_r:1.12e-06, loss_d:2.82e-06  Valid # loss:3.94e-06, loss_r:1.12e-06, loss_d:2.82e-06
# Iter #  56000/200000	loss:3.89e-03, loss_r:1.11e-06, loss_d:2.78e-06  Valid # loss:3.89e-06, loss_r:1.11e-06, loss_d:2.78e-06
# Iter #  56500/200000	loss:5.75e-03, loss_r:1.68e-06, loss_d:4.07e-06  Valid # loss:6.44e-06, loss_r:1.87e-06, loss_d:4.57e-06
# Iter #  57000/200000	loss:3.98e-03, loss_r:1.14e-06, loss_d:2.83e-06  Valid # loss:3.83e-06, loss_r:1.10e-06, loss_d:2.73e-06
# Iter #  57500/200000	loss:4.04e-03, loss_r:1.17e-06, loss_d:2.87e-06  Valid # loss:4.95e-06, loss_r:1.51e-06, loss_d:3.44e-06
# Iter #  58000/200000	loss:3.90e-03, loss_r:1.18e-06, loss_d:2.73e-06  Valid # loss:4.18e-06, loss_r:1.24e-06, loss_d:2.94e-06
# Iter #  58500/200000	loss:2.33e-02, loss_r:7.17e-06, loss_d:1.61e-05  Valid # loss:2.26e-05, loss_r:7.05e-06, loss_d:1.55e-05
# Iter #  59000/200000	loss:6.82e-03, loss_r:2.14e-06, loss_d:4.68e-06  Valid # loss:4.11e-06, loss_r:1.21e-06, loss_d:2.90e-06
# Iter #  59500/200000	loss:3.91e-03, loss_r:1.20e-06, loss_d:2.72e-06  Valid # loss:3.76e-06, loss_r:1.12e-06, loss_d:2.64e-06
# Iter #  60000/200000	loss:5.16e-03, loss_r:1.59e-06, loss_d:3.57e-06  Valid # loss:5.38e-06, loss_r:1.65e-06, loss_d:3.73e-06
# Iter #  60500/200000	loss:3.42e-03, loss_r:1.01e-06, loss_d:2.42e-06  Valid # loss:3.43e-06, loss_r:1.01e-06, loss_d:2.42e-06
# Iter #  61000/200000	loss:3.44e-03, loss_r:1.03e-06, loss_d:2.41e-06  Valid # loss:3.50e-06, loss_r:1.03e-06, loss_d:2.47e-06
# Iter #  61500/200000	loss:3.37e-03, loss_r:1.00e-06, loss_d:2.36e-06  Valid # loss:3.47e-06, loss_r:1.03e-06, loss_d:2.44e-06
# Iter #  62000/200000	loss:3.30e-03, loss_r:9.86e-07, loss_d:2.31e-06  Valid # loss:3.29e-06, loss_r:9.84e-07, loss_d:2.31e-06
# Iter #  62500/200000	loss:3.64e-03, loss_r:1.17e-06, loss_d:2.47e-06  Valid # loss:3.69e-06, loss_r:1.15e-06, loss_d:2.54e-06
# Iter #  63000/200000	loss:3.21e-03, loss_r:9.59e-07, loss_d:2.25e-06  Valid # loss:3.20e-06, loss_r:9.63e-07, loss_d:2.24e-06
# Iter #  63500/200000	loss:4.83e-03, loss_r:1.56e-06, loss_d:3.27e-06  Valid # loss:4.16e-06, loss_r:1.37e-06, loss_d:2.79e-06
# Iter #  64000/200000	loss:3.12e-03, loss_r:9.43e-07, loss_d:2.18e-06  Valid # loss:3.13e-06, loss_r:9.45e-07, loss_d:2.18e-06
# Iter #  64500/200000	loss:3.09e-03, loss_r:9.37e-07, loss_d:2.16e-06  Valid # loss:3.12e-06, loss_r:9.54e-07, loss_d:2.17e-06
# Iter #  65000/200000	loss:3.20e-03, loss_r:9.96e-07, loss_d:2.21e-06  Valid # loss:3.55e-06, loss_r:1.11e-06, loss_d:2.45e-06
# Iter #  65500/200000	loss:3.14e-03, loss_r:9.58e-07, loss_d:2.18e-06  Valid # loss:3.15e-06, loss_r:9.72e-07, loss_d:2.18e-06
# Iter #  66000/200000	loss:2.94e-03, loss_r:9.03e-07, loss_d:2.04e-06  Valid # loss:2.94e-06, loss_r:9.01e-07, loss_d:2.04e-06
# Iter #  66500/200000	loss:2.97e-03, loss_r:9.20e-07, loss_d:2.05e-06  Valid # loss:2.99e-06, loss_r:9.17e-07, loss_d:2.07e-06
# Iter #  67000/200000	loss:5.43e-03, loss_r:2.02e-06, loss_d:3.40e-06  Valid # loss:5.98e-06, loss_r:1.92e-06, loss_d:4.06e-06
# Iter #  67500/200000	loss:5.05e-03, loss_r:1.62e-06, loss_d:3.43e-06  Valid # loss:5.73e-06, loss_r:1.87e-06, loss_d:3.86e-06
# Iter #  68000/200000	loss:2.83e-03, loss_r:8.86e-07, loss_d:1.95e-06  Valid # loss:2.83e-06, loss_r:8.83e-07, loss_d:1.95e-06
# Iter #  68500/200000	loss:2.74e-03, loss_r:8.58e-07, loss_d:1.88e-06  Valid # loss:2.74e-06, loss_r:8.58e-07, loss_d:1.88e-06
# Iter #  69000/200000	loss:4.33e-03, loss_r:1.46e-06, loss_d:2.87e-06  Valid # loss:5.38e-06, loss_r:1.79e-06, loss_d:3.59e-06
# Iter #  69500/200000	loss:3.66e-03, loss_r:1.17e-06, loss_d:2.49e-06  Valid # loss:2.79e-06, loss_r:8.75e-07, loss_d:1.91e-06
# Iter #  70000/200000	loss:2.65e-03, loss_r:8.44e-07, loss_d:1.81e-06  Valid # loss:2.81e-06, loss_r:8.90e-07, loss_d:1.92e-06
# Iter #  70500/200000	loss:2.63e-03, loss_r:8.45e-07, loss_d:1.79e-06  Valid # loss:2.63e-06, loss_r:8.48e-07, loss_d:1.79e-06
# Iter #  71000/200000	loss:3.48e-03, loss_r:1.10e-06, loss_d:2.38e-06  Valid # loss:2.76e-06, loss_r:8.99e-07, loss_d:1.86e-06
# Iter #  71500/200000	loss:2.53e-03, loss_r:8.10e-07, loss_d:1.72e-06  Valid # loss:2.53e-06, loss_r:8.09e-07, loss_d:1.72e-06
# Iter #  72000/200000	loss:2.49e-03, loss_r:8.02e-07, loss_d:1.69e-06  Valid # loss:2.49e-06, loss_r:8.02e-07, loss_d:1.69e-06
# Iter #  72500/200000	loss:4.13e-03, loss_r:1.31e-06, loss_d:2.82e-06  Valid # loss:4.79e-06, loss_r:1.49e-06, loss_d:3.30e-06
# Iter #  73000/200000	loss:2.94e-03, loss_r:9.50e-07, loss_d:1.99e-06  Valid # loss:2.57e-06, loss_r:8.33e-07, loss_d:1.74e-06
# Iter #  73500/200000	loss:2.40e-03, loss_r:7.82e-07, loss_d:1.62e-06  Valid # loss:2.42e-06, loss_r:7.90e-07, loss_d:1.63e-06
# Iter #  74000/200000	loss:2.42e-03, loss_r:7.96e-07, loss_d:1.63e-06  Valid # loss:2.41e-06, loss_r:7.90e-07, loss_d:1.62e-06
# Iter #  74500/200000	loss:1.39e-02, loss_r:4.47e-06, loss_d:9.40e-06  Valid # loss:9.95e-06, loss_r:3.15e-06, loss_d:6.79e-06
# Iter #  75000/200000	loss:2.31e-03, loss_r:7.68e-07, loss_d:1.54e-06  Valid # loss:2.31e-06, loss_r:7.69e-07, loss_d:1.54e-06
# Iter #  75500/200000	loss:2.27e-03, loss_r:7.50e-07, loss_d:1.52e-06  Valid # loss:2.27e-06, loss_r:7.50e-07, loss_d:1.52e-06
# Iter #  76000/200000	loss:7.48e-03, loss_r:2.32e-06, loss_d:5.16e-06  Valid # loss:7.32e-06, loss_r:2.32e-06, loss_d:5.00e-06
# Iter #  76500/200000	loss:6.71e-03, loss_r:2.26e-06, loss_d:4.45e-06  Valid # loss:6.63e-06, loss_r:2.29e-06, loss_d:4.34e-06
# Iter #  77000/200000	loss:3.50e-03, loss_r:1.22e-06, loss_d:2.28e-06  Valid # loss:2.85e-06, loss_r:1.00e-06, loss_d:1.85e-06
# Iter #  77500/200000	loss:2.18e-03, loss_r:7.34e-07, loss_d:1.44e-06  Valid # loss:2.18e-06, loss_r:7.30e-07, loss_d:1.45e-06
# Iter #  78000/200000	loss:2.32e-03, loss_r:9.00e-07, loss_d:1.42e-06  Valid # loss:2.38e-06, loss_r:9.63e-07, loss_d:1.42e-06
# Iter #  78500/200000	loss:2.10e-03, loss_r:7.09e-07, loss_d:1.39e-06  Valid # loss:2.10e-06, loss_r:7.08e-07, loss_d:1.39e-06
# Iter #  79000/200000	loss:2.22e-03, loss_r:8.36e-07, loss_d:1.38e-06  Valid # loss:2.26e-06, loss_r:8.76e-07, loss_d:1.38e-06
# Iter #  79500/200000	loss:2.07e-03, loss_r:7.07e-07, loss_d:1.36e-06  Valid # loss:2.27e-06, loss_r:7.60e-07, loss_d:1.51e-06
# Iter #  80000/200000	loss:4.77e-03, loss_r:1.57e-06, loss_d:3.20e-06  Valid # loss:3.88e-06, loss_r:1.33e-06, loss_d:2.55e-06
# Iter #  80500/200000	loss:1.99e-03, loss_r:6.82e-07, loss_d:1.31e-06  Valid # loss:1.99e-06, loss_r:6.85e-07, loss_d:1.31e-06
# Iter #  81000/200000	loss:2.16e-03, loss_r:7.52e-07, loss_d:1.40e-06  Valid # loss:2.15e-06, loss_r:7.43e-07, loss_d:1.41e-06
# Iter #  81500/200000	loss:1.94e-03, loss_r:6.71e-07, loss_d:1.27e-06  Valid # loss:1.94e-06, loss_r:6.72e-07, loss_d:1.27e-06
# Iter #  82000/200000	loss:1.96e-03, loss_r:7.07e-07, loss_d:1.25e-06  Valid # loss:1.99e-06, loss_r:7.32e-07, loss_d:1.25e-06
# Iter #  82500/200000	loss:1.89e-03, loss_r:6.52e-07, loss_d:1.23e-06  Valid # loss:1.89e-06, loss_r:6.52e-07, loss_d:1.23e-06
# Iter #  83000/200000	loss:1.96e-03, loss_r:7.41e-07, loss_d:1.22e-06  Valid # loss:1.97e-06, loss_r:7.48e-07, loss_d:1.22e-06
# Iter #  83500/200000	loss:2.23e-03, loss_r:7.61e-07, loss_d:1.46e-06  Valid # loss:2.14e-06, loss_r:7.44e-07, loss_d:1.40e-06
# Iter #  84000/200000	loss:1.84e-03, loss_r:6.52e-07, loss_d:1.19e-06  Valid # loss:1.92e-06, loss_r:6.75e-07, loss_d:1.24e-06
# Iter #  84500/200000	loss:1.81e-03, loss_r:6.33e-07, loss_d:1.17e-06  Valid # loss:1.84e-06, loss_r:6.42e-07, loss_d:1.19e-06
# Iter #  85000/200000	loss:1.02e-02, loss_r:3.73e-06, loss_d:6.44e-06  Valid # loss:8.17e-06, loss_r:2.89e-06, loss_d:5.27e-06
# Iter #  85500/200000	loss:4.16e-03, loss_r:1.47e-06, loss_d:2.69e-06  Valid # loss:2.85e-06, loss_r:9.57e-07, loss_d:1.89e-06
# Iter #  86000/200000	loss:2.18e-03, loss_r:7.86e-07, loss_d:1.40e-06  Valid # loss:2.31e-06, loss_r:8.17e-07, loss_d:1.49e-06
# Iter #  86500/200000	loss:1.70e-03, loss_r:6.01e-07, loss_d:1.10e-06  Valid # loss:1.70e-06, loss_r:6.01e-07, loss_d:1.10e-06
# Iter #  87000/200000	loss:1.69e-03, loss_r:5.98e-07, loss_d:1.09e-06  Valid # loss:1.68e-06, loss_r:5.95e-07, loss_d:1.08e-06
# Iter #  87500/200000	loss:1.68e-03, loss_r:6.03e-07, loss_d:1.08e-06  Valid # loss:1.67e-06, loss_r:5.97e-07, loss_d:1.07e-06
# Iter #  88000/200000	loss:1.66e-03, loss_r:5.93e-07, loss_d:1.07e-06  Valid # loss:1.66e-06, loss_r:5.91e-07, loss_d:1.07e-06
# Iter #  88500/200000	loss:1.67e-03, loss_r:6.09e-07, loss_d:1.06e-06  Valid # loss:1.69e-06, loss_r:6.33e-07, loss_d:1.06e-06
# Iter #  89000/200000	loss:1.60e-03, loss_r:5.72e-07, loss_d:1.03e-06  Valid # loss:1.60e-06, loss_r:5.71e-07, loss_d:1.03e-06
# Iter #  89500/200000	loss:1.58e-03, loss_r:5.67e-07, loss_d:1.01e-06  Valid # loss:1.58e-06, loss_r:5.70e-07, loss_d:1.01e-06
# Iter #  90000/200000	loss:5.34e-03, loss_r:1.72e-06, loss_d:3.62e-06  Valid # loss:3.83e-06, loss_r:1.29e-06, loss_d:2.53e-06
# Iter #  90500/200000	loss:1.59e-03, loss_r:5.69e-07, loss_d:1.02e-06  Valid # loss:1.62e-06, loss_r:5.84e-07, loss_d:1.04e-06
# Iter #  91000/200000	loss:1.63e-03, loss_r:5.91e-07, loss_d:1.04e-06  Valid # loss:1.53e-06, loss_r:5.53e-07, loss_d:9.73e-07
# Iter #  91500/200000	loss:1.79e-03, loss_r:6.31e-07, loss_d:1.16e-06  Valid # loss:1.91e-06, loss_r:6.86e-07, loss_d:1.23e-06
# Iter #  92000/200000	loss:1.52e-03, loss_r:5.52e-07, loss_d:9.67e-07  Valid # loss:1.54e-06, loss_r:5.56e-07, loss_d:9.88e-07
# Iter #  92500/200000	loss:1.47e-03, loss_r:5.34e-07, loss_d:9.32e-07  Valid # loss:1.47e-06, loss_r:5.34e-07, loss_d:9.32e-07
# Iter #  93000/200000	loss:1.45e-03, loss_r:5.29e-07, loss_d:9.20e-07  Valid # loss:1.45e-06, loss_r:5.29e-07, loss_d:9.20e-07
# Iter #  93500/200000	loss:1.43e-03, loss_r:5.24e-07, loss_d:9.10e-07  Valid # loss:1.44e-06, loss_r:5.26e-07, loss_d:9.10e-07
# Iter #  94000/200000	loss:1.42e-03, loss_r:5.22e-07, loss_d:9.00e-07  Valid # loss:1.43e-06, loss_r:5.25e-07, loss_d:9.01e-07
# Iter #  94500/200000	loss:2.09e-03, loss_r:8.47e-07, loss_d:1.25e-06  Valid # loss:1.59e-06, loss_r:6.42e-07, loss_d:9.44e-07
# Iter #  95000/200000	loss:1.40e-03, loss_r:5.26e-07, loss_d:8.76e-07  Valid # loss:1.41e-06, loss_r:5.29e-07, loss_d:8.79e-07
# Iter #  95500/200000	loss:1.37e-03, loss_r:5.05e-07, loss_d:8.62e-07  Valid # loss:1.37e-06, loss_r:5.05e-07, loss_d:8.62e-07
# Iter #  96000/200000	loss:1.35e-03, loss_r:5.01e-07, loss_d:8.50e-07  Valid # loss:1.35e-06, loss_r:5.00e-07, loss_d:8.50e-07
# Iter #  96500/200000	loss:1.52e-03, loss_r:5.53e-07, loss_d:9.70e-07  Valid # loss:1.56e-06, loss_r:5.70e-07, loss_d:9.87e-07
# Iter #  97000/200000	loss:1.70e-03, loss_r:6.09e-07, loss_d:1.09e-06  Valid # loss:1.83e-06, loss_r:6.57e-07, loss_d:1.17e-06
# Iter #  97500/200000	loss:1.31e-03, loss_r:4.88e-07, loss_d:8.18e-07  Valid # loss:1.31e-06, loss_r:4.88e-07, loss_d:8.20e-07
# Iter #  98000/200000	loss:1.29e-03, loss_r:4.83e-07, loss_d:8.09e-07  Valid # loss:1.30e-06, loss_r:4.86e-07, loss_d:8.11e-07
# Iter #  98500/200000	loss:1.44e-03, loss_r:5.70e-07, loss_d:8.69e-07  Valid # loss:1.32e-06, loss_r:5.13e-07, loss_d:8.09e-07
# Iter #  99000/200000	loss:1.28e-03, loss_r:4.85e-07, loss_d:7.94e-07  Valid # loss:1.28e-06, loss_r:4.89e-07, loss_d:7.93e-07
# Iter #  99500/200000	loss:1.27e-03, loss_r:4.81e-07, loss_d:7.89e-07  Valid # loss:1.32e-06, loss_r:5.00e-07, loss_d:8.24e-07
# Iter # 100000/200000	loss:1.27e-03, loss_r:4.91e-07, loss_d:7.79e-07  Valid # loss:1.27e-06, loss_r:4.88e-07, loss_d:7.79e-07
# Iter # 100500/200000	loss:1.23e-03, loss_r:4.75e-07, loss_d:7.58e-07  Valid # loss:1.26e-06, loss_r:5.00e-07, loss_d:7.59e-07
# Iter # 101000/200000	loss:1.51e-03, loss_r:5.62e-07, loss_d:9.48e-07  Valid # loss:1.61e-06, loss_r:5.80e-07, loss_d:1.03e-06
# Iter # 101500/200000	loss:1.44e-03, loss_r:5.35e-07, loss_d:9.07e-07  Valid # loss:1.29e-06, loss_r:4.89e-07, loss_d:8.02e-07
# Iter # 102000/200000	loss:2.69e-03, loss_r:9.67e-07, loss_d:1.73e-06  Valid # loss:2.50e-06, loss_r:8.82e-07, loss_d:1.62e-06
# Iter # 102500/200000	loss:1.85e-03, loss_r:6.87e-07, loss_d:1.16e-06  Valid # loss:1.56e-06, loss_r:5.88e-07, loss_d:9.68e-07
# Iter # 103000/200000	loss:1.33e-03, loss_r:6.07e-07, loss_d:7.26e-07  Valid # loss:1.37e-06, loss_r:6.48e-07, loss_d:7.26e-07
# Iter # 103500/200000	loss:2.46e-03, loss_r:8.54e-07, loss_d:1.60e-06  Valid # loss:2.64e-06, loss_r:9.34e-07, loss_d:1.70e-06
# Iter # 104000/200000	loss:1.29e-03, loss_r:5.12e-07, loss_d:7.74e-07  Valid # loss:1.55e-06, loss_r:6.00e-07, loss_d:9.48e-07
# Iter # 104500/200000	loss:1.15e-03, loss_r:4.45e-07, loss_d:7.06e-07  Valid # loss:1.19e-06, loss_r:4.52e-07, loss_d:7.42e-07
# Iter # 105000/200000	loss:1.12e-03, loss_r:4.33e-07, loss_d:6.88e-07  Valid # loss:1.11e-06, loss_r:4.30e-07, loss_d:6.81e-07
# Iter # 105500/200000	loss:1.10e-03, loss_r:4.27e-07, loss_d:6.75e-07  Valid # loss:1.10e-06, loss_r:4.27e-07, loss_d:6.72e-07
# Iter # 106000/200000	loss:1.16e-03, loss_r:4.47e-07, loss_d:7.13e-07  Valid # loss:1.19e-06, loss_r:4.64e-07, loss_d:7.30e-07
# Iter # 106500/200000	loss:1.09e-03, loss_r:4.27e-07, loss_d:6.60e-07  Valid # loss:1.08e-06, loss_r:4.25e-07, loss_d:6.56e-07
# Iter # 107000/200000	loss:1.10e-03, loss_r:4.26e-07, loss_d:6.73e-07  Valid # loss:1.11e-06, loss_r:4.31e-07, loss_d:6.74e-07
# Iter # 107500/200000	loss:1.10e-03, loss_r:4.32e-07, loss_d:6.68e-07  Valid # loss:1.11e-06, loss_r:4.31e-07, loss_d:6.82e-07
# Iter # 108000/200000	loss:1.16e-03, loss_r:5.04e-07, loss_d:6.61e-07  Valid # loss:1.19e-06, loss_r:5.21e-07, loss_d:6.67e-07
# Iter # 108500/200000	loss:1.20e-03, loss_r:4.61e-07, loss_d:7.36e-07  Valid # loss:1.22e-06, loss_r:4.60e-07, loss_d:7.62e-07
# Iter # 109000/200000	loss:1.07e-03, loss_r:4.37e-07, loss_d:6.28e-07  Valid # loss:1.10e-06, loss_r:4.58e-07, loss_d:6.42e-07
# Iter # 109500/200000	loss:1.16e-03, loss_r:4.84e-07, loss_d:6.77e-07  Valid # loss:1.21e-06, loss_r:5.08e-07, loss_d:6.98e-07
# Iter # 110000/200000	loss:1.04e-03, loss_r:4.21e-07, loss_d:6.21e-07  Valid # loss:1.03e-06, loss_r:4.13e-07, loss_d:6.13e-07
# Iter # 110500/200000	loss:1.02e-03, loss_r:4.04e-07, loss_d:6.13e-07  Valid # loss:1.00e-06, loss_r:3.97e-07, loss_d:6.05e-07
# Iter # 111000/200000	loss:1.10e-03, loss_r:4.35e-07, loss_d:6.65e-07  Valid # loss:1.21e-06, loss_r:4.80e-07, loss_d:7.33e-07
# Iter # 111500/200000	loss:1.25e-03, loss_r:4.97e-07, loss_d:7.54e-07  Valid # loss:1.33e-06, loss_r:5.31e-07, loss_d:8.03e-07
# Iter # 112000/200000	loss:1.17e-03, loss_r:5.17e-07, loss_d:6.51e-07  Valid # loss:1.22e-06, loss_r:5.45e-07, loss_d:6.72e-07
# Iter # 112500/200000	loss:9.69e-04, loss_r:3.87e-07, loss_d:5.81e-07  Valid # loss:9.66e-07, loss_r:3.89e-07, loss_d:5.77e-07
# Iter # 113000/200000	loss:9.77e-04, loss_r:4.00e-07, loss_d:5.77e-07  Valid # loss:9.50e-07, loss_r:3.85e-07, loss_d:5.65e-07
# Iter # 113500/200000	loss:9.56e-04, loss_r:3.84e-07, loss_d:5.72e-07  Valid # loss:9.90e-07, loss_r:3.98e-07, loss_d:5.92e-07
# Iter # 114000/200000	loss:9.32e-04, loss_r:3.77e-07, loss_d:5.55e-07  Valid # loss:9.31e-07, loss_r:3.77e-07, loss_d:5.54e-07
# Iter # 114500/200000	loss:9.44e-04, loss_r:3.86e-07, loss_d:5.59e-07  Valid # loss:9.69e-07, loss_r:3.87e-07, loss_d:5.82e-07
# Iter # 115000/200000	loss:9.11e-04, loss_r:3.71e-07, loss_d:5.40e-07  Valid # loss:9.11e-07, loss_r:3.71e-07, loss_d:5.40e-07
# Iter # 115500/200000	loss:9.76e-04, loss_r:4.28e-07, loss_d:5.48e-07  Valid # loss:1.02e-06, loss_r:4.67e-07, loss_d:5.53e-07
# Iter # 116000/200000	loss:8.94e-04, loss_r:3.65e-07, loss_d:5.28e-07  Valid # loss:8.93e-07, loss_r:3.65e-07, loss_d:5.28e-07
# Iter # 116500/200000	loss:9.38e-04, loss_r:3.88e-07, loss_d:5.50e-07  Valid # loss:9.12e-07, loss_r:3.71e-07, loss_d:5.41e-07
# Iter # 117000/200000	loss:8.79e-04, loss_r:3.60e-07, loss_d:5.18e-07  Valid # loss:8.81e-07, loss_r:3.63e-07, loss_d:5.18e-07
# Iter # 117500/200000	loss:8.99e-04, loss_r:3.82e-07, loss_d:5.17e-07  Valid # loss:8.94e-07, loss_r:3.79e-07, loss_d:5.15e-07
# Iter # 118000/200000	loss:8.66e-04, loss_r:3.57e-07, loss_d:5.08e-07  Valid # loss:8.64e-07, loss_r:3.56e-07, loss_d:5.08e-07
# Iter # 118500/200000	loss:8.56e-04, loss_r:3.54e-07, loss_d:5.02e-07  Valid # loss:8.57e-07, loss_r:3.55e-07, loss_d:5.02e-07
# Iter # 119000/200000	loss:1.58e-03, loss_r:6.50e-07, loss_d:9.28e-07  Valid # loss:1.80e-06, loss_r:7.62e-07, loss_d:1.04e-06
# Iter # 119500/200000	loss:8.39e-04, loss_r:3.49e-07, loss_d:4.90e-07  Valid # loss:8.39e-07, loss_r:3.48e-07, loss_d:4.90e-07
# Iter # 120000/200000	loss:8.77e-04, loss_r:3.62e-07, loss_d:5.14e-07  Valid # loss:8.83e-07, loss_r:3.60e-07, loss_d:5.23e-07
# Iter # 120500/200000	loss:8.24e-04, loss_r:3.44e-07, loss_d:4.80e-07  Valid # loss:8.24e-07, loss_r:3.44e-07, loss_d:4.79e-07
# Iter # 121000/200000	loss:1.02e-03, loss_r:4.32e-07, loss_d:5.88e-07  Valid # loss:9.83e-07, loss_r:4.16e-07, loss_d:5.67e-07
# Iter # 121500/200000	loss:8.30e-04, loss_r:3.49e-07, loss_d:4.80e-07  Valid # loss:8.46e-07, loss_r:3.61e-07, loss_d:4.85e-07
# Iter # 122000/200000	loss:1.02e-03, loss_r:4.08e-07, loss_d:6.11e-07  Valid # loss:1.02e-06, loss_r:4.16e-07, loss_d:6.09e-07
# Iter # 122500/200000	loss:7.98e-04, loss_r:3.36e-07, loss_d:4.61e-07  Valid # loss:7.98e-07, loss_r:3.38e-07, loss_d:4.61e-07
# Iter # 123000/200000	loss:7.91e-04, loss_r:3.34e-07, loss_d:4.57e-07  Valid # loss:7.91e-07, loss_r:3.35e-07, loss_d:4.57e-07
# Iter # 123500/200000	loss:8.18e-04, loss_r:3.45e-07, loss_d:4.73e-07  Valid # loss:8.31e-07, loss_r:3.45e-07, loss_d:4.86e-07
# Iter # 124000/200000	loss:7.79e-04, loss_r:3.32e-07, loss_d:4.46e-07  Valid # loss:7.83e-07, loss_r:3.32e-07, loss_d:4.51e-07
# Iter # 124500/200000	loss:8.08e-04, loss_r:3.57e-07, loss_d:4.51e-07  Valid # loss:8.15e-07, loss_r:3.61e-07, loss_d:4.53e-07
# Iter # 125000/200000	loss:8.51e-04, loss_r:3.51e-07, loss_d:5.00e-07  Valid # loss:7.94e-07, loss_r:3.37e-07, loss_d:4.57e-07
# Iter # 125500/200000	loss:7.55e-04, loss_r:3.23e-07, loss_d:4.32e-07  Valid # loss:7.55e-07, loss_r:3.23e-07, loss_d:4.32e-07
# Iter # 126000/200000	loss:7.51e-04, loss_r:3.21e-07, loss_d:4.29e-07  Valid # loss:7.50e-07, loss_r:3.22e-07, loss_d:4.28e-07
# Iter # 126500/200000	loss:7.43e-04, loss_r:3.19e-07, loss_d:4.23e-07  Valid # loss:7.43e-07, loss_r:3.19e-07, loss_d:4.24e-07
# Iter # 127000/200000	loss:7.36e-04, loss_r:3.17e-07, loss_d:4.19e-07  Valid # loss:7.36e-07, loss_r:3.17e-07, loss_d:4.19e-07
# Iter # 127500/200000	loss:7.31e-04, loss_r:3.16e-07, loss_d:4.15e-07  Valid # loss:7.30e-07, loss_r:3.15e-07, loss_d:4.15e-07
# Iter # 128000/200000	loss:7.37e-04, loss_r:3.18e-07, loss_d:4.18e-07  Valid # loss:7.47e-07, loss_r:3.19e-07, loss_d:4.28e-07
# Iter # 128500/200000	loss:7.20e-04, loss_r:3.12e-07, loss_d:4.08e-07  Valid # loss:7.24e-07, loss_r:3.14e-07, loss_d:4.10e-07
# Iter # 129000/200000	loss:7.17e-04, loss_r:3.12e-07, loss_d:4.05e-07  Valid # loss:7.19e-07, loss_r:3.12e-07, loss_d:4.08e-07
# Iter # 129500/200000	loss:7.07e-04, loss_r:3.08e-07, loss_d:3.99e-07  Valid # loss:7.07e-07, loss_r:3.08e-07, loss_d:3.99e-07
# Iter # 130000/200000	loss:7.38e-04, loss_r:3.29e-07, loss_d:4.09e-07  Valid # loss:7.48e-07, loss_r:3.39e-07, loss_d:4.09e-07
# Iter # 130500/200000	loss:7.06e-04, loss_r:3.09e-07, loss_d:3.97e-07  Valid # loss:7.03e-07, loss_r:3.06e-07, loss_d:3.97e-07
# Iter # 131000/200000	loss:6.89e-04, loss_r:3.03e-07, loss_d:3.87e-07  Valid # loss:6.90e-07, loss_r:3.03e-07, loss_d:3.87e-07
# Iter # 131500/200000	loss:6.84e-04, loss_r:3.00e-07, loss_d:3.83e-07  Valid # loss:6.84e-07, loss_r:3.01e-07, loss_d:3.83e-07
# Iter # 132000/200000	loss:7.19e-04, loss_r:3.16e-07, loss_d:4.03e-07  Valid # loss:6.93e-07, loss_r:3.03e-07, loss_d:3.90e-07
# Iter # 132500/200000	loss:6.73e-04, loss_r:2.97e-07, loss_d:3.76e-07  Valid # loss:6.73e-07, loss_r:2.97e-07, loss_d:3.76e-07
# Iter # 133000/200000	loss:8.10e-04, loss_r:4.11e-07, loss_d:3.99e-07  Valid # loss:8.86e-07, loss_r:4.67e-07, loss_d:4.19e-07
# Iter # 133500/200000	loss:8.57e-04, loss_r:3.61e-07, loss_d:4.96e-07  Valid # loss:8.16e-07, loss_r:3.49e-07, loss_d:4.67e-07
# Iter # 134000/200000	loss:7.74e-04, loss_r:3.38e-07, loss_d:4.36e-07  Valid # loss:8.80e-07, loss_r:3.71e-07, loss_d:5.09e-07
# Iter # 134500/200000	loss:6.80e-04, loss_r:3.01e-07, loss_d:3.80e-07  Valid # loss:6.85e-07, loss_r:2.99e-07, loss_d:3.86e-07
# Iter # 135000/200000	loss:7.11e-04, loss_r:3.51e-07, loss_d:3.59e-07  Valid # loss:7.03e-07, loss_r:3.45e-07, loss_d:3.58e-07
# Iter # 135500/200000	loss:6.44e-04, loss_r:2.87e-07, loss_d:3.57e-07  Valid # loss:6.44e-07, loss_r:2.88e-07, loss_d:3.56e-07
# Iter # 136000/200000	loss:6.37e-04, loss_r:2.85e-07, loss_d:3.52e-07  Valid # loss:6.37e-07, loss_r:2.86e-07, loss_d:3.52e-07
# Iter # 136500/200000	loss:6.98e-04, loss_r:3.20e-07, loss_d:3.78e-07  Valid # loss:6.65e-07, loss_r:3.12e-07, loss_d:3.53e-07
# Iter # 137000/200000	loss:6.47e-04, loss_r:2.90e-07, loss_d:3.57e-07  Valid # loss:6.29e-07, loss_r:2.82e-07, loss_d:3.46e-07
# Iter # 137500/200000	loss:6.25e-04, loss_r:2.82e-07, loss_d:3.43e-07  Valid # loss:6.26e-07, loss_r:2.82e-07, loss_d:3.45e-07
# Iter # 138000/200000	loss:7.29e-04, loss_r:3.66e-07, loss_d:3.63e-07  Valid # loss:6.97e-07, loss_r:3.21e-07, loss_d:3.76e-07
# Iter # 138500/200000	loss:6.13e-04, loss_r:2.77e-07, loss_d:3.36e-07  Valid # loss:6.13e-07, loss_r:2.78e-07, loss_d:3.36e-07
# Iter # 139000/200000	loss:6.09e-04, loss_r:2.76e-07, loss_d:3.33e-07  Valid # loss:6.09e-07, loss_r:2.76e-07, loss_d:3.33e-07
# Iter # 139500/200000	loss:6.05e-04, loss_r:2.75e-07, loss_d:3.30e-07  Valid # loss:6.05e-07, loss_r:2.75e-07, loss_d:3.30e-07
# Iter # 140000/200000	loss:6.47e-04, loss_r:3.09e-07, loss_d:3.38e-07  Valid # loss:6.63e-07, loss_r:3.08e-07, loss_d:3.54e-07
# Iter # 140500/200000	loss:5.95e-04, loss_r:2.71e-07, loss_d:3.23e-07  Valid # loss:5.95e-07, loss_r:2.71e-07, loss_d:3.24e-07
# Iter # 141000/200000	loss:6.02e-04, loss_r:2.75e-07, loss_d:3.27e-07  Valid # loss:6.04e-07, loss_r:2.77e-07, loss_d:3.27e-07
# Iter # 141500/200000	loss:5.89e-04, loss_r:2.70e-07, loss_d:3.19e-07  Valid # loss:5.92e-07, loss_r:2.70e-07, loss_d:3.23e-07
# Iter # 142000/200000	loss:5.95e-04, loss_r:2.74e-07, loss_d:3.21e-07  Valid # loss:5.98e-07, loss_r:2.74e-07, loss_d:3.24e-07
# Iter # 142500/200000	loss:8.91e-04, loss_r:3.87e-07, loss_d:5.04e-07  Valid # loss:9.45e-07, loss_r:3.99e-07, loss_d:5.46e-07
# Iter # 143000/200000	loss:5.75e-04, loss_r:2.65e-07, loss_d:3.10e-07  Valid # loss:5.75e-07, loss_r:2.65e-07, loss_d:3.10e-07
# Iter # 143500/200000	loss:5.69e-04, loss_r:2.62e-07, loss_d:3.07e-07  Valid # loss:5.69e-07, loss_r:2.62e-07, loss_d:3.07e-07
# Iter # 144000/200000	loss:5.69e-04, loss_r:2.62e-07, loss_d:3.07e-07  Valid # loss:5.71e-07, loss_r:2.64e-07, loss_d:3.07e-07
# Iter # 144500/200000	loss:5.62e-04, loss_r:2.61e-07, loss_d:3.02e-07  Valid # loss:5.62e-07, loss_r:2.60e-07, loss_d:3.01e-07
# Iter # 145000/200000	loss:5.58e-04, loss_r:2.58e-07, loss_d:3.00e-07  Valid # loss:5.58e-07, loss_r:2.59e-07, loss_d:2.99e-07
# Iter # 145500/200000	loss:5.53e-04, loss_r:2.57e-07, loss_d:2.97e-07  Valid # loss:5.53e-07, loss_r:2.57e-07, loss_d:2.96e-07
# Iter # 146000/200000	loss:5.80e-04, loss_r:2.67e-07, loss_d:3.12e-07  Valid # loss:5.89e-07, loss_r:2.73e-07, loss_d:3.17e-07
# Iter # 146500/200000	loss:5.85e-04, loss_r:2.80e-07, loss_d:3.05e-07  Valid # loss:5.96e-07, loss_r:2.80e-07, loss_d:3.17e-07
# Iter # 147000/200000	loss:6.13e-04, loss_r:2.83e-07, loss_d:3.30e-07  Valid # loss:5.87e-07, loss_r:2.72e-07, loss_d:3.15e-07
# Iter # 147500/200000	loss:7.27e-04, loss_r:3.18e-07, loss_d:4.09e-07  Valid # loss:7.10e-07, loss_r:3.00e-07, loss_d:4.10e-07
# Iter # 148000/200000	loss:5.45e-04, loss_r:2.55e-07, loss_d:2.91e-07  Valid # loss:5.48e-07, loss_r:2.53e-07, loss_d:2.95e-07
# Iter # 148500/200000	loss:5.31e-04, loss_r:2.50e-07, loss_d:2.82e-07  Valid # loss:5.31e-07, loss_r:2.49e-07, loss_d:2.82e-07
# Iter # 149000/200000	loss:5.27e-04, loss_r:2.47e-07, loss_d:2.79e-07  Valid # loss:5.27e-07, loss_r:2.47e-07, loss_d:2.79e-07
# Iter # 149500/200000	loss:5.26e-04, loss_r:2.47e-07, loss_d:2.78e-07  Valid # loss:5.26e-07, loss_r:2.47e-07, loss_d:2.79e-07
# Iter # 150000/200000	loss:5.30e-04, loss_r:2.51e-07, loss_d:2.80e-07  Valid # loss:5.27e-07, loss_r:2.49e-07, loss_d:2.78e-07
# Iter # 150500/200000	loss:5.16e-04, loss_r:2.44e-07, loss_d:2.72e-07  Valid # loss:5.16e-07, loss_r:2.44e-07, loss_d:2.72e-07
# Iter # 151000/200000	loss:5.17e-04, loss_r:2.45e-07, loss_d:2.73e-07  Valid # loss:5.18e-07, loss_r:2.45e-07, loss_d:2.73e-07
# Iter # 151500/200000	loss:5.33e-04, loss_r:2.47e-07, loss_d:2.86e-07  Valid # loss:5.22e-07, loss_r:2.46e-07, loss_d:2.75e-07
# Iter # 152000/200000	loss:9.19e-04, loss_r:3.76e-07, loss_d:5.43e-07  Valid # loss:9.06e-07, loss_r:3.86e-07, loss_d:5.21e-07
# Iter # 152500/200000	loss:5.05e-04, loss_r:2.40e-07, loss_d:2.65e-07  Valid # loss:5.06e-07, loss_r:2.41e-07, loss_d:2.65e-07
# Iter # 153000/200000	loss:5.00e-04, loss_r:2.38e-07, loss_d:2.62e-07  Valid # loss:5.00e-07, loss_r:2.37e-07, loss_d:2.62e-07
# Iter # 153500/200000	loss:4.97e-04, loss_r:2.37e-07, loss_d:2.60e-07  Valid # loss:4.96e-07, loss_r:2.37e-07, loss_d:2.60e-07
# Iter # 154000/200000	loss:4.97e-04, loss_r:2.38e-07, loss_d:2.59e-07  Valid # loss:4.98e-07, loss_r:2.39e-07, loss_d:2.59e-07
# Iter # 154500/200000	loss:5.22e-04, loss_r:2.45e-07, loss_d:2.77e-07  Valid # loss:5.58e-07, loss_r:2.61e-07, loss_d:2.97e-07
# Iter # 155000/200000	loss:4.91e-04, loss_r:2.36e-07, loss_d:2.55e-07  Valid # loss:4.89e-07, loss_r:2.33e-07, loss_d:2.55e-07
# Iter # 155500/200000	loss:4.84e-04, loss_r:2.32e-07, loss_d:2.52e-07  Valid # loss:4.84e-07, loss_r:2.32e-07, loss_d:2.52e-07
# Iter # 156000/200000	loss:5.36e-04, loss_r:2.52e-07, loss_d:2.83e-07  Valid # loss:5.12e-07, loss_r:2.47e-07, loss_d:2.66e-07
# Iter # 156500/200000	loss:4.78e-04, loss_r:2.30e-07, loss_d:2.48e-07  Valid # loss:4.78e-07, loss_r:2.30e-07, loss_d:2.48e-07
# Iter # 157000/200000	loss:4.91e-04, loss_r:2.37e-07, loss_d:2.54e-07  Valid # loss:4.82e-07, loss_r:2.32e-07, loss_d:2.50e-07
# Iter # 157500/200000	loss:5.76e-04, loss_r:2.81e-07, loss_d:2.96e-07  Valid # loss:6.10e-07, loss_r:2.91e-07, loss_d:3.19e-07
# Iter # 158000/200000	loss:6.27e-04, loss_r:2.90e-07, loss_d:3.37e-07  Valid # loss:6.53e-07, loss_r:2.96e-07, loss_d:3.57e-07
# Iter # 158500/200000	loss:5.11e-04, loss_r:2.41e-07, loss_d:2.70e-07  Valid # loss:4.81e-07, loss_r:2.32e-07, loss_d:2.48e-07
# Iter # 159000/200000	loss:4.63e-04, loss_r:2.24e-07, loss_d:2.39e-07  Valid # loss:4.63e-07, loss_r:2.24e-07, loss_d:2.39e-07
# Iter # 159500/200000	loss:4.73e-04, loss_r:2.28e-07, loss_d:2.45e-07  Valid # loss:4.78e-07, loss_r:2.29e-07, loss_d:2.49e-07
# Iter # 160000/200000	loss:4.57e-04, loss_r:2.22e-07, loss_d:2.36e-07  Valid # loss:4.57e-07, loss_r:2.22e-07, loss_d:2.36e-07
# Iter # 160500/200000	loss:4.55e-04, loss_r:2.21e-07, loss_d:2.34e-07  Valid # loss:4.55e-07, loss_r:2.21e-07, loss_d:2.34e-07
# Iter # 161000/200000	loss:5.43e-04, loss_r:2.55e-07, loss_d:2.89e-07  Valid # loss:5.78e-07, loss_r:2.65e-07, loss_d:3.13e-07
# Iter # 161500/200000	loss:4.51e-04, loss_r:2.19e-07, loss_d:2.32e-07  Valid # loss:4.52e-07, loss_r:2.20e-07, loss_d:2.32e-07
# Iter # 162000/200000	loss:4.47e-04, loss_r:2.18e-07, loss_d:2.29e-07  Valid # loss:4.47e-07, loss_r:2.18e-07, loss_d:2.30e-07
# Iter # 162500/200000	loss:4.92e-04, loss_r:2.32e-07, loss_d:2.60e-07  Valid # loss:4.84e-07, loss_r:2.31e-07, loss_d:2.53e-07
# Iter # 163000/200000	loss:4.49e-04, loss_r:2.17e-07, loss_d:2.31e-07  Valid # loss:4.46e-07, loss_r:2.18e-07, loss_d:2.29e-07
# Iter # 163500/200000	loss:4.39e-04, loss_r:2.15e-07, loss_d:2.24e-07  Valid # loss:4.39e-07, loss_r:2.14e-07, loss_d:2.24e-07
# Iter # 164000/200000	loss:4.37e-04, loss_r:2.14e-07, loss_d:2.23e-07  Valid # loss:4.36e-07, loss_r:2.13e-07, loss_d:2.23e-07
# Iter # 164500/200000	loss:5.30e-04, loss_r:2.41e-07, loss_d:2.88e-07  Valid # loss:5.65e-07, loss_r:2.57e-07, loss_d:3.08e-07
# Iter # 165000/200000	loss:4.35e-04, loss_r:2.12e-07, loss_d:2.23e-07  Valid # loss:4.35e-07, loss_r:2.13e-07, loss_d:2.21e-07
# Iter # 165500/200000	loss:4.29e-04, loss_r:2.10e-07, loss_d:2.18e-07  Valid # loss:4.29e-07, loss_r:2.10e-07, loss_d:2.18e-07
# Iter # 166000/200000	loss:4.76e-04, loss_r:2.29e-07, loss_d:2.48e-07  Valid # loss:4.95e-07, loss_r:2.35e-07, loss_d:2.60e-07
# Iter # 166500/200000	loss:4.24e-04, loss_r:2.09e-07, loss_d:2.16e-07  Valid # loss:4.24e-07, loss_r:2.09e-07, loss_d:2.15e-07
# Iter # 167000/200000	loss:4.24e-04, loss_r:2.09e-07, loss_d:2.15e-07  Valid # loss:4.23e-07, loss_r:2.08e-07, loss_d:2.15e-07
# Iter # 167500/200000	loss:4.19e-04, loss_r:2.07e-07, loss_d:2.13e-07  Valid # loss:4.19e-07, loss_r:2.07e-07, loss_d:2.13e-07
# Iter # 168000/200000	loss:4.19e-04, loss_r:2.07e-07, loss_d:2.12e-07  Valid # loss:4.19e-07, loss_r:2.06e-07, loss_d:2.13e-07
# Iter # 168500/200000	loss:4.15e-04, loss_r:2.05e-07, loss_d:2.10e-07  Valid # loss:4.15e-07, loss_r:2.05e-07, loss_d:2.10e-07
# Iter # 169000/200000	loss:4.13e-04, loss_r:2.04e-07, loss_d:2.09e-07  Valid # loss:4.13e-07, loss_r:2.04e-07, loss_d:2.09e-07
# Iter # 169500/200000	loss:4.16e-04, loss_r:2.06e-07, loss_d:2.10e-07  Valid # loss:4.16e-07, loss_r:2.05e-07, loss_d:2.11e-07
# Iter # 170000/200000	loss:4.08e-04, loss_r:2.02e-07, loss_d:2.06e-07  Valid # loss:4.08e-07, loss_r:2.02e-07, loss_d:2.06e-07
# Iter # 170500/200000	loss:4.06e-04, loss_r:2.01e-07, loss_d:2.05e-07  Valid # loss:4.06e-07, loss_r:2.01e-07, loss_d:2.05e-07
# Iter # 171000/200000	loss:4.04e-04, loss_r:2.00e-07, loss_d:2.04e-07  Valid # loss:4.04e-07, loss_r:2.01e-07, loss_d:2.04e-07
# Iter # 171500/200000	loss:4.02e-04, loss_r:2.00e-07, loss_d:2.03e-07  Valid # loss:4.02e-07, loss_r:2.00e-07, loss_d:2.03e-07
# Iter # 172000/200000	loss:4.00e-04, loss_r:1.99e-07, loss_d:2.01e-07  Valid # loss:4.00e-07, loss_r:1.99e-07, loss_d:2.02e-07
# Iter # 172500/200000	loss:3.98e-04, loss_r:1.99e-07, loss_d:2.00e-07  Valid # loss:3.99e-07, loss_r:1.99e-07, loss_d:2.00e-07
# Iter # 173000/200000	loss:3.96e-04, loss_r:1.97e-07, loss_d:1.99e-07  Valid # loss:3.99e-07, loss_r:1.98e-07, loss_d:2.01e-07
# Iter # 173500/200000	loss:3.93e-04, loss_r:1.96e-07, loss_d:1.97e-07  Valid # loss:3.93e-07, loss_r:1.96e-07, loss_d:1.97e-07
# Iter # 174000/200000	loss:3.92e-04, loss_r:1.95e-07, loss_d:1.96e-07  Valid # loss:3.91e-07, loss_r:1.95e-07, loss_d:1.96e-07
# Iter # 174500/200000	loss:3.90e-04, loss_r:1.94e-07, loss_d:1.96e-07  Valid # loss:3.90e-07, loss_r:1.95e-07, loss_d:1.95e-07
# Iter # 175000/200000	loss:3.88e-04, loss_r:1.94e-07, loss_d:1.94e-07  Valid # loss:3.88e-07, loss_r:1.94e-07, loss_d:1.94e-07
# Iter # 175500/200000	loss:3.93e-04, loss_r:1.97e-07, loss_d:1.96e-07  Valid # loss:3.96e-07, loss_r:1.97e-07, loss_d:1.98e-07
# Iter # 176000/200000	loss:3.85e-04, loss_r:1.93e-07, loss_d:1.92e-07  Valid # loss:3.85e-07, loss_r:1.93e-07, loss_d:1.92e-07
# Iter # 176500/200000	loss:3.83e-04, loss_r:1.92e-07, loss_d:1.91e-07  Valid # loss:3.83e-07, loss_r:1.92e-07, loss_d:1.91e-07
# Iter # 177000/200000	loss:4.11e-04, loss_r:2.06e-07, loss_d:2.05e-07  Valid # loss:4.20e-07, loss_r:2.09e-07, loss_d:2.12e-07
# Iter # 177500/200000	loss:3.83e-04, loss_r:1.93e-07, loss_d:1.90e-07  Valid # loss:3.83e-07, loss_r:1.94e-07, loss_d:1.89e-07
# Iter # 178000/200000	loss:3.89e-04, loss_r:1.94e-07, loss_d:1.95e-07  Valid # loss:3.94e-07, loss_r:1.96e-07, loss_d:1.98e-07
# Iter # 178500/200000	loss:3.75e-04, loss_r:1.88e-07, loss_d:1.87e-07  Valid # loss:3.75e-07, loss_r:1.88e-07, loss_d:1.87e-07
# Iter # 179000/200000	loss:3.73e-04, loss_r:1.87e-07, loss_d:1.86e-07  Valid # loss:3.73e-07, loss_r:1.88e-07, loss_d:1.85e-07
# Iter # 179500/200000	loss:3.71e-04, loss_r:1.87e-07, loss_d:1.84e-07  Valid # loss:3.71e-07, loss_r:1.87e-07, loss_d:1.85e-07
# Iter # 180000/200000	loss:3.69e-04, loss_r:1.86e-07, loss_d:1.84e-07  Valid # loss:3.69e-07, loss_r:1.86e-07, loss_d:1.83e-07
# Iter # 180500/200000	loss:3.69e-04, loss_r:1.86e-07, loss_d:1.83e-07  Valid # loss:3.68e-07, loss_r:1.85e-07, loss_d:1.83e-07
# Iter # 181000/200000	loss:3.66e-04, loss_r:1.84e-07, loss_d:1.81e-07  Valid # loss:3.66e-07, loss_r:1.84e-07, loss_d:1.81e-07
# Iter # 181500/200000	loss:3.64e-04, loss_r:1.84e-07, loss_d:1.80e-07  Valid # loss:3.64e-07, loss_r:1.84e-07, loss_d:1.81e-07
# Iter # 182000/200000	loss:3.62e-04, loss_r:1.83e-07, loss_d:1.80e-07  Valid # loss:3.62e-07, loss_r:1.83e-07, loss_d:1.80e-07
# Iter # 182500/200000	loss:3.63e-04, loss_r:1.83e-07, loss_d:1.80e-07  Valid # loss:3.63e-07, loss_r:1.83e-07, loss_d:1.80e-07
# Iter # 183000/200000	loss:3.59e-04, loss_r:1.81e-07, loss_d:1.78e-07  Valid # loss:3.59e-07, loss_r:1.82e-07, loss_d:1.78e-07
# Iter # 183500/200000	loss:3.66e-04, loss_r:1.85e-07, loss_d:1.82e-07  Valid # loss:3.67e-07, loss_r:1.84e-07, loss_d:1.84e-07
# Iter # 184000/200000	loss:3.56e-04, loss_r:1.80e-07, loss_d:1.76e-07  Valid # loss:3.56e-07, loss_r:1.80e-07, loss_d:1.76e-07
# Iter # 184500/200000	loss:3.61e-04, loss_r:1.81e-07, loss_d:1.80e-07  Valid # loss:3.65e-07, loss_r:1.84e-07, loss_d:1.81e-07
# Iter # 185000/200000	loss:3.63e-04, loss_r:1.82e-07, loss_d:1.81e-07  Valid # loss:3.65e-07, loss_r:1.85e-07, loss_d:1.81e-07
# Iter # 185500/200000	loss:3.56e-04, loss_r:1.80e-07, loss_d:1.76e-07  Valid # loss:3.54e-07, loss_r:1.79e-07, loss_d:1.75e-07
# Iter # 186000/200000	loss:3.95e-04, loss_r:2.00e-07, loss_d:1.96e-07  Valid # loss:3.66e-07, loss_r:1.89e-07, loss_d:1.77e-07
# Iter # 186500/200000	loss:3.48e-04, loss_r:1.77e-07, loss_d:1.71e-07  Valid # loss:3.48e-07, loss_r:1.77e-07, loss_d:1.71e-07
# Iter # 187000/200000	loss:3.47e-04, loss_r:1.76e-07, loss_d:1.71e-07  Valid # loss:3.49e-07, loss_r:1.77e-07, loss_d:1.72e-07
# Iter # 187500/200000	loss:3.49e-04, loss_r:1.79e-07, loss_d:1.70e-07  Valid # loss:3.50e-07, loss_r:1.79e-07, loss_d:1.70e-07
# Iter # 188000/200000	loss:3.44e-04, loss_r:1.75e-07, loss_d:1.69e-07  Valid # loss:3.44e-07, loss_r:1.75e-07, loss_d:1.69e-07
# Iter # 188500/200000	loss:3.47e-04, loss_r:1.76e-07, loss_d:1.71e-07  Valid # loss:3.50e-07, loss_r:1.76e-07, loss_d:1.74e-07
# Iter # 189000/200000	loss:3.42e-04, loss_r:1.74e-07, loss_d:1.68e-07  Valid # loss:3.42e-07, loss_r:1.74e-07, loss_d:1.68e-07
# Iter # 189500/200000	loss:3.39e-04, loss_r:1.73e-07, loss_d:1.67e-07  Valid # loss:3.39e-07, loss_r:1.73e-07, loss_d:1.67e-07
# Iter # 190000/200000	loss:3.40e-04, loss_r:1.73e-07, loss_d:1.67e-07  Valid # loss:3.38e-07, loss_r:1.72e-07, loss_d:1.66e-07
# Iter # 190500/200000	loss:3.36e-04, loss_r:1.71e-07, loss_d:1.65e-07  Valid # loss:3.36e-07, loss_r:1.72e-07, loss_d:1.65e-07
# Iter # 191000/200000	loss:3.35e-04, loss_r:1.71e-07, loss_d:1.64e-07  Valid # loss:3.35e-07, loss_r:1.71e-07, loss_d:1.64e-07
# Iter # 191500/200000	loss:3.40e-04, loss_r:1.72e-07, loss_d:1.67e-07  Valid # loss:3.42e-07, loss_r:1.74e-07, loss_d:1.68e-07
# Iter # 192000/200000	loss:3.50e-04, loss_r:1.77e-07, loss_d:1.73e-07  Valid # loss:3.48e-07, loss_r:1.75e-07, loss_d:1.73e-07
# Iter # 192500/200000	loss:3.34e-04, loss_r:1.71e-07, loss_d:1.63e-07  Valid # loss:3.40e-07, loss_r:1.72e-07, loss_d:1.68e-07
# Iter # 193000/200000	loss:3.51e-04, loss_r:1.75e-07, loss_d:1.76e-07  Valid # loss:3.52e-07, loss_r:1.78e-07, loss_d:1.75e-07
# Iter # 193500/200000	loss:3.28e-04, loss_r:1.68e-07, loss_d:1.60e-07  Valid # loss:3.28e-07, loss_r:1.68e-07, loss_d:1.60e-07
# Iter # 194000/200000	loss:3.29e-04, loss_r:1.69e-07, loss_d:1.61e-07  Valid # loss:3.31e-07, loss_r:1.70e-07, loss_d:1.61e-07
# Iter # 194500/200000	loss:3.25e-04, loss_r:1.67e-07, loss_d:1.59e-07  Valid # loss:3.25e-07, loss_r:1.67e-07, loss_d:1.59e-07
# Iter # 195000/200000	loss:3.54e-04, loss_r:1.75e-07, loss_d:1.79e-07  Valid # loss:3.57e-07, loss_r:1.78e-07, loss_d:1.79e-07
# Iter # 195500/200000	loss:3.59e-04, loss_r:1.80e-07, loss_d:1.78e-07  Valid # loss:3.65e-07, loss_r:1.86e-07, loss_d:1.79e-07
# Iter # 196000/200000	loss:3.23e-04, loss_r:1.65e-07, loss_d:1.58e-07  Valid # loss:3.22e-07, loss_r:1.65e-07, loss_d:1.57e-07
# Iter # 196500/200000	loss:3.37e-04, loss_r:1.75e-07, loss_d:1.63e-07  Valid # loss:3.30e-07, loss_r:1.73e-07, loss_d:1.57e-07
# Iter # 197000/200000	loss:3.19e-04, loss_r:1.64e-07, loss_d:1.55e-07  Valid # loss:3.19e-07, loss_r:1.64e-07, loss_d:1.55e-07
# Iter # 197500/200000	loss:3.18e-04, loss_r:1.63e-07, loss_d:1.55e-07  Valid # loss:3.18e-07, loss_r:1.63e-07, loss_d:1.55e-07
# Iter # 198000/200000	loss:3.38e-04, loss_r:1.72e-07, loss_d:1.66e-07  Valid # loss:3.31e-07, loss_r:1.69e-07, loss_d:1.62e-07
# Iter # 198500/200000	loss:3.15e-04, loss_r:1.62e-07, loss_d:1.53e-07  Valid # loss:3.15e-07, loss_r:1.62e-07, loss_d:1.53e-07
# Iter # 199000/200000	loss:3.14e-04, loss_r:1.61e-07, loss_d:1.53e-07  Valid # loss:3.14e-07, loss_r:1.62e-07, loss_d:1.53e-07
# Iter # 199500/200000	loss:3.13e-04, loss_r:1.61e-07, loss_d:1.52e-07  Valid # loss:3.13e-07, loss_r:1.61e-07, loss_d:1.52e-07
# Iter # 200000/200000	loss:3.13e-04, loss_r:1.61e-07, loss_d:1.52e-07  Valid # loss:3.12e-07, loss_r:1.61e-07, loss_d:1.51e-07

# %%
np.save("./logger.npy", logger)

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':20})

# %%
logger = np.load("./logger.npy", allow_pickle=True).item()
k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_data"][::k], label=r"$\mathcal{L}_{data}$", linewidth=3)
    plt.legend()
#     plt.xticks([0, 10000, 20000, 30000, 40000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('loss.png', dpi=100)
    plt.show()

# %%
# 导入模型参数
mu = logger["mu"].cpu()
sigma = logger["sigma"].cpu()

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma)

model_state = torch.load(os.path.join(model_path, 'pinn_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_lam.load_state_dict(model_state['nn_lam_state'])
pinn.eval()

# 导入数据
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
u_star = data['solution']
t = data['t'].flatten()
x = data['x'].flatten()
# 生成网格
TT, XX = np.meshgrid(t, x)
TX = np.concatenate([TT.reshape(-1,1), XX.reshape(-1,1)], axis=1)
TX = torch.from_numpy(TX).double()

pinn = pinn.cpu().double()
u_pred = pinn.net_u(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

u_error = np.linalg.norm(u_pred - u_star) / np.linalg.norm(u_star) 
print('Relative l2 error of u: {:.3e}'.format(u_error))
# Out:
# forward with normalization, mu=[5.0, -2.5033952688602312e-09], sigma=[2.9454433917999268, 3.508115530014038]
# Relative l2 error of u: 3.115e-03

# %%
def M_true(t):
    M_true = np.zeros(t.shape)
    for i in range(len(t)):
        if (t[i]>=0) and (t[i]<=5):
            M_true[i] = 0.2
        else:M_true[i] = 0.1 
    return M_true

# %%
t = torch.tensor(t.reshape(-1,1))  # 1001,1
M_pred = pinn.net_M(t).detach().numpy()  # 1001,1

M_true = M_true(t)
M_error = np.linalg.norm(M_pred - M_true) / np.linalg.norm(M_true)

print('Relative l2 error of M: {:.3e}'.format(M_error))
print(M_true)
# Out:
# Relative l2 error of M: 1.981e+00
# [[0.2]
#  [0.2]
#  [0.2]
#  ...
#  [0.1]
#  [0.1]
#  [0.1]]

# %%
M_pred[480:520]
# Out:
# array([[-0.17383683],
#        [-0.1727148 ],
#        [-0.17157468],
#        [-0.17041709],
#        [-0.16924264],
#        [-0.16805198],
#        [-0.16684579],
#        [-0.16562477],
#        [-0.16438966],
#        [-0.16314121],
#        [-0.1618802 ],
#        [-0.16060746],
#        [-0.15932381],
#        [-0.15803013],
#        [-0.1567273 ],
#        [-0.15541622],
#        [-0.15409785],
#        [-0.15277314],
#        [-0.15144307],
#        [-0.15010863],
#        [-0.14877085],
#        [-0.14743075],
#        [-0.14608939],
#        [-0.14474781],
#        [-0.14340709],
#        [-0.14206829],
#        [-0.14073249],
#        [-0.13940077],
#        [-0.13807419],
#        [-0.13675384],
#        [-0.13544075],
#        [-0.13413599],
#        [-0.13284057],
#        [-0.13155551],
#        [-0.13028181],
#        [-0.12902042],
#        [-0.12777228],
#        [-0.12653831],
#        [-0.12531936],
#        [-0.12411629]])

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

plt.subplot(1,3,1)
cax1 = axes[0].pcolor(TT, XX, u_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u(t,x)$')
axes[0].set_xlim([0, 10])
axes[0].set_ylim([-6, 6])
axes[0].set_xticks(np.arange(0, 10.1, 2.))
axes[0].set_yticks(np.arange(-6, 6.1, 4.))
axes[0].set_aspect(1./axes[0].get_data_ratio())

plt.subplot(1,3,2)
cax2 = axes[1].pcolor(TT, XX, u_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u(t,x)$')
axes[1].set_xlim([0, 10])
axes[1].set_ylim([-6, 6])
axes[1].set_xticks(np.arange(0, 10.1, 2.))
axes[1].set_yticks(np.arange(-6, 6.1, 4.))
axes[1].set_aspect(1./axes[1].get_data_ratio())

plt.subplot(1,3,3)
cax3 = axes[2].pcolor(TT, XX, np.abs(u_star - u_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([0, 10])
axes[2].set_ylim([-6, 6])
axes[2].set_xticks(np.arange(0, 10.1, 2.))
axes[2].set_yticks(np.arange(-6, 6.1, 4.))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Fisher_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size':18})

fig, ax = plt.subplots(figsize=(9, 7), dpi=100)
# lines = ax.plot(t[:-1].reshape(5, -1).T, lam2_sol[:-1].reshape(5, -1).T, 
#                 linewidth=3, color='k', label="True")
# plt.setp(lines[1:], label="_")

t = torch.tensor(t.reshape(-1,1))  # 1001,1
M = pinn.net_M(t).detach().numpy()  # 1001,1
t = np.array(t)

ax.plot(t, M_true, linewidth=3, linestyle='-', color='black', label='True')
# ax.scatter(t[::20], M[::20], marker='^', s=120, color='blue', label='cS-PINN')
ax.plot(t, M, linewidth=3, linestyle='--', color='blue', label='cS-PINN')
ax.set_xlim([0, 10])
ax.set_xticks(np.arange(0, 10.1, 2))
ax.set_xlabel('$t$')
# ax.set_ylim([0., 0.3])
# ax.set_yticks(np.arange(0., 0.31, 0.1))
ax.set_ylabel('$M_t$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("./M.png", dpi=100)
plt.show()
