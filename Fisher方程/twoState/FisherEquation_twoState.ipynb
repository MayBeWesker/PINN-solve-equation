# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import seaborn as sns
from pyDOE import lhs
import random
import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
#     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
#     torch.use_deterministic_algorithms(True)  # 有检查操作，看下文区别
 
seed_torch(314)

# %%
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
# data = scipy.io.loadmat('./three-state(0.05-0.1-0.2-0.1-0.05).mat')
t = data['t'].flatten()
x = data['x'].flatten()
u_data = data['solution']
# 生成网格
TT, XX = np.meshgrid(t, x)
# 画图
fig = plt.figure(figsize=(6, 5))
plt.subplot(111)
plt.pcolor(TT, XX, u_data, cmap='jet')
plt.colorbar()
plt.xlim([0, 10])
plt.ylim([-6, 6])
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Reference $u(t,x)$')
plt.tight_layout()
plt.show()

data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Mar 21 12:11:16 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'C': array([[1, 2]], dtype=uint8),
#  'C_t': array([[ 0.2,  1. , -1. ],
#         [ 0.1,  1. , -1. ]]),
#  'T': array([[10]], dtype=uint8),
#  'Time': array([[10]], dtype=uint8),
#  'a': array([[-6]], dtype=int16),
#  'b': array([[6]], dtype=uint8),
#  'h': array([[0.06]]),
#  'jump_time_point': array([[ 0],
#         [ 5],
#         [10]], dtype=uint8),
#  'solution': array([[1.92874985e-22, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [3.51441136e-22, 3.84751374e-22, 4.31921353e-22, ...,
#          9.90659535e-02, 9.91484454e-02, 9.92303005e-02],
#         [6.40367501e-22, 7.89693237e-22, 9.66503734e-22, ...,
#          1.95288538e-01, 1.95448948e-01, 1.95608117e-01],
#         ...,
#         [1.31989579e-30, 1.62767908e-30, 1.99211267e-30, ...,
#          1.91905731e-01, 1.92091981e-01, 1.92276833e-01],
#         [7.24374170e-31, 7.93031688e-31, 8.90256261e-31, ...,
#          9.73265838e-02, 9.74223299e-02, 9.75173589e-02],
#         [3.97544974e-31, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  't': array([[ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ]]),
#  'tau0': array([[0.01]]),
#  'x': array([[-6.  , -5.94, -5.88, -5.82, -5.76, -5.7 , -5.64, -5.58, -5.52,
#          -5.46, -5.4 , -5.34, -5.28, -5.22, -5.16, -5.1 , -5.04, -4.98,
#          -4.92, -4.86, -4.8 , -4.74, -4.68, -4.62, -4.56, -4.5 , -4.44,
#          -4.38, -4.32, -4.26, -4.2 , -4.14, -4.08, -4.02, -3.96, -3.9 ,
#          -3.84, -3.78, -3.72, -3.66, -3.6 , -3.54, -3.48, -3.42, -3.36,
#          -3.3 , -3.24, -3.18, -3.12, -3.06, -3.  , -2.94, -2.88, -2.82,
#          -2.76, -2.7 , -2.64, -2.58, -2.52, -2.46, -2.4 , -2.34, -2.28,
#          -2.22, -2.16, -2.1 , -2.04, -1.98, -1.92, -1.86, -1.8 , -1.74,
#          -1.68, -1.62, -1.56, -1.5 , -1.44, -1.38, -1.32, -1.26, -1.2 ,
#          -1.14, -1.08, -1.02, -0.96, -0.9 , -0.84, -0.78, -0.72, -0.66,
#          -0.6 , -0.54, -0.48, -0.42, -0.36, -0.3 , -0.24, -0.18, -0.12,
#          -0.06,  0.  ,  0.06,  0.12,  0.18,  0.24,  0.3 ,  0.36,  0.42,
#           0.48,  0.54,  0.6 ,  0.66,  0.72,  0.78,  0.84,  0.9 ,  0.96,
#           1.02,  1.08,  1.14,  1.2 ,  1.26,  1.32,  1.38,  1.44,  1.5 ,
#           1.56,  1.62,  1.68,  1.74,  1.8 ,  1.86,  1.92,  1.98,  2.04,
#           2.1 ,  2.16,  2.22,  2.28,  2.34,  2.4 ,  2.46,  2.52,  2.58,
#           2.64,  2.7 ,  2.76,  2.82,  2.88,  2.94,  3.  ,  3.06,  3.12,
#           3.18,  3.24,  3.3 ,  3.36,  3.42,  3.48,  3.54,  3.6 ,  3.66,
#           3.72,  3.78,  3.84,  3.9 ,  3.96,  4.02,  4.08,  4.14,  4.2 ,
#           4.26,  4.32,  4.38,  4.44,  4.5 ,  4.56,  4.62,  4.68,  4.74,
#           4.8 ,  4.86,  4.92,  4.98,  5.04,  5.1 ,  5.16,  5.22,  5.28,
#           5.34,  5.4 ,  5.46,  5.52,  5.58,  5.64,  5.7 ,  5.76,  5.82,
#           5.88,  5.94,  6.  ]])}

# %% [markdown]
# ## 超参数

# %%
domain = (0, 10, -6, 6)
tmin, tmax, xmin, xmax = domain
backbone_layers = [2] + [40]*4 + [1]
nn_lam_layers = [1] + [40]*6 + [1]
adam_iters = 30000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class DatasetBurgers:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, verbose=None):
        tmin, tmax, xmin, xmax = self.domain
        # 内部点采样
        t_res = np.linspace(tmin, tmax, 50)
        x_res = np.linspace(xmin, xmax, 80)
        X_res = self.sample_xy(t_res, x_res)
        # 真实数据
        X_data, u_data = self.added_data()
        
        return X_res, X_data, u_data
    
    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X
    
    def added_data(self):
        data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
        u_data = data['solution']
        t = data['t']
        x = data['x']
        
        TT, XX = np.meshgrid(t, x)  # meshgrid之后的数组shape为(nx, nt)
        
        X_data = np.concatenate([TT.reshape(-1, 1), XX.reshape(-1, 1)], axis=1)
        u_data = u_data.reshape(-1, 1)
        
        # 随机采样一小批数据 用以反演
        idx = np.random.permutation(range(X_data.shape[0]))
        idx = idx[:4000]  # 采样4000个真实数据点
        return X_data[idx, :], u_data[idx, :]
    

dataset = DatasetBurgers(domain)
X_res, X_data, u_data = dataset.train_data()
print(X_res.shape, X_data.shape, u_data.shape)
# Out:
# (4000, 2) (4000, 2) (4000, 1)

# %%
# 随即采样真实数据
plt.scatter(X_data[:, 0], X_data[:, 1], c=u_data[:, 0], s=5, cmap='jet')
plt.colorbar()

# %% [markdown]
# ## 主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)
    
backbone = MLP(backbone_layers)
nn_lam = MLP(nn_lam_layers)

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True, 
                               retain_graph=True)

# %%
class PINNFisher(nn.Module):
    def __init__(self, backbone, nn_lam, mu=None, sigma=None):
        super(PINNFisher, self).__init__()
        self.backbone = backbone
        self.nn_lam = nn_lam
        
        self.bound = 0.15
        if mu is not None and sigma is not None:
            self.is_inputs_normalization = True
            self.mu = mu
            self.sigma = sigma
            print(f'forward with normalization, mu={self.mu.tolist()}, sigma={self.sigma.tolist()}')
        else:
            self.is_inputs_normalization = False
    
    def forward(self, X_res, X_data, u_data):
        loss_res = torch.mean(self.net_f(X_res)**2)
        loss_data = torch.mean(self.net_data(X_data, u_data)**2)
        return loss_res, loss_data
    
    def net_M(self, t):
        if self.is_inputs_normalization == True:
            t = (t - self.mu[0]) / self.sigma[0]
        M_t = self.nn_lam(t)
        return M_t * self.bound
    
    def net_u(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.backbone(X)
    
    def net_f(self, X_res):
        X_res.requires_grad_(True)
        u = self.net_u(X_res)
        
        grad_u = grad(u, X_res)[0]
        u_t = grad_u[:,[0]] 
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, X_res)[0][:,[1]]
        
        M = self.net_M(X_res[:, [0]])

        f = u_t - M*u_xx - u + u**2
        return f
    
    def net_data(self, X_data, u_data):
        u_data_pred = self.net_u(X_data)
        data = u_data_pred - u_data
        return data
    
pinn = PINNFisher(backbone, nn_lam)

# %% [markdown]
# ## Adams

# %%
dataset = DatasetBurgers(domain)  # 生成训练数据
X_res, X_data, u_data = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_data = torch.from_numpy(X_data).float().to(device)
u_data = torch.from_numpy(u_data).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma).to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=1e-4)
optimizer_adam_lam = optim.Adam(pinn.nn_lam.parameters(), lr=1e-4)

lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=0.8)  # 指数衰减学习率
lr_sche_lam = optim.lr_scheduler.ExponentialLR(optimizer_adam_lam, gamma=0.9)

# 自适应
w_res = torch.cat((100 * torch.ones(1000,1 ),torch.ones(X_res.shape[0]-1000,1 )),dim=0).uniform_().float().to(device)  # 权重
# w_data = (100 * torch.ones(X_data.shape[0],1 )).float().to(device)
w_data = torch.cat((100 * torch.ones(1000,1 ),torch.ones(X_data.shape[0]-1000,1 )),dim=0).float().to(device)

w_res.requires_grad = True
w_data.requires_grad = True

optimizer_w_res = optim.Adam([w_res], lr=5e-3, betas=(0.9, 0.999))  # 权重优化器
optimizer_w_data = optim.Adam([w_data], lr=5e-3, betas=(0.9, 0.999))


logger = {
    "loss": [], 
    "loss_res": [],
    "loss_data": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
best_loss = 1e9

# 训练
start_time = time.time()
for it in range(adam_iters):
    # 计算loss并更新网络 -------
    pinn.train()
    pinn.zero_grad()
    
    loss_res, loss_data = pinn(X_res, X_data, u_data)
    loss_res = torch.mean(w_res * pinn.net_f(X_res)**2)
    loss_data = torch.mean(w_data * pinn.net_data(X_data, u_data)**2)
    loss = 100 * loss_res + 1000 * loss_data
    
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_lam.step()
    # 计算loss并更新网络 -------
    
    for w in [w_res,w_data]:
        w.grad *= -1.
    optimizer_w_res.step()
    optimizer_w_data.step()
    
    if (it + 1) % 100 == 0:
        # 保存loss信息
        pinn.train(False)
        loss_res_valid, loss_data_valid = pinn(X_res, X_data, u_data)
        loss_valid = loss_res_valid + loss_data_valid
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res"].append(loss_res_valid.item())
        logger["loss_data"].append(loss_data_valid.item())
        logger["iter"].append(it+1)
        
        # 保存训练loss最低的模型
        if loss_valid.item() < best_loss:
            model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(), 'nn_lam_state': pinn.nn_lam.state_dict()}
            torch.save(model_state, os.path.join(model_path, 'pinn_adam.pth'))
            best_loss = loss_valid.item()
        
        if (it + 1) % 500 == 0:
            # 保存并打印训练日志
            info = f'Iter # {it+1:6d}/{adam_iters}\t' + \
                f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_d:{loss_data.item():.2e}  ' + \
                f'Valid # loss:{loss_valid.item():.2e}, loss_r:{loss_res_valid.item():.2e}, loss_d:{loss_data_valid.item():.2e}'
            with open(train_info_path + 'train_info.txt', 'a') as f:
                f.write(info + '\n')
            print(info)
            
        # 衰减学习率
        if (it + 1) % 4000 == 0:
            lr_sche.step()
            lr_sche_lam.step()
# Out:
# forward with normalization, mu=[5.0, 6.103515914901436e-08], sigma=[2.945443630218506, 3.508115530014038]
# Iter #    500/30000	loss:1.02e+03, loss_r:2.71e-02, loss_d:1.01e+00  Valid # loss:4.64e-02, loss_r:1.12e-02, loss_d:3.52e-02
# Iter #   1000/30000	loss:6.13e+02, loss_r:3.23e-02, loss_d:6.10e-01  Valid # loss:2.87e-02, loss_r:7.66e-03, loss_d:2.10e-02
# Iter #   1500/30000	loss:5.55e+02, loss_r:4.40e-02, loss_d:5.51e-01  Valid # loss:2.55e-02, loss_r:7.27e-03, loss_d:1.83e-02
# Iter #   2000/30000	loss:3.93e+02, loss_r:4.60e-02, loss_d:3.89e-01  Valid # loss:1.82e-02, loss_r:5.98e-03, loss_d:1.22e-02
# Iter #   2500/30000	loss:2.00e+02, loss_r:2.82e-02, loss_d:1.97e-01  Valid # loss:8.96e-03, loss_r:3.13e-03, loss_d:5.84e-03
# Iter #   3000/30000	loss:1.19e+02, loss_r:1.94e-02, loss_d:1.17e-01  Valid # loss:5.23e-03, loss_r:1.93e-03, loss_d:3.30e-03
# Iter #   3500/30000	loss:8.23e+01, loss_r:1.46e-02, loss_d:8.09e-02  Valid # loss:3.53e-03, loss_r:1.32e-03, loss_d:2.21e-03
# Iter #   4000/30000	loss:5.59e+01, loss_r:1.37e-02, loss_d:5.45e-02  Valid # loss:2.57e-03, loss_r:1.07e-03, loss_d:1.50e-03
# Iter #   4500/30000	loss:4.28e+01, loss_r:1.46e-02, loss_d:4.13e-02  Valid # loss:2.21e-03, loss_r:1.03e-03, loss_d:1.18e-03
# Iter #   5000/30000	loss:3.37e+01, loss_r:1.58e-02, loss_d:3.22e-02  Valid # loss:1.96e-03, loss_r:1.01e-03, loss_d:9.49e-04
# Iter #   5500/30000	loss:2.62e+01, loss_r:1.71e-02, loss_d:2.45e-02  Valid # loss:1.75e-03, loss_r:1.01e-03, loss_d:7.41e-04
# Iter #   6000/30000	loss:2.00e+01, loss_r:1.70e-02, loss_d:1.83e-02  Valid # loss:1.50e-03, loss_r:9.38e-04, loss_d:5.61e-04
# Iter #   6500/30000	loss:1.49e+01, loss_r:1.37e-02, loss_d:1.35e-02  Valid # loss:1.13e-03, loss_r:7.22e-04, loss_d:4.09e-04
# Iter #   7000/30000	loss:1.11e+01, loss_r:1.04e-02, loss_d:1.01e-02  Valid # loss:8.27e-04, loss_r:5.30e-04, loss_d:2.97e-04
# Iter #   7500/30000	loss:8.72e+00, loss_r:8.29e-03, loss_d:7.89e-03  Valid # loss:6.38e-04, loss_r:4.12e-04, loss_d:2.26e-04
# Iter #   8000/30000	loss:7.18e+00, loss_r:7.00e-03, loss_d:6.48e-03  Valid # loss:5.25e-04, loss_r:3.44e-04, loss_d:1.82e-04
# Iter #   8500/30000	loss:6.23e+00, loss_r:6.29e-03, loss_d:5.60e-03  Valid # loss:4.57e-04, loss_r:3.02e-04, loss_d:1.55e-04
# Iter #   9000/30000	loss:5.50e+00, loss_r:5.79e-03, loss_d:4.92e-03  Valid # loss:4.06e-04, loss_r:2.71e-04, loss_d:1.36e-04
# Iter #   9500/30000	loss:4.89e+00, loss_r:5.53e-03, loss_d:4.34e-03  Valid # loss:3.66e-04, loss_r:2.47e-04, loss_d:1.19e-04
# Iter #  10000/30000	loss:4.43e+00, loss_r:5.42e-03, loss_d:3.89e-03  Valid # loss:3.39e-04, loss_r:2.32e-04, loss_d:1.07e-04
# Iter #  10500/30000	loss:4.06e+00, loss_r:5.40e-03, loss_d:3.52e-03  Valid # loss:3.20e-04, loss_r:2.23e-04, loss_d:9.71e-05
# Iter #  11000/30000	loss:3.74e+00, loss_r:5.44e-03, loss_d:3.20e-03  Valid # loss:3.07e-04, loss_r:2.18e-04, loss_d:8.89e-05
# Iter #  11500/30000	loss:3.51e+00, loss_r:5.54e-03, loss_d:2.95e-03  Valid # loss:3.00e-04, loss_r:2.17e-04, loss_d:8.31e-05
# Iter #  12000/30000	loss:3.24e+00, loss_r:5.58e-03, loss_d:2.69e-03  Valid # loss:2.91e-04, loss_r:2.14e-04, loss_d:7.64e-05
# Iter #  12500/30000	loss:3.07e+00, loss_r:5.63e-03, loss_d:2.50e-03  Valid # loss:2.84e-04, loss_r:2.12e-04, loss_d:7.19e-05
# Iter #  13000/30000	loss:2.88e+00, loss_r:5.64e-03, loss_d:2.32e-03  Valid # loss:2.78e-04, loss_r:2.10e-04, loss_d:6.74e-05
# Iter #  13500/30000	loss:2.73e+00, loss_r:5.62e-03, loss_d:2.16e-03  Valid # loss:2.70e-04, loss_r:2.06e-04, loss_d:6.34e-05
# Iter #  14000/30000	loss:2.57e+00, loss_r:5.58e-03, loss_d:2.01e-03  Valid # loss:2.63e-04, loss_r:2.04e-04, loss_d:5.96e-05
# Iter #  14500/30000	loss:2.43e+00, loss_r:5.50e-03, loss_d:1.88e-03  Valid # loss:2.56e-04, loss_r:2.00e-04, loss_d:5.62e-05
# Iter #  15000/30000	loss:2.30e+00, loss_r:5.41e-03, loss_d:1.76e-03  Valid # loss:2.49e-04, loss_r:1.96e-04, loss_d:5.29e-05
# Iter #  15500/30000	loss:2.18e+00, loss_r:5.27e-03, loss_d:1.65e-03  Valid # loss:2.38e-04, loss_r:1.88e-04, loss_d:5.00e-05
# Iter #  16000/30000	loss:2.06e+00, loss_r:5.11e-03, loss_d:1.55e-03  Valid # loss:2.29e-04, loss_r:1.82e-04, loss_d:4.72e-05
# Iter #  16500/30000	loss:1.97e+00, loss_r:4.95e-03, loss_d:1.48e-03  Valid # loss:2.22e-04, loss_r:1.77e-04, loss_d:4.52e-05
# Iter #  17000/30000	loss:1.87e+00, loss_r:4.78e-03, loss_d:1.39e-03  Valid # loss:2.11e-04, loss_r:1.68e-04, loss_d:4.27e-05
# Iter #  17500/30000	loss:1.79e+00, loss_r:4.61e-03, loss_d:1.32e-03  Valid # loss:2.03e-04, loss_r:1.62e-04, loss_d:4.07e-05
# Iter #  18000/30000	loss:1.71e+00, loss_r:4.46e-03, loss_d:1.26e-03  Valid # loss:1.95e-04, loss_r:1.56e-04, loss_d:3.88e-05
# Iter #  18500/30000	loss:1.63e+00, loss_r:4.31e-03, loss_d:1.20e-03  Valid # loss:1.88e-04, loss_r:1.51e-04, loss_d:3.71e-05
# Iter #  19000/30000	loss:1.57e+00, loss_r:4.18e-03, loss_d:1.15e-03  Valid # loss:1.81e-04, loss_r:1.46e-04, loss_d:3.56e-05
# Iter #  19500/30000	loss:1.51e+00, loss_r:4.06e-03, loss_d:1.11e-03  Valid # loss:1.76e-04, loss_r:1.42e-04, loss_d:3.42e-05
# Iter #  20000/30000	loss:1.46e+00, loss_r:3.96e-03, loss_d:1.06e-03  Valid # loss:1.70e-04, loss_r:1.37e-04, loss_d:3.27e-05
# Iter #  20500/30000	loss:1.42e+00, loss_r:3.88e-03, loss_d:1.03e-03  Valid # loss:1.65e-04, loss_r:1.33e-04, loss_d:3.16e-05
# Iter #  21000/30000	loss:1.37e+00, loss_r:3.79e-03, loss_d:9.96e-04  Valid # loss:1.59e-04, loss_r:1.29e-04, loss_d:3.04e-05
# Iter #  21500/30000	loss:1.34e+00, loss_r:3.74e-03, loss_d:9.71e-04  Valid # loss:1.55e-04, loss_r:1.25e-04, loss_d:2.94e-05
# Iter #  22000/30000	loss:1.29e+00, loss_r:3.62e-03, loss_d:9.32e-04  Valid # loss:1.50e-04, loss_r:1.22e-04, loss_d:2.83e-05
# Iter #  22500/30000	loss:1.26e+00, loss_r:3.53e-03, loss_d:9.03e-04  Valid # loss:1.46e-04, loss_r:1.18e-04, loss_d:2.73e-05
# Iter #  23000/30000	loss:1.22e+00, loss_r:3.43e-03, loss_d:8.74e-04  Valid # loss:1.41e-04, loss_r:1.15e-04, loss_d:2.63e-05
# Iter #  23500/30000	loss:1.18e+00, loss_r:3.33e-03, loss_d:8.46e-04  Valid # loss:1.36e-04, loss_r:1.11e-04, loss_d:2.54e-05
# Iter #  24000/30000	loss:1.14e+00, loss_r:3.23e-03, loss_d:8.19e-04  Valid # loss:1.32e-04, loss_r:1.07e-04, loss_d:2.45e-05
# Iter #  24500/30000	loss:1.11e+00, loss_r:3.14e-03, loss_d:7.97e-04  Valid # loss:1.27e-04, loss_r:1.04e-04, loss_d:2.38e-05
# Iter #  25000/30000	loss:1.08e+00, loss_r:3.04e-03, loss_d:7.73e-04  Valid # loss:1.23e-04, loss_r:1.00e-04, loss_d:2.30e-05
# Iter #  25500/30000	loss:1.04e+00, loss_r:2.93e-03, loss_d:7.50e-04  Valid # loss:1.19e-04, loss_r:9.64e-05, loss_d:2.23e-05
# Iter #  26000/30000	loss:1.01e+00, loss_r:2.83e-03, loss_d:7.28e-04  Valid # loss:1.14e-04, loss_r:9.27e-05, loss_d:2.16e-05
# Iter #  26500/30000	loss:9.79e-01, loss_r:2.73e-03, loss_d:7.07e-04  Valid # loss:1.10e-04, loss_r:8.90e-05, loss_d:2.09e-05
# Iter #  27000/30000	loss:9.49e-01, loss_r:2.62e-03, loss_d:6.87e-04  Valid # loss:1.06e-04, loss_r:8.58e-05, loss_d:2.03e-05
# Iter #  27500/30000	loss:9.20e-01, loss_r:2.53e-03, loss_d:6.67e-04  Valid # loss:1.01e-04, loss_r:8.18e-05, loss_d:1.96e-05
# Iter #  28000/30000	loss:8.92e-01, loss_r:2.44e-03, loss_d:6.48e-04  Valid # loss:9.74e-05, loss_r:7.85e-05, loss_d:1.89e-05
# Iter #  28500/30000	loss:8.67e-01, loss_r:2.36e-03, loss_d:6.31e-04  Valid # loss:9.42e-05, loss_r:7.57e-05, loss_d:1.85e-05
# Iter #  29000/30000	loss:8.42e-01, loss_r:2.27e-03, loss_d:6.15e-04  Valid # loss:9.07e-05, loss_r:7.28e-05, loss_d:1.79e-05
# Iter #  29500/30000	loss:8.17e-01, loss_r:2.19e-03, loss_d:5.98e-04  Valid # loss:8.74e-05, loss_r:7.00e-05, loss_d:1.74e-05
# Iter #  30000/30000	loss:7.93e-01, loss_r:2.11e-03, loss_d:5.81e-04  Valid # loss:8.44e-05, loss_r:6.76e-05, loss_d:1.69e-05

# %%
# np.save("./logger.npy", logger)

# %% [markdown]
# ## LBFGS

# %%
"""LBFGS训练"""
start_time = time.time()

dataset = DatasetBurgers(domain)  # 生成训练数据
X_res, X_data, u_data = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_data = torch.from_numpy(X_data).float().to(device)
u_data = torch.from_numpy(u_data).float().to(device)


mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma).to(device)

model_state = torch.load(os.path.join(model_path, 'pinn_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_lam.load_state_dict(model_state['nn_lam_state'])

optimizer_lbfgs = optim.LBFGS(pinn.backbone.parameters(), 
                              max_iter=50000, 
                              line_search_fn="strong_wolfe",
                              tolerance_grad=1e-6)
optimizer_lbfgs_lam = optim.LBFGS(pinn.nn_lam.parameters(),
                                  max_iter=50000, 
                                  line_search_fn="strong_wolfe",
                                  tolerance_grad=1e-6)

loss_log_lbfgs = []
it = 0
with open(train_info_path + 'train_info.txt', 'a') as f:
    f.write('Training by LBFGS:\n')


def closure():
    global it, best_loss, adam_iters
    pinn.zero_grad()
    loss_res, loss_data = pinn(X_res, X_data, u_data)
    
    loss_res = torch.mean(w_res * pinn.net_f(X_res)**2)
    loss_data = torch.mean(w_data * pinn.net_data(X_data, u_data)**2)
    
    loss = 1000*loss_res + 10000*loss_data   
    loss.backward()
    
    loss_log_lbfgs.append(loss.item())
    if (it + 1) % 100 == 0:
        pinn.train(False)  # 验证 -------
        loss_res_valid, loss_data_valid = pinn(X_res, X_data, u_data)
        loss_valid = loss_res_valid + loss_data_valid
        
        logger["loss"].append(loss_valid.item())  # 记录loss信息 -------
        logger["loss_res"].append(loss_res_valid.item())
        logger["loss_data"].append(loss_data_valid.item())
        logger["iter"].append(adam_iters + it + 1)
        
        info = f'Iter # {it + 1:4d}\ttime:{time.time() - start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_d:{loss_data.item():2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        if loss_valid.item() < best_loss:  # 保存训练loss最低的模型 -------
            model_state = {'backbone_dict': pinn.backbone.state_dict()}
            torch.save(model_state, os.path.join(model_path, f'pinn_lbfgs.pth'))
            best_loss = loss.item()
    it = it + 1
    return loss

optimizer_lbfgs.step(closure)
optimizer_lbfgs_lam.step(closure)

model_state = {'backbone_state': pinn.backbone.state_dict(), 'nn_lam_state': pinn.nn_lam.state_dict()}
backbone_path = os.path.join(model_path, f'pinn_lbfgs.pth')
torch.save(model_state, backbone_path)
# Out:
# forward with normalization, mu=[5.0, 6.103515914901436e-08], sigma=[2.945443630218506, 3.508115530014038]
# Iter #  100	time:7.7	loss:5.79e+00, loss_r:1.72e-03, loss_d:4.066511e-04
# Iter #  200	time:15.3	loss:4.37e+00, loss_r:1.37e-03, loss_d:2.999004e-04
# Iter #  300	time:23.1	loss:3.88e+00, loss_r:1.15e-03, loss_d:2.735429e-04
# Iter #  400	time:30.9	loss:3.56e+00, loss_r:1.09e-03, loss_d:2.464962e-04
# Iter #  500	time:38.6	loss:3.36e+00, loss_r:8.90e-04, loss_d:2.474980e-04
# Iter #  600	time:46.3	loss:3.18e+00, loss_r:8.17e-04, loss_d:2.361958e-04
# Iter #  700	time:53.9	loss:3.06e+00, loss_r:7.70e-04, loss_d:2.286651e-04
# Iter #  800	time:61.5	loss:2.92e+00, loss_r:7.75e-04, loss_d:2.141155e-04
# Iter #  900	time:69.1	loss:2.82e+00, loss_r:7.92e-04, loss_d:2.028928e-04
# Iter # 1000	time:76.8	loss:2.69e+00, loss_r:7.30e-04, loss_d:1.962429e-04
# Iter # 1100	time:84.8	loss:2.59e+00, loss_r:6.68e-04, loss_d:1.917577e-04
# Iter # 1200	time:92.5	loss:2.48e+00, loss_r:6.86e-04, loss_d:1.790047e-04
# Iter # 1300	time:100.5	loss:2.42e+00, loss_r:6.39e-04, loss_d:1.777881e-04
# Iter # 1400	time:108.9	loss:2.36e+00, loss_r:6.35e-04, loss_d:1.728954e-04
# Iter # 1500	time:117.9	loss:2.32e+00, loss_r:6.20e-04, loss_d:1.702027e-04
# Iter # 1600	time:126.0	loss:2.26e+00, loss_r:6.31e-04, loss_d:1.626799e-04
# Iter # 1700	time:136.1	loss:2.21e+00, loss_r:5.79e-04, loss_d:1.635014e-04
# Iter # 1800	time:146.2	loss:2.18e+00, loss_r:5.74e-04, loss_d:1.607650e-04
# Iter # 1900	time:156.2	loss:2.13e+00, loss_r:5.62e-04, loss_d:1.570821e-04
# Iter # 2000	time:168.8	loss:2.10e+00, loss_r:5.48e-04, loss_d:1.552092e-04
# Iter # 2100	time:179.2	loss:2.08e+00, loss_r:5.32e-04, loss_d:1.543266e-04
# Iter # 2200	time:189.4	loss:2.04e+00, loss_r:5.44e-04, loss_d:1.492576e-04
# Iter # 2300	time:198.5	loss:2.00e+00, loss_r:5.38e-04, loss_d:1.466250e-04
# Iter # 2400	time:207.5	loss:1.98e+00, loss_r:5.27e-04, loss_d:1.450838e-04
# Iter # 2500	time:216.1	loss:1.94e+00, loss_r:5.32e-04, loss_d:1.408440e-04
# Iter # 2600	time:223.9	loss:1.91e+00, loss_r:5.12e-04, loss_d:1.393164e-04
# Iter # 2700	time:231.7	loss:1.87e+00, loss_r:5.23e-04, loss_d:1.349683e-04
# Iter # 2800	time:239.5	loss:1.84e+00, loss_r:5.16e-04, loss_d:1.325093e-04
# Iter # 2900	time:247.3	loss:1.81e+00, loss_r:5.04e-04, loss_d:1.305436e-04
# Iter # 3000	time:254.9	loss:1.78e+00, loss_r:4.83e-04, loss_d:1.300764e-04
# Iter # 3100	time:262.6	loss:1.76e+00, loss_r:4.93e-04, loss_d:1.263040e-04
# Iter # 3200	time:270.3	loss:1.74e+00, loss_r:4.88e-04, loss_d:1.246850e-04
# Iter # 3300	time:278.0	loss:1.71e+00, loss_r:4.60e-04, loss_d:1.249244e-04
# Iter # 3400	time:286.0	loss:1.69e+00, loss_r:4.37e-04, loss_d:1.252055e-04
# Iter # 3500	time:293.7	loss:1.67e+00, loss_r:4.13e-04, loss_d:1.253494e-04
# Iter # 3600	time:301.3	loss:1.65e+00, loss_r:4.19e-04, loss_d:1.226991e-04
# Iter # 3700	time:308.9	loss:1.61e+00, loss_r:3.92e-04, loss_d:1.218677e-04
# Iter # 3800	time:316.5	loss:1.59e+00, loss_r:3.95e-04, loss_d:1.192598e-04
# Iter # 3900	time:324.2	loss:1.57e+00, loss_r:3.74e-04, loss_d:1.191401e-04
# Iter # 4000	time:332.1	loss:1.54e+00, loss_r:3.90e-04, loss_d:1.154123e-04
# Iter # 4100	time:340.0	loss:1.51e+00, loss_r:3.91e-04, loss_d:1.116717e-04
# Iter # 4200	time:347.7	loss:1.47e+00, loss_r:3.96e-04, loss_d:1.070542e-04
# Iter # 4300	time:355.5	loss:1.43e+00, loss_r:3.78e-04, loss_d:1.050279e-04
# Iter # 4400	time:363.1	loss:1.38e+00, loss_r:3.71e-04, loss_d:1.006947e-04
# Iter # 4500	time:370.8	loss:1.29e+00, loss_r:4.06e-04, loss_d:8.880226e-05
# Iter # 4600	time:376.9	loss:1.17e+00, loss_r:4.21e-04, loss_d:7.535263e-05
# Iter # 4700	time:383.1	loss:1.04e+00, loss_r:3.54e-04, loss_d:6.826007e-05
# Iter # 4800	time:388.7	loss:9.53e-01, loss_r:3.54e-04, loss_d:5.982570e-05
# Iter # 4900	time:393.4	loss:8.82e-01, loss_r:3.42e-04, loss_d:5.399338e-05
# Iter # 5000	time:398.7	loss:7.92e-01, loss_r:3.10e-04, loss_d:4.822453e-05
# Iter # 5100	time:403.4	loss:7.06e-01, loss_r:2.73e-04, loss_d:4.326733e-05
# Iter # 5200	time:408.2	loss:6.23e-01, loss_r:2.51e-04, loss_d:3.723682e-05
# Iter # 5300	time:412.9	loss:5.55e-01, loss_r:2.13e-04, loss_d:3.426507e-05
# Iter # 5400	time:417.6	loss:5.13e-01, loss_r:1.92e-04, loss_d:3.212752e-05
# Iter # 5500	time:422.4	loss:4.86e-01, loss_r:1.69e-04, loss_d:3.172723e-05
# Iter # 5600	time:427.3	loss:4.61e-01, loss_r:1.55e-04, loss_d:3.059419e-05
# Iter # 5700	time:433.1	loss:4.42e-01, loss_r:1.48e-04, loss_d:2.945337e-05
# Iter # 5800	time:438.6	loss:4.25e-01, loss_r:1.37e-04, loss_d:2.874389e-05
# Iter # 5900	time:444.8	loss:4.09e-01, loss_r:1.25e-04, loss_d:2.842960e-05
# Iter # 6000	time:452.2	loss:3.96e-01, loss_r:1.18e-04, loss_d:2.772720e-05
# Iter # 6100	time:461.0	loss:3.84e-01, loss_r:1.18e-04, loss_d:2.658466e-05
# Iter # 6200	time:468.7	loss:3.76e-01, loss_r:1.13e-04, loss_d:2.624318e-05
# Iter # 6300	time:475.6	loss:3.67e-01, loss_r:1.09e-04, loss_d:2.585880e-05
# Iter # 6400	time:482.5	loss:3.61e-01, loss_r:1.06e-04, loss_d:2.540691e-05
# Iter # 6500	time:489.3	loss:3.52e-01, loss_r:1.03e-04, loss_d:2.487962e-05
# Iter # 6600	time:496.2	loss:3.47e-01, loss_r:1.02e-04, loss_d:2.449347e-05
# Iter # 6700	time:503.9	loss:3.41e-01, loss_r:1.01e-04, loss_d:2.402014e-05
# Iter # 6800	time:508.9	loss:3.35e-01, loss_r:9.78e-05, loss_d:2.371097e-05
# Iter # 6900	time:513.7	loss:3.30e-01, loss_r:9.57e-05, loss_d:2.346205e-05
# Iter # 7000	time:519.3	loss:3.23e-01, loss_r:9.59e-05, loss_d:2.269937e-05
# Iter # 7100	time:524.3	loss:3.18e-01, loss_r:9.56e-05, loss_d:2.220487e-05
# Iter # 7200	time:531.0	loss:3.12e-01, loss_r:9.80e-05, loss_d:2.141322e-05
# Iter # 7300	time:537.2	loss:3.06e-01, loss_r:1.00e-04, loss_d:2.061390e-05
# Iter # 7400	time:543.7	loss:3.03e-01, loss_r:9.94e-05, loss_d:2.032580e-05
# Iter # 7500	time:549.0	loss:2.98e-01, loss_r:9.87e-05, loss_d:1.995695e-05
# Iter # 7600	time:553.8	loss:2.94e-01, loss_r:9.93e-05, loss_d:1.944221e-05
# Iter # 7700	time:558.5	loss:2.88e-01, loss_r:9.61e-05, loss_d:1.914209e-05
# Iter # 7800	time:563.2	loss:2.81e-01, loss_r:9.53e-05, loss_d:1.858505e-05
# Iter # 7900	time:568.0	loss:2.76e-01, loss_r:9.28e-05, loss_d:1.829223e-05
# Iter # 8000	time:572.7	loss:2.71e-01, loss_r:9.19e-05, loss_d:1.788807e-05
# Iter # 8100	time:577.5	loss:2.66e-01, loss_r:8.99e-05, loss_d:1.762060e-05
# Iter # 8200	time:583.4	loss:2.62e-01, loss_r:8.93e-05, loss_d:1.725429e-05
# Iter # 8300	time:589.2	loss:2.58e-01, loss_r:8.91e-05, loss_d:1.693198e-05
# Iter # 8400	time:593.9	loss:2.55e-01, loss_r:8.79e-05, loss_d:1.676308e-05
# Iter # 8500	time:598.7	loss:2.52e-01, loss_r:8.86e-05, loss_d:1.634163e-05
# Iter # 8600	time:603.3	loss:2.48e-01, loss_r:8.62e-05, loss_d:1.621019e-05
# Iter # 8700	time:608.0	loss:2.45e-01, loss_r:8.46e-05, loss_d:1.605152e-05
# Iter # 8800	time:612.7	loss:2.41e-01, loss_r:8.34e-05, loss_d:1.580509e-05
# Iter # 8900	time:617.4	loss:2.38e-01, loss_r:8.26e-05, loss_d:1.558026e-05
# Iter # 9000	time:622.2	loss:2.36e-01, loss_r:8.30e-05, loss_d:1.529798e-05
# Iter # 9100	time:627.0	loss:2.33e-01, loss_r:8.30e-05, loss_d:1.503110e-05
# Iter # 9200	time:631.7	loss:2.31e-01, loss_r:8.20e-05, loss_d:1.490329e-05
# Iter # 9300	time:636.3	loss:2.28e-01, loss_r:7.97e-05, loss_d:1.487215e-05
# Iter # 9400	time:641.0	loss:2.25e-01, loss_r:7.84e-05, loss_d:1.465392e-05
# Iter # 9500	time:645.7	loss:2.22e-01, loss_r:7.70e-05, loss_d:1.448798e-05
# Iter # 9600	time:650.4	loss:2.19e-01, loss_r:7.68e-05, loss_d:1.427262e-05
# Iter # 9700	time:655.1	loss:2.17e-01, loss_r:7.42e-05, loss_d:1.427655e-05
# Iter # 9800	time:659.8	loss:2.14e-01, loss_r:7.44e-05, loss_d:1.394309e-05
# Iter # 9900	time:664.4	loss:2.10e-01, loss_r:7.22e-05, loss_d:1.374738e-05
# Iter # 10000	time:669.1	loss:2.07e-01, loss_r:7.15e-05, loss_d:1.354897e-05
# Iter # 10100	time:673.8	loss:2.05e-01, loss_r:6.82e-05, loss_d:1.365444e-05
# Iter # 10200	time:678.5	loss:2.02e-01, loss_r:6.79e-05, loss_d:1.344802e-05
# Iter # 10300	time:683.2	loss:2.00e-01, loss_r:6.63e-05, loss_d:1.335828e-05
# Iter # 10400	time:687.9	loss:1.99e-01, loss_r:6.58e-05, loss_d:1.328131e-05
# Iter # 10500	time:692.6	loss:1.97e-01, loss_r:6.58e-05, loss_d:1.310806e-05
# Iter # 10600	time:697.3	loss:1.96e-01, loss_r:6.63e-05, loss_d:1.294897e-05
# Iter # 10700	time:702.1	loss:1.94e-01, loss_r:6.73e-05, loss_d:1.271260e-05
# Iter # 10800	time:706.8	loss:1.93e-01, loss_r:6.76e-05, loss_d:1.251888e-05
# Iter # 10900	time:711.5	loss:1.91e-01, loss_r:6.77e-05, loss_d:1.234466e-05
# Iter # 11000	time:716.2	loss:1.90e-01, loss_r:6.73e-05, loss_d:1.225806e-05
# Iter # 11100	time:720.8	loss:1.88e-01, loss_r:6.64e-05, loss_d:1.218710e-05
# Iter # 11200	time:725.8	loss:1.87e-01, loss_r:6.58e-05, loss_d:1.210518e-05
# Iter # 11300	time:730.4	loss:1.85e-01, loss_r:6.32e-05, loss_d:1.219009e-05
# Iter # 11400	time:735.2	loss:1.83e-01, loss_r:6.23e-05, loss_d:1.209175e-05
# Iter # 11500	time:739.8	loss:1.81e-01, loss_r:6.29e-05, loss_d:1.183290e-05
# Iter # 11600	time:744.5	loss:1.80e-01, loss_r:6.13e-05, loss_d:1.184446e-05
# Iter # 11700	time:749.3	loss:1.78e-01, loss_r:6.14e-05, loss_d:1.165223e-05
# Iter # 11800	time:754.0	loss:1.76e-01, loss_r:5.98e-05, loss_d:1.166504e-05
# Iter # 11900	time:758.7	loss:1.75e-01, loss_r:5.95e-05, loss_d:1.152992e-05
# Iter # 12000	time:763.4	loss:1.74e-01, loss_r:5.95e-05, loss_d:1.141527e-05
# Iter # 12100	time:768.3	loss:1.73e-01, loss_r:5.92e-05, loss_d:1.134865e-05
# Iter # 12200	time:773.0	loss:1.72e-01, loss_r:5.99e-05, loss_d:1.116104e-05
# Iter # 12300	time:777.7	loss:1.70e-01, loss_r:5.95e-05, loss_d:1.108995e-05
# Iter # 12400	time:782.4	loss:1.69e-01, loss_r:5.89e-05, loss_d:1.105300e-05
# Iter # 12500	time:787.1	loss:1.68e-01, loss_r:5.96e-05, loss_d:1.088440e-05
# Iter # 12600	time:791.8	loss:1.67e-01, loss_r:5.93e-05, loss_d:1.079671e-05
# Iter # 12700	time:796.4	loss:1.66e-01, loss_r:5.94e-05, loss_d:1.066098e-05
# Iter # 12800	time:801.1	loss:1.65e-01, loss_r:5.91e-05, loss_d:1.056395e-05
# Iter # 12900	time:805.8	loss:1.64e-01, loss_r:5.92e-05, loss_d:1.045325e-05
# Iter # 13000	time:810.5	loss:1.63e-01, loss_r:5.82e-05, loss_d:1.043950e-05
# Iter # 13100	time:815.2	loss:1.62e-01, loss_r:5.67e-05, loss_d:1.050221e-05
# Iter # 13200	time:819.9	loss:1.61e-01, loss_r:5.62e-05, loss_d:1.046600e-05
# Iter # 13300	time:824.7	loss:1.60e-01, loss_r:5.65e-05, loss_d:1.035776e-05
# Iter # 13400	time:829.4	loss:1.59e-01, loss_r:5.57e-05, loss_d:1.034643e-05
# Iter # 13500	time:834.0	loss:1.58e-01, loss_r:5.55e-05, loss_d:1.028100e-05
# Iter # 13600	time:839.0	loss:1.57e-01, loss_r:5.45e-05, loss_d:1.028438e-05
# Iter # 13700	time:844.0	loss:1.56e-01, loss_r:5.43e-05, loss_d:1.020286e-05
# Iter # 13800	time:848.6	loss:1.56e-01, loss_r:5.49e-05, loss_d:1.006791e-05
# Iter # 13900	time:853.3	loss:1.55e-01, loss_r:5.43e-05, loss_d:1.003605e-05
# Iter # 14000	time:858.0	loss:1.54e-01, loss_r:5.44e-05, loss_d:9.973234e-06

# %%
np.save("./logger.npy", logger)
it
# Out:
# 14078

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
logger = np.load("./logger.npy", allow_pickle=True).item()
k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_data"][::k], label=r"$\mathcal{L}_{data}$", linewidth=3)
    plt.legend()
    plt.xticks([0, 10000, 20000, 30000, 40000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('loss.png', dpi=100)
    plt.show()

# %%
# 导入模型参数
mu = logger["mu"].cpu()
sigma = logger["sigma"].cpu()

backbone = MLP(backbone_layers)  # 主干网络
nn_lam = MLP(nn_lam_layers)  # 参数网络 lambda1,2
pinn = PINNFisher(backbone, nn_lam, mu, sigma)

model_state = torch.load(os.path.join(model_path, 'pinn_lbfgs.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_lam.load_state_dict(model_state['nn_lam_state'])
pinn.eval()

# 导入数据
data = scipy.io.loadmat('./two-state(0.2-0.1).mat')
u_star = data['solution']
t = data['t'].flatten()
x = data['x'].flatten()
# 生成网格
TT, XX = np.meshgrid(t, x)
TX = np.concatenate([TT.reshape(-1,1), XX.reshape(-1,1)], axis=1)
TX = torch.from_numpy(TX).double()

pinn = pinn.cpu().double()
u_pred = pinn.net_u(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

u_error = np.linalg.norm(u_pred - u_star) / np.linalg.norm(u_star) 
print('Relative l2 error of u: {:.3e}'.format(u_error))
# Out:
# forward with normalization, mu=[5.0, 6.103515914901436e-08], sigma=[2.945443630218506, 3.508115530014038]
# Relative l2 error of u: 4.780e-03

# %%
def M_true(t):
    M_true = np.zeros(t.shape)
    for i in range(len(t)):
        if (t[i]>=0) and (t[i]<=5):
            M_true[i] = 0.2
        else:M_true[i] = 0.1 
    return M_true

# %%
t = torch.tensor(t.reshape(-1,1))  # 1001,1
M_pred = pinn.net_M(t).detach().numpy()  # 1001,1

M_true = M_true(t)
M_error = np.linalg.norm(M_pred - M_true) / np.linalg.norm(M_true)

print('Relative l2 error of M: {:.3e}'.format(M_error))
print(M_true)
# Out:
# Relative l2 error of M: 1.623e-01
# [[0.2]
#  [0.2]
#  [0.2]
#  ...
#  [0.1]
#  [0.1]
#  [0.1]]

# %%
M_pred[:30]
# Out:
# array([[0.04743621],
#        [0.04964931],
#        [0.05189995],
#        [0.05418825],
#        [0.05651428],
#        [0.05887803],
#        [0.06127941],
#        [0.06371826],
#        [0.06619434],
#        [0.06870728],
#        [0.07125664],
#        [0.07384187],
#        [0.0764623 ],
#        [0.07911713],
#        [0.08180546],
#        [0.08452624],
#        [0.0872783 ],
#        [0.09006031],
#        [0.09287083],
#        [0.09570825],
#        [0.09857083],
#        [0.10145666],
#        [0.10436371],
#        [0.10728979],
#        [0.11023257],
#        [0.11318958],
#        [0.11615821],
#        [0.11913573],
#        [0.12211929],
#        [0.12510592]])

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

plt.subplot(1,3,1)
cax1 = axes[0].pcolor(TT, XX, u_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u(t,x)$')
axes[0].set_xlim([0, 10])
axes[0].set_ylim([-6, 6])
axes[0].set_xticks(np.arange(0, 10.1, 2.))
axes[0].set_yticks(np.arange(-6, 6.1, 4.))
axes[0].set_aspect(1./axes[0].get_data_ratio())

plt.subplot(1,3,2)
cax2 = axes[1].pcolor(TT, XX, u_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u(t,x)$')
axes[1].set_xlim([0, 10])
axes[1].set_ylim([-6, 6])
axes[1].set_xticks(np.arange(0, 10.1, 2.))
axes[1].set_yticks(np.arange(-6, 6.1, 4.))
axes[1].set_aspect(1./axes[1].get_data_ratio())

plt.subplot(1,3,3)
cax3 = axes[2].pcolor(TT, XX, np.abs(u_star - u_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([0, 10])
axes[2].set_ylim([-6, 6])
axes[2].set_xticks(np.arange(0, 10.1, 2.))
axes[2].set_yticks(np.arange(-6, 6.1, 4.))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Fisher_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
plt.rcParams.update({'font.size':18})

fig, ax = plt.subplots(figsize=(9, 7), dpi=100)
# lines = ax.plot(t[:-1].reshape(5, -1).T, lam2_sol[:-1].reshape(5, -1).T, 
#                 linewidth=3, color='k', label="True")
# plt.setp(lines[1:], label="_")

t = torch.tensor(t.reshape(-1,1))  # 1001,1
M = pinn.net_M(t).detach().numpy()  # 1001,1
t = np.array(t)

ax.plot(t, M_true, linewidth=3, linestyle='--', color='black', label='cS-true')
ax.plot(t, M, linewidth=3, linestyle='--', color='blue', label='cS-PINN')
# ax.scatter(t[::30], M[::30], marker='^', s=120, color='blue', label='cS-PINN')
ax.set_xlim([0, 10])
ax.set_xticks(np.arange(0, 10.1, 2))
ax.set_xlabel('$t$')
ax.set_ylim([-0.5, 0.5])
ax.set_yticks(np.arange(-0.5, 0.6, 0.5))
ax.set_ylabel('$M_t$')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig("./M.png", dpi=100)
plt.show()
