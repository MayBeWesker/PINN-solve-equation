# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_365364/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io
import pandas as pd

import os
import time

# %%
# file_path = '../../正演数据.xlsx'  
# data = pd.read_excel(file_path, engine='openpyxl')  

# horizontal = np.array(data['水平方向'])  
# vertical = np.array(data['垂直方向'])  
# axis = np.array(data['轴向'])  
# temperature = np.array(data['温度'])  
# k = 0.7 * 1e-6

# %% [markdown]
# ## 超参数设置

# %%
domain = (0, 0.25, 0, 0.25)
xmin, xmax, ymin, ymax = domain
mlp_layers = [2] + [60]*8 + [1]
mlp_layers_G = [2] + [20]*2 + [1]
# n_iters = 20000
n_iters = 200000
learning_rate = 1e-3
gamma = 0.6

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class Dataset:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, N=5000, verbose=None):
        # 内部点
        x_res = np.linspace(xmin, xmax, 50)
        y_res = np.linspace(ymin, ymax, 80)
        xx, yy = np.meshgrid(x_res, y_res)
        X_res = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        u_res = self.u_res_func(X_res)

        # 边界点
        observed_idx = np.concatenate([np.where(X_res[:,[0]] == xmin)[0], np.where(X_res[:,[0]] == xmax)[0], np.where(X_res[:,[1]] == ymin)[0], np.where(X_res[:,[1]] == ymax)[0]], axis=0)
        X_bcs = X_res[observed_idx]
        u_bcs = self.u_bcs_func(X_bcs)
        # T_data = temperature.reshape(-1, 1)[observed_idx]
        
        return X_res, X_bcs, u_bcs, u_res
    
    def u_bcs_func(self, X_res):
        f_bcs = (1/(2*(4*np.pi)**2)) * (np.sin(4*np.pi*X_res[:,[0]])) * (np.sin(4*np.pi*X_res[:,[1]])) 
        return f_bcs
    
    def u_res_func(self, X_res):
        f_res = (np.sin(4*np.pi*X_res[:,[0]])) * (np.sin(4*np.pi*X_res[:,[1]])) 
        return f_res
    

dataset = Dataset(domain)
X_res, X_bcs, u_bcs, u_res = dataset.train_data()
print(X_res.shape, X_bcs.shape)
X_res
u_res
# Out:
# (4000, 2) (260, 2)
# array([[0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        ...,
#        [1.56604357e-17],
#        [7.84633898e-18],
#        [1.49975978e-32]])

# %%
X = np.concatenate([X_res,X_bcs],axis=0)
U = np.concatenate([u_res,u_bcs],axis=0)
# print()
plt.scatter(X[:,0], X[:,1],c=U)
plt.colorbar()

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            self.model.add_module(f'fc{i+1}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            self.model.add_module(f'act{i+1}', nn.Tanh())
        self.model.add_module(f'fc{len(mlp_layers)-1})', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
    
    def forward(self, X):
        return self.model(X)
    
    
mlp = MLP(mlp_layers)
mlp_G = MLP(mlp_layers_G)
mlp.model
# Out:
# Sequential(
#   (fc1): Linear(in_features=2, out_features=60, bias=True)
#   (act1): Tanh()
#   (fc2): Linear(in_features=60, out_features=60, bias=True)
#   (act2): Tanh()
#   (fc3): Linear(in_features=60, out_features=60, bias=True)
#   (act3): Tanh()
#   (fc4): Linear(in_features=60, out_features=60, bias=True)
#   (act4): Tanh()
#   (fc5): Linear(in_features=60, out_features=60, bias=True)
#   (act5): Tanh()
#   (fc6): Linear(in_features=60, out_features=60, bias=True)
#   (act6): Tanh()
#   (fc7): Linear(in_features=60, out_features=60, bias=True)
#   (act7): Tanh()
#   (fc8): Linear(in_features=60, out_features=60, bias=True)
#   (act8): Tanh()
#   (fc9)): Linear(in_features=60, out_features=1, bias=False)
# )

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINN(nn.Module):
    def __init__(self, backbone, nn_G, mu=None, sigma=None):
        super(PINN, self).__init__()
        self.backbone = backbone
        self.nn_G = nn_G
        
        if mu is not None and sigma is not None:
            self.is_inputs_normalization = True
            self.mu = mu
            self.sigma = sigma
            print(f'forward with normalization, mu={self.mu.tolist()}, sigma={self.sigma.tolist()}')
        else:
            self.is_inputs_normalization = False
    
    def forward(self, X_res, X_bcs, u_bcs_data):
        u_res_pred = self.net_f(X_res)
        u_bcs_pred = self.net_u(X_bcs)

        loss_res = torch.mean((u_res_pred) ** 2)
        loss_data = torch.mean((u_bcs_pred - u_bcs_data) ** 2)
        return loss_res, loss_data
    
    def net_u(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.backbone(X)
    
    def net_G(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.nn_G(X)
    
    def net_f(self, X):
        X.requires_grad_(True)
        u_pred = self.net_u(X)
        
        # 求实部u的梯度
        grad_u = grad(u_pred, X)[0]
        u_x = grad_u[:, [0]]
        u_y = grad_u[:, [1]]
        
        u_xx = grad(u_x, X)[0][:, [0]]
        u_yy = grad(u_y, X)[0][:, [1]]
        
        G = self.net_G(X)
        
        f_res_pred = u_xx + u_yy + G
        
        return f_res_pred
    

pinn = PINN(mlp, mlp_G)

# %% [markdown]
# ## Adam训练

# %%
# 训练
dataset = Dataset(domain)
X_res, X_bcs, u_bcs, u_res = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_bcs = torch.from_numpy(X_bcs).float().to(device)
u_bcs = torch.from_numpy(u_bcs).float().to(device)
u_res = torch.from_numpy(u_res).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(mlp_layers)
nn_G = MLP(mlp_layers_G)
pinn = PINN(backbone, nn_G, mu, sigma)
pinn = pinn.to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=learning_rate)
optimizer_adam_param = optim.Adam(pinn.nn_G.parameters(), lr=learning_rate)
# optimizer, mode='min', factor=0.1, patience=10, threshold=0.0001, 
# threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08, verbose=False
lr_sche = ReduceLROnPlateau(optimizer_adam, mode='min', factor=gamma, verbose=True)
lr_sche_param = ReduceLROnPlateau(optimizer_adam_param, mode='min', factor=gamma, verbose=True)

logger = {
    "loss": [],
    "loss_res": [],
    "loss_data": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for it in range(n_iters):
    pinn.zero_grad()
    loss_res, loss_data = pinn(X_res, X_bcs, u_bcs)
    loss = 10*loss_res + 1000*loss_data
#     loss = 100*loss_res + loss_data
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_param.step()
    
    # 保存训练信息 -------
    logger["loss"].append(loss.item())
    logger["loss_res"].append(loss_res.item())
    logger["loss_data"].append(loss_data.item())
    logger["iter"].append(it + 1)
    
    if (it + 1) % 100 == 0:  # 打印训练信息 -------
        info = f'Iter # {it+1:4d}/{n_iters}\ttime:{time.time()-start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_d:{loss_data.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        
    if (it + 1) % 100 == 0:  # 学习率衰减 -------
        lr_sche.step(loss)
        lr_sche_param.step(loss)
# Out:
# forward with normalization, mu=[0.125, 0.125], sigma=[0.07363609224557877, 0.0730857402086258]
# Iter #  100/200000	time:1.2	loss:9.70e-04, loss_r:8.78e-05, loss_d:9.14e-08
# Iter #  200/200000	time:1.8	loss:2.91e-04, loss_r:2.65e-05, loss_d:2.55e-08
# Iter #  300/200000	time:2.5	loss:1.32e-04, loss_r:1.17e-05, loss_d:1.49e-08
# Iter #  400/200000	time:3.1	loss:9.03e-05, loss_r:7.70e-06, loss_d:1.33e-08
# Iter #  500/200000	time:3.7	loss:6.72e-05, loss_r:5.51e-06, loss_d:1.21e-08
# Iter #  600/200000	time:4.3	loss:5.06e-05, loss_r:3.97e-06, loss_d:1.09e-08
# Iter #  700/200000	time:5.0	loss:3.85e-05, loss_r:2.87e-06, loss_d:9.82e-09
# Iter #  800/200000	time:5.6	loss:2.98e-05, loss_r:2.09e-06, loss_d:8.93e-09
# Iter #  900/200000	time:6.2	loss:2.36e-05, loss_r:1.54e-06, loss_d:8.20e-09
# Iter # 1000/200000	time:6.8	loss:1.91e-05, loss_r:1.15e-06, loss_d:7.60e-09
# Iter # 1100/200000	time:7.4	loss:1.60e-05, loss_r:8.87e-07, loss_d:7.11e-09
# Iter # 1200/200000	time:8.0	loss:1.37e-05, loss_r:7.00e-07, loss_d:6.71e-09
# Iter # 1300/200000	time:8.7	loss:1.21e-05, loss_r:5.68e-07, loss_d:6.38e-09
# Iter # 1400/200000	time:9.3	loss:1.09e-05, loss_r:4.76e-07, loss_d:6.10e-09
# Iter # 1500/200000	time:9.9	loss:1.01e-05, loss_r:4.19e-07, loss_d:5.89e-09
# Iter # 1600/200000	time:10.5	loss:1.13e-05, loss_r:4.85e-07, loss_d:6.40e-09
# Iter # 1700/200000	time:11.1	loss:9.41e-06, loss_r:3.75e-07, loss_d:5.67e-09
# Iter # 1800/200000	time:11.7	loss:8.78e-06, loss_r:3.32e-07, loss_d:5.46e-09
# Iter # 1900/200000	time:12.3	loss:8.32e-06, loss_r:3.04e-07, loss_d:5.28e-09
# Iter # 2000/200000	time:12.9	loss:7.96e-06, loss_r:2.84e-07, loss_d:5.13e-09
# Iter # 2100/200000	time:13.5	loss:7.67e-06, loss_r:2.68e-07, loss_d:4.99e-09
# Iter # 2200/200000	time:14.1	loss:1.56e-04, loss_r:5.40e-06, loss_d:1.02e-07
# Iter # 2300/200000	time:14.6	loss:8.55e-06, loss_r:3.52e-07, loss_d:5.03e-09
# Iter # 2400/200000	time:15.2	loss:7.69e-06, loss_r:2.88e-07, loss_d:4.81e-09
# Iter # 2500/200000	time:15.8	loss:7.18e-06, loss_r:2.54e-07, loss_d:4.64e-09
# Iter # 2600/200000	time:16.4	loss:6.83e-06, loss_r:2.32e-07, loss_d:4.51e-09
# Iter # 2700/200000	time:17.1	loss:1.14e-02, loss_r:5.75e-05, loss_d:1.09e-05
# Iter # 2800/200000	time:17.7	loss:7.09e-06, loss_r:2.43e-07, loss_d:4.66e-09
# Iter # 2900/200000	time:18.3	loss:6.45e-06, loss_r:2.12e-07, loss_d:4.33e-09
# Iter # 3000/200000	time:18.9	loss:6.15e-06, loss_r:1.94e-07, loss_d:4.21e-09
# Iter # 3100/200000	time:19.5	loss:5.93e-06, loss_r:1.83e-07, loss_d:4.10e-09
# Iter # 3200/200000	time:20.1	loss:1.29e-04, loss_r:3.27e-07, loss_d:1.25e-07
# Iter # 3300/200000	time:20.7	loss:6.02e-06, loss_r:1.98e-07, loss_d:4.04e-09
# Iter # 3400/200000	time:21.3	loss:5.66e-06, loss_r:1.75e-07, loss_d:3.91e-09
# Iter # 3500/200000	time:21.9	loss:5.43e-06, loss_r:1.62e-07, loss_d:3.82e-09
# Iter # 3600/200000	time:22.5	loss:1.17e-05, loss_r:7.94e-07, loss_d:3.72e-09
# Iter # 3700/200000	time:23.1	loss:2.17e-04, loss_r:4.47e-07, loss_d:2.13e-07
# Iter # 3800/200000	time:23.7	loss:5.88e-06, loss_r:2.32e-07, loss_d:3.56e-09
# Iter # 3900/200000	time:24.3	loss:5.28e-06, loss_r:1.81e-07, loss_d:3.47e-09
# Iter # 4000/200000	time:24.9	loss:4.94e-06, loss_r:1.54e-07, loss_d:3.40e-09
# Iter # 4100/200000	time:25.5	loss:4.95e-03, loss_r:1.13e-06, loss_d:4.94e-06
# Iter # 4200/200000	time:26.1	loss:5.48e-06, loss_r:1.93e-07, loss_d:3.55e-09
# Iter # 4300/200000	time:26.7	loss:4.70e-06, loss_r:1.49e-07, loss_d:3.21e-09
# Iter # 4400/200000	time:27.3	loss:4.44e-06, loss_r:1.29e-07, loss_d:3.15e-09
# Iter # 4500/200000	time:28.0	loss:4.27e-06, loss_r:1.18e-07, loss_d:3.09e-09
# Iter # 4600/200000	time:28.6	loss:4.14e-06, loss_r:1.11e-07, loss_d:3.03e-09
# Iter # 4700/200000	time:29.2	loss:6.01e-06, loss_r:2.51e-07, loss_d:3.51e-09
# Iter # 4800/200000	time:29.7	loss:4.36e-06, loss_r:1.56e-07, loss_d:2.80e-09
# Iter # 4900/200000	time:30.3	loss:2.47e-05, loss_r:1.98e-06, loss_d:4.86e-09
# Iter # 5000/200000	time:30.9	loss:3.97e-06, loss_r:1.39e-07, loss_d:2.58e-09
# Iter # 5100/200000	time:31.5	loss:3.69e-06, loss_r:1.14e-07, loss_d:2.55e-09
# Iter # 5200/200000	time:32.1	loss:3.53e-06, loss_r:1.02e-07, loss_d:2.51e-09
# Iter # 5300/200000	time:32.7	loss:7.80e-04, loss_r:1.70e-06, loss_d:7.63e-07
# Iter # 5400/200000	time:33.3	loss:5.87e-06, loss_r:3.55e-07, loss_d:2.33e-09
# Iter # 5500/200000	time:33.9	loss:4.05e-06, loss_r:1.95e-07, loss_d:2.10e-09
# Iter # 5600/200000	time:34.5	loss:3.47e-06, loss_r:1.38e-07, loss_d:2.09e-09
# Iter # 5700/200000	time:35.1	loss:3.18e-06, loss_r:1.12e-07, loss_d:2.06e-09
# Iter # 5800/200000	time:35.7	loss:3.00e-06, loss_r:9.74e-08, loss_d:2.03e-09
# Iter # 5900/200000	time:36.3	loss:2.87e-06, loss_r:8.83e-08, loss_d:1.99e-09
# Iter # 6000/200000	time:36.9	loss:1.20e-04, loss_r:9.61e-07, loss_d:1.11e-07
# Iter # 6100/200000	time:37.5	loss:2.82e-06, loss_r:1.10e-07, loss_d:1.72e-09
# Iter # 6200/200000	time:38.1	loss:2.59e-06, loss_r:8.85e-08, loss_d:1.70e-09
# Iter # 6300/200000	time:38.7	loss:3.61e-03, loss_r:1.08e-06, loss_d:3.60e-06
# Iter # 6400/200000	time:39.3	loss:2.73e-06, loss_r:1.16e-07, loss_d:1.57e-09
# Iter # 6500/200000	time:39.9	loss:2.32e-06, loss_r:8.30e-08, loss_d:1.49e-09
# Iter # 6600/200000	time:40.6	loss:2.17e-06, loss_r:7.11e-08, loss_d:1.46e-09
# Iter # 6700/200000	time:41.2	loss:2.07e-06, loss_r:6.47e-08, loss_d:1.42e-09
# Iter # 6800/200000	time:41.8	loss:1.99e-06, loss_r:6.03e-08, loss_d:1.38e-09
# Iter # 6900/200000	time:42.4	loss:5.50e-04, loss_r:1.66e-05, loss_d:3.84e-07
# Iter # 7000/200000	time:43.0	loss:2.41e-06, loss_r:1.43e-07, loss_d:9.83e-10
# Iter # 7100/200000	time:43.6	loss:1.91e-06, loss_r:9.25e-08, loss_d:9.87e-10
# Iter # 7200/200000	time:44.2	loss:1.71e-06, loss_r:7.39e-08, loss_d:9.70e-10
# Iter # 7300/200000	time:44.8	loss:1.58e-06, loss_r:6.41e-08, loss_d:9.43e-10
# Iter # 7400/200000	time:45.5	loss:1.49e-06, loss_r:5.75e-08, loss_d:9.12e-10
# Iter # 7500/200000	time:46.1	loss:3.93e-06, loss_r:2.82e-07, loss_d:1.11e-09
# Iter # 7600/200000	time:46.7	loss:1.36e-06, loss_r:5.61e-08, loss_d:8.00e-10
# Iter # 7700/200000	time:47.3	loss:1.26e-06, loss_r:4.84e-08, loss_d:7.80e-10
# Iter # 7800/200000	time:47.9	loss:1.19e-06, loss_r:4.41e-08, loss_d:7.54e-10
# Iter # 7900/200000	time:48.5	loss:1.56e-04, loss_r:2.08e-06, loss_d:1.35e-07
# Iter # 8000/200000	time:49.1	loss:1.49e-06, loss_r:9.03e-08, loss_d:5.84e-10
# Iter # 8100/200000	time:49.7	loss:1.12e-06, loss_r:5.34e-08, loss_d:5.85e-10
# Iter # 8200/200000	time:50.3	loss:1.01e-06, loss_r:4.42e-08, loss_d:5.72e-10
# Iter # 8300/200000	time:50.9	loss:9.48e-07, loss_r:3.95e-08, loss_d:5.54e-10
# Iter # 8400/200000	time:51.5	loss:8.94e-07, loss_r:3.61e-08, loss_d:5.34e-10
# Iter # 8500/200000	time:52.1	loss:7.24e-06, loss_r:3.98e-08, loss_d:6.84e-09
# Iter # 8600/200000	time:52.7	loss:1.18e-06, loss_r:7.72e-08, loss_d:4.04e-10
# Iter # 8700/200000	time:53.3	loss:8.28e-07, loss_r:4.40e-08, loss_d:3.87e-10
# Iter # 8800/200000	time:53.9	loss:7.40e-07, loss_r:3.63e-08, loss_d:3.77e-10
# Iter # 8900/200000	time:54.5	loss:6.83e-07, loss_r:3.20e-08, loss_d:3.63e-10
# Iter # 9000/200000	time:55.1	loss:6.37e-07, loss_r:2.89e-08, loss_d:3.48e-10
# Iter # 9100/200000	time:55.7	loss:6.02e-07, loss_r:2.68e-08, loss_d:3.35e-10
# Iter # 9200/200000	time:56.3	loss:1.16e-06, loss_r:6.03e-08, loss_d:5.55e-10
# Iter # 9300/200000	time:56.8	loss:5.88e-07, loss_r:3.14e-08, loss_d:2.74e-10
# Iter # 9400/200000	time:57.4	loss:1.82e-04, loss_r:1.03e-07, loss_d:1.81e-07
# Iter # 9500/200000	time:58.0	loss:5.37e-07, loss_r:3.06e-08, loss_d:2.31e-10
# Iter # 9600/200000	time:58.6	loss:4.73e-07, loss_r:2.48e-08, loss_d:2.24e-10
# Iter # 9700/200000	time:59.2	loss:1.03e-04, loss_r:7.99e-08, loss_d:1.03e-07
# Iter # 9800/200000	time:59.8	loss:1.41e-05, loss_r:3.76e-08, loss_d:1.37e-08
# Iter # 9900/200000	time:60.4	loss:1.95e-04, loss_r:2.18e-07, loss_d:1.93e-07
# Iter # 10000/200000	time:61.0	loss:2.00e-05, loss_r:1.75e-06, loss_d:2.45e-09
# Iter # 10100/200000	time:61.5	loss:7.72e-05, loss_r:2.29e-06, loss_d:5.43e-08
# Iter # 10200/200000	time:62.1	loss:6.29e-04, loss_r:5.16e-05, loss_d:1.13e-07
# Iter # 10300/200000	time:62.7	loss:1.62e-05, loss_r:1.20e-06, loss_d:4.22e-09
# Iter # 10400/200000	time:63.3	loss:1.32e-05, loss_r:9.44e-07, loss_d:3.74e-09
# Iter # 10500/200000	time:63.9	loss:1.15e-05, loss_r:8.03e-07, loss_d:3.51e-09
# Iter # 10600/200000	time:64.5	loss:1.03e-05, loss_r:6.96e-07, loss_d:3.33e-09
# Iter # 10700/200000	time:65.1	loss:9.28e-06, loss_r:6.10e-07, loss_d:3.18e-09
# Epoch 00107: reducing learning rate of group 0 to 6.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 6.0000e-04.
# Iter # 10800/200000	time:65.7	loss:8.75e-06, loss_r:5.65e-07, loss_d:3.10e-09
# Iter # 10900/200000	time:66.3	loss:8.27e-06, loss_r:5.25e-07, loss_d:3.02e-09
# Iter # 11000/200000	time:66.9	loss:7.83e-06, loss_r:4.88e-07, loss_d:2.95e-09
# Iter # 11100/200000	time:67.4	loss:7.43e-06, loss_r:4.55e-07, loss_d:2.88e-09
# Iter # 11200/200000	time:68.0	loss:7.06e-06, loss_r:4.24e-07, loss_d:2.82e-09
# Iter # 11300/200000	time:68.6	loss:6.71e-06, loss_r:3.96e-07, loss_d:2.75e-09
# Iter # 11400/200000	time:69.2	loss:6.40e-06, loss_r:3.71e-07, loss_d:2.69e-09
# Iter # 11500/200000	time:69.8	loss:6.11e-06, loss_r:3.47e-07, loss_d:2.63e-09
# Iter # 11600/200000	time:70.4	loss:5.84e-06, loss_r:3.26e-07, loss_d:2.58e-09
# Iter # 11700/200000	time:71.0	loss:5.59e-06, loss_r:3.07e-07, loss_d:2.52e-09
# Iter # 11800/200000	time:71.6	loss:5.35e-06, loss_r:2.89e-07, loss_d:2.47e-09
# Epoch 00118: reducing learning rate of group 0 to 3.6000e-04.
# Epoch 00118: reducing learning rate of group 0 to 3.6000e-04.
# Iter # 11900/200000	time:72.2	loss:5.22e-06, loss_r:2.79e-07, loss_d:2.43e-09
# Iter # 12000/200000	time:72.8	loss:5.09e-06, loss_r:2.69e-07, loss_d:2.40e-09
# Iter # 12100/200000	time:73.4	loss:4.97e-06, loss_r:2.60e-07, loss_d:2.37e-09
# Iter # 12200/200000	time:74.0	loss:4.85e-06, loss_r:2.51e-07, loss_d:2.33e-09
# Iter # 12300/200000	time:74.6	loss:4.73e-06, loss_r:2.43e-07, loss_d:2.30e-09
# Iter # 12400/200000	time:75.1	loss:4.61e-06, loss_r:2.34e-07, loss_d:2.27e-09
# Iter # 12500/200000	time:75.7	loss:4.50e-06, loss_r:2.26e-07, loss_d:2.23e-09
# Iter # 12600/200000	time:76.3	loss:4.39e-06, loss_r:2.19e-07, loss_d:2.20e-09
# Iter # 12700/200000	time:76.9	loss:4.28e-06, loss_r:2.12e-07, loss_d:2.17e-09
# Iter # 12800/200000	time:77.5	loss:4.18e-06, loss_r:2.05e-07, loss_d:2.13e-09
# Iter # 12900/200000	time:78.1	loss:4.08e-06, loss_r:1.98e-07, loss_d:2.10e-09
# Epoch 00129: reducing learning rate of group 0 to 2.1600e-04.
# Epoch 00129: reducing learning rate of group 0 to 2.1600e-04.
# Iter # 13000/200000	time:78.7	loss:4.02e-06, loss_r:1.94e-07, loss_d:2.07e-09
# Iter # 13100/200000	time:79.3	loss:3.96e-06, loss_r:1.90e-07, loss_d:2.05e-09
# Iter # 13200/200000	time:79.9	loss:3.90e-06, loss_r:1.87e-07, loss_d:2.03e-09
# Iter # 13300/200000	time:80.5	loss:3.84e-06, loss_r:1.83e-07, loss_d:2.01e-09
# Iter # 13400/200000	time:81.1	loss:3.78e-06, loss_r:1.79e-07, loss_d:1.99e-09
# Iter # 13500/200000	time:81.7	loss:3.72e-06, loss_r:1.75e-07, loss_d:1.96e-09
# Iter # 13600/200000	time:82.3	loss:3.66e-06, loss_r:1.72e-07, loss_d:1.94e-09
# Iter # 13700/200000	time:82.9	loss:3.60e-06, loss_r:1.68e-07, loss_d:1.91e-09
# Iter # 13800/200000	time:83.5	loss:3.54e-06, loss_r:1.65e-07, loss_d:1.89e-09
# Iter # 13900/200000	time:84.1	loss:3.47e-06, loss_r:1.61e-07, loss_d:1.86e-09
# Iter # 14000/200000	time:84.7	loss:3.41e-06, loss_r:1.58e-07, loss_d:1.84e-09
# Epoch 00140: reducing learning rate of group 0 to 1.2960e-04.
# Epoch 00140: reducing learning rate of group 0 to 1.2960e-04.
# Iter # 14100/200000	time:85.3	loss:3.38e-06, loss_r:1.55e-07, loss_d:1.82e-09
# Iter # 14200/200000	time:85.9	loss:3.34e-06, loss_r:1.53e-07, loss_d:1.81e-09
# Iter # 14300/200000	time:86.5	loss:3.30e-06, loss_r:1.51e-07, loss_d:1.79e-09
# Iter # 14400/200000	time:87.0	loss:3.26e-06, loss_r:1.49e-07, loss_d:1.77e-09
# Iter # 14500/200000	time:87.6	loss:3.22e-06, loss_r:1.47e-07, loss_d:1.76e-09
# Iter # 14600/200000	time:88.2	loss:3.18e-06, loss_r:1.44e-07, loss_d:1.74e-09
# Iter # 14700/200000	time:88.8	loss:3.14e-06, loss_r:1.42e-07, loss_d:1.72e-09
# Iter # 14800/200000	time:89.4	loss:3.10e-06, loss_r:1.40e-07, loss_d:1.70e-09
# Iter # 14900/200000	time:90.0	loss:3.06e-06, loss_r:1.37e-07, loss_d:1.68e-09
# Iter # 15000/200000	time:90.6	loss:3.01e-06, loss_r:1.35e-07, loss_d:1.66e-09
# Iter # 15100/200000	time:91.2	loss:2.97e-06, loss_r:1.33e-07, loss_d:1.64e-09
# Epoch 00151: reducing learning rate of group 0 to 7.7760e-05.
# Epoch 00151: reducing learning rate of group 0 to 7.7760e-05.
# Iter # 15200/200000	time:91.8	loss:2.94e-06, loss_r:1.31e-07, loss_d:1.63e-09
# Iter # 15300/200000	time:92.4	loss:2.91e-06, loss_r:1.30e-07, loss_d:1.62e-09
# Iter # 15400/200000	time:93.0	loss:2.88e-06, loss_r:1.28e-07, loss_d:1.60e-09
# Iter # 15500/200000	time:93.6	loss:2.85e-06, loss_r:1.26e-07, loss_d:1.59e-09
# Iter # 15600/200000	time:94.2	loss:2.82e-06, loss_r:1.25e-07, loss_d:1.58e-09
# Iter # 15700/200000	time:94.8	loss:2.79e-06, loss_r:1.23e-07, loss_d:1.56e-09
# Iter # 15800/200000	time:95.4	loss:2.76e-06, loss_r:1.21e-07, loss_d:1.55e-09
# Iter # 15900/200000	time:96.0	loss:2.73e-06, loss_r:1.20e-07, loss_d:1.53e-09
# Iter # 16000/200000	time:96.6	loss:2.70e-06, loss_r:1.18e-07, loss_d:1.52e-09
# Iter # 16100/200000	time:97.2	loss:2.66e-06, loss_r:1.16e-07, loss_d:1.50e-09
# Iter # 16200/200000	time:97.8	loss:2.63e-06, loss_r:1.14e-07, loss_d:1.48e-09
# Epoch 00162: reducing learning rate of group 0 to 4.6656e-05.
# Epoch 00162: reducing learning rate of group 0 to 4.6656e-05.
# Iter # 16300/200000	time:98.4	loss:2.60e-06, loss_r:1.13e-07, loss_d:1.47e-09
# Iter # 16400/200000	time:99.0	loss:2.58e-06, loss_r:1.12e-07, loss_d:1.46e-09
# Iter # 16500/200000	time:99.6	loss:2.56e-06, loss_r:1.11e-07, loss_d:1.45e-09
# Iter # 16600/200000	time:100.2	loss:2.53e-06, loss_r:1.09e-07, loss_d:1.44e-09
# Iter # 16700/200000	time:100.8	loss:2.51e-06, loss_r:1.08e-07, loss_d:1.43e-09
# Iter # 16800/200000	time:101.4	loss:2.48e-06, loss_r:1.07e-07, loss_d:1.42e-09
# Iter # 16900/200000	time:102.0	loss:2.46e-06, loss_r:1.05e-07, loss_d:1.40e-09
# Iter # 17000/200000	time:102.6	loss:2.43e-06, loss_r:1.04e-07, loss_d:1.39e-09
# Iter # 17100/200000	time:103.2	loss:2.40e-06, loss_r:1.03e-07, loss_d:1.38e-09
# Iter # 17200/200000	time:103.8	loss:2.37e-06, loss_r:1.01e-07, loss_d:1.36e-09
# Iter # 17300/200000	time:104.4	loss:2.34e-06, loss_r:9.96e-08, loss_d:1.35e-09
# Epoch 00173: reducing learning rate of group 0 to 2.7994e-05.
# Epoch 00173: reducing learning rate of group 0 to 2.7994e-05.
# Iter # 17400/200000	time:105.0	loss:2.33e-06, loss_r:9.86e-08, loss_d:1.34e-09
# Iter # 17500/200000	time:105.6	loss:2.31e-06, loss_r:9.77e-08, loss_d:1.33e-09
# Iter # 17600/200000	time:106.3	loss:2.29e-06, loss_r:9.67e-08, loss_d:1.32e-09
# Iter # 17700/200000	time:106.9	loss:2.27e-06, loss_r:9.56e-08, loss_d:1.31e-09
# Iter # 17800/200000	time:107.5	loss:2.25e-06, loss_r:9.46e-08, loss_d:1.30e-09
# Iter # 17900/200000	time:108.1	loss:2.22e-06, loss_r:9.35e-08, loss_d:1.29e-09
# Iter # 18000/200000	time:108.7	loss:2.20e-06, loss_r:9.24e-08, loss_d:1.28e-09
# Iter # 18100/200000	time:109.4	loss:2.18e-06, loss_r:9.12e-08, loss_d:1.27e-09
# Iter # 18200/200000	time:110.0	loss:2.15e-06, loss_r:9.00e-08, loss_d:1.25e-09
# Iter # 18300/200000	time:110.6	loss:2.13e-06, loss_r:8.88e-08, loss_d:1.24e-09
# Iter # 18400/200000	time:111.3	loss:2.10e-06, loss_r:8.75e-08, loss_d:1.23e-09
# Epoch 00184: reducing learning rate of group 0 to 1.6796e-05.
# Epoch 00184: reducing learning rate of group 0 to 1.6796e-05.
# Iter # 18500/200000	time:111.9	loss:2.09e-06, loss_r:8.68e-08, loss_d:1.22e-09
# Iter # 18600/200000	time:112.5	loss:2.07e-06, loss_r:8.60e-08, loss_d:1.21e-09
# Iter # 18700/200000	time:113.1	loss:2.06e-06, loss_r:8.51e-08, loss_d:1.20e-09
# Iter # 18800/200000	time:113.8	loss:2.04e-06, loss_r:8.43e-08, loss_d:1.19e-09
# Iter # 18900/200000	time:114.4	loss:2.02e-06, loss_r:8.34e-08, loss_d:1.19e-09
# Iter # 19000/200000	time:115.0	loss:2.00e-06, loss_r:8.25e-08, loss_d:1.18e-09
# Iter # 19100/200000	time:115.6	loss:1.98e-06, loss_r:8.15e-08, loss_d:1.17e-09
# Iter # 19200/200000	time:116.2	loss:1.96e-06, loss_r:8.06e-08, loss_d:1.16e-09
# Iter # 19300/200000	time:116.8	loss:1.94e-06, loss_r:7.96e-08, loss_d:1.14e-09
# Iter # 19400/200000	time:117.4	loss:1.92e-06, loss_r:7.86e-08, loss_d:1.13e-09
# Iter # 19500/200000	time:118.1	loss:1.90e-06, loss_r:7.75e-08, loss_d:1.12e-09
# Epoch 00195: reducing learning rate of group 0 to 1.0078e-05.
# Epoch 00195: reducing learning rate of group 0 to 1.0078e-05.
# Iter # 19600/200000	time:118.6	loss:1.88e-06, loss_r:7.69e-08, loss_d:1.11e-09
# Iter # 19700/200000	time:119.2	loss:1.87e-06, loss_r:7.62e-08, loss_d:1.11e-09
# Iter # 19800/200000	time:119.8	loss:1.85e-06, loss_r:7.55e-08, loss_d:1.10e-09
# Iter # 19900/200000	time:120.4	loss:1.84e-06, loss_r:7.48e-08, loss_d:1.09e-09
# Iter # 20000/200000	time:121.0	loss:1.82e-06, loss_r:7.40e-08, loss_d:1.08e-09
# Iter # 20100/200000	time:121.6	loss:1.80e-06, loss_r:7.33e-08, loss_d:1.07e-09
# Iter # 20200/200000	time:122.2	loss:1.79e-06, loss_r:7.25e-08, loss_d:1.06e-09
# Iter # 20300/200000	time:122.8	loss:1.77e-06, loss_r:7.16e-08, loss_d:1.05e-09
# Iter # 20400/200000	time:123.5	loss:1.75e-06, loss_r:7.08e-08, loss_d:1.04e-09
# Iter # 20500/200000	time:124.1	loss:1.73e-06, loss_r:6.99e-08, loss_d:1.03e-09
# Iter # 20600/200000	time:124.7	loss:1.71e-06, loss_r:6.90e-08, loss_d:1.02e-09
# Epoch 00206: reducing learning rate of group 0 to 6.0466e-06.
# Epoch 00206: reducing learning rate of group 0 to 6.0466e-06.
# Iter # 20700/200000	time:125.4	loss:1.70e-06, loss_r:6.85e-08, loss_d:1.02e-09
# Iter # 20800/200000	time:126.1	loss:1.69e-06, loss_r:6.79e-08, loss_d:1.01e-09
# Iter # 20900/200000	time:126.7	loss:1.67e-06, loss_r:6.73e-08, loss_d:1.00e-09
# Iter # 21000/200000	time:127.9	loss:1.66e-06, loss_r:6.67e-08, loss_d:9.93e-10
# Iter # 21100/200000	time:129.0	loss:1.65e-06, loss_r:6.61e-08, loss_d:9.86e-10
# Iter # 21200/200000	time:130.1	loss:1.63e-06, loss_r:6.54e-08, loss_d:9.77e-10
# Iter # 21300/200000	time:131.2	loss:1.62e-06, loss_r:6.48e-08, loss_d:9.69e-10
# Iter # 21400/200000	time:132.4	loss:1.60e-06, loss_r:6.41e-08, loss_d:9.60e-10
# Iter # 21500/200000	time:133.5	loss:1.58e-06, loss_r:6.34e-08, loss_d:9.51e-10
# Iter # 21600/200000	time:134.6	loss:1.57e-06, loss_r:6.26e-08, loss_d:9.41e-10
# Iter # 21700/200000	time:135.7	loss:1.55e-06, loss_r:6.19e-08, loss_d:9.31e-10
# Epoch 00217: reducing learning rate of group 0 to 3.6280e-06.
# Epoch 00217: reducing learning rate of group 0 to 3.6280e-06.
# Iter # 21800/200000	time:136.9	loss:1.54e-06, loss_r:6.14e-08, loss_d:9.25e-10
# Iter # 21900/200000	time:138.0	loss:1.53e-06, loss_r:6.09e-08, loss_d:9.18e-10
# Iter # 22000/200000	time:139.1	loss:1.52e-06, loss_r:6.04e-08, loss_d:9.11e-10
# Iter # 22100/200000	time:140.2	loss:1.50e-06, loss_r:5.99e-08, loss_d:9.05e-10
# Iter # 22200/200000	time:141.4	loss:1.49e-06, loss_r:5.94e-08, loss_d:8.97e-10
# Iter # 22300/200000	time:142.5	loss:1.48e-06, loss_r:5.88e-08, loss_d:8.90e-10
# Iter # 22400/200000	time:143.6	loss:1.46e-06, loss_r:5.82e-08, loss_d:8.82e-10
# Iter # 22500/200000	time:144.3	loss:1.45e-06, loss_r:5.76e-08, loss_d:8.73e-10
# Iter # 22600/200000	time:144.9	loss:1.44e-06, loss_r:5.70e-08, loss_d:8.65e-10
# Iter # 22700/200000	time:145.5	loss:1.42e-06, loss_r:5.64e-08, loss_d:8.56e-10
# Iter # 22800/200000	time:146.2	loss:1.40e-06, loss_r:5.58e-08, loss_d:8.47e-10
# Epoch 00228: reducing learning rate of group 0 to 2.1768e-06.
# Epoch 00228: reducing learning rate of group 0 to 2.1768e-06.
# Iter # 22900/200000	time:146.8	loss:1.39e-06, loss_r:5.54e-08, loss_d:8.41e-10
# Iter # 23000/200000	time:147.5	loss:1.38e-06, loss_r:5.49e-08, loss_d:8.35e-10
# Iter # 23100/200000	time:148.1	loss:1.37e-06, loss_r:5.45e-08, loss_d:8.29e-10
# Iter # 23200/200000	time:149.2	loss:1.36e-06, loss_r:5.41e-08, loss_d:8.22e-10
# Iter # 23300/200000	time:150.4	loss:1.35e-06, loss_r:5.36e-08, loss_d:8.16e-10
# Iter # 23400/200000	time:151.5	loss:1.34e-06, loss_r:5.31e-08, loss_d:8.09e-10
# Iter # 23500/200000	time:152.6	loss:1.33e-06, loss_r:5.26e-08, loss_d:8.01e-10
# Iter # 23600/200000	time:153.7	loss:1.32e-06, loss_r:5.21e-08, loss_d:7.94e-10
# Iter # 23700/200000	time:154.9	loss:1.30e-06, loss_r:5.16e-08, loss_d:7.86e-10
# Iter # 23800/200000	time:156.0	loss:1.29e-06, loss_r:5.11e-08, loss_d:7.78e-10
# Iter # 23900/200000	time:157.1	loss:1.27e-06, loss_r:5.05e-08, loss_d:7.69e-10
# Epoch 00239: reducing learning rate of group 0 to 1.3061e-06.
# Epoch 00239: reducing learning rate of group 0 to 1.3061e-06.
# Iter # 24000/200000	time:158.2	loss:1.27e-06, loss_r:5.02e-08, loss_d:7.64e-10
# Iter # 24100/200000	time:159.3	loss:1.26e-06, loss_r:4.98e-08, loss_d:7.59e-10
# Iter # 24200/200000	time:160.5	loss:1.25e-06, loss_r:4.95e-08, loss_d:7.53e-10
# Iter # 24300/200000	time:161.6	loss:1.24e-06, loss_r:4.91e-08, loss_d:7.47e-10
# Iter # 24400/200000	time:162.7	loss:1.23e-06, loss_r:4.87e-08, loss_d:7.41e-10
# Iter # 24500/200000	time:163.8	loss:1.22e-06, loss_r:4.83e-08, loss_d:7.34e-10
# Iter # 24600/200000	time:164.9	loss:1.21e-06, loss_r:4.79e-08, loss_d:7.28e-10
# Iter # 24700/200000	time:166.0	loss:1.20e-06, loss_r:4.75e-08, loss_d:7.21e-10
# Iter # 24800/200000	time:167.1	loss:1.18e-06, loss_r:4.70e-08, loss_d:7.14e-10
# Iter # 24900/200000	time:168.3	loss:1.17e-06, loss_r:4.66e-08, loss_d:7.06e-10
# Iter # 25000/200000	time:169.4	loss:1.16e-06, loss_r:4.61e-08, loss_d:6.99e-10
# Epoch 00250: reducing learning rate of group 0 to 7.8364e-07.
# Epoch 00250: reducing learning rate of group 0 to 7.8364e-07.
# Iter # 25100/200000	time:170.5	loss:1.15e-06, loss_r:4.58e-08, loss_d:6.94e-10
# Iter # 25200/200000	time:171.6	loss:1.14e-06, loss_r:4.55e-08, loss_d:6.89e-10
# Iter # 25300/200000	time:172.7	loss:1.14e-06, loss_r:4.52e-08, loss_d:6.84e-10
# Iter # 25400/200000	time:173.9	loss:1.13e-06, loss_r:4.49e-08, loss_d:6.78e-10
# Iter # 25500/200000	time:175.0	loss:1.12e-06, loss_r:4.46e-08, loss_d:6.73e-10
# Iter # 25600/200000	time:176.1	loss:1.11e-06, loss_r:4.42e-08, loss_d:6.67e-10
# Iter # 25700/200000	time:177.2	loss:1.10e-06, loss_r:4.39e-08, loss_d:6.61e-10
# Iter # 25800/200000	time:178.3	loss:1.09e-06, loss_r:4.35e-08, loss_d:6.54e-10
# Iter # 25900/200000	time:179.4	loss:1.08e-06, loss_r:4.31e-08, loss_d:6.48e-10
# Iter # 26000/200000	time:180.6	loss:1.07e-06, loss_r:4.27e-08, loss_d:6.41e-10
# Iter # 26100/200000	time:181.7	loss:1.06e-06, loss_r:4.24e-08, loss_d:6.34e-10
# Epoch 00261: reducing learning rate of group 0 to 4.7018e-07.
# Epoch 00261: reducing learning rate of group 0 to 4.7018e-07.
# Iter # 26200/200000	time:182.8	loss:1.05e-06, loss_r:4.21e-08, loss_d:6.30e-10
# Iter # 26300/200000	time:183.9	loss:1.04e-06, loss_r:4.18e-08, loss_d:6.25e-10
# Iter # 26400/200000	time:185.0	loss:1.04e-06, loss_r:4.16e-08, loss_d:6.20e-10
# Iter # 26500/200000	time:186.1	loss:1.03e-06, loss_r:4.13e-08, loss_d:6.15e-10
# Iter # 26600/200000	time:187.3	loss:1.02e-06, loss_r:4.10e-08, loss_d:6.10e-10
# Iter # 26700/200000	time:188.4	loss:1.01e-06, loss_r:4.07e-08, loss_d:6.05e-10
# Iter # 26800/200000	time:189.5	loss:1.00e-06, loss_r:4.04e-08, loss_d:6.00e-10
# Iter # 26900/200000	time:190.6	loss:9.95e-07, loss_r:4.01e-08, loss_d:5.94e-10
# Iter # 27000/200000	time:191.7	loss:9.86e-07, loss_r:3.98e-08, loss_d:5.88e-10
# Iter # 27100/200000	time:192.8	loss:9.77e-07, loss_r:3.95e-08, loss_d:5.82e-10
# Iter # 27200/200000	time:194.0	loss:9.67e-07, loss_r:3.92e-08, loss_d:5.76e-10
# Epoch 00272: reducing learning rate of group 0 to 2.8211e-07.
# Epoch 00272: reducing learning rate of group 0 to 2.8211e-07.
# Iter # 27300/200000	time:195.1	loss:9.61e-07, loss_r:3.89e-08, loss_d:5.72e-10
# Iter # 27400/200000	time:196.2	loss:9.55e-07, loss_r:3.87e-08, loss_d:5.68e-10
# Iter # 27500/200000	time:197.3	loss:9.49e-07, loss_r:3.85e-08, loss_d:5.64e-10
# Iter # 27600/200000	time:198.4	loss:9.42e-07, loss_r:3.83e-08, loss_d:5.59e-10
# Iter # 27700/200000	time:199.6	loss:9.35e-07, loss_r:3.81e-08, loss_d:5.55e-10
# Iter # 27800/200000	time:200.7	loss:9.28e-07, loss_r:3.78e-08, loss_d:5.50e-10
# Iter # 27900/200000	time:201.8	loss:9.21e-07, loss_r:3.76e-08, loss_d:5.46e-10
# Iter # 28000/200000	time:202.9	loss:9.14e-07, loss_r:3.73e-08, loss_d:5.41e-10
# Iter # 28100/200000	time:204.0	loss:9.06e-07, loss_r:3.70e-08, loss_d:5.36e-10
# Iter # 28200/200000	time:205.1	loss:8.98e-07, loss_r:3.68e-08, loss_d:5.30e-10
# Iter # 28300/200000	time:206.3	loss:8.90e-07, loss_r:3.65e-08, loss_d:5.25e-10
# Epoch 00283: reducing learning rate of group 0 to 1.6927e-07.
# Epoch 00283: reducing learning rate of group 0 to 1.6927e-07.
# Iter # 28400/200000	time:207.4	loss:8.85e-07, loss_r:3.63e-08, loss_d:5.21e-10
# Iter # 28500/200000	time:208.5	loss:8.79e-07, loss_r:3.61e-08, loss_d:5.18e-10
# Iter # 28600/200000	time:209.6	loss:8.74e-07, loss_r:3.60e-08, loss_d:5.14e-10
# Iter # 28700/200000	time:210.7	loss:8.68e-07, loss_r:3.58e-08, loss_d:5.11e-10
# Iter # 28800/200000	time:211.8	loss:8.63e-07, loss_r:3.56e-08, loss_d:5.07e-10
# Iter # 28900/200000	time:213.0	loss:8.57e-07, loss_r:3.54e-08, loss_d:5.03e-10
# Iter # 29000/200000	time:214.1	loss:8.50e-07, loss_r:3.52e-08, loss_d:4.99e-10
# Iter # 29100/200000	time:215.2	loss:8.44e-07, loss_r:3.49e-08, loss_d:4.95e-10
# Iter # 29200/200000	time:216.3	loss:8.38e-07, loss_r:3.47e-08, loss_d:4.90e-10
# Iter # 29300/200000	time:217.4	loss:8.31e-07, loss_r:3.45e-08, loss_d:4.86e-10
# Iter # 29400/200000	time:218.6	loss:8.24e-07, loss_r:3.43e-08, loss_d:4.81e-10
# Epoch 00294: reducing learning rate of group 0 to 1.0156e-07.
# Epoch 00294: reducing learning rate of group 0 to 1.0156e-07.
# Iter # 29500/200000	time:219.7	loss:8.20e-07, loss_r:3.41e-08, loss_d:4.79e-10
# Iter # 29600/200000	time:220.8	loss:8.15e-07, loss_r:3.40e-08, loss_d:4.76e-10
# Iter # 29700/200000	time:221.9	loss:8.11e-07, loss_r:3.38e-08, loss_d:4.73e-10
# Iter # 29800/200000	time:223.0	loss:8.06e-07, loss_r:3.37e-08, loss_d:4.70e-10
# Iter # 29900/200000	time:224.1	loss:8.02e-07, loss_r:3.35e-08, loss_d:4.67e-10
# Iter # 30000/200000	time:225.2	loss:7.97e-07, loss_r:3.33e-08, loss_d:4.63e-10
# Iter # 30100/200000	time:226.4	loss:7.92e-07, loss_r:3.32e-08, loss_d:4.60e-10
# Iter # 30200/200000	time:227.5	loss:7.87e-07, loss_r:3.30e-08, loss_d:4.57e-10
# Iter # 30300/200000	time:228.6	loss:7.81e-07, loss_r:3.28e-08, loss_d:4.53e-10
# Iter # 30400/200000	time:229.7	loss:7.76e-07, loss_r:3.26e-08, loss_d:4.50e-10
# Iter # 30500/200000	time:230.8	loss:7.71e-07, loss_r:3.24e-08, loss_d:4.46e-10
# Epoch 00305: reducing learning rate of group 0 to 6.0936e-08.
# Epoch 00305: reducing learning rate of group 0 to 6.0936e-08.
# Iter # 30600/200000	time:232.0	loss:7.67e-07, loss_r:3.23e-08, loss_d:4.44e-10
# Iter # 30700/200000	time:233.1	loss:7.64e-07, loss_r:3.22e-08, loss_d:4.42e-10
# Iter # 30800/200000	time:234.2	loss:7.60e-07, loss_r:3.21e-08, loss_d:4.40e-10
# Iter # 30900/200000	time:235.3	loss:7.57e-07, loss_r:3.19e-08, loss_d:4.37e-10
# Iter # 31000/200000	time:236.4	loss:7.53e-07, loss_r:3.18e-08, loss_d:4.35e-10
# Iter # 31100/200000	time:237.5	loss:7.49e-07, loss_r:3.17e-08, loss_d:4.32e-10
# Iter # 31200/200000	time:238.7	loss:7.45e-07, loss_r:3.15e-08, loss_d:4.30e-10
# Iter # 31300/200000	time:239.8	loss:7.41e-07, loss_r:3.14e-08, loss_d:4.27e-10
# Iter # 31400/200000	time:240.9	loss:7.37e-07, loss_r:3.12e-08, loss_d:4.25e-10
# Iter # 31500/200000	time:242.0	loss:7.33e-07, loss_r:3.11e-08, loss_d:4.22e-10
# Iter # 31600/200000	time:243.1	loss:7.29e-07, loss_r:3.09e-08, loss_d:4.20e-10
# Epoch 00316: reducing learning rate of group 0 to 3.6562e-08.
# Epoch 00316: reducing learning rate of group 0 to 3.6562e-08.
# Iter # 31700/200000	time:244.2	loss:7.26e-07, loss_r:3.08e-08, loss_d:4.18e-10
# Iter # 31800/200000	time:245.4	loss:7.24e-07, loss_r:3.07e-08, loss_d:4.16e-10
# Iter # 31900/200000	time:246.5	loss:7.21e-07, loss_r:3.06e-08, loss_d:4.15e-10
# Iter # 32000/200000	time:247.6	loss:7.19e-07, loss_r:3.05e-08, loss_d:4.13e-10
# Iter # 32100/200000	time:248.7	loss:7.16e-07, loss_r:3.04e-08, loss_d:4.11e-10
# Iter # 32200/200000	time:249.8	loss:7.13e-07, loss_r:3.03e-08, loss_d:4.10e-10
# Iter # 32300/200000	time:250.9	loss:7.10e-07, loss_r:3.02e-08, loss_d:4.08e-10
# Iter # 32400/200000	time:252.1	loss:7.07e-07, loss_r:3.01e-08, loss_d:4.06e-10
# Iter # 32500/200000	time:253.2	loss:7.05e-07, loss_r:3.00e-08, loss_d:4.05e-10
# Iter # 32600/200000	time:254.3	loss:7.02e-07, loss_r:2.99e-08, loss_d:4.03e-10
# Iter # 32700/200000	time:255.4	loss:6.99e-07, loss_r:2.98e-08, loss_d:4.01e-10
# Epoch 00327: reducing learning rate of group 0 to 2.1937e-08.
# Epoch 00327: reducing learning rate of group 0 to 2.1937e-08.
# Iter # 32800/200000	time:256.5	loss:6.97e-07, loss_r:2.97e-08, loss_d:4.00e-10
# Iter # 32900/200000	time:257.6	loss:6.95e-07, loss_r:2.96e-08, loss_d:3.99e-10
# Iter # 33000/200000	time:258.8	loss:6.93e-07, loss_r:2.95e-08, loss_d:3.98e-10
# Iter # 33100/200000	time:259.9	loss:6.92e-07, loss_r:2.95e-08, loss_d:3.97e-10
# Iter # 33200/200000	time:261.0	loss:6.90e-07, loss_r:2.94e-08, loss_d:3.96e-10
# Iter # 33300/200000	time:262.1	loss:6.88e-07, loss_r:2.93e-08, loss_d:3.95e-10
# Iter # 33400/200000	time:263.2	loss:6.86e-07, loss_r:2.92e-08, loss_d:3.94e-10
# Iter # 33500/200000	time:264.4	loss:6.84e-07, loss_r:2.91e-08, loss_d:3.93e-10
# Iter # 33600/200000	time:265.5	loss:6.82e-07, loss_r:2.91e-08, loss_d:3.92e-10
# Iter # 33700/200000	time:266.6	loss:6.80e-07, loss_r:2.90e-08, loss_d:3.91e-10
# Iter # 33800/200000	time:267.7	loss:6.78e-07, loss_r:2.89e-08, loss_d:3.90e-10
# Iter # 33900/200000	time:268.8	loss:6.76e-07, loss_r:2.88e-08, loss_d:3.88e-10
# Iter # 34000/200000	time:269.9	loss:6.74e-07, loss_r:2.87e-08, loss_d:3.87e-10
# Iter # 34100/200000	time:271.0	loss:6.72e-07, loss_r:2.86e-08, loss_d:3.86e-10
# Iter # 34200/200000	time:272.2	loss:6.70e-07, loss_r:2.85e-08, loss_d:3.85e-10
# Iter # 34300/200000	time:273.3	loss:6.68e-07, loss_r:2.84e-08, loss_d:3.84e-10
# Iter # 34400/200000	time:274.4	loss:6.66e-07, loss_r:2.83e-08, loss_d:3.83e-10
# Iter # 34500/200000	time:275.5	loss:6.64e-07, loss_r:2.82e-08, loss_d:3.82e-10
# Iter # 34600/200000	time:276.7	loss:6.62e-07, loss_r:2.81e-08, loss_d:3.81e-10
# Iter # 34700/200000	time:277.8	loss:6.60e-07, loss_r:2.80e-08, loss_d:3.79e-10
# Iter # 34800/200000	time:278.9	loss:6.58e-07, loss_r:2.80e-08, loss_d:3.78e-10
# Iter # 34900/200000	time:280.0	loss:6.56e-07, loss_r:2.79e-08, loss_d:3.77e-10
# Iter # 35000/200000	time:281.1	loss:6.54e-07, loss_r:2.78e-08, loss_d:3.76e-10
# Iter # 35100/200000	time:282.2	loss:6.51e-07, loss_r:2.77e-08, loss_d:3.75e-10
# Iter # 35200/200000	time:283.4	loss:6.49e-07, loss_r:2.76e-08, loss_d:3.74e-10
# Iter # 35300/200000	time:284.5	loss:6.47e-07, loss_r:2.75e-08, loss_d:3.72e-10
# Iter # 35400/200000	time:285.6	loss:6.45e-07, loss_r:2.74e-08, loss_d:3.71e-10
# Iter # 35500/200000	time:286.7	loss:6.43e-07, loss_r:2.73e-08, loss_d:3.70e-10
# Iter # 35600/200000	time:287.8	loss:6.41e-07, loss_r:2.72e-08, loss_d:3.69e-10
# Iter # 35700/200000	time:289.0	loss:6.39e-07, loss_r:2.71e-08, loss_d:3.68e-10
# Iter # 35800/200000	time:290.1	loss:6.36e-07, loss_r:2.70e-08, loss_d:3.67e-10
# Iter # 35900/200000	time:291.2	loss:6.34e-07, loss_r:2.69e-08, loss_d:3.65e-10
# Iter # 36000/200000	time:292.3	loss:6.32e-07, loss_r:2.68e-08, loss_d:3.64e-10
# Iter # 36100/200000	time:293.4	loss:6.30e-07, loss_r:2.67e-08, loss_d:3.63e-10
# Iter # 36200/200000	time:294.5	loss:6.28e-07, loss_r:2.66e-08, loss_d:3.62e-10
# Iter # 36300/200000	time:295.6	loss:6.25e-07, loss_r:2.65e-08, loss_d:3.61e-10
# Iter # 36400/200000	time:296.8	loss:6.23e-07, loss_r:2.64e-08, loss_d:3.59e-10
# Iter # 36500/200000	time:297.9	loss:6.21e-07, loss_r:2.63e-08, loss_d:3.58e-10
# Iter # 36600/200000	time:299.0	loss:6.19e-07, loss_r:2.62e-08, loss_d:3.57e-10
# Iter # 36700/200000	time:300.1	loss:6.17e-07, loss_r:2.61e-08, loss_d:3.56e-10
# Iter # 36800/200000	time:301.2	loss:6.15e-07, loss_r:2.60e-08, loss_d:3.55e-10
# Iter # 36900/200000	time:302.4	loss:6.12e-07, loss_r:2.59e-08, loss_d:3.54e-10
# Iter # 37000/200000	time:303.5	loss:6.10e-07, loss_r:2.58e-08, loss_d:3.52e-10
# Iter # 37100/200000	time:304.6	loss:6.08e-07, loss_r:2.57e-08, loss_d:3.51e-10
# Iter # 37200/200000	time:305.7	loss:6.06e-07, loss_r:2.56e-08, loss_d:3.50e-10
# Iter # 37300/200000	time:306.8	loss:6.04e-07, loss_r:2.55e-08, loss_d:3.49e-10
# Iter # 37400/200000	time:307.9	loss:6.02e-07, loss_r:2.54e-08, loss_d:3.48e-10
# Iter # 37500/200000	time:309.1	loss:6.00e-07, loss_r:2.53e-08, loss_d:3.47e-10
# Iter # 37600/200000	time:310.2	loss:5.98e-07, loss_r:2.52e-08, loss_d:3.46e-10
# Iter # 37700/200000	time:311.3	loss:5.96e-07, loss_r:2.51e-08, loss_d:3.44e-10
# Iter # 37800/200000	time:312.4	loss:5.94e-07, loss_r:2.50e-08, loss_d:3.43e-10
# Iter # 37900/200000	time:313.5	loss:5.92e-07, loss_r:2.49e-08, loss_d:3.42e-10
# Iter # 38000/200000	time:314.7	loss:5.89e-07, loss_r:2.48e-08, loss_d:3.41e-10
# Iter # 38100/200000	time:315.8	loss:5.87e-07, loss_r:2.47e-08, loss_d:3.40e-10
# Iter # 38200/200000	time:316.9	loss:5.85e-07, loss_r:2.47e-08, loss_d:3.39e-10
# Iter # 38300/200000	time:318.0	loss:5.83e-07, loss_r:2.46e-08, loss_d:3.38e-10
# Iter # 38400/200000	time:319.1	loss:5.81e-07, loss_r:2.45e-08, loss_d:3.36e-10
# Iter # 38500/200000	time:320.2	loss:5.79e-07, loss_r:2.44e-08, loss_d:3.35e-10
# Iter # 38600/200000	time:321.4	loss:5.77e-07, loss_r:2.43e-08, loss_d:3.34e-10
# Iter # 38700/200000	time:322.5	loss:5.75e-07, loss_r:2.42e-08, loss_d:3.33e-10
# Iter # 38800/200000	time:323.6	loss:5.73e-07, loss_r:2.41e-08, loss_d:3.32e-10
# Iter # 38900/200000	time:324.7	loss:5.71e-07, loss_r:2.40e-08, loss_d:3.31e-10
# Iter # 39000/200000	time:325.8	loss:5.69e-07, loss_r:2.39e-08, loss_d:3.30e-10
# Iter # 39100/200000	time:326.9	loss:5.67e-07, loss_r:2.38e-08, loss_d:3.29e-10
# Iter # 39200/200000	time:328.1	loss:5.65e-07, loss_r:2.38e-08, loss_d:3.28e-10
# Iter # 39300/200000	time:329.2	loss:5.63e-07, loss_r:2.37e-08, loss_d:3.26e-10
# Iter # 39400/200000	time:330.3	loss:5.61e-07, loss_r:2.36e-08, loss_d:3.25e-10
# Iter # 39500/200000	time:331.4	loss:5.59e-07, loss_r:2.35e-08, loss_d:3.24e-10
# Iter # 39600/200000	time:332.5	loss:5.57e-07, loss_r:2.34e-08, loss_d:3.23e-10
# Iter # 39700/200000	time:333.7	loss:5.55e-07, loss_r:2.33e-08, loss_d:3.22e-10
# Iter # 39800/200000	time:334.8	loss:5.53e-07, loss_r:2.32e-08, loss_d:3.21e-10
# Iter # 39900/200000	time:335.9	loss:5.51e-07, loss_r:2.32e-08, loss_d:3.20e-10
# Iter # 40000/200000	time:337.0	loss:5.50e-07, loss_r:2.31e-08, loss_d:3.19e-10
# Iter # 40100/200000	time:338.1	loss:5.48e-07, loss_r:2.30e-08, loss_d:3.18e-10
# Iter # 40200/200000	time:339.2	loss:5.46e-07, loss_r:2.29e-08, loss_d:3.17e-10
# Iter # 40300/200000	time:340.3	loss:5.44e-07, loss_r:2.28e-08, loss_d:3.16e-10
# Iter # 40400/200000	time:341.5	loss:5.42e-07, loss_r:2.27e-08, loss_d:3.15e-10
# Iter # 40500/200000	time:342.6	loss:5.40e-07, loss_r:2.27e-08, loss_d:3.14e-10
# Iter # 40600/200000	time:343.7	loss:5.38e-07, loss_r:2.26e-08, loss_d:3.13e-10
# Iter # 40700/200000	time:344.8	loss:5.37e-07, loss_r:2.25e-08, loss_d:3.12e-10
# Iter # 40800/200000	time:345.9	loss:5.35e-07, loss_r:2.24e-08, loss_d:3.11e-10
# Iter # 40900/200000	time:347.0	loss:5.33e-07, loss_r:2.23e-08, loss_d:3.10e-10
# Iter # 41000/200000	time:348.2	loss:5.31e-07, loss_r:2.23e-08, loss_d:3.08e-10
# Iter # 41100/200000	time:349.3	loss:5.29e-07, loss_r:2.22e-08, loss_d:3.07e-10
# Iter # 41200/200000	time:350.4	loss:5.28e-07, loss_r:2.21e-08, loss_d:3.07e-10
# Iter # 41300/200000	time:351.5	loss:5.26e-07, loss_r:2.21e-08, loss_d:3.06e-10
# Iter # 41400/200000	time:352.6	loss:5.24e-07, loss_r:2.20e-08, loss_d:3.05e-10
# Iter # 41500/200000	time:353.7	loss:5.23e-07, loss_r:2.19e-08, loss_d:3.04e-10
# Iter # 41600/200000	time:354.8	loss:5.21e-07, loss_r:2.18e-08, loss_d:3.03e-10
# Iter # 41700/200000	time:356.0	loss:5.19e-07, loss_r:2.18e-08, loss_d:3.02e-10
# Iter # 41800/200000	time:357.1	loss:5.17e-07, loss_r:2.17e-08, loss_d:3.01e-10
# Iter # 41900/200000	time:358.2	loss:5.16e-07, loss_r:2.16e-08, loss_d:3.00e-10
# Iter # 42000/200000	time:359.3	loss:5.14e-07, loss_r:2.15e-08, loss_d:2.99e-10
# Iter # 42100/200000	time:360.4	loss:5.12e-07, loss_r:2.15e-08, loss_d:2.98e-10
# Iter # 42200/200000	time:361.5	loss:5.11e-07, loss_r:2.14e-08, loss_d:2.97e-10
# Iter # 42300/200000	time:362.7	loss:5.09e-07, loss_r:2.13e-08, loss_d:2.96e-10
# Iter # 42400/200000	time:363.8	loss:5.07e-07, loss_r:2.13e-08, loss_d:2.95e-10
# Iter # 42500/200000	time:364.9	loss:5.06e-07, loss_r:2.12e-08, loss_d:2.94e-10
# Iter # 42600/200000	time:366.0	loss:5.04e-07, loss_r:2.11e-08, loss_d:2.93e-10
# Iter # 42700/200000	time:367.1	loss:5.02e-07, loss_r:2.11e-08, loss_d:2.92e-10
# Iter # 42800/200000	time:368.2	loss:5.01e-07, loss_r:2.10e-08, loss_d:2.91e-10
# Iter # 42900/200000	time:369.4	loss:4.99e-07, loss_r:2.09e-08, loss_d:2.90e-10
# Iter # 43000/200000	time:370.5	loss:4.97e-07, loss_r:2.09e-08, loss_d:2.89e-10
# Iter # 43100/200000	time:371.6	loss:4.96e-07, loss_r:2.08e-08, loss_d:2.88e-10
# Iter # 43200/200000	time:372.7	loss:4.94e-07, loss_r:2.07e-08, loss_d:2.87e-10
# Iter # 43300/200000	time:373.8	loss:4.93e-07, loss_r:2.07e-08, loss_d:2.86e-10
# Iter # 43400/200000	time:375.0	loss:4.91e-07, loss_r:2.06e-08, loss_d:2.85e-10
# Iter # 43500/200000	time:376.1	loss:4.89e-07, loss_r:2.05e-08, loss_d:2.84e-10
# Iter # 43600/200000	time:377.2	loss:4.88e-07, loss_r:2.05e-08, loss_d:2.83e-10
# Iter # 43700/200000	time:378.3	loss:4.86e-07, loss_r:2.04e-08, loss_d:2.82e-10
# Iter # 43800/200000	time:379.4	loss:4.84e-07, loss_r:2.03e-08, loss_d:2.81e-10
# Iter # 43900/200000	time:380.5	loss:4.83e-07, loss_r:2.03e-08, loss_d:2.80e-10
# Iter # 44000/200000	time:381.7	loss:4.81e-07, loss_r:2.02e-08, loss_d:2.79e-10
# Iter # 44100/200000	time:382.8	loss:4.80e-07, loss_r:2.02e-08, loss_d:2.78e-10
# Iter # 44200/200000	time:383.9	loss:4.78e-07, loss_r:2.01e-08, loss_d:2.77e-10
# Iter # 44300/200000	time:385.0	loss:4.77e-07, loss_r:2.00e-08, loss_d:2.76e-10
# Iter # 44400/200000	time:386.1	loss:4.75e-07, loss_r:2.00e-08, loss_d:2.75e-10
# Iter # 44500/200000	time:387.3	loss:4.74e-07, loss_r:1.99e-08, loss_d:2.75e-10
# Iter # 44600/200000	time:388.4	loss:4.72e-07, loss_r:1.98e-08, loss_d:2.74e-10
# Iter # 44700/200000	time:389.5	loss:4.70e-07, loss_r:1.98e-08, loss_d:2.73e-10
# Iter # 44800/200000	time:390.6	loss:4.69e-07, loss_r:1.97e-08, loss_d:2.72e-10
# Iter # 44900/200000	time:391.7	loss:4.68e-07, loss_r:1.97e-08, loss_d:2.71e-10
# Iter # 45000/200000	time:392.9	loss:4.66e-07, loss_r:1.96e-08, loss_d:2.70e-10
# Iter # 45100/200000	time:394.0	loss:4.65e-07, loss_r:1.96e-08, loss_d:2.69e-10
# Iter # 45200/200000	time:395.1	loss:4.63e-07, loss_r:1.95e-08, loss_d:2.68e-10
# Iter # 45300/200000	time:396.2	loss:4.62e-07, loss_r:1.94e-08, loss_d:2.67e-10
# Iter # 45400/200000	time:397.3	loss:4.60e-07, loss_r:1.94e-08, loss_d:2.66e-10
# Iter # 45500/200000	time:398.4	loss:4.59e-07, loss_r:1.93e-08, loss_d:2.65e-10
# Iter # 45600/200000	time:399.6	loss:4.57e-07, loss_r:1.93e-08, loss_d:2.64e-10
# Iter # 45700/200000	time:400.7	loss:4.56e-07, loss_r:1.92e-08, loss_d:2.64e-10
# Iter # 45800/200000	time:401.8	loss:4.54e-07, loss_r:1.92e-08, loss_d:2.63e-10
# Iter # 45900/200000	time:402.9	loss:4.53e-07, loss_r:1.91e-08, loss_d:2.62e-10
# Iter # 46000/200000	time:404.0	loss:4.51e-07, loss_r:1.90e-08, loss_d:2.61e-10
# Iter # 46100/200000	time:405.1	loss:4.50e-07, loss_r:1.90e-08, loss_d:2.60e-10
# Iter # 46200/200000	time:406.3	loss:4.49e-07, loss_r:1.89e-08, loss_d:2.59e-10
# Iter # 46300/200000	time:407.4	loss:4.47e-07, loss_r:1.89e-08, loss_d:2.58e-10
# Iter # 46400/200000	time:408.5	loss:4.46e-07, loss_r:1.88e-08, loss_d:2.57e-10
# Iter # 46500/200000	time:409.6	loss:4.44e-07, loss_r:1.88e-08, loss_d:2.56e-10
# Iter # 46600/200000	time:410.7	loss:4.43e-07, loss_r:1.87e-08, loss_d:2.56e-10
# Iter # 46700/200000	time:411.8	loss:4.41e-07, loss_r:1.87e-08, loss_d:2.55e-10
# Iter # 46800/200000	time:413.0	loss:4.40e-07, loss_r:1.86e-08, loss_d:2.54e-10
# Iter # 46900/200000	time:414.1	loss:4.39e-07, loss_r:1.86e-08, loss_d:2.53e-10
# Iter # 47000/200000	time:415.2	loss:4.37e-07, loss_r:1.85e-08, loss_d:2.52e-10
# Iter # 47100/200000	time:416.3	loss:4.36e-07, loss_r:1.85e-08, loss_d:2.51e-10
# Iter # 47200/200000	time:417.4	loss:4.34e-07, loss_r:1.84e-08, loss_d:2.50e-10
# Iter # 47300/200000	time:418.6	loss:4.33e-07, loss_r:1.84e-08, loss_d:2.49e-10
# Iter # 47400/200000	time:419.7	loss:4.32e-07, loss_r:1.83e-08, loss_d:2.49e-10
# Iter # 47500/200000	time:420.8	loss:4.30e-07, loss_r:1.83e-08, loss_d:2.48e-10
# Iter # 47600/200000	time:421.9	loss:4.29e-07, loss_r:1.82e-08, loss_d:2.47e-10
# Iter # 47700/200000	time:423.0	loss:4.28e-07, loss_r:1.82e-08, loss_d:2.46e-10
# Iter # 47800/200000	time:424.2	loss:4.26e-07, loss_r:1.81e-08, loss_d:2.45e-10
# Iter # 47900/200000	time:425.3	loss:4.25e-07, loss_r:1.81e-08, loss_d:2.44e-10
# Iter # 48000/200000	time:426.4	loss:4.23e-07, loss_r:1.80e-08, loss_d:2.43e-10
# Iter # 48100/200000	time:427.5	loss:4.22e-07, loss_r:1.80e-08, loss_d:2.42e-10
# Iter # 48200/200000	time:428.6	loss:4.21e-07, loss_r:1.79e-08, loss_d:2.42e-10
# Iter # 48300/200000	time:429.7	loss:4.19e-07, loss_r:1.79e-08, loss_d:2.41e-10
# Iter # 48400/200000	time:430.8	loss:4.18e-07, loss_r:1.78e-08, loss_d:2.40e-10
# Iter # 48500/200000	time:432.0	loss:4.17e-07, loss_r:1.78e-08, loss_d:2.39e-10
# Iter # 48600/200000	time:433.1	loss:4.15e-07, loss_r:1.77e-08, loss_d:2.38e-10
# Iter # 48700/200000	time:434.2	loss:4.14e-07, loss_r:1.77e-08, loss_d:2.37e-10
# Iter # 48800/200000	time:435.3	loss:4.13e-07, loss_r:1.76e-08, loss_d:2.37e-10
# Iter # 48900/200000	time:436.4	loss:4.12e-07, loss_r:1.76e-08, loss_d:2.36e-10
# Iter # 49000/200000	time:437.5	loss:4.10e-07, loss_r:1.75e-08, loss_d:2.35e-10
# Iter # 49100/200000	time:438.7	loss:4.09e-07, loss_r:1.75e-08, loss_d:2.34e-10
# Iter # 49200/200000	time:439.8	loss:4.08e-07, loss_r:1.75e-08, loss_d:2.33e-10
# Iter # 49300/200000	time:440.9	loss:4.07e-07, loss_r:1.74e-08, loss_d:2.32e-10
# Iter # 49400/200000	time:442.0	loss:4.05e-07, loss_r:1.74e-08, loss_d:2.32e-10
# Iter # 49500/200000	time:443.1	loss:4.04e-07, loss_r:1.73e-08, loss_d:2.31e-10
# Iter # 49600/200000	time:444.3	loss:4.03e-07, loss_r:1.73e-08, loss_d:2.30e-10
# Iter # 49700/200000	time:445.4	loss:4.01e-07, loss_r:1.72e-08, loss_d:2.29e-10
# Iter # 49800/200000	time:446.5	loss:4.00e-07, loss_r:1.72e-08, loss_d:2.28e-10
# Iter # 49900/200000	time:447.6	loss:3.99e-07, loss_r:1.71e-08, loss_d:2.27e-10
# Iter # 50000/200000	time:448.7	loss:3.98e-07, loss_r:1.71e-08, loss_d:2.27e-10
# Iter # 50100/200000	time:449.8	loss:3.96e-07, loss_r:1.70e-08, loss_d:2.26e-10
# Iter # 50200/200000	time:451.0	loss:3.95e-07, loss_r:1.70e-08, loss_d:2.25e-10
# Iter # 50300/200000	time:452.1	loss:3.94e-07, loss_r:1.70e-08, loss_d:2.24e-10
# Iter # 50400/200000	time:453.2	loss:3.93e-07, loss_r:1.69e-08, loss_d:2.23e-10
# Iter # 50500/200000	time:454.3	loss:3.91e-07, loss_r:1.69e-08, loss_d:2.23e-10
# Iter # 50600/200000	time:455.5	loss:3.90e-07, loss_r:1.68e-08, loss_d:2.22e-10
# Iter # 50700/200000	time:456.6	loss:3.89e-07, loss_r:1.68e-08, loss_d:2.21e-10
# Iter # 50800/200000	time:457.7	loss:3.88e-07, loss_r:1.67e-08, loss_d:2.20e-10
# Iter # 50900/200000	time:458.9	loss:3.86e-07, loss_r:1.67e-08, loss_d:2.19e-10
# Iter # 51000/200000	time:460.0	loss:3.85e-07, loss_r:1.67e-08, loss_d:2.19e-10
# Iter # 51100/200000	time:461.1	loss:3.84e-07, loss_r:1.66e-08, loss_d:2.18e-10
# Iter # 51200/200000	time:462.2	loss:3.83e-07, loss_r:1.66e-08, loss_d:2.17e-10
# Iter # 51300/200000	time:463.3	loss:3.81e-07, loss_r:1.65e-08, loss_d:2.16e-10
# Iter # 51400/200000	time:464.5	loss:3.80e-07, loss_r:1.65e-08, loss_d:2.15e-10
# Iter # 51500/200000	time:465.6	loss:3.79e-07, loss_r:1.64e-08, loss_d:2.15e-10
# Iter # 51600/200000	time:466.7	loss:3.78e-07, loss_r:1.64e-08, loss_d:2.14e-10
# Iter # 51700/200000	time:467.8	loss:3.77e-07, loss_r:1.64e-08, loss_d:2.13e-10
# Iter # 51800/200000	time:469.0	loss:3.75e-07, loss_r:1.63e-08, loss_d:2.12e-10
# Iter # 51900/200000	time:470.1	loss:3.74e-07, loss_r:1.63e-08, loss_d:2.12e-10
# Iter # 52000/200000	time:471.2	loss:3.73e-07, loss_r:1.62e-08, loss_d:2.11e-10
# Iter # 52100/200000	time:472.3	loss:3.72e-07, loss_r:1.62e-08, loss_d:2.10e-10
# Iter # 52200/200000	time:473.4	loss:3.71e-07, loss_r:1.62e-08, loss_d:2.09e-10
# Iter # 52300/200000	time:474.5	loss:3.70e-07, loss_r:1.61e-08, loss_d:2.08e-10
# Iter # 52400/200000	time:475.6	loss:3.68e-07, loss_r:1.61e-08, loss_d:2.08e-10
# Iter # 52500/200000	time:476.8	loss:3.67e-07, loss_r:1.60e-08, loss_d:2.07e-10
# Iter # 52600/200000	time:477.9	loss:3.66e-07, loss_r:1.60e-08, loss_d:2.06e-10
# Iter # 52700/200000	time:479.0	loss:3.65e-07, loss_r:1.59e-08, loss_d:2.05e-10
# Iter # 52800/200000	time:480.1	loss:3.64e-07, loss_r:1.59e-08, loss_d:2.05e-10
# Iter # 52900/200000	time:481.3	loss:3.62e-07, loss_r:1.59e-08, loss_d:2.04e-10
# Iter # 53000/200000	time:482.4	loss:3.61e-07, loss_r:1.58e-08, loss_d:2.03e-10
# Iter # 53100/200000	time:483.5	loss:3.60e-07, loss_r:1.58e-08, loss_d:2.02e-10
# Iter # 53200/200000	time:484.6	loss:3.59e-07, loss_r:1.57e-08, loss_d:2.02e-10
# Iter # 53300/200000	time:485.7	loss:3.58e-07, loss_r:1.57e-08, loss_d:2.01e-10
# Iter # 53400/200000	time:486.9	loss:3.57e-07, loss_r:1.57e-08, loss_d:2.00e-10
# Iter # 53500/200000	time:488.0	loss:3.56e-07, loss_r:1.56e-08, loss_d:1.99e-10
# Iter # 53600/200000	time:489.1	loss:3.55e-07, loss_r:1.56e-08, loss_d:1.99e-10
# Iter # 53700/200000	time:490.2	loss:3.54e-07, loss_r:1.56e-08, loss_d:1.98e-10
# Iter # 53800/200000	time:491.3	loss:3.53e-07, loss_r:1.55e-08, loss_d:1.97e-10
# Iter # 53900/200000	time:492.4	loss:3.51e-07, loss_r:1.55e-08, loss_d:1.96e-10
# Iter # 54000/200000	time:493.6	loss:3.50e-07, loss_r:1.55e-08, loss_d:1.96e-10
# Iter # 54100/200000	time:494.7	loss:3.49e-07, loss_r:1.54e-08, loss_d:1.95e-10
# Iter # 54200/200000	time:495.8	loss:3.48e-07, loss_r:1.54e-08, loss_d:1.94e-10
# Iter # 54300/200000	time:496.9	loss:3.47e-07, loss_r:1.53e-08, loss_d:1.94e-10
# Iter # 54400/200000	time:498.0	loss:3.46e-07, loss_r:1.53e-08, loss_d:1.93e-10
# Iter # 54500/200000	time:499.2	loss:3.45e-07, loss_r:1.53e-08, loss_d:1.92e-10
# Iter # 54600/200000	time:500.3	loss:3.43e-07, loss_r:1.52e-08, loss_d:1.91e-10
# Iter # 54700/200000	time:501.4	loss:3.42e-07, loss_r:1.52e-08, loss_d:1.91e-10
# Iter # 54800/200000	time:502.5	loss:3.41e-07, loss_r:1.51e-08, loss_d:1.90e-10
# Iter # 54900/200000	time:503.7	loss:3.40e-07, loss_r:1.51e-08, loss_d:1.89e-10
# Iter # 55000/200000	time:504.8	loss:3.39e-07, loss_r:1.51e-08, loss_d:1.88e-10
# Iter # 55100/200000	time:505.9	loss:3.38e-07, loss_r:1.50e-08, loss_d:1.88e-10
# Iter # 55200/200000	time:507.0	loss:3.37e-07, loss_r:1.50e-08, loss_d:1.87e-10
# Iter # 55300/200000	time:508.1	loss:3.36e-07, loss_r:1.50e-08, loss_d:1.86e-10
# Iter # 55400/200000	time:509.2	loss:3.35e-07, loss_r:1.49e-08, loss_d:1.86e-10
# Iter # 55500/200000	time:510.4	loss:3.34e-07, loss_r:1.49e-08, loss_d:1.85e-10
# Iter # 55600/200000	time:511.5	loss:3.33e-07, loss_r:1.49e-08, loss_d:1.84e-10
# Iter # 55700/200000	time:512.6	loss:3.32e-07, loss_r:1.48e-08, loss_d:1.84e-10
# Iter # 55800/200000	time:513.7	loss:3.31e-07, loss_r:1.48e-08, loss_d:1.83e-10
# Iter # 55900/200000	time:514.8	loss:3.30e-07, loss_r:1.48e-08, loss_d:1.82e-10
# Iter # 56000/200000	time:515.9	loss:3.29e-07, loss_r:1.47e-08, loss_d:1.81e-10
# Iter # 56100/200000	time:517.1	loss:3.28e-07, loss_r:1.47e-08, loss_d:1.81e-10
# Iter # 56200/200000	time:518.2	loss:3.26e-07, loss_r:1.46e-08, loss_d:1.80e-10
# Iter # 56300/200000	time:519.3	loss:3.25e-07, loss_r:1.46e-08, loss_d:1.79e-10
# Iter # 56400/200000	time:520.4	loss:3.24e-07, loss_r:1.46e-08, loss_d:1.79e-10
# Iter # 56500/200000	time:521.5	loss:3.23e-07, loss_r:1.45e-08, loss_d:1.78e-10
# Iter # 56600/200000	time:522.6	loss:3.22e-07, loss_r:1.45e-08, loss_d:1.77e-10
# Iter # 56700/200000	time:523.8	loss:3.21e-07, loss_r:1.45e-08, loss_d:1.77e-10
# Iter # 56800/200000	time:524.9	loss:3.20e-07, loss_r:1.45e-08, loss_d:1.76e-10
# Iter # 56900/200000	time:526.0	loss:3.19e-07, loss_r:1.44e-08, loss_d:1.75e-10
# Iter # 57000/200000	time:527.1	loss:3.19e-07, loss_r:1.44e-08, loss_d:1.75e-10
# Iter # 57100/200000	time:528.2	loss:3.18e-07, loss_r:1.44e-08, loss_d:1.74e-10
# Iter # 57200/200000	time:529.4	loss:3.17e-07, loss_r:1.43e-08, loss_d:1.73e-10
# Iter # 57300/200000	time:530.5	loss:3.16e-07, loss_r:1.43e-08, loss_d:1.73e-10
# Iter # 57400/200000	time:531.6	loss:3.15e-07, loss_r:1.43e-08, loss_d:1.72e-10
# Iter # 57500/200000	time:532.7	loss:3.14e-07, loss_r:1.42e-08, loss_d:1.71e-10
# Iter # 57600/200000	time:533.8	loss:3.13e-07, loss_r:1.42e-08, loss_d:1.71e-10
# ...
# Iter # 180400/200000	time:1913.0	loss:2.56e-08, loss_r:1.61e-09, loss_d:9.55e-12
# Iter # 180500/200000	time:1914.1	loss:2.56e-08, loss_r:1.61e-09, loss_d:9.54e-12
# Iter # 180600/200000	time:1915.2	loss:2.56e-08, loss_r:1.60e-09, loss_d:9.54e-12
# Iter # 180700/200000	time:1916.3	loss:2.56e-08, loss_r:1.60e-09, loss_d:9.53e-12
# Iter # 180800/200000	time:1917.5	loss:2.55e-08, loss_r:1.60e-09, loss_d:9.53e-12
# Iter # 180900/200000	time:1918.6	loss:2.55e-08, loss_r:1.60e-09, loss_d:9.53e-12
# Iter # 181000/200000	time:1919.7	loss:2.55e-08, loss_r:1.60e-09, loss_d:9.52e-12
# Iter # 181100/200000	time:1920.8	loss:2.55e-08, loss_r:1.60e-09, loss_d:9.52e-12
# Iter # 181200/200000	time:1921.9	loss:2.55e-08, loss_r:1.60e-09, loss_d:9.51e-12
# Iter # 181300/200000	time:1923.1	loss:2.54e-08, loss_r:1.59e-09, loss_d:9.51e-12
# Iter # 181400/200000	time:1924.2	loss:2.54e-08, loss_r:1.59e-09, loss_d:9.51e-12
# Iter # 181500/200000	time:1925.3	loss:2.54e-08, loss_r:1.59e-09, loss_d:9.50e-12
# Iter # 181600/200000	time:1926.4	loss:2.54e-08, loss_r:1.59e-09, loss_d:9.49e-12
# Iter # 181700/200000	time:1927.5	loss:2.54e-08, loss_r:1.59e-09, loss_d:9.49e-12
# Iter # 181800/200000	time:1928.7	loss:2.53e-08, loss_r:1.59e-09, loss_d:9.48e-12
# Iter # 181900/200000	time:1929.8	loss:2.53e-08, loss_r:1.58e-09, loss_d:9.47e-12
# Iter # 182000/200000	time:1930.9	loss:2.53e-08, loss_r:1.58e-09, loss_d:9.47e-12
# Iter # 182100/200000	time:1932.0	loss:2.53e-08, loss_r:1.58e-09, loss_d:9.46e-12
# Iter # 182200/200000	time:1933.1	loss:2.52e-08, loss_r:1.58e-09, loss_d:9.45e-12
# Iter # 182300/200000	time:1934.3	loss:2.52e-08, loss_r:1.58e-09, loss_d:9.45e-12
# Iter # 182400/200000	time:1935.4	loss:2.52e-08, loss_r:1.57e-09, loss_d:9.44e-12
# Iter # 182500/200000	time:1936.5	loss:2.51e-08, loss_r:1.57e-09, loss_d:9.43e-12
# Iter # 182600/200000	time:1937.6	loss:2.51e-08, loss_r:1.57e-09, loss_d:9.43e-12
# Iter # 182700/200000	time:1938.8	loss:2.51e-08, loss_r:1.57e-09, loss_d:9.42e-12
# Iter # 182800/200000	time:1939.9	loss:2.51e-08, loss_r:1.57e-09, loss_d:9.41e-12
# Iter # 182900/200000	time:1941.0	loss:2.50e-08, loss_r:1.56e-09, loss_d:9.40e-12
# Iter # 183000/200000	time:1942.1	loss:2.50e-08, loss_r:1.56e-09, loss_d:9.40e-12
# Iter # 183100/200000	time:1943.2	loss:2.50e-08, loss_r:1.56e-09, loss_d:9.39e-12
# Iter # 183200/200000	time:1944.4	loss:2.50e-08, loss_r:1.56e-09, loss_d:9.38e-12
# Iter # 183300/200000	time:1945.5	loss:2.49e-08, loss_r:1.55e-09, loss_d:9.37e-12
# Iter # 183400/200000	time:1946.6	loss:2.49e-08, loss_r:1.55e-09, loss_d:9.36e-12
# Iter # 183500/200000	time:1947.7	loss:2.49e-08, loss_r:1.55e-09, loss_d:9.35e-12
# Iter # 183600/200000	time:1948.9	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.35e-12
# Iter # 183700/200000	time:1950.0	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.35e-12
# Iter # 183800/200000	time:1951.1	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.35e-12
# Iter # 183900/200000	time:1952.2	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.35e-12
# Iter # 184000/200000	time:1953.3	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.34e-12
# Iter # 184100/200000	time:1954.5	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.34e-12
# Iter # 184200/200000	time:1955.6	loss:2.48e-08, loss_r:1.55e-09, loss_d:9.34e-12
# Iter # 184300/200000	time:1956.7	loss:2.48e-08, loss_r:1.54e-09, loss_d:9.34e-12
# Iter # 184400/200000	time:1957.8	loss:2.48e-08, loss_r:1.54e-09, loss_d:9.33e-12
# Iter # 184500/200000	time:1958.9	loss:2.48e-08, loss_r:1.54e-09, loss_d:9.33e-12
# Iter # 184600/200000	time:1960.1	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.33e-12
# Iter # 184700/200000	time:1961.2	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.33e-12
# Iter # 184800/200000	time:1962.3	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.33e-12
# Iter # 184900/200000	time:1963.4	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.32e-12
# Iter # 185000/200000	time:1964.6	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.32e-12
# Iter # 185100/200000	time:1965.7	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.32e-12
# Iter # 185200/200000	time:1966.8	loss:2.47e-08, loss_r:1.54e-09, loss_d:9.31e-12
# Iter # 185300/200000	time:1968.0	loss:2.47e-08, loss_r:1.53e-09, loss_d:9.31e-12
# Iter # 185400/200000	time:1969.1	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.31e-12
# Iter # 185500/200000	time:1970.2	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.30e-12
# Iter # 185600/200000	time:1971.3	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.30e-12
# Iter # 185700/200000	time:1972.5	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.29e-12
# Iter # 185800/200000	time:1973.6	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.29e-12
# Iter # 185900/200000	time:1974.7	loss:2.46e-08, loss_r:1.53e-09, loss_d:9.29e-12
# Iter # 186000/200000	time:1975.8	loss:2.45e-08, loss_r:1.53e-09, loss_d:9.28e-12
# Iter # 186100/200000	time:1977.0	loss:2.45e-08, loss_r:1.52e-09, loss_d:9.28e-12
# Iter # 186200/200000	time:1978.1	loss:2.45e-08, loss_r:1.52e-09, loss_d:9.28e-12
# Iter # 186300/200000	time:1979.2	loss:2.45e-08, loss_r:1.52e-09, loss_d:9.27e-12
# Iter # 186400/200000	time:1980.3	loss:2.45e-08, loss_r:1.52e-09, loss_d:9.26e-12
# Iter # 186500/200000	time:1981.4	loss:2.44e-08, loss_r:1.52e-09, loss_d:9.26e-12
# Iter # 186600/200000	time:1982.6	loss:2.44e-08, loss_r:1.52e-09, loss_d:9.26e-12
# Iter # 186700/200000	time:1983.7	loss:2.44e-08, loss_r:1.52e-09, loss_d:9.25e-12
# Iter # 186800/200000	time:1984.8	loss:2.44e-08, loss_r:1.51e-09, loss_d:9.24e-12
# Iter # 186900/200000	time:1985.9	loss:2.44e-08, loss_r:1.51e-09, loss_d:9.24e-12
# Iter # 187000/200000	time:1987.1	loss:2.43e-08, loss_r:1.51e-09, loss_d:9.23e-12
# Iter # 187100/200000	time:1988.2	loss:2.43e-08, loss_r:1.51e-09, loss_d:9.23e-12
# Iter # 187200/200000	time:1989.3	loss:2.43e-08, loss_r:1.51e-09, loss_d:9.22e-12
# Iter # 187300/200000	time:1990.4	loss:2.43e-08, loss_r:1.51e-09, loss_d:9.21e-12
# Iter # 187400/200000	time:1991.6	loss:2.42e-08, loss_r:1.50e-09, loss_d:9.21e-12
# Iter # 187500/200000	time:1992.7	loss:2.42e-08, loss_r:1.50e-09, loss_d:9.20e-12
# Iter # 187600/200000	time:1993.8	loss:2.42e-08, loss_r:1.50e-09, loss_d:9.20e-12
# Iter # 187700/200000	time:1994.9	loss:2.42e-08, loss_r:1.50e-09, loss_d:9.19e-12
# Iter # 187800/200000	time:1996.0	loss:2.41e-08, loss_r:1.50e-09, loss_d:9.18e-12
# Iter # 187900/200000	time:1997.2	loss:2.41e-08, loss_r:1.49e-09, loss_d:9.17e-12
# Iter # 188000/200000	time:1998.3	loss:2.41e-08, loss_r:1.49e-09, loss_d:9.17e-12
# Iter # 188100/200000	time:1999.4	loss:2.41e-08, loss_r:1.49e-09, loss_d:9.16e-12
# Iter # 188200/200000	time:2000.5	loss:2.40e-08, loss_r:1.49e-09, loss_d:9.15e-12
# Iter # 188300/200000	time:2001.6	loss:2.40e-08, loss_r:1.49e-09, loss_d:9.14e-12
# Iter # 188400/200000	time:2002.8	loss:2.42e-08, loss_r:1.49e-09, loss_d:9.30e-12
# Iter # 188500/200000	time:2003.9	loss:2.40e-08, loss_r:1.48e-09, loss_d:9.14e-12
# Iter # 188600/200000	time:2005.0	loss:2.40e-08, loss_r:1.48e-09, loss_d:9.13e-12
# Iter # 188700/200000	time:2006.2	loss:2.40e-08, loss_r:1.48e-09, loss_d:9.13e-12
# Iter # 188800/200000	time:2007.3	loss:2.40e-08, loss_r:1.48e-09, loss_d:9.13e-12
# Iter # 188900/200000	time:2008.4	loss:2.40e-08, loss_r:1.48e-09, loss_d:9.13e-12
# Iter # 189000/200000	time:2009.5	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.13e-12
# Iter # 189100/200000	time:2010.6	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.12e-12
# Iter # 189200/200000	time:2011.8	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.12e-12
# Iter # 189300/200000	time:2012.9	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.12e-12
# Iter # 189400/200000	time:2014.0	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.12e-12
# Iter # 189500/200000	time:2015.1	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.11e-12
# Iter # 189600/200000	time:2016.2	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.11e-12
# Iter # 189700/200000	time:2017.4	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.11e-12
# Iter # 189800/200000	time:2018.5	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.11e-12
# Iter # 189900/200000	time:2019.6	loss:2.39e-08, loss_r:1.48e-09, loss_d:9.11e-12
# Iter # 190000/200000	time:2020.7	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.10e-12
# Iter # 190100/200000	time:2021.8	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.10e-12
# Iter # 190200/200000	time:2023.0	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.10e-12
# Iter # 190300/200000	time:2024.1	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.10e-12
# Iter # 190400/200000	time:2025.2	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.09e-12
# Iter # 190500/200000	time:2026.3	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.09e-12
# Iter # 190600/200000	time:2027.4	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.09e-12
# Iter # 190700/200000	time:2028.6	loss:2.38e-08, loss_r:1.47e-09, loss_d:9.08e-12
# Iter # 190800/200000	time:2029.7	loss:2.37e-08, loss_r:1.47e-09, loss_d:9.08e-12
# Iter # 190900/200000	time:2030.8	loss:2.37e-08, loss_r:1.47e-09, loss_d:9.08e-12
# Iter # 191000/200000	time:2031.9	loss:2.37e-08, loss_r:1.46e-09, loss_d:9.07e-12
# Iter # 191100/200000	time:2033.1	loss:2.37e-08, loss_r:1.46e-09, loss_d:9.07e-12
# Iter # 191200/200000	time:2034.2	loss:2.37e-08, loss_r:1.46e-09, loss_d:9.07e-12
# Iter # 191300/200000	time:2035.3	loss:2.37e-08, loss_r:1.46e-09, loss_d:9.06e-12
# Iter # 191400/200000	time:2036.4	loss:2.37e-08, loss_r:1.46e-09, loss_d:9.06e-12
# Iter # 191500/200000	time:2037.6	loss:2.36e-08, loss_r:1.46e-09, loss_d:9.05e-12
# Iter # 191600/200000	time:2038.7	loss:2.36e-08, loss_r:1.46e-09, loss_d:9.05e-12
# Iter # 191700/200000	time:2039.8	loss:2.36e-08, loss_r:1.46e-09, loss_d:9.04e-12
# Iter # 191800/200000	time:2040.9	loss:2.36e-08, loss_r:1.45e-09, loss_d:9.04e-12
# Iter # 191900/200000	time:2042.1	loss:2.36e-08, loss_r:1.45e-09, loss_d:9.03e-12
# Iter # 192000/200000	time:2043.2	loss:2.35e-08, loss_r:1.45e-09, loss_d:9.03e-12
# Iter # 192100/200000	time:2044.3	loss:2.35e-08, loss_r:1.45e-09, loss_d:9.02e-12
# Iter # 192200/200000	time:2045.4	loss:2.35e-08, loss_r:1.45e-09, loss_d:9.02e-12
# Iter # 192300/200000	time:2046.6	loss:2.35e-08, loss_r:1.45e-09, loss_d:9.01e-12
# Iter # 192400/200000	time:2047.7	loss:2.35e-08, loss_r:1.45e-09, loss_d:9.01e-12
# Iter # 192500/200000	time:2048.8	loss:2.34e-08, loss_r:1.44e-09, loss_d:9.00e-12
# Iter # 192600/200000	time:2049.9	loss:2.34e-08, loss_r:1.44e-09, loss_d:9.00e-12
# Iter # 192700/200000	time:2051.1	loss:2.34e-08, loss_r:1.44e-09, loss_d:8.99e-12
# Iter # 192800/200000	time:2052.2	loss:2.34e-08, loss_r:1.44e-09, loss_d:8.98e-12
# Iter # 192900/200000	time:2053.3	loss:2.34e-08, loss_r:1.44e-09, loss_d:8.98e-12
# Iter # 193000/200000	time:2054.4	loss:2.33e-08, loss_r:1.44e-09, loss_d:8.97e-12
# Iter # 193100/200000	time:2055.5	loss:2.33e-08, loss_r:1.43e-09, loss_d:8.96e-12
# Iter # 193200/200000	time:2056.7	loss:2.33e-08, loss_r:1.43e-09, loss_d:8.95e-12
# Iter # 193300/200000	time:2057.8	loss:2.33e-08, loss_r:1.43e-09, loss_d:8.94e-12
# Iter # 193400/200000	time:2058.9	loss:2.36e-08, loss_r:1.44e-09, loss_d:9.20e-12
# Iter # 193500/200000	time:2060.1	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.94e-12
# Iter # 193600/200000	time:2061.2	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.94e-12
# Iter # 193700/200000	time:2062.3	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.93e-12
# Iter # 193800/200000	time:2063.4	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.93e-12
# Iter # 193900/200000	time:2064.5	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.93e-12
# Iter # 194000/200000	time:2065.7	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.93e-12
# Iter # 194100/200000	time:2066.8	loss:2.32e-08, loss_r:1.43e-09, loss_d:8.93e-12
# Iter # 194200/200000	time:2067.9	loss:2.32e-08, loss_r:1.42e-09, loss_d:8.92e-12
# Iter # 194300/200000	time:2069.0	loss:2.32e-08, loss_r:1.42e-09, loss_d:8.92e-12
# Iter # 194400/200000	time:2070.1	loss:2.32e-08, loss_r:1.42e-09, loss_d:8.92e-12
# Iter # 194500/200000	time:2071.3	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.92e-12
# Iter # 194600/200000	time:2072.4	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.92e-12
# Iter # 194700/200000	time:2073.5	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.91e-12
# Iter # 194800/200000	time:2074.6	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.91e-12
# Iter # 194900/200000	time:2075.8	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.91e-12
# Iter # 195000/200000	time:2076.9	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.91e-12
# Iter # 195100/200000	time:2078.0	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.90e-12
# Iter # 195200/200000	time:2079.1	loss:2.31e-08, loss_r:1.42e-09, loss_d:8.90e-12
# Iter # 195300/200000	time:2080.3	loss:2.30e-08, loss_r:1.42e-09, loss_d:8.90e-12
# Iter # 195400/200000	time:2081.4	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.89e-12
# Iter # 195500/200000	time:2082.5	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.89e-12
# Iter # 195600/200000	time:2083.6	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.89e-12
# Iter # 195700/200000	time:2084.8	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.88e-12
# Iter # 195800/200000	time:2085.9	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.88e-12
# Iter # 195900/200000	time:2087.0	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.88e-12
# Iter # 196000/200000	time:2088.1	loss:2.30e-08, loss_r:1.41e-09, loss_d:8.87e-12
# Iter # 196100/200000	time:2089.2	loss:2.29e-08, loss_r:1.41e-09, loss_d:8.87e-12
# Iter # 196200/200000	time:2090.4	loss:2.29e-08, loss_r:1.41e-09, loss_d:8.86e-12
# Iter # 196300/200000	time:2091.5	loss:2.29e-08, loss_r:1.40e-09, loss_d:8.86e-12
# Iter # 196400/200000	time:2092.6	loss:2.29e-08, loss_r:1.40e-09, loss_d:8.85e-12
# Iter # 196500/200000	time:2093.7	loss:2.29e-08, loss_r:1.40e-09, loss_d:8.85e-12
# Iter # 196600/200000	time:2094.9	loss:2.29e-08, loss_r:1.40e-09, loss_d:8.84e-12
# Iter # 196700/200000	time:2096.0	loss:2.28e-08, loss_r:1.40e-09, loss_d:8.84e-12
# Iter # 196800/200000	time:2097.1	loss:2.28e-08, loss_r:1.40e-09, loss_d:8.83e-12
# Iter # 196900/200000	time:2098.2	loss:2.28e-08, loss_r:1.40e-09, loss_d:8.83e-12
# Iter # 197000/200000	time:2099.4	loss:2.28e-08, loss_r:1.40e-09, loss_d:8.82e-12
# Iter # 197100/200000	time:2100.5	loss:2.28e-08, loss_r:1.39e-09, loss_d:8.82e-12
# Iter # 197200/200000	time:2101.6	loss:2.27e-08, loss_r:1.39e-09, loss_d:8.81e-12
# Iter # 197300/200000	time:2102.7	loss:2.27e-08, loss_r:1.39e-09, loss_d:8.81e-12
# Iter # 197400/200000	time:2103.9	loss:2.27e-08, loss_r:1.39e-09, loss_d:8.80e-12
# Iter # 197500/200000	time:2105.0	loss:2.27e-08, loss_r:1.39e-09, loss_d:8.79e-12
# Iter # 197600/200000	time:2106.1	loss:2.27e-08, loss_r:1.39e-09, loss_d:8.79e-12
# Iter # 197700/200000	time:2107.2	loss:2.26e-08, loss_r:1.38e-09, loss_d:8.78e-12
# Iter # 197800/200000	time:2108.3	loss:2.26e-08, loss_r:1.38e-09, loss_d:8.78e-12
# Iter # 197900/200000	time:2109.5	loss:2.26e-08, loss_r:1.38e-09, loss_d:8.77e-12
# Iter # 198000/200000	time:2110.6	loss:2.26e-08, loss_r:1.38e-09, loss_d:8.76e-12
# Iter # 198100/200000	time:2111.7	loss:2.25e-08, loss_r:1.38e-09, loss_d:8.76e-12
# Iter # 198200/200000	time:2112.8	loss:2.25e-08, loss_r:1.38e-09, loss_d:8.75e-12
# Iter # 198300/200000	time:2114.0	loss:2.25e-08, loss_r:1.38e-09, loss_d:8.74e-12
# Iter # 198400/200000	time:2115.1	loss:2.25e-08, loss_r:1.37e-09, loss_d:8.74e-12
# Iter # 198500/200000	time:2116.2	loss:2.25e-08, loss_r:1.37e-09, loss_d:8.73e-12
# Iter # 198600/200000	time:2117.3	loss:2.25e-08, loss_r:1.37e-09, loss_d:8.73e-12
# Iter # 198700/200000	time:2118.5	loss:2.25e-08, loss_r:1.37e-09, loss_d:8.73e-12
# Iter # 198800/200000	time:2119.6	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.73e-12
# Iter # 198900/200000	time:2120.7	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.73e-12
# Iter # 199000/200000	time:2121.8	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199100/200000	time:2122.9	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199200/200000	time:2124.1	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199300/200000	time:2125.2	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199400/200000	time:2126.3	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199500/200000	time:2127.4	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199600/200000	time:2128.6	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.72e-12
# Iter # 199700/200000	time:2129.7	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.71e-12
# Iter # 199800/200000	time:2130.8	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.71e-12
# Iter # 199900/200000	time:2131.9	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.71e-12
# Iter # 200000/200000	time:2133.0	loss:2.24e-08, loss_r:1.37e-09, loss_d:8.71e-12

# %%
plt.hist(pinn.net_f(X_res).detach().cpu().numpy())
# Out:
# (array([   2.,    4.,   26.,  241.,  613., 1259., 1292.,  475.,   81.,
#            7.]),
#  array([-1.89109938e-04, -1.56707945e-04, -1.24305952e-04, -9.19039594e-05,
#         -5.95019665e-05, -2.70999735e-05,  5.30201942e-06,  3.77040124e-05,
#          7.01060053e-05,  1.02507998e-04,  1.34909991e-04]),
#  <BarContainer object of 10 artists>)

# %%
# 保存模型参数 训练记录
model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(),'nn_G_state': pinn.nn_G.state_dict()}
backbone_path = os.path.join(model_path, f'backbone_adam.pth')
torch.save(model_state, backbone_path)

np.save("./loss_logger_dict.npy", logger)

# %%
# 训练用时
def used_time(start_time):
    seconds = time.time() - start_time
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print(f'used time: {hours:.0f}h {minutes:.0f}m {seconds:.0f}s')
    
used_time(start_time)
# Out:
# used time: 0h 35m 33s

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
# loss曲线
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k_plot = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k_plot], loss_logger["loss_res"][::k_plot], label=r"Re($\mathcal{L}_{r})$", linewidth=3)
ax.plot(loss_logger["iter"][::k_plot], loss_logger["loss_data"][::k_plot], label=r"Re($\mathcal{L}_{data})$", linewidth=3)
ax.set_yscale('log')
ax.set_xticks(np.linspace(0, loss_logger["iter"][-1], 5))
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
# 导入模型参数
mu = logger["mu"].cpu()
sigma = logger["sigma"].cpu()

backbone = MLP(mlp_layers)
nn_G = MLP(mlp_layers_G)
pinn = PINN(backbone, nn_G, mu, sigma)
model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_G.load_state_dict(model_state['nn_G_state'])
pinn.eval()
# Out:
# forward with normalization, mu=[0.125, 0.125], sigma=[0.07363609224557877, 0.0730857402086258]
# PINN(
#   (backbone): MLP(
#     (model): Sequential(
#       (fc1): Linear(in_features=2, out_features=60, bias=True)
#       (act1): Tanh()
#       (fc2): Linear(in_features=60, out_features=60, bias=True)
#       (act2): Tanh()
#       (fc3): Linear(in_features=60, out_features=60, bias=True)
#       (act3): Tanh()
#       (fc4): Linear(in_features=60, out_features=60, bias=True)
#       (act4): Tanh()
#       (fc5): Linear(in_features=60, out_features=60, bias=True)
#       (act5): Tanh()
#       (fc6): Linear(in_features=60, out_features=60, bias=True)
#       (act6): Tanh()
#       (fc7): Linear(in_features=60, out_features=60, bias=True)
#       (act7): Tanh()
#       (fc8): Linear(in_features=60, out_features=60, bias=True)
#       (act8): Tanh()
#       (fc9)): Linear(in_features=60, out_features=1, bias=False)
#     )
#   )
#   (nn_G): MLP(
#     (model): Sequential(
#       (fc1): Linear(in_features=2, out_features=20, bias=True)
#       (act1): Tanh()
#       (fc2): Linear(in_features=20, out_features=20, bias=True)
#       (act2): Tanh()
#       (fc3)): Linear(in_features=20, out_features=1, bias=False)
#     )
#   )
# )

# %%
def fun_G(X):
    return (np.sin(4*np.pi*X[:,[0]])) * (np.sin(4*np.pi*X[:,[1]]))

dataset = Dataset(domain)
X_res, X_bcs, u_bcs, u_res = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_bcs = torch.from_numpy(X_bcs).float().to(device)
u_bcs = torch.from_numpy(u_bcs).float().to(device)
u_res = torch.from_numpy(u_res).float().to(device)

# %%
X_res= X_res.cpu().detach().numpy()
X_bcs= X_bcs.cpu().detach().numpy()
X = np.concatenate([X_res,X_bcs],axis=0)
X = torch.from_numpy(X)
# X = X.reshape(-1, 1)

G_star = fun_G(X)
G_pred = pinn.net_G(X).detach()

# G_pred = G_pred.reshape(t.shape)
print(G_star.shape)
print(G_pred.shape)
G_error = np.linalg.norm(G_pred - G_star) / np.linalg.norm(G_star)

print('Relative l2 error of G: {:.3e}'.format(G_error))
# Out:
# torch.Size([4260, 1])
# torch.Size([4260, 1])
# Relative l2 error of G: 9.997e-01

# %%
plt.scatter(X[:,[0]], X[:,[1]], c=G_star)
plt.colorbar()

# %%
plt.scatter(X[:,[0]], X[:,[1]], c=G_pred)
plt.colorbar()

# %%
x = X[:,[0]]
y = X[:,[1]]
XX, YY = np.meshgrid(x, y)
XY = np.concatenate([XX.reshape(-1,1), YY.reshape(-1,1)], axis=1)
XY = torch.from_numpy(XY)

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].scatter(X[:,[0]], X[:,[1]], c=G_star)
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u(t,x)$')

axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].scatter(X[:,[0]], X[:,[1]], c=G_pred)
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u(t,x)$')
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].scatter(X[:,[0]], X[:,[1]], c=np.abs(G_star - G_pred))
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Burgers_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(30, 24))  
  
for i, ax in enumerate(axs.flat):  
    # 生成随机的数据  
    index = np.where(axis == (i+1))
    horizontal_filtered = horizontal[index]  
    vertical_filtered = vertical[index]  
    axis_filtered = axis[index]  
    
    X_filtered = np.stack([horizontal_filtered.flatten(), vertical_filtered.flatten(), axis_filtered.flatten()], axis=1)
    X_filtered = torch.from_numpy(X_filtered).float()
    temperature_filtered = pinn.net_u(X_filtered)
    temperature_filtered = temperature_filtered.detach().cpu().numpy().flatten()
    
#     temperature_filtered = temperature[index] 
  
    # 在子图中绘制数据  
    cax = ax.scatter(horizontal_filtered, vertical_filtered, c=temperature_filtered, s=100)
    fig.colorbar(cax)
  
    # 设置子图的标题和标签  
    ax.set_title(r'$T(x,y,z=$' + f'{i+1}' + r')')  
    ax.set_xlabel('$x$')  
    ax.set_ylabel('$y$')  
  
    # 清除坐标轴标签和刻度  
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_xticks(np.linspace(xmin, xmax, 5))
    ax.set_yticks(np.linspace(ymin, ymax, 5))
    ax.set_aspect(1./ax.get_data_ratio())
    
plt.tight_layout()  # 调整图像布局  
  
# 显示图像  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 fig, axs = plt.subplots(5, 5, figsize=(30, 24))
#       3 for i, ax in enumerate(axs.flat):
#       4     # 生成随机的数据
# ----> 5     index = np.where(axis == (i+1))
#       6     horizontal_filtered = horizontal[index]
#       7     vertical_filtered = vertical[index]
#
# NameError: name 'axis' is not defined

# %%
fig, axs = plt.subplots(5, 5, figsize=(30, 24))  
  
for i, ax in enumerate(axs.flat):  
    # 生成随机的数据  
    index = np.where(axis == (i+1))
    horizontal_filtered = horizontal[index]  
    vertical_filtered = vertical[index]  
    axis_filtered = axis[index]  
    
    X_filtered = np.stack([horizontal_filtered.flatten(), vertical_filtered.flatten(), axis_filtered.flatten()], axis=1)
    X_filtered = torch.from_numpy(X_filtered).float()
    temperature_filtered = pinn.net_u(X_filtered)
    temperature_filtered = temperature_filtered.detach().cpu().numpy().flatten()
    
    temperature_filtered_true = temperature[index] 
  
    # 在子图中绘制数据  
    cax = ax.scatter(horizontal_filtered, vertical_filtered, c=abs(temperature_filtered - temperature_filtered_true), s=100)
    fig.colorbar(cax)
  
    # 设置子图的标题和标签  
    ax.set_title('Absolute error')  
    ax.set_xlabel('$x$')  
    ax.set_ylabel('$y$')  
  
    # 清除坐标轴标签和刻度  
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_xticks(np.linspace(xmin, xmax, 5))
    ax.set_yticks(np.linspace(ymin, ymax, 5))
    ax.set_aspect(1./ax.get_data_ratio())
    
plt.tight_layout()  # 调整图像布局  
  
# 显示图像  
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(30, 24))  
  
for i, ax in enumerate(axs.flat):  
    # 生成随机的数据  
    index = np.where(axis == (i+1))
    horizontal_filtered = horizontal[index]  
    vertical_filtered = vertical[index]  
    axis_filtered = axis[index]  
    
    X_filtered = np.stack([horizontal_filtered.flatten(), vertical_filtered.flatten(), axis_filtered.flatten()], axis=1)
    X_filtered = torch.from_numpy(X_filtered).float()
    G_filtered = pinn.net_param(X_filtered)
    G_filtered = G_filtered.detach().cpu().numpy().flatten()
    
#     temperature_filtered = temperature[index] 
  
    # 在子图中绘制数据  
    cax = ax.scatter(horizontal_filtered, vertical_filtered, c=G_filtered, s=100)
    cbar = fig.colorbar(cax)
    cbar.formatter.set_powerlimits((-5, -5))
    cbar.update_ticks()
  
    # 设置子图的标题和标签  
    ax.set_title(r'$G(x,y,z=$' + f'{i+1}' + r')')  
    ax.set_xlabel('$x$')  
    ax.set_ylabel('$y$')  
  
    # 清除坐标轴标签和刻度  
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    ax.set_xticks(np.linspace(xmin, xmax, 5))
    ax.set_yticks(np.linspace(ymin, ymax, 5))
    ax.set_aspect(1./ax.get_data_ratio())
    
plt.tight_layout()  # 调整图像布局  
  
# 显示图像  
plt.show()

# %%
# import scipy.io as io
# io.savemat('./HelmholtzPINNsDiscovery.mat',{
#     'x':x_test, 
#     'y':x_test,
#     'xx':xx,
#     'yy':yy, 
#     'uu':uu, 
#     'vv':vv, 
#     'kk':kk, 
#     'uu_pred':uu_pred, 
#     'vv_pred':vv_pred, 
#     'kk_pred':kk_pred
# })
