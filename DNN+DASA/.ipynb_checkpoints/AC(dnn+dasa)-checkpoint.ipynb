# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_13095/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import time
from pyDOE import lhs
import matplotlib
# matplotlib.use('Agg')
import imageio
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import shutil
import pickle
import scipy.io
import random
import math
from scipy.interpolate import griddata

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.optim import lr_scheduler

import warnings
warnings.filterwarnings("ignore")

# %%
import argparse
class Options_AC(object):
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--use_subnet', default=True, help=' use subnet or not')
        parser.add_argument('--no_cuda', action='store_true', default=False, help='disable CUDA or not')
        parser.add_argument('--dim_hidden', type=int, default=128, help='neurons in hidden layers')
        parser.add_argument('--hidden_layers', type=int, default=4, help='number of hidden layers')
        parser.add_argument('--lr', type=float, default=1e-3, help='initial learning rate')
        parser.add_argument('--epochs_Adam', type=int, default=50000, help='epochs for Adam optimizer')
        parser.add_argument('--epochs_LBFGS', type=int, default=1000, help='epochs for LBFGS optimizer')
        parser.add_argument('--newton_iter', type=int, default=100, help='newton_iter for LBFGS optimizer')
        parser.add_argument('--step_size', type=int, default=5000, help='step size in lr_scheduler for Adam optimizer')
        parser.add_argument('--gamma', type=float, default=0.9, help='gamma in lr_scheduler for Adam optimizer')
        
        self.parser = parser

    def parse(self):
        arg = self.parser.parse_args(args=[])
        # arg.cuda = False
        # arg.device = torch.device('cpu')
        arg.cuda = not arg.no_cuda and torch.cuda.is_available()
        arg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        return arg

args = Options_AC().parse()
print(args.hidden_layers)

def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)
# Out:
# 8

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

def activation(name):
    if name in ['tanh', 'Tanh']:
        return nn.Tanh()
    elif name in ['relu', 'ReLU']:
        return nn.ReLU(inplace=True)
    elif name in ['leaky_relu', 'LeakyReLU']:
        return nn.LeakyReLU(inplace=True)
    elif name in ['sigmoid', 'Sigmoid']:
        return nn.Sigmoid()
    elif name in ['softplus', 'Softplus']:
        return nn.Softplus()
    else:
        raise ValueError(f'unknown activation function: {name}')

# %%
seed_torch(42)

# %%
class Modified_MLP(nn.Module):
    def __init__(self, dim_in, dim_out, dim_hidden, hidden_layers,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        self.hidden_layers = hidden_layers

        encoder_U = nn.Sequential()
        encoder_U.add_module('fc', nn.Linear(dim_in, dim_hidden, bias=True))
        encoder_U.add_module('act', activation(act_name))
        self.encoder_U = encoder_U

        encoder_V = nn.Sequential()
        encoder_V.add_module('fc', nn.Linear(dim_in, dim_hidden, bias=True))
        encoder_V.add_module('act', activation(act_name))
        self.encoder_V = encoder_V

        model = nn.Sequential()
        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))

        self.model = model
        if init_name is not None:
            self.init_weight(init_name)

        self.size = self.model_size()

    def init_weight(self, name):
        """初始化网络参数"""

        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
    
    def forward(self, x):
        """模型的正向传播"""
        U = self.encoder_U(x)
        V = self.encoder_V(x)
        for i in range(self.hidden_layers):
            x = self.model[2 * i](x)      # 调用线性层
            x = self.model[2 * i + 1](x)  # 调用激活层
            x = (1 - x) * U + x * V       # 特征融合
        x = self.model[-1](x)             # 调用最后一个线性层得到输出
        return x

    def model_size(self):
        """模型大小"""
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %% [markdown]
# ## 网络模型(DNN)

# %%
class MLP(nn.Module):
    """Deep Neural Network"""

    def __init__(self, L, M, dim_hidden, hidden_layers, dim_out,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        
        dim_in = M * 2 + 2
        
        model = Modified_MLP(dim_in, dim_out, dim_hidden, hidden_layers)
        
#         model = nn.Sequential()
        
#         model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
#         model.add_module('act0', activation(act_name))
#         for i in range(1, hidden_layers):
#             model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
#             model.add_module(f'act{i}', activation(act_name))
#         model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))
            
        self.model = model
        
        self.L = L
        self.M = M
        
        if init_name is not None:
            self.init_weight(init_name)

            
        self.k = nn.Parameter(torch.arange(1, self.M+1).float(), requires_grad=False)
                    
    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
                
    def input_encoding(self, t, x):
        w = 2.0 * math.pi / self.L
        out = torch.hstack([t, torch.ones_like(t), 
                            torch.cos(self.k * w * x), torch.sin(self.k * w * x)]) 
        
        return out    
            
    def forward(self, H):
        t = H[:, 0:1]
        x = H[:, 1:2]
        
        H = self.input_encoding(t, x)
        H = self.model(H)
        
        return H
    
    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %%
class DNN(nn.Module):
    """Deep Neural Network"""

    def __init__(self, dim_in, dim_out, dim_hidden, hidden_layers,
                 act_name='tanh', init_name=None):
        super().__init__()
        model = nn.Sequential()

        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))

        self.model = model
        if init_name is not None:
            self.init_weight(init_name)

    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)

    def forward(self, x):
        return self.model(x)

    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %%
# model = MLP(L=2.0, M=10, dim_hidden=args.dim_hidden, hidden_layers=args.hidden_layers, dim_out=1)
model = DNN(dim_in=2, dim_out=1, dim_hidden=args.dim_hidden, hidden_layers=args.hidden_layers)
model.cuda()
args.model=model

# %% [markdown]
# ## 数据集生成

# %%
class Trainset_AC():
    def __init__(self, *args):
        self.args = args
        self.shape = (self.args[1], self.args[0])
        
    def __call__(self):
        return self.data()
    
    def data(self):
        
        Nsd = self.args[0]
        n_ics = self.args[1]
        
        lb = np.array([0.0, -1.0])
        ub = np.array([1.0, 1.0])
        tx = (ub-lb)*lhs(2, Nsd)+lb
        
        lb_ics = np.array([0.0, -1.0])
        ub_ics = np.array([0.0, 1.0]) 
        tx_ics = (ub_ics-lb_ics)*lhs(2, n_ics)+lb_ics
        
        u_ics = tx_ics[:,[1]] ** 2 * np.cos(math.pi*tx_ics[:,[1]])
        
        
        tx = torch.from_numpy(tx).float().cuda()
        tx_ics = torch.from_numpy(tx_ics).float().cuda()
        u_ics = torch.from_numpy(u_ics).float().cuda()
        
        return tx, tx_ics, u_ics

# %%
trainset = Trainset_AC(25600, 512)
args.trainset = trainset
tx, tx_ics, u_ics = trainset()

# %% [markdown]
# ## 训练

# %%
class Unet(DNN):
    """Physics Constrained Neural Networks
    """
    def __init__(self, dim_in=2, dim_out=1, dim_hidden=10, hidden_layers=5,
                 act_name='sigmoid', init_name=None):
        super().__init__(dim_in, dim_out, dim_hidden, hidden_layers,
                         act_name=act_name, init_name=init_name)
        self.model.fc5.bias.requires_grad = False
    def minmaxscaler(self, data):
        mmin = torch.min(data,dim=0)[0]
        mmax = torch.max(data,dim=0)[0]
        data = (data - mmin)/(mmax-mmin)
        output = data/torch.sum(data) * len(data) + 1
        
        return output
    def forward(self, x):
        u = super().forward(x)
        u = self.minmaxscaler(u)
        return u

# %%
class Trainer_AC(object):
    def __init__(self, args):
        self.model = args.model
        self.lr = args.lr
        self.gamma = args.gamma

        self.newton_iter = args.newton_iter
        self.step_size = args.step_size
        
        self.model_name = self.model.__class__.__name__
        self.model_path = self._model_path()
        
        self.epochs_Adam = args.epochs_Adam
        self.epochs_LBFGS = args.epochs_LBFGS
        self.optimizer_Adam = optim.Adam(self.model.parameters(), lr=self.lr, betas=(0.9, 0.999))
        self.optimizer_LBFGS = optim.LBFGS(self.model.parameters(),
                                            lr=0.8,
                                            max_iter=self.newton_iter,
                                            tolerance_grad=1.e-5,
                                            tolerance_change=1.e-9)
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        
        # subnet(Unet)
        self.use_subnet = args.use_subnet
        self.Unet = args.Unet
        self.Unet.cuda()
        self.Unet.zero_grad()
        self.optimizer_Adam_Unet = optim.Adam(filter(lambda p: p.requires_grad==True, self.Unet.parameters()), lr=args.lr)    
        self.scheduler_Unet = lr_scheduler.ExponentialLR(self.optimizer_Adam_Unet, gamma=self.gamma, verbose=True)
        
        # data
        self.tx, self.tx_ics, self.u_ics = args.trainset()
 
        # Logger
        self.loss_log = []
        self.loss_b_log = []
        self.loss_r_log = []
        self.epoch_log = []
        
        self.loss_lbfgs_log = []
        self.loss_b_lbfgs_log = []
        self.loss_r_lbfgs_log = []
        self.epoch_lbfgs_log = []
        
        
    def _model_path(self):
        """Path to save the model"""
        if not os.path.exists('checkpoints'):
            os.mkdir('checkpoints')
        
        path = os.path.join('checkpoints', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path

    
    def net_r(self, tx):
        tx.requires_grad_(True)

        u = self.model(tx)

        grad_u = grad(u, tx)[0]
        u_t = grad_u[:,[0]]
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, tx)[0][:,[1]]

        residual = u_t - 0.0001*u_xx + 5*u**3 - 5*u

        return residual

    
    def net_u(self, tx):
        u = self.model(tx)
        
        return u
    
    
    def loss(self, use_ad=False):
        self.r_pred = self.net_r(self.tx)
        self.g_pred = self.net_u(self.tx_ics)

        if use_ad:

            self.r_weights = self.Unet(self.tx)
            loss_r = torch.mean((self.r_weights * self.r_pred)**2)
            loss_b = torch.mean((self.g_pred-self.u_ics)**2)
            loss = loss_r + 100*loss_b

        else:
            loss_r = torch.mean(self.r_pred**2)
            loss_b = torch.mean((self.g_pred-self.u_ics)**2)
            loss = loss_r + 100*loss_b

        return loss, loss_r, loss_b


    def train_Adam(self, mode='0'):
        """
        mode='0'：subnet参与计算，只训练主网络
        mode='1'：subnet参与计算，只训练subnet
        mode='2'：subnet参与计算，主网络和subnet对抗训练
        mode='3'：subnet不参与计算，只训练主网络
        """
        if mode == '0':
            self.optimizer_Adam.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()
            self.optimizer_Adam.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()
        
        elif mode == '1':
            self.optimizer_Adam_Unet.zero_grad()
            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()

            for name, parms in self.Unet.named_parameters():
                if parms.requires_grad==True:
                    parms.grad *= -1

            self.optimizer_Adam_Unet.step()        

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()

        elif mode == '2':
            self.optimizer_Adam.zero_grad()
            self.optimizer_Adam_Unet.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()
            self.optimizer_Adam.step()

            for name, parms in self.Unet.named_parameters():
                if parms.requires_grad==True:
                    parms.grad *= -1

            self.optimizer_Adam_Unet.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()

        else:
            self.optimizer_Adam.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=False)
            loss_value.backward()
            self.optimizer_Adam.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()
        

    def train_LBFGS(self):
        loss_value, loss_r_value, loss_b_value = self.loss()
        
        def closure():
            loss_value, loss_r_value, loss_b_value = self.loss()

            self.optimizer_LBFGS.zero_grad()
            loss_value.backward()

            return loss_value

        self.optimizer_LBFGS.step(closure)
        loss_value = closure()
        
        return loss_value.item(), loss_r_value.item(), loss_b_value.item()
    
    
    def validate(self, epoch):
        self.model.eval()
        loss_value, loss_r_value, loss_b_value = self.loss()
        
        infos = 'Valid   ' + \
                f'Loss:{loss_value:.4e}  ' + \
                f'Loss_r:{loss_r_value:.4e} '
        print(infos)
        self.model.train()
        return loss_value.item()
    
    
    def save_both_model(self, step, epoch):
        # save backbone
        model_state = {
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
        }
        backbone = os.path.join(self.model_path, 'backbone_%s_%d.pth' % (step, epoch))
        torch.save(model_state, backbone)

        # save subnet
        subnet_state = {
            'epoch': epoch,
            'state_dict': self.Unet.state_dict(),
        }    
        subnet = os.path.join(self.model_path, 'subnet_%s_%d.pth' % (step, epoch))
        torch.save(subnet_state, subnet)

    
    def train(self):
        start = time.time()
        best_loss = 1.e10
        
        # 1.只训练主网络
        for epoch in range(5000):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='3')    
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 1000 == 0:
                self.save_both_model('step1', epoch+1)
                                
                # data
                self.tx, self.tx_ics, self.u_ics = args.trainset()
                
        # 2.只训练subnet      
        for epoch in range(2000):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='1')      
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 1000 == 0:
                self.save_both_model('step2', epoch+1)
                                
                # data
                self.tx, self.tx_ics, self.u_ics = args.trainset()
                
                
        # 3.主网络和subnet对抗，一起训练      
        for epoch in range(self.epochs_Adam):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='2')
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()
                self.scheduler_Unet.step()
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)  
                
            if (epoch+1) % 1000 == 0:
                self.save_both_model('step3', epoch+1)
                                
                # data
                self.tx, self.tx_ics, self.u_ics = args.trainset()
         
        
        # 使用最好的模型
        state_dict = torch.load(f'{self.model_path}/best_model.pth')
        self.model.load_state_dict(state_dict['state_dict'])
            
        # 4.只训练主网络主网络
        for epoch in range(self.epochs_Adam):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='3')
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()         
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)  
                
            if (epoch+1) % 1000 == 0:
                self.save_both_model('step4', epoch+1) 
                
                # data
                self.tx, self.tx_ics, self.u_ics = args.trainset()

        # 5.lbfgs只训练主网络主网络    
        for epoch in range(self.epochs_LBFGS):
            loss_value, loss_r_value, loss_b_value = self.train_LBFGS()
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)         
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam + self.epochs_LBFGS}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 100 == 0:
                self.save_both_model('step5', epoch+1) 
                
                # data
                self.tx, self.tx_ics, self.u_ics = args.trainset()

# %%
args.Unet = Unet(dim_in=2)
trainer = Trainer_AC(args)
trainer.train()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch #  100/150000    time:13.99
# loss:3.24e-01, loss_r:3.03e-01, loss_b:2.10e-04,
# Valid   Loss:3.2268e-01  Loss_r:3.0213e-01
# Epoch #  200/150000    time:13.61
# loss:2.40e-01, loss_r:2.28e-01, loss_b:1.23e-04,
# Valid   Loss:2.3937e-01  Loss_r:2.2711e-01
# Epoch #  300/150000    time:13.58
# loss:1.54e-01, loss_r:1.46e-01, loss_b:8.44e-05,
# Valid   Loss:1.5338e-01  Loss_r:1.4497e-01
# Epoch #  400/150000    time:13.59
# loss:8.46e-02, loss_r:7.85e-02, loss_b:6.08e-05,
# Valid   Loss:8.4151e-02  Loss_r:7.8086e-02
# Epoch #  500/150000    time:13.59
# loss:5.94e-02, loss_r:5.43e-02, loss_b:5.04e-05,
# Valid   Loss:5.9214e-02  Loss_r:5.4181e-02
# Epoch #  600/150000    time:13.59
# loss:4.56e-02, loss_r:4.17e-02, loss_b:3.95e-05,
# Valid   Loss:4.5479e-02  Loss_r:4.1536e-02
# Epoch #  700/150000    time:13.88
# loss:3.58e-02, loss_r:3.27e-02, loss_b:3.13e-05,
# Valid   Loss:3.5734e-02  Loss_r:3.2614e-02
# Epoch #  800/150000    time:13.57
# loss:2.93e-02, loss_r:2.67e-02, loss_b:2.57e-05,
# Valid   Loss:2.9241e-02  Loss_r:2.6676e-02
# Epoch #  900/150000    time:13.56
# loss:2.40e-02, loss_r:2.14e-02, loss_b:2.55e-05,
# Valid   Loss:2.4069e-02  Loss_r:2.1544e-02
# Epoch #  1000/150000    time:13.56
# loss:1.83e-02, loss_r:1.66e-02, loss_b:1.67e-05,
# Valid   Loss:1.8287e-02  Loss_r:1.6544e-02
# Epoch #  1100/150000    time:13.55
# loss:1.59e-02, loss_r:1.33e-02, loss_b:2.61e-05,
# Valid   Loss:1.6647e-02  Loss_r:1.3599e-02
# Epoch #  1200/150000    time:13.57
# loss:1.07e-02, loss_r:9.70e-03, loss_b:1.03e-05,
# Valid   Loss:1.1127e-02  Loss_r:9.8160e-03
# Epoch #  1300/150000    time:13.57
# loss:9.31e-03, loss_r:8.38e-03, loss_b:9.31e-06,
# Valid   Loss:9.2511e-03  Loss_r:8.2651e-03
# Epoch #  1400/150000    time:13.56
# loss:8.32e-03, loss_r:7.50e-03, loss_b:8.23e-06,
# Valid   Loss:8.3203e-03  Loss_r:7.5501e-03
# Epoch #  1500/150000    time:13.57
# loss:9.06e-03, loss_r:7.86e-03, loss_b:1.20e-05,
# Valid   Loss:9.5344e-03  Loss_r:7.7395e-03
# Epoch #  1600/150000    time:13.56
# loss:1.67e-02, loss_r:1.20e-02, loss_b:4.73e-05,
# Valid   Loss:1.8144e-02  Loss_r:1.1312e-02
# Epoch #  1700/150000    time:13.57
# loss:8.24e-03, loss_r:6.84e-03, loss_b:1.40e-05,
# Valid   Loss:7.8659e-03  Loss_r:6.7444e-03
# Epoch #  1800/150000    time:13.57
# loss:7.47e-03, loss_r:6.53e-03, loss_b:9.44e-06,
# Valid   Loss:7.2604e-03  Loss_r:6.3011e-03
# Epoch #  1900/150000    time:13.57
# loss:7.40e-03, loss_r:6.29e-03, loss_b:1.11e-05,
# Valid   Loss:7.5737e-03  Loss_r:6.5954e-03
# Epoch #  2000/150000    time:13.57
# loss:6.72e-03, loss_r:6.04e-03, loss_b:6.79e-06,
# Valid   Loss:6.9158e-03  Loss_r:6.0478e-03
# Epoch #  2100/150000    time:13.58
# loss:9.83e-03, loss_r:7.13e-03, loss_b:2.69e-05,
# Valid   Loss:7.7682e-03  Loss_r:6.8111e-03
# Epoch #  2200/150000    time:13.57
# loss:6.50e-03, loss_r:5.89e-03, loss_b:6.06e-06,
# Valid   Loss:6.4980e-03  Loss_r:5.9016e-03
# Epoch #  2300/150000    time:13.56
# loss:9.32e-03, loss_r:7.89e-03, loss_b:1.43e-05,
# Valid   Loss:1.0112e-02  Loss_r:7.1788e-03
# Epoch #  2400/150000    time:13.56
# loss:2.22e-02, loss_r:1.23e-02, loss_b:9.84e-05,
# Valid   Loss:2.5958e-02  Loss_r:1.7583e-02
# Epoch #  2500/150000    time:13.56
# loss:8.77e-03, loss_r:6.44e-03, loss_b:2.33e-05,
# Valid   Loss:9.9202e-03  Loss_r:8.1635e-03
# Epoch #  2600/150000    time:13.56
# loss:6.35e-03, loss_r:5.62e-03, loss_b:7.35e-06,
# Valid   Loss:6.4206e-03  Loss_r:5.7943e-03
# Epoch #  2700/150000    time:13.56
# loss:6.15e-03, loss_r:5.56e-03, loss_b:5.90e-06,
# Valid   Loss:6.1474e-03  Loss_r:5.5948e-03
# Epoch #  2800/150000    time:13.56
# loss:6.10e-03, loss_r:5.55e-03, loss_b:5.50e-06,
# Valid   Loss:6.1026e-03  Loss_r:5.5255e-03
# Epoch #  2900/150000    time:13.56
# loss:6.18e-03, loss_r:5.62e-03, loss_b:5.58e-06,
# Valid   Loss:6.1154e-03  Loss_r:5.4470e-03
# Epoch #  3000/150000    time:13.57
# loss:6.03e-03, loss_r:5.45e-03, loss_b:5.78e-06,
# Valid   Loss:6.0265e-03  Loss_r:5.4645e-03
# Epoch #  3100/150000    time:13.58
# loss:6.43e-03, loss_r:5.39e-03, loss_b:1.03e-05,
# Valid   Loss:6.3620e-03  Loss_r:5.6686e-03
# Epoch #  3200/150000    time:13.57
# loss:2.98e-02, loss_r:1.36e-02, loss_b:1.62e-04,
# Valid   Loss:2.1731e-02  Loss_r:1.4988e-02
# Epoch #  3300/150000    time:13.57
# loss:5.89e-03, loss_r:5.34e-03, loss_b:5.50e-06,
# Valid   Loss:5.8921e-03  Loss_r:5.3331e-03
# Epoch #  3400/150000    time:13.57
# loss:5.92e-03, loss_r:5.33e-03, loss_b:5.92e-06,
# Valid   Loss:5.8997e-03  Loss_r:5.3392e-03
# Epoch #  3500/150000    time:13.57
# loss:5.91e-03, loss_r:5.26e-03, loss_b:6.49e-06,
# Valid   Loss:5.9159e-03  Loss_r:5.3579e-03
# Epoch #  3600/150000    time:13.58
# loss:5.93e-03, loss_r:5.17e-03, loss_b:7.65e-06,
# Valid   Loss:5.9588e-03  Loss_r:5.4827e-03
# Epoch #  3700/150000    time:13.57
# loss:5.86e-03, loss_r:5.20e-03, loss_b:6.55e-06,
# Valid   Loss:5.8862e-03  Loss_r:5.3503e-03
# Epoch #  3800/150000    time:13.57
# loss:5.98e-03, loss_r:5.54e-03, loss_b:4.37e-06,
# Valid   Loss:6.0168e-03  Loss_r:5.0966e-03
# Epoch #  3900/150000    time:13.57
# loss:5.99e-03, loss_r:5.31e-03, loss_b:6.74e-06,
# Valid   Loss:6.3192e-03  Loss_r:5.5304e-03
# Epoch #  4000/150000    time:13.57
# loss:5.74e-03, loss_r:5.09e-03, loss_b:6.51e-06,
# Valid   Loss:5.7414e-03  Loss_r:5.2569e-03
# Epoch #  4100/150000    time:13.58
# loss:5.80e-03, loss_r:4.99e-03, loss_b:8.06e-06,
# Valid   Loss:5.8071e-03  Loss_r:5.3862e-03
# Epoch #  4200/150000    time:13.57
# loss:1.36e-02, loss_r:9.19e-03, loss_b:4.37e-05,
# Valid   Loss:1.3855e-02  Loss_r:7.0085e-03
# Epoch #  4300/150000    time:13.57
# loss:5.66e-03, loss_r:4.84e-03, loss_b:8.25e-06,
# Valid   Loss:5.6903e-03  Loss_r:5.2782e-03
# Epoch #  4400/150000    time:13.57
# loss:8.10e-03, loss_r:6.73e-03, loss_b:1.37e-05,
# Valid   Loss:7.9269e-03  Loss_r:5.1157e-03
# Epoch #  4500/150000    time:13.56
# loss:5.06e-03, loss_r:4.51e-03, loss_b:5.42e-06,
# Valid   Loss:5.0690e-03  Loss_r:4.5830e-03
# Epoch #  4600/150000    time:13.57
# loss:5.08e-03, loss_r:4.61e-03, loss_b:4.68e-06,
# Valid   Loss:5.0645e-03  Loss_r:4.3979e-03
# Epoch #  4700/150000    time:13.57
# loss:5.83e-03, loss_r:4.85e-03, loss_b:9.86e-06,
# Valid   Loss:6.3776e-03  Loss_r:4.7030e-03
# Epoch #  4800/150000    time:13.57
# loss:4.64e-03, loss_r:4.26e-03, loss_b:3.80e-06,
# Valid   Loss:4.5319e-03  Loss_r:3.9586e-03
# Epoch #  4900/150000    time:13.56
# loss:4.45e-03, loss_r:3.83e-03, loss_b:6.19e-06,
# Valid   Loss:4.4413e-03  Loss_r:3.9652e-03
# Epoch #  5000/150000    time:13.57
# loss:1.84e-02, loss_r:5.12e-03, loss_b:1.32e-04,
# Valid   Loss:1.7284e-02  Loss_r:7.4940e-03
# Epoch #  100/150000    time:13.66
# loss:5.77e-02, loss_r:4.79e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  200/150000    time:13.65
# loss:5.86e-02, loss_r:4.88e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  300/150000    time:13.65
# loss:5.92e-02, loss_r:4.94e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  400/150000    time:13.65
# loss:6.09e-02, loss_r:5.11e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  500/150000    time:13.65
# loss:9.07e-02, loss_r:8.09e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  600/150000    time:13.64
# loss:9.23e-02, loss_r:8.26e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  700/150000    time:13.64
# loss:9.05e-02, loss_r:8.07e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  800/150000    time:13.64
# loss:9.86e-02, loss_r:8.88e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  900/150000    time:13.65
# loss:9.81e-02, loss_r:8.83e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  1000/150000    time:13.64
# loss:1.00e-01, loss_r:9.05e-02, loss_b:9.77e-05,
# Valid   Loss:1.7492e-02  Loss_r:7.7187e-03
# Epoch #  1100/150000    time:13.65
# loss:9.48e-02, loss_r:8.50e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1200/150000    time:13.64
# loss:9.83e-02, loss_r:8.85e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1300/150000    time:13.65
# loss:9.86e-02, loss_r:8.89e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1400/150000    time:13.65
# loss:9.82e-02, loss_r:8.85e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1500/150000    time:13.64
# loss:9.90e-02, loss_r:8.93e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1600/150000    time:13.64
# loss:9.89e-02, loss_r:8.92e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1700/150000    time:13.64
# loss:1.00e-01, loss_r:9.03e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1800/150000    time:13.64
# loss:9.99e-02, loss_r:9.02e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  1900/150000    time:13.64
# loss:1.01e-01, loss_r:9.10e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  2000/150000    time:13.64
# loss:1.01e-01, loss_r:9.09e-02, loss_b:9.73e-05,
# Valid   Loss:1.7242e-02  Loss_r:7.5081e-03
# Epoch #  100/150000    time:13.68
# loss:2.94e-01, loss_r:1.71e-01, loss_b:1.23e-03,
# Valid   Loss:1.4541e-01  Loss_r:2.4272e-02
# Epoch #  200/150000    time:13.68
# loss:1.25e-01, loss_r:6.00e-02, loss_b:6.52e-04,
# Valid   Loss:7.2824e-02  Loss_r:8.1452e-03
# Epoch #  300/150000    time:13.68
# loss:5.90e-02, loss_r:2.90e-02, loss_b:3.00e-04,
# Valid   Loss:3.4596e-02  Loss_r:4.7924e-03
# Epoch #  400/150000    time:13.68
# loss:4.29e-02, loss_r:2.07e-02, loss_b:2.22e-04,
# Valid   Loss:2.5665e-02  Loss_r:3.5257e-03
# Epoch #  500/150000    time:13.68
# loss:3.70e-02, loss_r:1.75e-02, loss_b:1.95e-04,
# Valid   Loss:2.2389e-02  Loss_r:2.8906e-03
# Epoch #  600/150000    time:13.68
# loss:3.58e-02, loss_r:1.66e-02, loss_b:1.92e-04,
# Valid   Loss:2.1872e-02  Loss_r:2.6833e-03
# Epoch #  700/150000    time:13.69
# loss:3.56e-02, loss_r:1.62e-02, loss_b:1.93e-04,
# Valid   Loss:2.1912e-02  Loss_r:2.5851e-03
# Epoch #  800/150000    time:13.68
# loss:3.56e-02, loss_r:1.61e-02, loss_b:1.95e-04,
# Valid   Loss:2.2078e-02  Loss_r:2.5370e-03
# Epoch #  900/150000    time:13.68
# loss:3.57e-02, loss_r:1.60e-02, loss_b:1.98e-04,
# Valid   Loss:2.2296e-02  Loss_r:2.5126e-03
# Epoch #  1000/150000    time:13.67
# loss:3.64e-02, loss_r:1.62e-02, loss_b:2.03e-04,
# Valid   Loss:2.2924e-02  Loss_r:2.6369e-03
# Epoch #  1100/150000    time:13.68
# loss:3.59e-02, loss_r:1.59e-02, loss_b:2.00e-04,
# Valid   Loss:2.2525e-02  Loss_r:2.4983e-03
# Epoch #  1200/150000    time:13.73
# loss:3.56e-02, loss_r:1.56e-02, loss_b:1.99e-04,
# Valid   Loss:2.2297e-02  Loss_r:2.4097e-03
# Epoch #  1300/150000    time:13.68
# loss:3.56e-02, loss_r:1.60e-02, loss_b:1.95e-04,
# Valid   Loss:2.2492e-02  Loss_r:2.3212e-03
# Epoch #  1400/150000    time:13.68
# loss:3.53e-02, loss_r:1.57e-02, loss_b:1.96e-04,
# Valid   Loss:2.2144e-02  Loss_r:2.4256e-03
# Epoch #  1500/150000    time:13.67
# loss:3.49e-02, loss_r:1.49e-02, loss_b:2.00e-04,
# Valid   Loss:2.1624e-02  Loss_r:2.4204e-03
# Epoch #  1600/150000    time:13.67
# loss:3.48e-02, loss_r:1.56e-02, loss_b:1.92e-04,
# Valid   Loss:2.1870e-02  Loss_r:2.5090e-03
# Epoch #  1700/150000    time:13.67
# loss:3.40e-02, loss_r:1.53e-02, loss_b:1.86e-04,
# Valid   Loss:2.1356e-02  Loss_r:2.4645e-03
# Epoch #  1800/150000    time:13.67
# loss:3.34e-02, loss_r:1.51e-02, loss_b:1.83e-04,
# Valid   Loss:2.1106e-02  Loss_r:2.4833e-03
# Epoch #  1900/150000    time:13.67
# loss:3.23e-02, loss_r:1.45e-02, loss_b:1.78e-04,
# Valid   Loss:2.0060e-02  Loss_r:2.5796e-03
# Epoch #  2000/150000    time:13.68
# loss:2.92e-02, loss_r:1.36e-02, loss_b:1.56e-04,
# Valid   Loss:1.8255e-02  Loss_r:2.5639e-03
# Epoch #  2100/150000    time:13.68
# loss:6.12e-01, loss_r:3.38e-01, loss_b:2.74e-03,
# Valid   Loss:3.1253e-01  Loss_r:4.3351e-02
# Epoch #  2200/150000    time:13.67
# loss:1.26e-01, loss_r:7.13e-02, loss_b:5.42e-04,
# Valid   Loss:6.3033e-02  Loss_r:9.9712e-03
# Epoch #  2300/150000    time:13.67
# loss:4.56e-02, loss_r:2.79e-02, loss_b:1.78e-04,
# Valid   Loss:2.2179e-02  Loss_r:4.5217e-03
# Epoch #  2400/150000    time:13.68
# loss:3.08e-02, loss_r:1.90e-02, loss_b:1.18e-04,
# Valid   Loss:1.5085e-02  Loss_r:3.3026e-03
# Epoch #  2500/150000    time:13.67
# loss:2.51e-02, loss_r:1.57e-02, loss_b:9.40e-05,
# Valid   Loss:1.2239e-02  Loss_r:2.7416e-03
# Epoch #  2600/150000    time:13.68
# loss:2.36e-02, loss_r:1.43e-02, loss_b:9.26e-05,
# Valid   Loss:1.1669e-02  Loss_r:2.3977e-03
# Epoch #  2700/150000    time:13.68
# loss:2.36e-02, loss_r:1.28e-02, loss_b:1.08e-04,
# Valid   Loss:1.3016e-02  Loss_r:2.2604e-03
# Epoch #  2800/150000    time:13.68
# loss:1.88e-02, loss_r:9.79e-03, loss_b:9.02e-05,
# Valid   Loss:1.0676e-02  Loss_r:1.6664e-03
# Epoch #  2900/150000    time:13.68
# loss:1.43e-02, loss_r:6.78e-03, loss_b:7.51e-05,
# Valid   Loss:8.8820e-03  Loss_r:1.3844e-03
# Epoch #  3000/150000    time:13.68
# loss:1.02e-02, loss_r:4.83e-03, loss_b:5.39e-05,
# Valid   Loss:6.4504e-03  Loss_r:1.0725e-03
# Epoch #  3100/150000    time:13.69
# loss:7.81e-03, loss_r:3.75e-03, loss_b:4.05e-05,
# Valid   Loss:4.8811e-03  Loss_r:8.3986e-04
# Epoch #  3200/150000    time:13.68
# loss:5.90e-03, loss_r:2.90e-03, loss_b:3.00e-05,
# Valid   Loss:3.6832e-03  Loss_r:6.9091e-04
# Epoch #  3300/150000    time:13.68
# loss:4.07e-03, loss_r:2.07e-03, loss_b:2.00e-05,
# Valid   Loss:2.6017e-03  Loss_r:4.8446e-04
# Epoch #  3400/150000    time:13.67
# loss:3.34e-03, loss_r:1.55e-03, loss_b:1.79e-05,
# Valid   Loss:2.3198e-03  Loss_r:5.9353e-04
# Epoch #  3500/150000    time:13.68
# loss:2.34e-01, loss_r:1.31e-01, loss_b:1.03e-03,
# Valid   Loss:1.1819e-01  Loss_r:1.6449e-02
# Epoch #  3600/150000    time:13.67
# loss:9.94e-02, loss_r:5.65e-02, loss_b:4.29e-04,
# Valid   Loss:4.9872e-02  Loss_r:7.5958e-03
# Epoch #  3700/150000    time:13.68
# loss:2.76e-02, loss_r:1.72e-02, loss_b:1.03e-04,
# Valid   Loss:1.3320e-02  Loss_r:2.9894e-03
# Epoch #  3800/150000    time:13.67
# loss:1.99e-02, loss_r:1.22e-02, loss_b:7.69e-05,
# Valid   Loss:9.7618e-03  Loss_r:2.1036e-03
# Epoch #  3900/150000    time:13.67
# loss:1.73e-02, loss_r:1.04e-02, loss_b:6.91e-05,
# Valid   Loss:8.6136e-03  Loss_r:1.7190e-03
# Epoch #  4000/150000    time:13.67
# loss:1.56e-02, loss_r:9.19e-03, loss_b:6.43e-05,
# Valid   Loss:7.8547e-03  Loss_r:1.4247e-03
# Epoch #  4100/150000    time:13.68
# loss:1.50e-02, loss_r:8.62e-03, loss_b:6.38e-05,
# Valid   Loss:7.6169e-03  Loss_r:1.2768e-03
# Epoch #  4200/150000    time:13.68
# loss:1.46e-02, loss_r:8.34e-03, loss_b:6.31e-05,
# Valid   Loss:7.4903e-03  Loss_r:1.2579e-03
# Epoch #  4300/150000    time:13.67
# loss:1.44e-02, loss_r:8.14e-03, loss_b:6.22e-05,
# Valid   Loss:7.3695e-03  Loss_r:1.1523e-03
# Epoch #  4400/150000    time:13.68
# loss:1.41e-02, loss_r:7.93e-03, loss_b:6.18e-05,
# Valid   Loss:7.2127e-03  Loss_r:1.1271e-03
# Epoch #  4500/150000    time:13.67
# loss:1.38e-02, loss_r:7.79e-03, loss_b:6.01e-05,
# Valid   Loss:7.1524e-03  Loss_r:1.0738e-03
# Epoch #  4600/150000    time:13.68
# loss:1.35e-02, loss_r:7.54e-03, loss_b:5.96e-05,
# Valid   Loss:6.9703e-03  Loss_r:1.0446e-03
# Epoch #  4700/150000    time:13.67
# loss:1.38e-02, loss_r:8.08e-03, loss_b:5.72e-05,
# Valid   Loss:6.7073e-03  Loss_r:1.0150e-03
# Epoch #  4800/150000    time:13.67
# loss:1.21e-02, loss_r:6.77e-03, loss_b:5.36e-05,
# Valid   Loss:6.3045e-03  Loss_r:9.3905e-04
# Epoch #  4900/150000    time:13.67
# loss:1.34e-02, loss_r:7.66e-03, loss_b:5.77e-05,
# Valid   Loss:6.0082e-03  Loss_r:1.1178e-03
# Adjusting learning rate of group 0 to 9.0000e-04.
# Adjusting learning rate of group 0 to 9.0000e-04.
# Epoch #  5000/150000    time:13.68
# loss:9.85e-03, loss_r:5.49e-03, loss_b:4.35e-05,
# Valid   Loss:5.1255e-03  Loss_r:7.7713e-04
# Epoch #  5100/150000    time:13.68
# loss:8.45e-03, loss_r:4.71e-03, loss_b:3.74e-05,
# Valid   Loss:4.3983e-03  Loss_r:6.6495e-04
# Epoch #  5200/150000    time:13.67
# loss:6.49e-03, loss_r:3.63e-03, loss_b:2.86e-05,
# Valid   Loss:3.3772e-03  Loss_r:5.3020e-04
# Epoch #  5300/150000    time:13.68
# loss:4.66e-02, loss_r:3.71e-02, loss_b:9.51e-05,
# Valid   Loss:1.1108e-02  Loss_r:5.0478e-03
# Epoch #  5400/150000    time:13.69
# loss:6.67e-04, loss_r:4.49e-04, loss_b:2.18e-06,
# Valid   Loss:3.1326e-04  Loss_r:9.2427e-05
# Epoch #  5500/150000    time:13.68
# loss:3.90e-03, loss_r:3.02e-03, loss_b:8.85e-06,
# Valid   Loss:2.2752e-03  Loss_r:1.1771e-03
# Epoch #  5600/150000    time:13.67
# loss:5.33e-04, loss_r:3.55e-04, loss_b:1.79e-06,
# Valid   Loss:2.5326e-04  Loss_r:6.9924e-05
# Epoch #  5700/150000    time:13.67
# loss:6.17e-04, loss_r:4.46e-04, loss_b:1.70e-06,
# Valid   Loss:5.6595e-04  Loss_r:2.0442e-04
# Epoch #  5800/150000    time:13.67
# loss:4.52e-04, loss_r:2.97e-04, loss_b:1.56e-06,
# Valid   Loss:2.1022e-04  Loss_r:5.9811e-05
# Epoch #  5900/150000    time:13.67
# loss:4.40e-04, loss_r:3.04e-04, loss_b:1.36e-06,
# Valid   Loss:2.0636e-04  Loss_r:5.7218e-05
# Epoch #  6000/150000    time:13.67
# loss:5.11e-04, loss_r:3.49e-04, loss_b:1.62e-06,
# Valid   Loss:2.2116e-04  Loss_r:8.4319e-05
# Epoch #  6100/150000    time:13.68
# loss:7.07e-04, loss_r:5.50e-04, loss_b:1.57e-06,
# Valid   Loss:3.0261e-04  Loss_r:1.0039e-04
# Epoch #  6200/150000    time:13.67
# loss:8.59e-03, loss_r:7.23e-03, loss_b:1.36e-05,
# Valid   Loss:2.5921e-03  Loss_r:1.1738e-03
# Epoch #  6300/150000    time:13.67
# loss:4.00e-04, loss_r:2.92e-04, loss_b:1.09e-06,
# Valid   Loss:2.1922e-04  Loss_r:6.3948e-05
# Epoch #  6400/150000    time:13.68
# loss:1.51e-03, loss_r:1.28e-03, loss_b:2.36e-06,
# Valid   Loss:4.8359e-04  Loss_r:2.1234e-04
# Epoch #  6500/150000    time:13.67
# loss:4.47e-04, loss_r:3.45e-04, loss_b:1.02e-06,
# Valid   Loss:1.7076e-04  Loss_r:5.3410e-05
# Epoch #  6600/150000    time:13.67
# loss:3.30e-04, loss_r:2.34e-04, loss_b:9.58e-07,
# Valid   Loss:1.3420e-04  Loss_r:4.2667e-05
# Epoch #  6700/150000    time:13.67
# loss:8.98e-04, loss_r:7.31e-04, loss_b:1.67e-06,
# Valid   Loss:4.2931e-04  Loss_r:1.4800e-04
# Epoch #  6800/150000    time:13.67
# loss:1.18e-03, loss_r:1.02e-03, loss_b:1.65e-06,
# Valid   Loss:4.9549e-04  Loss_r:2.3723e-04
# Epoch #  6900/150000    time:13.67
# loss:5.82e-03, loss_r:5.11e-03, loss_b:7.05e-06,
# Valid   Loss:1.0677e-03  Loss_r:5.2740e-04
# Epoch #  7000/150000    time:13.67
# loss:2.65e-03, loss_r:2.11e-03, loss_b:5.39e-06,
# Valid   Loss:7.5614e-04  Loss_r:3.7971e-04
# Epoch #  7100/150000    time:13.68
# loss:1.85e-04, loss_r:1.34e-04, loss_b:5.10e-07,
# Valid   Loss:7.8600e-05  Loss_r:3.3087e-05
# Epoch #  7200/150000    time:13.68
# loss:2.79e-04, loss_r:2.12e-04, loss_b:6.76e-07,
# Valid   Loss:9.7151e-05  Loss_r:4.3418e-05
# Epoch #  7300/150000    time:13.68
# loss:4.37e-04, loss_r:3.77e-04, loss_b:6.04e-07,
# Valid   Loss:1.3878e-04  Loss_r:7.2533e-05
# Epoch #  7400/150000    time:13.67
# loss:4.00e-03, loss_r:3.56e-03, loss_b:4.42e-06,
# Valid   Loss:4.2674e-04  Loss_r:2.6946e-04
# Epoch #  7500/150000    time:13.67
# loss:2.68e-04, loss_r:2.21e-04, loss_b:4.63e-07,
# Valid   Loss:8.1677e-05  Loss_r:3.9646e-05
# Epoch #  7600/150000    time:13.67
# loss:5.05e-03, loss_r:4.51e-03, loss_b:5.43e-06,
# Valid   Loss:1.4940e-03  Loss_r:9.6653e-04
# Epoch #  7700/150000    time:13.68
# loss:1.32e-02, loss_r:1.14e-02, loss_b:1.84e-05,
# Valid   Loss:7.5969e-03  Loss_r:4.0355e-03
# Epoch #  7800/150000    time:13.67
# loss:2.99e-04, loss_r:2.24e-04, loss_b:7.45e-07,
# Valid   Loss:1.2702e-04  Loss_r:5.2840e-05
# Epoch #  7900/150000    time:13.67
# loss:2.11e-04, loss_r:1.46e-04, loss_b:6.49e-07,
# Valid   Loss:9.7751e-05  Loss_r:3.2925e-05
# Epoch #  8000/150000    time:13.67
# loss:1.88e-04, loss_r:1.26e-04, loss_b:6.25e-07,
# Valid   Loss:9.0671e-05  Loss_r:2.8190e-05
# Epoch #  8100/150000    time:13.68
# loss:1.82e-04, loss_r:1.14e-04, loss_b:6.76e-07,
# Valid   Loss:9.3255e-05  Loss_r:2.5654e-05
# Epoch #  8200/150000    time:13.67
# loss:1.70e-04, loss_r:1.05e-04, loss_b:6.56e-07,
# Valid   Loss:8.9355e-05  Loss_r:2.3790e-05
# Epoch #  8300/150000    time:13.67
# loss:1.61e-04, loss_r:9.73e-05, loss_b:6.37e-07,
# Valid   Loss:8.5978e-05  Loss_r:2.2332e-05
# Epoch #  8400/150000    time:13.67
# loss:1.53e-04, loss_r:9.11e-05, loss_b:6.17e-07,
# Valid   Loss:8.2830e-05  Loss_r:2.1122e-05
# Epoch #  8500/150000    time:13.67
# loss:1.45e-04, loss_r:8.56e-05, loss_b:5.97e-07,
# Valid   Loss:7.9782e-05  Loss_r:2.0069e-05
# Epoch #  8600/150000    time:13.67
# loss:1.38e-04, loss_r:8.06e-05, loss_b:5.77e-07,
# Valid   Loss:7.6809e-05  Loss_r:1.9113e-05
# Epoch #  8700/150000    time:13.67
# loss:1.32e-04, loss_r:7.61e-05, loss_b:5.56e-07,
# Valid   Loss:7.3847e-05  Loss_r:1.8233e-05
# Epoch #  8800/150000    time:13.67
# loss:1.25e-04, loss_r:7.18e-05, loss_b:5.36e-07,
# Valid   Loss:7.0931e-05  Loss_r:1.7407e-05
# Epoch #  8900/150000    time:13.67
# loss:1.19e-04, loss_r:6.78e-05, loss_b:5.16e-07,
# Valid   Loss:6.8064e-05  Loss_r:1.6639e-05
# Epoch #  9000/150000    time:13.68
# loss:3.69e-03, loss_r:3.17e-03, loss_b:5.18e-06,
# Valid   Loss:8.1988e-04  Loss_r:3.0430e-04
# Epoch #  9100/150000    time:13.68
# loss:1.04e-04, loss_r:6.52e-05, loss_b:3.89e-07,
# Valid   Loss:5.4895e-05  Loss_r:1.5955e-05
# Epoch #  9200/150000    time:13.67
# loss:9.73e-05, loss_r:6.02e-05, loss_b:3.71e-07,
# Valid   Loss:5.2013e-05  Loss_r:1.4975e-05
# Epoch #  9300/150000    time:13.67
# loss:9.16e-05, loss_r:5.62e-05, loss_b:3.54e-07,
# Valid   Loss:4.9272e-05  Loss_r:1.4233e-05
# Epoch #  9400/150000    time:13.68
# loss:1.20e-04, loss_r:8.85e-05, loss_b:3.15e-07,
# Valid   Loss:5.1409e-05  Loss_r:1.5276e-05
# Epoch #  9500/150000    time:13.67
# loss:2.78e-02, loss_r:2.43e-02, loss_b:3.50e-05,
# Valid   Loss:4.0592e-03  Loss_r:1.6149e-03
# Epoch #  9600/150000    time:13.68
# loss:4.38e-04, loss_r:3.81e-04, loss_b:5.73e-07,
# Valid   Loss:1.1992e-04  Loss_r:6.3530e-05
# Epoch #  9700/150000    time:13.68
# loss:3.51e-03, loss_r:3.20e-03, loss_b:3.08e-06,
# Valid   Loss:6.1109e-04  Loss_r:3.0111e-04
# Epoch #  9800/150000    time:13.67
# loss:4.95e-03, loss_r:4.38e-03, loss_b:5.76e-06,
# Valid   Loss:1.1263e-03  Loss_r:4.3323e-04
# Epoch #  9900/150000    time:13.68
# loss:8.91e-05, loss_r:6.26e-05, loss_b:2.65e-07,
# Valid   Loss:3.8142e-05  Loss_r:1.3366e-05
# Adjusting learning rate of group 0 to 8.1000e-04.
# Adjusting learning rate of group 0 to 8.1000e-04.
# Epoch #  10000/150000    time:13.67
# loss:5.88e-05, loss_r:4.00e-05, loss_b:1.88e-07,
# Valid   Loss:2.8691e-05  Loss_r:9.9649e-06
# Epoch #  10100/150000    time:13.68
# loss:5.95e-05, loss_r:3.90e-05, loss_b:2.06e-07,
# Valid   Loss:3.0053e-05  Loss_r:9.5032e-06
# Epoch #  10200/150000    time:13.67
# loss:5.72e-05, loss_r:3.70e-05, loss_b:2.02e-07,
# Valid   Loss:2.9358e-05  Loss_r:9.1385e-06
# Epoch #  10300/150000    time:13.67
# loss:6.24e-05, loss_r:4.41e-05, loss_b:1.83e-07,
# Valid   Loss:3.1019e-05  Loss_r:1.0234e-05
# Epoch #  10400/150000    time:13.67
# loss:4.43e-03, loss_r:4.10e-03, loss_b:3.25e-06,
# Valid   Loss:8.0437e-04  Loss_r:5.0206e-04
# Epoch #  10500/150000    time:13.67
# loss:5.23e-05, loss_r:3.41e-05, loss_b:1.82e-07,
# Valid   Loss:2.7285e-05  Loss_r:9.1221e-06
# Epoch #  10600/150000    time:13.68
# loss:4.98e-05, loss_r:3.22e-05, loss_b:1.76e-07,
# Valid   Loss:2.6418e-05  Loss_r:8.7988e-06
# Epoch #  10700/150000    time:13.68
# loss:8.54e-05, loss_r:6.47e-05, loss_b:2.07e-07,
# Valid   Loss:3.7460e-05  Loss_r:1.2285e-05
# Epoch #  10800/150000    time:13.68
# loss:5.32e-05, loss_r:3.57e-05, loss_b:1.76e-07,
# Valid   Loss:2.4544e-05  Loss_r:9.1092e-06
# Epoch #  10900/150000    time:13.68
# loss:9.09e-03, loss_r:7.27e-03, loss_b:1.82e-05,
# Valid   Loss:1.5874e-03  Loss_r:4.8322e-04
# Epoch #  11000/150000    time:13.68
# loss:4.47e-05, loss_r:2.96e-05, loss_b:1.51e-07,
# Valid   Loss:2.2757e-05  Loss_r:8.1652e-06
# Epoch #  11100/150000    time:13.69
# loss:4.14e-05, loss_r:2.72e-05, loss_b:1.42e-07,
# Valid   Loss:2.2411e-05  Loss_r:8.1979e-06
# Epoch #  11200/150000    time:13.69
# loss:1.12e-04, loss_r:9.13e-05, loss_b:2.03e-07,
# Valid   Loss:2.9984e-05  Loss_r:1.0823e-05
# Epoch #  11300/150000    time:13.69
# loss:4.68e-05, loss_r:3.44e-05, loss_b:1.24e-07,
# Valid   Loss:2.0944e-05  Loss_r:7.9799e-06
# Epoch #  11400/150000    time:13.68
# loss:5.46e-05, loss_r:4.22e-05, loss_b:1.23e-07,
# Valid   Loss:2.0672e-05  Loss_r:7.8396e-06
# Epoch #  11500/150000    time:13.67
# loss:4.82e-05, loss_r:3.33e-05, loss_b:1.50e-07,
# Valid   Loss:2.1037e-05  Loss_r:7.6640e-06
# Epoch #  11600/150000    time:13.68
# loss:8.62e-03, loss_r:8.02e-03, loss_b:6.08e-06,
# Valid   Loss:1.3132e-03  Loss_r:5.7357e-04
# Epoch #  11700/150000    time:13.67
# loss:9.68e-02, loss_r:6.14e-02, loss_b:3.55e-04,
# Valid   Loss:4.3605e-02  Loss_r:1.5231e-02
# Epoch #  11800/150000    time:13.67
# loss:2.77e-02, loss_r:1.93e-02, loss_b:8.42e-05,
# Valid   Loss:1.2583e-02  Loss_r:4.2298e-03
# Epoch #  11900/150000    time:13.67
# loss:1.36e-02, loss_r:9.37e-03, loss_b:4.24e-05,
# Valid   Loss:6.1857e-03  Loss_r:1.9773e-03
# Epoch #  12000/150000    time:13.67
# loss:6.49e-03, loss_r:4.52e-03, loss_b:1.96e-05,
# Valid   Loss:2.9067e-03  Loss_r:9.5543e-04
# Epoch #  12100/150000    time:13.68
# loss:3.96e-03, loss_r:2.77e-03, loss_b:1.19e-05,
# Valid   Loss:1.7717e-03  Loss_r:5.8959e-04
# Epoch #  12200/150000    time:13.68
# loss:3.02e-03, loss_r:2.10e-03, loss_b:9.16e-06,
# Valid   Loss:1.3557e-03  Loss_r:4.4208e-04
# Epoch #  12300/150000    time:13.68
# loss:2.35e-03, loss_r:1.64e-03, loss_b:7.14e-06,
# Valid   Loss:1.0502e-03  Loss_r:3.3837e-04
# Epoch #  12400/150000    time:13.68
# loss:1.75e-03, loss_r:1.23e-03, loss_b:5.26e-06,
# Valid   Loss:7.7243e-04  Loss_r:2.4849e-04
# Epoch #  12500/150000    time:13.68
# loss:1.18e-03, loss_r:8.36e-04, loss_b:3.46e-06,
# Valid   Loss:5.1031e-04  Loss_r:1.6583e-04
# Epoch #  12600/150000    time:13.67
# loss:5.40e-04, loss_r:3.93e-04, loss_b:1.47e-06,
# Valid   Loss:2.2266e-04  Loss_r:7.7683e-05
# Epoch #  12700/150000    time:13.68
# loss:1.58e-04, loss_r:1.25e-04, loss_b:3.27e-07,
# Valid   Loss:5.8753e-05  Loss_r:2.6524e-05
# Epoch #  12800/150000    time:13.68
# loss:8.11e-05, loss_r:6.66e-05, loss_b:1.45e-07,
# Valid   Loss:3.0076e-05  Loss_r:1.5638e-05
# Epoch #  12900/150000    time:13.68
# loss:6.05e-05, loss_r:4.98e-05, loss_b:1.07e-07,
# Valid   Loss:2.3083e-05  Loss_r:1.2390e-05
# Epoch #  13000/150000    time:13.68
# loss:5.06e-05, loss_r:4.15e-05, loss_b:9.09e-08,
# Valid   Loss:1.9777e-05  Loss_r:1.0698e-05
# Epoch #  13100/150000    time:13.69
# loss:4.51e-05, loss_r:3.71e-05, loss_b:7.97e-08,
# Valid   Loss:1.7699e-05  Loss_r:9.7349e-06
# Epoch #  13200/150000    time:13.68
# loss:4.02e-05, loss_r:3.29e-05, loss_b:7.36e-08,
# Valid   Loss:1.6169e-05  Loss_r:8.8133e-06
# Epoch #  13300/150000    time:13.68
# loss:3.67e-05, loss_r:2.98e-05, loss_b:6.91e-08,
# Valid   Loss:1.5015e-05  Loss_r:8.1080e-06
# Epoch #  13400/150000    time:13.68
# loss:3.39e-05, loss_r:2.74e-05, loss_b:6.55e-08,
# Valid   Loss:1.4124e-05  Loss_r:7.5374e-06
# Epoch #  13500/150000    time:13.68
# loss:3.17e-05, loss_r:2.54e-05, loss_b:6.32e-08,
# Valid   Loss:1.3338e-05  Loss_r:7.0929e-06
# Epoch #  13600/150000    time:13.67
# loss:5.39e-05, loss_r:4.48e-05, loss_b:9.11e-08,
# Valid   Loss:1.5567e-05  Loss_r:7.6466e-06
# Epoch #  13700/150000    time:13.68
# loss:1.22e-03, loss_r:1.02e-03, loss_b:1.94e-06,
# Valid   Loss:3.2377e-04  Loss_r:1.3190e-04
# Epoch #  13800/150000    time:13.68
# loss:1.10e-03, loss_r:9.75e-04, loss_b:1.30e-06,
# Valid   Loss:3.6771e-04  Loss_r:1.6196e-04
# Epoch #  13900/150000    time:13.69
# loss:3.98e-05, loss_r:3.27e-05, loss_b:7.05e-08,
# Valid   Loss:1.5975e-05  Loss_r:7.4042e-06
# Epoch #  14000/150000    time:13.69
# loss:2.47e-05, loss_r:1.95e-05, loss_b:5.21e-08,
# Valid   Loss:1.0937e-05  Loss_r:5.7124e-06
# Epoch #  14100/150000    time:13.69
# loss:6.35e-05, loss_r:5.22e-05, loss_b:1.12e-07,
# Valid   Loss:1.7448e-05  Loss_r:9.3822e-06
# Epoch #  14200/150000    time:13.68
# loss:1.91e-02, loss_r:1.67e-02, loss_b:2.37e-05,
# Valid   Loss:4.1807e-03  Loss_r:1.7894e-03
# Epoch #  14300/150000    time:13.67
# loss:2.36e-05, loss_r:1.89e-05, loss_b:4.70e-08,
# Valid   Loss:1.0634e-05  Loss_r:5.6400e-06
# Epoch #  14400/150000    time:13.67
# loss:1.93e-04, loss_r:1.76e-04, loss_b:1.70e-07,
# Valid   Loss:4.2960e-05  Loss_r:2.4390e-05
# Epoch #  14500/150000    time:13.67
# loss:3.58e-03, loss_r:3.31e-03, loss_b:2.69e-06,
# Valid   Loss:9.4684e-04  Loss_r:4.9449e-04
# Epoch #  14600/150000    time:13.68
# loss:2.48e-03, loss_r:2.29e-03, loss_b:1.88e-06,
# Valid   Loss:5.3536e-04  Loss_r:2.6931e-04
# Epoch #  14700/150000    time:13.68
# loss:9.54e-04, loss_r:8.82e-04, loss_b:7.24e-07,
# Valid   Loss:6.5781e-05  Loss_r:3.9408e-05
# Epoch #  14800/150000    time:13.67
# loss:2.12e-05, loss_r:1.78e-05, loss_b:3.46e-08,
# Valid   Loss:1.0767e-05  Loss_r:7.3150e-06
# Epoch #  14900/150000    time:13.67
# loss:1.82e-05, loss_r:1.49e-05, loss_b:3.22e-08,
# Valid   Loss:9.7421e-06  Loss_r:6.5261e-06
# Adjusting learning rate of group 0 to 7.2900e-04.
# Adjusting learning rate of group 0 to 7.2900e-04.
# Epoch #  15000/150000    time:13.67
# loss:1.81e-03, loss_r:1.73e-03, loss_b:8.67e-07,
# Valid   Loss:4.5315e-04  Loss_r:2.7049e-04
# Epoch #  15100/150000    time:13.69
# loss:2.18e-05, loss_r:1.46e-05, loss_b:7.21e-08,
# Valid   Loss:1.3899e-05  Loss_r:6.6781e-06
# Epoch #  15200/150000    time:13.67
# loss:2.02e-05, loss_r:1.32e-05, loss_b:6.95e-08,
# Valid   Loss:1.3234e-05  Loss_r:6.2875e-06
# Epoch #  15300/150000    time:13.67
# loss:1.92e-05, loss_r:1.24e-05, loss_b:6.76e-08,
# Valid   Loss:1.2801e-05  Loss_r:6.0441e-06
# Epoch #  15400/150000    time:13.67
# loss:4.54e-05, loss_r:3.75e-05, loss_b:7.94e-08,
# Valid   Loss:2.2503e-05  Loss_r:1.0870e-05
# Epoch #  15500/150000    time:13.67
# loss:8.75e-03, loss_r:8.24e-03, loss_b:5.01e-06,
# Valid   Loss:1.7485e-03  Loss_r:1.0005e-03
# Epoch #  15600/150000    time:13.68
# loss:1.93e-05, loss_r:1.28e-05, loss_b:6.49e-08,
# Valid   Loss:1.2480e-05  Loss_r:5.9053e-06
# Epoch #  15700/150000    time:13.68
# loss:2.44e-04, loss_r:2.20e-04, loss_b:2.43e-07,
# Valid   Loss:4.9905e-05  Loss_r:2.2267e-05
# Epoch #  15800/150000    time:13.68
# loss:1.33e-03, loss_r:1.23e-03, loss_b:1.00e-06,
# Valid   Loss:1.8897e-04  Loss_r:7.8830e-05
# Epoch #  15900/150000    time:13.68
# loss:6.10e-04, loss_r:5.49e-04, loss_b:6.11e-07,
# Valid   Loss:7.4411e-05  Loss_r:3.3497e-05
# Epoch #  16000/150000    time:13.68
# loss:5.64e-04, loss_r:5.21e-04, loss_b:4.33e-07,
# Valid   Loss:7.7618e-05  Loss_r:4.9650e-05
# Epoch #  16100/150000    time:13.69
# loss:3.46e-03, loss_r:3.32e-03, loss_b:1.40e-06,
# Valid   Loss:4.4454e-04  Loss_r:2.7197e-04
# Epoch #  16200/150000    time:13.68
# loss:1.30e-04, loss_r:1.13e-04, loss_b:1.70e-07,
# Valid   Loss:3.1718e-05  Loss_r:1.3609e-05
# Epoch #  16300/150000    time:13.67
# loss:8.15e-03, loss_r:7.59e-03, loss_b:5.62e-06,
# Valid   Loss:1.1143e-03  Loss_r:5.4083e-04
# Epoch #  16400/150000    time:13.68
# loss:3.61e-04, loss_r:3.29e-04, loss_b:3.18e-07,
# Valid   Loss:6.2296e-05  Loss_r:2.7222e-05
# Epoch #  16500/150000    time:13.68
# loss:2.93e-04, loss_r:2.55e-04, loss_b:3.80e-07,
# Valid   Loss:6.8128e-05  Loss_r:2.7000e-05
# Epoch #  16600/150000    time:13.67
# loss:5.86e-03, loss_r:5.33e-03, loss_b:5.32e-06,
# Valid   Loss:1.1357e-03  Loss_r:4.4025e-04
# Epoch #  16700/150000    time:13.68
# loss:1.10e-02, loss_r:1.03e-02, loss_b:7.37e-06,
# Valid   Loss:1.2572e-03  Loss_r:6.1961e-04
# Epoch #  16800/150000    time:13.67
# loss:2.32e-03, loss_r:2.14e-03, loss_b:1.79e-06,
# Valid   Loss:3.0625e-04  Loss_r:1.3371e-04
# Epoch #  16900/150000    time:13.68
# loss:9.98e-04, loss_r:9.07e-04, loss_b:9.10e-07,
# Valid   Loss:1.4464e-04  Loss_r:6.2914e-05
# Epoch #  17000/150000    time:13.67
# loss:6.43e-05, loss_r:5.31e-05, loss_b:1.12e-07,
# Valid   Loss:2.2831e-05  Loss_r:9.4708e-06
# Epoch #  17100/150000    time:13.64
# loss:1.15e-05, loss_r:9.43e-06, loss_b:2.06e-08,
# Valid   Loss:7.3692e-06  Loss_r:5.2651e-06
# Epoch #  17200/150000    time:13.63
# loss:1.09e-05, loss_r:8.92e-06, loss_b:1.95e-08,
# Valid   Loss:7.0115e-06  Loss_r:4.9195e-06
# Epoch #  17300/150000    time:13.63
# loss:1.62e-05, loss_r:1.35e-05, loss_b:2.73e-08,
# Valid   Loss:7.2055e-06  Loss_r:5.2111e-06
# Epoch #  17400/150000    time:13.67
# loss:1.51e-05, loss_r:1.28e-05, loss_b:2.32e-08,
# Valid   Loss:7.9464e-06  Loss_r:5.2573e-06
# Epoch #  17500/150000    time:13.68
# loss:1.48e-05, loss_r:1.24e-05, loss_b:2.34e-08,
# Valid   Loss:7.2427e-06  Loss_r:5.2494e-06
# Epoch #  17600/150000    time:13.67
# loss:2.82e-04, loss_r:2.61e-04, loss_b:2.07e-07,
# Valid   Loss:6.5897e-05  Loss_r:3.4260e-05
# Epoch #  17700/150000    time:13.67
# loss:2.72e-05, loss_r:2.34e-05, loss_b:3.80e-08,
# Valid   Loss:1.0165e-05  Loss_r:6.3684e-06
# Epoch #  17800/150000    time:13.68
# loss:1.47e-05, loss_r:1.24e-05, loss_b:2.36e-08,
# Valid   Loss:7.0542e-06  Loss_r:5.0027e-06
# Epoch #  17900/150000    time:13.68
# loss:2.98e-04, loss_r:2.78e-04, loss_b:1.95e-07,
# Valid   Loss:5.7136e-05  Loss_r:2.4723e-05
# Epoch #  18000/150000    time:13.68
# loss:7.31e-05, loss_r:6.41e-05, loss_b:9.06e-08,
# Valid   Loss:1.2960e-05  Loss_r:7.1370e-06
# Epoch #  18100/150000    time:13.69
# loss:6.23e-03, loss_r:5.91e-03, loss_b:3.17e-06,
# Valid   Loss:9.0111e-04  Loss_r:5.1924e-04
# Epoch #  18200/150000    time:13.68
# loss:2.35e-05, loss_r:1.76e-05, loss_b:5.98e-08,
# Valid   Loss:1.1578e-05  Loss_r:5.7373e-06
# Epoch #  18300/150000    time:13.68
# loss:1.84e-05, loss_r:1.27e-05, loss_b:5.70e-08,
# Valid   Loss:1.0223e-05  Loss_r:4.8388e-06
# Epoch #  18400/150000    time:13.68
# loss:1.23e-03, loss_r:1.14e-03, loss_b:8.72e-07,
# Valid   Loss:1.5041e-04  Loss_r:7.3906e-05
# Epoch #  18500/150000    time:13.68
# loss:3.56e-03, loss_r:3.29e-03, loss_b:2.71e-06,
# Valid   Loss:6.8438e-04  Loss_r:3.2802e-04
# Epoch #  18600/150000    time:13.68
# loss:2.37e-03, loss_r:2.12e-03, loss_b:2.46e-06,
# Valid   Loss:3.7733e-04  Loss_r:1.3137e-04
# Epoch #  18700/150000    time:13.68
# loss:1.10e-04, loss_r:9.69e-05, loss_b:1.27e-07,
# Valid   Loss:2.6075e-05  Loss_r:9.7782e-06
# Epoch #  18800/150000    time:13.68
# loss:1.84e-04, loss_r:1.56e-04, loss_b:2.81e-07,
# Valid   Loss:4.9450e-05  Loss_r:1.5785e-05
# Epoch #  18900/150000    time:13.68
# loss:7.10e-04, loss_r:6.51e-04, loss_b:5.90e-07,
# Valid   Loss:1.1767e-04  Loss_r:4.8705e-05
# Epoch #  19000/150000    time:13.69
# loss:5.35e-04, loss_r:4.43e-04, loss_b:9.14e-07,
# Valid   Loss:9.2305e-05  Loss_r:3.2750e-05
# Epoch #  19100/150000    time:13.69
# loss:1.40e-03, loss_r:1.27e-03, loss_b:1.30e-06,
# Valid   Loss:2.7757e-04  Loss_r:1.0480e-04
# Epoch #  19200/150000    time:13.67
# loss:8.24e-04, loss_r:6.76e-04, loss_b:1.48e-06,
# Valid   Loss:2.4883e-04  Loss_r:6.4280e-05
# Epoch #  19300/150000    time:13.68
# loss:7.85e-06, loss_r:6.69e-06, loss_b:1.16e-08,
# Valid   Loss:5.0807e-06  Loss_r:3.9460e-06
# Epoch #  19400/150000    time:13.68
# loss:1.50e-03, loss_r:1.42e-03, loss_b:8.46e-07,
# Valid   Loss:2.1407e-04  Loss_r:1.0946e-04
# Epoch #  19500/150000    time:13.69
# loss:6.62e-05, loss_r:6.08e-05, loss_b:5.37e-08,
# Valid   Loss:1.6064e-05  Loss_r:8.1701e-06
# Epoch #  19600/150000    time:13.68
# loss:2.25e-04, loss_r:1.97e-04, loss_b:2.85e-07,
# Valid   Loss:2.2167e-05  Loss_r:1.0417e-05
# Epoch #  19700/150000    time:13.68
# loss:1.16e-04, loss_r:1.06e-04, loss_b:9.90e-08,
# Valid   Loss:2.0001e-05  Loss_r:1.0679e-05
# Epoch #  19800/150000    time:13.68
# loss:3.04e-05, loss_r:2.69e-05, loss_b:3.51e-08,
# Valid   Loss:9.1001e-06  Loss_r:5.1226e-06
# Epoch #  19900/150000    time:13.68
# loss:9.92e-04, loss_r:5.83e-04, loss_b:4.09e-06,
# Valid   Loss:2.7708e-04  Loss_r:6.9979e-05
# Adjusting learning rate of group 0 to 6.5610e-04.
# Adjusting learning rate of group 0 to 6.5610e-04.
# Epoch #  20000/150000    time:13.69
# loss:3.84e-05, loss_r:3.61e-05, loss_b:2.23e-08,
# Valid   Loss:1.0167e-05  Loss_r:6.8610e-06
# Epoch #  20100/150000    time:13.69
# loss:1.01e-05, loss_r:5.82e-06, loss_b:4.30e-08,
# Valid   Loss:7.8332e-06  Loss_r:3.5392e-06
# Epoch #  20200/150000    time:13.68
# loss:3.69e-03, loss_r:3.48e-03, loss_b:2.11e-06,
# Valid   Loss:3.5601e-04  Loss_r:1.9050e-04
# Epoch #  20300/150000    time:13.68
# loss:6.99e-04, loss_r:6.29e-04, loss_b:6.95e-07,
# Valid   Loss:1.8396e-04  Loss_r:8.3347e-05
# Epoch #  20400/150000    time:13.69
# loss:1.11e-05, loss_r:6.68e-06, loss_b:4.39e-08,
# Valid   Loss:7.8521e-06  Loss_r:3.5138e-06
# Epoch #  20500/150000    time:13.68
# loss:3.47e-05, loss_r:2.80e-05, loss_b:6.67e-08,
# Valid   Loss:1.1822e-05  Loss_r:5.5468e-06
# Epoch #  20600/150000    time:13.68
# loss:1.54e-05, loss_r:1.12e-05, loss_b:4.22e-08,
# Valid   Loss:8.0196e-06  Loss_r:3.5575e-06
# Epoch #  20700/150000    time:13.68
# loss:5.76e-05, loss_r:5.14e-05, loss_b:6.16e-08,
# Valid   Loss:1.6790e-05  Loss_r:9.1952e-06
# Epoch #  20800/150000    time:13.68
# loss:8.92e-05, loss_r:8.12e-05, loss_b:7.97e-08,
# Valid   Loss:1.7583e-05  Loss_r:8.0669e-06
# Epoch #  20900/150000    time:13.68
# loss:1.38e-03, loss_r:1.27e-03, loss_b:1.12e-06,
# Valid   Loss:2.6920e-04  Loss_r:1.2282e-04
# Epoch #  21000/150000    time:13.68
# loss:4.15e-04, loss_r:3.66e-04, loss_b:4.87e-07,
# Valid   Loss:9.0015e-05  Loss_r:3.6289e-05
# Epoch #  21100/150000    time:13.68
# loss:7.61e-05, loss_r:6.73e-05, loss_b:8.81e-08,
# Valid   Loss:1.9652e-05  Loss_r:9.9789e-06
# Epoch #  21200/150000    time:13.68
# loss:5.51e-05, loss_r:4.88e-05, loss_b:6.27e-08,
# Valid   Loss:1.5148e-05  Loss_r:6.7297e-06
# Epoch #  21300/150000    time:13.70
# loss:7.92e-05, loss_r:6.79e-05, loss_b:1.13e-07,
# Valid   Loss:1.0125e-05  Loss_r:5.2425e-06
# Epoch #  21400/150000    time:13.69
# loss:1.53e-03, loss_r:1.38e-03, loss_b:1.52e-06,
# Valid   Loss:3.0563e-04  Loss_r:1.2248e-04
# Epoch #  21500/150000    time:13.68
# loss:3.87e-04, loss_r:3.27e-04, loss_b:6.02e-07,
# Valid   Loss:8.1657e-05  Loss_r:2.6647e-05
# Epoch #  21600/150000    time:13.68
# loss:1.65e-04, loss_r:1.48e-04, loss_b:1.71e-07,
# Valid   Loss:4.7949e-05  Loss_r:2.1593e-05
# Epoch #  21700/150000    time:13.69
# loss:3.68e-04, loss_r:3.32e-04, loss_b:3.62e-07,
# Valid   Loss:8.1370e-05  Loss_r:3.2111e-05
# Epoch #  21800/150000    time:13.69
# loss:3.39e-04, loss_r:2.78e-04, loss_b:6.05e-07,
# Valid   Loss:8.8632e-05  Loss_r:2.2779e-05
# Epoch #  21900/150000    time:13.69
# loss:2.44e-03, loss_r:2.04e-03, loss_b:3.95e-06,
# Valid   Loss:4.0974e-04  Loss_r:8.5573e-05
# Epoch #  22000/150000    time:13.69
# loss:1.42e-03, loss_r:1.27e-03, loss_b:1.50e-06,
# Valid   Loss:2.4903e-04  Loss_r:9.1495e-05
# Epoch #  22100/150000    time:13.69
# loss:2.90e-04, loss_r:2.54e-04, loss_b:3.59e-07,
# Valid   Loss:5.8408e-05  Loss_r:2.6581e-05
# Epoch #  22200/150000    time:13.69
# loss:7.42e-05, loss_r:6.48e-05, loss_b:9.34e-08,
# Valid   Loss:1.9534e-05  Loss_r:7.8206e-06
# Epoch #  22300/150000    time:13.69
# loss:1.63e-04, loss_r:1.49e-04, loss_b:1.42e-07,
# Valid   Loss:2.7096e-05  Loss_r:1.2838e-05
# Epoch #  22400/150000    time:13.68
# loss:1.93e-03, loss_r:1.73e-03, loss_b:2.02e-06,
# Valid   Loss:2.2709e-04  Loss_r:7.9947e-05
# Epoch #  22500/150000    time:13.68
# loss:2.19e-03, loss_r:2.02e-03, loss_b:1.65e-06,
# Valid   Loss:3.0997e-04  Loss_r:1.5124e-04
# Epoch #  22600/150000    time:13.68
# loss:8.18e-04, loss_r:7.54e-04, loss_b:6.39e-07,
# Valid   Loss:1.5061e-04  Loss_r:6.4580e-05
# Epoch #  22700/150000    time:13.68
# loss:5.75e-05, loss_r:5.08e-05, loss_b:6.68e-08,
# Valid   Loss:1.2204e-05  Loss_r:6.0739e-06
# Epoch #  22800/150000    time:13.68
# loss:4.68e-04, loss_r:4.25e-04, loss_b:4.29e-07,
# Valid   Loss:8.2286e-05  Loss_r:3.7306e-05
# Epoch #  22900/150000    time:13.68
# loss:1.57e-03, loss_r:1.44e-03, loss_b:1.31e-06,
# Valid   Loss:1.9991e-04  Loss_r:9.1595e-05
# Epoch #  23000/150000    time:13.68
# loss:3.75e-04, loss_r:3.24e-04, loss_b:5.07e-07,
# Valid   Loss:6.8818e-05  Loss_r:2.6732e-05
# Epoch #  23100/150000    time:13.69
# loss:7.36e-06, loss_r:5.28e-06, loss_b:2.09e-08,
# Valid   Loss:5.1368e-06  Loss_r:2.9550e-06
# Epoch #  23200/150000    time:13.68
# loss:1.45e-02, loss_r:1.29e-02, loss_b:1.54e-05,
# Valid   Loss:1.4330e-03  Loss_r:4.2516e-04
# Epoch #  23300/150000    time:13.68
# loss:7.45e-06, loss_r:5.37e-06, loss_b:2.08e-08,
# Valid   Loss:5.1519e-06  Loss_r:3.0783e-06
# Epoch #  23400/150000    time:13.68
# loss:6.70e-06, loss_r:4.71e-06, loss_b:1.99e-08,
# Valid   Loss:4.8172e-06  Loss_r:2.8301e-06
# Epoch #  23500/150000    time:13.68
# loss:1.02e-03, loss_r:8.95e-04, loss_b:1.30e-06,
# Valid   Loss:1.2418e-04  Loss_r:7.5422e-05
# Epoch #  23600/150000    time:13.68
# loss:6.43e-06, loss_r:4.53e-06, loss_b:1.90e-08,
# Valid   Loss:4.6897e-06  Loss_r:2.7901e-06
# Epoch #  23700/150000    time:13.68
# loss:2.37e-04, loss_r:1.98e-04, loss_b:3.88e-07,
# Valid   Loss:1.0394e-04  Loss_r:3.0793e-05
# Epoch #  23800/150000    time:13.68
# loss:8.49e-05, loss_r:7.81e-05, loss_b:6.80e-08,
# Valid   Loss:1.8041e-05  Loss_r:9.6700e-06
# Epoch #  23900/150000    time:13.68
# loss:9.91e-06, loss_r:7.62e-06, loss_b:2.28e-08,
# Valid   Loss:5.2299e-06  Loss_r:2.9150e-06
# Epoch #  24000/150000    time:13.68
# loss:1.61e-05, loss_r:1.33e-05, loss_b:2.77e-08,
# Valid   Loss:5.4411e-06  Loss_r:3.0963e-06
# Epoch #  24100/150000    time:13.68
# loss:1.18e-05, loss_r:7.53e-06, loss_b:4.22e-08,
# Valid   Loss:7.4968e-06  Loss_r:3.1580e-06
# Epoch #  24200/150000    time:13.67
# loss:1.25e-03, loss_r:1.12e-03, loss_b:1.25e-06,
# Valid   Loss:1.0885e-04  Loss_r:3.8611e-05
# Epoch #  24300/150000    time:13.68
# loss:4.96e-05, loss_r:4.36e-05, loss_b:6.07e-08,
# Valid   Loss:1.4273e-05  Loss_r:6.3287e-06
# Epoch #  24400/150000    time:13.68
# loss:2.59e-05, loss_r:2.16e-05, loss_b:4.26e-08,
# Valid   Loss:8.8221e-06  Loss_r:3.8455e-06
# Epoch #  24500/150000    time:13.68
# loss:1.03e-05, loss_r:6.95e-06, loss_b:3.40e-08,
# Valid   Loss:6.1838e-06  Loss_r:2.6765e-06
# Epoch #  24600/150000    time:13.68
# loss:2.33e-05, loss_r:1.74e-05, loss_b:5.82e-08,
# Valid   Loss:7.7620e-06  Loss_r:3.5102e-06
# Epoch #  24700/150000    time:13.68
# loss:8.35e-06, loss_r:5.04e-06, loss_b:3.31e-08,
# Valid   Loss:5.6629e-06  Loss_r:2.6057e-06
# Epoch #  24800/150000    time:13.68
# loss:5.14e-05, loss_r:4.36e-05, loss_b:7.82e-08,
# Valid   Loss:1.8694e-05  Loss_r:6.6278e-06
# Epoch #  24900/150000    time:13.68
# loss:8.24e-04, loss_r:7.48e-04, loss_b:7.55e-07,
# Valid   Loss:1.3318e-04  Loss_r:5.3153e-05
# Adjusting learning rate of group 0 to 5.9049e-04.
# Adjusting learning rate of group 0 to 5.9049e-04.
# Epoch #  25000/150000    time:13.67
# loss:2.11e-04, loss_r:1.90e-04, loss_b:2.11e-07,
# Valid   Loss:3.9813e-05  Loss_r:1.4970e-05
# Epoch #  25100/150000    time:13.69
# loss:4.30e-06, loss_r:3.82e-06, loss_b:4.75e-09,
# Valid   Loss:2.8876e-06  Loss_r:2.4138e-06
# Epoch #  25200/150000    time:13.68
# loss:4.31e-06, loss_r:3.83e-06, loss_b:4.81e-09,
# Valid   Loss:2.7608e-06  Loss_r:2.2799e-06
# Epoch #  25300/150000    time:13.68
# loss:2.13e-05, loss_r:7.61e-06, loss_b:1.37e-07,
# Valid   Loss:1.5401e-05  Loss_r:2.6822e-06
# Epoch #  25400/150000    time:13.68
# loss:2.13e-05, loss_r:1.76e-05, loss_b:3.65e-08,
# Valid   Loss:6.6368e-06  Loss_r:3.1456e-06
# Epoch #  25500/150000    time:13.68
# loss:3.98e-06, loss_r:3.56e-06, loss_b:4.18e-09,
# Valid   Loss:2.7057e-06  Loss_r:2.2859e-06
# Epoch #  25600/150000    time:13.68
# loss:9.64e-06, loss_r:8.96e-06, loss_b:6.82e-09,
# Valid   Loss:3.2627e-06  Loss_r:2.5726e-06
# Epoch #  25700/150000    time:13.68
# loss:3.49e-04, loss_r:3.14e-04, loss_b:3.56e-07,
# Valid   Loss:8.8229e-05  Loss_r:3.5522e-05
# Epoch #  25800/150000    time:13.68
# loss:5.37e-06, loss_r:4.62e-06, loss_b:7.50e-09,
# Valid   Loss:3.0550e-06  Loss_r:2.3682e-06
# Epoch #  25900/150000    time:13.69
# loss:6.21e-03, loss_r:5.74e-03, loss_b:4.70e-06,
# Valid   Loss:5.9068e-04  Loss_r:2.3611e-04
# Epoch #  26000/150000    time:13.69
# loss:2.06e-03, loss_r:1.93e-03, loss_b:1.28e-06,
# Valid   Loss:3.7909e-04  Loss_r:1.8832e-04
# Epoch #  26100/150000    time:13.70
# loss:6.67e-06, loss_r:3.62e-06, loss_b:3.05e-08,
# Valid   Loss:5.1965e-06  Loss_r:2.1600e-06
# Epoch #  26200/150000    time:13.69
# loss:6.01e-03, loss_r:5.37e-03, loss_b:6.38e-06,
# Valid   Loss:1.5839e-03  Loss_r:5.4959e-04
# Epoch #  26300/150000    time:13.69
# loss:6.53e-06, loss_r:3.63e-06, loss_b:2.89e-08,
# Valid   Loss:5.2078e-06  Loss_r:2.1654e-06
# Epoch #  26400/150000    time:13.68
# loss:4.57e-03, loss_r:4.20e-03, loss_b:3.76e-06,
# Valid   Loss:6.1983e-04  Loss_r:2.6144e-04
# Epoch #  26500/150000    time:13.69
# loss:9.58e-06, loss_r:6.45e-06, loss_b:3.13e-08,
# Valid   Loss:5.3724e-06  Loss_r:2.2608e-06
# Epoch #  26600/150000    time:13.68
# loss:3.84e-04, loss_r:3.51e-04, loss_b:3.30e-07,
# Valid   Loss:6.4267e-05  Loss_r:2.7164e-05
# Epoch #  26700/150000    time:13.68
# loss:7.42e-04, loss_r:6.91e-04, loss_b:5.14e-07,
# Valid   Loss:7.6301e-05  Loss_r:3.6235e-05
# Epoch #  26800/150000    time:13.68
# loss:3.78e-04, loss_r:3.47e-04, loss_b:3.16e-07,
# Valid   Loss:5.7722e-05  Loss_r:2.3137e-05
# Epoch #  26900/150000    time:13.68
# loss:2.31e-04, loss_r:2.07e-04, loss_b:2.37e-07,
# Valid   Loss:4.8499e-05  Loss_r:1.7618e-05
# Epoch #  27000/150000    time:13.69
# loss:2.25e-04, loss_r:1.98e-04, loss_b:2.78e-07,
# Valid   Loss:3.7824e-05  Loss_r:1.2950e-05
# Epoch #  27100/150000    time:13.65
# loss:1.81e-04, loss_r:1.72e-04, loss_b:8.80e-08,
# Valid   Loss:2.7778e-05  Loss_r:1.6612e-05
# Epoch #  27200/150000    time:13.64
# loss:3.44e-03, loss_r:3.16e-03, loss_b:2.83e-06,
# Valid   Loss:2.7887e-04  Loss_r:9.9932e-05
# Epoch #  27300/150000    time:13.64
# loss:2.95e-04, loss_r:1.99e-04, loss_b:9.68e-07,
# Valid   Loss:8.1775e-05  Loss_r:2.3576e-05
# Epoch #  27400/150000    time:13.64
# loss:5.01e-06, loss_r:3.55e-06, loss_b:1.46e-08,
# Valid   Loss:3.4627e-06  Loss_r:2.0033e-06
# Epoch #  27500/150000    time:13.64
# loss:4.81e-06, loss_r:3.37e-06, loss_b:1.44e-08,
# Valid   Loss:3.2741e-06  Loss_r:1.8329e-06
# Epoch #  27600/150000    time:13.64
# loss:1.60e-02, loss_r:1.48e-02, loss_b:1.18e-05,
# Valid   Loss:4.1199e-03  Loss_r:1.5522e-03
# Epoch #  27700/150000    time:13.64
# loss:1.39e-04, loss_r:1.31e-04, loss_b:8.10e-08,
# Valid   Loss:2.4700e-05  Loss_r:1.2948e-05
# Epoch #  27800/150000    time:13.64
# loss:6.29e-06, loss_r:4.78e-06, loss_b:1.51e-08,
# Valid   Loss:3.5217e-06  Loss_r:2.0799e-06
# Epoch #  27900/150000    time:13.64
# loss:4.69e-06, loss_r:3.28e-06, loss_b:1.41e-08,
# Valid   Loss:3.2668e-06  Loss_r:1.8599e-06
# Epoch #  28000/150000    time:13.64
# loss:1.22e-03, loss_r:1.13e-03, loss_b:8.27e-07,
# Valid   Loss:1.6320e-04  Loss_r:7.6394e-05
# Epoch #  28100/150000    time:13.64
# loss:4.96e-06, loss_r:4.56e-06, loss_b:4.07e-09,
# Valid   Loss:2.5496e-06  Loss_r:2.2174e-06
# Epoch #  28200/150000    time:13.64
# loss:3.56e-06, loss_r:3.24e-06, loss_b:3.13e-09,
# Valid   Loss:2.2362e-06  Loss_r:1.9230e-06
# Epoch #  28300/150000    time:13.64
# loss:3.56e-06, loss_r:3.22e-06, loss_b:3.38e-09,
# Valid   Loss:2.1228e-06  Loss_r:1.7848e-06
# Epoch #  28400/150000    time:13.64
# loss:3.75e-06, loss_r:3.29e-06, loss_b:4.56e-09,
# Valid   Loss:2.1955e-06  Loss_r:1.6709e-06
# Epoch #  28500/150000    time:13.63
# loss:6.59e-05, loss_r:4.72e-05, loss_b:1.87e-07,
# Valid   Loss:2.5507e-05  Loss_r:1.1182e-05
# Epoch #  28600/150000    time:13.64
# loss:5.24e-06, loss_r:4.77e-06, loss_b:4.67e-09,
# Valid   Loss:2.8916e-06  Loss_r:2.4289e-06
# Epoch #  28700/150000    time:13.68
# loss:4.28e-06, loss_r:3.89e-06, loss_b:3.94e-09,
# Valid   Loss:2.4170e-06  Loss_r:2.0238e-06
# Epoch #  28800/150000    time:13.69
# loss:3.96e-06, loss_r:3.59e-06, loss_b:3.73e-09,
# Valid   Loss:2.2502e-06  Loss_r:1.8776e-06
# Epoch #  28900/150000    time:13.69
# loss:3.78e-06, loss_r:3.42e-06, loss_b:3.63e-09,
# Valid   Loss:2.1507e-06  Loss_r:1.7885e-06
# Epoch #  29000/150000    time:13.69
# loss:4.03e-06, loss_r:3.67e-06, loss_b:3.55e-09,
# Valid   Loss:2.1379e-06  Loss_r:1.7429e-06
# Epoch #  29100/150000    time:13.70
# loss:7.81e-06, loss_r:6.99e-06, loss_b:8.13e-09,
# Valid   Loss:2.6292e-06  Loss_r:2.0301e-06
# Epoch #  29200/150000    time:13.70
# loss:5.38e-06, loss_r:4.87e-06, loss_b:5.16e-09,
# Valid   Loss:2.4593e-06  Loss_r:1.9348e-06
# Epoch #  29300/150000    time:13.69
# loss:4.73e-04, loss_r:4.47e-04, loss_b:2.60e-07,
# Valid   Loss:6.7174e-05  Loss_r:3.2483e-05
# Epoch #  29400/150000    time:13.69
# loss:1.54e-04, loss_r:1.46e-04, loss_b:7.57e-08,
# Valid   Loss:1.8135e-05  Loss_r:1.1154e-05
# Epoch #  29500/150000    time:13.69
# loss:1.81e-03, loss_r:1.73e-03, loss_b:7.16e-07,
# Valid   Loss:1.5906e-04  Loss_r:8.7947e-05
# Epoch #  29600/150000    time:13.69
# loss:1.43e-03, loss_r:1.36e-03, loss_b:6.98e-07,
# Valid   Loss:8.6048e-05  Loss_r:3.8335e-05
# Epoch #  29700/150000    time:13.69
# loss:1.47e-04, loss_r:1.28e-04, loss_b:1.91e-07,
# Valid   Loss:3.1815e-05  Loss_r:1.5973e-05
# Epoch #  29800/150000    time:13.69
# loss:3.75e-06, loss_r:3.22e-06, loss_b:5.32e-09,
# Valid   Loss:2.0737e-06  Loss_r:1.5335e-06
# Epoch #  29900/150000    time:13.69
# loss:3.66e-06, loss_r:3.12e-06, loss_b:5.36e-09,
# Valid   Loss:2.0029e-06  Loss_r:1.4673e-06
# ...
# Epoch #  138900/150000    time:13.56
# loss:4.77e-08, loss_r:2.34e-08, loss_b:2.43e-10,
# Valid   Loss:4.9491e-08  Loss_r:2.3658e-08
# Epoch #  139000/150000    time:13.55
# loss:5.75e-08, loss_r:2.47e-08, loss_b:3.28e-10,
# Valid   Loss:5.4633e-08  Loss_r:2.4272e-08
# Epoch #  139100/150000    time:13.56
# loss:1.03e-07, loss_r:1.71e-08, loss_b:8.57e-10,
# Valid   Loss:1.0343e-07  Loss_r:1.7224e-08
# Epoch #  139200/150000    time:13.55
# loss:5.98e-08, loss_r:1.65e-08, loss_b:4.33e-10,
# Valid   Loss:5.9584e-08  Loss_r:1.6528e-08
# Epoch #  139300/150000    time:13.55
# loss:4.99e-08, loss_r:1.68e-08, loss_b:3.31e-10,
# Valid   Loss:4.9667e-08  Loss_r:1.6764e-08
# Epoch #  139400/150000    time:13.54
# loss:4.88e-08, loss_r:1.81e-08, loss_b:3.07e-10,
# Valid   Loss:4.7300e-08  Loss_r:1.7799e-08
# Epoch #  139500/150000    time:13.52
# loss:3.45e-08, loss_r:1.62e-08, loss_b:1.83e-10,
# Valid   Loss:3.5039e-08  Loss_r:1.6364e-08
# Epoch #  139600/150000    time:13.55
# loss:3.05e-08, loss_r:1.59e-08, loss_b:1.46e-10,
# Valid   Loss:3.0698e-08  Loss_r:1.5947e-08
# Epoch #  139700/150000    time:13.55
# loss:3.20e-08, loss_r:1.64e-08, loss_b:1.57e-10,
# Valid   Loss:3.1652e-08  Loss_r:1.6318e-08
# Epoch #  139800/150000    time:13.55
# loss:3.13e-08, loss_r:1.59e-08, loss_b:1.54e-10,
# Valid   Loss:2.9397e-08  Loss_r:1.5790e-08
# Epoch #  139900/150000    time:13.55
# loss:2.59e-08, loss_r:1.56e-08, loss_b:1.03e-10,
# Valid   Loss:2.5655e-08  Loss_r:1.5604e-08
# Adjusting learning rate of group 0 to 2.2185e-06.
# Epoch #  140000/150000    time:13.55
# loss:2.34e-08, loss_r:1.54e-08, loss_b:7.99e-11,
# Valid   Loss:2.3395e-08  Loss_r:1.5372e-08
# Epoch #  140100/150000    time:13.56
# loss:3.57e-08, loss_r:2.23e-08, loss_b:1.34e-10,
# Valid   Loss:3.5550e-08  Loss_r:2.2224e-08
# Epoch #  140200/150000    time:13.55
# loss:2.91e-08, loss_r:2.05e-08, loss_b:8.51e-11,
# Valid   Loss:2.9017e-08  Loss_r:2.0526e-08
# Epoch #  140300/150000    time:13.55
# loss:2.67e-08, loss_r:1.96e-08, loss_b:7.06e-11,
# Valid   Loss:2.6741e-08  Loss_r:1.9623e-08
# Epoch #  140400/150000    time:13.55
# loss:2.86e-08, loss_r:1.95e-08, loss_b:9.13e-11,
# Valid   Loss:2.8602e-08  Loss_r:1.9437e-08
# Epoch #  140500/150000    time:13.55
# loss:2.33e-08, loss_r:1.83e-08, loss_b:5.02e-11,
# Valid   Loss:2.3305e-08  Loss_r:1.8321e-08
# Epoch #  140600/150000    time:13.55
# loss:2.24e-08, loss_r:1.79e-08, loss_b:4.50e-11,
# Valid   Loss:2.2571e-08  Loss_r:1.7934e-08
# Epoch #  140700/150000    time:13.55
# loss:2.26e-08, loss_r:1.77e-08, loss_b:4.83e-11,
# Valid   Loss:2.2318e-08  Loss_r:1.7683e-08
# Epoch #  140800/150000    time:13.55
# loss:2.13e-08, loss_r:1.73e-08, loss_b:3.95e-11,
# Valid   Loss:2.1317e-08  Loss_r:1.7318e-08
# Epoch #  140900/150000    time:13.55
# loss:2.05e-08, loss_r:1.70e-08, loss_b:3.44e-11,
# Valid   Loss:2.0525e-08  Loss_r:1.7029e-08
# Epoch #  141000/150000    time:13.55
# loss:2.04e-08, loss_r:1.69e-08, loss_b:3.49e-11,
# Valid   Loss:2.0535e-08  Loss_r:1.6893e-08
# Epoch #  141100/150000    time:13.56
# loss:2.27e-08, loss_r:1.91e-08, loss_b:3.56e-11,
# Valid   Loss:2.2650e-08  Loss_r:1.9141e-08
# Epoch #  141200/150000    time:13.55
# loss:2.27e-08, loss_r:1.88e-08, loss_b:3.94e-11,
# Valid   Loss:2.2633e-08  Loss_r:1.8779e-08
# Epoch #  141300/150000    time:13.55
# loss:2.24e-08, loss_r:1.84e-08, loss_b:3.96e-11,
# Valid   Loss:2.4636e-08  Loss_r:1.8638e-08
# Epoch #  141400/150000    time:13.56
# loss:3.04e-08, loss_r:1.92e-08, loss_b:1.12e-10,
# Valid   Loss:2.7192e-08  Loss_r:1.8769e-08
# Epoch #  141500/150000    time:13.55
# loss:2.20e-08, loss_r:1.80e-08, loss_b:4.02e-11,
# Valid   Loss:2.0757e-08  Loss_r:1.7873e-08
# Epoch #  141600/150000    time:13.55
# loss:2.17e-08, loss_r:1.77e-08, loss_b:4.04e-11,
# Valid   Loss:2.2053e-08  Loss_r:1.7726e-08
# Epoch #  141700/150000    time:13.55
# loss:1.93e-08, loss_r:1.74e-08, loss_b:1.89e-11,
# Valid   Loss:1.9152e-08  Loss_r:1.7361e-08
# Epoch #  141800/150000    time:13.55
# loss:1.92e-08, loss_r:1.73e-08, loss_b:1.99e-11,
# Valid   Loss:1.9153e-08  Loss_r:1.7244e-08
# Epoch #  141900/150000    time:13.55
# loss:1.85e-08, loss_r:1.70e-08, loss_b:1.45e-11,
# Valid   Loss:1.8438e-08  Loss_r:1.7018e-08
# Epoch #  142000/150000    time:13.55
# loss:2.19e-08, loss_r:1.73e-08, loss_b:4.63e-11,
# Valid   Loss:2.3305e-08  Loss_r:1.7491e-08
# Epoch #  142100/150000    time:13.56
# loss:2.22e-08, loss_r:1.77e-08, loss_b:4.53e-11,
# Valid   Loss:2.2250e-08  Loss_r:1.7714e-08
# Epoch #  142200/150000    time:13.55
# loss:2.28e-08, loss_r:1.75e-08, loss_b:5.30e-11,
# Valid   Loss:2.3060e-08  Loss_r:1.7472e-08
# Epoch #  142300/150000    time:13.55
# loss:2.04e-08, loss_r:1.70e-08, loss_b:3.36e-11,
# Valid   Loss:2.0448e-08  Loss_r:1.7032e-08
# Epoch #  142400/150000    time:13.55
# loss:1.96e-08, loss_r:1.68e-08, loss_b:2.83e-11,
# Valid   Loss:1.9647e-08  Loss_r:1.6757e-08
# Epoch #  142500/150000    time:13.56
# loss:2.22e-08, loss_r:1.69e-08, loss_b:5.32e-11,
# Valid   Loss:2.2502e-08  Loss_r:1.6942e-08
# Epoch #  142600/150000    time:13.55
# loss:1.96e-08, loss_r:1.65e-08, loss_b:3.06e-11,
# Valid   Loss:1.9447e-08  Loss_r:1.6478e-08
# Epoch #  142700/150000    time:13.56
# loss:1.84e-08, loss_r:1.63e-08, loss_b:2.19e-11,
# Valid   Loss:1.8487e-08  Loss_r:1.6266e-08
# Epoch #  142800/150000    time:13.56
# loss:2.00e-08, loss_r:1.63e-08, loss_b:3.75e-11,
# Valid   Loss:2.0122e-08  Loss_r:1.6309e-08
# Epoch #  142900/150000    time:13.55
# loss:2.20e-08, loss_r:1.67e-08, loss_b:5.33e-11,
# Valid   Loss:2.3119e-08  Loss_r:1.6871e-08
# Epoch #  143000/150000    time:13.55
# loss:1.92e-08, loss_r:1.60e-08, loss_b:3.20e-11,
# Valid   Loss:1.9172e-08  Loss_r:1.6030e-08
# Epoch #  143100/150000    time:13.56
# loss:3.62e-08, loss_r:1.90e-08, loss_b:1.73e-10,
# Valid   Loss:3.6512e-08  Loss_r:1.9018e-08
# Epoch #  143200/150000    time:13.55
# loss:2.87e-08, loss_r:1.84e-08, loss_b:1.03e-10,
# Valid   Loss:2.8584e-08  Loss_r:1.8422e-08
# Epoch #  143300/150000    time:13.55
# loss:2.73e-08, loss_r:1.82e-08, loss_b:9.17e-11,
# Valid   Loss:2.7648e-08  Loss_r:1.8307e-08
# Epoch #  143400/150000    time:13.55
# loss:2.94e-08, loss_r:1.84e-08, loss_b:1.10e-10,
# Valid   Loss:2.9676e-08  Loss_r:1.8413e-08
# Epoch #  143500/150000    time:13.55
# loss:2.21e-08, loss_r:1.75e-08, loss_b:4.59e-11,
# Valid   Loss:2.2113e-08  Loss_r:1.7510e-08
# Epoch #  143600/150000    time:13.55
# loss:2.21e-08, loss_r:1.74e-08, loss_b:4.67e-11,
# Valid   Loss:2.2438e-08  Loss_r:1.7453e-08
# Epoch #  143700/150000    time:13.56
# loss:2.12e-08, loss_r:1.73e-08, loss_b:3.88e-11,
# Valid   Loss:2.0993e-08  Loss_r:1.7300e-08
# Epoch #  143800/150000    time:13.56
# loss:2.22e-08, loss_r:1.74e-08, loss_b:4.77e-11,
# Valid   Loss:2.1123e-08  Loss_r:1.7325e-08
# Epoch #  143900/150000    time:13.55
# loss:2.40e-08, loss_r:1.78e-08, loss_b:6.26e-11,
# Valid   Loss:2.6852e-08  Loss_r:1.8017e-08
# Epoch #  144000/150000    time:13.55
# loss:2.10e-08, loss_r:1.72e-08, loss_b:3.79e-11,
# Valid   Loss:2.0955e-08  Loss_r:1.7149e-08
# Epoch #  144100/150000    time:13.56
# loss:5.56e-08, loss_r:4.17e-08, loss_b:1.40e-10,
# Valid   Loss:5.5456e-08  Loss_r:4.1571e-08
# Epoch #  144200/150000    time:13.55
# loss:3.89e-08, loss_r:3.31e-08, loss_b:5.81e-11,
# Valid   Loss:3.8958e-08  Loss_r:3.3040e-08
# Epoch #  144300/150000    time:13.55
# loss:3.38e-08, loss_r:2.92e-08, loss_b:4.59e-11,
# Valid   Loss:3.4384e-08  Loss_r:2.9192e-08
# Epoch #  144400/150000    time:13.55
# loss:3.26e-08, loss_r:2.70e-08, loss_b:5.60e-11,
# Valid   Loss:3.0807e-08  Loss_r:2.6858e-08
# Epoch #  144500/150000    time:13.55
# loss:2.70e-08, loss_r:2.50e-08, loss_b:1.94e-11,
# Valid   Loss:2.7007e-08  Loss_r:2.5033e-08
# Epoch #  144600/150000    time:13.55
# loss:3.05e-08, loss_r:2.40e-08, loss_b:6.51e-11,
# Valid   Loss:3.1478e-08  Loss_r:2.4028e-08
# Epoch #  144700/150000    time:13.55
# loss:2.47e-08, loss_r:2.29e-08, loss_b:1.77e-11,
# Valid   Loss:2.4496e-08  Loss_r:2.2842e-08
# Epoch #  144800/150000    time:13.55
# loss:2.52e-08, loss_r:2.22e-08, loss_b:3.08e-11,
# Valid   Loss:2.5144e-08  Loss_r:2.2140e-08
# Epoch #  144900/150000    time:13.55
# loss:2.35e-08, loss_r:2.14e-08, loss_b:2.09e-11,
# Valid   Loss:2.3851e-08  Loss_r:2.1486e-08
# Adjusting learning rate of group 0 to 1.9967e-06.
# Epoch #  145000/150000    time:13.55
# loss:2.29e-08, loss_r:2.09e-08, loss_b:1.90e-11,
# Valid   Loss:2.2552e-08  Loss_r:2.0882e-08
# Epoch #  145100/150000    time:13.56
# loss:2.04e-08, loss_r:1.53e-08, loss_b:5.11e-11,
# Valid   Loss:2.0418e-08  Loss_r:1.5327e-08
# Epoch #  145200/150000    time:13.55
# loss:1.90e-08, loss_r:1.49e-08, loss_b:4.09e-11,
# Valid   Loss:1.9030e-08  Loss_r:1.4935e-08
# Epoch #  145300/150000    time:13.55
# loss:1.85e-08, loss_r:1.48e-08, loss_b:3.75e-11,
# Valid   Loss:1.8507e-08  Loss_r:1.4758e-08
# Epoch #  145400/150000    time:13.55
# loss:1.82e-08, loss_r:1.46e-08, loss_b:3.56e-11,
# Valid   Loss:1.8189e-08  Loss_r:1.4637e-08
# Epoch #  145500/150000    time:13.55
# loss:1.80e-08, loss_r:1.45e-08, loss_b:3.41e-11,
# Valid   Loss:1.7955e-08  Loss_r:1.4542e-08
# Epoch #  145600/150000    time:13.55
# loss:5.40e-08, loss_r:1.95e-08, loss_b:3.46e-10,
# Valid   Loss:8.6646e-08  Loss_r:2.5014e-08
# Epoch #  145700/150000    time:13.55
# loss:1.76e-08, loss_r:1.44e-08, loss_b:3.23e-11,
# Valid   Loss:1.7617e-08  Loss_r:1.4397e-08
# Epoch #  145800/150000    time:13.55
# loss:1.75e-08, loss_r:1.43e-08, loss_b:3.14e-11,
# Valid   Loss:1.7482e-08  Loss_r:1.4342e-08
# Epoch #  145900/150000    time:13.55
# loss:1.74e-08, loss_r:1.43e-08, loss_b:3.07e-11,
# Valid   Loss:1.7360e-08  Loss_r:1.4288e-08
# Epoch #  146000/150000    time:13.56
# loss:1.72e-08, loss_r:1.42e-08, loss_b:3.01e-11,
# Valid   Loss:1.7246e-08  Loss_r:1.4239e-08
# Epoch #  146100/150000    time:13.56
# loss:1.03e-07, loss_r:3.27e-08, loss_b:6.99e-10,
# Valid   Loss:1.0222e-07  Loss_r:3.2678e-08
# Epoch #  146200/150000    time:13.56
# loss:9.13e-08, loss_r:3.57e-08, loss_b:5.55e-10,
# Valid   Loss:9.2368e-08  Loss_r:3.5850e-08
# Epoch #  146300/150000    time:13.56
# loss:7.09e-08, loss_r:3.62e-08, loss_b:3.47e-10,
# Valid   Loss:7.0998e-08  Loss_r:3.6246e-08
# Epoch #  146400/150000    time:13.55
# loss:6.79e-08, loss_r:3.79e-08, loss_b:3.00e-10,
# Valid   Loss:6.7674e-08  Loss_r:3.7916e-08
# Epoch #  146500/150000    time:13.55
# loss:6.22e-08, loss_r:3.85e-08, loss_b:2.37e-10,
# Valid   Loss:6.2353e-08  Loss_r:3.8518e-08
# Epoch #  146600/150000    time:13.55
# loss:6.01e-08, loss_r:3.92e-08, loss_b:2.09e-10,
# Valid   Loss:6.0115e-08  Loss_r:3.9195e-08
# Epoch #  146700/150000    time:13.55
# loss:6.41e-08, loss_r:4.04e-08, loss_b:2.38e-10,
# Valid   Loss:6.5300e-08  Loss_r:4.0505e-08
# Epoch #  146800/150000    time:13.56
# loss:5.72e-08, loss_r:3.98e-08, loss_b:1.74e-10,
# Valid   Loss:5.7285e-08  Loss_r:3.9838e-08
# Epoch #  146900/150000    time:13.55
# loss:5.73e-08, loss_r:4.00e-08, loss_b:1.73e-10,
# Valid   Loss:5.7523e-08  Loss_r:4.0000e-08
# Epoch #  147000/150000    time:13.55
# loss:5.62e-08, loss_r:4.01e-08, loss_b:1.61e-10,
# Valid   Loss:5.6039e-08  Loss_r:4.0117e-08
# Epoch #  147100/150000    time:13.57
# loss:6.33e-08, loss_r:2.92e-08, loss_b:3.42e-10,
# Valid   Loss:6.2941e-08  Loss_r:2.9100e-08
# Epoch #  147200/150000    time:13.56
# loss:4.38e-08, loss_r:2.41e-08, loss_b:1.97e-10,
# Valid   Loss:4.3715e-08  Loss_r:2.4057e-08
# Epoch #  147300/150000    time:13.55
# loss:3.62e-08, loss_r:2.21e-08, loss_b:1.41e-10,
# Valid   Loss:3.6184e-08  Loss_r:2.2088e-08
# Epoch #  147400/150000    time:13.55
# loss:3.48e-08, loss_r:2.13e-08, loss_b:1.34e-10,
# Valid   Loss:3.5294e-08  Loss_r:2.1389e-08
# Epoch #  147500/150000    time:13.55
# loss:3.47e-08, loss_r:2.09e-08, loss_b:1.38e-10,
# Valid   Loss:3.4524e-08  Loss_r:2.0872e-08
# Epoch #  147600/150000    time:13.55
# loss:3.50e-08, loss_r:2.05e-08, loss_b:1.45e-10,
# Valid   Loss:3.6671e-08  Loss_r:2.0737e-08
# Epoch #  147700/150000    time:13.56
# loss:2.58e-08, loss_r:1.90e-08, loss_b:6.79e-11,
# Valid   Loss:2.6129e-08  Loss_r:1.9054e-08
# Epoch #  147800/150000    time:13.56
# loss:3.10e-08, loss_r:1.96e-08, loss_b:1.14e-10,
# Valid   Loss:3.4128e-08  Loss_r:2.0047e-08
# Epoch #  147900/150000    time:13.56
# loss:2.33e-08, loss_r:1.82e-08, loss_b:5.07e-11,
# Valid   Loss:2.3322e-08  Loss_r:1.8248e-08
# Epoch #  148000/150000    time:13.56
# loss:2.46e-08, loss_r:1.81e-08, loss_b:6.53e-11,
# Valid   Loss:2.4295e-08  Loss_r:1.8086e-08
# Epoch #  148100/150000    time:13.57
# loss:2.08e-08, loss_r:1.66e-08, loss_b:4.21e-11,
# Valid   Loss:2.0195e-08  Loss_r:1.6532e-08
# Epoch #  148200/150000    time:13.56
# loss:1.95e-08, loss_r:1.61e-08, loss_b:3.39e-11,
# Valid   Loss:1.9566e-08  Loss_r:1.6124e-08
# Epoch #  148300/150000    time:13.56
# loss:1.94e-08, loss_r:1.59e-08, loss_b:3.54e-11,
# Valid   Loss:1.9678e-08  Loss_r:1.5899e-08
# Epoch #  148400/150000    time:13.56
# loss:1.89e-08, loss_r:1.57e-08, loss_b:3.20e-11,
# Valid   Loss:1.8164e-08  Loss_r:1.5635e-08
# Epoch #  148500/150000    time:13.56
# loss:1.77e-08, loss_r:1.55e-08, loss_b:2.23e-11,
# Valid   Loss:1.7791e-08  Loss_r:1.5466e-08
# Epoch #  148600/150000    time:13.56
# loss:1.99e-08, loss_r:1.57e-08, loss_b:4.28e-11,
# Valid   Loss:1.9382e-08  Loss_r:1.5596e-08
# Epoch #  148700/150000    time:13.56
# loss:1.73e-08, loss_r:1.52e-08, loss_b:2.03e-11,
# Valid   Loss:1.7269e-08  Loss_r:1.5220e-08
# Epoch #  148800/150000    time:13.56
# loss:2.04e-08, loss_r:1.55e-08, loss_b:4.87e-11,
# Valid   Loss:2.0985e-08  Loss_r:1.5556e-08
# Epoch #  148900/150000    time:13.56
# loss:1.67e-08, loss_r:1.50e-08, loss_b:1.69e-11,
# Valid   Loss:1.6789e-08  Loss_r:1.5012e-08
# Epoch #  149000/150000    time:13.56
# loss:1.65e-08, loss_r:1.49e-08, loss_b:1.55e-11,
# Valid   Loss:1.6455e-08  Loss_r:1.4902e-08
# Epoch #  149100/150000    time:13.56
# loss:2.16e-08, loss_r:1.96e-08, loss_b:1.96e-11,
# Valid   Loss:2.1589e-08  Loss_r:1.9626e-08
# Epoch #  149200/150000    time:13.56
# loss:2.31e-08, loss_r:1.84e-08, loss_b:4.79e-11,
# Valid   Loss:2.4362e-08  Loss_r:1.8491e-08
# Epoch #  149300/150000    time:13.56
# loss:2.09e-08, loss_r:1.75e-08, loss_b:3.36e-11,
# Valid   Loss:2.0085e-08  Loss_r:1.7334e-08
# Epoch #  149400/150000    time:13.56
# loss:2.21e-08, loss_r:1.70e-08, loss_b:5.07e-11,
# Valid   Loss:2.0598e-08  Loss_r:1.6763e-08
# Epoch #  149500/150000    time:13.56
# loss:2.20e-08, loss_r:1.68e-08, loss_b:5.21e-11,
# Valid   Loss:2.2722e-08  Loss_r:1.6845e-08
# Epoch #  149600/150000    time:13.56
# loss:1.88e-08, loss_r:1.60e-08, loss_b:2.85e-11,
# Valid   Loss:1.9166e-08  Loss_r:1.6031e-08
# Epoch #  149700/150000    time:13.56
# loss:1.93e-08, loss_r:1.61e-08, loss_b:3.23e-11,
# Valid   Loss:1.9798e-08  Loss_r:1.6137e-08
# Epoch #  149800/150000    time:13.56
# loss:1.81e-08, loss_r:1.58e-08, loss_b:2.33e-11,
# Valid   Loss:1.7110e-08  Loss_r:1.5628e-08
# Epoch #  149900/150000    time:13.56
# loss:1.64e-08, loss_r:1.54e-08, loss_b:1.02e-11,
# Valid   Loss:1.6526e-08  Loss_r:1.5431e-08
# Adjusting learning rate of group 0 to 1.7970e-06.
# Epoch #  150000/150000    time:13.56
# loss:1.92e-08, loss_r:1.56e-08, loss_b:3.66e-11,
# Valid   Loss:1.8040e-08  Loss_r:1.5468e-08
# Epoch #  100/151000    time:32.47
# loss:2.54e-08, loss_r:1.91e-08, loss_b:6.28e-11,
# Valid   Loss:2.5355e-08  Loss_r:1.9074e-08
# Epoch #  200/151000    time:31.96
# loss:3.68e-08, loss_r:1.78e-08, loss_b:1.89e-10,
# Valid   Loss:3.6755e-08  Loss_r:1.7810e-08
# Epoch #  300/151000    time:31.68
# loss:9.40e-08, loss_r:2.28e-08, loss_b:7.12e-10,
# Valid   Loss:9.4009e-08  Loss_r:2.2826e-08
# Epoch #  400/151000    time:31.68
# loss:2.22e-08, loss_r:1.90e-08, loss_b:3.28e-11,
# Valid   Loss:2.2247e-08  Loss_r:1.8965e-08
# Epoch #  500/151000    time:31.69
# loss:2.11e-08, loss_r:1.81e-08, loss_b:3.06e-11,
# Valid   Loss:2.1138e-08  Loss_r:1.8076e-08
# Epoch #  600/151000    time:31.70
# loss:7.57e-08, loss_r:2.23e-08, loss_b:5.34e-10,
# Valid   Loss:7.5702e-08  Loss_r:2.2333e-08
# Epoch #  700/151000    time:31.70
# loss:2.29e-08, loss_r:1.87e-08, loss_b:4.16e-11,
# Valid   Loss:2.2886e-08  Loss_r:1.8725e-08
# Epoch #  800/151000    time:31.69
# loss:3.00e-08, loss_r:2.73e-08, loss_b:2.71e-11,
# Valid   Loss:3.0039e-08  Loss_r:2.7326e-08
# Epoch #  900/151000    time:31.69
# loss:1.98e-08, loss_r:1.63e-08, loss_b:3.55e-11,
# Valid   Loss:1.9835e-08  Loss_r:1.6288e-08
# Epoch #  1000/151000    time:47.06
# loss:1.74e-07, loss_r:4.73e-08, loss_b:1.27e-09,
# Valid   Loss:1.7424e-07  Loss_r:4.7284e-08

# %%
# 使用最好的模型
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
model.load_state_dict(state_dict['state_dict'])
# Out:
# <All keys matched successfully>

# %%
file = f'checkpoints/subnet,{args.epochs_Adam}Adam,{args.epochs_LBFGS}LBFGS'
if os.path.exists(file)==False:
    os.mkdir(file)

# %%
# np.save(f'{file}/loss_r_log.npy',np.array(trainer.loss_r_log))
# np.save(f'{file}/loss_b_log.npy',np.array(trainer.loss_b_log))

# %%
trainer.loss_r_log = np.load(f'{file}/loss_r_log.npy')
trainer.loss_b_log = np.load(f'{file}/loss_b_log.npy')

# %%
import seaborn as sns
with sns.axes_style("darkgrid"):
    fig = plt.figure(figsize=(6, 5))
    plt.rcParams.update({'font.size':16})
    plt.plot(np.arange(len(trainer.loss_r_log)), trainer.loss_r_log, label='$ \mathcal{L}_r$')
    plt.plot(np.arange(len(trainer.loss_b_log)), trainer.loss_b_log, label='$ \mathcal{L}_{ic}$')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.legend()
    plt.savefig(f'{file}/loss.jpg', dpi=750, bbox_inches = 'tight')

# %% [markdown]
# ## 预测

# %%
model.cpu();
trainer.Unet.cpu();

# %%
# load the data
data = scipy.io.loadmat('AC.mat')
usol = data['uu']

# Grid
t_star = data['tt'][0]
x_star = data['x'][0]
TT, XX = np.meshgrid(t_star, x_star)

# Reference solution
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
# Out:
# Text(0, 0.5, '$x$')

# %%
# Get trained network parameters
TX = np.hstack((TT.reshape(-1,1), XX.reshape(-1,1)))
TX = torch.from_numpy(TX).double()

model = trainer.model.cpu().double()
u_pred = model(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

error = np.linalg.norm(u_pred - usol) / np.linalg.norm(usol) 
print('Relative l2 error: {:.3e}'.format(error))
# Out:
# Relative l2 error: 8.116e-05

# %%
plt.rcParams.update({'font.size':18})

fig = plt.figure(3, figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Reference $u(t,x)$')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.pcolor(TT, XX, u_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Predicted $u(t,x)$')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.pcolor(TT, XX, np.abs(usol - u_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Absolute error')
plt.tight_layout()

plt.savefig(f'{file}/results_ac.jpg', dpi=750, bbox_inches = 'tight')
plt.show()
