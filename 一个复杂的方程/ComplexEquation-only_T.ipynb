# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import seaborn as sns
from pyDOE import lhs

import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
#     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
#     torch.use_deterministic_algorithms(True)  # 有检查操作，看下文区别
 
seed_torch(314)

# %% [markdown]
# ## 参数设置

# %%
pi = np.pi
pf=1000;# kg/m-3
ps=2700;
pp=5540;
p=1000;# 水的密度
d31=-210e-12;
Cp=89.5e-9;
hp=0.3e-3;
hs=0.15e-3;
ha=-(hs+hp)/2;
hb=(hs-hp)/2;
hc=(hs+hp)/2;
Es=70e9; # KN/m2
Ep=15.857e9;# KN/m2
D=16e-3;
Lc=45e-3;
M0=0.01;
b=18e-3;
L=100e-3;
Mf=pf*pi*D**2*Lc/4+(33/140)*pi*pf*b**2*(L/4);
M=M0+Mf;
It=(M*(D/2)**2)/2;
m=ps*hs*b+pp*hp*b;
k1=0.086;# 阻尼比
K=b*(Es*(hb**3-ha**3)+Ep*(hc**3-hb**3))/3;
CD=2;
C1=0.3;
U=1;  # 速度
lam=1;
keci=0.3;
A=12;
St=0.2;
wf=2*pi*St*U/D;
R=0.5e6;

e31=-Ep*d31;
theta=-e31*b*(hc**2-hb**2)/(2*hp);
lamda=0.808646;
wn=lamda**2*(K/(m*L**4))**0.5; # 固有频率

#f_L=double(subs(f,x,L));
#df_L=double(subs(df,x,L));
#fi=(f_L+0.5*D*df_L);
f_L=-6.1894;
df_L=-92.8022;
fi=-6.9318;

# %%
domain = (0, 1.5, -0.0025, 0.0025)
tmin, tmax, xmin, xmax = domain
backbone_layers = [1] + [64]*6 + [1]
# backbone_layers = [1] + [20]*9 + [1]
adam_iters = 40000
# adam_iters = 20000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class Dataset:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, verbose=None):
        tmin, tmax, xmin, xmax = self.domain
        # 内部点采样
        t_res = np.linspace(tmin, tmax, 100)
        X_res = np.expand_dims(t_res, axis=1)
        X_res = np.repeat(X_res,5,axis=1)
        
        # 初始点采样
        X_ics =np.ones((1,5)) * tmin
#         X_ics = np.concatenate([X_ics, self.sample_xy(np.array([tmin]), np.linspace(xmin,xmax,100))], axis=0)
#         X_ics = np.expand_dims(X_ics, axis=1)
#         X_ics = np.repeat(X_ics,5,axis=1)

        u_ics = 0.0002
        return X_res, X_ics, u_ics
    
    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X

    
dataset = Dataset(domain)
X_res, X_ics, u_ics = dataset.train_data()
# X_res_1 = X_res_2 =X_res_3 =X_res_4 =X_res_5 =X_res
print(X_res.shape, X_ics.shape, u_ics)
X_res[:,1].max()
# Out:
# (100, 5) (1, 5) 0.0002
# 1.5

# %% [markdown]
# ## DNN

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)
    
backbone1 = MLP(backbone_layers)
backbone2 = MLP(backbone_layers)
backbone3 = MLP(backbone_layers)
backbone4 = MLP(backbone_layers)
backbone5 = MLP(backbone_layers)

# nn_lam = MLP(nn_lam_layers)

# %% [markdown]
# ## 主干网络

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINN(nn.Module):
    def __init__(self, backbone1, backbone2, backbone3, backbone4, backbone5, mu=None, sigma=None):
        super(PINN, self).__init__()
        self.backbone1 = backbone1
        self.backbone2 = backbone2
        self.backbone3 = backbone3
        self.backbone4 = backbone4
        self.backbone5 = backbone5

    def forward(self, X_res, X_ics, u_ics):
        
        loss_res_1 = torch.mean(self.net_E1(X_res)** 2)
        loss_res_2 = torch.mean(self.net_E2(X_res)** 2)
        loss_res_3 = torch.mean(self.net_E3(X_res)** 2)
        loss_res_4 = torch.mean(self.net_E4(X_res)** 2)
        loss_res_5 = torch.mean(self.net_E5(X_res)** 2)
        loss_ics = torch.mean((self.net_pred1(X_ics[:,[0]])- u_ics)**2) + torch.mean(self.net_pred2(X_ics[:,[1]])**2) + torch.mean(self.net_pred3(X_ics[:,[2]])**2)+ torch.mean(self.net_pred4(X_ics[:,[3]])**2)+ torch.mean(self.net_pred5(X_ics[:,[4]])**2)
#         print(self.net_E5(X_res))
        
        return loss_res_1, loss_res_2, loss_res_3, loss_res_4, loss_res_5, loss_ics 

    def net_pred1(self, X):
        return self.backbone1(X)
    
    def net_pred2(self, X):
        return self.backbone2(X)
    
    def net_pred3(self, X):
        return self.backbone3(X)
    
    def net_pred4(self, X):
        return self.backbone4(X)
    
    def net_pred5(self, X):
        return self.backbone5(X)
    
    def net_X_res_pred(self, X):
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
        X3_star = X[:,[2]]
        X4_star = X[:,[3]]
        X5_star = X[:,[4]]
        
#         X1_star.requires_grad_(True)
#         X2_star.requires_grad_(True)
#         X3_star.requires_grad_(True)
#         X4_star.requires_grad_(True)
#         X5_star.requires_grad_(True)
        
        X1 = self.net_pred1(X1_star)
        X2 = self.net_pred2(X2_star)
        X3 = self.net_pred3(X3_star)
        X4 = self.net_pred4(X4_star)
        X5 = self.net_pred5(X5_star)
        return X1,X2,X3,X4,X5
        

    def net_E1(self, X):
        X.requires_grad_(True)
        
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
#         print(X1_star.shape)
        X1_star.requires_grad_(True)
        X2_star.requires_grad_(True)
        
        X1 = self.net_pred1(X1_star)
        X2 = self.net_pred2(X2_star)

        grad_X1 = grad(X1, X1_star)[0]
        X1_pred_t = grad_X1[:, [0]]
        
        return X1_pred_t - X2  
    
    def net_E2(self,X):
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
        X3_star = X[:,[2]]
        X4_star = X[:,[3]]
        X5_star = X[:,[4]]
        
        X1_star.requires_grad_(True)
        X2_star.requires_grad_(True)
        X3_star.requires_grad_(True)
        X5_star.requires_grad_(True)

        X1 = self.net_pred1(X1_star)
        X2 = self.net_pred2(X2_star)
        X3 = self.net_pred3(X3_star)
        X5 = self.net_pred5(X5_star)
        
        grad_X = grad(X2, X2_star)[0]
        X2_pred_t = grad_X[:, [0]]
        
        return X2_pred_t + (2*k1*wn+0.5*CD*p*D*U*Lc*fi**2)*X2-wn**2*X1-theta*df_L*X5+0.25*C1*p*D*U**2*Lc*fi*X3
    
    def net_E3(self, X):
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
        X3_star = X[:,[2]]
        X4_star = X[:,[3]]
        X5_star = X[:,[4]]
        
        X1_star.requires_grad_(True)
        X3_star.requires_grad_(True)
        
        X3 = self.net_pred3(X3_star)
        X4 = self.net_pred4(X4_star)
        
        grad_X = grad(X3, X3_star)[0]
        X3_pred_t = grad_X[:, [0]]
        return X3_pred_t-X4
    
    def net_E4(self, X):
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
        X3_star = X[:,[2]]
        X4_star = X[:,[3]]
        X5_star = X[:,[4]]
        
        X4_star.requires_grad_(True)
        X1 = self.net_pred1(X1_star)
        X2 = self.net_pred2(X2_star)
        X3 = self.net_pred3(X3_star)
        X4 = self.net_pred4(X4_star)
        X5 = self.net_pred5(X5_star)
        
        grad_X = grad(X4, X4_star)[0]
        X4_pred_t = grad_X[:, [0]]
        
        return X4_pred_t - (-lam*keci*wf*(X3)**2*X4+lam*keci*wf*X4-wf**2*X3+A/D*fi*(-(2*k1*wn+0.5*CD*p*D*U*Lc*fi**2)*X2-wn**2*X1-theta*df_L*X5+0.25*C1*p*D*U**2*Lc*fi*X3))
    
    def net_E5(self,X):
        X1_star = X[:,[0]]
        X2_star = X[:,[1]]
        X3_star = X[:,[2]]
        X4_star = X[:,[3]]
        X5_star = X[:,[4]]
        
        X4_star.requires_grad_(True)
        X2 = self.net_pred2(X2_star)
        X5 = self.net_pred5(X5_star)
        
        grad_X = grad(X5, X5_star)[0]
        X5_pred_t = grad_X[:, [0]]
        
        return X5_pred_t-((-X5/R+theta*df_L*X2)/Cp)
        
#     def net_ics(self,X):
#         X1 = X[:,0]
#         X2 = X[:,1:]
#         X1 = np.add(X1, -np.ones((X1.shape))*0.0002).reshape((-1,1))
#         X_ics = torch.cat((X1,X2),1)
#         print(X_ics)
#         return X_ics
        
pinn = PINN(backbone_layers,backbone_layers,backbone_layers,backbone_layers,backbone_layers)
# pinn.net_E1(torch.tensor(X_res_1),torch.tensor(X_res_2))

# %% [markdown]
# ## Adam

# %%
dataset = Dataset(domain)
X_res, X_ics, u_ics = dataset.train_data()
X_res = torch.from_numpy(X_res).float().to(device)
X_ics = torch.from_numpy(X_ics).float().to(device)
u_ics = torch.tensor(u_ics).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone1 = MLP(backbone_layers)  # 主干网络
backbone2 = MLP(backbone_layers)
backbone3 = MLP(backbone_layers)
backbone4 = MLP(backbone_layers)
backbone5 = MLP(backbone_layers)
pinn = PINN(backbone1, backbone2, backbone3, backbone4, backbone5, mu, sigma).to(device)

optimizer_adam = optim.Adam(pinn.parameters(), lr=1e-3)

lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=0.8)  # 指数衰减学习率
logger = {
    "loss": [], 
    "loss_res_1": [],
    "loss_res_2": [],
    "loss_res_3": [],
    "loss_res_4": [],
    "loss_res_5": [],
    "loss_ics": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
best_loss = 1e9

# 训练
start_time = time.time()
for it in range(adam_iters):
    # 计算loss并更新网络 -------
    pinn.train()
    pinn.zero_grad()
    
    loss_res_1, loss_res_2, loss_res_3, loss_res_4, loss_res_5, loss_ics   = pinn(X_res, X_ics,u_ics)
    loss = loss_res_1 + 1000*loss_res_2 + loss_res_3 + 100*loss_res_4 + 100*loss_res_5 + 1000*loss_ics 
#     loss = loss_res_1 + 100*loss_res_2 + loss_res_3 + 100*loss_res_4 + 100*loss_res_5 
    
    loss.backward()
    optimizer_adam.step()
#     optimizer_adam_lam.step()
    # 计算loss并更新网络 -------
    
    
    if (it + 1) % 100 == 0:
        # 保存loss信息
        pinn.train(False)
        loss_res_1_valid, loss_res_2_valid, loss_res_3_valid, loss_res_4_valid, loss_res_5_valid, loss_ics_valid  = pinn(X_res, X_ics,u_ics)
        loss_valid = loss_res_1_valid + loss_res_2_valid + loss_res_3_valid + loss_res_4_valid + loss_res_4_valid + loss_ics_valid
#         loss_valid = loss_res_1_valid + loss_res_2_valid + loss_res_3_valid + loss_res_4_valid + loss_res_4_valid 
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res_1"].append(loss_res_1_valid.item())
        logger["loss_res_2"].append(loss_res_2_valid.item())
        logger["loss_res_3"].append(loss_res_3_valid.item())
        logger["loss_res_4"].append(loss_res_4_valid.item())
        logger["loss_res_5"].append(loss_res_5_valid.item())
        logger["loss_ics"].append(loss_ics_valid.item())
        logger["iter"].append(it+1)
        
        # 保存训练loss最低的模型
        if loss_valid.item() < best_loss:
            model_state = {'iter': it+1, 'backbone_state': pinn.state_dict()}
            torch.save(model_state, os.path.join(model_path, 'pinn_adam.pth'))
            best_loss = loss_valid.item()
        
        if (it + 1) % 500 == 0:
            # 保存并打印训练日志
            info = f'Iter # {it+1:6d}/{adam_iters}\t' + \
                f'loss:{loss.item():.2e}, loss_r_1:{loss_res_1.item():.2e}, loss_r_2:{loss_res_2.item():.2e}, loss_r_3:{loss_res_3.item():.2e},loss_r_4:{loss_res_4.item():.2e},loss_r_5:{loss_res_5.item():.2e} loss_i:{loss_ics.item():.2e}  ' + \
                f'Valid # loss:{loss_valid.item():.2e}, loss_r:{loss_res_1_valid.item():.2e}, loss_i:{loss_ics_valid.item():.2e}'
            with open(train_info_path + 'train_info.txt', 'a') as f:
                f.write(info + '\n')
            print(info)
            
        # 衰减学习率
        if (it + 1) % 4000 == 0:
            lr_sche.step()
#             lr_sche_lam.step()
# Out:
# Iter #    500/40000	loss:5.79e+04, loss_r_1:1.77e-05, loss_r_2:1.19e-01, loss_r_3:4.98e-03,loss_r_4:5.01e+02,loss_r_5:7.11e+01 loss_i:6.12e-01  Valid # loss:1.00e+03, loss_r:1.77e-05, loss_i:6.21e-01
# Iter #   1000/40000	loss:3.89e+04, loss_r_1:1.76e-05, loss_r_2:1.18e-01, loss_r_3:4.99e-03,loss_r_4:3.66e+02,loss_r_5:5.47e+00 loss_i:1.57e+00  Valid # loss:7.34e+02, loss_r:1.76e-05, loss_i:1.57e+00
# Iter #   1500/40000	loss:2.59e+04, loss_r_1:1.76e-05, loss_r_2:1.18e-01, loss_r_3:5.00e-03,loss_r_4:2.37e+02,loss_r_5:4.46e+00 loss_i:1.65e+00  Valid # loss:4.75e+02, loss_r:1.76e-05, loss_i:1.65e+00
# Iter #   2000/40000	loss:1.56e+04, loss_r_1:1.74e-05, loss_r_2:1.17e-01, loss_r_3:5.00e-03,loss_r_4:1.34e+02,loss_r_5:3.65e+00 loss_i:1.71e+00  Valid # loss:2.70e+02, loss_r:1.74e-05, loss_i:1.71e+00
# Iter #   2500/40000	loss:9.15e+03, loss_r_1:1.71e-05, loss_r_2:1.15e-01, loss_r_3:5.00e-03,loss_r_4:6.98e+01,loss_r_5:3.04e+00 loss_i:1.75e+00  Valid # loss:1.41e+02, loss_r:1.71e-05, loss_i:1.75e+00
# Iter #   3000/40000	loss:6.21e+03, loss_r_1:1.66e-05, loss_r_2:1.12e-01, loss_r_3:5.00e-03,loss_r_4:4.09e+01,loss_r_5:2.54e+00 loss_i:1.75e+00  Valid # loss:1.07e+02, loss_r:1.65e-05, loss_i:1.75e+00
# Iter #   3500/40000	loss:1.47e+04, loss_r_1:3.72e-05, loss_r_2:2.30e-01, loss_r_3:9.83e-04,loss_r_4:1.27e+02,loss_r_5:1.91e+00 loss_i:1.54e+00  Valid # loss:2.56e+02, loss_r:3.72e-05, loss_i:1.54e+00
# Iter #   4000/40000	loss:8.97e+03, loss_r_1:3.69e-05, loss_r_2:2.28e-01, loss_r_3:9.74e-04,loss_r_4:7.08e+01,loss_r_5:1.95e+00 loss_i:1.47e+00  Valid # loss:1.43e+02, loss_r:3.69e-05, loss_i:1.47e+00
# Iter #  36500/40000	loss:5.81e+01, loss_r_1:9.55e-06, loss_r_2:5.57e-02, loss_r_3:1.05e-04,loss_r_4:2.05e-02,loss_r_5:1.63e-03 loss_i:1.43e-04  Valid # loss:9.76e-02, loss_r:9.55e-06, loss_i:1.43e-04
# Iter #  37000/40000	loss:5.79e+01, loss_r_1:9.54e-06, loss_r_2:5.57e-02, loss_r_3:1.05e-04,loss_r_4:1.94e-02,loss_r_5:1.32e-03 loss_i:1.36e-04  Valid # loss:9.52e-02, loss_r:9.54e-06, loss_i:1.36e-04
# Iter #  37500/40000	loss:5.98e+01, loss_r_1:9.43e-06, loss_r_2:5.49e-02, loss_r_3:1.02e-04,loss_r_4:4.34e-02,loss_r_5:3.79e-03 loss_i:1.37e-04  Valid # loss:1.40e-01, loss_r:9.43e-06, loss_i:1.37e-04
# Iter #  38000/40000	loss:5.66e+01, loss_r_1:9.43e-06, loss_r_2:5.49e-02, loss_r_3:1.02e-04,loss_r_4:1.36e-02,loss_r_5:1.46e-03 loss_i:1.40e-04  Valid # loss:8.23e-02, loss_r:9.43e-06, loss_i:1.40e-04
# Iter #  38500/40000	loss:5.65e+01, loss_r_1:9.42e-06, loss_r_2:5.49e-02, loss_r_3:1.01e-04,loss_r_4:1.33e-02,loss_r_5:1.23e-03 loss_i:1.40e-04  Valid # loss:8.17e-02, loss_r:9.42e-06, loss_i:1.40e-04
# Iter #  39000/40000	loss:5.64e+01, loss_r_1:9.42e-06, loss_r_2:5.49e-02, loss_r_3:1.01e-04,loss_r_4:1.26e-02,loss_r_5:1.10e-03 loss_i:1.38e-04  Valid # loss:8.07e-02, loss_r:9.42e-06, loss_i:1.38e-04
# Iter #  39500/40000	loss:5.63e+01, loss_r_1:9.41e-06, loss_r_2:5.48e-02, loss_r_3:1.00e-04,loss_r_4:1.23e-02,loss_r_5:9.67e-04 loss_i:1.36e-04  Valid # loss:7.97e-02, loss_r:9.41e-06, loss_i:1.36e-04
# Iter #  40000/40000	loss:2.00e+02, loss_r_1:9.29e-06, loss_r_2:5.41e-02, loss_r_3:1.01e-04,loss_r_4:1.45e+00,loss_r_5:3.03e-03 loss_i:5.10e-04  Valid # loss:2.94e+00, loss_r:9.29e-06, loss_i:5.09e-04

# %%
np.save("./logger.npy", logger)
model_state
# Out:
# {'iter': 39700,
#  'backbone_state': OrderedDict([('backbone1.model.layer0.fc0.weight',
#                tensor([[ 0.1025],
#                        [ 0.4785],
#                        [ 0.4575],
#                        [-0.0513],
#                        [ 0.1325],
#                        [-0.0600],
#                        [-1.0075],
#                        [ 0.4089],
#                        [ 0.3291],
#                        [-0.0155],
#                        [ 1.0130],
#                        [ 0.9575],
#                        [ 0.5794],
#                        [-0.6595],
#                        [-0.5188],
#                        [-0.9628],
#                        [ 0.4590],
#                        [-0.2132],
#                        [ 0.6811],
#                        [-0.9803],
#                        [ 0.6739],
#                        [ 0.4468],
#                        [-0.6623],
#                        [-0.2956],
#                        [-0.7059],
#                        [ 0.8833],
#                        [-0.0220],
#                        [-0.1878],
#                        [ 0.4135],
#                        [-0.6772],
#                        [ 0.9649],
#                        [ 0.2624],
#                        [-0.9283],
#                        [-0.3863],
#                        [-0.3262],
#                        [-0.9460],
#                        [-0.4902],
#                        [ 0.0998],
#                        [ 0.6544],
#                        [-0.8745],
#                        [ 0.6533],
#                        [ 0.4372],
#                        [ 0.9134],
#                        [ 0.4586],
#                        [ 0.2898],
#                        [-0.8979],
#                        [-0.5973],
#                        [-0.1503],
#                        [ 0.7275],
#                        [ 0.4651],
#                        [ 0.8686],
#                        [ 0.4557],
#                        [-0.2364],
#                        [ 0.9740],
#                        [ 0.7611],
#                        [ 0.4405],
#                        [-0.1084],
#                        [ 0.0244],
#                        [ 0.2694],
#                        [ 0.0106],
#                        [ 0.4424],
#                        [ 0.5379],
#                        [-0.4175],
#                        [ 0.9686]])),
#               ('backbone1.model.layer0.fc0.bias',
#                tensor([ 0.4660,  0.3984,  0.2326, -0.8397, -0.6175,  0.0239,  0.8933,  0.2485,
#                         0.6337,  0.2688, -0.7663, -0.0755, -0.9399,  0.3820, -0.7778,  0.1675,
#                         0.1509,  0.6455, -0.5191,  0.7603,  0.3316,  0.5125,  0.1228,  0.9039,
#                        -0.1442, -0.3930, -0.7959, -0.7533, -0.2409, -0.6766,  0.2678,  0.6023,
#                         0.6973,  0.7668,  0.3527,  0.1877,  0.3694, -0.2816,  0.4759,  0.7254,
#                         0.5165,  0.5404, -0.8788,  0.2771, -0.8850,  0.5010,  0.6804,  0.8410,
#                         0.1537,  0.6319, -0.2606,  0.3374, -0.6699, -0.4366, -0.7826,  0.5429,
#                        -0.1186, -0.4026,  0.4035,  0.9695,  0.5874,  0.2947,  0.4416,  0.3992])),
#               ('backbone1.model.layer1.fc1.weight',
#                tensor([[-0.0671, -0.1059, -0.0112,  ..., -0.0523,  0.0837, -0.1038],
#                        [ 0.0822,  0.1112,  0.0074,  ...,  0.0016,  0.0491, -0.1109],
#                        [-0.0770,  0.1079,  0.1008,  ..., -0.0615, -0.0861, -0.0512],
#                        ...,
#                        [-0.0218,  0.0934,  0.1045,  ...,  0.0543, -0.0767, -0.0226],
#                        [-0.0463,  0.0342, -0.0783,  ...,  0.0799,  0.0133,  0.0538],
#                        [-0.0081, -0.1089,  0.0841,  ...,  0.0669,  0.0821, -0.1150]])),
#               ('backbone1.model.layer1.fc1.bias',
#                tensor([ 0.0831, -0.0038,  0.0555, -0.0646, -0.0977,  0.0247, -0.0064, -0.0477,
#                        -0.0761,  0.1016,  0.0560, -0.0577,  0.0211,  0.0333, -0.1123, -0.0535,
#                        -0.0551, -0.0542, -0.0213, -0.0205, -0.0899, -0.0143,  0.0894,  0.0467,
#                         0.0801, -0.1264,  0.0470, -0.1025,  0.0831,  0.0353, -0.0003, -0.1267,
#                         0.0317, -0.1165,  0.0555,  0.0011, -0.0975,  0.0719, -0.0265,  0.0588,
#                        -0.0673, -0.1038, -0.0400,  0.0350,  0.0936, -0.0908, -0.0978, -0.0863,
#                         0.0957,  0.0967, -0.0227,  0.0784, -0.0769,  0.1229, -0.0848,  0.0539,
#                         0.0090, -0.0049,  0.1072,  0.0548,  0.0474,  0.0051, -0.0679, -0.1247])),
#               ('backbone1.model.layer2.fc2.weight',
#                tensor([[-0.0790, -0.0696,  0.0135,  ..., -0.0667,  0.0404,  0.1131],
#                        [-0.0789, -0.1139, -0.0902,  ..., -0.1018, -0.0046, -0.1029],
#                        [ 0.1040, -0.0089, -0.0719,  ..., -0.0868, -0.0300, -0.0211],
#                        ...,
#                        [-0.0118,  0.0624,  0.0985,  ...,  0.0083,  0.1159, -0.1054],
#                        [ 0.0986, -0.0048,  0.0413,  ...,  0.0850,  0.0500, -0.1118],
#                        [-0.0463, -0.0923, -0.0262,  ...,  0.0559,  0.0489, -0.0179]])),
#               ('backbone1.model.layer2.fc2.bias',
#                tensor([-0.0849,  0.0773,  0.0905,  0.0676, -0.0265, -0.0594,  0.0388, -0.0274,
#                         0.0413,  0.0559, -0.0872, -0.0672,  0.0647,  0.0400, -0.0231,  0.0650,
#                         0.0289, -0.0032, -0.0080, -0.0272, -0.0360,  0.0917, -0.0005, -0.1062,
#                         0.0929, -0.0517,  0.0040,  0.0624,  0.0859,  0.1029,  0.0376, -0.0482,
#                         0.0872, -0.0510,  0.0626, -0.0345,  0.0294,  0.1209, -0.0259,  0.0943,
#                         0.0436, -0.0284, -0.0720,  0.0165, -0.0586,  0.0054, -0.0890, -0.1103,
#                        -0.1048,  0.0522,  0.0114,  0.1077, -0.0334,  0.0382, -0.0936,  0.0959,
#                        -0.0776, -0.0881, -0.0854, -0.0949,  0.0927,  0.0339, -0.1277,  0.0399])),
#               ('backbone1.model.layer3.fc3.weight',
#                tensor([[-0.0908, -0.0387, -0.0035,  ...,  0.1052,  0.0648,  0.0310],
#                        [ 0.0761, -0.0368,  0.0132,  ..., -0.0585,  0.0754, -0.0230],
#                        [ 0.0934,  0.0464, -0.0445,  ...,  0.0692,  0.0062,  0.0629],
#                        ...,
#                        [-0.0385,  0.0019, -0.0601,  ..., -0.0081, -0.0395,  0.0422],
#                        [-0.0891,  0.1020,  0.0611,  ...,  0.0997, -0.0700, -0.0144],
#                        [ 0.0024, -0.0769,  0.0642,  ...,  0.0596,  0.0565, -0.0028]])),
#               ('backbone1.model.layer3.fc3.bias',
#                tensor([-0.0394, -0.0300,  0.0181,  0.0830,  0.0630, -0.1096, -0.0341, -0.0821,
#                         0.0023,  0.0640, -0.1095, -0.0032, -0.0531,  0.1105,  0.0738,  0.0539,
#                         0.0032, -0.1125, -0.0436, -0.0066, -0.0440, -0.0189,  0.0319,  0.0678,
#                         0.0808,  0.0906,  0.0193, -0.0682, -0.0922,  0.0244, -0.0030,  0.0354,
#                         0.0241, -0.0528, -0.0793, -0.0617, -0.0070, -0.0763,  0.1289,  0.0732,
#                        -0.0403,  0.1011,  0.0579,  0.0651,  0.0819, -0.0720, -0.0795, -0.0556,
#                        -0.0099,  0.0054, -0.0368,  0.0991,  0.0744, -0.1017, -0.0590,  0.0076,
#                        -0.0802, -0.0737, -0.0951,  0.0541,  0.0452, -0.0791,  0.1060, -0.1040])),
#               ('backbone1.model.layer4.fc4.weight',
#                tensor([[-0.0883, -0.0566, -0.0425,  ..., -0.0242,  0.0592,  0.1022],
#                        [ 0.0519, -0.0475, -0.0667,  ...,  0.1012, -0.0742, -0.0476],
#                        [-0.0369, -0.0316,  0.0310,  ..., -0.0482,  0.1406, -0.0188],
#                        ...,
#                        [ 0.0095, -0.0702,  0.0708,  ...,  0.0499,  0.0096,  0.0705],
#                        [-0.0261, -0.0941,  0.0998,  ...,  0.0115,  0.0268,  0.1071],
#                        [ 0.0639,  0.0929, -0.0095,  ...,  0.0942, -0.1040,  0.1045]])),
#               ('backbone1.model.layer4.fc4.bias',
#                tensor([-0.0135,  0.0922, -0.0671, -0.0834,  0.0278,  0.0792,  0.0310,  0.0475,
#                         0.0494, -0.0462,  0.0975, -0.0424, -0.0145,  0.0267,  0.0038, -0.0555,
#                        -0.1104, -0.0251, -0.0136,  0.0480,  0.0076,  0.0311,  0.0778,  0.0337,
#                        -0.0436,  0.0373,  0.0825, -0.0899,  0.0895, -0.0275, -0.0069, -0.0982,
#                         0.0144,  0.0162, -0.0177, -0.0768,  0.0063,  0.0913, -0.0034,  0.0564,
#                         0.0080, -0.0890,  0.0627, -0.0934, -0.0674, -0.0331, -0.0037,  0.0595,
#                         0.0130,  0.0202, -0.0130, -0.0916, -0.1034,  0.0599, -0.0106,  0.0335,
#                        -0.0563, -0.0552,  0.0946,  0.0708,  0.0459,  0.0735,  0.0623,  0.0693])),
#               ('backbone1.model.layer5.fc5.weight',
#                tensor([[-9.1345e-02,  7.6065e-02,  7.2602e-02,  ..., -1.1786e-01,
#                          9.5948e-02,  3.1208e-02],
#                        [-4.0526e-02, -7.3212e-02,  3.0724e-02,  ..., -8.0540e-02,
#                         -4.5224e-02,  1.1405e-01],
#                        [ 1.2780e-01, -8.6519e-02, -5.1262e-02,  ...,  8.7395e-02,
#                         -4.9926e-02, -4.8624e-02],
#                        ...,
#                        [-8.4622e-02,  1.2070e-01, -4.2327e-02,  ...,  5.8493e-03,
#                         -7.1600e-03,  1.1492e-02],
#                        [ 1.1702e-04, -5.6296e-04,  1.1455e-01,  ..., -8.3515e-02,
#                          7.6855e-02,  1.0284e-01],
#                        [ 6.8522e-02, -5.2916e-02, -8.7204e-02,  ..., -3.1616e-02,
#                         -9.3429e-02, -1.1495e-01]])),
#               ('backbone1.model.layer5.fc5.bias',
#                tensor([ 5.1763e-04, -6.7778e-04,  1.6458e-02, -1.1050e-01,  2.8064e-04,
#                        -8.2069e-02,  1.8412e-02, -2.2978e-02, -2.6654e-02, -1.5490e-02,
#                        -1.4714e-04,  9.9045e-02, -7.4567e-02, -6.7705e-02,  1.2488e-02,
#                        -8.0923e-02,  6.3650e-02,  1.1055e-01,  3.1237e-03,  4.8875e-04,
#                        -9.3608e-04, -6.2716e-02,  6.9266e-03,  5.6485e-02,  4.9319e-02,
#                        -6.9881e-02,  8.2482e-02, -1.0428e-01, -2.7184e-02, -6.7879e-02,
#                        [ 7.1412e-01],
#                        [ 1.7037e-01],
#                        [-4.6033e-01],
#                        [-5.0312e-01],
#                        [-6.7434e-04],
#                        [ 2.3263e-01],
#                        [-7.2971e-01],
#                        [-8.2200e-01],
#                        [ 6.3988e-01],
#                        [ 2.8911e-01],
#                        [ 9.2851e-01],
#                        [-1.0729e-01],
#                        [ 7.9379e-01],
#                        [ 2.5796e-02],
#                        [ 9.2029e-01],
#                        [-7.3085e-01],
#                        [ 6.0880e-01],
#                        [ 1.4440e-01],
#                        [-5.8553e-01],
#                        [ 4.2540e-01],
#                        [ 4.0821e-01],
#                        [ 9.2158e-01],
#                        [-6.4926e-01],
#                        [-2.7752e-01],
#                        [-5.0610e-01],
#                        [-7.8035e-01],
#                        [ 8.6662e-02],
#                        [-1.0559e-02],
#                        [ 2.4751e-01],
#                        [ 8.1077e-01]])),
#               ('backbone2.model.layer0.fc0.bias',
#                tensor([-0.1977,  0.9511,  0.7935, -0.4421, -0.7807, -0.7143,  0.3917,  0.9001,
#                        -0.4295, -0.8743,  0.8236, -0.0028,  0.0503, -0.8255, -0.6515,  0.2335,
#                         0.6479,  0.4766,  0.6808,  0.0891, -0.2989, -0.6898, -0.8027,  0.4667,
#                        -0.1722, -0.4272, -0.6812,  0.5436, -0.7330, -0.1489, -0.8912,  0.8728,
#                        -0.8435, -0.8343,  0.7334, -0.0714,  0.4873,  0.3831,  0.4812, -0.0903,
#                        -0.3061, -0.1659, -0.1425, -0.2299,  0.7566,  0.8434, -0.7712, -0.2892,
#                        -0.7429,  0.5998,  0.0780, -0.4653,  0.4092, -0.3744, -0.3980,  0.5925,
#                         0.9797,  0.2761,  0.9126,  0.3815,  0.1528, -0.4261,  0.7952, -0.0055])),
#               ('backbone2.model.layer1.fc1.weight',
#                tensor([[-0.1146,  0.0112, -0.0749,  ..., -0.0551, -0.1121,  0.0149],
#                        [ 0.0369,  0.0847, -0.0016,  ...,  0.0832,  0.1210, -0.0911],
#                        [-0.0028,  0.0510,  0.0008,  ...,  0.0259, -0.0252, -0.0541],
#                        ...,
#                        [-0.0190,  0.0792, -0.0780,  ...,  0.0430, -0.0575, -0.0129],
#                        [-0.0111, -0.0574, -0.0444,  ..., -0.0425, -0.0188,  0.0921],
#                        [-0.1173,  0.0628,  0.1067,  ...,  0.1169, -0.0633, -0.1157]])),
#               ('backbone2.model.layer1.fc1.bias',
#                tensor([-0.1162, -0.0924,  0.0342,  0.0324, -0.0744, -0.0854,  0.1137,  0.0566,
#                        -0.0627, -0.0603,  0.0840, -0.0302,  0.0659,  0.0546, -0.0363, -0.0726,
#                         0.0142, -0.0024,  0.0453,  0.0468, -0.0380,  0.0783, -0.1242,  0.0798,
#                         0.0046,  0.0505,  0.0490, -0.0901,  0.0120, -0.0652,  0.0858, -0.0589,
#                        -0.1301, -0.0426, -0.1124, -0.0287, -0.0565,  0.0489, -0.0943, -0.0519,
#                        -0.1201,  0.0683, -0.0380,  0.0892, -0.0564, -0.0657, -0.1235, -0.0199,
#                         0.0660,  0.0511,  0.0180,  0.0499, -0.0147, -0.0785,  0.0046,  0.0973,
#                        -0.0440,  0.0634, -0.0770, -0.0882,  0.0206,  0.0206, -0.0332,  0.0665])),
#               ('backbone2.model.layer2.fc2.weight',
#                tensor([[ 0.0454,  0.0026,  0.0874,  ..., -0.0506, -0.0523, -0.0640],
#                        [ 0.0294,  0.0993, -0.0648,  ...,  0.0406,  0.0102,  0.0118],
#                        [-0.0266,  0.0712,  0.0203,  ...,  0.1003,  0.0924,  0.0534],
#                        ...,
#                        [-0.0210, -0.0830,  0.1140,  ...,  0.0567,  0.0124, -0.0359],
#                        [ 0.0479,  0.0383, -0.0838,  ...,  0.0705,  0.0184, -0.0123],
#                        [ 0.0991, -0.0950, -0.0507,  ..., -0.0840, -0.0239,  0.0149]])),
#               ('backbone2.model.layer2.fc2.bias',
#                tensor([-0.0846,  0.0857,  0.0258, -0.0826, -0.1011, -0.1243, -0.0134,  0.0914,
#                         0.0346,  0.0211, -0.0284, -0.1115, -0.0465, -0.0536,  0.0077, -0.0947,
#                         0.1366,  0.0439,  0.0488, -0.0636,  0.0410,  0.0017, -0.0404,  0.0387,
#                         0.0715, -0.0695, -0.0092, -0.0194,  0.1053,  0.0796,  0.0064, -0.0648,
#                        -0.0315, -0.0370, -0.0159, -0.0138,  0.0121, -0.0536, -0.0939,  0.0972,
#                        -0.0322,  0.0490,  0.0239,  0.0870,  0.0545, -0.0594,  0.0787, -0.0920,
#                         0.0823, -0.0431, -0.0412, -0.1090,  0.0218,  0.0448,  0.0749, -0.0526,
#                        -0.0671,  0.0281, -0.0649, -0.0798, -0.1018, -0.0189,  0.1022,  0.0150])),
#               ('backbone2.model.layer3.fc3.weight',
#                tensor([[ 0.0113,  0.0288, -0.0522,  ..., -0.0719,  0.0534, -0.0032],
#                        [-0.0073, -0.0240, -0.0429,  ...,  0.0671,  0.0762, -0.0845],
#                        [ 0.0088,  0.1104, -0.0404,  ..., -0.0179, -0.0932, -0.1006],
#                        ...,
#                        [-0.1100,  0.1085, -0.0410,  ..., -0.0286,  0.0979,  0.0540],
#                        [ 0.0675, -0.0141,  0.0318,  ...,  0.0906,  0.1127, -0.0222],
#                        [-0.0921, -0.0808,  0.0852,  ...,  0.0514,  0.0978, -0.0463]])),
#               ('backbone2.model.layer3.fc3.bias',
#                tensor([-0.0086,  0.0488, -0.0772, -0.0779, -0.0479, -0.0624,  0.0327, -0.0248,
#                         0.0327, -0.0281,  0.0780, -0.0663,  0.0444,  0.1180, -0.0151,  0.0278,
#                         0.0946,  0.0201,  0.0618, -0.0147, -0.0611, -0.0717, -0.0766,  0.0618,
#                         0.0486,  0.1088,  0.0801,  0.1155,  0.1063,  0.0679, -0.0006, -0.0504,
#                        -0.0730, -0.0558, -0.0050, -0.0784,  0.1010,  0.1045, -0.0139, -0.0460,
#                         0.0410,  0.0685,  0.0955, -0.0884, -0.0743,  0.1101, -0.0620, -0.0336,
#                        -0.1135,  0.0088,  0.0987, -0.0567,  0.0137,  0.0123, -0.0499,  0.0853,
#                        -0.0392,  0.0765,  0.0867, -0.0202, -0.0023, -0.0086, -0.1080, -0.0096])),
#               ('backbone2.model.layer4.fc4.weight',
#                tensor([[-0.0705,  0.1007,  0.1415,  ...,  0.0059, -0.0886,  0.0302],
#                        [-0.0918, -0.0058, -0.0852,  ..., -0.0913, -0.0483,  0.0877],
#                        [ 0.1082,  0.0952,  0.0730,  ..., -0.0511,  0.0018, -0.0519],
#                        ...,
#                        [-0.0210, -0.0944, -0.1267,  ...,  0.0515, -0.0751,  0.0002],
#                        [ 0.0530,  0.0972, -0.0802,  ..., -0.1268, -0.0485, -0.0993],
#                        [ 0.0204, -0.0241,  0.0792,  ..., -0.0313,  0.0872,  0.0662]])),
#               ('backbone2.model.layer4.fc4.bias',
#                tensor([ 0.0566, -0.0160, -0.0151, -0.0318, -0.0173, -0.0008,  0.0853,  0.0167,
#                         0.0961,  0.0536,  0.0150, -0.0326, -0.0938,  0.0784, -0.0086, -0.0198,
#                        -0.0284, -0.0023, -0.0887, -0.0537, -0.0371, -0.0393, -0.0687, -0.0427,
#                         0.0550, -0.0744,  0.0314, -0.0922, -0.0293, -0.0846, -0.0557, -0.0718,
#                        -0.0732, -0.0508,  0.0893, -0.0799,  0.0840,  0.0663,  0.0211,  0.0169,
#                         0.0157, -0.0896, -0.0268,  0.0473,  0.0818,  0.0157,  0.0386,  0.0425,
#                         0.0677, -0.0377, -0.0629, -0.0620,  0.0778,  0.0556, -0.0529,  0.0315,
#                        -0.0458,  0.0968, -0.0684, -0.0761,  0.0443, -0.0601, -0.0619,  0.0643])),
#               ('backbone2.model.layer5.fc5.weight',
#                tensor([[-0.0164, -0.0886,  0.0878,  ..., -0.0050,  0.1096, -0.0321],
#                        [ 0.0127, -0.1129,  0.0919,  ..., -0.0098, -0.0344,  0.1240],
#                        [-0.0863,  0.0854, -0.0616,  ...,  0.1162,  0.0744, -0.1057],
#                        ...,
#                        [ 0.0375,  0.0739,  0.1062,  ...,  0.0675,  0.0039,  0.0787],
#                        [ 0.1081,  0.0031, -0.0752,  ...,  0.1067, -0.0301,  0.0622],
#                        [-0.0661,  0.0853,  0.0883,  ...,  0.0199, -0.0512, -0.1128]])),
#               ('backbone2.model.layer5.fc5.bias',
#                tensor([-0.0253, -0.0028,  0.1073, -0.0707,  0.0003,  0.0882,  0.0914, -0.0640,
#                         0.1177, -0.0003, -0.0624,  0.0017,  0.1212, -0.0284,  0.0258, -0.0299,
#                        -0.0520, -0.0550, -0.1193,  0.0015, -0.0009,  0.0741,  0.0136,  0.1108,
#                        -0.0987, -0.0587, -0.0089, -0.0179, -0.0395,  0.0837, -0.0148,  0.1178,
#                        -0.0503, -0.0366,  0.0474, -0.1034,  0.0187, -0.1111,  0.0937,  0.0507,
#                        -0.0008, -0.0341, -0.0613, -0.0594,  0.0450,  0.0672,  0.0592,  0.0001,
#                        -0.0432,  0.0321,  0.0434, -0.0810, -0.0312,  0.1042, -0.0447, -0.0724,
#                         0.0578, -0.0511,  0.0816,  0.0387,  0.0589,  0.0069, -0.0003, -0.0434])),
#               ('backbone2.model.layer6.fc6.weight',
#                tensor([[ 1.5201e-02, -1.2876e-03,  3.0161e-02, -4.1086e-02, -2.4093e-04,
#                          6.4126e-03,  1.0692e-01, -9.0802e-02, -3.4184e-02,  7.8656e-05,
#                         -1.5517e-02,  2.2923e-02, -7.6264e-02,  5.6916e-02,  8.3778e-02,
#                         -3.9873e-02,  4.4055e-02,  9.7900e-02, -9.5789e-02,  3.6325e-04,
#                         -3.8759e-02,  7.4521e-02, -1.9104e-02,  6.4295e-02, -3.9767e-02,
#                          7.6115e-03, -3.5177e-03, -4.5247e-02, -7.0269e-02, -7.1802e-02,
#                         -5.3236e-02, -3.2523e-02, -9.5030e-02, -4.9546e-03, -3.7805e-02,
#                          1.1248e-01,  7.3905e-02,  1.0991e-01,  8.9364e-02, -5.1668e-02,
#                         -6.3612e-05, -3.3385e-02, -2.5729e-02, -2.2723e-02,  3.3692e-02,
#                         -1.0168e-01,  9.9259e-02, -8.0486e-05, -4.7835e-02,  9.4022e-02,
#                         -1.3220e-03, -5.9095e-02,  2.4024e-02, -1.1282e-01,  6.3024e-02,
#                          4.2351e-02, -8.1287e-02,  7.3151e-02,  2.9794e-02, -3.1195e-02,
#                          6.7073e-02,  6.5796e-02, -1.3933e-04,  5.3752e-02]])),
#               ('backbone3.model.layer0.fc0.weight',
#                tensor([[ 0.4821],
#                        [-0.2314],
#                        [ 0.8465],
#                        [ 0.0714],
#                        [-0.8252],
#                        [-0.4308],
#                        [-0.9033],
#                        [ 0.0369],
#                        [ 0.6877],
#                        [ 0.1540],
#                        [ 0.3229],
#                        [-0.8118],
#                        [ 0.2044],
#                        [-0.3907],
#                        [ 0.3880],
#                        [ 0.2728],
#                        [ 0.5735],
#                        [-0.5506],
#                        [-0.6915],
#                        [-0.7127],
#                        [ 0.7322],
#                        [ 0.4911],
#                        [-0.7870],
#                        [ 0.2558],
#                        [-0.1325],
#                        [ 0.2948],
#                        [ 0.3738],
#                        [-0.3924],
#                        [ 0.5393],
#                        [-0.4328],
#                        [-0.5614],
#                        [-0.7305],
#                        [ 0.7575],
#                        [-0.4580],
#                        [ 0.5954],
#                        [ 0.3046],
#                        [ 0.4876],
#                        [-0.5060],
#                        [-0.7664],
#                        [-0.3192],
#                        [-0.7137],
#                        [-0.7500],
#                        [ 0.6649],
#                        [ 0.0532],
#                        [-0.0873],
#                        [ 0.4276],
#                        [ 0.1055],
#                        [-0.8453],
#                        [ 0.7691],
#                        [ 0.1257],
#                        [-0.1754],
#                        [ 0.8555],
#                        [-0.8952],
#                        [ 0.8089],
#                        [ 0.7631],
#                        [ 0.2993],
#                        [ 0.6469],
#                        [-0.6371],
#                        [ 0.8967],
#                        [ 0.1361],
#                        [ 0.3909],
#                        [ 0.7642],
#                        [-0.8808],
#                        [ 0.1538]])),
#               ('backbone3.model.layer0.fc0.bias',
#                tensor([-0.0543,  0.5588, -0.9653,  0.1201,  0.3384,  0.5791,  0.1819, -0.0283,
#                        -0.7458,  0.1942,  0.3050, -0.3824, -0.1567,  0.8637,  0.9401, -0.3616,
#                        -0.7908,  0.2870, -0.2604,  0.0795,  0.9137,  0.7309,  0.2293,  0.0820,
#                        -0.5957,  0.5507, -0.9236, -0.0782, -0.3101,  0.9448,  0.0977, -0.0913,
#                        -0.9153, -0.5621, -0.7611, -0.1079, -0.4702, -0.0719,  0.7679, -0.2999,
#                         0.4392, -0.7846,  0.3709, -0.3592,  0.7676, -0.4168,  0.2834, -0.7073,
#                         0.3285,  0.8813,  0.7687, -0.6954,  0.3975, -0.1524,  0.8814, -0.6420,
#                        -0.0766,  0.1088,  0.7388,  0.5047,  0.6012, -0.5646, -0.3958,  0.0103])),
#               ('backbone3.model.layer1.fc1.weight',
#                tensor([[-0.1150,  0.0885, -0.0336,  ...,  0.0040, -0.0600,  0.0960],
#                        [-0.0460, -0.0870,  0.0581,  ..., -0.0028,  0.0092, -0.0114],
#                        [ 0.0133, -0.0808,  0.0978,  ...,  0.1122, -0.0670, -0.1201],
#                        ...,
#                        [ 0.1101,  0.0740, -0.0744,  ..., -0.1294,  0.0286,  0.0150],
#                        [ 0.1052,  0.0525, -0.0704,  ...,  0.1162,  0.0477,  0.0760],
#                        [ 0.0910,  0.0577,  0.1041,  ..., -0.0675,  0.0461, -0.1120]])),
#               ('backbone3.model.layer1.fc1.bias',
#                tensor([-0.0901,  0.1091, -0.0040, -0.0010,  0.0793,  0.0605, -0.0406, -0.0291,
#                         0.0304, -0.0852, -0.0290,  0.0550,  0.0727, -0.1121,  0.0455, -0.0892,
#                         0.0474, -0.0530, -0.0933,  0.0626, -0.0639,  0.0968,  0.0824, -0.0071,
#                        -0.0791, -0.1063,  0.0124, -0.0825, -0.0589,  0.0202,  0.0369, -0.0198,
#                        -0.0988,  0.0527, -0.0857,  0.0410,  0.1007, -0.0352,  0.0739, -0.0194,
#                        -0.0642,  0.0021,  0.1064, -0.1306, -0.0762,  0.0112, -0.1007, -0.0375,
#                        -0.1092,  0.0843, -0.0855,  0.1080, -0.0403,  0.0253,  0.0632, -0.1119,
#                        -0.0801, -0.0012, -0.0670, -0.0390,  0.0776, -0.0493,  0.0019,  0.1176])),
#               ('backbone3.model.layer2.fc2.weight',
#                tensor([[ 0.0131, -0.0384, -0.0556,  ...,  0.0621,  0.0662,  0.0291],
#                        [-0.0372, -0.0288, -0.0940,  ...,  0.0569, -0.0071,  0.0539],
#                        [-0.0651,  0.0003,  0.0286,  ..., -0.0881, -0.0085,  0.0571],
#                        ...,
#                        [ 0.0589,  0.0345,  0.0448,  ...,  0.0134,  0.0173, -0.0930],
#                        [ 0.0314, -0.0685,  0.0952,  ..., -0.0429,  0.0767,  0.0447],
#                        [-0.0493, -0.0479,  0.0186,  ...,  0.1138, -0.1035, -0.0632]])),
#               ('backbone3.model.layer2.fc2.bias',
#                tensor([-0.1211, -0.0519,  0.0123, -0.0624,  0.0366,  0.0691,  0.1037, -0.0299,
#                         0.0382, -0.0239,  0.0200, -0.0201, -0.0455, -0.0358,  0.0285,  0.0403,
#                         0.0406, -0.0335, -0.0295,  0.0877, -0.0252, -0.0535,  0.0875, -0.0760,
#                         0.1009, -0.0324, -0.0791,  0.0461, -0.0202,  0.0055, -0.0964, -0.0916,
#                        -0.0858,  0.0256, -0.1261,  0.0802,  0.0083,  0.0364,  0.0038,  0.0667,
#                         0.0445,  0.0352,  0.0191,  0.0270, -0.0980, -0.0254,  0.0150,  0.0686,
#                        -0.0496, -0.0875,  0.0954, -0.0303, -0.0778, -0.0336,  0.0202,  0.0660,
#                         0.0787,  0.0954,  0.0408, -0.0405,  0.0168,  0.0612, -0.0295,  0.0199])),
#               ('backbone3.model.layer3.fc3.weight',
#                tensor([[-0.0051, -0.1002,  0.1323,  ...,  0.0625,  0.0315, -0.0367],
#                        [-0.0774, -0.0605,  0.0694,  ...,  0.1206,  0.0637,  0.0656],
#                        [ 0.0727,  0.1349,  0.0661,  ..., -0.0606, -0.0194,  0.0013],
#                        ...,
#                        [-0.0191, -0.1036,  0.0443,  ..., -0.0548, -0.0294,  0.0516],
#                        [ 0.0272,  0.1060,  0.1158,  ..., -0.0527, -0.0297,  0.0573],
#                        [ 0.0269,  0.0795,  0.0890,  ..., -0.1032,  0.0386, -0.0777]])),
#               ('backbone3.model.layer3.fc3.bias',
#                tensor([-0.0815,  0.1035,  0.0122,  0.0629, -0.0488,  0.0142,  0.0182,  0.0103,
#                        -0.0047,  0.0430, -0.0053,  0.0900, -0.0108, -0.0392,  0.0455,  0.0254,
#                         0.0056, -0.0508,  0.0689,  0.0563, -0.1008,  0.0387, -0.0731, -0.0527,
#                        -0.0264, -0.0875,  0.1135,  0.0871, -0.0373,  0.0625,  0.0135,  0.0779,
#                        -0.0808, -0.0254, -0.0427,  0.0086, -0.0567, -0.0228, -0.1169,  0.0221,
#                        -0.1064, -0.0461,  0.0403, -0.0908, -0.0368, -0.0147,  0.0283, -0.0727,
#                        -0.0464,  0.0239, -0.1206,  0.0206,  0.0630,  0.0117,  0.0492, -0.0290,
#                        -0.0100,  0.0296,  0.1011, -0.0589, -0.0734,  0.0021,  0.0191, -0.0693])),
#               ('backbone3.model.layer4.fc4.weight',
#                tensor([[ 0.0087,  0.0761, -0.1144,  ..., -0.0119,  0.0260, -0.0628],
#                        [ 0.0639, -0.0632,  0.0566,  ..., -0.1360,  0.1085,  0.0050],
#                        [-0.0488,  0.0380,  0.0197,  ...,  0.0494, -0.0403, -0.0088],
#                        ...,
#                        [-0.1328, -0.0206, -0.0353,  ...,  0.0831, -0.0230,  0.0713],
#                        [ 0.0847, -0.0121, -0.0337,  ...,  0.0099, -0.0082,  0.0829],
#                        [-0.0072, -0.0015,  0.0816,  ..., -0.0499,  0.0823,  0.0102]])),
#               ('backbone3.model.layer4.fc4.bias',
#                tensor([ 0.0083,  0.0614, -0.0716, -0.0307, -0.0908,  0.0215, -0.0075,  0.0627,
#                         -2.8773e-02, -6.6384e-02,  5.4781e-02,  5.5236e-02, -7.0087e-02,
#                         -8.5277e-02, -2.2425e-02,  3.1716e-05,  7.3981e-02,  9.4672e-02,
#                          1.0140e-01,  6.9943e-02, -9.0019e-02,  6.1873e-02,  7.9285e-02,
#                          6.1850e-02,  1.0203e-01,  6.9901e-02, -2.7484e-04, -7.1447e-02,
#                          8.7237e-02,  1.9618e-02,  3.5486e-02, -2.3547e-03, -9.5352e-03,
#                         -5.8072e-02, -5.8000e-02,  2.0063e-04, -2.4741e-02, -5.5469e-03,
#                         -9.3532e-02, -5.1962e-02,  1.1234e-01, -4.2272e-04, -8.3461e-02,
#                         -6.3599e-02, -2.5735e-02,  5.6626e-03, -8.5863e-02, -5.6955e-02,
#                         -2.0271e-02,  7.6080e-02, -1.8386e-02,  3.7483e-02, -4.2407e-02,
#                         -7.1452e-02, -1.0441e-01, -3.8607e-04, -7.9073e-02]])),
#               ('backbone4.model.layer0.fc0.weight',
#                tensor([[-0.1853],
#                        [-0.7504],
#                        [ 0.0259],
#                        [-0.7991],
#                        [ 0.3200],
#                        [-0.0757],
#                        [ 0.3994],
#                        [ 0.7082],
#                        [ 0.6188],
#                        [ 0.4518],
#                        [-0.0206],
#                        [ 0.2321],
#                        [-0.1629],
#                        [ 0.3940],
#                        [ 0.2775],
#                        [-0.5989],
#                        [-0.9697],
#                        [-0.3451],
#                        [-0.6831],
#                        [-0.1317],
#                        [ 0.4110],
#                        [-0.1293],
#                        [-0.2789],
#                        [ 0.8323],
#                        [-0.1597],
#                        [ 0.7052],
#                        [ 0.5655],
#                        [-0.0138],
#                        [-0.2827],
#                        [ 0.8538],
#                        [ 0.5019],
#                        [-0.0568],
#                        [-0.6941],
#                        [ 0.6591],
#                        [-0.7409],
#                        [-0.8988],
#                        [ 0.4259],
#                        [ 0.9482],
#                        [-0.7992],
#                        [ 0.6729],
#                        [-0.2806],
#                        [-0.4667],
#                        [ 0.7904],
#                        [-0.5698],
#                        [-0.5367],
#                        [-0.6113],
#                        [-0.0641],
#                        [ 0.4442],
#                        [ 0.5362],
#                        [-0.0610],
#                        [-0.1586],
#                        [ 0.9513],
#                        [-0.8337],
#                        [ 0.7362],
#                        [-0.7277],
#                        [-0.3881],
#                        [ 0.7577],
#                        [ 0.4520],
#                        [ 0.3074],
#                        [ 0.7171],
#                        [ 0.5360],
#                        [-0.1803],
#                        [-0.6017],
#                        [ 0.4356]])),
#               ('backbone4.model.layer0.fc0.bias',
#                tensor([ 0.7196,  0.8496, -0.5484,  0.2030, -0.1852, -0.1083, -0.2385, -0.7010,
#                        -0.1031, -0.8362, -0.0901,  0.9444, -0.2588, -0.0669,  0.9556, -0.6782,
#                         0.7224,  0.7125, -0.0377,  0.0170,  0.3026, -0.2149,  0.4992,  0.3564,
#                         0.0868,  0.1219, -0.4241,  0.1000,  0.6821,  0.5273,  0.9176, -0.2329,
#                         0.6609,  0.3995,  0.2934, -0.1079,  0.1142, -0.9604, -0.7033,  0.6523,
#                         0.4063,  0.6672, -0.8355, -0.9444,  0.5883, -0.1885, -0.0551, -0.3629,
#                        -0.2025,  0.7956, -0.9140, -0.6647, -0.5015,  0.6035,  0.9729, -0.1695,
#                         0.6700, -0.4983,  0.0585, -0.6533, -0.5583,  0.5350, -0.9285, -0.7584])),
#               ('backbone4.model.layer1.fc1.weight',
#                tensor([[ 0.0960, -0.0308,  0.0406,  ..., -0.1059,  0.0619, -0.1312],
#                        [ 0.0764,  0.0487,  0.1179,  ...,  0.0416,  0.1310,  0.0468],
#                        [-0.1097,  0.0085, -0.0627,  ..., -0.0344,  0.0714, -0.1050],
#                        ...,
#                        [-0.0498, -0.0935, -0.0745,  ...,  0.1112, -0.1393, -0.0849],
#                        [-0.0633, -0.0836,  0.0367,  ...,  0.0647,  0.1215, -0.0685],
#                        [-0.1137, -0.0837,  0.1010,  ...,  0.1237, -0.0489,  0.0185]])),
#               ('backbone4.model.layer1.fc1.bias',
#                tensor([-0.0274, -0.0207,  0.0273, -0.0282,  0.0425, -0.1057, -0.0891,  0.0752,
#                        -0.0564,  0.0546, -0.0452,  0.0415, -0.0415, -0.0746,  0.0088,  0.1130,
#                         0.1036,  0.0772,  0.0442,  0.0445, -0.0950, -0.0470,  0.0991,  0.0516,
#                         0.0204, -0.0704, -0.1154,  0.0679,  0.0684, -0.0303,  0.1308,  0.0238,
#                        -0.1268, -0.0773,  0.0723, -0.0903,  0.0026, -0.0382,  0.0812, -0.1058,
#                        -0.0588,  0.0962,  0.0411, -0.0137,  0.0070, -0.0505,  0.1185,  0.0764,
#                        -0.0567, -0.1281,  0.0059,  0.0081,  0.0114, -0.0112, -0.1240, -0.0188,
#                        -0.1388,  0.0504,  0.0617,  0.0721, -0.0111, -0.0701, -0.0490,  0.0538])),
#               ('backbone4.model.layer2.fc2.weight',
#                tensor([[-0.0805,  0.1019, -0.0300,  ..., -0.0398, -0.0279,  0.0102],
#                        [ 0.0439,  0.1202,  0.1031,  ..., -0.0031,  0.0290,  0.0925],
#                        [ 0.0691,  0.0155,  0.0021,  ...,  0.0192, -0.0106,  0.1033],
#                        ...,
#                        [-0.0050,  0.0804, -0.0740,  ..., -0.0696,  0.0469,  0.0818],
#                        [ 0.0322,  0.0573,  0.1367,  ..., -0.0798, -0.0122,  0.0769],
#                        [-0.0509,  0.0444,  0.0858,  ...,  0.1124,  0.0543, -0.0835]])),
#               ('backbone4.model.layer2.fc2.bias',
#                tensor([-0.0727, -0.0568, -0.0002, -0.0132, -0.1397,  0.0553,  0.0557, -0.1046,
#                         0.0162, -0.0936, -0.0487,  0.0587, -0.1037,  0.0669,  0.0231,  0.1016,
#                        -0.0656,  0.0076, -0.0747,  0.1008, -0.0565,  0.0512, -0.0398,  0.0558,
#                        -0.0689, -0.0209,  0.0954,  0.0019, -0.0285, -0.0957, -0.0582, -0.1112,
#                        -0.0028,  0.0482,  0.0197, -0.0884,  0.1053,  0.1108,  0.0949, -0.0428,
#                         0.0066,  0.0771, -0.0165,  0.0443,  0.0187,  0.0350,  0.0440, -0.0938,
#                         0.0321, -0.0789, -0.1048, -0.0023, -0.0689, -0.0878, -0.1168, -0.0384,
#                        -0.0149,  0.0262,  0.0856,  0.0367,  0.0759, -0.0585, -0.0086,  0.0146])),
#               ('backbone4.model.layer3.fc3.weight',
#                tensor([[ 0.0205, -0.0889,  0.0344,  ...,  0.1079,  0.0728, -0.0894],
#                        [-0.0438, -0.0340,  0.0506,  ...,  0.0127, -0.1426,  0.0877],
#                        [-0.0247, -0.0456, -0.0798,  ..., -0.0453, -0.0967,  0.0098],
#                        ...,
#                        [ 0.0684,  0.1113,  0.0314,  ..., -0.0614,  0.0963, -0.0051],
#                        [ 0.0017, -0.0217, -0.0024,  ..., -0.0908, -0.0246, -0.0796],
#                        [ 0.1055,  0.0080,  0.0072,  ...,  0.0386, -0.0601, -0.1223]])),
#               ('backbone4.model.layer3.fc3.bias',
#                tensor([-8.6990e-02,  1.0330e-01, -2.9245e-02, -6.4535e-02, -6.9831e-02,
#                        -4.3621e-02,  2.4950e-03,  9.8748e-03, -1.1322e-01,  9.2151e-02,
#                         8.3593e-02, -1.0775e-01, -5.7889e-02,  1.0449e-01,  5.4449e-02,
#                        -1.9931e-02,  9.7624e-02,  2.6531e-02, -2.9602e-02, -1.9635e-02,
#                         9.9242e-02,  4.7959e-02, -9.2103e-05, -8.8286e-02,  9.2573e-02,
#                         2.7563e-02,  5.7472e-02, -1.2582e-02, -3.9068e-02,  4.5183e-02,
#                         1.0270e-01, -9.2558e-02, -6.7775e-02,  5.8430e-02,  1.2573e-02,
#                         1.1464e-01, -5.4411e-02,  2.7645e-02,  2.9357e-02, -2.3754e-02,
#                         5.8556e-02,  4.2209e-02,  5.4363e-04,  1.5190e-02,  3.7449e-02,
#                        -4.8437e-02, -1.6412e-02,  6.3601e-02, -1.0885e-01, -6.9544e-02,
#                         1.0347e-01, -6.6239e-02,  8.3342e-02,  1.8027e-03,  5.7824e-02,
#                         6.9427e-03, -3.5708e-02,  7.4661e-02, -4.6663e-02,  3.9659e-02,
#                         7.8954e-02, -1.1985e-01, -1.8415e-02, -4.1777e-02])),
#               ('backbone4.model.layer4.fc4.weight',
#                tensor([[ 0.0562, -0.0414,  0.0821,  ...,  0.0887,  0.0070, -0.0680],
#                        [ 0.1096,  0.0026, -0.0062,  ..., -0.1451, -0.0866,  0.0264],
#                        [-0.0949,  0.0996, -0.0482,  ..., -0.0101, -0.0558,  0.0026],
#                        ...,
#                        [ 0.0353,  0.1330, -0.0341,  ..., -0.0627, -0.0251, -0.1079],
#                        [-0.0917,  0.0025,  0.1152,  ...,  0.0371, -0.1011, -0.0446],
#                        [-0.0426, -0.1315, -0.0748,  ..., -0.0226,  0.0617,  0.0361]])),
#               ('backbone4.model.layer4.fc4.bias',
#                tensor([-0.0136, -0.0095,  0.0227,  0.0267, -0.0302, -0.0650, -0.0758,  0.0096,
#                         0.0674, -0.0846,  0.0392, -0.0229,  0.0656,  0.0702,  0.0019, -0.0755,
#                         0.0670, -0.0264,  0.0596,  0.0515, -0.0583, -0.0870,  0.0177, -0.0307,
#                         0.0286,  0.0895, -0.0476, -0.0340, -0.0721,  0.0542,  0.0016,  0.0451,
#                         0.0404, -0.0417, -0.1045, -0.0392,  0.0216, -0.0144, -0.0305, -0.0129,
#                         0.0581,  0.0157,  0.0636, -0.0304, -0.0049,  0.0540, -0.0466, -0.0088,
#                         0.0236, -0.0399,  0.0002,  0.0495,  0.0494, -0.0877,  0.0346, -0.0687,
#                        -0.1053,  0.0048, -0.0764,  0.0148,  0.0184, -0.0254, -0.0409,  0.0424])),
#               ('backbone4.model.layer5.fc5.weight',
#                tensor([[ 3.4327e-03, -1.3010e-01,  4.1586e-03,  ..., -1.0713e-01,
#                         -7.4911e-02,  1.1266e-01],
#                        [-1.8484e-02,  5.1865e-02, -1.5937e-02,  ..., -8.4267e-02,
#                         -1.1580e-01,  9.8783e-02],
#                        [ 1.1705e-01,  3.0522e-02,  7.7367e-02,  ...,  2.5241e-02,
#                         -1.0293e-01, -4.6461e-02],
#                        ...,
#                        [-1.1509e-04, -4.9454e-03,  6.4104e-02,  ..., -9.8978e-02,
#                          1.4650e-02, -2.0835e-02],
#                        [-3.6256e-02, -9.0284e-02, -5.0591e-02,  ...,  1.9121e-03,
#                          2.9500e-02, -9.2747e-02],
#                        [ 6.6017e-03, -1.7868e-02, -8.5653e-02,  ...,  6.5935e-02,
#                         -9.2502e-02, -6.3171e-02]])),
#               ('backbone4.model.layer5.fc5.bias',
#                tensor([-0.0795,  0.0165,  0.0521, -0.0288,  0.0912, -0.0878, -0.0260, -0.0080,
#                        -0.0365, -0.0223, -0.1073,  0.0496, -0.0502, -0.0829, -0.1194, -0.0405,
#                         0.0985,  0.1094,  0.0671,  0.0452,  0.1067, -0.0263,  0.0496, -0.0658,
#                        -0.0467,  0.0009, -0.0678, -0.1123, -0.0724, -0.1027,  0.1234, -0.0436,
#                         0.0356, -0.0023,  0.0419,  0.1114, -0.1122,  0.0854, -0.1209,  0.0614,
#                        -0.1046, -0.1192,  0.0506, -0.0234,  0.0793,  0.0008,  0.0141, -0.0764,
#                         0.0324, -0.1136, -0.0226, -0.1034, -0.0400,  0.0753,  0.0782, -0.1060,
#                         0.0210,  0.0009, -0.0629, -0.0154,  0.0360,  0.0407,  0.0176,  0.1107])),
#               ('backbone4.model.layer6.fc6.weight',
#                tensor([[ 4.8763e-02,  3.4219e-03,  2.2264e-02, -7.1576e-02, -9.4275e-02,
#                          1.2478e-02, -6.0240e-02,  9.9591e-03, -6.1995e-02,  7.1116e-02,
#                          1.0638e-02, -6.2684e-03,  8.4206e-03, -3.1557e-02, -1.0270e-01,
#                          4.7682e-03,  8.3007e-02, -1.9451e-02, -3.6849e-02, -1.0540e-02,
#                          6.1122e-02,  2.0219e-03, -7.1388e-02,  3.2426e-03,  4.1110e-03,
#                          4.2606e-04,  1.0866e-01, -9.0074e-02, -5.8183e-02, -6.2219e-02,
#                         -6.0770e-02,  6.5937e-02, -7.8770e-02, -1.4158e-04, -5.7445e-02,
#                         -3.3568e-02, -4.2166e-02, -4.5842e-02,  1.0097e-01,  1.6419e-02,
#                         -7.3710e-02, -7.4294e-02, -6.3139e-02,  2.6975e-03, -1.0471e-01,
#                         -3.6786e-05, -7.5184e-02, -5.3589e-02,  4.6318e-03,  6.3788e-02,
#                         -6.2138e-02,  8.8044e-02, -1.9835e-02,  5.1848e-02,  7.1045e-02,
#                         -8.4155e-02, -6.3232e-02, -8.4193e-05,  4.5961e-02,  8.5138e-02,
#                          6.3307e-02, -1.0650e-01, -5.4643e-02, -7.0821e-02]])),
#               ('backbone5.model.layer0.fc0.weight',
#                tensor([[ 0.3935],
#                        [ 0.2629],
#                        [ 0.2280],
#                        [-0.0018],
#                        [ 0.4199],
#                        [-0.8079],
#                        [-1.0722],
#                        [ 0.9723],
#                        [-1.0835],
#                        [-0.8622],
#                        [ 0.3166],
#                        [ 0.6342],
#                        [-1.2176],
#                        [-0.8900],
#                        [ 0.7667],
#                        [ 0.4858],
#                        [-0.2182],
#                        [ 0.1917],
#                        [-0.2101],
#                        [ 0.0611],
#                        [ 0.4178],
#                        [-0.6842],
#                        [ 0.4397],
#                        [ 0.7147],
#                        [-0.6625],
#                        [ 0.7109],
#                        [-0.1780],
#                        [ 0.0989],
#                        [ 0.0777],
#                        [ 0.2753],
#                        [-0.3146],
#                        [ 0.7012],
#                        [ 0.6773],
#                        [-0.2074],
#                        [-0.6658],
#                        [ 0.0942],
#                        [ 0.4113],
#                        [-0.5658],
#                        [ 0.6429],
#                        [-0.7729],
#                        [-1.1595],
#                        [-0.3779],
#                        [ 0.4494],
#                        [ 0.6024],
#                        [ 1.0887],
#                        [ 0.7172],
#                        [ 0.3054],
#                        [-0.2291],
#                        [-1.1036],
#                        [-0.4149],
#                        [-0.7858],
#                        [ 0.8286],
#                        [ 1.0517],
#                        [ 0.0436],
#                        [-0.8437],
#                        [ 0.3337],
#                        [-0.4913],
#                        [ 0.6932],
#                        [ 0.9074],
#                        [-0.5784],
#                        [-0.9486],
#                        [ 0.0517],
#                        [-0.4357],
#                        [ 0.6247]])),
#               ('backbone5.model.layer0.fc0.bias',
#                tensor([ 0.1350,  0.6784, -0.8773, -0.4268,  0.4512,  0.0953, -0.1719, -0.5645,
#                         0.6152,  0.0404, -0.3914,  0.2697, -0.0977, -0.4447, -0.5665, -0.3371,
#                        -0.4638, -0.2737,  0.0424, -0.7521, -0.2736, -0.8966,  0.3270,  0.6275,
#                        -0.0788,  0.2251,  0.2877, -0.7850, -0.8138,  0.5351,  0.0885,  0.4973,
#                        -0.2886, -0.4309, -0.2128,  0.7308, -0.7942,  0.5586, -0.1564, -0.5825,
#                        -0.7282, -0.4759,  0.8800, -0.6727, -0.2840,  0.2046,  0.7292,  0.4042,
#                        -0.5843,  0.8827,  0.8386,  0.2876,  0.7794,  0.3261,  0.3451,  0.5859,
#                        -0.3690, -0.5269, -0.5263, -0.6124,  0.2374, -0.4755, -0.4796, -0.5381])),
#               ('backbone5.model.layer1.fc1.weight',
#                tensor([[-0.0466,  0.0722, -0.0940,  ..., -0.1153,  0.0409,  0.0579],
#                        [ 0.0005, -0.0205, -0.1088,  ...,  0.0908,  0.1101, -0.1215],
#                        [-0.0338, -0.1196, -0.0718,  ..., -0.0246,  0.0341,  0.0696],
#                        ...,
#                        [-0.1026, -0.1207,  0.0605,  ...,  0.1023,  0.0253,  0.0514],
#                        [-0.0893,  0.0710,  0.0897,  ...,  0.0134, -0.0269, -0.0228],
#                        [ 0.1504, -0.0226,  0.0697,  ...,  0.0185,  0.0348,  0.0050]])),
#               ('backbone5.model.layer1.fc1.bias',
#                tensor([ 7.5404e-02,  1.0386e-01, -1.5958e-02,  2.8772e-05,  8.4643e-02,
#                        -1.2480e-01,  8.0709e-02,  3.5123e-02, -8.6761e-02,  8.3985e-02,
#                         1.2041e-02, -6.5733e-02, -7.9554e-02,  2.0505e-02, -8.9869e-02,
#                         2.6481e-02,  3.0865e-02,  4.9913e-02,  9.4025e-02, -2.4055e-02,
#                        -1.3140e-01, -9.7080e-02, -7.6922e-02,  6.9864e-02,  3.3926e-02,
#                         5.1900e-02, -3.0600e-02, -1.2185e-02, -2.9644e-02,  5.4116e-02,
#                         2.6161e-02,  1.4509e-01, -1.3001e-01, -2.4100e-02, -1.3462e-01,
#                        -7.9909e-03,  6.4755e-02,  7.3696e-02, -5.8736e-02, -6.1993e-02,
#                        -4.4850e-02,  7.9066e-02, -5.2990e-03, -9.5664e-02, -1.1917e-01,
#                         1.9730e-02,  5.5347e-03, -3.5860e-03, -6.8216e-02, -6.6359e-02,
#                        -5.5096e-02,  7.7145e-04, -4.0154e-02, -1.0540e-01, -5.2998e-02,
#                        -7.2631e-02, -1.0894e-01, -1.2184e-02, -7.0238e-02,  8.9532e-02,
#                        -8.3917e-02, -1.0811e-01,  1.2642e-01, -4.1718e-02])),
#               ('backbone5.model.layer2.fc2.weight',
#                tensor([[-0.0681, -0.0141,  0.0836,  ...,  0.0488,  0.0054, -0.1029],
#                        [ 0.0387,  0.0419,  0.1409,  ..., -0.0342, -0.0525,  0.0303],
#                        [-0.0330,  0.0904, -0.0056,  ...,  0.0229, -0.0666, -0.0427],
#                        ...,
#                        [-0.0641,  0.0936, -0.0397,  ..., -0.1186,  0.0172,  0.0179],
#                        [-0.0330,  0.0800, -0.0938,  ...,  0.0844,  0.1029, -0.0283],
#                        [-0.2104,  0.1115,  0.0723,  ..., -0.0883, -0.0952,  0.2390]])),
#               ('backbone5.model.layer2.fc2.bias',
#                tensor([-7.1260e-02, -5.1225e-02, -1.0381e-01,  1.0132e-01,  1.2319e-02,
#                         1.2720e-01, -5.0324e-02, -2.5482e-02, -1.0948e-02, -3.6486e-02,
#                         1.2050e-01, -2.4736e-02,  6.8420e-03,  1.2004e-02,  2.7470e-02,
#                         1.0786e-01,  2.9530e-02,  6.7023e-02, -1.4558e-01, -1.2633e-01,
#                         3.5451e-02, -6.5288e-02, -8.8391e-02,  6.3209e-02,  9.9838e-02,
#                        -1.3470e-01,  1.2252e-01, -5.0444e-02,  4.6526e-02,  3.8764e-02,
#                        -5.6310e-02, -4.6778e-03, -6.1543e-05,  1.0727e-01,  4.2856e-02,
#                         7.3138e-02,  1.6680e-02,  5.7577e-02, -2.1409e-02, -5.6772e-02,
#                        -1.1201e-01,  4.6946e-03, -1.2570e-01, -1.1489e-01, -1.1456e-02,
#                        -5.0595e-02, -6.2054e-02, -1.2132e-01, -5.4864e-02, -3.0028e-02,
#                        -1.0239e-01, -1.0399e-01, -5.1417e-02,  1.4562e-01, -1.1407e-01,
#                        -8.3832e-02,  6.8605e-02,  1.0521e-01, -1.0612e-01, -7.2364e-02,
#                        -5.2089e-02, -5.7542e-02,  1.0760e-01, -8.2842e-03])),
#               ('backbone5.model.layer3.fc3.weight',
#                tensor([[-0.0022,  0.1038, -0.0130,  ..., -0.1481,  0.0778,  0.0522],
#                        [ 0.0146,  0.0480, -0.0157,  ..., -0.0527, -0.0358,  0.0611],
#                        [-0.0669,  0.0127, -0.0988,  ..., -0.0132, -0.0873, -0.0396],
#                        ...,
#                        [-0.0793, -0.0091,  0.0049,  ..., -0.0390, -0.1146, -0.0697],
#                        [-0.0265, -0.0651,  0.0046,  ..., -0.0244, -0.1152,  0.0221],
#                        [ 0.0107, -0.1040, -0.0518,  ...,  0.1294, -0.0663,  0.0075]])),
#               ('backbone5.model.layer3.fc3.bias',
#                tensor([-0.0262,  0.0208, -0.0662, -0.1033,  0.1148, -0.0635, -0.0419, -0.0700,
#                        -0.0053,  0.0926,  0.0620, -0.1068, -0.0260, -0.0827, -0.1197, -0.0165,
#                        -0.0749,  0.0294, -0.1453,  0.0399, -0.0030, -0.0679, -0.0297,  0.0821,
#                        -0.0915, -0.1478,  0.0245, -0.0187,  0.1003, -0.1230, -0.0997, -0.0781,
#                        -0.0293,  0.0300, -0.0336,  0.0627,  0.0315, -0.0782, -0.0853, -0.0883,
#                        -0.0569,  0.0657,  0.0555, -0.1105,  0.0779,  0.0434,  0.0199,  0.0938,
#                         0.0237,  0.1188, -0.0098,  0.0632,  0.0637,  0.0404, -0.0075,  0.0856,
#                        -0.0513,  0.0439, -0.0785, -0.0557,  0.0599,  0.0035,  0.0700, -0.0077])),
#               ('backbone5.model.layer4.fc4.weight',
#                tensor([[ 0.0738,  0.0979, -0.0176,  ..., -0.0583, -0.0437, -0.1094],
#                        [-0.0677,  0.1101, -0.0150,  ..., -0.0458, -0.0582, -0.1020],
#                        [-0.2022,  0.0206,  0.1235,  ...,  0.0412,  0.1036, -0.1324],
#                        ...,
#                        [-0.0998, -0.0148,  0.0577,  ..., -0.0426,  0.0468, -0.0429],
#                        [-0.0218,  0.0886,  0.0963,  ...,  0.1049,  0.0007,  0.1180],
#                        [ 0.0825, -0.0106, -0.0638,  ..., -0.0990,  0.0271,  0.0162]])),
#               ('backbone5.model.layer4.fc4.bias',
#                tensor([-0.1334,  0.0746, -0.0205, -0.0496, -0.0156, -0.0345,  0.1128, -0.0396,
#                         0.1016,  0.0465,  0.0005,  0.0451,  0.0328, -0.0085, -0.0955,  0.0457,
#                         0.0983,  0.1137,  0.0647, -0.0149, -0.0667,  0.1219,  0.0942, -0.0035,
#                        -0.0248, -0.0670, -0.0164, -0.0485,  0.0493, -0.0179,  0.0630, -0.0497,
#                        -0.0663,  0.0615, -0.1166,  0.0310, -0.0516,  0.0999,  0.0688, -0.0255,
#                        -0.0937,  0.0396,  0.1129,  0.1224, -0.0444, -0.0686, -0.0478, -0.0493,
#                        -0.0495, -0.0621,  0.0923,  0.0494,  0.0606,  0.0697, -0.1283, -0.0928,
#                        -0.0478,  0.0309,  0.1196,  0.0115,  0.0574, -0.0386,  0.0422,  0.0640])),
#               ('backbone5.model.layer5.fc5.weight',
#                tensor([[ 0.0801, -0.0572,  0.0533,  ...,  0.0255, -0.0862, -0.0932],
#                        [ 0.1008, -0.0148,  0.1103,  ..., -0.0752,  0.1117, -0.0638],
#                        [-0.0925,  0.0588,  0.0231,  ...,  0.0569,  0.1040, -0.0406],
#                        ...,
#                        [ 0.0163, -0.0878, -0.0573,  ..., -0.0506, -0.1026,  0.0026],
#                        [ 0.0621,  0.1140, -0.1294,  ...,  0.0360,  0.1091,  0.0728],
#                        [ 0.0586,  0.0031,  0.0084,  ...,  0.0728,  0.0924, -0.0764]])),
#               ('backbone5.model.layer5.fc5.bias',
#                tensor([-0.0960,  0.0831, -0.1053, -0.0591,  0.0926, -0.0750, -0.0061, -0.0876,
#                         0.1094,  0.0494,  0.0741, -0.0187,  0.1099,  0.0738, -0.0495, -0.0934,
#                         0.0793,  0.0478,  0.0227,  0.0644, -0.0047, -0.0025,  0.0534, -0.0122,
#                         0.0250, -0.0334,  0.1003, -0.1040,  0.0135,  0.1075,  0.1012,  0.1031,
#                        -0.0390,  0.0541,  0.0733,  0.0177,  0.0519, -0.0716, -0.0883,  0.1257,
#                        -0.0754,  0.0323, -0.1196,  0.0720,  0.0186,  0.0344, -0.0464, -0.0476,
#                         0.0766,  0.0058, -0.0979, -0.1229,  0.0485,  0.0638, -0.0791, -0.1353,
#                        -0.1067, -0.0930, -0.0872,  0.1144, -0.0314,  0.0764,  0.1118,  0.1087])),
#               ('backbone5.model.layer6.fc6.weight',
#                tensor([[-3.5234e-03,  3.2148e-02, -1.9214e-02, -2.8111e-02,  1.5789e-05,
#                         -7.6518e-02, -8.1763e-02,  1.8297e-02,  1.0676e-02, -2.7661e-02,
#                          8.5637e-02, -5.3401e-02,  5.5443e-03,  2.9053e-02, -3.5363e-02,
#                         -8.5154e-03,  4.7678e-02,  2.2906e-02,  2.7374e-02,  1.2016e-01,
#                          1.9490e-02,  1.9055e-02,  1.1843e-02,  3.8648e-02,  4.3629e-02,
#                         -2.3757e-04,  1.0933e-01,  1.6378e-02,  5.0214e-03, -9.6814e-03,
#                          6.1942e-02,  8.7352e-03,  5.6286e-02, -2.2450e-02,  6.0584e-02,
#                         -4.8342e-03,  1.1817e-02,  2.6527e-03, -1.2907e-02,  9.1711e-02,
#                         -5.9237e-02,  6.5608e-02, -2.9173e-02,  4.5504e-02, -7.3730e-03,
#                          4.6792e-04, -4.2577e-02,  5.0473e-02, -1.5434e-03,  1.4235e-02,
#                         -8.7218e-02, -3.5399e-02,  2.9991e-02, -2.2547e-03, -6.3296e-02,
#                         -4.5729e-02,  8.7487e-03, -1.8141e-02,  8.3344e-02,  7.5168e-02,
#                         -2.6871e-02,  4.6416e-02,  4.2177e-02,  7.5299e-02]]))])}

# %% [markdown]
# # LBFGS

# %%
"""LBFGS训练"""
start_time = time.time()

# dataset = Dataset(domain)
# X_res, X_ics,u_ics = dataset.train_data()
# X_res = torch.from_numpy(X_res).float().to(device)
# X_ics = torch.from_numpy(X_ics).float().to(device)
# u_ics = torch.tensor(u_ics).float().to(device)

# mu = X_res.mean(dim=0)
# sigma = X_res.std(dim=0)  # 求样本标准差

# backbone1 = MLP(backbone_layers)  # 主干网络
# backbone2 = MLP(backbone_layers)
# backbone3 = MLP(backbone_layers)
# backbone4 = MLP(backbone_layers)
# backbone5 = MLP(backbone_layers)
# pinn = PINN(backbone1, backbone2, backbone3, backbone4, backbone5, mu, sigma).to(device)

model_state = torch.load(os.path.join(model_path, 'pinn_adam.pth'))
pinn.load_state_dict(model_state['backbone_state'])

optimizer_lbfgs = optim.LBFGS(pinn.parameters(), max_iter=50000, line_search_fn="strong_wolfe",tolerance_grad=1e-5)

loss_log_lbfgs = []
it = 0

with open(train_info_path + 'train_info.txt', 'a') as f:
    f.write('Training by LBFGS:\n')


def closure():
    global it, best_loss, adam_iters
    pinn.zero_grad()
    loss_res_1, loss_res_2, loss_res_3, loss_res_4, loss_res_5, loss_ics   = pinn(X_res, X_ics, u_ics)
    loss = loss_res_1 + loss_res_2 + loss_res_3 + loss_res_4 + loss_res_5 + loss_ics
#     print(loss)
    loss.backward()
    
    loss_log_lbfgs.append(loss.item())
    if (it + 1) % 100 == 0:
        pinn.train(False)  # 验证 -------
        loss_res_1_valid, loss_res_2_valid, loss_res_3_valid, loss_res_4_valid, loss_res_5_valid, loss_ics_valid  = pinn(X_res, X_ics, u_ics)
        loss_valid = loss_res_1_valid + loss_res_2_valid + loss_res_3_valid + loss_res_4_valid + loss_res_4_valid + loss_ics_valid
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res_1"].append(loss_res_1_valid.item())
        logger["loss_res_2"].append(loss_res_2_valid.item())
        logger["loss_res_3"].append(loss_res_3_valid.item())
        logger["loss_res_4"].append(loss_res_4_valid.item())
        logger["loss_res_5"].append(loss_res_5_valid.item())
        logger["loss_ics"].append(loss_ics_valid.item())
        logger["iter"].append(it+1)
        
        info = f'Iter # {it + 1:4d}\ttime:{time.time() - start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r_1:{loss_res_1.item():.2e}, loss_i:{loss_ics.item():2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        if loss_valid.item() < best_loss:  # 保存训练loss最低的模型 -------
            model_state = {'backbone_dict': pinn.backbone.state_dict()}
            torch.save(model_state, os.path.join(model_path, f'pinn_lbfgs.pth'))
            best_loss = loss.item()
    it = it + 1
    return loss

optimizer_lbfgs.step(closure)

model_state = {'backbone_state': pinn.state_dict()}
backbone_path = os.path.join(model_path, f'pinn_lbfgs.pth')
torch.save(model_state, backbone_path)

# %%
it
# Out:
# 4

# %%
logger = np.load("./logger.npy", allow_pickle=True).item()
k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res_1"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_ics"][::k], label=r"$\mathcal{L}_{data}$", linewidth=3)
    plt.legend()
#     plt.xticks([0, 5000, 10000, 15000, 20000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('loss.png', dpi=100)
    plt.show()

# %%
# 导入模型参数
mu = logger["mu"].cpu()
sigma = logger["sigma"].cpu()

backbone1 = MLP(backbone_layers)  # 主干网络
backbone2 = MLP(backbone_layers) 
backbone3 = MLP(backbone_layers) 
backbone4 = MLP(backbone_layers) 
backbone5 = MLP(backbone_layers) 
pinn = PINN(backbone1,backbone2,backbone3,backbone4,backbone5, mu, sigma)

model_state = torch.load(os.path.join(model_path, 'pinn_lbfgs.pth'))
# model_state = torch.load(os.path.join(model_path, 'pinn_adam.pth'))
pinn.load_state_dict(model_state['backbone_state'])
pinn.eval()

# 生成网格
t_res = np.linspace(tmin, tmax, 1000)
# x_res = np.linspace(xmin, xmax, 100)
# X_res = dataset.sample_xy(t_res, x_res)

X_res = np.expand_dims(t_res, axis=1)
X_res = np.repeat(X_res,5,axis=1)
# print(X_res.shape)

X_res = torch.from_numpy(X_res).double()
pinn = pinn.cpu().double()
X1_pred,X2_pred,X3_pred,X4_pred,X5_pred = pinn.net_X_res_pred(X_res)

X1_pred = X1_pred.detach().numpy()
X2_pred = X2_pred.detach().numpy()
X3_pred = X3_pred.detach().numpy()
X4_pred = X4_pred.detach().numpy()
X5_pred = X5_pred.detach().numpy()

print(X1_pred.shape)
# X1_error = np.linalg.norm(X1_pred - X1_star) / np.linalg.norm(X1_star) 
# print('Relative l2 error of u: {:.3e}'.format(u_error))
# Out:
# (1000, 1)

# %%
fig = plt.figure(figsize=(6, 5))

plt.rcParams.update({'font.size':18})
with sns.axes_style("darkgrid"):
    fig = plt.figure(figsize=(16, 5))
    ax = plt.subplot(1, 3, 1)
    plt.plot(t_res, X1_pred, linewidth=3)
#     plt.scatter(X1_pred[:,0], X1_pred[:,1])
    plt.xlabel('$t$')
    plt.ylabel('X1')
#     plt.xticks([0, 1, 2, 3, 4])
    plt.legend(loc='upper right', fontsize=15)
    plt.tight_layout()
    ax.set_aspect(1./ax.get_data_ratio())
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
