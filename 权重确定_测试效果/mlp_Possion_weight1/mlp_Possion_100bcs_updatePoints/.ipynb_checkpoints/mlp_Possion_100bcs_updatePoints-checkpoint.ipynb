# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /tmp/ipykernel_39417/82325636.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from pyDOE import lhs

import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
#     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
#     torch.use_deterministic_algorithms(True)  # 有检查操作，看下文区别
 
seed_torch(1024)

# %%
domain = (-1, 1, -1, 1)
xmin, xmax, ymin, ymax = domain
mlp_layers = [2, 128, 128, 128, 128, 128, 128, 1]
Nsd = 10000
n_b = 128
lr=1e-3
adam_epoch = 25000
lbfgs_epoch = 1000
gamma = 0.7
step_size = 1000
newton_iter = 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
class DatasetAC:
    def __init__(self, domain):
        self.domain = domain
    
    def train_data(self, verbose=None):
        xmin, xmax, ymin, ymax = self.domain
        # 内部点采样
        
#         lb1 = np.array([-1., -1.])
#         ub1 = np.array([0., 0.])
#         lb2 = np.array([-1., 0.])
#         ub2 = np.array([0., 1.])
#         lb3 = np.array([0.0, -1.])
#         ub3 = np.array([1., 0.])

#         xy_res1 = (ub1-lb1)*lhs(2, int(Nsd/3))+lb1
#         xy_res2 = (ub2-lb2)*lhs(2, int(Nsd/3))+lb2
#         xy_res3 = (ub3-lb3)*lhs(2, int(Nsd/3))+lb3
        
#         X_res = np.concatenate([xy_res1, xy_res2, xy_res3], 0)

        lb = np.array([-1.0, -1.0])
        ub = np.array([1.0, 1.0])
        xy = (ub-lb)*lhs(2, Nsd)+lb
        xy = xy[~((xy[:,0]>=0) * (xy[:,1]>=0))]
        
        # 边界点采样
        
#         # 对于x
#         lb_bcs_1 = np.array([-1., -1.])
#         ub_bcs_1 = np.array([1., -1.])
#         lb_bcs_2 = np.array([-1., 1.])
#         ub_bcs_2 = np.array([0.0, 1.])
#         lb_bcs_3 = np.array([0.0, 0.0])
#         ub_bcs_3 = np.array([1., 0.0])
#         xy_bcs_1 = (ub_bcs_1-lb_bcs_1)*lhs(2, n_bcs)+lb_bcs_1
#         xy_bcs_2 = (ub_bcs_2-lb_bcs_2)*lhs(2, n_bcs)+lb_bcs_2
#         xy_bcs_3 = (ub_bcs_3-lb_bcs_3)*lhs(2, n_bcs)+lb_bcs_3
#         xy_bcs_x = np.concatenate([xy_bcs_1,xy_bcs_2,xy_bcs_3],0)
#         # 对于y
#         lb_bcs_4 = np.array([-1., -1.])
#         ub_bcs_4 = np.array([-1., 1.])
#         lb_bcs_5 = np.array([0.0, 0.0])
#         ub_bcs_5 = np.array([0.0, 1.])
#         lb_bcs_6 = np.array([1., -1.])
#         ub_bcs_6 = np.array([1., 0.0])
#         xy_bcs_4 = (ub_bcs_4-lb_bcs_4)*lhs(2, n_bcs)+lb_bcs_4
#         xy_bcs_5 = (ub_bcs_5-lb_bcs_5)*lhs(2, n_bcs)+lb_bcs_5
#         xy_bcs_6 = (ub_bcs_6-lb_bcs_6)*lhs(2, n_bcs)+lb_bcs_6
#         xy_bcs_y = np.concatenate([xy_bcs_4,xy_bcs_5,xy_bcs_6],0)
#         X_bcs = np.concatenate([xy_bcs_x,xy_bcs_y],0)


        bound_1 = lhs(1, n_b)-1 # -1 -> 0
        bound_1 = bound_1.reshape(-1,1)
        
        bound_2 = lhs(1, n_b) # 0 -> 1
        bound_2 = bound_2.reshape(-1,1)
        
        xy_b_1 = np.hstack((bound_1, bound_1*0-1))
        xy_b_2 = np.hstack((bound_2, bound_2*0-1))
        xy_b_3 = np.hstack((bound_1*0-1, bound_1))
        xy_b_4 = np.hstack((bound_1*0-1, bound_2))
        xy_b_5 = np.hstack((bound_1, bound_1*0+1))
        xy_b_6 = np.hstack((bound_2, bound_1*0))
        xy_b_7 = np.hstack((bound_1*0+1, bound_1))
        xy_b_8 = np.hstack((bound_1*0, bound_2))        
        xy_b = np.vstack([xy_b_1, xy_b_2, xy_b_3, xy_b_4, xy_b_5, xy_b_6, xy_b_7, xy_b_8])
        
        xy = torch.from_numpy(xy).float().to(device)
        xy_b = torch.from_numpy(xy_b).float().to(device)
        return xy, xy_b
    
    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X
    

dataset = DatasetAC(domain)
X_res, X_bcs = dataset.train_data()
print(X_res.shape, X_bcs.shape)
# Out:
# torch.Size([7494, 2]) torch.Size([1024, 2])

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
        for param in self.parameters():
            if len(param.shape) > 1:
                nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)
    
    
backbone = MLP(mlp_layers)
backbone.model
# Out:
# Sequential(
#   (layer0): Sequential(
#     (fc0): Linear(in_features=2, out_features=128, bias=True)
#     (act0): Tanh()
#   )
#   (layer1): Sequential(
#     (fc1): Linear(in_features=128, out_features=128, bias=True)
#     (act1): Tanh()
#   )
#   (layer2): Sequential(
#     (fc2): Linear(in_features=128, out_features=128, bias=True)
#     (act2): Tanh()
#   )
#   (layer3): Sequential(
#     (fc3): Linear(in_features=128, out_features=128, bias=True)
#     (act3): Tanh()
#   )
#   (layer4): Sequential(
#     (fc4): Linear(in_features=128, out_features=128, bias=True)
#     (act4): Tanh()
#   )
#   (layer5): Sequential(
#     (fc5): Linear(in_features=128, out_features=128, bias=True)
#     (act5): Tanh()
#   )
#   (layer6): Sequential(
#     (fc6): Linear(in_features=128, out_features=1, bias=False)
#   )
# )

# %% [markdown]
# ## 预设的权重函数

# %%
def points_weight_fn1(X):
    if torch.is_tensor(X):
        d = torch.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
    else:
        d = np.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
    return -2 * d + 6.2

def points_weight_fn2(X):
    if torch.is_tensor(X):
        d = torch.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
        return 8 * torch.exp(-0.78*d)
    else:
        d = np.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
        return 8 * np.exp(-0.78*d)

def points_weight_fn3(X):
    if torch.is_tensor(X):
        d = torch.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
    else:
        d = np.sqrt((X[:, [0]]-1)**2 + (X[:, [1]]-1)**2)
    return -0.3*d**2 + 3.8

# %%
fixed_w1 = points_weight_fn1(X_res).cpu()
fixed_w2 = points_weight_fn2(X_res).cpu()
fixed_w3 = points_weight_fn3(X_res).cpu()
X_res = X_res.cpu()

# %%
fig = plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.scatter(X_res[:, 0], X_res[:, 1], c=fixed_w1[:, 0], cmap='jet')
plt.colorbar()
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Fixed points weight 1')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.scatter(X_res[:, 0], X_res[:, 1], c=fixed_w2[:, 0], cmap='jet')
plt.colorbar()
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Fixed points weight 2')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.scatter(X_res[:, 0], X_res[:, 1], c=fixed_w3[:, 0], cmap='jet')
plt.colorbar()
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Fixed points weight 3')
plt.tight_layout()

plt.show()
plt.savefig('weight_possion_Lshape.png', dpi=400)

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True, 
                               retain_graph=True)

# %%
class PINNAC(nn.Module):
    def __init__(self, backbone, mu=None, sigma=None, points_weight_fn=None):
        super(PINNAC, self).__init__()
        self.backbone = backbone
        self.d = 0.0001
        if mu is not None and sigma is not None:
            self.is_inputs_normalization = True
            self.mu = mu
            self.sigma = sigma
            print(f'forward with normalization, mu={self.mu.tolist()}, sigma={self.sigma.tolist()}')
        else:
            self.is_inputs_normalization = False
            
        if points_weight_fn is not None:
            self.is_pw_fn = True
            self.pw_fn = points_weight_fn
        else:
            self.is_pw_fn = False
    
    def forward(self, X_res, X_bcs):
        if self.is_pw_fn:
            pw_res = self.pw_fn(X_res)
            pw_res.requires_grad_(False)
            loss_res = torch.mean(self.net_f(pw_res * X_res)**2)
        else:
            loss_res = torch.mean(self.net_f(X_res)**2)
        loss_bcs = torch.mean(self.net_u(X_bcs)**2)
        return loss_res, loss_bcs
    
    def net_u(self, X):
        if self.is_inputs_normalization == True:
            X = (X - self.mu) / self.sigma
        return self.backbone(X)
    
    def net_f(self, X_res):
        X_res.requires_grad_(True)
        u = self.net_u(X_res)

        grad_u = grad(u, X_res)[0]
        u_x = grad_u[:,[0]]
        u_y = grad_u[:,[1]]
        u_xx = grad(u_x, X_res)[0][:,[0]]
        u_yy = grad(u_y, X_res)[0][:,[1]]

        return 1 + u_xx + u_yy
    

pinn = PINNAC(backbone)

# %% [markdown]
# ## Adam训练

# %%
# 训练
dataset = DatasetAC(domain)
X_res, X_bcs = dataset.train_data()


mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(mlp_layers)
# 使用第一种权重生成方法
pinn = PINNAC(backbone, mu, sigma, points_weight_fn=points_weight_fn1).to(device)

optimizer_adam = optim.Adam(pinn.parameters(), lr=lr)
# lr_sche_step = int( adam_epoch / (np.log(1e-3) / np.log(lr_sche_gamma)) )
# print(f"ExponentialLR, gamma: {lr_sche_gamma}, step: {lr_sche_step}")
lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=gamma, verbose=True)

loss_r_log_adam = []
loss_b_log_adam = []
best_loss = 1e9

with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for epoch in range(adam_epoch):
    pinn.zero_grad()
    
    loss_res, loss_bcs = pinn(X_res, X_bcs)
    loss = loss_res + 100*loss_bcs
    
    loss.backward()
    optimizer_adam.step()
    
    loss_r_log_adam.append(loss_res.item())
    loss_b_log_adam.append(loss_bcs.item())
        
    if (epoch + 1) % 100 == 0:
        info = f'Epoch # {epoch+1:5d}/{adam_epoch}\ttime:{time.time()-start_time:.1e}\t' + \
            f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_b:{loss_bcs.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        model_state = {'epoch': epoch+1, 'state_dict': pinn.backbone.state_dict()}
#         backbone_path = os.path.join(model_path, f'backbone_{epoch+1}.pth')
#         torch.save(model_state, backbone_path)
        if loss.item() < best_loss:
            # 保存训练loss最低的模型
            torch.save(model_state, os.path.join(model_path, f'backbone_adam.pth'))
            best_loss = loss.item()
            
    if ((epoch + 1)>5000) and ((epoch + 1)<=15000):
        if (epoch + 1 -5000) % step_size == 0:
            lr_sche.step()
    if (epoch+1) % 1000 ==0:
        X_res, X_bcs = dataset.train_data()
# Out:
# forward with normalization, mu=[-0.16289235651493073, -0.16407690942287445], sigma=[0.5545392632484436, 0.5529333353042603]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch #   100/25000	time:1.3e+00	loss:6.08e-01, loss_r:5.90e-01, loss_b:1.82e-04
# Epoch #   200/25000	time:2.5e+00	loss:4.06e-01, loss_r:3.84e-01, loss_b:2.16e-04
# Epoch #   300/25000	time:3.8e+00	loss:2.26e-01, loss_r:2.10e-01, loss_b:1.54e-04
# Epoch #   400/25000	time:5.1e+00	loss:1.07e-01, loss_r:9.65e-02, loss_b:1.03e-04
# Epoch #   500/25000	time:6.3e+00	loss:6.17e-02, loss_r:5.33e-02, loss_b:8.40e-05
# Epoch #   600/25000	time:7.6e+00	loss:4.15e-02, loss_r:3.38e-02, loss_b:7.70e-05
# Epoch #   700/25000	time:8.9e+00	loss:3.05e-02, loss_r:2.32e-02, loss_b:7.25e-05
# Epoch #   800/25000	time:1.0e+01	loss:1.65e-01, loss_r:1.95e-02, loss_b:1.46e-03
# Epoch #   900/25000	time:1.1e+01	loss:2.02e-02, loss_r:1.39e-02, loss_b:6.34e-05
# Epoch #  1000/25000	time:1.3e+01	loss:1.65e-02, loss_r:1.08e-02, loss_b:5.71e-05
# Epoch #  1100/25000	time:1.4e+01	loss:5.12e-02, loss_r:1.21e-02, loss_b:3.91e-04
# Epoch #  1200/25000	time:1.5e+01	loss:1.36e-02, loss_r:8.20e-03, loss_b:5.37e-05
# Epoch #  1300/25000	time:1.6e+01	loss:1.15e-02, loss_r:6.68e-03, loss_b:4.79e-05
# Epoch #  1400/25000	time:1.8e+01	loss:9.96e-03, loss_r:5.63e-03, loss_b:4.33e-05
# Epoch #  1500/25000	time:1.9e+01	loss:1.04e-02, loss_r:6.16e-03, loss_b:4.20e-05
# Epoch #  1600/25000	time:2.0e+01	loss:8.58e-03, loss_r:4.83e-03, loss_b:3.75e-05
# Epoch #  1700/25000	time:2.1e+01	loss:7.58e-03, loss_r:4.12e-03, loss_b:3.45e-05
# Epoch #  1800/25000	time:2.3e+01	loss:9.09e-03, loss_r:3.78e-03, loss_b:5.30e-05
# Epoch #  1900/25000	time:2.4e+01	loss:6.66e-03, loss_r:3.58e-03, loss_b:3.08e-05
# Epoch #  2000/25000	time:2.5e+01	loss:2.57e-02, loss_r:7.56e-03, loss_b:1.82e-04
# Epoch #  2100/25000	time:2.6e+01	loss:7.11e-03, loss_r:3.61e-03, loss_b:3.50e-05
# Epoch #  2200/25000	time:2.8e+01	loss:6.00e-03, loss_r:2.97e-03, loss_b:3.03e-05
# Epoch #  2300/25000	time:2.9e+01	loss:5.32e-03, loss_r:2.59e-03, loss_b:2.74e-05
# Epoch #  2400/25000	time:3.0e+01	loss:7.25e-03, loss_r:4.58e-03, loss_b:2.67e-05
# Epoch #  2500/25000	time:3.1e+01	loss:4.93e-03, loss_r:2.48e-03, loss_b:2.45e-05
# Epoch #  2600/25000	time:3.3e+01	loss:4.44e-03, loss_r:2.16e-03, loss_b:2.28e-05
# Epoch #  2700/25000	time:3.4e+01	loss:4.56e-03, loss_r:2.32e-03, loss_b:2.24e-05
# Epoch #  2800/25000	time:3.5e+01	loss:4.02e-03, loss_r:1.95e-03, loss_b:2.06e-05
# Epoch #  2900/25000	time:3.6e+01	loss:5.30e-03, loss_r:3.16e-03, loss_b:2.13e-05
# Epoch #  3000/25000	time:3.8e+01	loss:3.89e-03, loss_r:1.88e-03, loss_b:2.00e-05
# Epoch #  3100/25000	time:3.9e+01	loss:4.58e-03, loss_r:2.31e-03, loss_b:2.27e-05
# Epoch #  3200/25000	time:4.0e+01	loss:5.28e-03, loss_r:2.32e-03, loss_b:2.96e-05
# Epoch #  3300/25000	time:4.1e+01	loss:3.84e-03, loss_r:1.83e-03, loss_b:2.01e-05
# Epoch #  3400/25000	time:4.3e+01	loss:5.36e-03, loss_r:2.23e-03, loss_b:3.12e-05
# Epoch #  3500/25000	time:4.4e+01	loss:3.35e-03, loss_r:1.57e-03, loss_b:1.78e-05
# Epoch #  3600/25000	time:4.5e+01	loss:9.64e-03, loss_r:6.07e-03, loss_b:3.57e-05
# Epoch #  3700/25000	time:4.6e+01	loss:6.57e-03, loss_r:1.57e-03, loss_b:5.00e-05
# Epoch #  3800/25000	time:4.8e+01	loss:2.90e-03, loss_r:1.31e-03, loss_b:1.59e-05
# Epoch #  3900/25000	time:4.9e+01	loss:2.70e-03, loss_r:1.18e-03, loss_b:1.51e-05
# Epoch #  4000/25000	time:5.0e+01	loss:3.07e-03, loss_r:1.37e-03, loss_b:1.69e-05
# Epoch #  4100/25000	time:5.2e+01	loss:4.91e-03, loss_r:1.64e-03, loss_b:3.26e-05
# Epoch #  4200/25000	time:5.3e+01	loss:3.26e-03, loss_r:1.31e-03, loss_b:1.95e-05
# Epoch #  4300/25000	time:5.4e+01	loss:2.95e-03, loss_r:1.22e-03, loss_b:1.73e-05
# Epoch #  4400/25000	time:5.5e+01	loss:5.19e-03, loss_r:1.23e-03, loss_b:3.96e-05
# Epoch #  4500/25000	time:5.7e+01	loss:3.34e-03, loss_r:1.11e-03, loss_b:2.23e-05
# Epoch #  4600/25000	time:5.8e+01	loss:9.05e-03, loss_r:1.12e-03, loss_b:7.93e-05
# Epoch #  4700/25000	time:5.9e+01	loss:3.05e-03, loss_r:9.86e-04, loss_b:2.07e-05
# Epoch #  4800/25000	time:6.0e+01	loss:2.45e-03, loss_r:9.53e-04, loss_b:1.49e-05
# Epoch #  4900/25000	time:6.2e+01	loss:5.86e-03, loss_r:1.95e-03, loss_b:3.92e-05
# Epoch #  5000/25000	time:6.3e+01	loss:3.46e-02, loss_r:1.41e-03, loss_b:3.32e-04
# Epoch #  5100/25000	time:6.4e+01	loss:2.48e-03, loss_r:1.05e-03, loss_b:1.43e-05
# Epoch #  5200/25000	time:6.5e+01	loss:2.40e-03, loss_r:9.59e-04, loss_b:1.44e-05
# Epoch #  5300/25000	time:6.7e+01	loss:7.55e-02, loss_r:2.81e-03, loss_b:7.27e-04
# Epoch #  5400/25000	time:6.8e+01	loss:5.39e-03, loss_r:9.87e-04, loss_b:4.41e-05
# Epoch #  5500/25000	time:6.9e+01	loss:5.97e-03, loss_r:9.82e-04, loss_b:4.98e-05
# Epoch #  5600/25000	time:7.1e+01	loss:2.07e-03, loss_r:7.87e-04, loss_b:1.28e-05
# Epoch #  5700/25000	time:7.2e+01	loss:2.12e-02, loss_r:2.31e-03, loss_b:1.89e-04
# Epoch #  5800/25000	time:7.3e+01	loss:1.58e-02, loss_r:1.35e-03, loss_b:1.44e-04
# Epoch #  5900/25000	time:7.4e+01	loss:2.34e-03, loss_r:8.86e-04, loss_b:1.45e-05
# Epoch #  6000/25000	time:7.6e+01	loss:2.85e-03, loss_r:1.07e-03, loss_b:1.78e-05
# Adjusting learning rate of group 0 to 7.0000e-04.
# Epoch #  6100/25000	time:7.7e+01	loss:2.23e-03, loss_r:7.75e-04, loss_b:1.46e-05
# Epoch #  6200/25000	time:7.8e+01	loss:2.10e-03, loss_r:6.99e-04, loss_b:1.40e-05
# Epoch #  6300/25000	time:7.9e+01	loss:2.01e-03, loss_r:6.55e-04, loss_b:1.36e-05
# Epoch #  6400/25000	time:8.1e+01	loss:1.94e-03, loss_r:6.24e-04, loss_b:1.32e-05
# Epoch #  6500/25000	time:8.2e+01	loss:1.88e-03, loss_r:5.98e-04, loss_b:1.28e-05
# Epoch #  6600/25000	time:8.3e+01	loss:1.83e-03, loss_r:5.77e-04, loss_b:1.25e-05
# Epoch #  6700/25000	time:8.4e+01	loss:1.78e-03, loss_r:5.57e-04, loss_b:1.22e-05
# Epoch #  6800/25000	time:8.6e+01	loss:2.73e-01, loss_r:1.48e-02, loss_b:2.59e-03
# Epoch #  6900/25000	time:8.7e+01	loss:1.81e-03, loss_r:5.76e-04, loss_b:1.23e-05
# Epoch #  7000/25000	time:8.8e+01	loss:1.78e-03, loss_r:5.54e-04, loss_b:1.23e-05
# Adjusting learning rate of group 0 to 4.9000e-04.
# Epoch #  7100/25000	time:8.9e+01	loss:2.25e-03, loss_r:7.64e-04, loss_b:1.48e-05
# Epoch #  7200/25000	time:9.1e+01	loss:2.12e-03, loss_r:7.08e-04, loss_b:1.41e-05
# Epoch #  7300/25000	time:9.2e+01	loss:2.03e-03, loss_r:6.75e-04, loss_b:1.35e-05
# Epoch #  7400/25000	time:9.3e+01	loss:1.96e-03, loss_r:6.50e-04, loss_b:1.31e-05
# Epoch #  7500/25000	time:9.4e+01	loss:1.90e-03, loss_r:6.29e-04, loss_b:1.27e-05
# Epoch #  7600/25000	time:9.6e+01	loss:1.84e-03, loss_r:6.09e-04, loss_b:1.23e-05
# Epoch #  7700/25000	time:9.7e+01	loss:2.98e-03, loss_r:1.16e-03, loss_b:1.82e-05
# Epoch #  7800/25000	time:9.8e+01	loss:2.12e-03, loss_r:6.09e-04, loss_b:1.51e-05
# Epoch #  7900/25000	time:9.9e+01	loss:1.77e-03, loss_r:5.76e-04, loss_b:1.19e-05
# Epoch #  8000/25000	time:1.0e+02	loss:1.83e-03, loss_r:5.88e-04, loss_b:1.24e-05
# Adjusting learning rate of group 0 to 3.4300e-04.
# Epoch #  8100/25000	time:1.0e+02	loss:1.59e-03, loss_r:5.20e-04, loss_b:1.07e-05
# Epoch #  8200/25000	time:1.0e+02	loss:1.48e-03, loss_r:4.82e-04, loss_b:9.97e-06
# Epoch #  8300/25000	time:1.0e+02	loss:1.41e-03, loss_r:4.60e-04, loss_b:9.52e-06
# Epoch #  8400/25000	time:1.1e+02	loss:1.36e-03, loss_r:4.45e-04, loss_b:9.19e-06
# Epoch #  8500/25000	time:1.1e+02	loss:1.32e-03, loss_r:4.32e-04, loss_b:8.91e-06
# Epoch #  8600/25000	time:1.1e+02	loss:1.29e-03, loss_r:4.21e-04, loss_b:8.67e-06
# Epoch #  8700/25000	time:1.1e+02	loss:1.26e-03, loss_r:4.11e-04, loss_b:8.47e-06
# Epoch #  8800/25000	time:1.1e+02	loss:6.83e-03, loss_r:1.22e-03, loss_b:5.61e-05
# Epoch #  8900/25000	time:1.1e+02	loss:1.37e-02, loss_r:7.08e-04, loss_b:1.30e-04
# Epoch #  9000/25000	time:1.1e+02	loss:1.20e-03, loss_r:3.89e-04, loss_b:8.07e-06
# Adjusting learning rate of group 0 to 2.4010e-04.
# Epoch #  9100/25000	time:1.1e+02	loss:1.34e-03, loss_r:4.50e-04, loss_b:8.95e-06
# Epoch #  9200/25000	time:1.2e+02	loss:1.25e-03, loss_r:4.11e-04, loss_b:8.41e-06
# Epoch #  9300/25000	time:1.2e+02	loss:1.21e-03, loss_r:3.92e-04, loss_b:8.16e-06
# Epoch #  9400/25000	time:1.2e+02	loss:1.18e-03, loss_r:3.78e-04, loss_b:7.99e-06
# Epoch #  9500/25000	time:1.2e+02	loss:1.15e-03, loss_r:3.67e-04, loss_b:7.84e-06
# Epoch #  9600/25000	time:1.2e+02	loss:1.13e-03, loss_r:3.58e-04, loss_b:7.71e-06
# Epoch #  9700/25000	time:1.2e+02	loss:3.51e-03, loss_r:1.36e-03, loss_b:2.15e-05
# Epoch #  9800/25000	time:1.2e+02	loss:1.12e-03, loss_r:3.45e-04, loss_b:7.75e-06
# Epoch #  9900/25000	time:1.2e+02	loss:1.14e-03, loss_r:3.44e-04, loss_b:7.93e-06
# Epoch # 10000/25000	time:1.3e+02	loss:1.23e-03, loss_r:3.57e-04, loss_b:8.76e-06
# Adjusting learning rate of group 0 to 1.6807e-04.
# Epoch # 10100/25000	time:1.3e+02	loss:1.66e-03, loss_r:5.18e-04, loss_b:1.14e-05
# Epoch # 10200/25000	time:1.3e+02	loss:1.52e-03, loss_r:4.51e-04, loss_b:1.07e-05
# Epoch # 10300/25000	time:1.3e+02	loss:1.43e-03, loss_r:4.18e-04, loss_b:1.02e-05
# Epoch # 10400/25000	time:1.3e+02	loss:1.37e-03, loss_r:3.95e-04, loss_b:9.73e-06
# Epoch # 10500/25000	time:1.3e+02	loss:1.31e-03, loss_r:3.78e-04, loss_b:9.36e-06
# Epoch # 10600/25000	time:1.3e+02	loss:1.27e-03, loss_r:3.64e-04, loss_b:9.04e-06
# Epoch # 10700/25000	time:1.3e+02	loss:1.23e-03, loss_r:3.51e-04, loss_b:8.75e-06
# Epoch # 10800/25000	time:1.4e+02	loss:1.27e-03, loss_r:3.74e-04, loss_b:8.96e-06
# Epoch # 10900/25000	time:1.4e+02	loss:1.16e-03, loss_r:3.32e-04, loss_b:8.24e-06
# Epoch # 11000/25000	time:1.4e+02	loss:1.21e-03, loss_r:3.31e-04, loss_b:8.78e-06
# Adjusting learning rate of group 0 to 1.1765e-04.
# Epoch # 11100/25000	time:1.4e+02	loss:1.15e-03, loss_r:3.54e-04, loss_b:7.92e-06
# Epoch # 11200/25000	time:1.4e+02	loss:1.09e-03, loss_r:3.28e-04, loss_b:7.59e-06
# Epoch # 11300/25000	time:1.4e+02	loss:1.05e-03, loss_r:3.14e-04, loss_b:7.37e-06
# Epoch # 11400/25000	time:1.4e+02	loss:1.02e-03, loss_r:3.03e-04, loss_b:7.19e-06
# Epoch # 11500/25000	time:1.4e+02	loss:9.98e-04, loss_r:2.95e-04, loss_b:7.03e-06
# Epoch # 11600/25000	time:1.5e+02	loss:9.77e-04, loss_r:2.88e-04, loss_b:6.90e-06
# Epoch # 11700/25000	time:1.5e+02	loss:1.64e-03, loss_r:4.42e-04, loss_b:1.20e-05
# Epoch # 11800/25000	time:1.5e+02	loss:9.76e-04, loss_r:2.77e-04, loss_b:6.98e-06
# Epoch # 11900/25000	time:1.5e+02	loss:9.30e-04, loss_r:2.71e-04, loss_b:6.59e-06
# Epoch # 12000/25000	time:1.5e+02	loss:1.49e-03, loss_r:2.99e-04, loss_b:1.19e-05
# Adjusting learning rate of group 0 to 8.2354e-05.
# Epoch # 12100/25000	time:1.5e+02	loss:1.22e-03, loss_r:3.81e-04, loss_b:8.40e-06
# Epoch # 12200/25000	time:1.5e+02	loss:1.07e-03, loss_r:3.27e-04, loss_b:7.42e-06
# Epoch # 12300/25000	time:1.5e+02	loss:1.00e-03, loss_r:3.04e-04, loss_b:6.98e-06
# Epoch # 12400/25000	time:1.6e+02	loss:9.62e-04, loss_r:2.91e-04, loss_b:6.72e-06
# Epoch # 12500/25000	time:1.6e+02	loss:9.35e-04, loss_r:2.82e-04, loss_b:6.54e-06
# Epoch # 12600/25000	time:1.6e+02	loss:9.14e-04, loss_r:2.74e-04, loss_b:6.40e-06
# Epoch # 12700/25000	time:1.6e+02	loss:8.97e-04, loss_r:2.68e-04, loss_b:6.29e-06
# Epoch # 12800/25000	time:1.6e+02	loss:8.81e-04, loss_r:2.62e-04, loss_b:6.19e-06
# Epoch # 12900/25000	time:1.6e+02	loss:8.71e-04, loss_r:2.57e-04, loss_b:6.14e-06
# Epoch # 13000/25000	time:1.6e+02	loss:8.79e-04, loss_r:2.56e-04, loss_b:6.23e-06
# Adjusting learning rate of group 0 to 5.7648e-05.
# Epoch # 13100/25000	time:1.7e+02	loss:1.02e-03, loss_r:3.05e-04, loss_b:7.12e-06
# Epoch # 13200/25000	time:1.7e+02	loss:9.61e-04, loss_r:2.84e-04, loss_b:6.78e-06
# Epoch # 13300/25000	time:1.7e+02	loss:9.30e-04, loss_r:2.72e-04, loss_b:6.58e-06
# Epoch # 13400/25000	time:1.7e+02	loss:9.07e-04, loss_r:2.65e-04, loss_b:6.42e-06
# Epoch # 13500/25000	time:1.7e+02	loss:8.88e-04, loss_r:2.59e-04, loss_b:6.29e-06
# Epoch # 13600/25000	time:1.7e+02	loss:8.72e-04, loss_r:2.53e-04, loss_b:6.18e-06
# Epoch # 13700/25000	time:1.7e+02	loss:8.57e-04, loss_r:2.49e-04, loss_b:6.08e-06
# Epoch # 13800/25000	time:1.7e+02	loss:8.44e-04, loss_r:2.45e-04, loss_b:5.99e-06
# Epoch # 13900/25000	time:1.8e+02	loss:8.32e-04, loss_r:2.41e-04, loss_b:5.91e-06
# Epoch # 14000/25000	time:1.8e+02	loss:8.21e-04, loss_r:2.37e-04, loss_b:5.84e-06
# Adjusting learning rate of group 0 to 4.0354e-05.
# Epoch # 14100/25000	time:1.8e+02	loss:8.78e-04, loss_r:2.54e-04, loss_b:6.25e-06
# Epoch # 14200/25000	time:1.8e+02	loss:8.49e-04, loss_r:2.38e-04, loss_b:6.11e-06
# Epoch # 14300/25000	time:1.8e+02	loss:8.31e-04, loss_r:2.30e-04, loss_b:6.01e-06
# Epoch # 14400/25000	time:1.8e+02	loss:8.18e-04, loss_r:2.25e-04, loss_b:5.93e-06
# Epoch # 14500/25000	time:1.8e+02	loss:8.07e-04, loss_r:2.21e-04, loss_b:5.86e-06
# Epoch # 14600/25000	time:1.8e+02	loss:7.97e-04, loss_r:2.17e-04, loss_b:5.79e-06
# Epoch # 14700/25000	time:1.9e+02	loss:7.87e-04, loss_r:2.14e-04, loss_b:5.73e-06
# Epoch # 14800/25000	time:1.9e+02	loss:7.78e-04, loss_r:2.11e-04, loss_b:5.67e-06
# Epoch # 14900/25000	time:1.9e+02	loss:7.70e-04, loss_r:2.09e-04, loss_b:5.61e-06
# Epoch # 15000/25000	time:1.9e+02	loss:7.62e-04, loss_r:2.06e-04, loss_b:5.56e-06
# Adjusting learning rate of group 0 to 2.8248e-05.
# Epoch # 15100/25000	time:1.9e+02	loss:1.06e-03, loss_r:3.53e-04, loss_b:7.02e-06
# Epoch # 15200/25000	time:1.9e+02	loss:9.19e-04, loss_r:2.72e-04, loss_b:6.46e-06
# Epoch # 15300/25000	time:1.9e+02	loss:8.65e-04, loss_r:2.43e-04, loss_b:6.22e-06
# Epoch # 15400/25000	time:1.9e+02	loss:8.37e-04, loss_r:2.28e-04, loss_b:6.08e-06
# Epoch # 15500/25000	time:2.0e+02	loss:8.18e-04, loss_r:2.20e-04, loss_b:5.99e-06
# Epoch # 15600/25000	time:2.0e+02	loss:8.05e-04, loss_r:2.14e-04, loss_b:5.91e-06
# Epoch # 15700/25000	time:2.0e+02	loss:7.94e-04, loss_r:2.10e-04, loss_b:5.84e-06
# Epoch # 15800/25000	time:2.0e+02	loss:7.85e-04, loss_r:2.06e-04, loss_b:5.79e-06
# Epoch # 15900/25000	time:2.0e+02	loss:7.78e-04, loss_r:2.04e-04, loss_b:5.74e-06
# Epoch # 16000/25000	time:2.0e+02	loss:7.71e-04, loss_r:2.01e-04, loss_b:5.69e-06
# Epoch # 16100/25000	time:2.0e+02	loss:8.34e-04, loss_r:2.26e-04, loss_b:6.09e-06
# Epoch # 16200/25000	time:2.0e+02	loss:7.92e-04, loss_r:2.15e-04, loss_b:5.77e-06
# Epoch # 16300/25000	time:2.1e+02	loss:7.69e-04, loss_r:2.11e-04, loss_b:5.57e-06
# Epoch # 16400/25000	time:2.1e+02	loss:7.52e-04, loss_r:2.09e-04, loss_b:5.43e-06
# Epoch # 16500/25000	time:2.1e+02	loss:7.39e-04, loss_r:2.06e-04, loss_b:5.32e-06
# Epoch # 16600/25000	time:2.1e+02	loss:7.40e-04, loss_r:2.04e-04, loss_b:5.36e-06
# Epoch # 16700/25000	time:2.1e+02	loss:7.17e-04, loss_r:2.02e-04, loss_b:5.15e-06
# Epoch # 16800/25000	time:2.1e+02	loss:7.08e-04, loss_r:2.01e-04, loss_b:5.08e-06
# Epoch # 16900/25000	time:2.1e+02	loss:7.00e-04, loss_r:1.99e-04, loss_b:5.01e-06
# Epoch # 17000/25000	time:2.1e+02	loss:6.92e-04, loss_r:1.97e-04, loss_b:4.95e-06
# Epoch # 17100/25000	time:2.2e+02	loss:7.81e-04, loss_r:2.54e-04, loss_b:5.27e-06
# Epoch # 17200/25000	time:2.2e+02	loss:7.46e-04, loss_r:2.28e-04, loss_b:5.18e-06
# Epoch # 17300/25000	time:2.2e+02	loss:7.27e-04, loss_r:2.16e-04, loss_b:5.11e-06
# Epoch # 17400/25000	time:2.2e+02	loss:7.28e-04, loss_r:2.10e-04, loss_b:5.18e-06
# Epoch # 17500/25000	time:2.2e+02	loss:7.04e-04, loss_r:2.04e-04, loss_b:5.00e-06
# Epoch # 17600/25000	time:2.2e+02	loss:6.96e-04, loss_r:2.01e-04, loss_b:4.95e-06
# Epoch # 17700/25000	time:2.2e+02	loss:6.89e-04, loss_r:1.97e-04, loss_b:4.91e-06
# Epoch # 17800/25000	time:2.2e+02	loss:7.14e-04, loss_r:1.94e-04, loss_b:5.20e-06
# Epoch # 17900/25000	time:2.3e+02	loss:6.76e-04, loss_r:1.92e-04, loss_b:4.84e-06
# Epoch # 18000/25000	time:2.3e+02	loss:6.70e-04, loss_r:1.90e-04, loss_b:4.81e-06
# Epoch # 18100/25000	time:2.3e+02	loss:7.39e-04, loss_r:1.93e-04, loss_b:5.46e-06
# Epoch # 18200/25000	time:2.3e+02	loss:7.18e-04, loss_r:1.81e-04, loss_b:5.37e-06
# Epoch # 18300/25000	time:2.3e+02	loss:7.07e-04, loss_r:1.76e-04, loss_b:5.32e-06
# Epoch # 18400/25000	time:2.3e+02	loss:6.99e-04, loss_r:1.72e-04, loss_b:5.27e-06
# Epoch # 18500/25000	time:2.3e+02	loss:7.15e-04, loss_r:1.68e-04, loss_b:5.47e-06
# Epoch # 18600/25000	time:2.3e+02	loss:6.86e-04, loss_r:1.66e-04, loss_b:5.19e-06
# Epoch # 18700/25000	time:2.4e+02	loss:6.80e-04, loss_r:1.64e-04, loss_b:5.16e-06
# Epoch # 18800/25000	time:2.4e+02	loss:6.79e-04, loss_r:1.63e-04, loss_b:5.16e-06
# Epoch # 18900/25000	time:2.4e+02	loss:6.71e-04, loss_r:1.62e-04, loss_b:5.09e-06
# Epoch # 19000/25000	time:2.4e+02	loss:6.68e-04, loss_r:1.63e-04, loss_b:5.05e-06
# Epoch # 19100/25000	time:2.4e+02	loss:7.28e-04, loss_r:2.11e-04, loss_b:5.17e-06
# Epoch # 19200/25000	time:2.4e+02	loss:6.95e-04, loss_r:1.95e-04, loss_b:5.00e-06
# Epoch # 19300/25000	time:2.4e+02	loss:6.76e-04, loss_r:1.87e-04, loss_b:4.89e-06
# Epoch # 19400/25000	time:2.4e+02	loss:6.64e-04, loss_r:1.82e-04, loss_b:4.82e-06
# Epoch # 19500/25000	time:2.5e+02	loss:7.17e-04, loss_r:2.11e-04, loss_b:5.06e-06
# Epoch # 19600/25000	time:2.5e+02	loss:6.47e-04, loss_r:1.74e-04, loss_b:4.72e-06
# Epoch # 19700/25000	time:2.5e+02	loss:6.40e-04, loss_r:1.71e-04, loss_b:4.68e-06
# Epoch # 19800/25000	time:2.5e+02	loss:7.19e-04, loss_r:2.49e-04, loss_b:4.70e-06
# Epoch # 19900/25000	time:2.5e+02	loss:6.30e-04, loss_r:1.68e-04, loss_b:4.63e-06
# Epoch # 20000/25000	time:2.5e+02	loss:6.32e-04, loss_r:1.70e-04, loss_b:4.62e-06
# Epoch # 20100/25000	time:2.5e+02	loss:6.67e-04, loss_r:1.72e-04, loss_b:4.95e-06
# Epoch # 20200/25000	time:2.5e+02	loss:6.46e-04, loss_r:1.65e-04, loss_b:4.81e-06
# Epoch # 20300/25000	time:2.6e+02	loss:6.79e-04, loss_r:1.64e-04, loss_b:5.16e-06
# Epoch # 20400/25000	time:2.6e+02	loss:6.24e-04, loss_r:1.59e-04, loss_b:4.66e-06
# Epoch # 20500/25000	time:2.6e+02	loss:6.17e-04, loss_r:1.57e-04, loss_b:4.60e-06
# Epoch # 20600/25000	time:2.6e+02	loss:6.15e-04, loss_r:1.56e-04, loss_b:4.59e-06
# Epoch # 20700/25000	time:2.6e+02	loss:6.44e-04, loss_r:1.82e-04, loss_b:4.62e-06
# Epoch # 20800/25000	time:2.6e+02	loss:6.00e-04, loss_r:1.52e-04, loss_b:4.48e-06
# Epoch # 20900/25000	time:2.6e+02	loss:5.96e-04, loss_r:1.51e-04, loss_b:4.45e-06
# Epoch # 21000/25000	time:2.6e+02	loss:5.92e-04, loss_r:1.50e-04, loss_b:4.42e-06
# Epoch # 21100/25000	time:2.7e+02	loss:6.34e-04, loss_r:1.87e-04, loss_b:4.47e-06
# Epoch # 21200/25000	time:2.7e+02	loss:6.16e-04, loss_r:1.73e-04, loss_b:4.43e-06
# Epoch # 21300/25000	time:2.7e+02	loss:6.07e-04, loss_r:1.66e-04, loss_b:4.40e-06
# Epoch # 21400/25000	time:2.7e+02	loss:6.00e-04, loss_r:1.62e-04, loss_b:4.38e-06
# Epoch # 21500/25000	time:2.7e+02	loss:5.94e-04, loss_r:1.59e-04, loss_b:4.35e-06
# Epoch # 21600/25000	time:2.7e+02	loss:5.92e-04, loss_r:1.56e-04, loss_b:4.36e-06
# Epoch # 21700/25000	time:2.7e+02	loss:5.85e-04, loss_r:1.54e-04, loss_b:4.31e-06
# Epoch # 21800/25000	time:2.7e+02	loss:5.95e-04, loss_r:1.63e-04, loss_b:4.32e-06
# Epoch # 21900/25000	time:2.8e+02	loss:5.77e-04, loss_r:1.50e-04, loss_b:4.26e-06
# Epoch # 22000/25000	time:2.8e+02	loss:5.72e-04, loss_r:1.48e-04, loss_b:4.24e-06
# Epoch # 22100/25000	time:2.8e+02	loss:6.52e-04, loss_r:1.74e-04, loss_b:4.78e-06
# Epoch # 22200/25000	time:2.8e+02	loss:6.27e-04, loss_r:1.60e-04, loss_b:4.68e-06
# Epoch # 22300/25000	time:2.8e+02	loss:6.14e-04, loss_r:1.53e-04, loss_b:4.61e-06
# Epoch # 22400/25000	time:2.8e+02	loss:6.05e-04, loss_r:1.48e-04, loss_b:4.56e-06
# Epoch # 22500/25000	time:2.8e+02	loss:5.97e-04, loss_r:1.45e-04, loss_b:4.52e-06
# Epoch # 22600/25000	time:2.8e+02	loss:5.91e-04, loss_r:1.42e-04, loss_b:4.49e-06
# Epoch # 22700/25000	time:2.9e+02	loss:5.88e-04, loss_r:1.40e-04, loss_b:4.48e-06
# Epoch # 22800/25000	time:2.9e+02	loss:5.81e-04, loss_r:1.38e-04, loss_b:4.43e-06
# Epoch # 22900/25000	time:2.9e+02	loss:5.77e-04, loss_r:1.37e-04, loss_b:4.40e-06
# Epoch # 23000/25000	time:2.9e+02	loss:5.73e-04, loss_r:1.35e-04, loss_b:4.38e-06
# Epoch # 23100/25000	time:2.9e+02	loss:5.80e-04, loss_r:1.43e-04, loss_b:4.37e-06
# Epoch # 23200/25000	time:2.9e+02	loss:5.64e-04, loss_r:1.34e-04, loss_b:4.30e-06
# Epoch # 23300/25000	time:2.9e+02	loss:5.55e-04, loss_r:1.30e-04, loss_b:4.24e-06
# Epoch # 23400/25000	time:2.9e+02	loss:5.48e-04, loss_r:1.28e-04, loss_b:4.20e-06
# Epoch # 23500/25000	time:3.0e+02	loss:5.74e-04, loss_r:1.30e-04, loss_b:4.44e-06
# Epoch # 23600/25000	time:3.0e+02	loss:5.38e-04, loss_r:1.24e-04, loss_b:4.14e-06
# Epoch # 23700/25000	time:3.0e+02	loss:8.14e-04, loss_r:1.48e-04, loss_b:6.67e-06
# Epoch # 23800/25000	time:3.0e+02	loss:5.30e-04, loss_r:1.22e-04, loss_b:4.09e-06
# Epoch # 23900/25000	time:3.0e+02	loss:5.27e-04, loss_r:1.21e-04, loss_b:4.06e-06
# Epoch # 24000/25000	time:3.0e+02	loss:5.24e-04, loss_r:1.20e-04, loss_b:4.04e-06
# Epoch # 24100/25000	time:3.0e+02	loss:5.61e-04, loss_r:1.44e-04, loss_b:4.17e-06
# Epoch # 24200/25000	time:3.0e+02	loss:5.46e-04, loss_r:1.36e-04, loss_b:4.10e-06
# Epoch # 24300/25000	time:3.1e+02	loss:5.38e-04, loss_r:1.33e-04, loss_b:4.05e-06
# Epoch # 24400/25000	time:3.1e+02	loss:5.32e-04, loss_r:1.31e-04, loss_b:4.01e-06
# Epoch # 24500/25000	time:3.1e+02	loss:5.28e-04, loss_r:1.30e-04, loss_b:3.98e-06
# Epoch # 24600/25000	time:3.1e+02	loss:5.23e-04, loss_r:1.28e-04, loss_b:3.95e-06
# Epoch # 24700/25000	time:3.1e+02	loss:5.19e-04, loss_r:1.27e-04, loss_b:3.92e-06
# Epoch # 24800/25000	time:3.1e+02	loss:9.12e-04, loss_r:2.61e-04, loss_b:6.51e-06
# Epoch # 24900/25000	time:3.1e+02	loss:5.13e-04, loss_r:1.25e-04, loss_b:3.87e-06
# Epoch # 25000/25000	time:3.1e+02	loss:5.09e-04, loss_r:1.25e-04, loss_b:3.85e-06

# %%
mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(mlp_layers)
# 使用第一种权重生成方法
pinn = PINNAC(backbone, mu, sigma).to(device)

model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['state_dict'])

optimizer_lbfgs = optim.LBFGS(pinn.backbone.parameters(), max_iter=newton_iter, line_search_fn="strong_wolfe",tolerance_grad=1.e-5,lr=0.8, tolerance_change=1.e-9)

loss_r_log_lbfgs = []
loss_b_log_lbfgs = []
it = 0
with open(train_info_path + 'train_info.txt', 'a') as f:
    f.write('Training by LBFGS:\n')


def closure():
    global it
    pinn.zero_grad()
    loss_res, loss_bcs = pinn(X_res, X_bcs)
    loss = loss_res + 100*loss_bcs
    loss.backward()
    it = it + 1
    loss_r_log_lbfgs.append(loss_res.item())
    loss_b_log_lbfgs.append(loss_bcs.item())
    if (it + 1) % 100 == 0:
        info = f'Iter # {it + 1:4d}' +  f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_b:{loss_bcs.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
    
        
    return loss

for epoch in range(lbfgs_epoch):
    optimizer_lbfgs.step(closure)
    if loss.item() < best_loss:
        # 保存训练loss最低的模型
        torch.save(model_state, os.path.join(model_path, f'backbone_lbfgs.pth'))
        best_loss = loss.item()
    if (epoch+1) % 1000 ==0:
        X_res, X_bcs = dataset.train_data()
# Out:
# forward with normalization, mu=[-0.16564859449863434, -0.16662296652793884], sigma=[0.5519244074821472, 0.5509239435195923]
# Iter #  100loss:1.22e-03, loss_r:4.11e-04, loss_b:8.08e-06
# Iter #  200loss:7.69e-04, loss_r:2.91e-04, loss_b:4.78e-06
# Iter #  300loss:5.41e-04, loss_r:1.95e-04, loss_b:3.46e-06
# Iter #  400loss:4.31e-04, loss_r:1.36e-04, loss_b:2.96e-06
# Iter #  500loss:3.57e-04, loss_r:1.17e-04, loss_b:2.40e-06
# Iter #  600loss:2.99e-04, loss_r:9.51e-05, loss_b:2.04e-06
# Iter #  700loss:2.58e-04, loss_r:8.53e-05, loss_b:1.73e-06
# Iter #  800loss:2.28e-04, loss_r:7.50e-05, loss_b:1.53e-06
# Iter #  900loss:2.03e-04, loss_r:6.99e-05, loss_b:1.33e-06
# Iter # 1000loss:1.77e-04, loss_r:6.61e-05, loss_b:1.10e-06
# Iter # 1100loss:1.55e-04, loss_r:6.13e-05, loss_b:9.41e-07
# Iter # 1200loss:1.38e-04, loss_r:5.60e-05, loss_b:8.20e-07
# Iter # 1300loss:1.22e-04, loss_r:4.93e-05, loss_b:7.23e-07
# Iter # 1400loss:1.09e-04, loss_r:4.37e-05, loss_b:6.56e-07
# Iter # 1500loss:9.92e-05, loss_r:4.01e-05, loss_b:5.92e-07
# Iter # 1600loss:9.16e-05, loss_r:3.75e-05, loss_b:5.41e-07
# Iter # 1700loss:8.39e-05, loss_r:3.43e-05, loss_b:4.95e-07
# Iter # 1800loss:7.72e-05, loss_r:3.00e-05, loss_b:4.72e-07
# Iter # 1900loss:7.17e-05, loss_r:2.77e-05, loss_b:4.39e-07
# Iter # 2000loss:6.63e-05, loss_r:2.61e-05, loss_b:4.02e-07
# Iter # 2100loss:6.10e-05, loss_r:2.42e-05, loss_b:3.68e-07
# Iter # 2200loss:5.56e-05, loss_r:2.25e-05, loss_b:3.31e-07
# Iter # 2300loss:5.11e-05, loss_r:2.14e-05, loss_b:2.96e-07
# Iter # 2400loss:4.78e-05, loss_r:2.10e-05, loss_b:2.68e-07
# Iter # 2500loss:4.40e-05, loss_r:1.91e-05, loss_b:2.49e-07
# Iter # 2600loss:4.14e-05, loss_r:1.86e-05, loss_b:2.29e-07
# Iter # 2700loss:3.85e-05, loss_r:1.80e-05, loss_b:2.06e-07
# Iter # 2800loss:3.60e-05, loss_r:1.69e-05, loss_b:1.92e-07
# Iter # 2900loss:3.38e-05, loss_r:1.59e-05, loss_b:1.79e-07
# Iter # 3000loss:3.06e-05, loss_r:1.52e-05, loss_b:1.54e-07
# Iter # 3100loss:2.78e-05, loss_r:1.35e-05, loss_b:1.42e-07
# Iter # 3200loss:2.56e-05, loss_r:1.27e-05, loss_b:1.30e-07
# Iter # 3300loss:2.39e-05, loss_r:1.18e-05, loss_b:1.20e-07
# Iter # 3400loss:2.20e-05, loss_r:1.13e-05, loss_b:1.07e-07
# Iter # 3500loss:1.99e-05, loss_r:1.07e-05, loss_b:9.21e-08
# Iter # 3600loss:1.86e-05, loss_r:1.01e-05, loss_b:8.54e-08
# Iter # 3700loss:1.74e-05, loss_r:9.46e-06, loss_b:7.90e-08
# Iter # 3800loss:1.61e-05, loss_r:8.83e-06, loss_b:7.25e-08
# Iter # 3900loss:1.52e-05, loss_r:8.42e-06, loss_b:6.81e-08
# Iter # 4000loss:1.45e-05, loss_r:7.90e-06, loss_b:6.55e-08
# Iter # 4100loss:1.37e-05, loss_r:7.54e-06, loss_b:6.17e-08
# Iter # 4200loss:1.31e-05, loss_r:7.33e-06, loss_b:5.79e-08
# Iter # 4300loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4400loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4500loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4600loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4700loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4800loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 4900loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5000loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5100loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5200loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5300loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5400loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5500loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5600loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5700loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5800loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 5900loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6000loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6100loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6200loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6300loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6400loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6500loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6600loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6700loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6800loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 6900loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7000loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7100loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7200loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7300loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7400loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7500loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7600loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7700loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7800loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 7900loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8000loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8100loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8200loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8300loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8400loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8500loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8600loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8700loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8800loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 8900loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08
# Iter # 9000loss:1.30e-05, loss_r:7.21e-06, loss_b:5.76e-08

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
plt.figure(figsize=(8, 6))
plt.subplot(111)
plt.plot(loss_r_log_adam+loss_r_log_lbfgs, label='$loss$')
plt.plot(loss_b_log_adam+loss_b_log_lbfgs, label='$loss$')
plt.xlabel('epochs')
plt.yscale('log')
plt.legend()
plt.grid()
plt.savefig('loss_log.png', dpi=100)
plt.show()
plt.savefig('loss_possion_Lshape.png', dpi=400)

# %%
# load the data
data = scipy.io.loadmat('Lpoission_more.mat')

x = data['x']
y = data['y']
u_star = data['z']

ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_position(('data', -1))
ax.spines['left'].set_position(('data', -1))
plt.scatter(x, y, c=u_star, s=1, marker='.', cmap='jet')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title(r'Reference $u(x,y)$')
plt.tight_layout()

# print(x.shape)
# xx, yy = np.meshgrid(x, y)
X = np.concatenate([x.reshape((-1, 1)), y.reshape((-1, 1))], axis=1)
u_star = u_star.reshape((1, -1))
X.shape
u_star.shape
# Out:
# (1, 109610)

# %%
pinn.eval()
# X = np.hstack((xx.reshape(-1,1), yy.reshape(-1,1)))
X = torch.from_numpy(X).double()

pinn.mu = pinn.mu.cpu().double()
pinn.sigma = pinn.sigma.cpu().double()
pinn = pinn.cpu().double()
u_pred = pinn.net_u(X).detach().numpy()
u_pred = u_pred.reshape(x.shape)

error = np.linalg.norm(u_pred - u_star) / np.linalg.norm(u_star)
print('Relative l2 error: {:.3e}'.format(error))
u_pred.shape
# Out:
# Relative l2 error: 2.543e-03
# (1, 109610)

# %%
ax = plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_position(('data', -1))
ax.spines['left'].set_position(('data', -1))
plt.scatter(x, y, c=u_pred, s=1, marker='.', cmap='jet')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title(r'Predicted $u(x,y)$')
plt.tight_layout()

# %%
plt.rcParams.update({'font.size':18})

fig, ax = plt.subplots(3, figsize=(24, 5))

ax1 = plt.subplot(1, 3, 1)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['bottom'].set_position(('data', -1))
ax1.spines['left'].set_position(('data', -1))
plt.scatter(x, y, c=u_star, s=1, marker='.', cmap='jet')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title(r'Reference $u(x,y)$')
plt.tight_layout()
ax1.set_aspect(1./ax1.get_data_ratio())

ax2 = plt.subplot(1, 3, 2)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['bottom'].set_position(('data', -1))
ax2.spines['left'].set_position(('data', -1))
plt.scatter(x, y, c=u_pred, s=1, marker='.', cmap='jet')
plt.colorbar()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title(r'Predicted $u(x,y)$')
plt.tight_layout()
ax2.set_aspect(1./ax2.get_data_ratio())

ax3 = plt.subplot(1, 3, 3)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['bottom'].set_position(('data', -1))
ax3.spines['left'].set_position(('data', -1))
plt.scatter(x, y, c=np.abs(u_star-u_pred), s=1, marker='.', cmap='jet')
cbar = plt.colorbar()
cbar.formatter.set_powerlimits((0,0))
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title(r'Absolute error')
plt.tight_layout()
ax3.set_aspect(1./ax3.get_data_ratio())
plt.savefig('result_possion_Lshape.png', dpi=400)
# Out:
# /tmp/ipykernel_39417/3680345.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(1, 3, 1)
