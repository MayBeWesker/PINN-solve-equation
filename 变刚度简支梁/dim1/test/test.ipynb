# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io

import os
import time

# %%
def piecewise_function(x):
    return torch.where(x < 0, x**2, torch.sin(x))

# %%
# 生成训练数据
torch.manual_seed(42)
X_train = torch.randn(100, 1)

# 计算目标值
y_train = piecewise_function(X_train)

# %%
data = pd.read_excel('dabashuju.xlsx')
data.keys()
x = data["x"]
y = data["y"]

# %%
plt.plot(x, y)

# %%
data = io.loadmat('result.mat')
data.keys()
x_1 = data["x"].reshape(-1,1)
y_1 = data["y"][0,:].reshape(-1,1)
plt.plot(x_1, y_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0e58525115d1> in <module>
#       4 y_1 = data["y"][0,:].reshape(-1,1)
#       5 plt.plot(x_1, y_1)
# ----> 6 print(x-x_1)
#
# d:\Program Files\Anaconda\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# d:\Program Files\Anaconda\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#      95     @unpack_zerodim_and_defer("__sub__")
#      96     def __sub__(self, other):
# ---> 97         return self._arith_method(other, operator.sub)
#      98
#      99     @unpack_zerodim_and_defer("__rsub__")
#
# d:\Program Files\Anaconda\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
# -> 5000         return self._construct_result(result, name=res_name)
#    5001
#    5002
#
# d:\Program Files\Anaconda\lib\site-packages\pandas\core\series.py in _construct_result(self, result, name)
#    2761         # We do not pass dtype to ensure that the Series constructor
#    2762         #  does inference in the case where `result` has object-dtype.
# -> 2763         out = self._constructor(result, index=self.index)
#    2764         out = out.__finalize__(self)
#    2765
#
# d:\Program Files\Anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     348                 try:
#     349                     if len(index) != len(data):
# --> 350                         raise ValueError(
#     351                             f"Length of passed values is {len(data)}, "
#     352                             f"index implies {len(index)}."
#
# ValueError: Length of passed values is 5000, index implies 400.

# %%
X_train.shape, y_train.shape
plt.scatter(X_train, y_train)
