# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_359313/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io

import os
import time

# %% [markdown]
# ## 超参数设置

# %%
domain = (-1, 1, -1, 1)
xmin, xmax, ymin, ymax = domain
mlp_layers = [1] + [40]*4 + [1]
mlp_layers_k = [1] + [20]*2 + [1]
# n_iters = 200000
n_iters = 50000
learning_rate = 1e-3
gamma = 0.6

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# 生成x的数据点
x = torch.linspace(0, 1, 100)

# 计算对应的y值
#计算解析解，光滑刚度最小值为18750KN.m
y1 = (125*torch.arctan(torch.tensor(2)))/32 - (25*x)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x**2 - x + 5/16))/128 + (
    125*torch.arctan(4*x - 2))/32 + x*((25*x)/4 - (125*torch.arctan(4*x - 2))/16) - (25*x**2)/8

#计算解析解，光滑刚度最小值为31250KN.m
y2 = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
    45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
    45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
    (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
    15 * x ** 2) / 4

#计算解析解，光滑刚度最小值为62500KN.m
y3 = (45*torch.log(x**2 - x + 3/4))/8 - (45*torch.log(torch.tensor(3/4)))/8 - (15*x)/2 + (
    45*2**(1/2)*torch.arctan(2**(1/2)*x - 2**(1/2)/2))/8 + x*(15*x - (45*2**(1/2)*torch.arctan(2**(1/2)*x - 2**(1/2)/2))/4) - (
    15*x**2)/2 + (45*2**(1/2)*torch.arctan(torch.tensor(2**(1/2)/2)))/8

#计算解析解,刚度不变一直为93750KN.m
y4 = 5/3*x**4-10/3*x**3+5/3*x

# 创建一个数据框
data = pd.DataFrame({'x': x.numpy(), 'y1': y1.numpy()})

# 绘制图形
plt.figure(figsize=(8, 6))
plt.plot(x.numpy(), y1.numpy(), 'r-', label='Minimum with 5times')
plt.plot(x.numpy(), y2.numpy(), 'k-', label='Minimum with 3times')
plt.plot(x.numpy(), y3.numpy(), 'g-', label='Minimum with 1.5times')
plt.plot(x.numpy(), y4.numpy(), 'b-', label='unchange')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Analytic Solution')
plt.legend()
plt.grid(True)

# 保存数据到Excel文件
data.to_excel('output.xlsx', index=False)

# 显示图形
plt.show()

# %%
class Dataset:
    def __init__(self, N):
        self.x = torch.linspace(0, 1, N)
        
    
    def train_data(self, N, verbose=None):
        # 无量纲化
        t0 = 5
        K0 = 31250
        U0 = 0.001

        x = self.x
        x_1 = x[(x <= 1/3)]
        x_2 = x[(x > 1/3) & (x <= 2/3)]
        x_3 = x[(x > 2/3)]
        k_1 = self.k(x_1)
        k_2 = self.k(x_2)
        k_3 = self.k(x_3)
        y_1 = (45 * torch.log(x_1 ** 2 - x_1 + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x_1) / 4 + (
            45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_1 - 2 ** (1 / 2))) / 16 + (
            45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x_1 * (
            (15 * x_1) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_1 - 2 ** (1 / 2))) / 8) - (
            15 * x_1 ** 2) / 4

        y_2 = (45 * torch.log(x_2 ** 2 - x_2 + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x_2) / 4 + (
            45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_2 - 2 ** (1 / 2))) / 16 + (
            45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x_2 * (
            (15 * x_2) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_2 - 2 ** (1 / 2))) / 8) - (
            15 * x_2 ** 2) / 4

        y_3 = (45 * torch.log(x_3 ** 2 - x_3 + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x_3) / 4 + (
            45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_3 - 2 ** (1 / 2))) / 16 + (
            45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x_3 * (
            (15 * x_3) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x_3 - 2 ** (1 / 2))) / 8) - (
            15 * x_3 ** 2) / 4

        # y = 5/3*x**4 - 10/3*x**3 + 5/3*x
        # print(self.x.shape)
        idx = np.random.randint(0,x_1.shape[0]-1,N)
        # return x.reshape(-1,1), k.reshape(-1,1), y.reshape(-1,1)
        # return x[idx].reshape(-1, 1), k[idx].reshape(-1,1), y[idx].reshape(-1,1)
        return x_1[idx].reshape(-1, 1), k_1[idx].reshape(-1, 1), y_1[idx].reshape(-1, 1), x_2[idx].reshape(-1, 1), k_2[idx].reshape(-1, 1), y_2[idx].reshape(-1, 1), x_3[idx].reshape(-1, 1), k_3[idx].reshape(-1, 1), y_3[idx].reshape(-1, 1)

    # k函数
    def k(self, t):
        return 8/3*t**2 - 8/3*t + 1
        # return 10000*(t*5-2.5)**2 + 31250
    

N = 5000
dataset = Dataset(N)
t1_data, k1_data, u1_data, t2_data, k2_data, u2_data, t3_data, k3_data, u3_data = dataset.train_data(N)
# print(t_data.shape, k_data.shape, u_data.shape)
print(t1_data.shape, k1_data.shape, u1_data.shape)
# Out:
# torch.Size([5000, 1]) torch.Size([5000, 1]) torch.Size([5000, 1])

# %%
# u_data
plt.scatter(t1_data, u1_data)

# %%
# k_data
plt.scatter(t1_data, k1_data)

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            self.model.add_module(f'fc{i+1}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            self.model.add_module(f'act{i+1}', nn.Tanh())
        self.model.add_module(f'fc{len(mlp_layers)-1})', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
    
    def forward(self, X):
        return self.model(X)
    
    
mlp = MLP(mlp_layers)
mlp_k = MLP(mlp_layers_k)
mlp.model
# Out:
# Sequential(
#   (fc1): Linear(in_features=1, out_features=40, bias=True)
#   (act1): Tanh()
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (act2): Tanh()
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (act3): Tanh()
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (act4): Tanh()
#   (fc5)): Linear(in_features=40, out_features=1, bias=False)
# )

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINNHelmholtz(nn.Module):
    def __init__(self, backbone, nn_k):
        super(PINNHelmholtz, self).__init__()
        self.backbone = backbone
        self.nn_k = nn_k
        
    def forward(self, t1_data, t2_data, t3_data, u1_data, u2_data, u3_data):
        f1_res_pred = self.net_f(t1_data)
        f2_res_pred = self.net_f(t2_data)
        f3_res_pred = self.net_f(t3_data)
        u1_pred = self.net_u(t1_data)
        u2_pred = self.net_u(t2_data)
        u3_pred = self.net_u(t3_data)

        loss_res_u1 = torch.mean((f1_res_pred - 30) ** 2)
        loss_res_u2 = torch.mean((f2_res_pred - 30) ** 2)
        loss_res_u3 = torch.mean((f3_res_pred - 30) ** 2)
        loss_data_u1 = torch.mean((u1_pred - u1_data) ** 2)
        loss_data_u2 = torch.mean((u2_pred - u2_data) ** 2)
        loss_data_u3 = torch.mean((u3_pred - u3_data) ** 2)
        return loss_res_u1, loss_res_u2, loss_res_u3, loss_data_u1, loss_data_u2, loss_data_u3
    
    def net_u(self, X):
        return self.backbone(X)
        # return self.backbone(X)*(X*(X-1))
    
    def net_k(self, X):
        # return 8/3*X**2 - 8/3*X + 1
        return self.nn_k(X)*(X*(X-1))+1

    def net_3u(self, X):
        X.requires_grad_(True)
        u = self.net_u(X)

        # 求u的梯度
        du = grad(u, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        return d3u
    
    def net_f(self, X):
        X.requires_grad_(True)
        u_pred = self.net_u(X)
        
        # 求u的梯度
        du = grad(u_pred, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        d4u = grad(d3u, X)[0]
        
        k_pred = self.net_k(X)
        dk = grad(k_pred, X)[0]
        d2k = grad(dk, X)[0]
        
        f_res_pred = 0.75*k_pred*d4u + 1.5*dk*d3u + 0.75*d2k*d2u
        
        return f_res_pred
    

pinn = PINNHelmholtz(mlp,mlp_k)

# %% [markdown]
# ## Adam训练

# %%
# 训练
N = 1000
dataset = Dataset(N)
t1_data, k1_data, u1_data, t2_data, k2_data, u2_data, t3_data, k3_data, u3_data = dataset.train_data(N)
t1_data = t1_data.float().to(device)
t2_data = t2_data.float().to(device)
t3_data = t3_data.float().to(device)
u1_data = u1_data.float().to(device)
u2_data = u2_data.float().to(device)
u3_data = u3_data.float().to(device)

backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=learning_rate)
optimizer_adam_k = optim.Adam(pinn.nn_k.parameters(), lr=learning_rate)

lr_sche = ReduceLROnPlateau(optimizer_adam, mode='min', factor=gamma, verbose=True)
lr_sche_k = ReduceLROnPlateau(optimizer_adam_k, mode='min', factor=gamma, verbose=True)
# lr_sche = ExponentialLR(optimizer_adam, gamma=gamma, verbose=True)
# lr_sche_k = ExponentialLR(optimizer_adam_k, gamma=gamma, verbose=True)

logger = {
    "loss": [],
    "loss_res_u1": [],
    "loss_res_u2": [],
    "loss_res_u3": [],
    "loss_data_u1": [],
    "loss_data_u2": [],
    "loss_data_u3": [],
    "iter": []
}
with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for it in range(n_iters):
    pinn.zero_grad()
    loss_res_u1, loss_res_u2, loss_res_u3, loss_data_u1, loss_data_u2, loss_data_u3 = pinn(
        t1_data, t2_data, t3_data, u1_data, u2_data, u3_data)
    # loss = 1*(loss_res_u) + 1e2*(loss_data_u)
    loss = (1e2*loss_res_u1 + 1*loss_res_u2 + 1e2*loss_res_u3) + \
        (1e7*loss_data_u1 + 1e4*loss_data_u2 + 1e7*loss_data_u3)
    loss_res_u = 1*loss_res_u1 + 1*loss_res_u2 + 1*loss_res_u3
    loss_data_u = 1*loss_data_u1 + 1*loss_data_u2 + 1*loss_data_u3
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_k.step()
    
    # 保存训练信息 -------
    logger["loss"].append(loss.item())
    logger["loss_res_u1"].append(loss_res_u1.item())
    logger["loss_res_u2"].append(loss_res_u2.item())
    logger["loss_res_u3"].append(loss_res_u3.item())
    logger["loss_data_u1"].append(loss_data_u1.item())
    logger["loss_data_u2"].append(loss_data_u2.item())
    logger["loss_data_u3"].append(loss_data_u3.item())
    logger["iter"].append(it + 1)
    
    if (it + 1) % 100 == 0:  # 打印训练信息 -------
        info = f'Iter # {it+1:4d}/{n_iters}\ttime:{time.time()-start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r_u:{loss_res_u.item():.2e}, loss_d_u:{loss_data_u.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        
    if (it + 1) % 100 == 0:  # 学习率衰减 -------
        lr_sche.step(loss)
        lr_sche_k.step(loss)
# Out:
# Iter #  100/50000	time:2.8	loss:2.10e+06, loss_r_u:2.35e+03, loss_d_u:5.78e-01
# Iter #  200/50000	time:5.5	loss:6.95e+05, loss_r_u:2.09e+03, loss_d_u:1.56e-01
# Iter #  300/50000	time:8.3	loss:8.44e+03, loss_r_u:1.73e+03, loss_d_u:8.52e-04
# Iter #  400/50000	time:11.0	loss:3.77e+03, loss_r_u:1.18e+03, loss_d_u:9.57e-04
# Iter #  500/50000	time:13.7	loss:2.97e+03, loss_r_u:9.60e+02, loss_d_u:7.32e-04
# Iter #  600/50000	time:16.5	loss:1.81e+04, loss_r_u:7.24e+02, loss_d_u:4.35e-03
# Iter #  700/50000	time:19.2	loss:1.87e+03, loss_r_u:7.10e+02, loss_d_u:5.78e-04
# Iter #  800/50000	time:21.9	loss:1.93e+03, loss_r_u:6.38e+02, loss_d_u:3.82e-04
# Iter #  900/50000	time:24.6	loss:1.34e+03, loss_r_u:5.46e+02, loss_d_u:3.97e-04
# Iter # 1000/50000	time:27.3	loss:2.27e+03, loss_r_u:4.84e+02, loss_d_u:7.89e-04
# Iter # 1100/50000	time:30.1	loss:1.01e+03, loss_r_u:4.33e+02, loss_d_u:2.85e-04
# Iter # 1200/50000	time:32.8	loss:8.46e+02, loss_r_u:3.71e+02, loss_d_u:2.30e-04
# Iter # 1300/50000	time:35.5	loss:8.26e+02, loss_r_u:3.53e+02, loss_d_u:2.46e-04
# Iter # 1400/50000	time:38.2	loss:6.84e+02, loss_r_u:3.07e+02, loss_d_u:1.76e-04
# Iter # 1500/50000	time:41.0	loss:1.01e+04, loss_r_u:2.20e+02, loss_d_u:1.86e-03
# Iter # 1600/50000	time:43.7	loss:5.92e+02, loss_r_u:2.65e+02, loss_d_u:1.50e-04
# Iter # 1700/50000	time:46.4	loss:5.00e+02, loss_r_u:2.29e+02, loss_d_u:1.20e-04
# Iter # 1800/50000	time:49.2	loss:5.96e+03, loss_r_u:2.13e+02, loss_d_u:6.44e-04
# Iter # 1900/50000	time:51.9	loss:4.54e+02, loss_r_u:2.03e+02, loss_d_u:1.12e-04
# Iter # 2000/50000	time:54.6	loss:3.84e+02, loss_r_u:1.76e+02, loss_d_u:8.91e-05
# Iter # 2100/50000	time:57.3	loss:3.26e+02, loss_r_u:1.49e+02, loss_d_u:7.41e-05
# Iter # 2200/50000	time:60.0	loss:3.83e+02, loss_r_u:1.60e+02, loss_d_u:1.13e-04
# Iter # 2300/50000	time:62.8	loss:3.12e+02, loss_r_u:1.41e+02, loss_d_u:7.32e-05
# Iter # 2400/50000	time:65.5	loss:2.63e+02, loss_r_u:1.19e+02, loss_d_u:5.87e-05
# Iter # 2500/50000	time:68.3	loss:5.55e+02, loss_r_u:1.29e+02, loss_d_u:6.78e-05
# Iter # 2600/50000	time:71.0	loss:2.58e+02, loss_r_u:1.13e+02, loss_d_u:6.33e-05
# Iter # 2700/50000	time:73.7	loss:2.16e+02, loss_r_u:9.48e+01, loss_d_u:5.06e-05
# Iter # 2800/50000	time:76.5	loss:2.97e+02, loss_r_u:9.16e+01, loss_d_u:6.86e-05
# Iter # 2900/50000	time:79.2	loss:2.28e+02, loss_r_u:9.59e+01, loss_d_u:6.23e-05
# Iter # 3000/50000	time:81.9	loss:1.89e+02, loss_r_u:8.05e+01, loss_d_u:4.84e-05
# Iter # 3100/50000	time:84.7	loss:1.58e+02, loss_r_u:6.56e+01, loss_d_u:3.94e-05
# Iter # 3200/50000	time:87.4	loss:2.18e+02, loss_r_u:7.93e+01, loss_d_u:7.87e-05
# Iter # 3300/50000	time:90.1	loss:1.72e+02, loss_r_u:7.03e+01, loss_d_u:4.89e-05
# Iter # 3400/50000	time:92.9	loss:1.41e+02, loss_r_u:5.70e+01, loss_d_u:3.87e-05
# Iter # 3500/50000	time:95.6	loss:7.67e+02, loss_r_u:4.30e+01, loss_d_u:7.82e-05
# Iter # 3600/50000	time:98.3	loss:1.65e+02, loss_r_u:6.34e+01, loss_d_u:5.53e-05
# Iter # 3700/50000	time:101.1	loss:1.34e+02, loss_r_u:5.25e+01, loss_d_u:4.12e-05
# Iter # 3800/50000	time:103.8	loss:1.09e+02, loss_r_u:4.15e+01, loss_d_u:3.25e-05
# Iter # 3900/50000	time:106.6	loss:1.88e+02, loss_r_u:4.46e+01, loss_d_u:8.23e-05
# Iter # 4000/50000	time:109.3	loss:1.33e+02, loss_r_u:4.98e+01, loss_d_u:4.73e-05
# Iter # 4100/50000	time:112.0	loss:1.07e+02, loss_r_u:3.97e+01, loss_d_u:3.57e-05
# Iter # 4200/50000	time:114.8	loss:8.60e+01, loss_r_u:3.06e+01, loss_d_u:2.79e-05
# Iter # 4300/50000	time:117.5	loss:3.57e+02, loss_r_u:4.05e+01, loss_d_u:1.49e-04
# Iter # 4400/50000	time:120.2	loss:1.17e+02, loss_r_u:4.23e+01, loss_d_u:4.52e-05
# Iter # 4500/50000	time:123.0	loss:9.29e+01, loss_r_u:3.30e+01, loss_d_u:3.38e-05
# Iter # 4600/50000	time:125.7	loss:7.39e+01, loss_r_u:2.49e+01, loss_d_u:2.61e-05
# Iter # 4700/50000	time:128.4	loss:2.71e+03, loss_r_u:2.70e+01, loss_d_u:2.81e-04
# Iter # 4800/50000	time:131.2	loss:1.02e+02, loss_r_u:3.44e+01, loss_d_u:4.20e-05
# Iter # 4900/50000	time:133.9	loss:7.94e+01, loss_r_u:2.65e+01, loss_d_u:3.11e-05
# Iter # 5000/50000	time:136.6	loss:6.25e+01, loss_r_u:1.97e+01, loss_d_u:2.36e-05
# Iter # 5100/50000	time:139.4	loss:1.74e+03, loss_r_u:2.38e+01, loss_d_u:1.74e-04
# Iter # 5200/50000	time:142.1	loss:8.48e+01, loss_r_u:2.75e+01, loss_d_u:3.69e-05
# Iter # 5300/50000	time:144.8	loss:6.57e+01, loss_r_u:2.06e+01, loss_d_u:2.71e-05
# Iter # 5400/50000	time:147.5	loss:5.16e+01, loss_r_u:1.49e+01, loss_d_u:2.05e-05
# Iter # 5500/50000	time:150.3	loss:2.08e+02, loss_r_u:2.39e+01, loss_d_u:8.70e-05
# Iter # 5600/50000	time:153.0	loss:7.27e+01, loss_r_u:2.27e+01, loss_d_u:3.30e-05
# Iter # 5700/50000	time:155.8	loss:5.59e+01, loss_r_u:1.64e+01, loss_d_u:2.41e-05
# Iter # 5800/50000	time:158.5	loss:4.39e+01, loss_r_u:1.16e+01, loss_d_u:1.89e-05
# Iter # 5900/50000	time:161.2	loss:9.03e+01, loss_r_u:2.26e+01, loss_d_u:5.15e-05
# Iter # 6000/50000	time:164.0	loss:5.95e+01, loss_r_u:1.76e+01, loss_d_u:2.82e-05
# Iter # 6100/50000	time:166.8	loss:4.58e+01, loss_r_u:1.23e+01, loss_d_u:2.10e-05
# Iter # 6200/50000	time:169.5	loss:1.11e+04, loss_r_u:1.30e+01, loss_d_u:1.41e-03
# Iter # 6300/50000	time:172.2	loss:7.15e+01, loss_r_u:2.13e+01, loss_d_u:3.84e-05
# Iter # 6400/50000	time:174.9	loss:5.30e+01, loss_r_u:1.49e+01, loss_d_u:2.72e-05
# Iter # 6500/50000	time:177.7	loss:4.05e+01, loss_r_u:1.02e+01, loss_d_u:2.04e-05
# Iter # 6600/50000	time:180.4	loss:1.95e+02, loss_r_u:9.16e+00, loss_d_u:4.98e-05
# Iter # 6700/50000	time:183.1	loss:4.90e+01, loss_r_u:1.34e+01, loss_d_u:2.71e-05
# Iter # 6800/50000	time:185.9	loss:3.72e+01, loss_r_u:9.06e+00, loss_d_u:2.08e-05
# Iter # 6900/50000	time:188.6	loss:1.20e+02, loss_r_u:1.49e+01, loss_d_u:4.60e-05
# Iter # 7000/50000	time:191.3	loss:5.16e+01, loss_r_u:1.39e+01, loss_d_u:3.23e-05
# Iter # 7100/50000	time:194.0	loss:3.84e+01, loss_r_u:9.34e+00, loss_d_u:2.37e-05
# Iter # 7200/50000	time:196.8	loss:3.21e+01, loss_r_u:6.24e+00, loss_d_u:2.13e-05
# Iter # 7300/50000	time:199.5	loss:6.91e+01, loss_r_u:2.07e+01, loss_d_u:4.10e-05
# Iter # 7400/50000	time:202.2	loss:4.74e+01, loss_r_u:1.30e+01, loss_d_u:3.34e-05
# Iter # 7500/50000	time:205.0	loss:3.52e+01, loss_r_u:8.36e+00, loss_d_u:2.55e-05
# Iter # 7600/50000	time:207.7	loss:3.85e+03, loss_r_u:7.85e+00, loss_d_u:4.67e-04
# Iter # 7700/50000	time:210.4	loss:5.61e+01, loss_r_u:1.51e+01, loss_d_u:4.41e-05
# Iter # 7800/50000	time:213.2	loss:3.92e+01, loss_r_u:9.74e+00, loss_d_u:3.09e-05
# Iter # 7900/50000	time:215.9	loss:2.95e+01, loss_r_u:6.33e+00, loss_d_u:2.39e-05
# Iter # 8000/50000	time:218.6	loss:7.45e+02, loss_r_u:1.16e+01, loss_d_u:1.71e-04
# Iter # 8100/50000	time:221.4	loss:4.28e+01, loss_r_u:1.13e+01, loss_d_u:3.75e-05
# Iter # 8200/50000	time:224.1	loss:3.11e+01, loss_r_u:7.05e+00, loss_d_u:2.85e-05
# Iter # 8300/50000	time:226.9	loss:2.41e+03, loss_r_u:4.63e+00, loss_d_u:4.91e-04
# Iter # 8400/50000	time:229.6	loss:4.08e+01, loss_r_u:1.06e+01, loss_d_u:3.72e-05
# Iter # 8500/50000	time:232.3	loss:2.95e+01, loss_r_u:6.50e+00, loss_d_u:2.90e-05
# Iter # 8600/50000	time:235.1	loss:6.20e+02, loss_r_u:8.33e+00, loss_d_u:6.48e-05
# Iter # 8700/50000	time:237.8	loss:4.51e+01, loss_r_u:1.21e+01, loss_d_u:4.33e-05
# Iter # 8800/50000	time:240.6	loss:3.15e+01, loss_r_u:7.21e+00, loss_d_u:3.33e-05
# Iter # 8900/50000	time:243.3	loss:2.19e+03, loss_r_u:4.60e+00, loss_d_u:2.40e-04
# Iter # 9000/50000	time:246.0	loss:3.06e+01, loss_r_u:7.10e+00, loss_d_u:3.42e-05
# Iter # 9100/50000	time:248.8	loss:3.18e+03, loss_r_u:5.85e+00, loss_d_u:6.66e-04
# Iter # 9200/50000	time:251.5	loss:3.62e+01, loss_r_u:9.04e+00, loss_d_u:4.01e-05
# Iter # 9300/50000	time:254.2	loss:2.59e+01, loss_r_u:5.36e+00, loss_d_u:3.10e-05
# Iter # 9400/50000	time:257.0	loss:3.56e+02, loss_r_u:2.21e+01, loss_d_u:6.42e-05
# Iter # 9500/50000	time:259.8	loss:4.12e+01, loss_r_u:1.09e+01, loss_d_u:4.84e-05
# Iter # 9600/50000	time:262.5	loss:2.84e+01, loss_r_u:6.18e+00, loss_d_u:3.64e-05
# Iter # 9700/50000	time:265.3	loss:5.01e+02, loss_r_u:9.93e+00, loss_d_u:1.92e-04
# Iter # 9800/50000	time:268.1	loss:3.23e+01, loss_r_u:7.57e+00, loss_d_u:4.02e-05
# Iter # 9900/50000	time:270.9	loss:2.35e+01, loss_r_u:4.49e+00, loss_d_u:3.14e-05
# Iter # 10000/50000	time:273.7	loss:7.74e+01, loss_r_u:1.56e+01, loss_d_u:4.80e-05
# Iter # 10100/50000	time:276.5	loss:3.45e+01, loss_r_u:8.43e+00, loss_d_u:4.50e-05
# Iter # 10200/50000	time:279.2	loss:2.43e+01, loss_r_u:4.76e+00, loss_d_u:3.44e-05
# Iter # 10300/50000	time:282.0	loss:1.32e+03, loss_r_u:1.82e+01, loss_d_u:1.41e-04
# Iter # 10400/50000	time:284.8	loss:3.47e+01, loss_r_u:8.56e+00, loss_d_u:4.50e-05
# Iter # 10500/50000	time:287.6	loss:2.43e+01, loss_r_u:4.71e+00, loss_d_u:3.50e-05
# Iter # 10600/50000	time:290.4	loss:1.54e+04, loss_r_u:5.87e+00, loss_d_u:2.48e-03
# Iter # 10700/50000	time:293.2	loss:3.90e+01, loss_r_u:1.04e+01, loss_d_u:5.03e-05
# Iter # 10800/50000	time:296.0	loss:2.59e+01, loss_r_u:5.32e+00, loss_d_u:3.91e-05
# Iter # 10900/50000	time:298.8	loss:1.95e+01, loss_r_u:3.07e+00, loss_d_u:3.23e-05
# Iter # 11000/50000	time:301.5	loss:4.59e+01, loss_r_u:1.06e+01, loss_d_u:6.27e-05
# Iter # 11100/50000	time:304.3	loss:2.63e+01, loss_r_u:5.40e+00, loss_d_u:4.00e-05
# Iter # 11200/50000	time:307.1	loss:1.92e+01, loss_r_u:3.07e+00, loss_d_u:3.18e-05
# Iter # 11300/50000	time:309.9	loss:5.05e+01, loss_r_u:1.01e+01, loss_d_u:4.60e-05
# Iter # 11400/50000	time:312.6	loss:2.27e+01, loss_r_u:4.42e+00, loss_d_u:3.82e-05
# Iter # 11500/50000	time:315.4	loss:4.00e+02, loss_r_u:6.44e+00, loss_d_u:1.57e-04
# Iter # 11600/50000	time:318.2	loss:2.29e+01, loss_r_u:4.49e+00, loss_d_u:3.82e-05
# Iter # 11700/50000	time:320.9	loss:1.76e+01, loss_r_u:2.46e+00, loss_d_u:2.83e-05
# Iter # 11800/50000	time:323.7	loss:4.44e+01, loss_r_u:1.16e+01, loss_d_u:6.12e-05
# Iter # 11900/50000	time:326.5	loss:2.57e+01, loss_r_u:5.22e+00, loss_d_u:4.26e-05
# Iter # 12000/50000	time:329.2	loss:1.83e+01, loss_r_u:2.77e+00, loss_d_u:3.32e-05
# Iter # 12100/50000	time:332.0	loss:4.73e+01, loss_r_u:6.29e+00, loss_d_u:5.83e-05
# Iter # 12200/50000	time:334.8	loss:1.83e+01, loss_r_u:2.97e+00, loss_d_u:3.35e-05
# Iter # 12300/50000	time:337.5	loss:2.99e+02, loss_r_u:8.87e+00, loss_d_u:1.08e-04
# Iter # 12400/50000	time:340.3	loss:2.25e+01, loss_r_u:4.43e+00, loss_d_u:3.94e-05
# Iter # 12500/50000	time:343.1	loss:1.60e+01, loss_r_u:2.21e+00, loss_d_u:3.12e-05
# Iter # 12600/50000	time:345.9	loss:6.29e+01, loss_r_u:1.12e+01, loss_d_u:7.15e-05
# Iter # 12700/50000	time:348.6	loss:2.42e+01, loss_r_u:4.69e+00, loss_d_u:4.16e-05
# Iter # 12800/50000	time:351.4	loss:1.54e+02, loss_r_u:1.95e+00, loss_d_u:6.33e-05
# Iter # 12900/50000	time:354.2	loss:1.66e+01, loss_r_u:2.73e+00, loss_d_u:3.01e-05
# Iter # 13000/50000	time:356.9	loss:5.84e+01, loss_r_u:7.76e+00, loss_d_u:3.66e-05
# Iter # 13100/50000	time:359.7	loss:1.76e+01, loss_r_u:2.83e+00, loss_d_u:3.44e-05
# Iter # 13200/50000	time:362.4	loss:1.35e+03, loss_r_u:4.72e+00, loss_d_u:2.31e-04
# Iter # 13300/50000	time:365.2	loss:2.07e+01, loss_r_u:4.17e+00, loss_d_u:3.97e-05
# Iter # 13400/50000	time:368.0	loss:9.48e+02, loss_r_u:1.78e+00, loss_d_u:1.98e-04
# Iter # 13500/50000	time:370.8	loss:1.85e+01, loss_r_u:3.37e+00, loss_d_u:3.46e-05
# Iter # 13600/50000	time:373.6	loss:2.76e+01, loss_r_u:1.41e+00, loss_d_u:3.83e-05
# Epoch 00136: reducing learning rate of group 0 to 6.0000e-04.
# Epoch 00136: reducing learning rate of group 0 to 6.0000e-04.
# Iter # 13700/50000	time:376.3	loss:1.11e+01, loss_r_u:1.07e+00, loss_d_u:2.50e-05
# Iter # 13800/50000	time:379.1	loss:9.66e+00, loss_r_u:7.88e-01, loss_d_u:2.28e-05
# Iter # 13900/50000	time:381.9	loss:8.54e+00, loss_r_u:6.06e-01, loss_d_u:2.09e-05
# Iter # 14000/50000	time:384.6	loss:7.65e+00, loss_r_u:4.87e-01, loss_d_u:1.95e-05
# Iter # 14100/50000	time:387.4	loss:6.94e+00, loss_r_u:4.08e-01, loss_d_u:1.83e-05
# Iter # 14200/50000	time:390.2	loss:6.36e+00, loss_r_u:3.58e-01, loss_d_u:1.73e-05
# Iter # 14300/50000	time:393.0	loss:5.88e+00, loss_r_u:3.25e-01, loss_d_u:1.65e-05
# Iter # 14400/50000	time:395.7	loss:5.49e+00, loss_r_u:3.05e-01, loss_d_u:1.58e-05
# Iter # 14500/50000	time:398.5	loss:5.16e+00, loss_r_u:2.93e-01, loss_d_u:1.53e-05
# Iter # 14600/50000	time:401.3	loss:9.34e+00, loss_r_u:1.07e+00, loss_d_u:2.24e-05
# Iter # 14700/50000	time:404.0	loss:6.08e+00, loss_r_u:5.26e-01, loss_d_u:1.82e-05
# Iter # 14800/50000	time:406.8	loss:3.61e+03, loss_r_u:1.08e+00, loss_d_u:6.24e-04
# Iter # 14900/50000	time:409.6	loss:6.82e+00, loss_r_u:8.55e-01, loss_d_u:2.04e-05
# Iter # 15000/50000	time:412.4	loss:1.47e+03, loss_r_u:1.81e+00, loss_d_u:1.60e-04
# Iter # 15100/50000	time:415.2	loss:5.34e+02, loss_r_u:1.51e+00, loss_d_u:5.51e-05
# Iter # 15200/50000	time:417.9	loss:5.83e+00, loss_r_u:5.50e-01, loss_d_u:1.81e-05
# Iter # 15300/50000	time:420.7	loss:2.29e+01, loss_r_u:1.12e+00, loss_d_u:3.11e-05
# Iter # 15400/50000	time:423.4	loss:5.86e+00, loss_r_u:5.30e-01, loss_d_u:1.84e-05
# Iter # 15500/50000	time:426.2	loss:1.99e+01, loss_r_u:7.41e-01, loss_d_u:2.53e-05
# Iter # 15600/50000	time:428.9	loss:6.09e+00, loss_r_u:7.93e-01, loss_d_u:1.88e-05
# Epoch 00156: reducing learning rate of group 0 to 3.6000e-04.
# Epoch 00156: reducing learning rate of group 0 to 3.6000e-04.
# Iter # 15700/50000	time:431.7	loss:5.52e+00, loss_r_u:5.07e-01, loss_d_u:1.76e-05
# Iter # 15800/50000	time:434.5	loss:5.13e+00, loss_r_u:3.91e-01, loss_d_u:1.66e-05
# Iter # 15900/50000	time:437.3	loss:4.83e+00, loss_r_u:3.34e-01, loss_d_u:1.58e-05
# Iter # 16000/50000	time:440.0	loss:4.59e+00, loss_r_u:3.04e-01, loss_d_u:1.51e-05
# Iter # 16100/50000	time:442.8	loss:4.39e+00, loss_r_u:2.88e-01, loss_d_u:1.45e-05
# Iter # 16200/50000	time:445.6	loss:4.22e+00, loss_r_u:2.78e-01, loss_d_u:1.41e-05
# Iter # 16300/50000	time:448.4	loss:4.07e+00, loss_r_u:2.73e-01, loss_d_u:1.37e-05
# Iter # 16400/50000	time:451.2	loss:3.94e+00, loss_r_u:2.70e-01, loss_d_u:1.34e-05
# Iter # 16500/50000	time:453.9	loss:3.82e+00, loss_r_u:2.67e-01, loss_d_u:1.31e-05
# Iter # 16600/50000	time:456.7	loss:3.71e+00, loss_r_u:2.65e-01, loss_d_u:1.28e-05
# Iter # 16700/50000	time:459.5	loss:4.63e+01, loss_r_u:4.99e-01, loss_d_u:3.09e-05
# Iter # 16800/50000	time:462.3	loss:3.96e+00, loss_r_u:3.55e-01, loss_d_u:1.42e-05
# Iter # 16900/50000	time:465.1	loss:3.77e+00, loss_r_u:2.82e-01, loss_d_u:1.35e-05
# Iter # 17000/50000	time:467.9	loss:1.18e+02, loss_r_u:3.94e-01, loss_d_u:5.00e-05
# Iter # 17100/50000	time:470.6	loss:3.90e+00, loss_r_u:3.46e-01, loss_d_u:1.43e-05
# Iter # 17200/50000	time:473.4	loss:4.08e+00, loss_r_u:3.15e-01, loss_d_u:1.27e-05
# Iter # 17300/50000	time:476.2	loss:2.96e+01, loss_r_u:3.86e-01, loss_d_u:9.56e-06
# Iter # 17400/50000	time:479.0	loss:3.72e+00, loss_r_u:3.08e-01, loss_d_u:1.34e-05
# Iter # 17500/50000	time:481.8	loss:4.18e+02, loss_r_u:3.71e-01, loss_d_u:5.63e-05
# Iter # 17600/50000	time:484.5	loss:3.72e+00, loss_r_u:3.44e-01, loss_d_u:1.38e-05
# Iter # 17700/50000	time:487.3	loss:1.17e+03, loss_r_u:9.81e-01, loss_d_u:1.35e-04
# Epoch 00177: reducing learning rate of group 0 to 2.1600e-04.
# Epoch 00177: reducing learning rate of group 0 to 2.1600e-04.
# Iter # 17800/50000	time:490.1	loss:3.61e+00, loss_r_u:3.02e-01, loss_d_u:1.34e-05
# Iter # 17900/50000	time:492.8	loss:3.50e+00, loss_r_u:2.62e-01, loss_d_u:1.29e-05
# Iter # 18000/50000	time:495.6	loss:3.42e+00, loss_r_u:2.43e-01, loss_d_u:1.26e-05
# Iter # 18100/50000	time:498.3	loss:3.35e+00, loss_r_u:2.34e-01, loss_d_u:1.23e-05
# Iter # 18200/50000	time:501.1	loss:3.29e+00, loss_r_u:2.30e-01, loss_d_u:1.21e-05
# Iter # 18300/50000	time:503.9	loss:3.24e+00, loss_r_u:2.27e-01, loss_d_u:1.19e-05
# Iter # 18400/50000	time:506.7	loss:3.18e+00, loss_r_u:2.24e-01, loss_d_u:1.17e-05
# Iter # 18500/50000	time:509.4	loss:3.13e+00, loss_r_u:2.22e-01, loss_d_u:1.15e-05
# Iter # 18600/50000	time:512.2	loss:3.09e+00, loss_r_u:2.20e-01, loss_d_u:1.14e-05
# Iter # 18700/50000	time:515.0	loss:3.04e+00, loss_r_u:2.17e-01, loss_d_u:1.13e-05
# Iter # 18800/50000	time:517.7	loss:3.00e+00, loss_r_u:2.14e-01, loss_d_u:1.11e-05
# Iter # 18900/50000	time:520.5	loss:7.12e+02, loss_r_u:5.44e-01, loss_d_u:7.95e-05
# Iter # 19000/50000	time:523.3	loss:3.03e+00, loss_r_u:2.47e-01, loss_d_u:1.16e-05
# Iter # 19100/50000	time:526.1	loss:2.97e+00, loss_r_u:2.15e-01, loss_d_u:1.12e-05
# Iter # 19200/50000	time:528.9	loss:6.13e+00, loss_r_u:2.44e-01, loss_d_u:1.25e-05
# Iter # 19300/50000	time:531.7	loss:5.12e+00, loss_r_u:2.21e-01, loss_d_u:1.35e-05
# Iter # 19400/50000	time:534.5	loss:1.13e+02, loss_r_u:3.39e-01, loss_d_u:1.32e-05
# Iter # 19500/50000	time:537.3	loss:2.90e+00, loss_r_u:2.06e-01, loss_d_u:1.12e-05
# Iter # 19600/50000	time:540.1	loss:1.66e+01, loss_r_u:2.69e-01, loss_d_u:8.26e-06
# Iter # 19700/50000	time:542.9	loss:2.86e+00, loss_r_u:1.99e-01, loss_d_u:1.10e-05
# Iter # 19800/50000	time:545.7	loss:3.34e+02, loss_r_u:4.30e-01, loss_d_u:3.50e-05
# Iter # 19900/50000	time:548.5	loss:2.97e+00, loss_r_u:1.96e-01, loss_d_u:1.03e-05
# Iter # 20000/50000	time:551.2	loss:3.04e+00, loss_r_u:2.06e-01, loss_d_u:1.03e-05
# Iter # 20100/50000	time:554.0	loss:2.32e+02, loss_r_u:3.82e-01, loss_d_u:2.43e-05
# Iter # 20200/50000	time:556.8	loss:2.90e+00, loss_r_u:1.87e-01, loss_d_u:1.06e-05
# Iter # 20300/50000	time:559.6	loss:3.73e+00, loss_r_u:1.85e-01, loss_d_u:9.41e-06
# Iter # 20400/50000	time:562.4	loss:2.86e+00, loss_r_u:1.95e-01, loss_d_u:1.03e-05
# Iter # 20500/50000	time:565.2	loss:2.70e+00, loss_r_u:1.70e-01, loss_d_u:1.04e-05
# Iter # 20600/50000	time:567.9	loss:3.04e+00, loss_r_u:2.05e-01, loss_d_u:9.87e-06
# Iter # 20700/50000	time:570.7	loss:2.67e+00, loss_r_u:1.71e-01, loss_d_u:1.03e-05
# Iter # 20800/50000	time:573.5	loss:1.13e+01, loss_r_u:2.06e-01, loss_d_u:1.55e-05
# Iter # 20900/50000	time:576.2	loss:2.68e+00, loss_r_u:1.79e-01, loss_d_u:1.05e-05
# Iter # 21000/50000	time:579.0	loss:2.63e+00, loss_r_u:1.60e-01, loss_d_u:1.02e-05
# Iter # 21100/50000	time:581.8	loss:2.60e+00, loss_r_u:1.54e-01, loss_d_u:1.00e-05
# Iter # 21200/50000	time:584.5	loss:4.79e+00, loss_r_u:2.51e-01, loss_d_u:9.21e-06
# Iter # 21300/50000	time:587.3	loss:2.64e+00, loss_r_u:1.73e-01, loss_d_u:1.04e-05
# Iter # 21400/50000	time:590.1	loss:2.59e+00, loss_r_u:1.54e-01, loss_d_u:1.01e-05
# Iter # 21500/50000	time:592.9	loss:4.41e+00, loss_r_u:1.59e-01, loss_d_u:9.34e-06
# Iter # 21600/50000	time:595.7	loss:2.54e+00, loss_r_u:1.49e-01, loss_d_u:9.67e-06
# Iter # 21700/50000	time:598.4	loss:2.75e+00, loss_r_u:1.74e-01, loss_d_u:1.06e-05
# Iter # 21800/50000	time:601.2	loss:2.52e+00, loss_r_u:1.49e-01, loss_d_u:9.84e-06
# Iter # 21900/50000	time:604.0	loss:1.49e+02, loss_r_u:2.51e-01, loss_d_u:1.59e-05
# Iter # 22000/50000	time:606.8	loss:2.55e+00, loss_r_u:1.76e-01, loss_d_u:1.00e-05
# Iter # 22100/50000	time:609.5	loss:2.50e+00, loss_r_u:1.45e-01, loss_d_u:9.78e-06
# Iter # 22200/50000	time:612.3	loss:1.28e+01, loss_r_u:1.32e-01, loss_d_u:9.64e-06
# Iter # 22300/50000	time:615.1	loss:2.12e+01, loss_r_u:1.50e-01, loss_d_u:1.76e-05
# Iter # 22400/50000	time:617.9	loss:2.45e+00, loss_r_u:1.43e-01, loss_d_u:9.58e-06
# Iter # 22500/50000	time:620.7	loss:8.54e+00, loss_r_u:1.58e-01, loss_d_u:1.36e-05
# Iter # 22600/50000	time:623.5	loss:2.43e+00, loss_r_u:1.39e-01, loss_d_u:9.52e-06
# Iter # 22700/50000	time:626.2	loss:1.38e+02, loss_r_u:2.24e-01, loss_d_u:1.89e-05
# Iter # 22800/50000	time:629.0	loss:2.44e+00, loss_r_u:1.55e-01, loss_d_u:9.60e-06
# Iter # 22900/50000	time:631.8	loss:2.39e+00, loss_r_u:1.34e-01, loss_d_u:9.34e-06
# Iter # 23000/50000	time:634.5	loss:1.71e+01, loss_r_u:2.33e-01, loss_d_u:7.15e-06
# Iter # 23100/50000	time:637.3	loss:2.39e+00, loss_r_u:1.39e-01, loss_d_u:9.41e-06
# Iter # 23200/50000	time:640.1	loss:2.36e+00, loss_r_u:1.26e-01, loss_d_u:9.21e-06
# Iter # 23300/50000	time:642.8	loss:1.51e+02, loss_r_u:1.17e-01, loss_d_u:4.50e-05
# Iter # 23400/50000	time:645.6	loss:2.43e+00, loss_r_u:1.54e-01, loss_d_u:9.19e-06
# Iter # 23500/50000	time:648.4	loss:2.34e+00, loss_r_u:1.26e-01, loss_d_u:9.17e-06
# Iter # 23600/50000	time:651.2	loss:8.66e+00, loss_r_u:1.50e-01, loss_d_u:1.00e-05
# Iter # 23700/50000	time:654.0	loss:3.72e+00, loss_r_u:1.35e-01, loss_d_u:1.06e-05
# Iter # 23800/50000	time:656.7	loss:1.31e+01, loss_r_u:1.41e-01, loss_d_u:6.60e-06
# Iter # 23900/50000	time:659.5	loss:2.40e+00, loss_r_u:1.36e-01, loss_d_u:9.49e-06
# Iter # 24000/50000	time:662.3	loss:2.28e+00, loss_r_u:1.18e-01, loss_d_u:8.89e-06
# Iter # 24100/50000	time:665.1	loss:3.54e+01, loss_r_u:1.55e-01, loss_d_u:2.11e-05
# Iter # 24200/50000	time:667.9	loss:2.28e+00, loss_r_u:1.27e-01, loss_d_u:9.03e-06
# Iter # 24300/50000	time:670.6	loss:2.29e+00, loss_r_u:1.18e-01, loss_d_u:8.64e-06
# Iter # 24400/50000	time:673.4	loss:8.58e+01, loss_r_u:1.13e-01, loss_d_u:3.17e-05
# Iter # 24500/50000	time:676.2	loss:2.24e+00, loss_r_u:1.18e-01, loss_d_u:8.82e-06
# Iter # 24600/50000	time:679.0	loss:9.76e+00, loss_r_u:1.42e-01, loss_d_u:7.45e-06
# Iter # 24700/50000	time:681.7	loss:2.95e+00, loss_r_u:1.21e-01, loss_d_u:7.73e-06
# Iter # 24800/50000	time:684.5	loss:2.37e+00, loss_r_u:1.25e-01, loss_d_u:8.26e-06
# Iter # 24900/50000	time:687.3	loss:3.58e+02, loss_r_u:1.45e-01, loss_d_u:8.08e-05
# Iter # 25000/50000	time:690.1	loss:2.25e+00, loss_r_u:1.22e-01, loss_d_u:8.96e-06
# Iter # 25100/50000	time:692.8	loss:1.15e+02, loss_r_u:3.35e-01, loss_d_u:2.24e-05
# Iter # 25200/50000	time:695.6	loss:1.27e+01, loss_r_u:1.14e-01, loss_d_u:1.39e-05
# Iter # 25300/50000	time:698.4	loss:5.64e+00, loss_r_u:9.98e-02, loss_d_u:1.10e-05
# Iter # 25400/50000	time:701.2	loss:2.26e+00, loss_r_u:1.16e-01, loss_d_u:8.88e-06
# Iter # 25500/50000	time:703.9	loss:3.50e+01, loss_r_u:9.51e-02, loss_d_u:1.49e-05
# Iter # 25600/50000	time:706.7	loss:3.97e+01, loss_r_u:9.92e-02, loss_d_u:2.03e-05
# Epoch 00256: reducing learning rate of group 0 to 1.2960e-04.
# Epoch 00256: reducing learning rate of group 0 to 1.2960e-04.
# Iter # 25700/50000	time:709.4	loss:2.13e+00, loss_r_u:1.10e-01, loss_d_u:8.33e-06
# Iter # 25800/50000	time:712.2	loss:2.11e+00, loss_r_u:1.03e-01, loss_d_u:8.20e-06
# Iter # 25900/50000	time:715.0	loss:2.10e+00, loss_r_u:9.95e-02, loss_d_u:8.10e-06
# Iter # 26000/50000	time:717.7	loss:2.08e+00, loss_r_u:9.80e-02, loss_d_u:8.01e-06
# Iter # 26100/50000	time:720.5	loss:2.07e+00, loss_r_u:9.72e-02, loss_d_u:7.94e-06
# Iter # 26200/50000	time:723.3	loss:2.06e+00, loss_r_u:9.65e-02, loss_d_u:7.88e-06
# Iter # 26300/50000	time:726.1	loss:2.05e+00, loss_r_u:9.57e-02, loss_d_u:7.82e-06
# Iter # 26400/50000	time:728.8	loss:2.03e+00, loss_r_u:9.49e-02, loss_d_u:7.76e-06
# Iter # 26500/50000	time:731.6	loss:2.02e+00, loss_r_u:9.39e-02, loss_d_u:7.71e-06
# Iter # 26600/50000	time:734.4	loss:2.01e+00, loss_r_u:9.27e-02, loss_d_u:7.66e-06
# Iter # 26700/50000	time:737.2	loss:2.00e+00, loss_r_u:9.14e-02, loss_d_u:7.61e-06
# Iter # 26800/50000	time:739.9	loss:3.00e+00, loss_r_u:1.15e-01, loss_d_u:6.82e-06
# Iter # 26900/50000	time:742.7	loss:1.99e+00, loss_r_u:9.51e-02, loss_d_u:7.70e-06
# Iter # 27000/50000	time:745.5	loss:1.07e+02, loss_r_u:2.21e-01, loss_d_u:1.67e-05
# Iter # 27100/50000	time:748.3	loss:2.67e+01, loss_r_u:1.22e-01, loss_d_u:5.72e-06
# Iter # 27200/50000	time:751.1	loss:1.96e+01, loss_r_u:7.96e-02, loss_d_u:1.46e-05
# Iter # 27300/50000	time:753.9	loss:1.96e+00, loss_r_u:9.07e-02, loss_d_u:7.47e-06
# Iter # 27400/50000	time:756.7	loss:9.90e+00, loss_r_u:8.77e-02, loss_d_u:1.18e-05
# Iter # 27500/50000	time:759.4	loss:1.94e+00, loss_r_u:8.78e-02, loss_d_u:7.54e-06
# Iter # 27600/50000	time:762.2	loss:3.31e+00, loss_r_u:8.23e-02, loss_d_u:6.86e-06
# Iter # 27700/50000	time:765.0	loss:1.95e+00, loss_r_u:8.78e-02, loss_d_u:7.22e-06
# Iter # 27800/50000	time:767.8	loss:2.85e+01, loss_r_u:7.91e-02, loss_d_u:1.67e-05
# Iter # 27900/50000	time:770.5	loss:1.90e+00, loss_r_u:8.39e-02, loss_d_u:7.40e-06
# Iter # 28000/50000	time:773.3	loss:4.04e+01, loss_r_u:7.48e-02, loss_d_u:1.93e-05
# Iter # 28100/50000	time:776.1	loss:1.90e+00, loss_r_u:8.15e-02, loss_d_u:7.40e-06
# Iter # 28200/50000	time:778.9	loss:1.89e+00, loss_r_u:8.43e-02, loss_d_u:7.39e-06
# Iter # 28300/50000	time:781.7	loss:1.88e+00, loss_r_u:7.88e-02, loss_d_u:7.09e-06
# Iter # 28400/50000	time:784.5	loss:1.90e+00, loss_r_u:8.55e-02, loss_d_u:7.06e-06
# Iter # 28500/50000	time:787.2	loss:3.42e+01, loss_r_u:7.44e-02, loss_d_u:9.64e-06
# Iter # 28600/50000	time:790.0	loss:1.78e+01, loss_r_u:7.15e-02, loss_d_u:1.35e-05
# Iter # 28700/50000	time:792.8	loss:1.84e+00, loss_r_u:7.70e-02, loss_d_u:7.06e-06
# Iter # 28800/50000	time:795.6	loss:1.85e+00, loss_r_u:8.50e-02, loss_d_u:7.07e-06
# Iter # 28900/50000	time:798.4	loss:2.50e+00, loss_r_u:8.13e-02, loss_d_u:7.27e-06
# Iter # 29000/50000	time:801.1	loss:9.59e+01, loss_r_u:7.40e-02, loss_d_u:3.03e-05
# Iter # 29100/50000	time:803.9	loss:1.81e+00, loss_r_u:7.46e-02, loss_d_u:6.94e-06
# Iter # 29200/50000	time:806.7	loss:3.57e+00, loss_r_u:8.64e-02, loss_d_u:5.82e-06
# Iter # 29300/50000	time:809.5	loss:1.79e+00, loss_r_u:7.23e-02, loss_d_u:6.88e-06
# Iter # 29400/50000	time:812.3	loss:4.24e+01, loss_r_u:6.73e-02, loss_d_u:1.91e-05
# Iter # 29500/50000	time:815.1	loss:1.78e+00, loss_r_u:7.23e-02, loss_d_u:6.90e-06
# Iter # 29600/50000	time:817.8	loss:2.03e+00, loss_r_u:7.78e-02, loss_d_u:7.49e-06
# Iter # 29700/50000	time:820.6	loss:1.76e+00, loss_r_u:7.06e-02, loss_d_u:6.82e-06
# Iter # 29800/50000	time:823.4	loss:1.04e+01, loss_r_u:7.11e-02, loss_d_u:1.12e-05
# Iter # 29900/50000	time:826.2	loss:1.75e+00, loss_r_u:7.03e-02, loss_d_u:6.74e-06
# Iter # 30000/50000	time:828.9	loss:1.83e+00, loss_r_u:6.67e-02, loss_d_u:6.78e-06
# Iter # 30100/50000	time:831.7	loss:1.85e+00, loss_r_u:7.07e-02, loss_d_u:7.08e-06
# Iter # 30200/50000	time:834.5	loss:1.73e+00, loss_r_u:6.63e-02, loss_d_u:6.69e-06
# Iter # 30300/50000	time:837.3	loss:1.86e+00, loss_r_u:7.54e-02, loss_d_u:6.35e-06
# Iter # 30400/50000	time:840.0	loss:4.01e+01, loss_r_u:7.23e-02, loss_d_u:9.19e-06
# Iter # 30500/50000	time:842.8	loss:1.02e+02, loss_r_u:7.10e-02, loss_d_u:3.09e-05
# Iter # 30600/50000	time:845.6	loss:1.71e+00, loss_r_u:6.69e-02, loss_d_u:6.67e-06
# Iter # 30700/50000	time:848.4	loss:4.36e+01, loss_r_u:5.74e-02, loss_d_u:1.85e-05
# Iter # 30800/50000	time:851.2	loss:1.70e+00, loss_r_u:6.74e-02, loss_d_u:6.64e-06
# Iter # 30900/50000	time:854.0	loss:2.59e+00, loss_r_u:6.13e-02, loss_d_u:6.30e-06
# Iter # 31000/50000	time:856.8	loss:1.00e+01, loss_r_u:6.07e-02, loss_d_u:1.06e-05
# Iter # 31100/50000	time:859.5	loss:1.67e+00, loss_r_u:6.58e-02, loss_d_u:6.52e-06
# Iter # 31200/50000	time:862.3	loss:1.71e+00, loss_r_u:6.29e-02, loss_d_u:6.38e-06
# Iter # 31300/50000	time:865.1	loss:2.14e+00, loss_r_u:6.14e-02, loss_d_u:7.09e-06
# Iter # 31400/50000	time:867.9	loss:1.70e+00, loss_r_u:6.54e-02, loss_d_u:6.14e-06
# Iter # 31500/50000	time:870.7	loss:9.49e+00, loss_r_u:6.11e-02, loss_d_u:1.03e-05
# Iter # 31600/50000	time:873.4	loss:1.64e+00, loss_r_u:6.18e-02, loss_d_u:6.25e-06
# Iter # 31700/50000	time:876.2	loss:1.73e+00, loss_r_u:6.46e-02, loss_d_u:6.43e-06
# Iter # 31800/50000	time:878.7	loss:3.68e+00, loss_r_u:6.07e-02, loss_d_u:7.95e-06
# Iter # 31900/50000	time:881.3	loss:6.78e+00, loss_r_u:5.80e-02, loss_d_u:9.07e-06
# Iter # 32000/50000	time:883.9	loss:1.61e+00, loss_r_u:6.02e-02, loss_d_u:6.25e-06
# Iter # 32100/50000	time:886.4	loss:1.78e+00, loss_r_u:6.13e-02, loss_d_u:6.49e-06
# Iter # 32200/50000	time:889.0	loss:2.92e+01, loss_r_u:5.51e-02, loss_d_u:1.52e-05
# Iter # 32300/50000	time:891.6	loss:1.68e+00, loss_r_u:5.98e-02, loss_d_u:5.81e-06
# Iter # 32400/50000	time:894.1	loss:1.67e+00, loss_r_u:6.03e-02, loss_d_u:6.38e-06
# Iter # 32500/50000	time:896.7	loss:2.95e+02, loss_r_u:2.09e-01, loss_d_u:3.19e-05
# Iter # 32600/50000	time:899.2	loss:1.58e+00, loss_r_u:5.98e-02, loss_d_u:6.05e-06
# Iter # 32700/50000	time:901.8	loss:1.76e+00, loss_r_u:5.78e-02, loss_d_u:5.79e-06
# Iter # 32800/50000	time:904.3	loss:2.02e+00, loss_r_u:6.36e-02, loss_d_u:5.86e-06
# Iter # 32900/50000	time:906.9	loss:1.56e+00, loss_r_u:5.69e-02, loss_d_u:5.96e-06
# Iter # 33000/50000	time:909.4	loss:1.70e+00, loss_r_u:6.95e-02, loss_d_u:6.06e-06
# Iter # 33100/50000	time:912.0	loss:1.55e+00, loss_r_u:5.65e-02, loss_d_u:5.93e-06
# Iter # 33200/50000	time:914.6	loss:1.67e+00, loss_r_u:6.67e-02, loss_d_u:5.67e-06
# Iter # 33300/50000	time:917.1	loss:1.54e+00, loss_r_u:5.61e-02, loss_d_u:5.89e-06
# Iter # 33400/50000	time:919.7	loss:2.83e+01, loss_r_u:5.26e-02, loss_d_u:1.49e-05
# Iter # 33500/50000	time:922.3	loss:1.53e+00, loss_r_u:5.81e-02, loss_d_u:5.84e-06
# Iter # 33600/50000	time:924.8	loss:5.46e+01, loss_r_u:1.06e-01, loss_d_u:1.27e-05
# Iter # 33700/50000	time:927.4	loss:2.61e+01, loss_r_u:8.89e-02, loss_d_u:4.75e-06
# Iter # 33800/50000	time:929.9	loss:1.51e+00, loss_r_u:5.55e-02, loss_d_u:5.75e-06
# Iter # 33900/50000	time:932.5	loss:1.76e+00, loss_r_u:5.14e-02, loss_d_u:6.19e-06
# Iter # 34000/50000	time:935.1	loss:1.51e+00, loss_r_u:5.89e-02, loss_d_u:5.80e-06
# Iter # 34100/50000	time:937.6	loss:1.50e+00, loss_r_u:5.27e-02, loss_d_u:5.67e-06
# Iter # 34200/50000	time:940.2	loss:1.50e+00, loss_r_u:5.29e-02, loss_d_u:5.70e-06
# Iter # 34300/50000	time:942.7	loss:1.94e+00, loss_r_u:6.08e-02, loss_d_u:5.19e-06
# Iter # 34400/50000	time:945.3	loss:1.48e+00, loss_r_u:5.28e-02, loss_d_u:5.66e-06
# Iter # 34500/50000	time:947.8	loss:1.71e+00, loss_r_u:5.61e-02, loss_d_u:5.38e-06
# Iter # 34600/50000	time:950.4	loss:1.47e+00, loss_r_u:5.20e-02, loss_d_u:5.56e-06
# Iter # 34700/50000	time:953.0	loss:1.68e+00, loss_r_u:5.66e-02, loss_d_u:5.81e-06
# Iter # 34800/50000	time:955.5	loss:1.46e+00, loss_r_u:5.17e-02, loss_d_u:5.56e-06
# Iter # 34900/50000	time:958.1	loss:2.96e+02, loss_r_u:1.02e-01, loss_d_u:6.09e-05
# Iter # 35000/50000	time:960.7	loss:1.46e+00, loss_r_u:5.61e-02, loss_d_u:5.59e-06
# Iter # 35100/50000	time:963.2	loss:1.44e+00, loss_r_u:5.10e-02, loss_d_u:5.50e-06
# Iter # 35200/50000	time:965.8	loss:1.44e+00, loss_r_u:4.98e-02, loss_d_u:5.44e-06
# Iter # 35300/50000	time:968.3	loss:1.91e+00, loss_r_u:6.34e-02, loss_d_u:5.07e-06
# Iter # 35400/50000	time:970.9	loss:1.43e+00, loss_r_u:5.10e-02, loss_d_u:5.46e-06
# Iter # 35500/50000	time:973.4	loss:1.42e+00, loss_r_u:4.93e-02, loss_d_u:5.39e-06
# Iter # 35600/50000	time:976.0	loss:2.81e+00, loss_r_u:6.84e-02, loss_d_u:4.61e-06
# Iter # 35700/50000	time:978.6	loss:1.42e+00, loss_r_u:5.12e-02, loss_d_u:5.44e-06
# Iter # 35800/50000	time:981.1	loss:1.44e+00, loss_r_u:4.96e-02, loss_d_u:5.37e-06
# Iter # 35900/50000	time:983.7	loss:6.58e+01, loss_r_u:5.05e-02, loss_d_u:2.17e-05
# Iter # 36000/50000	time:986.2	loss:1.40e+00, loss_r_u:5.08e-02, loss_d_u:5.30e-06
# Iter # 36100/50000	time:988.8	loss:1.47e+00, loss_r_u:5.36e-02, loss_d_u:5.62e-06
# Iter # 36200/50000	time:991.3	loss:1.87e+00, loss_r_u:6.16e-02, loss_d_u:5.29e-06
# Iter # 36300/50000	time:993.9	loss:1.86e+00, loss_r_u:5.45e-02, loss_d_u:4.72e-06
# Iter # 36400/50000	time:996.4	loss:2.76e+01, loss_r_u:4.53e-02, loss_d_u:1.37e-05
# Iter # 36500/50000	time:999.0	loss:1.38e+00, loss_r_u:4.92e-02, loss_d_u:5.25e-06
# Iter # 36600/50000	time:1001.6	loss:1.44e+00, loss_r_u:5.64e-02, loss_d_u:5.49e-06
# Iter # 36700/50000	time:1004.1	loss:1.79e+00, loss_r_u:5.17e-02, loss_d_u:5.39e-06
# Iter # 36800/50000	time:1006.7	loss:1.08e+02, loss_r_u:6.07e-02, loss_d_u:2.97e-05
# Iter # 36900/50000	time:1009.2	loss:1.36e+00, loss_r_u:4.95e-02, loss_d_u:5.18e-06
# Iter # 37000/50000	time:1011.8	loss:6.33e+00, loss_r_u:4.21e-02, loss_d_u:7.76e-06
# Iter # 37100/50000	time:1014.3	loss:1.36e+00, loss_r_u:5.17e-02, loss_d_u:5.11e-06
# Iter # 37200/50000	time:1016.9	loss:1.11e+01, loss_r_u:5.43e-02, loss_d_u:7.02e-06
# Iter # 37300/50000	time:1019.4	loss:1.34e+00, loss_r_u:4.60e-02, loss_d_u:5.05e-06
# Iter # 37400/50000	time:1022.0	loss:1.46e+00, loss_r_u:5.26e-02, loss_d_u:5.45e-06
# Iter # 37500/50000	time:1024.6	loss:1.33e+00, loss_r_u:4.69e-02, loss_d_u:5.05e-06
# Iter # 37600/50000	time:1027.1	loss:1.20e+01, loss_r_u:5.60e-02, loss_d_u:8.78e-06
# Iter # 37700/50000	time:1029.7	loss:1.06e+01, loss_r_u:6.07e-02, loss_d_u:3.70e-06
# Iter # 37800/50000	time:1032.2	loss:1.33e+00, loss_r_u:4.68e-02, loss_d_u:5.08e-06
# Iter # 37900/50000	time:1034.8	loss:1.35e+00, loss_r_u:5.00e-02, loss_d_u:5.17e-06
# Iter # 38000/50000	time:1037.3	loss:1.36e+00, loss_r_u:4.51e-02, loss_d_u:5.16e-06
# Iter # 38100/50000	time:1039.9	loss:1.38e+00, loss_r_u:4.83e-02, loss_d_u:5.23e-06
# Iter # 38200/50000	time:1042.5	loss:4.64e+00, loss_r_u:5.61e-02, loss_d_u:5.59e-06
# Iter # 38300/50000	time:1045.0	loss:1.39e+00, loss_r_u:4.93e-02, loss_d_u:5.17e-06
# Iter # 38400/50000	time:1047.6	loss:1.31e+00, loss_r_u:4.56e-02, loss_d_u:4.77e-06
# Iter # 38500/50000	time:1050.2	loss:1.33e+00, loss_r_u:4.93e-02, loss_d_u:4.74e-06
# Iter # 38600/50000	time:1052.7	loss:3.83e+00, loss_r_u:4.38e-02, loss_d_u:4.50e-06
# Iter # 38700/50000	time:1055.3	loss:2.52e+00, loss_r_u:4.70e-02, loss_d_u:6.02e-06
# Iter # 38800/50000	time:1057.8	loss:1.28e+00, loss_r_u:4.47e-02, loss_d_u:4.80e-06
# Iter # 38900/50000	time:1060.4	loss:1.30e+00, loss_r_u:5.27e-02, loss_d_u:4.74e-06
# Iter # 39000/50000	time:1063.0	loss:1.34e+00, loss_r_u:4.34e-02, loss_d_u:4.76e-06
# Iter # 39100/50000	time:1065.5	loss:9.94e+00, loss_r_u:5.54e-02, loss_d_u:3.47e-06
# Iter # 39200/50000	time:1068.1	loss:1.27e+00, loss_r_u:4.58e-02, loss_d_u:4.85e-06
# Iter # 39300/50000	time:1070.6	loss:7.57e+01, loss_r_u:4.80e-02, loss_d_u:2.27e-05
# Iter # 39400/50000	time:1073.2	loss:1.25e+00, loss_r_u:4.48e-02, loss_d_u:4.77e-06
# Iter # 39500/50000	time:1075.7	loss:3.49e+00, loss_r_u:4.88e-02, loss_d_u:3.90e-06
# Iter # 39600/50000	time:1078.3	loss:1.26e+00, loss_r_u:4.56e-02, loss_d_u:4.60e-06
# Iter # 39700/50000	time:1080.8	loss:1.63e+01, loss_r_u:4.16e-02, loss_d_u:1.02e-05
# Iter # 39800/50000	time:1083.4	loss:1.24e+00, loss_r_u:4.41e-02, loss_d_u:4.70e-06
# Iter # 39900/50000	time:1086.0	loss:4.24e+00, loss_r_u:4.44e-02, loss_d_u:6.42e-06
# Iter # 40000/50000	time:1088.5	loss:1.31e+00, loss_r_u:4.33e-02, loss_d_u:4.87e-06
# Iter # 40100/50000	time:1091.1	loss:1.24e+00, loss_r_u:4.60e-02, loss_d_u:4.55e-06
# Iter # 40200/50000	time:1093.7	loss:3.53e+01, loss_r_u:4.14e-02, loss_d_u:1.47e-05
# Iter # 40300/50000	time:1096.2	loss:1.22e+00, loss_r_u:4.33e-02, loss_d_u:4.55e-06
# Iter # 40400/50000	time:1098.8	loss:3.00e+00, loss_r_u:4.82e-02, loss_d_u:3.68e-06
# Iter # 40500/50000	time:1101.3	loss:9.75e+00, loss_r_u:3.99e-02, loss_d_u:8.28e-06
# Iter # 40600/50000	time:1103.9	loss:6.59e+01, loss_r_u:8.49e-02, loss_d_u:7.13e-06
# Iter # 40700/50000	time:1106.4	loss:1.22e+00, loss_r_u:4.26e-02, loss_d_u:4.63e-06
# Iter # 40800/50000	time:1109.0	loss:2.29e+00, loss_r_u:4.72e-02, loss_d_u:5.61e-06
# Iter # 40900/50000	time:1111.5	loss:2.31e+00, loss_r_u:4.87e-02, loss_d_u:5.26e-06
# Iter # 41000/50000	time:1114.1	loss:2.57e+01, loss_r_u:6.51e-02, loss_d_u:3.86e-06
# Iter # 41100/50000	time:1116.7	loss:1.20e+00, loss_r_u:4.36e-02, loss_d_u:4.37e-06
# Iter # 41200/50000	time:1119.2	loss:6.49e+01, loss_r_u:4.19e-02, loss_d_u:1.97e-05
# Iter # 41300/50000	time:1121.8	loss:1.18e+00, loss_r_u:4.29e-02, loss_d_u:4.43e-06
# Iter # 41400/50000	time:1124.3	loss:1.27e+00, loss_r_u:4.20e-02, loss_d_u:4.43e-06
# Iter # 41500/50000	time:1126.9	loss:1.30e+00, loss_r_u:4.67e-02, loss_d_u:4.79e-06
# Iter # 41600/50000	time:1129.5	loss:1.17e+00, loss_r_u:4.11e-02, loss_d_u:4.39e-06
# Iter # 41700/50000	time:1132.0	loss:2.53e+01, loss_r_u:6.77e-02, loss_d_u:3.84e-06
# Iter # 41800/50000	time:1134.6	loss:1.16e+00, loss_r_u:4.18e-02, loss_d_u:4.35e-06
# Iter # 41900/50000	time:1137.1	loss:1.16e+00, loss_r_u:4.01e-02, loss_d_u:4.32e-06
# Iter # 42000/50000	time:1139.7	loss:4.74e+00, loss_r_u:5.75e-02, loss_d_u:3.32e-06
# Iter # 42100/50000	time:1142.2	loss:1.15e+00, loss_r_u:4.10e-02, loss_d_u:4.34e-06
# Iter # 42200/50000	time:1144.8	loss:2.59e+00, loss_r_u:4.42e-02, loss_d_u:4.54e-06
# Iter # 42300/50000	time:1147.3	loss:1.42e+00, loss_r_u:3.99e-02, loss_d_u:4.74e-06
# Iter # 42400/50000	time:1149.9	loss:1.23e+00, loss_r_u:4.26e-02, loss_d_u:4.04e-06
# Iter # 42500/50000	time:1152.5	loss:1.49e+00, loss_r_u:4.68e-02, loss_d_u:3.87e-06
# Iter # 42600/50000	time:1155.0	loss:1.15e+00, loss_r_u:3.94e-02, loss_d_u:4.36e-06
# Iter # 42700/50000	time:1157.6	loss:1.20e+00, loss_r_u:4.36e-02, loss_d_u:4.07e-06
# Iter # 42800/50000	time:1160.1	loss:1.30e+00, loss_r_u:4.01e-02, loss_d_u:4.35e-06
# Iter # 42900/50000	time:1162.7	loss:3.39e+00, loss_r_u:4.20e-02, loss_d_u:5.77e-06
# Iter # 43000/50000	time:1165.2	loss:1.12e+00, loss_r_u:3.95e-02, loss_d_u:4.19e-06
# Iter # 43100/50000	time:1167.8	loss:4.08e+01, loss_r_u:3.57e-02, loss_d_u:1.13e-05
# Iter # 43200/50000	time:1170.4	loss:1.11e+00, loss_r_u:3.98e-02, loss_d_u:4.14e-06
# Iter # 43300/50000	time:1172.9	loss:1.66e+00, loss_r_u:4.87e-02, loss_d_u:3.69e-06
# Iter # 43400/50000	time:1175.5	loss:1.11e+00, loss_r_u:3.96e-02, loss_d_u:4.14e-06
# Iter # 43500/50000	time:1178.0	loss:1.32e+00, loss_r_u:3.71e-02, loss_d_u:4.50e-06
# Iter # 43600/50000	time:1180.6	loss:1.14e+00, loss_r_u:4.20e-02, loss_d_u:4.33e-06
# Iter # 43700/50000	time:1183.1	loss:1.10e+00, loss_r_u:3.83e-02, loss_d_u:4.10e-06
# Iter # 43800/50000	time:1185.7	loss:1.38e+00, loss_r_u:3.79e-02, loss_d_u:4.49e-06
# Iter # 43900/50000	time:1188.3	loss:1.13e+00, loss_r_u:4.01e-02, loss_d_u:4.26e-06
# Iter # 44000/50000	time:1190.8	loss:3.26e+00, loss_r_u:4.39e-02, loss_d_u:3.24e-06
# Iter # 44100/50000	time:1193.4	loss:1.09e+00, loss_r_u:3.95e-02, loss_d_u:4.01e-06
# Iter # 44200/50000	time:1195.9	loss:9.33e+00, loss_r_u:5.04e-02, loss_d_u:2.90e-06
# Iter # 44300/50000	time:1198.5	loss:1.11e+00, loss_r_u:3.84e-02, loss_d_u:4.17e-06
# Iter # 44400/50000	time:1201.1	loss:1.16e+00, loss_r_u:3.95e-02, loss_d_u:4.28e-06
# Iter # 44500/50000	time:1203.6	loss:7.84e+01, loss_r_u:4.28e-02, loss_d_u:2.19e-05
# Iter # 44600/50000	time:1206.2	loss:1.07e+00, loss_r_u:3.85e-02, loss_d_u:4.05e-06
# Iter # 44700/50000	time:1208.7	loss:1.66e+00, loss_r_u:3.74e-02, loss_d_u:4.54e-06
# Iter # 44800/50000	time:1211.3	loss:1.06e+00, loss_r_u:3.92e-02, loss_d_u:4.02e-06
# Iter # 44900/50000	time:1213.8	loss:3.06e+02, loss_r_u:9.64e-02, loss_d_u:6.10e-05
# Iter # 45000/50000	time:1216.4	loss:1.07e+00, loss_r_u:3.96e-02, loss_d_u:3.90e-06
# Iter # 45100/50000	time:1218.9	loss:1.06e+00, loss_r_u:3.62e-02, loss_d_u:3.90e-06
# Iter # 45200/50000	time:1221.5	loss:3.87e+01, loss_r_u:3.64e-02, loss_d_u:1.42e-05
# Iter # 45300/50000	time:1224.1	loss:1.04e+00, loss_r_u:3.79e-02, loss_d_u:3.91e-06
# Iter # 45400/50000	time:1226.6	loss:3.26e+00, loss_r_u:4.77e-02, loss_d_u:3.10e-06
# Iter # 45500/50000	time:1229.2	loss:1.04e+00, loss_r_u:3.68e-02, loss_d_u:3.87e-06
# Iter # 45600/50000	time:1231.7	loss:3.22e+00, loss_r_u:4.01e-02, loss_d_u:5.30e-06
# Iter # 45700/50000	time:1234.3	loss:1.03e+00, loss_r_u:3.68e-02, loss_d_u:3.86e-06
# Iter # 45800/50000	time:1236.8	loss:2.45e+00, loss_r_u:3.82e-02, loss_d_u:5.03e-06
# Iter # 45900/50000	time:1239.4	loss:1.03e+00, loss_r_u:3.78e-02, loss_d_u:3.89e-06
# Iter # 46000/50000	time:1241.9	loss:1.02e+00, loss_r_u:3.59e-02, loss_d_u:3.80e-06
# Iter # 46100/50000	time:1244.5	loss:1.09e+00, loss_r_u:4.63e-02, loss_d_u:3.73e-06
# Iter # 46200/50000	time:1247.0	loss:1.02e+00, loss_r_u:3.66e-02, loss_d_u:3.81e-06
# Iter # 46300/50000	time:1249.6	loss:3.01e+00, loss_r_u:3.35e-02, loss_d_u:3.73e-06
# Iter # 46400/50000	time:1252.2	loss:1.37e+01, loss_r_u:5.76e-02, loss_d_u:2.92e-06
# Iter # 46500/50000	time:1254.7	loss:1.01e+00, loss_r_u:3.65e-02, loss_d_u:3.76e-06
# Iter # 46600/50000	time:1257.3	loss:1.75e+01, loss_r_u:3.16e-02, loss_d_u:8.67e-06
# Iter # 46700/50000	time:1259.9	loss:1.01e+00, loss_r_u:3.71e-02, loss_d_u:3.77e-06
# Iter # 46800/50000	time:1262.4	loss:2.15e+00, loss_r_u:3.82e-02, loss_d_u:3.04e-06
# Iter # 46900/50000	time:1265.0	loss:1.04e+00, loss_r_u:3.87e-02, loss_d_u:3.61e-06
# Iter # 47000/50000	time:1267.5	loss:9.93e-01, loss_r_u:3.51e-02, loss_d_u:3.70e-06
# Iter # 47100/50000	time:1270.1	loss:1.41e+00, loss_r_u:4.44e-02, loss_d_u:4.22e-06
# Iter # 47200/50000	time:1272.6	loss:9.93e-01, loss_r_u:3.67e-02, loss_d_u:3.72e-06
# Iter # 47300/50000	time:1275.2	loss:9.86e-01, loss_r_u:3.44e-02, loss_d_u:3.66e-06
# Iter # 47400/50000	time:1277.8	loss:1.05e+00, loss_r_u:3.53e-02, loss_d_u:3.45e-06
# Iter # 47500/50000	time:1280.3	loss:1.05e+00, loss_r_u:3.72e-02, loss_d_u:3.89e-06
# Iter # 47600/50000	time:1282.9	loss:9.76e-01, loss_r_u:3.48e-02, loss_d_u:3.61e-06
# Iter # 47700/50000	time:1285.5	loss:1.16e+00, loss_r_u:4.10e-02, loss_d_u:3.39e-06
# Iter # 47800/50000	time:1288.0	loss:1.09e+00, loss_r_u:3.57e-02, loss_d_u:3.69e-06
# Iter # 47900/50000	time:1290.6	loss:9.81e-01, loss_r_u:3.39e-02, loss_d_u:3.67e-06
# Iter # 48000/50000	time:1293.2	loss:1.03e+00, loss_r_u:3.84e-02, loss_d_u:3.46e-06
# Iter # 48100/50000	time:1295.7	loss:9.62e-01, loss_r_u:3.43e-02, loss_d_u:3.57e-06
# Iter # 48200/50000	time:1298.3	loss:2.12e+00, loss_r_u:3.85e-02, loss_d_u:4.65e-06
# Iter # 48300/50000	time:1300.8	loss:9.63e-01, loss_r_u:3.45e-02, loss_d_u:3.58e-06
# Iter # 48400/50000	time:1303.4	loss:9.79e-01, loss_r_u:3.40e-02, loss_d_u:3.53e-06
# Iter # 48500/50000	time:1305.9	loss:1.63e+00, loss_r_u:4.11e-02, loss_d_u:3.08e-06
# Iter # 48600/50000	time:1308.5	loss:9.49e-01, loss_r_u:3.40e-02, loss_d_u:3.52e-06
# Iter # 48700/50000	time:1311.1	loss:2.73e+00, loss_r_u:3.96e-02, loss_d_u:4.69e-06
# Iter # 48800/50000	time:1313.6	loss:9.46e-01, loss_r_u:3.41e-02, loss_d_u:3.53e-06
# Iter # 48900/50000	time:1316.2	loss:1.44e+02, loss_r_u:1.07e-01, loss_d_u:1.54e-05
# Iter # 49000/50000	time:1318.7	loss:9.50e-01, loss_r_u:3.61e-02, loss_d_u:3.46e-06
# Iter # 49100/50000	time:1321.3	loss:9.36e-01, loss_r_u:3.34e-02, loss_d_u:3.48e-06
# Iter # 49200/50000	time:1323.9	loss:1.51e+00, loss_r_u:3.72e-02, loss_d_u:4.17e-06
# Iter # 49300/50000	time:1326.4	loss:9.32e-01, loss_r_u:3.36e-02, loss_d_u:3.46e-06
# Iter # 49400/50000	time:1329.0	loss:6.61e+01, loss_r_u:7.78e-02, loss_d_u:6.89e-06
# Iter # 49500/50000	time:1331.6	loss:1.08e+02, loss_r_u:4.56e-02, loss_d_u:2.63e-05
# Iter # 49600/50000	time:1334.1	loss:1.25e+00, loss_r_u:3.52e-02, loss_d_u:3.06e-06
# Iter # 49700/50000	time:1336.7	loss:9.55e-01, loss_r_u:3.50e-02, loss_d_u:3.31e-06
# Iter # 49800/50000	time:1339.2	loss:9.47e+00, loss_r_u:4.88e-02, loss_d_u:2.57e-06
# Iter # 49900/50000	time:1341.8	loss:6.73e+00, loss_r_u:3.47e-02, loss_d_u:3.62e-06
# Iter # 50000/50000	time:1344.3	loss:3.40e+01, loss_r_u:3.40e-02, loss_d_u:1.24e-05

# %%
model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(),'nn_k_state': pinn.nn_k.state_dict()}
backbone_path = os.path.join(model_path, f'backbone_adam.pth')
torch.save(model_state, backbone_path)

np.save("./loss_logger_dict.npy", logger)

# %%
def used_time(start_time):
    seconds = time.time() - start_time
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print(f'used time: {hours:.0f}h {minutes:.0f}m {seconds:.0f}s')
    
used_time(start_time)
# Out:
# used time: 0h 22m 24s

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
# loss曲线
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res_u1"]
        [::k], label=r"Re($\mathcal{L}_{r})$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_data_u1"]
        [::k], label=r"Re($\mathcal{L}_{data})$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)
model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_k.load_state_dict(model_state['nn_k_state'])
# Out:
# <All keys matched successfully>

# %%
N = 2000
dataset = Dataset(N)
t1_data, k1_data, u1_data, t2_data, k2_data, u2_data, t3_data, k3_data, u3_data = dataset.train_data(N)

# %%
# x = torch.linspace(0, 1, 2000)
# k_data = 8/3*x**2 - 8/3*x + 1
# u_data = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
#     45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
#     45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
#     (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
#     15 * x ** 2) / 4
# t_data = x

# %%
# relative L2 误差
u1_data = np.array(u1_data).reshape(-1, 1)
u2_data = np.array(u2_data).reshape(-1, 1)
u3_data = np.array(u3_data).reshape(-1, 1)
t1_data = np.array(t1_data).reshape(-1, 1)
t2_data = np.array(t2_data).reshape(-1, 1)
t3_data = np.array(t3_data).reshape(-1, 1)
k1_data = np.array(k1_data).reshape(-1, 1)
k2_data = np.array(k2_data).reshape(-1, 1)
k3_data = np.array(k3_data).reshape(-1, 1)

t1_data = torch.tensor(t1_data).float().to(device)
t2_data = torch.tensor(t2_data).float().to(device)
t3_data = torch.tensor(t3_data).float().to(device)
u1_pred = pinn.net_u(t1_data).detach().cpu().numpy()
u2_pred = pinn.net_u(t2_data).detach().cpu().numpy()
u3_pred = pinn.net_u(t3_data).detach().cpu().numpy()
k1_pred = pinn.net_k(t1_data).detach().cpu().numpy()
k2_pred = pinn.net_k(t2_data).detach().cpu().numpy()
k3_pred = pinn.net_k(t3_data).detach().cpu().numpy()
# u3_pred = pinn.net_3u(t1_data).detach().cpu().numpy()

t1_data = t1_data.detach().cpu().numpy()
t2_data = t2_data.detach().cpu().numpy()
t3_data = t3_data.detach().cpu().numpy()

t_data = np.concatenate([t1_data, t2_data, t3_data], axis=1)
u_pred = np.concatenate([u1_pred, u2_pred, u3_pred], axis=1)
u_data = np.concatenate([u1_data, u2_data, u3_data], axis=1)
k_pred = np.concatenate([k1_pred, k2_pred, k3_pred], axis=1)
k_data = np.concatenate([k1_data, k2_data, k3_data], axis=1)
error_u = np.linalg.norm(u_pred - u_data) / np.linalg.norm(u_data)
error_k = np.linalg.norm(k_pred - k_data) / np.linalg.norm(k_data)
print('u Relative l2 error: {:.3e}'.format(error_u))
print('k Relative l2 error: {:.3e}'.format(error_k))
# Out:
# u Relative l2 error: 1.629e-03
# k Relative l2 error: 5.616e-02

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t_data, u_data)
# cax = ax.plot(t_data, u_pred)

cax = ax.scatter(t_data, u_data)
cax = ax.scatter(t_data, u_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'$u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())


cax2 = ax2.scatter(t_data, np.abs(u_data - u_pred))
# cax2 = ax2.scatter(t_data, u_pred)
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error of $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t1_data, k1_data)
# cax = ax.plot(t1_data, k1_pred)

cax = ax.scatter(t_data, k_data)
cax = ax.scatter(t_data, k_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $k(t)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(k_data - k_pred))
cax2 = ax2.scatter(t_data, np.abs(k_data - k_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error $k(t)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('K.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

cax = ax.scatter(t1_data, u3_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $d3u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Predicted $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()
