# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_46663/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io

import os
import time

# %% [markdown]
# ## 超参数设置

# %%
domain = (-1, 1, -1, 1)
xmin, xmax, ymin, ymax = domain
mlp_layers = [1] + [40]*4 + [1]
mlp_layers_k = [1] + [20]*2 + [1]
n_iters = 100000
# n_iters = 50000
learning_rate = 1e-3
gamma = 0.7

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
# 生成x的数据点
x = torch.linspace(0, 1, 100)

# 计算对应的y值
y = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
    45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
    45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
    (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
    15 * x ** 2) / 4

# 创建一个数据框
data = pd.DataFrame({'x': x.numpy(), 'y': y.numpy()})

# 绘制图形
plt.figure(figsize=(8, 6))
plt.plot(x.numpy(), y.numpy(), label='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Y vs. X')
plt.legend()
plt.grid(True)

# 保存数据到Excel文件
data.to_excel('output.xlsx', index=False)

# 显示图形
plt.show()

# %%
class Dataset:
    def __init__(self, N):
        self.x = torch.linspace(0, 1, N)
        
    
    def train_data(self, N, verbose=None):
        # 无量纲化
        t0 = 5
        K0 = 31250
        U0 = 0.001

        x = self.x
        k = self.k(x)
        # y = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
        # 45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
        # 45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
        # (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
        # 15 * x ** 2) / 4

        y = 5/3*x**4 - 10/3*x**3 + 5/3*x
        # print(self.x.shape)
        idx = np.random.randint(0,self.x.shape[0],N)
        # return x.reshape(-1,1), k.reshape(-1,1), y.reshape(-1,1)
        return x[idx].reshape(-1, 1), k[idx].reshape(-1,1), y[idx].reshape(-1,1)

    # k函数
    def k(self, t):
        # return 8/3*t**2 - 8/3*t + 1
        return np.ones_like(t)
        # return 10000*(t*5-2.5)**2 + 31250
    

N = 1000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)
print(t_data.shape, k_data.shape, u_data.shape)
# Out:
# torch.Size([1000, 1]) (1000, 1) torch.Size([1000, 1])

# %%
# u_data
plt.scatter(t_data, u_data)

# %%
# k_data
plt.scatter(t_data, k_data)

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            self.model.add_module(f'fc{i+1}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            self.model.add_module(f'act{i+1}', nn.Tanh())
        self.model.add_module(f'fc{len(mlp_layers)-1})', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
    
    def forward(self, X):
        return self.model(X)
    
    
mlp = MLP(mlp_layers)
mlp_k = MLP(mlp_layers_k)
mlp.model
# Out:
# Sequential(
#   (fc1): Linear(in_features=1, out_features=40, bias=True)
#   (act1): Tanh()
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (act2): Tanh()
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (act3): Tanh()
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (act4): Tanh()
#   (fc5)): Linear(in_features=40, out_features=1, bias=False)
# )

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINNHelmholtz(nn.Module):
    def __init__(self, backbone, nn_k):
        super(PINNHelmholtz, self).__init__()
        self.backbone = backbone
        self.nn_k = nn_k
        self.k = nn.Parameter(torch.tensor(
            [0.7], dtype=torch.float32).to(device), requires_grad=True)
        self.backbone.register_parameter("k", self.k)

        
    def forward(self, X_res, u_data):
        f_res_pred = self.net_f(X_res)
        u_pred = self.net_u(X_res)

        loss_res_u = torch.mean((f_res_pred - 30) ** 2)
        loss_data_u = torch.mean((u_pred - u_data) ** 2)
        return loss_res_u, loss_data_u
    
    def net_u(self, X):
        return self.backbone(X)
    
    def net_k(self, X):
        # return 8/3*X**2 - 8/3*X + 1
        return self.nn_k(X)

    def net_3u(self, X):
        X.requires_grad_(True)
        u = self.net_u(X)

        # 求u的梯度
        du = grad(u, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        return d3u
    
    def net_f(self, X):
        X.requires_grad_(True)
        u_pred = self.net_u(X)
        
        # 求u的梯度
        du = grad(u_pred, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        d4u = grad(d3u, X)[0]
        
        # k_pred = torch.ones_like(u_pred)*self.k
        # dk = grad(k_pred, X)[0]
        # d2k = grad(dk, X)[0]
        
        f_res_pred = 0.75*self.k*d4u
        
        return f_res_pred
    

pinn = PINNHelmholtz(mlp,mlp_k)

# %% [markdown]
# ## Adam训练

# %%
# 训练
N = 1000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)
t_data = t_data.float().to(device)
u_data = u_data.float().to(device)

backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=learning_rate)
# optimizer_adam_k = optim.Adam(pinn.nn_k.parameters(), lr=learning_rate)

lr_sche = ReduceLROnPlateau(optimizer_adam, mode='min', factor=gamma, verbose=True)
# lr_sche_k = ReduceLROnPlateau(optimizer_adam_k, mode='min', factor=gamma, verbose=True)
# lr_sche = ExponentialLR(optimizer_adam, gamma=gamma, verbose=True)
# lr_sche_k = ExponentialLR(optimizer_adam_k, gamma=gamma, verbose=True)

logger = {
    "loss": [],
    "loss_res_u": [],
    "loss_data_u": [],
    "iter": [],
    "k": []
}
with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for it in range(n_iters):
    pinn.zero_grad()
    loss_res_u, loss_data_u = pinn(t_data, u_data)
    # loss = 1*(loss_res_u) + 1e2*(loss_data_u)
    loss = 1*(loss_res_u) + 1e4*(loss_data_u)
    loss.backward()
    optimizer_adam.step()
    # optimizer_adam_k.step()
    
    # 保存训练信息 -------
    logger["loss"].append(loss.item())
    logger["loss_res_u"].append(loss_res_u.item())
    logger["loss_data_u"].append(loss_data_u.item())
    logger["iter"].append(it + 1)
    logger["k"].append(pinn.k.cpu().detach().numpy())

    
    if (it + 1) % 100 == 0:  # 打印训练信息 -------
        info = f'Iter # {it+1:4d}/{n_iters}\ttime:{time.time()-start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r_u:{loss_res_u.item():.2e}, loss_d_u:{loss_data_u.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        
    if (it + 1) % 100 == 0:  # 学习率衰减 -------
        lr_sche.step(loss)
        # lr_sche_k.step(loss)
# Out:
# Iter #  100/100000	time:1.1	loss:2.73e+01, loss_r_u:1.99e+01, loss_d_u:7.38e-04
# Iter #  200/100000	time:2.1	loss:5.15e+00, loss_r_u:1.76e+00, loss_d_u:3.39e-04
# Iter #  300/100000	time:3.2	loss:4.06e+00, loss_r_u:1.37e+00, loss_d_u:2.69e-04
# Iter #  400/100000	time:4.3	loss:3.46e+00, loss_r_u:1.06e+00, loss_d_u:2.40e-04
# Iter #  500/100000	time:5.4	loss:2.99e+00, loss_r_u:8.71e-01, loss_d_u:2.12e-04
# Iter #  600/100000	time:6.4	loss:2.47e+00, loss_r_u:6.66e-01, loss_d_u:1.81e-04
# Iter #  700/100000	time:7.5	loss:2.11e+00, loss_r_u:5.91e-01, loss_d_u:1.52e-04
# Iter #  800/100000	time:8.6	loss:1.71e+00, loss_r_u:4.64e-01, loss_d_u:1.25e-04
# Iter #  900/100000	time:9.6	loss:1.42e+00, loss_r_u:3.95e-01, loss_d_u:1.03e-04
# Iter # 1000/100000	time:10.7	loss:1.19e+00, loss_r_u:3.58e-01, loss_d_u:8.31e-05
# Iter # 1100/100000	time:11.8	loss:9.94e-01, loss_r_u:3.02e-01, loss_d_u:6.92e-05
# Iter # 1200/100000	time:12.9	loss:8.39e-01, loss_r_u:2.67e-01, loss_d_u:5.72e-05
# Iter # 1300/100000	time:14.0	loss:7.09e-01, loss_r_u:2.60e-01, loss_d_u:4.49e-05
# Iter # 1400/100000	time:15.0	loss:6.03e-01, loss_r_u:2.19e-01, loss_d_u:3.84e-05
# Iter # 1500/100000	time:16.1	loss:5.07e-01, loss_r_u:1.94e-01, loss_d_u:3.13e-05
# Iter # 1600/100000	time:17.2	loss:5.94e-01, loss_r_u:2.21e-01, loss_d_u:3.73e-05
# Iter # 1700/100000	time:18.3	loss:3.25e-01, loss_r_u:1.33e-01, loss_d_u:1.91e-05
# Iter # 1800/100000	time:19.3	loss:2.37e-01, loss_r_u:9.76e-02, loss_d_u:1.40e-05
# Iter # 1900/100000	time:20.4	loss:6.56e-01, loss_r_u:2.05e-01, loss_d_u:4.51e-05
# Iter # 2000/100000	time:21.5	loss:1.16e-01, loss_r_u:4.85e-02, loss_d_u:6.75e-06
# Iter # 2100/100000	time:22.6	loss:8.14e-02, loss_r_u:3.60e-02, loss_d_u:4.54e-06
# Iter # 2200/100000	time:23.7	loss:7.11e-02, loss_r_u:3.36e-02, loss_d_u:3.74e-06
# Iter # 2300/100000	time:24.7	loss:5.30e-02, loss_r_u:2.74e-02, loss_d_u:2.55e-06
# Iter # 2400/100000	time:25.8	loss:5.63e-02, loss_r_u:2.74e-02, loss_d_u:2.90e-06
# Iter # 2500/100000	time:26.9	loss:4.12e-02, loss_r_u:2.40e-02, loss_d_u:1.72e-06
# Iter # 2600/100000	time:27.9	loss:3.22e-01, loss_r_u:2.03e-01, loss_d_u:1.19e-05
# Iter # 2700/100000	time:29.0	loss:3.49e-02, loss_r_u:2.14e-02, loss_d_u:1.35e-06
# Iter # 2800/100000	time:30.1	loss:3.17e-02, loss_r_u:2.01e-02, loss_d_u:1.15e-06
# Iter # 2900/100000	time:31.2	loss:6.12e-02, loss_r_u:4.99e-02, loss_d_u:1.13e-06
# Iter # 3000/100000	time:32.3	loss:2.85e-02, loss_r_u:1.81e-02, loss_d_u:1.04e-06
# Iter # 3100/100000	time:33.3	loss:2.64e-02, loss_r_u:1.71e-02, loss_d_u:9.33e-07
# Iter # 3200/100000	time:34.4	loss:6.84e-02, loss_r_u:2.36e-02, loss_d_u:4.47e-06
# Iter # 3300/100000	time:35.5	loss:2.42e-02, loss_r_u:1.54e-02, loss_d_u:8.87e-07
# Iter # 3400/100000	time:36.5	loss:3.07e-02, loss_r_u:1.78e-02, loss_d_u:1.28e-06
# Iter # 3500/100000	time:37.6	loss:2.29e-02, loss_r_u:1.48e-02, loss_d_u:8.08e-07
# Iter # 3600/100000	time:38.7	loss:2.12e-02, loss_r_u:1.36e-02, loss_d_u:7.61e-07
# Iter # 3700/100000	time:39.8	loss:2.06e+00, loss_r_u:3.26e-01, loss_d_u:1.73e-04
# Iter # 3800/100000	time:40.8	loss:2.01e-02, loss_r_u:1.22e-02, loss_d_u:7.94e-07
# Iter # 3900/100000	time:41.9	loss:1.91e-02, loss_r_u:1.19e-02, loss_d_u:7.22e-07
# Iter # 4000/100000	time:43.0	loss:2.00e-02, loss_r_u:1.21e-02, loss_d_u:7.98e-07
# Iter # 4100/100000	time:44.1	loss:1.80e-02, loss_r_u:1.12e-02, loss_d_u:6.84e-07
# Iter # 4200/100000	time:45.1	loss:1.73e-02, loss_r_u:1.07e-02, loss_d_u:6.60e-07
# Iter # 4300/100000	time:46.2	loss:2.10e-02, loss_r_u:1.44e-02, loss_d_u:6.59e-07
# Iter # 4400/100000	time:47.3	loss:1.65e-02, loss_r_u:1.02e-02, loss_d_u:6.32e-07
# Iter # 4500/100000	time:48.4	loss:4.06e-02, loss_r_u:2.40e-02, loss_d_u:1.66e-06
# Iter # 4600/100000	time:49.4	loss:8.62e-02, loss_r_u:4.32e-02, loss_d_u:4.31e-06
# Iter # 4700/100000	time:50.5	loss:1.60e-02, loss_r_u:9.33e-03, loss_d_u:6.69e-07
# Iter # 4800/100000	time:51.6	loss:1.49e-02, loss_r_u:9.00e-03, loss_d_u:5.92e-07
# Iter # 4900/100000	time:52.6	loss:7.51e-02, loss_r_u:6.53e-02, loss_d_u:9.76e-07
# Iter # 5000/100000	time:53.7	loss:1.42e-02, loss_r_u:8.30e-03, loss_d_u:5.90e-07
# Iter # 5100/100000	time:54.8	loss:1.76e-02, loss_r_u:1.10e-02, loss_d_u:6.68e-07
# Iter # 5200/100000	time:55.9	loss:1.44e-01, loss_r_u:1.26e-01, loss_d_u:1.81e-06
# Iter # 5300/100000	time:56.9	loss:1.32e-02, loss_r_u:7.43e-03, loss_d_u:5.76e-07
# Iter # 5400/100000	time:58.0	loss:2.40e-02, loss_r_u:1.45e-02, loss_d_u:9.59e-07
# Iter # 5500/100000	time:59.1	loss:1.11e+00, loss_r_u:1.01e+00, loss_d_u:1.02e-05
# Iter # 5600/100000	time:60.1	loss:4.91e-01, loss_r_u:1.20e-01, loss_d_u:3.71e-05
# Iter # 5700/100000	time:61.2	loss:1.23e-02, loss_r_u:6.94e-03, loss_d_u:5.40e-07
# Iter # 5800/100000	time:62.3	loss:2.02e-01, loss_r_u:3.84e-02, loss_d_u:1.63e-05
# Iter # 5900/100000	time:63.4	loss:1.61e-02, loss_r_u:1.09e-02, loss_d_u:5.13e-07
# Iter # 6000/100000	time:64.4	loss:1.32e-01, loss_r_u:3.28e-02, loss_d_u:9.95e-06
# Iter # 6100/100000	time:65.5	loss:7.78e-01, loss_r_u:5.90e-01, loss_d_u:1.88e-05
# Iter # 6200/100000	time:66.6	loss:1.13e-02, loss_r_u:6.21e-03, loss_d_u:5.07e-07
# Iter # 6300/100000	time:67.6	loss:7.97e-02, loss_r_u:4.60e-02, loss_d_u:3.37e-06
# Iter # 6400/100000	time:68.7	loss:1.07e-02, loss_r_u:5.90e-03, loss_d_u:4.85e-07
# Iter # 6500/100000	time:69.8	loss:5.80e-02, loss_r_u:5.03e-02, loss_d_u:7.69e-07
# Iter # 6600/100000	time:70.9	loss:1.64e-01, loss_r_u:4.19e-02, loss_d_u:1.22e-05
# Iter # 6700/100000	time:71.9	loss:1.51e-02, loss_r_u:7.70e-03, loss_d_u:7.36e-07
# Iter # 6800/100000	time:73.0	loss:1.04e-02, loss_r_u:5.59e-03, loss_d_u:4.80e-07
# Iter # 6900/100000	time:74.1	loss:1.55e-02, loss_r_u:1.09e-02, loss_d_u:4.64e-07
# Iter # 7000/100000	time:75.2	loss:9.07e-02, loss_r_u:4.98e-02, loss_d_u:4.08e-06
# Iter # 7100/100000	time:76.2	loss:9.65e-03, loss_r_u:5.11e-03, loss_d_u:4.54e-07
# Iter # 7200/100000	time:77.3	loss:1.14e-02, loss_r_u:6.04e-03, loss_d_u:5.37e-07
# Iter # 7300/100000	time:78.4	loss:1.14e-01, loss_r_u:5.47e-02, loss_d_u:5.97e-06
# Iter # 7400/100000	time:79.5	loss:9.31e-03, loss_r_u:4.92e-03, loss_d_u:4.39e-07
# Iter # 7500/100000	time:80.5	loss:1.18e-02, loss_r_u:6.95e-03, loss_d_u:4.81e-07
# Iter # 7600/100000	time:81.6	loss:1.74e+00, loss_r_u:6.32e-01, loss_d_u:1.11e-04
# Iter # 7700/100000	time:82.7	loss:9.12e-03, loss_r_u:4.91e-03, loss_d_u:4.20e-07
# Iter # 7800/100000	time:83.8	loss:1.41e-01, loss_r_u:9.02e-02, loss_d_u:5.06e-06
# Iter # 7900/100000	time:84.8	loss:8.81e-03, loss_r_u:4.62e-03, loss_d_u:4.19e-07
# Iter # 8000/100000	time:85.9	loss:1.16e-02, loss_r_u:5.36e-03, loss_d_u:6.24e-07
# Iter # 8100/100000	time:87.0	loss:3.01e-02, loss_r_u:1.09e-02, loss_d_u:1.93e-06
# Iter # 8200/100000	time:88.0	loss:1.02e-02, loss_r_u:5.82e-03, loss_d_u:4.33e-07
# Iter # 8300/100000	time:89.1	loss:5.21e-02, loss_r_u:1.74e-02, loss_d_u:3.46e-06
# Iter # 8400/100000	time:90.2	loss:1.31e-01, loss_r_u:4.65e-02, loss_d_u:8.43e-06
# Iter # 8500/100000	time:91.2	loss:6.87e-01, loss_r_u:1.10e-01, loss_d_u:5.78e-05
# Iter # 8600/100000	time:92.3	loss:6.01e-01, loss_r_u:5.32e-02, loss_d_u:5.48e-05
# Iter # 8700/100000	time:93.4	loss:3.76e-01, loss_r_u:1.30e-01, loss_d_u:2.47e-05
# Iter # 8800/100000	time:94.4	loss:2.32e-01, loss_r_u:1.15e-01, loss_d_u:1.17e-05
# Iter # 8900/100000	time:95.5	loss:8.07e-03, loss_r_u:4.33e-03, loss_d_u:3.74e-07
# Iter # 9000/100000	time:96.6	loss:1.04e-02, loss_r_u:5.94e-03, loss_d_u:4.47e-07
# Iter # 9100/100000	time:97.7	loss:1.96e-02, loss_r_u:9.90e-03, loss_d_u:9.74e-07
# Iter # 9200/100000	time:98.8	loss:1.33e-02, loss_r_u:9.79e-03, loss_d_u:3.50e-07
# Iter # 9300/100000	time:99.8	loss:6.54e-02, loss_r_u:2.11e-02, loss_d_u:4.43e-06
# Iter # 9400/100000	time:100.9	loss:5.14e-01, loss_r_u:2.85e-01, loss_d_u:2.29e-05
# Iter # 9500/100000	time:102.0	loss:8.26e-03, loss_r_u:4.93e-03, loss_d_u:3.33e-07
# Iter # 9600/100000	time:103.0	loss:9.49e-03, loss_r_u:5.04e-03, loss_d_u:4.45e-07
# Iter # 9700/100000	time:104.1	loss:7.54e-03, loss_r_u:4.25e-03, loss_d_u:3.29e-07
# Iter # 9800/100000	time:105.2	loss:1.41e-02, loss_r_u:1.04e-02, loss_d_u:3.63e-07
# Iter # 9900/100000	time:106.3	loss:5.26e-01, loss_r_u:1.81e-01, loss_d_u:3.44e-05
# Iter # 10000/100000	time:107.3	loss:3.22e-01, loss_r_u:3.00e-01, loss_d_u:2.19e-06
# Iter # 10100/100000	time:108.4	loss:6.58e-01, loss_r_u:2.32e-01, loss_d_u:4.26e-05
# Iter # 10200/100000	time:109.5	loss:7.96e-02, loss_r_u:3.57e-02, loss_d_u:4.39e-06
# Iter # 10300/100000	time:110.5	loss:3.92e-02, loss_r_u:1.78e-02, loss_d_u:2.14e-06
# Iter # 10400/100000	time:111.6	loss:1.64e-02, loss_r_u:1.31e-02, loss_d_u:3.30e-07
# Iter # 10500/100000	time:112.7	loss:3.55e-02, loss_r_u:1.22e-02, loss_d_u:2.33e-06
# Iter # 10600/100000	time:113.8	loss:6.57e-02, loss_r_u:5.85e-02, loss_d_u:7.20e-07
# Iter # 10700/100000	time:114.8	loss:1.09e+00, loss_r_u:3.41e-01, loss_d_u:7.50e-05
# Iter # 10800/100000	time:115.9	loss:7.05e-03, loss_r_u:4.11e-03, loss_d_u:2.94e-07
# Iter # 10900/100000	time:117.0	loss:1.01e-02, loss_r_u:5.52e-03, loss_d_u:4.54e-07
# Iter # 11000/100000	time:118.0	loss:7.17e-03, loss_r_u:4.15e-03, loss_d_u:3.01e-07
# Iter # 11100/100000	time:119.1	loss:2.09e-01, loss_r_u:5.12e-02, loss_d_u:1.58e-05
# Iter # 11200/100000	time:120.2	loss:8.28e-02, loss_r_u:7.93e-02, loss_d_u:3.50e-07
# Iter # 11300/100000	time:121.3	loss:1.62e-01, loss_r_u:4.33e-02, loss_d_u:1.18e-05
# Iter # 11400/100000	time:122.3	loss:7.05e-03, loss_r_u:4.01e-03, loss_d_u:3.05e-07
# Iter # 11500/100000	time:123.4	loss:8.89e-02, loss_r_u:8.36e-02, loss_d_u:5.25e-07
# Iter # 11600/100000	time:124.5	loss:8.66e-02, loss_r_u:5.88e-02, loss_d_u:2.78e-06
# Iter # 11700/100000	time:125.5	loss:8.37e-03, loss_r_u:5.52e-03, loss_d_u:2.86e-07
# Iter # 11800/100000	time:126.6	loss:1.65e-02, loss_r_u:9.08e-03, loss_d_u:7.45e-07
# Iter # 11900/100000	time:127.7	loss:8.56e-03, loss_r_u:5.30e-03, loss_d_u:3.25e-07
# Epoch 00119: reducing learning rate of group 0 to 7.0000e-04.
# Iter # 12000/100000	time:128.8	loss:6.30e-03, loss_r_u:3.79e-03, loss_d_u:2.51e-07
# Iter # 12100/100000	time:129.8	loss:6.22e-03, loss_r_u:3.71e-03, loss_d_u:2.51e-07
# Iter # 12200/100000	time:130.9	loss:6.16e-03, loss_r_u:3.65e-03, loss_d_u:2.51e-07
# Iter # 12300/100000	time:132.0	loss:6.10e-03, loss_r_u:3.60e-03, loss_d_u:2.50e-07
# Iter # 12400/100000	time:133.0	loss:6.04e-03, loss_r_u:3.56e-03, loss_d_u:2.48e-07
# Iter # 12500/100000	time:134.1	loss:5.98e-03, loss_r_u:3.52e-03, loss_d_u:2.46e-07
# Iter # 12600/100000	time:135.2	loss:5.92e-03, loss_r_u:3.49e-03, loss_d_u:2.44e-07
# Iter # 12700/100000	time:136.2	loss:3.25e-02, loss_r_u:2.86e-02, loss_d_u:3.94e-07
# Iter # 12800/100000	time:137.3	loss:7.32e-03, loss_r_u:3.73e-03, loss_d_u:3.58e-07
# Iter # 12900/100000	time:138.4	loss:9.66e-03, loss_r_u:6.80e-03, loss_d_u:2.86e-07
# Iter # 13000/100000	time:139.5	loss:2.03e-02, loss_r_u:1.44e-02, loss_d_u:5.96e-07
# Iter # 13100/100000	time:140.5	loss:5.50e-01, loss_r_u:4.11e-01, loss_d_u:1.39e-05
# Iter # 13200/100000	time:141.6	loss:3.50e-01, loss_r_u:1.29e-01, loss_d_u:2.22e-05
# Iter # 13300/100000	time:142.7	loss:5.88e-03, loss_r_u:3.69e-03, loss_d_u:2.20e-07
# Iter # 13400/100000	time:143.8	loss:5.26e-01, loss_r_u:1.27e-01, loss_d_u:3.98e-05
# Iter # 13500/100000	time:144.9	loss:1.45e-02, loss_r_u:1.23e-02, loss_d_u:2.24e-07
# Iter # 13600/100000	time:145.9	loss:7.89e-03, loss_r_u:4.21e-03, loss_d_u:3.68e-07
# Iter # 13700/100000	time:147.0	loss:1.91e-02, loss_r_u:8.74e-03, loss_d_u:1.03e-06
# Iter # 13800/100000	time:148.1	loss:3.69e-02, loss_r_u:1.15e-02, loss_d_u:2.54e-06
# Iter # 13900/100000	time:149.1	loss:7.68e-03, loss_r_u:4.77e-03, loss_d_u:2.91e-07
# Iter # 14000/100000	time:150.2	loss:8.95e-03, loss_r_u:5.36e-03, loss_d_u:3.59e-07
# Iter # 14100/100000	time:151.3	loss:5.73e-03, loss_r_u:3.57e-03, loss_d_u:2.17e-07
# Iter # 14200/100000	time:152.4	loss:5.52e-03, loss_r_u:3.53e-03, loss_d_u:1.99e-07
# Iter # 14300/100000	time:153.5	loss:1.57e-02, loss_r_u:9.35e-03, loss_d_u:6.36e-07
# Iter # 14400/100000	time:154.5	loss:6.74e-03, loss_r_u:3.94e-03, loss_d_u:2.80e-07
# Iter # 14500/100000	time:155.6	loss:2.69e-01, loss_r_u:2.11e-01, loss_d_u:5.73e-06
# Iter # 14600/100000	time:156.7	loss:2.06e-02, loss_r_u:1.79e-02, loss_d_u:2.66e-07
# Iter # 14700/100000	time:157.8	loss:2.76e-01, loss_r_u:1.35e-01, loss_d_u:1.41e-05
# Iter # 14800/100000	time:158.8	loss:5.53e-02, loss_r_u:1.97e-02, loss_d_u:3.56e-06
# Iter # 14900/100000	time:159.9	loss:1.58e-01, loss_r_u:6.65e-02, loss_d_u:9.13e-06
# Iter # 15000/100000	time:161.0	loss:7.45e-03, loss_r_u:3.74e-03, loss_d_u:3.71e-07
# Iter # 15100/100000	time:162.1	loss:1.50e-01, loss_r_u:1.44e-01, loss_d_u:5.64e-07
# Iter # 15200/100000	time:163.1	loss:1.79e-02, loss_r_u:6.01e-03, loss_d_u:1.19e-06
# Iter # 15300/100000	time:164.2	loss:8.83e-03, loss_r_u:6.95e-03, loss_d_u:1.87e-07
# Epoch 00153: reducing learning rate of group 0 to 4.9000e-04.
# Iter # 15400/100000	time:165.3	loss:4.76e-03, loss_r_u:3.06e-03, loss_d_u:1.70e-07
# Iter # 15500/100000	time:166.3	loss:4.71e-03, loss_r_u:3.02e-03, loss_d_u:1.69e-07
# Iter # 15600/100000	time:167.4	loss:4.67e-03, loss_r_u:2.99e-03, loss_d_u:1.68e-07
# Iter # 15700/100000	time:168.5	loss:4.62e-03, loss_r_u:2.95e-03, loss_d_u:1.67e-07
# Iter # 15800/100000	time:169.5	loss:4.58e-03, loss_r_u:2.92e-03, loss_d_u:1.66e-07
# Iter # 15900/100000	time:170.6	loss:4.53e-03, loss_r_u:2.89e-03, loss_d_u:1.64e-07
# Iter # 16000/100000	time:171.7	loss:4.48e-03, loss_r_u:2.86e-03, loss_d_u:1.63e-07
# Iter # 16100/100000	time:172.8	loss:1.43e-01, loss_r_u:1.41e-01, loss_d_u:2.27e-07
# Iter # 16200/100000	time:173.8	loss:4.43e-03, loss_r_u:2.86e-03, loss_d_u:1.57e-07
# Iter # 16300/100000	time:174.9	loss:1.86e-02, loss_r_u:1.00e-02, loss_d_u:8.60e-07
# Iter # 16400/100000	time:176.0	loss:4.34e-03, loss_r_u:2.83e-03, loss_d_u:1.52e-07
# Iter # 16500/100000	time:177.1	loss:2.56e-02, loss_r_u:5.51e-03, loss_d_u:2.00e-06
# Iter # 16600/100000	time:178.1	loss:2.08e-02, loss_r_u:1.34e-02, loss_d_u:7.45e-07
# Iter # 16700/100000	time:179.2	loss:4.45e-03, loss_r_u:2.83e-03, loss_d_u:1.63e-07
# Iter # 16800/100000	time:180.2	loss:7.59e-03, loss_r_u:3.98e-03, loss_d_u:3.61e-07
# Iter # 16900/100000	time:181.3	loss:7.72e-03, loss_r_u:3.79e-03, loss_d_u:3.93e-07
# Iter # 17000/100000	time:182.4	loss:3.13e-02, loss_r_u:2.94e-02, loss_d_u:1.88e-07
# Iter # 17100/100000	time:183.5	loss:1.62e-02, loss_r_u:5.79e-03, loss_d_u:1.05e-06
# Iter # 17200/100000	time:184.5	loss:6.94e-03, loss_r_u:5.48e-03, loss_d_u:1.46e-07
# Iter # 17300/100000	time:185.6	loss:1.53e-02, loss_r_u:3.42e-03, loss_d_u:1.18e-06
# Iter # 17400/100000	time:186.7	loss:6.89e-03, loss_r_u:4.00e-03, loss_d_u:2.89e-07
# Iter # 17500/100000	time:187.7	loss:3.94e-03, loss_r_u:2.59e-03, loss_d_u:1.35e-07
# Iter # 17600/100000	time:188.8	loss:6.26e-03, loss_r_u:4.12e-03, loss_d_u:2.14e-07
# Iter # 17700/100000	time:189.9	loss:5.61e-02, loss_r_u:5.10e-02, loss_d_u:5.16e-07
# Iter # 17800/100000	time:191.0	loss:4.14e-02, loss_r_u:3.92e-02, loss_d_u:2.20e-07
# Iter # 17900/100000	time:192.1	loss:6.72e-03, loss_r_u:4.08e-03, loss_d_u:2.64e-07
# Iter # 18000/100000	time:193.1	loss:3.72e-03, loss_r_u:2.44e-03, loss_d_u:1.28e-07
# Iter # 18100/100000	time:194.2	loss:6.15e-03, loss_r_u:4.34e-03, loss_d_u:1.81e-07
# Iter # 18200/100000	time:195.3	loss:3.90e-03, loss_r_u:2.58e-03, loss_d_u:1.32e-07
# Iter # 18300/100000	time:196.3	loss:3.60e-03, loss_r_u:2.40e-03, loss_d_u:1.20e-07
# Iter # 18400/100000	time:197.4	loss:3.63e-03, loss_r_u:2.41e-03, loss_d_u:1.22e-07
# Iter # 18500/100000	time:198.5	loss:5.43e-01, loss_r_u:1.43e-01, loss_d_u:4.00e-05
# Iter # 18600/100000	time:199.6	loss:3.45e-02, loss_r_u:3.06e-02, loss_d_u:3.90e-07
# Iter # 18700/100000	time:200.6	loss:3.70e-03, loss_r_u:2.41e-03, loss_d_u:1.30e-07
# Iter # 18800/100000	time:201.7	loss:3.41e-03, loss_r_u:2.29e-03, loss_d_u:1.12e-07
# Iter # 18900/100000	time:202.8	loss:9.23e-03, loss_r_u:4.34e-03, loss_d_u:4.89e-07
# Iter # 19000/100000	time:203.9	loss:1.36e-02, loss_r_u:8.47e-03, loss_d_u:5.11e-07
# Iter # 19100/100000	time:204.9	loss:3.33e-03, loss_r_u:2.24e-03, loss_d_u:1.08e-07
# Iter # 19200/100000	time:206.0	loss:3.49e-03, loss_r_u:2.38e-03, loss_d_u:1.11e-07
# Iter # 19300/100000	time:207.1	loss:3.84e-03, loss_r_u:2.33e-03, loss_d_u:1.51e-07
# Iter # 19400/100000	time:208.1	loss:5.43e-03, loss_r_u:3.96e-03, loss_d_u:1.47e-07
# Iter # 19500/100000	time:209.2	loss:4.64e-03, loss_r_u:3.29e-03, loss_d_u:1.35e-07
# Iter # 19600/100000	time:210.3	loss:3.50e-02, loss_r_u:3.33e-02, loss_d_u:1.71e-07
# Iter # 19700/100000	time:211.4	loss:1.21e-02, loss_r_u:1.08e-02, loss_d_u:1.22e-07
# Iter # 19800/100000	time:212.5	loss:3.01e-03, loss_r_u:2.05e-03, loss_d_u:9.64e-08
# Iter # 19900/100000	time:213.5	loss:1.30e-02, loss_r_u:4.55e-03, loss_d_u:8.42e-07
# Iter # 20000/100000	time:214.6	loss:3.01e-03, loss_r_u:2.00e-03, loss_d_u:1.01e-07
# Iter # 20100/100000	time:215.7	loss:3.83e-02, loss_r_u:1.07e-02, loss_d_u:2.76e-06
# Iter # 20200/100000	time:216.7	loss:5.07e-03, loss_r_u:2.81e-03, loss_d_u:2.25e-07
# Iter # 20300/100000	time:217.8	loss:2.87e-03, loss_r_u:1.93e-03, loss_d_u:9.39e-08
# Iter # 20400/100000	time:218.9	loss:3.52e-03, loss_r_u:2.14e-03, loss_d_u:1.38e-07
# Iter # 20500/100000	time:220.0	loss:2.93e-03, loss_r_u:1.93e-03, loss_d_u:1.00e-07
# Iter # 20600/100000	time:221.0	loss:2.85e-03, loss_r_u:1.88e-03, loss_d_u:9.65e-08
# Iter # 20700/100000	time:222.1	loss:3.35e-03, loss_r_u:2.11e-03, loss_d_u:1.24e-07
# Iter # 20800/100000	time:223.2	loss:2.71e-03, loss_r_u:1.88e-03, loss_d_u:8.28e-08
# Iter # 20900/100000	time:224.3	loss:9.03e-02, loss_r_u:3.61e-02, loss_d_u:5.42e-06
# Iter # 21000/100000	time:225.3	loss:2.72e-03, loss_r_u:1.80e-03, loss_d_u:9.24e-08
# Iter # 21100/100000	time:226.4	loss:3.42e-03, loss_r_u:2.03e-03, loss_d_u:1.39e-07
# Iter # 21200/100000	time:227.5	loss:2.55e-03, loss_r_u:1.75e-03, loss_d_u:8.03e-08
# Iter # 21300/100000	time:228.6	loss:3.77e-03, loss_r_u:2.14e-03, loss_d_u:1.63e-07
# Iter # 21400/100000	time:229.6	loss:4.49e-03, loss_r_u:2.89e-03, loss_d_u:1.60e-07
# Iter # 21500/100000	time:230.7	loss:5.81e-03, loss_r_u:3.20e-03, loss_d_u:2.61e-07
# Iter # 21600/100000	time:231.8	loss:1.21e-02, loss_r_u:7.18e-03, loss_d_u:4.89e-07
# Iter # 21700/100000	time:232.9	loss:1.81e-02, loss_r_u:1.39e-02, loss_d_u:4.24e-07
# Iter # 21800/100000	time:233.9	loss:8.95e-03, loss_r_u:7.65e-03, loss_d_u:1.30e-07
# Iter # 21900/100000	time:235.0	loss:2.33e-03, loss_r_u:1.63e-03, loss_d_u:7.06e-08
# Iter # 22000/100000	time:236.1	loss:2.92e-03, loss_r_u:2.03e-03, loss_d_u:8.88e-08
# Iter # 22100/100000	time:237.2	loss:2.28e-03, loss_r_u:1.57e-03, loss_d_u:7.16e-08
# Iter # 22200/100000	time:238.3	loss:3.16e-03, loss_r_u:1.91e-03, loss_d_u:1.25e-07
# Iter # 22300/100000	time:239.3	loss:2.40e-03, loss_r_u:1.61e-03, loss_d_u:7.91e-08
# Iter # 22400/100000	time:240.4	loss:4.13e-03, loss_r_u:2.54e-03, loss_d_u:1.59e-07
# Iter # 22500/100000	time:241.5	loss:2.51e-03, loss_r_u:1.82e-03, loss_d_u:6.83e-08
# Iter # 22600/100000	time:242.6	loss:2.14e-01, loss_r_u:6.46e-02, loss_d_u:1.50e-05
# Iter # 22700/100000	time:243.6	loss:4.23e-02, loss_r_u:3.99e-02, loss_d_u:2.35e-07
# Iter # 22800/100000	time:244.7	loss:1.34e-02, loss_r_u:1.12e-02, loss_d_u:2.27e-07
# Iter # 22900/100000	time:245.8	loss:2.06e-03, loss_r_u:1.45e-03, loss_d_u:6.06e-08
# Iter # 23000/100000	time:246.9	loss:2.35e-02, loss_r_u:1.87e-02, loss_d_u:4.82e-07
# Iter # 23100/100000	time:247.9	loss:3.66e-03, loss_r_u:3.06e-03, loss_d_u:6.05e-08
# Iter # 23200/100000	time:249.0	loss:2.52e-03, loss_r_u:1.90e-03, loss_d_u:6.15e-08
# Iter # 23300/100000	time:250.1	loss:9.22e-03, loss_r_u:4.64e-03, loss_d_u:4.58e-07
# Iter # 23400/100000	time:251.2	loss:7.79e-03, loss_r_u:6.90e-03, loss_d_u:8.90e-08
# Iter # 23500/100000	time:252.2	loss:2.35e-02, loss_r_u:9.91e-03, loss_d_u:1.35e-06
# Iter # 23600/100000	time:253.3	loss:1.02e-02, loss_r_u:8.03e-03, loss_d_u:2.18e-07
# Iter # 23700/100000	time:254.4	loss:6.07e-03, loss_r_u:1.97e-03, loss_d_u:4.10e-07
# Iter # 23800/100000	time:255.5	loss:4.10e-03, loss_r_u:3.16e-03, loss_d_u:9.39e-08
# Iter # 23900/100000	time:256.5	loss:2.07e-02, loss_r_u:1.35e-02, loss_d_u:7.12e-07
# Iter # 24000/100000	time:257.6	loss:1.19e-02, loss_r_u:1.01e-02, loss_d_u:1.77e-07
# Epoch 00240: reducing learning rate of group 0 to 3.4300e-04.
# Iter # 24100/100000	time:258.7	loss:1.76e-03, loss_r_u:1.24e-03, loss_d_u:5.22e-08
# Iter # 24200/100000	time:259.7	loss:1.73e-03, loss_r_u:1.21e-03, loss_d_u:5.21e-08
# Iter # 24300/100000	time:260.8	loss:1.71e-03, loss_r_u:1.19e-03, loss_d_u:5.17e-08
# Iter # 24400/100000	time:261.9	loss:1.68e-03, loss_r_u:1.17e-03, loss_d_u:5.12e-08
# Iter # 24500/100000	time:262.9	loss:1.65e-03, loss_r_u:1.15e-03, loss_d_u:5.06e-08
# Iter # 24600/100000	time:264.0	loss:1.63e-03, loss_r_u:1.13e-03, loss_d_u:5.00e-08
# Iter # 24700/100000	time:265.1	loss:1.60e-03, loss_r_u:1.10e-03, loss_d_u:4.93e-08
# Iter # 24800/100000	time:266.1	loss:2.41e-03, loss_r_u:1.46e-03, loss_d_u:9.48e-08
# Iter # 24900/100000	time:267.2	loss:6.08e-03, loss_r_u:2.50e-03, loss_d_u:3.58e-07
# Iter # 25000/100000	time:268.3	loss:2.04e-03, loss_r_u:1.21e-03, loss_d_u:8.31e-08
# Iter # 25100/100000	time:269.4	loss:1.94e-03, loss_r_u:1.23e-03, loss_d_u:7.17e-08
# Iter # 25200/100000	time:270.5	loss:7.53e-03, loss_r_u:3.73e-03, loss_d_u:3.80e-07
# Iter # 25300/100000	time:271.5	loss:1.51e-03, loss_r_u:1.05e-03, loss_d_u:4.60e-08
# Iter # 25400/100000	time:272.6	loss:1.63e-02, loss_r_u:1.52e-02, loss_d_u:1.10e-07
# Iter # 25500/100000	time:273.7	loss:5.93e-02, loss_r_u:3.26e-02, loss_d_u:2.67e-06
# Iter # 25600/100000	time:274.8	loss:1.84e-03, loss_r_u:1.11e-03, loss_d_u:7.33e-08
# Iter # 25700/100000	time:275.8	loss:1.44e-03, loss_r_u:1.02e-03, loss_d_u:4.18e-08
# Iter # 25800/100000	time:276.9	loss:3.55e-03, loss_r_u:2.99e-03, loss_d_u:5.62e-08
# Iter # 25900/100000	time:278.0	loss:6.35e-03, loss_r_u:5.63e-03, loss_d_u:7.16e-08
# Iter # 26000/100000	time:279.1	loss:2.60e-02, loss_r_u:2.45e-02, loss_d_u:1.48e-07
# Iter # 26100/100000	time:280.1	loss:3.98e-03, loss_r_u:3.08e-03, loss_d_u:9.02e-08
# Iter # 26200/100000	time:281.2	loss:1.34e-02, loss_r_u:1.20e-02, loss_d_u:1.38e-07
# Iter # 26300/100000	time:282.3	loss:2.32e-03, loss_r_u:1.89e-03, loss_d_u:4.34e-08
# Iter # 26400/100000	time:283.4	loss:1.47e-02, loss_r_u:1.35e-02, loss_d_u:1.18e-07
# Iter # 26500/100000	time:284.4	loss:3.18e-03, loss_r_u:1.77e-03, loss_d_u:1.41e-07
# Iter # 26600/100000	time:285.5	loss:8.29e-03, loss_r_u:5.26e-03, loss_d_u:3.02e-07
# Iter # 26700/100000	time:286.6	loss:3.71e-02, loss_r_u:3.52e-02, loss_d_u:1.87e-07
# Iter # 26800/100000	time:287.7	loss:1.20e-03, loss_r_u:8.57e-04, loss_d_u:3.46e-08
# Iter # 26900/100000	time:288.7	loss:1.49e-03, loss_r_u:9.95e-04, loss_d_u:4.91e-08
# Iter # 27000/100000	time:289.8	loss:1.17e-03, loss_r_u:8.39e-04, loss_d_u:3.31e-08
# Iter # 27100/100000	time:290.9	loss:1.37e-03, loss_r_u:8.56e-04, loss_d_u:5.14e-08
# Iter # 27200/100000	time:291.9	loss:1.29e-03, loss_r_u:9.33e-04, loss_d_u:3.62e-08
# Iter # 27300/100000	time:293.0	loss:1.29e-01, loss_r_u:3.27e-02, loss_d_u:9.62e-06
# Iter # 27400/100000	time:294.1	loss:1.11e-03, loss_r_u:8.00e-04, loss_d_u:3.12e-08
# Iter # 27500/100000	time:295.2	loss:1.33e-01, loss_r_u:3.48e-02, loss_d_u:9.85e-06
# Iter # 27600/100000	time:296.2	loss:1.12e-03, loss_r_u:8.12e-04, loss_d_u:3.06e-08
# Iter # 27700/100000	time:297.3	loss:1.11e-03, loss_r_u:7.98e-04, loss_d_u:3.09e-08
# Iter # 27800/100000	time:298.4	loss:1.21e-03, loss_r_u:8.87e-04, loss_d_u:3.26e-08
# Iter # 27900/100000	time:299.5	loss:1.47e-03, loss_r_u:1.18e-03, loss_d_u:2.91e-08
# Iter # 28000/100000	time:300.5	loss:9.72e-03, loss_r_u:7.57e-03, loss_d_u:2.15e-07
# Iter # 28100/100000	time:301.6	loss:1.02e-03, loss_r_u:7.45e-04, loss_d_u:2.77e-08
# Iter # 28200/100000	time:302.7	loss:1.05e-03, loss_r_u:7.72e-04, loss_d_u:2.74e-08
# Iter # 28300/100000	time:303.8	loss:3.73e-03, loss_r_u:1.40e-03, loss_d_u:2.33e-07
# Iter # 28400/100000	time:304.9	loss:3.04e-03, loss_r_u:2.71e-03, loss_d_u:3.33e-08
# Iter # 28500/100000	time:305.9	loss:1.20e-03, loss_r_u:7.49e-04, loss_d_u:4.52e-08
# Iter # 28600/100000	time:307.0	loss:7.39e-03, loss_r_u:1.92e-03, loss_d_u:5.47e-07
# Iter # 28700/100000	time:308.1	loss:3.26e-02, loss_r_u:1.53e-02, loss_d_u:1.73e-06
# Iter # 28800/100000	time:309.2	loss:2.21e-02, loss_r_u:1.16e-02, loss_d_u:1.05e-06
# Iter # 28900/100000	time:310.3	loss:8.66e-03, loss_r_u:7.95e-03, loss_d_u:7.04e-08
# Iter # 29000/100000	time:311.4	loss:2.92e-03, loss_r_u:2.22e-03, loss_d_u:6.98e-08
# Iter # 29100/100000	time:312.4	loss:1.44e-03, loss_r_u:9.64e-04, loss_d_u:4.74e-08
# Iter # 29200/100000	time:313.4	loss:5.19e-02, loss_r_u:1.33e-02, loss_d_u:3.87e-06
# Epoch 00292: reducing learning rate of group 0 to 2.4010e-04.
# Iter # 29300/100000	time:314.4	loss:8.97e-04, loss_r_u:6.77e-04, loss_d_u:2.20e-08
# Iter # 29400/100000	time:315.4	loss:8.85e-04, loss_r_u:6.69e-04, loss_d_u:2.17e-08
# Iter # 29500/100000	time:316.4	loss:8.75e-04, loss_r_u:6.61e-04, loss_d_u:2.14e-08
# Iter # 29600/100000	time:317.4	loss:8.64e-04, loss_r_u:6.53e-04, loss_d_u:2.11e-08
# Iter # 29700/100000	time:318.4	loss:8.53e-04, loss_r_u:6.45e-04, loss_d_u:2.08e-08
# Iter # 29800/100000	time:319.5	loss:8.41e-04, loss_r_u:6.37e-04, loss_d_u:2.05e-08
# Iter # 29900/100000	time:320.5	loss:8.30e-04, loss_r_u:6.29e-04, loss_d_u:2.01e-08
# Iter # 30000/100000	time:321.5	loss:3.18e-03, loss_r_u:2.15e-03, loss_d_u:1.03e-07
# Iter # 30100/100000	time:322.5	loss:8.54e-04, loss_r_u:6.58e-04, loss_d_u:1.96e-08
# Iter # 30200/100000	time:323.5	loss:6.92e-03, loss_r_u:3.67e-03, loss_d_u:3.26e-07
# Iter # 30300/100000	time:324.5	loss:8.12e-04, loss_r_u:6.21e-04, loss_d_u:1.92e-08
# Iter # 30400/100000	time:325.5	loss:1.08e-03, loss_r_u:8.27e-04, loss_d_u:2.52e-08
# Iter # 30500/100000	time:326.5	loss:2.20e-03, loss_r_u:1.80e-03, loss_d_u:4.04e-08
# Iter # 30600/100000	time:327.6	loss:8.43e-04, loss_r_u:6.36e-04, loss_d_u:2.07e-08
# Iter # 30700/100000	time:328.6	loss:1.82e-03, loss_r_u:1.12e-03, loss_d_u:7.01e-08
# Iter # 30800/100000	time:329.6	loss:3.72e-02, loss_r_u:3.16e-02, loss_d_u:5.54e-07
# Iter # 30900/100000	time:330.6	loss:9.76e-03, loss_r_u:3.06e-03, loss_d_u:6.70e-07
# Iter # 31000/100000	time:331.6	loss:7.70e-04, loss_r_u:5.96e-04, loss_d_u:1.74e-08
# Iter # 31100/100000	time:332.6	loss:7.52e-04, loss_r_u:5.80e-04, loss_d_u:1.72e-08
# Iter # 31200/100000	time:333.6	loss:1.44e-03, loss_r_u:1.16e-03, loss_d_u:2.77e-08
# Iter # 31300/100000	time:334.7	loss:1.01e-03, loss_r_u:7.25e-04, loss_d_u:2.87e-08
# Iter # 31400/100000	time:335.7	loss:4.40e-02, loss_r_u:1.85e-02, loss_d_u:2.55e-06
# Iter # 31500/100000	time:336.7	loss:3.97e-03, loss_r_u:1.42e-03, loss_d_u:2.54e-07
# Iter # 31600/100000	time:337.7	loss:5.70e-02, loss_r_u:3.95e-02, loss_d_u:1.75e-06
# Iter # 31700/100000	time:338.7	loss:1.31e-03, loss_r_u:8.72e-04, loss_d_u:4.38e-08
# Iter # 31800/100000	time:339.7	loss:7.10e-04, loss_r_u:5.62e-04, loss_d_u:1.47e-08
# Iter # 31900/100000	time:340.7	loss:3.85e-03, loss_r_u:3.69e-03, loss_d_u:1.61e-08
# Iter # 32000/100000	time:341.8	loss:6.98e-04, loss_r_u:5.60e-04, loss_d_u:1.38e-08
# Iter # 32100/100000	time:342.8	loss:7.10e-04, loss_r_u:5.66e-04, loss_d_u:1.43e-08
# Iter # 32200/100000	time:343.8	loss:1.82e-02, loss_r_u:3.20e-03, loss_d_u:1.50e-06
# Iter # 32300/100000	time:344.8	loss:6.85e-04, loss_r_u:5.55e-04, loss_d_u:1.29e-08
# Iter # 32400/100000	time:345.8	loss:6.81e-04, loss_r_u:5.54e-04, loss_d_u:1.27e-08
# Iter # 32500/100000	time:346.8	loss:1.55e-03, loss_r_u:1.32e-03, loss_d_u:2.23e-08
# Iter # 32600/100000	time:347.8	loss:1.41e-01, loss_r_u:4.35e-02, loss_d_u:9.72e-06
# Iter # 32700/100000	time:348.8	loss:6.57e-04, loss_r_u:5.35e-04, loss_d_u:1.22e-08
# Iter # 32800/100000	time:349.8	loss:2.49e-03, loss_r_u:2.21e-03, loss_d_u:2.83e-08
# Iter # 32900/100000	time:350.8	loss:3.64e-03, loss_r_u:3.22e-03, loss_d_u:4.12e-08
# Iter # 33000/100000	time:351.9	loss:7.32e-04, loss_r_u:5.50e-04, loss_d_u:1.83e-08
# Iter # 33100/100000	time:352.9	loss:8.08e-04, loss_r_u:6.85e-04, loss_d_u:1.24e-08
# Iter # 33200/100000	time:353.9	loss:9.21e-03, loss_r_u:3.96e-03, loss_d_u:5.25e-07
# Iter # 33300/100000	time:354.9	loss:6.45e-04, loss_r_u:5.23e-04, loss_d_u:1.22e-08
# Iter # 33400/100000	time:355.9	loss:6.62e-04, loss_r_u:5.34e-04, loss_d_u:1.29e-08
# Iter # 33500/100000	time:356.9	loss:1.40e-03, loss_r_u:1.08e-03, loss_d_u:3.21e-08
# Iter # 33600/100000	time:357.9	loss:6.42e-04, loss_r_u:5.25e-04, loss_d_u:1.17e-08
# Iter # 33700/100000	time:358.9	loss:3.85e-02, loss_r_u:1.09e-02, loss_d_u:2.76e-06
# Iter # 33800/100000	time:360.0	loss:6.79e-04, loss_r_u:5.41e-04, loss_d_u:1.38e-08
# Iter # 33900/100000	time:361.0	loss:7.11e-04, loss_r_u:5.49e-04, loss_d_u:1.63e-08
# Iter # 34000/100000	time:362.0	loss:6.33e-04, loss_r_u:5.09e-04, loss_d_u:1.24e-08
# Iter # 34100/100000	time:363.0	loss:6.32e-04, loss_r_u:5.36e-04, loss_d_u:9.62e-09
# Iter # 34200/100000	time:364.0	loss:3.20e-03, loss_r_u:2.14e-03, loss_d_u:1.06e-07
# Iter # 34300/100000	time:365.0	loss:1.74e-03, loss_r_u:1.40e-03, loss_d_u:3.36e-08
# Iter # 34400/100000	time:366.0	loss:7.19e-04, loss_r_u:5.65e-04, loss_d_u:1.54e-08
# Iter # 34500/100000	time:367.0	loss:6.02e-04, loss_r_u:5.13e-04, loss_d_u:8.89e-09
# Iter # 34600/100000	time:368.1	loss:9.75e-04, loss_r_u:6.37e-04, loss_d_u:3.37e-08
# Iter # 34700/100000	time:369.1	loss:1.03e-02, loss_r_u:1.57e-03, loss_d_u:8.69e-07
# Iter # 34800/100000	time:370.1	loss:6.92e-04, loss_r_u:5.64e-04, loss_d_u:1.28e-08
# Iter # 34900/100000	time:371.1	loss:1.07e-03, loss_r_u:6.08e-04, loss_d_u:4.58e-08
# Iter # 35000/100000	time:372.1	loss:5.87e-04, loss_r_u:4.93e-04, loss_d_u:9.39e-09
# Iter # 35100/100000	time:373.1	loss:3.26e-03, loss_r_u:1.48e-03, loss_d_u:1.79e-07
# Iter # 35200/100000	time:374.1	loss:9.12e-04, loss_r_u:8.29e-04, loss_d_u:8.28e-09
# Iter # 35300/100000	time:375.1	loss:1.32e-03, loss_r_u:8.98e-04, loss_d_u:4.18e-08
# Iter # 35400/100000	time:376.2	loss:7.77e-04, loss_r_u:6.35e-04, loss_d_u:1.42e-08
# Iter # 35500/100000	time:377.2	loss:6.31e-03, loss_r_u:5.75e-03, loss_d_u:5.59e-08
# Iter # 35600/100000	time:378.2	loss:2.94e-03, loss_r_u:1.78e-03, loss_d_u:1.16e-07
# Iter # 35700/100000	time:379.2	loss:5.74e-04, loss_r_u:5.02e-04, loss_d_u:7.23e-09
# Iter # 35800/100000	time:380.2	loss:5.72e-04, loss_r_u:5.00e-04, loss_d_u:7.24e-09
# Iter # 35900/100000	time:381.2	loss:1.67e-03, loss_r_u:7.73e-04, loss_d_u:8.95e-08
# Iter # 36000/100000	time:382.2	loss:2.52e-03, loss_r_u:1.31e-03, loss_d_u:1.21e-07
# Iter # 36100/100000	time:383.2	loss:3.78e-02, loss_r_u:1.67e-02, loss_d_u:2.10e-06
# Iter # 36200/100000	time:384.2	loss:7.06e-03, loss_r_u:2.44e-03, loss_d_u:4.62e-07
# Iter # 36300/100000	time:385.2	loss:3.40e-03, loss_r_u:1.43e-03, loss_d_u:1.97e-07
# Iter # 36400/100000	time:386.3	loss:9.28e-03, loss_r_u:8.90e-03, loss_d_u:3.87e-08
# Iter # 36500/100000	time:387.3	loss:8.82e-04, loss_r_u:7.66e-04, loss_d_u:1.15e-08
# Iter # 36600/100000	time:388.3	loss:3.20e-02, loss_r_u:1.70e-02, loss_d_u:1.50e-06
# Iter # 36700/100000	time:389.3	loss:1.34e-03, loss_r_u:6.85e-04, loss_d_u:6.58e-08
# Iter # 36800/100000	time:390.3	loss:2.30e-02, loss_r_u:2.06e-02, loss_d_u:2.49e-07
# Iter # 36900/100000	time:391.3	loss:1.24e-03, loss_r_u:6.29e-04, loss_d_u:6.07e-08
# Epoch 00369: reducing learning rate of group 0 to 1.6807e-04.
# Iter # 37000/100000	time:392.3	loss:5.17e-04, loss_r_u:4.60e-04, loss_d_u:5.74e-09
# Iter # 37100/100000	time:393.3	loss:5.14e-04, loss_r_u:4.57e-04, loss_d_u:5.68e-09
# Iter # 37200/100000	time:394.4	loss:5.11e-04, loss_r_u:4.55e-04, loss_d_u:5.61e-09
# Iter # 37300/100000	time:395.4	loss:5.09e-04, loss_r_u:4.53e-04, loss_d_u:5.55e-09
# Iter # 37400/100000	time:396.4	loss:5.06e-04, loss_r_u:4.51e-04, loss_d_u:5.47e-09
# Iter # 37500/100000	time:397.4	loss:5.03e-04, loss_r_u:4.49e-04, loss_d_u:5.39e-09
# Iter # 37600/100000	time:398.4	loss:4.99e-04, loss_r_u:4.46e-04, loss_d_u:5.31e-09
# Iter # 37700/100000	time:399.5	loss:6.53e-04, loss_r_u:5.43e-04, loss_d_u:1.10e-08
# Iter # 37800/100000	time:400.5	loss:7.46e-04, loss_r_u:5.04e-04, loss_d_u:2.42e-08
# Iter # 37900/100000	time:401.5	loss:5.10e-04, loss_r_u:4.58e-04, loss_d_u:5.26e-09
# Iter # 38000/100000	time:402.5	loss:1.68e-03, loss_r_u:8.40e-04, loss_d_u:8.37e-08
# Iter # 38100/100000	time:403.5	loss:4.99e-04, loss_r_u:4.44e-04, loss_d_u:5.56e-09
# Iter # 38200/100000	time:404.5	loss:1.90e-03, loss_r_u:1.12e-03, loss_d_u:7.83e-08
# Iter # 38300/100000	time:405.5	loss:2.30e-03, loss_r_u:1.41e-03, loss_d_u:8.83e-08
# Iter # 38400/100000	time:406.5	loss:7.88e-03, loss_r_u:1.81e-03, loss_d_u:6.07e-07
# Iter # 38500/100000	time:407.5	loss:4.88e-04, loss_r_u:4.39e-04, loss_d_u:4.94e-09
# Iter # 38600/100000	time:408.6	loss:7.58e-04, loss_r_u:6.68e-04, loss_d_u:8.97e-09
# Iter # 38700/100000	time:409.6	loss:9.20e-04, loss_r_u:8.26e-04, loss_d_u:9.32e-09
# Iter # 38800/100000	time:410.6	loss:4.15e-03, loss_r_u:1.44e-03, loss_d_u:2.71e-07
# Iter # 38900/100000	time:411.6	loss:4.82e-04, loss_r_u:4.32e-04, loss_d_u:4.95e-09
# Iter # 39000/100000	time:412.6	loss:5.39e-04, loss_r_u:4.71e-04, loss_d_u:6.78e-09
# Iter # 39100/100000	time:413.6	loss:5.02e-04, loss_r_u:4.56e-04, loss_d_u:4.54e-09
# Iter # 39200/100000	time:414.6	loss:5.63e-04, loss_r_u:4.71e-04, loss_d_u:9.28e-09
# Iter # 39300/100000	time:415.6	loss:5.61e-04, loss_r_u:4.46e-04, loss_d_u:1.16e-08
# Iter # 39400/100000	time:416.7	loss:6.96e-04, loss_r_u:6.44e-04, loss_d_u:5.24e-09
# Iter # 39500/100000	time:417.7	loss:9.48e-04, loss_r_u:8.78e-04, loss_d_u:7.02e-09
# Iter # 39600/100000	time:418.7	loss:2.29e-03, loss_r_u:1.35e-03, loss_d_u:9.39e-08
# Iter # 39700/100000	time:419.7	loss:3.01e-03, loss_r_u:2.36e-03, loss_d_u:6.51e-08
# Iter # 39800/100000	time:420.7	loss:6.58e-04, loss_r_u:5.08e-04, loss_d_u:1.50e-08
# Iter # 39900/100000	time:421.7	loss:1.96e-02, loss_r_u:9.99e-03, loss_d_u:9.62e-07
# Iter # 40000/100000	time:422.7	loss:1.27e-02, loss_r_u:2.62e-03, loss_d_u:1.00e-06
# Epoch 00400: reducing learning rate of group 0 to 1.1765e-04.
# Iter # 40100/100000	time:423.8	loss:4.58e-04, loss_r_u:4.19e-04, loss_d_u:3.92e-09
# Iter # 40200/100000	time:424.8	loss:4.56e-04, loss_r_u:4.17e-04, loss_d_u:3.84e-09
# Iter # 40300/100000	time:425.8	loss:4.54e-04, loss_r_u:4.16e-04, loss_d_u:3.80e-09
# Iter # 40400/100000	time:426.8	loss:4.52e-04, loss_r_u:4.14e-04, loss_d_u:3.75e-09
# Iter # 40500/100000	time:427.8	loss:4.50e-04, loss_r_u:4.13e-04, loss_d_u:3.71e-09
# Iter # 40600/100000	time:428.8	loss:4.48e-04, loss_r_u:4.11e-04, loss_d_u:3.66e-09
# Iter # 40700/100000	time:429.8	loss:4.46e-04, loss_r_u:4.10e-04, loss_d_u:3.60e-09
# Iter # 40800/100000	time:430.8	loss:3.90e-03, loss_r_u:2.04e-03, loss_d_u:1.86e-07
# Iter # 40900/100000	time:431.8	loss:1.29e-03, loss_r_u:9.75e-04, loss_d_u:3.19e-08
# Iter # 41000/100000	time:432.8	loss:1.04e-03, loss_r_u:8.56e-04, loss_d_u:1.81e-08
# Iter # 41100/100000	time:433.8	loss:5.30e-04, loss_r_u:4.22e-04, loss_d_u:1.08e-08
# Iter # 41200/100000	time:434.8	loss:4.42e-04, loss_r_u:4.07e-04, loss_d_u:3.46e-09
# Iter # 41300/100000	time:435.9	loss:8.34e-04, loss_r_u:5.79e-04, loss_d_u:2.55e-08
# Iter # 41400/100000	time:436.9	loss:1.91e-03, loss_r_u:9.54e-04, loss_d_u:9.57e-08
# Iter # 41500/100000	time:437.9	loss:1.29e-03, loss_r_u:1.25e-03, loss_d_u:4.27e-09
# Iter # 41600/100000	time:438.9	loss:5.50e-04, loss_r_u:4.79e-04, loss_d_u:7.08e-09
# Iter # 41700/100000	time:439.9	loss:1.25e-02, loss_r_u:4.17e-03, loss_d_u:8.37e-07
# Iter # 41800/100000	time:440.9	loss:4.35e-04, loss_r_u:4.03e-04, loss_d_u:3.25e-09
# Iter # 41900/100000	time:441.9	loss:2.42e-03, loss_r_u:9.83e-04, loss_d_u:1.44e-07
# Iter # 42000/100000	time:443.0	loss:4.68e-04, loss_r_u:4.35e-04, loss_d_u:3.25e-09
# Iter # 42100/100000	time:444.0	loss:5.82e-04, loss_r_u:4.60e-04, loss_d_u:1.22e-08
# Iter # 42200/100000	time:445.0	loss:4.49e-04, loss_r_u:4.13e-04, loss_d_u:3.56e-09
# Iter # 42300/100000	time:446.0	loss:5.15e-04, loss_r_u:4.33e-04, loss_d_u:8.25e-09
# Iter # 42400/100000	time:447.0	loss:4.39e-04, loss_r_u:4.08e-04, loss_d_u:3.17e-09
# Iter # 42500/100000	time:448.0	loss:2.85e-03, loss_r_u:1.25e-03, loss_d_u:1.61e-07
# Iter # 42600/100000	time:449.0	loss:2.44e-03, loss_r_u:2.33e-03, loss_d_u:1.06e-08
# Iter # 42700/100000	time:450.0	loss:7.01e-04, loss_r_u:6.53e-04, loss_d_u:4.78e-09
# Iter # 42800/100000	time:451.0	loss:4.58e-04, loss_r_u:3.95e-04, loss_d_u:6.35e-09
# Iter # 42900/100000	time:452.0	loss:7.67e-04, loss_r_u:4.47e-04, loss_d_u:3.20e-08
# Epoch 00429: reducing learning rate of group 0 to 8.2354e-05.
# Iter # 43000/100000	time:453.1	loss:4.16e-04, loss_r_u:3.88e-04, loss_d_u:2.79e-09
# Iter # 43100/100000	time:454.1	loss:4.15e-04, loss_r_u:3.87e-04, loss_d_u:2.76e-09
# Iter # 43200/100000	time:455.1	loss:4.14e-04, loss_r_u:3.86e-04, loss_d_u:2.73e-09
# Iter # 43300/100000	time:456.1	loss:4.12e-04, loss_r_u:3.85e-04, loss_d_u:2.70e-09
# Iter # 43400/100000	time:457.1	loss:4.11e-04, loss_r_u:3.84e-04, loss_d_u:2.67e-09
# Iter # 43500/100000	time:458.1	loss:4.09e-04, loss_r_u:3.83e-04, loss_d_u:2.64e-09
# Iter # 43600/100000	time:459.1	loss:4.08e-04, loss_r_u:3.82e-04, loss_d_u:2.61e-09
# Iter # 43700/100000	time:460.1	loss:2.49e-03, loss_r_u:2.37e-03, loss_d_u:1.20e-08
# Iter # 43800/100000	time:461.2	loss:5.39e-03, loss_r_u:1.37e-03, loss_d_u:4.02e-07
# Iter # 43900/100000	time:462.2	loss:4.04e-04, loss_r_u:3.79e-04, loss_d_u:2.52e-09
# Iter # 44000/100000	time:463.2	loss:6.35e-04, loss_r_u:6.05e-04, loss_d_u:3.04e-09
# Iter # 44100/100000	time:464.2	loss:8.01e-04, loss_r_u:6.46e-04, loss_d_u:1.55e-08
# Iter # 44200/100000	time:465.2	loss:4.01e-04, loss_r_u:3.76e-04, loss_d_u:2.43e-09
# Iter # 44300/100000	time:466.2	loss:4.03e-04, loss_r_u:3.77e-04, loss_d_u:2.57e-09
# Iter # 44400/100000	time:467.2	loss:4.27e-04, loss_r_u:4.00e-04, loss_d_u:2.69e-09
# Iter # 44500/100000	time:468.2	loss:4.13e-04, loss_r_u:3.82e-04, loss_d_u:3.07e-09
# Iter # 44600/100000	time:469.2	loss:1.27e-03, loss_r_u:6.39e-04, loss_d_u:6.33e-08
# Iter # 44700/100000	time:470.3	loss:2.11e-03, loss_r_u:2.05e-03, loss_d_u:5.53e-09
# Iter # 44800/100000	time:471.3	loss:4.08e-04, loss_r_u:3.73e-04, loss_d_u:3.41e-09
# Iter # 44900/100000	time:472.3	loss:3.96e-04, loss_r_u:3.73e-04, loss_d_u:2.34e-09
# Iter # 45000/100000	time:473.3	loss:3.93e-04, loss_r_u:3.70e-04, loss_d_u:2.25e-09
# Iter # 45100/100000	time:474.3	loss:4.12e-04, loss_r_u:3.90e-04, loss_d_u:2.24e-09
# Iter # 45200/100000	time:475.4	loss:1.62e-03, loss_r_u:1.54e-03, loss_d_u:7.67e-09
# Iter # 45300/100000	time:476.4	loss:4.00e-03, loss_r_u:9.55e-04, loss_d_u:3.05e-07
# Iter # 45400/100000	time:477.4	loss:3.93e-04, loss_r_u:3.71e-04, loss_d_u:2.15e-09
# Iter # 45500/100000	time:478.4	loss:1.24e-03, loss_r_u:6.96e-04, loss_d_u:5.42e-08
# Iter # 45600/100000	time:479.4	loss:1.21e-03, loss_r_u:1.16e-03, loss_d_u:5.45e-09
# Iter # 45700/100000	time:480.4	loss:5.73e-04, loss_r_u:4.76e-04, loss_d_u:9.65e-09
# Iter # 45800/100000	time:481.4	loss:3.90e-04, loss_r_u:3.68e-04, loss_d_u:2.15e-09
# Iter # 45900/100000	time:482.5	loss:2.96e-03, loss_r_u:9.46e-04, loss_d_u:2.01e-07
# Iter # 46000/100000	time:483.5	loss:2.75e-03, loss_r_u:2.41e-03, loss_d_u:3.39e-08
# Iter # 46100/100000	time:484.5	loss:6.60e-04, loss_r_u:4.20e-04, loss_d_u:2.39e-08
# Iter # 46200/100000	time:485.5	loss:2.48e-03, loss_r_u:2.42e-03, loss_d_u:6.18e-09
# Iter # 46300/100000	time:486.5	loss:5.44e-04, loss_r_u:5.25e-04, loss_d_u:1.89e-09
# Iter # 46400/100000	time:487.5	loss:4.79e-04, loss_r_u:4.46e-04, loss_d_u:3.36e-09
# Iter # 46500/100000	time:488.5	loss:5.96e-04, loss_r_u:4.90e-04, loss_d_u:1.06e-08
# Iter # 46600/100000	time:489.6	loss:8.52e-04, loss_r_u:5.38e-04, loss_d_u:3.14e-08
# Iter # 46700/100000	time:490.6	loss:5.10e-04, loss_r_u:4.46e-04, loss_d_u:6.36e-09
# Iter # 46800/100000	time:491.6	loss:6.40e-04, loss_r_u:4.47e-04, loss_d_u:1.92e-08
# Iter # 46900/100000	time:492.6	loss:7.93e-03, loss_r_u:7.79e-03, loss_d_u:1.43e-08
# Epoch 00469: reducing learning rate of group 0 to 5.7648e-05.
# Iter # 47000/100000	time:493.6	loss:3.70e-04, loss_r_u:3.52e-04, loss_d_u:1.82e-09
# Iter # 47100/100000	time:494.6	loss:3.69e-04, loss_r_u:3.51e-04, loss_d_u:1.80e-09
# Iter # 47200/100000	time:495.6	loss:3.68e-04, loss_r_u:3.50e-04, loss_d_u:1.78e-09
# Iter # 47300/100000	time:496.6	loss:3.67e-04, loss_r_u:3.50e-04, loss_d_u:1.77e-09
# Iter # 47400/100000	time:497.7	loss:3.66e-04, loss_r_u:3.49e-04, loss_d_u:1.75e-09
# Iter # 47500/100000	time:498.7	loss:3.65e-04, loss_r_u:3.48e-04, loss_d_u:1.74e-09
# Iter # 47600/100000	time:499.7	loss:3.64e-04, loss_r_u:3.47e-04, loss_d_u:1.72e-09
# Iter # 47700/100000	time:500.7	loss:6.49e-04, loss_r_u:5.70e-04, loss_d_u:7.86e-09
# Iter # 47800/100000	time:501.7	loss:3.62e-04, loss_r_u:3.46e-04, loss_d_u:1.69e-09
# Iter # 47900/100000	time:502.7	loss:4.45e-04, loss_r_u:3.94e-04, loss_d_u:5.18e-09
# Iter # 48000/100000	time:503.7	loss:6.36e-04, loss_r_u:4.29e-04, loss_d_u:2.07e-08
# Iter # 48100/100000	time:504.7	loss:4.09e-04, loss_r_u:3.61e-04, loss_d_u:4.81e-09
# Iter # 48200/100000	time:505.8	loss:2.90e-03, loss_r_u:9.04e-04, loss_d_u:2.00e-07
# Iter # 48300/100000	time:506.8	loss:5.19e-04, loss_r_u:4.98e-04, loss_d_u:2.15e-09
# Iter # 48400/100000	time:507.8	loss:5.36e-04, loss_r_u:3.85e-04, loss_d_u:1.51e-08
# Iter # 48500/100000	time:508.8	loss:4.51e-04, loss_r_u:3.94e-04, loss_d_u:5.69e-09
# Iter # 48600/100000	time:509.8	loss:3.56e-04, loss_r_u:3.40e-04, loss_d_u:1.60e-09
# Iter # 48700/100000	time:510.8	loss:1.40e-03, loss_r_u:5.19e-04, loss_d_u:8.82e-08
# Iter # 48800/100000	time:511.8	loss:3.80e-03, loss_r_u:2.67e-03, loss_d_u:1.13e-07
# Iter # 48900/100000	time:512.9	loss:3.55e-04, loss_r_u:3.37e-04, loss_d_u:1.77e-09
# Iter # 49000/100000	time:513.9	loss:3.58e-04, loss_r_u:3.42e-04, loss_d_u:1.67e-09
# Iter # 49100/100000	time:514.9	loss:3.76e-04, loss_r_u:3.45e-04, loss_d_u:3.17e-09
# Iter # 49200/100000	time:515.9	loss:4.28e-04, loss_r_u:3.64e-04, loss_d_u:6.33e-09
# Iter # 49300/100000	time:516.9	loss:3.73e-04, loss_r_u:3.58e-04, loss_d_u:1.44e-09
# Iter # 49400/100000	time:517.9	loss:8.07e-04, loss_r_u:4.90e-04, loss_d_u:3.17e-08
# Iter # 49500/100000	time:518.9	loss:6.84e-04, loss_r_u:6.61e-04, loss_d_u:2.33e-09
# Iter # 49600/100000	time:519.9	loss:3.75e-04, loss_r_u:3.40e-04, loss_d_u:3.46e-09
# Iter # 49700/100000	time:520.9	loss:3.70e-04, loss_r_u:3.53e-04, loss_d_u:1.77e-09
# Iter # 49800/100000	time:522.0	loss:6.48e-04, loss_r_u:6.29e-04, loss_d_u:1.82e-09
# Iter # 49900/100000	time:523.0	loss:4.41e-04, loss_r_u:4.19e-04, loss_d_u:2.19e-09
# Iter # 50000/100000	time:524.0	loss:5.34e-04, loss_r_u:4.94e-04, loss_d_u:4.01e-09
# Epoch 00500: reducing learning rate of group 0 to 4.0354e-05.
# Iter # 50100/100000	time:525.0	loss:3.41e-04, loss_r_u:3.27e-04, loss_d_u:1.37e-09
# Iter # 50200/100000	time:526.0	loss:3.40e-04, loss_r_u:3.26e-04, loss_d_u:1.37e-09
# Iter # 50300/100000	time:527.0	loss:3.39e-04, loss_r_u:3.26e-04, loss_d_u:1.36e-09
# Iter # 50400/100000	time:528.0	loss:3.39e-04, loss_r_u:3.25e-04, loss_d_u:1.35e-09
# Iter # 50500/100000	time:529.0	loss:3.38e-04, loss_r_u:3.24e-04, loss_d_u:1.34e-09
# Iter # 50600/100000	time:530.0	loss:3.37e-04, loss_r_u:3.24e-04, loss_d_u:1.33e-09
# Iter # 50700/100000	time:531.0	loss:3.36e-04, loss_r_u:3.23e-04, loss_d_u:1.32e-09
# Iter # 50800/100000	time:532.1	loss:1.45e-03, loss_r_u:1.22e-03, loss_d_u:2.26e-08
# Iter # 50900/100000	time:533.1	loss:3.36e-04, loss_r_u:3.21e-04, loss_d_u:1.42e-09
# Iter # 51000/100000	time:534.1	loss:3.34e-04, loss_r_u:3.21e-04, loss_d_u:1.32e-09
# Iter # 51100/100000	time:535.1	loss:3.42e-04, loss_r_u:3.29e-04, loss_d_u:1.32e-09
# Iter # 51200/100000	time:536.1	loss:3.39e-04, loss_r_u:3.26e-04, loss_d_u:1.36e-09
# Iter # 51300/100000	time:537.1	loss:3.52e-04, loss_r_u:3.27e-04, loss_d_u:2.56e-09
# Iter # 51400/100000	time:538.1	loss:3.32e-04, loss_r_u:3.18e-04, loss_d_u:1.42e-09
# Iter # 51500/100000	time:539.1	loss:3.37e-04, loss_r_u:3.22e-04, loss_d_u:1.43e-09
# Iter # 51600/100000	time:540.2	loss:4.14e-04, loss_r_u:3.98e-04, loss_d_u:1.64e-09
# Iter # 51700/100000	time:541.2	loss:5.60e-04, loss_r_u:3.73e-04, loss_d_u:1.88e-08
# Iter # 51800/100000	time:542.2	loss:3.68e-04, loss_r_u:3.31e-04, loss_d_u:3.68e-09
# Iter # 51900/100000	time:543.2	loss:3.27e-04, loss_r_u:3.15e-04, loss_d_u:1.22e-09
# Iter # 52000/100000	time:544.2	loss:3.27e-04, loss_r_u:3.14e-04, loss_d_u:1.28e-09
# Iter # 52100/100000	time:545.2	loss:3.28e-04, loss_r_u:3.16e-04, loss_d_u:1.19e-09
# Iter # 52200/100000	time:546.2	loss:8.30e-04, loss_r_u:5.34e-04, loss_d_u:2.96e-08
# Iter # 52300/100000	time:547.2	loss:3.85e-04, loss_r_u:3.68e-04, loss_d_u:1.66e-09
# Iter # 52400/100000	time:548.2	loss:3.32e-04, loss_r_u:3.16e-04, loss_d_u:1.56e-09
# Iter # 52500/100000	time:549.3	loss:4.46e-04, loss_r_u:3.67e-04, loss_d_u:7.83e-09
# Iter # 52600/100000	time:550.3	loss:3.45e-04, loss_r_u:3.12e-04, loss_d_u:3.27e-09
# Iter # 52700/100000	time:551.3	loss:3.30e-04, loss_r_u:3.18e-04, loss_d_u:1.19e-09
# Iter # 52800/100000	time:552.3	loss:3.19e-04, loss_r_u:3.08e-04, loss_d_u:1.13e-09
# Iter # 52900/100000	time:553.3	loss:1.91e-03, loss_r_u:7.68e-04, loss_d_u:1.14e-07
# Iter # 53000/100000	time:554.3	loss:3.17e-04, loss_r_u:3.06e-04, loss_d_u:1.12e-09
# Iter # 53100/100000	time:555.3	loss:3.63e-04, loss_r_u:3.50e-04, loss_d_u:1.28e-09
# Iter # 53200/100000	time:556.4	loss:2.67e-03, loss_r_u:8.39e-04, loss_d_u:1.83e-07
# Iter # 53300/100000	time:557.4	loss:1.79e-03, loss_r_u:1.31e-03, loss_d_u:4.81e-08
# Iter # 53400/100000	time:558.4	loss:1.51e-03, loss_r_u:7.90e-04, loss_d_u:7.19e-08
# Iter # 53500/100000	time:559.4	loss:3.73e-04, loss_r_u:3.50e-04, loss_d_u:2.38e-09
# Iter # 53600/100000	time:560.4	loss:3.31e-04, loss_r_u:3.04e-04, loss_d_u:2.71e-09
# Iter # 53700/100000	time:561.4	loss:3.30e-04, loss_r_u:3.16e-04, loss_d_u:1.46e-09
# Iter # 53800/100000	time:562.4	loss:5.75e-04, loss_r_u:5.33e-04, loss_d_u:4.17e-09
# Iter # 53900/100000	time:563.5	loss:3.19e-04, loss_r_u:3.04e-04, loss_d_u:1.53e-09
# Iter # 54000/100000	time:564.5	loss:4.53e-04, loss_r_u:3.26e-04, loss_d_u:1.27e-08
# Iter # 54100/100000	time:565.5	loss:3.23e-04, loss_r_u:3.04e-04, loss_d_u:1.95e-09
# Epoch 00541: reducing learning rate of group 0 to 2.8248e-05.
# Iter # 54200/100000	time:566.5	loss:3.09e-04, loss_r_u:2.98e-04, loss_d_u:1.02e-09
# Iter # 54300/100000	time:567.6	loss:3.08e-04, loss_r_u:2.98e-04, loss_d_u:1.01e-09
# Iter # 54400/100000	time:568.6	loss:3.07e-04, loss_r_u:2.97e-04, loss_d_u:1.01e-09
# Iter # 54500/100000	time:569.6	loss:3.07e-04, loss_r_u:2.97e-04, loss_d_u:1.00e-09
# Iter # 54600/100000	time:570.6	loss:3.06e-04, loss_r_u:2.96e-04, loss_d_u:9.97e-10
# Iter # 54700/100000	time:571.6	loss:3.05e-04, loss_r_u:2.96e-04, loss_d_u:9.91e-10
# Iter # 54800/100000	time:572.7	loss:3.05e-04, loss_r_u:2.95e-04, loss_d_u:9.85e-10
# Iter # 54900/100000	time:573.7	loss:3.08e-04, loss_r_u:2.95e-04, loss_d_u:1.28e-09
# Iter # 55000/100000	time:574.7	loss:3.03e-04, loss_r_u:2.94e-04, loss_d_u:9.76e-10
# Iter # 55100/100000	time:575.7	loss:3.20e-04, loss_r_u:3.10e-04, loss_d_u:9.91e-10
# Iter # 55200/100000	time:576.7	loss:3.56e-04, loss_r_u:3.45e-04, loss_d_u:1.06e-09
# Iter # 55300/100000	time:577.8	loss:3.13e-04, loss_r_u:3.02e-04, loss_d_u:1.10e-09
# Iter # 55400/100000	time:578.8	loss:3.01e-04, loss_r_u:2.91e-04, loss_d_u:9.47e-10
# Iter # 55500/100000	time:579.9	loss:3.08e-04, loss_r_u:2.96e-04, loss_d_u:1.23e-09
# Iter # 55600/100000	time:580.9	loss:7.82e-04, loss_r_u:7.60e-04, loss_d_u:2.15e-09
# Iter # 55700/100000	time:581.9	loss:3.00e-04, loss_r_u:2.90e-04, loss_d_u:1.02e-09
# Iter # 55800/100000	time:583.0	loss:2.98e-04, loss_r_u:2.89e-04, loss_d_u:9.29e-10
# Iter # 55900/100000	time:584.0	loss:3.02e-04, loss_r_u:2.92e-04, loss_d_u:1.03e-09
# Iter # 56000/100000	time:585.0	loss:3.69e-04, loss_r_u:3.60e-04, loss_d_u:9.25e-10
# Iter # 56100/100000	time:586.0	loss:6.01e-04, loss_r_u:3.68e-04, loss_d_u:2.33e-08
# Iter # 56200/100000	time:587.0	loss:2.95e-04, loss_r_u:2.86e-04, loss_d_u:9.04e-10
# Iter # 56300/100000	time:588.1	loss:9.01e-04, loss_r_u:4.46e-04, loss_d_u:4.55e-08
# Iter # 56400/100000	time:589.1	loss:2.94e-04, loss_r_u:2.85e-04, loss_d_u:8.92e-10
# Iter # 56500/100000	time:590.1	loss:3.13e-04, loss_r_u:2.91e-04, loss_d_u:2.26e-09
# Iter # 56600/100000	time:591.1	loss:2.93e-04, loss_r_u:2.84e-04, loss_d_u:8.82e-10
# Iter # 56700/100000	time:592.1	loss:2.94e-04, loss_r_u:2.84e-04, loss_d_u:9.31e-10
# Iter # 56800/100000	time:593.1	loss:3.25e-04, loss_r_u:2.87e-04, loss_d_u:3.74e-09
# Iter # 56900/100000	time:594.2	loss:2.92e-04, loss_r_u:2.83e-04, loss_d_u:8.93e-10
# Iter # 57000/100000	time:595.2	loss:2.90e-04, loss_r_u:2.82e-04, loss_d_u:8.62e-10
# Iter # 57100/100000	time:596.2	loss:2.93e-04, loss_r_u:2.82e-04, loss_d_u:1.10e-09
# Iter # 57200/100000	time:597.2	loss:2.89e-04, loss_r_u:2.81e-04, loss_d_u:8.50e-10
# Iter # 57300/100000	time:598.2	loss:2.93e-04, loss_r_u:2.83e-04, loss_d_u:9.51e-10
# ...
# Iter # 81000/100000	time:838.2	loss:1.91e-04, loss_r_u:1.88e-04, loss_d_u:3.29e-10
# Iter # 81100/100000	time:839.2	loss:2.02e-04, loss_r_u:1.94e-04, loss_d_u:8.47e-10
# Iter # 81200/100000	time:840.2	loss:1.90e-04, loss_r_u:1.87e-04, loss_d_u:3.36e-10
# Iter # 81300/100000	time:841.2	loss:1.93e-04, loss_r_u:1.90e-04, loss_d_u:3.52e-10
# Iter # 81400/100000	time:842.2	loss:3.33e-04, loss_r_u:3.06e-04, loss_d_u:2.66e-09
# Iter # 81500/100000	time:843.2	loss:1.94e-04, loss_r_u:1.91e-04, loss_d_u:3.29e-10
# Iter # 81600/100000	time:844.2	loss:2.25e-04, loss_r_u:1.98e-04, loss_d_u:2.68e-09
# Iter # 81700/100000	time:845.2	loss:2.42e-04, loss_r_u:2.33e-04, loss_d_u:9.44e-10
# Iter # 81800/100000	time:846.2	loss:1.93e-04, loss_r_u:1.87e-04, loss_d_u:6.09e-10
# Iter # 81900/100000	time:847.2	loss:1.98e-04, loss_r_u:1.92e-04, loss_d_u:5.59e-10
# Iter # 82000/100000	time:848.3	loss:1.88e-04, loss_r_u:1.85e-04, loss_d_u:3.46e-10
# Iter # 82100/100000	time:849.3	loss:1.88e-04, loss_r_u:1.85e-04, loss_d_u:3.38e-10
# Iter # 82200/100000	time:850.3	loss:1.88e-04, loss_r_u:1.85e-04, loss_d_u:3.56e-10
# Iter # 82300/100000	time:851.3	loss:2.02e-04, loss_r_u:1.99e-04, loss_d_u:3.42e-10
# Iter # 82400/100000	time:852.3	loss:2.43e-04, loss_r_u:2.39e-04, loss_d_u:4.35e-10
# Iter # 82500/100000	time:853.4	loss:1.87e-04, loss_r_u:1.84e-04, loss_d_u:3.25e-10
# Iter # 82600/100000	time:854.4	loss:2.16e-04, loss_r_u:1.97e-04, loss_d_u:1.81e-09
# Iter # 82700/100000	time:855.4	loss:2.69e-04, loss_r_u:2.62e-04, loss_d_u:6.97e-10
# Iter # 82800/100000	time:856.4	loss:3.22e-04, loss_r_u:2.80e-04, loss_d_u:4.24e-09
# Iter # 82900/100000	time:857.5	loss:1.86e-04, loss_r_u:1.82e-04, loss_d_u:3.13e-10
# Iter # 83000/100000	time:858.5	loss:1.86e-04, loss_r_u:1.83e-04, loss_d_u:3.82e-10
# Iter # 83100/100000	time:859.5	loss:1.97e-04, loss_r_u:1.93e-04, loss_d_u:3.98e-10
# Iter # 83200/100000	time:860.5	loss:1.85e-04, loss_r_u:1.82e-04, loss_d_u:3.58e-10
# Iter # 83300/100000	time:861.5	loss:4.20e-04, loss_r_u:2.31e-04, loss_d_u:1.89e-08
# Iter # 83400/100000	time:862.5	loss:3.43e-04, loss_r_u:3.23e-04, loss_d_u:2.00e-09
# Iter # 83500/100000	time:863.6	loss:6.76e-04, loss_r_u:2.68e-04, loss_d_u:4.08e-08
# Iter # 83600/100000	time:864.6	loss:1.85e-04, loss_r_u:1.82e-04, loss_d_u:3.04e-10
# Iter # 83700/100000	time:865.6	loss:4.92e-04, loss_r_u:2.55e-04, loss_d_u:2.36e-08
# Iter # 83800/100000	time:866.6	loss:2.47e-04, loss_r_u:2.39e-04, loss_d_u:7.39e-10
# Iter # 83900/100000	time:867.6	loss:3.97e-04, loss_r_u:2.29e-04, loss_d_u:1.67e-08
# Iter # 84000/100000	time:868.6	loss:1.83e-04, loss_r_u:1.80e-04, loss_d_u:3.02e-10
# Iter # 84100/100000	time:869.7	loss:1.86e-04, loss_r_u:1.81e-04, loss_d_u:5.21e-10
# Iter # 84200/100000	time:870.7	loss:1.83e-04, loss_r_u:1.80e-04, loss_d_u:3.29e-10
# Iter # 84300/100000	time:871.7	loss:1.85e-04, loss_r_u:1.80e-04, loss_d_u:4.97e-10
# Iter # 84400/100000	time:872.7	loss:1.82e-04, loss_r_u:1.79e-04, loss_d_u:2.99e-10
# Iter # 84500/100000	time:873.7	loss:1.94e-04, loss_r_u:1.80e-04, loss_d_u:1.39e-09
# Iter # 84600/100000	time:874.7	loss:1.88e-04, loss_r_u:1.85e-04, loss_d_u:2.92e-10
# Iter # 84700/100000	time:875.7	loss:1.91e-04, loss_r_u:1.80e-04, loss_d_u:1.16e-09
# Iter # 84800/100000	time:876.8	loss:1.82e-04, loss_r_u:1.79e-04, loss_d_u:2.98e-10
# Iter # 84900/100000	time:877.8	loss:1.82e-04, loss_r_u:1.78e-04, loss_d_u:4.00e-10
# Iter # 85000/100000	time:878.8	loss:1.81e-04, loss_r_u:1.77e-04, loss_d_u:3.11e-10
# Iter # 85100/100000	time:879.8	loss:1.86e-04, loss_r_u:1.79e-04, loss_d_u:6.34e-10
# Iter # 85200/100000	time:880.8	loss:1.83e-04, loss_r_u:1.79e-04, loss_d_u:4.56e-10
# Iter # 85300/100000	time:881.8	loss:2.29e-04, loss_r_u:1.86e-04, loss_d_u:4.36e-09
# Iter # 85400/100000	time:882.8	loss:1.85e-04, loss_r_u:1.81e-04, loss_d_u:4.30e-10
# Iter # 85500/100000	time:883.9	loss:1.79e-04, loss_r_u:1.76e-04, loss_d_u:3.08e-10
# Iter # 85600/100000	time:884.9	loss:1.81e-04, loss_r_u:1.77e-04, loss_d_u:4.03e-10
# Iter # 85700/100000	time:885.9	loss:1.79e-04, loss_r_u:1.76e-04, loss_d_u:2.87e-10
# Iter # 85800/100000	time:886.9	loss:1.79e-04, loss_r_u:1.76e-04, loss_d_u:3.01e-10
# Iter # 85900/100000	time:887.9	loss:1.81e-04, loss_r_u:1.76e-04, loss_d_u:5.80e-10
# Iter # 86000/100000	time:888.9	loss:1.78e-04, loss_r_u:1.75e-04, loss_d_u:2.85e-10
# Iter # 86100/100000	time:890.0	loss:1.79e-04, loss_r_u:1.75e-04, loss_d_u:3.91e-10
# Iter # 86200/100000	time:891.0	loss:1.83e-04, loss_r_u:1.79e-04, loss_d_u:4.25e-10
# Iter # 86300/100000	time:892.0	loss:5.81e-04, loss_r_u:2.69e-04, loss_d_u:3.12e-08
# Iter # 86400/100000	time:893.0	loss:3.62e-04, loss_r_u:2.92e-04, loss_d_u:6.91e-09
# Iter # 86500/100000	time:894.0	loss:1.84e-04, loss_r_u:1.75e-04, loss_d_u:9.03e-10
# Iter # 86600/100000	time:895.0	loss:1.91e-04, loss_r_u:1.76e-04, loss_d_u:1.51e-09
# Iter # 86700/100000	time:896.0	loss:1.86e-04, loss_r_u:1.82e-04, loss_d_u:3.65e-10
# Iter # 86800/100000	time:897.1	loss:1.76e-04, loss_r_u:1.73e-04, loss_d_u:2.84e-10
# Iter # 86900/100000	time:898.1	loss:1.78e-04, loss_r_u:1.75e-04, loss_d_u:3.29e-10
# Iter # 87000/100000	time:899.1	loss:1.79e-04, loss_r_u:1.73e-04, loss_d_u:5.36e-10
# Iter # 87100/100000	time:900.1	loss:1.77e-04, loss_r_u:1.74e-04, loss_d_u:3.36e-10
# Iter # 87200/100000	time:901.1	loss:1.77e-04, loss_r_u:1.74e-04, loss_d_u:2.95e-10
# Iter # 87300/100000	time:902.1	loss:5.75e-04, loss_r_u:3.48e-04, loss_d_u:2.28e-08
# Iter # 87400/100000	time:903.1	loss:1.96e-04, loss_r_u:1.75e-04, loss_d_u:2.16e-09
# Iter # 87500/100000	time:904.1	loss:1.74e-04, loss_r_u:1.71e-04, loss_d_u:2.82e-10
# Iter # 87600/100000	time:905.2	loss:1.75e-04, loss_r_u:1.72e-04, loss_d_u:2.96e-10
# Iter # 87700/100000	time:906.2	loss:1.74e-04, loss_r_u:1.71e-04, loss_d_u:2.90e-10
# Iter # 87800/100000	time:907.2	loss:1.76e-04, loss_r_u:1.71e-04, loss_d_u:5.73e-10
# Iter # 87900/100000	time:908.2	loss:1.82e-04, loss_r_u:1.77e-04, loss_d_u:4.77e-10
# Iter # 88000/100000	time:909.2	loss:1.88e-04, loss_r_u:1.71e-04, loss_d_u:1.67e-09
# Iter # 88100/100000	time:910.2	loss:3.90e-04, loss_r_u:3.81e-04, loss_d_u:9.25e-10
# Iter # 88200/100000	time:911.2	loss:1.79e-04, loss_r_u:1.71e-04, loss_d_u:7.70e-10
# Iter # 88300/100000	time:912.3	loss:1.85e-04, loss_r_u:1.72e-04, loss_d_u:1.36e-09
# Iter # 88400/100000	time:913.3	loss:1.75e-04, loss_r_u:1.70e-04, loss_d_u:5.66e-10
# Iter # 88500/100000	time:914.3	loss:4.40e-04, loss_r_u:3.42e-04, loss_d_u:9.80e-09
# Iter # 88600/100000	time:915.3	loss:2.07e-04, loss_r_u:1.76e-04, loss_d_u:3.03e-09
# Iter # 88700/100000	time:916.3	loss:4.55e-04, loss_r_u:4.00e-04, loss_d_u:5.50e-09
# Iter # 88800/100000	time:917.3	loss:2.02e-04, loss_r_u:1.75e-04, loss_d_u:2.62e-09
# Epoch 00888: reducing learning rate of group 0 to 1.3841e-05.
# Iter # 88900/100000	time:918.4	loss:1.71e-04, loss_r_u:1.68e-04, loss_d_u:2.64e-10
# Iter # 89000/100000	time:919.4	loss:1.70e-04, loss_r_u:1.68e-04, loss_d_u:2.63e-10
# Iter # 89100/100000	time:920.4	loss:1.70e-04, loss_r_u:1.68e-04, loss_d_u:2.63e-10
# Iter # 89200/100000	time:921.4	loss:1.70e-04, loss_r_u:1.67e-04, loss_d_u:2.64e-10
# Iter # 89300/100000	time:922.4	loss:1.70e-04, loss_r_u:1.67e-04, loss_d_u:2.63e-10
# Iter # 89400/100000	time:923.4	loss:1.70e-04, loss_r_u:1.67e-04, loss_d_u:2.63e-10
# Iter # 89500/100000	time:924.4	loss:1.69e-04, loss_r_u:1.67e-04, loss_d_u:2.63e-10
# Iter # 89600/100000	time:925.4	loss:2.02e-04, loss_r_u:1.99e-04, loss_d_u:3.02e-10
# Iter # 89700/100000	time:926.5	loss:1.71e-04, loss_r_u:1.67e-04, loss_d_u:3.86e-10
# Iter # 89800/100000	time:927.5	loss:2.87e-04, loss_r_u:2.19e-04, loss_d_u:6.76e-09
# Iter # 89900/100000	time:928.5	loss:1.94e-04, loss_r_u:1.87e-04, loss_d_u:6.53e-10
# Iter # 90000/100000	time:929.5	loss:1.70e-04, loss_r_u:1.67e-04, loss_d_u:2.96e-10
# Iter # 90100/100000	time:930.5	loss:1.68e-04, loss_r_u:1.65e-04, loss_d_u:2.68e-10
# Iter # 90200/100000	time:931.5	loss:1.68e-04, loss_r_u:1.65e-04, loss_d_u:2.65e-10
# Iter # 90300/100000	time:932.5	loss:1.68e-04, loss_r_u:1.65e-04, loss_d_u:2.61e-10
# Iter # 90400/100000	time:933.6	loss:1.71e-04, loss_r_u:1.67e-04, loss_d_u:3.92e-10
# Iter # 90500/100000	time:934.6	loss:1.67e-04, loss_r_u:1.65e-04, loss_d_u:2.58e-10
# Iter # 90600/100000	time:935.6	loss:1.68e-04, loss_r_u:1.64e-04, loss_d_u:3.45e-10
# Iter # 90700/100000	time:936.6	loss:1.67e-04, loss_r_u:1.64e-04, loss_d_u:2.58e-10
# Iter # 90800/100000	time:937.6	loss:1.82e-04, loss_r_u:1.79e-04, loss_d_u:2.96e-10
# Iter # 90900/100000	time:938.6	loss:1.67e-04, loss_r_u:1.64e-04, loss_d_u:2.66e-10
# Iter # 91000/100000	time:939.7	loss:1.66e-04, loss_r_u:1.64e-04, loss_d_u:2.78e-10
# Iter # 91100/100000	time:940.7	loss:1.66e-04, loss_r_u:1.63e-04, loss_d_u:2.52e-10
# Iter # 91200/100000	time:941.7	loss:1.66e-04, loss_r_u:1.63e-04, loss_d_u:2.94e-10
# Iter # 91300/100000	time:942.7	loss:1.70e-04, loss_r_u:1.67e-04, loss_d_u:2.96e-10
# Iter # 91400/100000	time:943.7	loss:1.82e-04, loss_r_u:1.79e-04, loss_d_u:2.99e-10
# Iter # 91500/100000	time:944.7	loss:1.65e-04, loss_r_u:1.62e-04, loss_d_u:2.49e-10
# Iter # 91600/100000	time:945.8	loss:2.35e-04, loss_r_u:1.70e-04, loss_d_u:6.52e-09
# Iter # 91700/100000	time:946.8	loss:2.13e-04, loss_r_u:2.10e-04, loss_d_u:3.35e-10
# Iter # 91800/100000	time:947.8	loss:1.65e-04, loss_r_u:1.62e-04, loss_d_u:2.76e-10
# Iter # 91900/100000	time:948.8	loss:1.68e-04, loss_r_u:1.65e-04, loss_d_u:2.62e-10
# Iter # 92000/100000	time:949.7	loss:1.77e-04, loss_r_u:1.74e-04, loss_d_u:2.87e-10
# Iter # 92100/100000	time:950.7	loss:2.59e-04, loss_r_u:2.47e-04, loss_d_u:1.21e-09
# Iter # 92200/100000	time:951.7	loss:1.63e-04, loss_r_u:1.61e-04, loss_d_u:2.44e-10
# Iter # 92300/100000	time:952.7	loss:1.77e-04, loss_r_u:1.67e-04, loss_d_u:9.99e-10
# Iter # 92400/100000	time:953.7	loss:1.73e-04, loss_r_u:1.62e-04, loss_d_u:1.03e-09
# Iter # 92500/100000	time:954.7	loss:2.29e-04, loss_r_u:1.83e-04, loss_d_u:4.51e-09
# Iter # 92600/100000	time:955.7	loss:1.62e-04, loss_r_u:1.60e-04, loss_d_u:2.42e-10
# Iter # 92700/100000	time:956.7	loss:3.17e-04, loss_r_u:1.76e-04, loss_d_u:1.41e-08
# Iter # 92800/100000	time:957.8	loss:1.62e-04, loss_r_u:1.60e-04, loss_d_u:2.42e-10
# Iter # 92900/100000	time:958.8	loss:1.62e-04, loss_r_u:1.60e-04, loss_d_u:2.49e-10
# Iter # 93000/100000	time:959.8	loss:1.62e-04, loss_r_u:1.60e-04, loss_d_u:2.58e-10
# Iter # 93100/100000	time:960.8	loss:1.62e-04, loss_r_u:1.60e-04, loss_d_u:2.37e-10
# Iter # 93200/100000	time:961.8	loss:1.62e-04, loss_r_u:1.59e-04, loss_d_u:2.60e-10
# Iter # 93300/100000	time:962.8	loss:1.63e-04, loss_r_u:1.60e-04, loss_d_u:3.28e-10
# Iter # 93400/100000	time:963.8	loss:1.61e-04, loss_r_u:1.58e-04, loss_d_u:2.81e-10
# Iter # 93500/100000	time:964.8	loss:1.62e-04, loss_r_u:1.59e-04, loss_d_u:2.69e-10
# Iter # 93600/100000	time:965.8	loss:1.74e-04, loss_r_u:1.71e-04, loss_d_u:2.60e-10
# Iter # 93700/100000	time:966.8	loss:1.80e-04, loss_r_u:1.76e-04, loss_d_u:4.07e-10
# Iter # 93800/100000	time:967.8	loss:3.44e-04, loss_r_u:1.93e-04, loss_d_u:1.51e-08
# Iter # 93900/100000	time:968.8	loss:1.60e-04, loss_r_u:1.57e-04, loss_d_u:2.35e-10
# Iter # 94000/100000	time:969.9	loss:1.60e-04, loss_r_u:1.57e-04, loss_d_u:2.40e-10
# Iter # 94100/100000	time:970.9	loss:1.61e-04, loss_r_u:1.58e-04, loss_d_u:2.85e-10
# Iter # 94200/100000	time:971.9	loss:1.67e-04, loss_r_u:1.58e-04, loss_d_u:9.11e-10
# Iter # 94300/100000	time:972.9	loss:1.63e-04, loss_r_u:1.59e-04, loss_d_u:3.15e-10
# Iter # 94400/100000	time:973.9	loss:1.66e-04, loss_r_u:1.59e-04, loss_d_u:6.66e-10
# Iter # 94500/100000	time:974.9	loss:1.62e-04, loss_r_u:1.59e-04, loss_d_u:3.15e-10
# Iter # 94600/100000	time:975.9	loss:1.64e-04, loss_r_u:1.58e-04, loss_d_u:6.81e-10
# Iter # 94700/100000	time:977.0	loss:2.43e-04, loss_r_u:1.96e-04, loss_d_u:4.65e-09
# Iter # 94800/100000	time:978.0	loss:1.58e-04, loss_r_u:1.56e-04, loss_d_u:2.29e-10
# Iter # 94900/100000	time:979.0	loss:1.58e-04, loss_r_u:1.55e-04, loss_d_u:2.27e-10
# Iter # 95000/100000	time:980.0	loss:1.58e-04, loss_r_u:1.55e-04, loss_d_u:2.38e-10
# Iter # 95100/100000	time:981.0	loss:1.58e-04, loss_r_u:1.56e-04, loss_d_u:2.26e-10
# Iter # 95200/100000	time:982.0	loss:1.58e-04, loss_r_u:1.55e-04, loss_d_u:2.27e-10
# Iter # 95300/100000	time:983.1	loss:1.57e-04, loss_r_u:1.55e-04, loss_d_u:2.74e-10
# Iter # 95400/100000	time:984.1	loss:1.58e-04, loss_r_u:1.55e-04, loss_d_u:3.44e-10
# Iter # 95500/100000	time:985.1	loss:1.73e-04, loss_r_u:1.60e-04, loss_d_u:1.29e-09
# Iter # 95600/100000	time:986.1	loss:1.76e-04, loss_r_u:1.67e-04, loss_d_u:9.22e-10
# Iter # 95700/100000	time:987.2	loss:3.46e-04, loss_r_u:1.84e-04, loss_d_u:1.62e-08
# Iter # 95800/100000	time:988.2	loss:1.63e-04, loss_r_u:1.60e-04, loss_d_u:2.34e-10
# Iter # 95900/100000	time:989.2	loss:1.57e-04, loss_r_u:1.54e-04, loss_d_u:3.16e-10
# Iter # 96000/100000	time:990.2	loss:1.59e-04, loss_r_u:1.56e-04, loss_d_u:2.79e-10
# Iter # 96100/100000	time:991.2	loss:1.56e-04, loss_r_u:1.53e-04, loss_d_u:2.59e-10
# Iter # 96200/100000	time:992.2	loss:1.57e-04, loss_r_u:1.54e-04, loss_d_u:3.53e-10
# Iter # 96300/100000	time:993.2	loss:1.78e-04, loss_r_u:1.70e-04, loss_d_u:7.72e-10
# Iter # 96400/100000	time:994.3	loss:1.55e-04, loss_r_u:1.52e-04, loss_d_u:2.27e-10
# Iter # 96500/100000	time:995.3	loss:1.55e-04, loss_r_u:1.52e-04, loss_d_u:2.39e-10
# Iter # 96600/100000	time:996.3	loss:1.81e-04, loss_r_u:1.57e-04, loss_d_u:2.46e-09
# Iter # 96700/100000	time:997.3	loss:1.66e-04, loss_r_u:1.61e-04, loss_d_u:5.07e-10
# Iter # 96800/100000	time:998.3	loss:1.66e-04, loss_r_u:1.56e-04, loss_d_u:9.80e-10
# Iter # 96900/100000	time:999.3	loss:1.54e-04, loss_r_u:1.51e-04, loss_d_u:2.16e-10
# Iter # 97000/100000	time:1000.3	loss:1.53e-04, loss_r_u:1.51e-04, loss_d_u:2.19e-10
# Iter # 97100/100000	time:1001.3	loss:1.53e-04, loss_r_u:1.51e-04, loss_d_u:2.16e-10
# Iter # 97200/100000	time:1002.3	loss:1.54e-04, loss_r_u:1.51e-04, loss_d_u:3.00e-10
# Iter # 97300/100000	time:1003.4	loss:2.49e-04, loss_r_u:1.66e-04, loss_d_u:8.24e-09
# Iter # 97400/100000	time:1004.4	loss:1.56e-04, loss_r_u:1.53e-04, loss_d_u:2.56e-10
# Iter # 97500/100000	time:1005.4	loss:1.68e-04, loss_r_u:1.65e-04, loss_d_u:2.36e-10
# Iter # 97600/100000	time:1006.4	loss:1.98e-04, loss_r_u:1.81e-04, loss_d_u:1.66e-09
# Iter # 97700/100000	time:1007.4	loss:1.72e-04, loss_r_u:1.56e-04, loss_d_u:1.63e-09
# Iter # 97800/100000	time:1008.4	loss:1.52e-04, loss_r_u:1.50e-04, loss_d_u:2.12e-10
# Iter # 97900/100000	time:1009.4	loss:1.54e-04, loss_r_u:1.51e-04, loss_d_u:2.90e-10
# Iter # 98000/100000	time:1010.4	loss:1.52e-04, loss_r_u:1.49e-04, loss_d_u:2.12e-10
# Iter # 98100/100000	time:1011.4	loss:1.51e-04, loss_r_u:1.49e-04, loss_d_u:2.10e-10
# Iter # 98200/100000	time:1012.5	loss:1.69e-04, loss_r_u:1.53e-04, loss_d_u:1.63e-09
# Iter # 98300/100000	time:1013.5	loss:1.53e-04, loss_r_u:1.50e-04, loss_d_u:3.47e-10
# Iter # 98400/100000	time:1014.5	loss:1.75e-04, loss_r_u:1.68e-04, loss_d_u:6.15e-10
# Iter # 98500/100000	time:1015.5	loss:2.74e-04, loss_r_u:1.95e-04, loss_d_u:7.87e-09
# Iter # 98600/100000	time:1016.5	loss:1.50e-04, loss_r_u:1.48e-04, loss_d_u:2.08e-10
# Iter # 98700/100000	time:1017.5	loss:1.51e-04, loss_r_u:1.48e-04, loss_d_u:2.38e-10
# Iter # 98800/100000	time:1018.5	loss:1.69e-04, loss_r_u:1.58e-04, loss_d_u:1.05e-09
# Iter # 98900/100000	time:1019.5	loss:1.78e-04, loss_r_u:1.55e-04, loss_d_u:2.38e-09
# Iter # 99000/100000	time:1020.6	loss:1.50e-04, loss_r_u:1.47e-04, loss_d_u:2.07e-10
# Iter # 99100/100000	time:1021.6	loss:1.49e-04, loss_r_u:1.47e-04, loss_d_u:2.04e-10
# Iter # 99200/100000	time:1022.6	loss:1.49e-04, loss_r_u:1.47e-04, loss_d_u:2.12e-10
# Iter # 99300/100000	time:1023.6	loss:1.68e-04, loss_r_u:1.50e-04, loss_d_u:1.72e-09
# Iter # 99400/100000	time:1024.6	loss:1.50e-04, loss_r_u:1.47e-04, loss_d_u:3.11e-10
# Iter # 99500/100000	time:1025.6	loss:2.52e-04, loss_r_u:1.64e-04, loss_d_u:8.73e-09
# Iter # 99600/100000	time:1026.6	loss:1.49e-04, loss_r_u:1.47e-04, loss_d_u:2.11e-10
# Iter # 99700/100000	time:1027.6	loss:1.48e-04, loss_r_u:1.46e-04, loss_d_u:2.12e-10
# Iter # 99800/100000	time:1028.6	loss:1.50e-04, loss_r_u:1.47e-04, loss_d_u:2.82e-10
# Iter # 99900/100000	time:1029.7	loss:1.48e-04, loss_r_u:1.46e-04, loss_d_u:2.01e-10
# Iter # 100000/100000	time:1030.7	loss:1.48e-04, loss_r_u:1.46e-04, loss_d_u:2.48e-10

# %%
model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(),'nn_k_state': pinn.nn_k.state_dict()}
backbone_path = os.path.join(model_path, f'backbone_adam.pth')
torch.save(model_state, backbone_path)

np.save("./loss_logger_dict.npy", logger)

# %%
def used_time(start_time):
    seconds = time.time() - start_time
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print(f'used time: {hours:.0f}h {minutes:.0f}m {seconds:.0f}s')
    
used_time(start_time)
# Out:
# used time: 0h 17m 11s

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
# loss曲线
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res_u"]
        [::k], label=r"Re($\mathcal{L}_{r})$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_data_u"]
        [::k], label=r"Re($\mathcal{L}_{data})$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)
model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_k.load_state_dict(model_state['nn_k_state'])
# Out:
# <All keys matched successfully>

# %%
N = 2000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)

# %%
# relative L2 误差
u_data = np.array(u_data).reshape(-1, 1)
t_data = np.array(t_data).reshape(-1, 1)
k_data = np.array(k_data).reshape(-1, 1)

t_data = torch.tensor(t_data).float().to(device)
u_pred = pinn.net_u(t_data).detach().cpu().numpy()
k_pred = pinn.k.detach().cpu().numpy()
k_pred = np.ones_like(u_pred)*k_pred
u3_pred = pinn.net_3u(t_data).detach().cpu().numpy()

t_data = t_data.detach().cpu().numpy()
error_u = np.linalg.norm(u_pred - u_data) / np.linalg.norm(u_data)
error_k = np.linalg.norm(k_pred - k_data) / np.linalg.norm(k_data)
print('u Relative l2 error: {:.3e}'.format(error_u))
print('k Relative l2 error: {:.3e}'.format(error_k))
# Out:
# u Relative l2 error: 4.224e-05
# k Relative l2 error: 1.795e-03

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t_data, u_data)
# cax = ax.plot(t_data, u_pred)

cax = ax.scatter(t_data, u_data)
# cax = ax.scatter(t_data, u_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
cax2 = ax2.scatter(t_data, u_pred)
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Predicted $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()

# %%
iter = np.array(loss_logger["iter"])
k = np.array(loss_logger["k"])
stander = np.ones_like(k)
plt.plot(iter, k, label=r"Re($\mathcal{L}_{r})$")
plt.plot(iter, stander)
plt.ylim(0.5,1.5)

plt.tight_layout()
plt.savefig('k.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t_data, k_data)
# cax = ax.plot(t_data, k_pred)

cax = ax.scatter(t_data, k_data)
cax = ax.scatter(t_data, k_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $k(t)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(k_data - k_pred))
cax2 = ax2.scatter(t_data, np.abs(k_data - k_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error $k(t)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('K.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

cax = ax.scatter(t_data, u3_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $d3u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Predicted $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()
