# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_29299/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io

import os
import time

# %% [markdown]
# ## 超参数设置

# %%
domain = (-1, 1, -1, 1)
xmin, xmax, ymin, ymax = domain
mlp_layers = [1] + [40]*4 + [1]
mlp_layers_k = [1] + [20]*2 + [1]
# n_iters = 1000000
n_iters = 50000
learning_rate = 1e-3
gamma = 0.7

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
# 生成x的数据点
x = torch.linspace(0, 1, 100)

# 计算对应的y值
y = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
    45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
    45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
    (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
    15 * x ** 2) / 4

# 创建一个数据框
data = pd.DataFrame({'x': x.numpy(), 'y': y.numpy()})

# 绘制图形
plt.figure(figsize=(8, 6))
plt.plot(x.numpy(), y.numpy(), label='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Y vs. X')
plt.legend()
plt.grid(True)

# 保存数据到Excel文件
data.to_excel('output.xlsx', index=False)

# 显示图形
plt.show()

# %%
class Dataset:
    def __init__(self, N):
        self.x = torch.linspace(0, 1, N)
        
    
    def train_data(self, N, verbose=None):
        # 无量纲化
        t0 = 5
        K0 = 31250
        U0 = 0.001

        x = self.x
        k = self.k(x)
        # y = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
        # 45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
        # 45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
        # (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
        # 15 * x ** 2) / 4

        y = 5/3*x**4 - 10/3*x**3 + 5/3*x
        # print(self.x.shape)
        idx = np.random.randint(0,self.x.shape[0],N)
        # return x.reshape(-1,1), k.reshape(-1,1), y.reshape(-1,1)
        return x[idx].reshape(-1, 1), k[idx].reshape(-1,1), y[idx].reshape(-1,1)

    # k函数
    def k(self, t):
        # return 8/3*t**2 - 8/3*t + 1
        return np.ones_like(t)
        # return 10000*(t*5-2.5)**2 + 31250
    

N = 1000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)
print(t_data.shape, k_data.shape, u_data.shape)
# Out:
# torch.Size([1000, 1]) (1000, 1) torch.Size([1000, 1])

# %%
# u_data
plt.scatter(t_data, u_data)

# %%
# k_data
plt.scatter(t_data, k_data)

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            self.model.add_module(f'fc{i+1}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            self.model.add_module(f'act{i+1}', nn.Tanh())
        self.model.add_module(f'fc{len(mlp_layers)-1})', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
    
    def forward(self, X):
        return self.model(X)
    
    
mlp = MLP(mlp_layers)
mlp_k = MLP(mlp_layers_k)
mlp.model
# Out:
# Sequential(
#   (fc1): Linear(in_features=1, out_features=40, bias=True)
#   (act1): Tanh()
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (act2): Tanh()
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (act3): Tanh()
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (act4): Tanh()
#   (fc5)): Linear(in_features=40, out_features=1, bias=False)
# )

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINNHelmholtz(nn.Module):
    def __init__(self, backbone, nn_k):
        super(PINNHelmholtz, self).__init__()
        self.backbone = backbone
        self.nn_k = nn_k
        self.k = nn.Parameter(torch.tensor(
            [0.8], dtype=torch.float32).to(device), requires_grad=True)
        self.backbone.register_parameter("k", self.k)

        
    def forward(self, X_res, u_data):
        f_res_pred = self.net_f(X_res)
        u_pred = self.net_u(X_res)

        loss_res_u = torch.mean((f_res_pred - 30) ** 2)
        loss_data_u = torch.mean((u_pred - u_data) ** 2)
        return loss_res_u, loss_data_u
    
    def net_u(self, X):
        return self.backbone(X)
    
    def net_k(self, X):
        # return 8/3*X**2 - 8/3*X + 1
        return self.nn_k(X)

    def net_3u(self, X):
        X.requires_grad_(True)
        u = self.net_u(X)

        # 求u的梯度
        du = grad(u, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        return d3u
    
    def net_f(self, X):
        X.requires_grad_(True)
        u_pred = self.net_u(X)
        
        # 求u的梯度
        du = grad(u_pred, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        d4u = grad(d3u, X)[0]
        
        # k_pred = torch.ones_like(u_pred)*self.k
        # dk = grad(k_pred, X)[0]
        # d2k = grad(dk, X)[0]
        
        f_res_pred = 0.75*self.k*d4u
        
        return f_res_pred
    

pinn = PINNHelmholtz(mlp,mlp_k)

# %% [markdown]
# ## Adam训练

# %%
# 训练
N = 1000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)
t_data = t_data.float().to(device)
u_data = u_data.float().to(device)

backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=learning_rate)
# optimizer_adam_k = optim.Adam(pinn.nn_k.parameters(), lr=learning_rate)

lr_sche = ReduceLROnPlateau(optimizer_adam, mode='min', factor=gamma, verbose=True)
# lr_sche_k = ReduceLROnPlateau(optimizer_adam_k, mode='min', factor=gamma, verbose=True)
# lr_sche = ExponentialLR(optimizer_adam, gamma=gamma, verbose=True)
# lr_sche_k = ExponentialLR(optimizer_adam_k, gamma=gamma, verbose=True)

logger = {
    "loss": [],
    "loss_res_u": [],
    "loss_data_u": [],
    "iter": [],
    "k": []
}
with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for it in range(n_iters):
    pinn.zero_grad()
    loss_res_u, loss_data_u = pinn(t_data, u_data)
    # loss = 1*(loss_res_u) + 1e2*(loss_data_u)
    loss = 1*(loss_res_u) + 100*(loss_data_u)
    loss.backward()
    optimizer_adam.step()
    # optimizer_adam_k.step()
    
    # 保存训练信息 -------
    logger["loss"].append(loss.item())
    logger["loss_res_u"].append(loss_res_u.item())
    logger["loss_data_u"].append(loss_data_u.item())
    logger["iter"].append(it + 1)
    logger["k"].append(pinn.k.cpu().detach().numpy())

    
    if (it + 1) % 100 == 0:  # 打印训练信息 -------
        info = f'Iter # {it+1:4d}/{n_iters}\ttime:{time.time()-start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r_u:{loss_res_u.item():.2e}, loss_d_u:{loss_data_u.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        
    if (it + 1) % 100 == 0:  # 学习率衰减 -------
        lr_sche.step(loss)
        # lr_sche_k.step(loss)
# Out:
# Iter #  100/50000	time:0.7	loss:1.95e+00, loss_r_u:8.17e-01, loss_d_u:1.13e-02
# Iter #  200/50000	time:1.4	loss:1.33e+00, loss_r_u:1.72e-01, loss_d_u:1.16e-02
# Iter #  300/50000	time:2.1	loss:1.14e+00, loss_r_u:1.42e-01, loss_d_u:9.96e-03
# Iter #  400/50000	time:2.7	loss:9.60e-01, loss_r_u:1.48e-01, loss_d_u:8.11e-03
# Iter #  500/50000	time:3.4	loss:7.93e-01, loss_r_u:1.60e-01, loss_d_u:6.33e-03
# Iter #  600/50000	time:4.0	loss:6.48e-01, loss_r_u:1.71e-01, loss_d_u:4.77e-03
# Iter #  700/50000	time:4.7	loss:5.27e-01, loss_r_u:1.71e-01, loss_d_u:3.56e-03
# Iter #  800/50000	time:5.4	loss:4.55e-01, loss_r_u:1.61e-01, loss_d_u:2.93e-03
# Iter #  900/50000	time:6.0	loss:3.44e-01, loss_r_u:1.25e-01, loss_d_u:2.20e-03
# Iter # 1000/50000	time:6.7	loss:2.78e-01, loss_r_u:9.31e-02, loss_d_u:1.85e-03
# Iter # 1100/50000	time:7.4	loss:3.04e-01, loss_r_u:1.32e-01, loss_d_u:1.71e-03
# Iter # 1200/50000	time:8.0	loss:1.69e-01, loss_r_u:5.33e-02, loss_d_u:1.15e-03
# Iter # 1300/50000	time:8.7	loss:1.60e-01, loss_r_u:6.31e-02, loss_d_u:9.74e-04
# Iter # 1400/50000	time:9.4	loss:9.91e-02, loss_r_u:2.66e-02, loss_d_u:7.25e-04
# Iter # 1500/50000	time:10.1	loss:2.04e-01, loss_r_u:1.13e-01, loss_d_u:9.12e-04
# Iter # 1600/50000	time:10.7	loss:7.27e-02, loss_r_u:1.95e-02, loss_d_u:5.32e-04
# Iter # 1700/50000	time:11.4	loss:5.23e-02, loss_r_u:1.57e-02, loss_d_u:3.65e-04
# Iter # 1800/50000	time:12.1	loss:4.09e-02, loss_r_u:1.31e-02, loss_d_u:2.78e-04
# Iter # 1900/50000	time:12.8	loss:4.24e-02, loss_r_u:1.24e-02, loss_d_u:3.00e-04
# Iter # 2000/50000	time:13.4	loss:3.33e-02, loss_r_u:1.12e-02, loss_d_u:2.22e-04
# Iter # 2100/50000	time:14.1	loss:7.56e-01, loss_r_u:7.27e-01, loss_d_u:2.92e-04
# Iter # 2200/50000	time:14.7	loss:2.98e-02, loss_r_u:9.57e-03, loss_d_u:2.02e-04
# Iter # 2300/50000	time:15.4	loss:2.55e-02, loss_r_u:9.37e-03, loss_d_u:1.61e-04
# Iter # 2400/50000	time:16.0	loss:2.59e-02, loss_r_u:8.42e-03, loss_d_u:1.75e-04
# Iter # 2500/50000	time:16.7	loss:2.30e-02, loss_r_u:8.25e-03, loss_d_u:1.48e-04
# Iter # 2600/50000	time:17.3	loss:2.16e-02, loss_r_u:8.32e-03, loss_d_u:1.33e-04
# Iter # 2700/50000	time:18.0	loss:2.31e-02, loss_r_u:7.80e-03, loss_d_u:1.53e-04
# Iter # 2800/50000	time:18.7	loss:2.02e-02, loss_r_u:7.33e-03, loss_d_u:1.28e-04
# Iter # 2900/50000	time:19.4	loss:4.14e-02, loss_r_u:2.84e-02, loss_d_u:1.30e-04
# Iter # 3000/50000	time:20.0	loss:1.89e-02, loss_r_u:6.27e-03, loss_d_u:1.26e-04
# Iter # 3100/50000	time:20.7	loss:9.31e-02, loss_r_u:7.86e-02, loss_d_u:1.45e-04
# Iter # 3200/50000	time:21.4	loss:1.76e-02, loss_r_u:6.04e-03, loss_d_u:1.15e-04
# Iter # 3300/50000	time:22.0	loss:1.80e-01, loss_r_u:1.63e-01, loss_d_u:1.68e-04
# Iter # 3400/50000	time:22.7	loss:1.66e-02, loss_r_u:5.16e-03, loss_d_u:1.14e-04
# Iter # 3500/50000	time:23.5	loss:1.57e-02, loss_r_u:5.20e-03, loss_d_u:1.05e-04
# Iter # 3600/50000	time:24.1	loss:2.20e-02, loss_r_u:9.63e-03, loss_d_u:1.24e-04
# Iter # 3700/50000	time:24.8	loss:1.51e-02, loss_r_u:4.89e-03, loss_d_u:1.02e-04
# Iter # 3800/50000	time:25.5	loss:1.41e-02, loss_r_u:4.66e-03, loss_d_u:9.47e-05
# Iter # 3900/50000	time:26.1	loss:2.05e-02, loss_r_u:9.40e-03, loss_d_u:1.11e-04
# Iter # 4000/50000	time:26.8	loss:1.37e-02, loss_r_u:3.81e-03, loss_d_u:9.87e-05
# Iter # 4100/50000	time:27.4	loss:3.22e-01, loss_r_u:3.11e-01, loss_d_u:1.10e-04
# Iter # 4200/50000	time:28.1	loss:1.28e-02, loss_r_u:3.92e-03, loss_d_u:8.92e-05
# Iter # 4300/50000	time:28.8	loss:1.20e-02, loss_r_u:3.74e-03, loss_d_u:8.28e-05
# Iter # 4400/50000	time:29.5	loss:1.64e-02, loss_r_u:6.96e-03, loss_d_u:9.42e-05
# Iter # 4500/50000	time:30.1	loss:1.15e-02, loss_r_u:3.24e-03, loss_d_u:8.29e-05
# Iter # 4600/50000	time:30.8	loss:1.09e-02, loss_r_u:3.23e-03, loss_d_u:7.64e-05
# Iter # 4700/50000	time:31.5	loss:1.16e-02, loss_r_u:3.71e-03, loss_d_u:7.89e-05
# Iter # 4800/50000	time:32.1	loss:1.03e-02, loss_r_u:3.11e-03, loss_d_u:7.15e-05
# Iter # 4900/50000	time:32.8	loss:1.48e-01, loss_r_u:1.37e-01, loss_d_u:1.09e-04
# Iter # 5000/50000	time:33.5	loss:9.85e-03, loss_r_u:2.30e-03, loss_d_u:7.54e-05
# Iter # 5100/50000	time:34.2	loss:2.60e-02, loss_r_u:1.89e-02, loss_d_u:7.11e-05
# Iter # 5200/50000	time:34.8	loss:8.82e-03, loss_r_u:2.54e-03, loss_d_u:6.27e-05
# Iter # 5300/50000	time:35.5	loss:5.70e-02, loss_r_u:4.93e-02, loss_d_u:7.74e-05
# Iter # 5400/50000	time:36.2	loss:8.40e-03, loss_r_u:2.23e-03, loss_d_u:6.17e-05
# Iter # 5500/50000	time:36.8	loss:7.72e-03, loss_r_u:2.20e-03, loss_d_u:5.52e-05
# Iter # 5600/50000	time:37.5	loss:2.89e-02, loss_r_u:2.22e-02, loss_d_u:6.74e-05
# Iter # 5700/50000	time:38.1	loss:7.39e-03, loss_r_u:1.86e-03, loss_d_u:5.53e-05
# Iter # 5800/50000	time:38.9	loss:1.22e-01, loss_r_u:1.15e-01, loss_d_u:7.26e-05
# Iter # 5900/50000	time:39.6	loss:6.48e-03, loss_r_u:2.06e-03, loss_d_u:4.42e-05
# Iter # 6000/50000	time:40.3	loss:7.37e-03, loss_r_u:2.24e-03, loss_d_u:5.12e-05
# Iter # 6100/50000	time:40.9	loss:5.98e-03, loss_r_u:1.60e-03, loss_d_u:4.38e-05
# Iter # 6200/50000	time:41.7	loss:2.92e-02, loss_r_u:2.41e-02, loss_d_u:5.08e-05
# Iter # 6300/50000	time:42.3	loss:5.60e-03, loss_r_u:1.51e-03, loss_d_u:4.09e-05
# Iter # 6400/50000	time:43.0	loss:6.11e-03, loss_r_u:2.52e-03, loss_d_u:3.60e-05
# Iter # 6500/50000	time:43.7	loss:7.75e-03, loss_r_u:4.09e-03, loss_d_u:3.66e-05
# Iter # 6600/50000	time:44.3	loss:4.91e-03, loss_r_u:1.38e-03, loss_d_u:3.52e-05
# Iter # 6700/50000	time:45.0	loss:7.83e-03, loss_r_u:4.20e-03, loss_d_u:3.63e-05
# Iter # 6800/50000	time:45.7	loss:4.30e-03, loss_r_u:1.23e-03, loss_d_u:3.07e-05
# Iter # 6900/50000	time:46.3	loss:1.39e-02, loss_r_u:1.04e-02, loss_d_u:3.50e-05
# Iter # 7000/50000	time:47.0	loss:3.96e-03, loss_r_u:1.12e-03, loss_d_u:2.84e-05
# Iter # 7100/50000	time:47.6	loss:4.70e-03, loss_r_u:2.01e-03, loss_d_u:2.69e-05
# Iter # 7200/50000	time:48.3	loss:6.31e-03, loss_r_u:3.48e-03, loss_d_u:2.83e-05
# Iter # 7300/50000	time:49.0	loss:3.34e-03, loss_r_u:1.03e-03, loss_d_u:2.31e-05
# Iter # 7400/50000	time:49.6	loss:3.44e-03, loss_r_u:9.26e-04, loss_d_u:2.51e-05
# Iter # 7500/50000	time:50.3	loss:3.24e-03, loss_r_u:1.19e-03, loss_d_u:2.05e-05
# Iter # 7600/50000	time:51.0	loss:3.02e-03, loss_r_u:1.08e-03, loss_d_u:1.94e-05
# Iter # 7700/50000	time:51.6	loss:3.09e-03, loss_r_u:9.32e-04, loss_d_u:2.16e-05
# Iter # 7800/50000	time:52.3	loss:3.12e-02, loss_r_u:2.84e-02, loss_d_u:2.84e-05
# Iter # 7900/50000	time:52.9	loss:2.61e-03, loss_r_u:7.76e-04, loss_d_u:1.84e-05
# Iter # 8000/50000	time:53.6	loss:1.12e-01, loss_r_u:1.09e-01, loss_d_u:3.02e-05
# Iter # 8100/50000	time:54.3	loss:2.35e-03, loss_r_u:8.97e-04, loss_d_u:1.45e-05
# Iter # 8200/50000	time:54.9	loss:2.61e-03, loss_r_u:7.51e-04, loss_d_u:1.86e-05
# Iter # 8300/50000	time:55.6	loss:2.09e-03, loss_r_u:6.76e-04, loss_d_u:1.42e-05
# Iter # 8400/50000	time:56.2	loss:4.17e-03, loss_r_u:2.57e-03, loss_d_u:1.60e-05
# Iter # 8500/50000	time:56.9	loss:1.95e-03, loss_r_u:7.15e-04, loss_d_u:1.24e-05
# Iter # 8600/50000	time:57.5	loss:3.98e-02, loss_r_u:3.70e-02, loss_d_u:2.76e-05
# Iter # 8700/50000	time:58.2	loss:4.22e-01, loss_r_u:4.18e-01, loss_d_u:3.96e-05
# Iter # 8800/50000	time:58.9	loss:1.76e-03, loss_r_u:6.26e-04, loss_d_u:1.14e-05
# Iter # 8900/50000	time:59.5	loss:8.31e-02, loss_r_u:8.09e-02, loss_d_u:2.18e-05
# Iter # 9000/50000	time:60.2	loss:1.62e-03, loss_r_u:5.91e-04, loss_d_u:1.02e-05
# Iter # 9100/50000	time:60.8	loss:2.72e-03, loss_r_u:1.75e-03, loss_d_u:9.68e-06
# Iter # 9200/50000	time:61.5	loss:2.66e-03, loss_r_u:1.62e-03, loss_d_u:1.04e-05
# Iter # 9300/50000	time:62.2	loss:3.27e-01, loss_r_u:3.26e-01, loss_d_u:1.36e-05
# Iter # 9400/50000	time:62.9	loss:1.38e-03, loss_r_u:5.45e-04, loss_d_u:8.38e-06
# Iter # 9500/50000	time:63.6	loss:3.38e-03, loss_r_u:2.55e-03, loss_d_u:8.28e-06
# Iter # 9600/50000	time:64.2	loss:1.40e-03, loss_r_u:6.25e-04, loss_d_u:7.77e-06
# Iter # 9700/50000	time:64.9	loss:3.89e-03, loss_r_u:2.89e-03, loss_d_u:9.94e-06
# Iter # 9800/50000	time:65.6	loss:1.21e-03, loss_r_u:4.96e-04, loss_d_u:7.15e-06
# Iter # 9900/50000	time:66.2	loss:3.74e-01, loss_r_u:3.68e-01, loss_d_u:6.12e-05
# Iter # 10000/50000	time:66.9	loss:3.17e-02, loss_r_u:3.11e-02, loss_d_u:5.86e-06
# Iter # 10100/50000	time:67.6	loss:1.11e-03, loss_r_u:4.28e-04, loss_d_u:6.78e-06
# Iter # 10200/50000	time:68.3	loss:6.92e-03, loss_r_u:6.15e-03, loss_d_u:7.69e-06
# Iter # 10300/50000	time:68.9	loss:9.76e-04, loss_r_u:4.33e-04, loss_d_u:5.43e-06
# Iter # 10400/50000	time:69.6	loss:4.26e-03, loss_r_u:3.38e-03, loss_d_u:8.84e-06
# Iter # 10500/50000	time:70.2	loss:1.02e-03, loss_r_u:4.69e-04, loss_d_u:5.54e-06
# Iter # 10600/50000	time:70.9	loss:1.07e-03, loss_r_u:5.68e-04, loss_d_u:5.00e-06
# Iter # 10700/50000	time:71.5	loss:1.19e-03, loss_r_u:6.37e-04, loss_d_u:5.56e-06
# Iter # 10800/50000	time:72.2	loss:9.88e-04, loss_r_u:5.09e-04, loss_d_u:4.78e-06
# Iter # 10900/50000	time:72.8	loss:7.16e-03, loss_r_u:6.36e-03, loss_d_u:7.96e-06
# Iter # 11000/50000	time:73.4	loss:2.38e-03, loss_r_u:1.90e-03, loss_d_u:4.79e-06
# Iter # 11100/50000	time:74.1	loss:1.22e-01, loss_r_u:1.22e-01, loss_d_u:5.34e-06
# Iter # 11200/50000	time:74.7	loss:9.73e-03, loss_r_u:9.10e-03, loss_d_u:6.31e-06
# Iter # 11300/50000	time:75.4	loss:7.54e-04, loss_r_u:3.82e-04, loss_d_u:3.72e-06
# Iter # 11400/50000	time:76.0	loss:2.33e-03, loss_r_u:1.72e-03, loss_d_u:6.00e-06
# Iter # 11500/50000	time:76.7	loss:2.02e-03, loss_r_u:1.63e-03, loss_d_u:3.89e-06
# Iter # 11600/50000	time:77.4	loss:2.19e-03, loss_r_u:1.75e-03, loss_d_u:4.34e-06
# Iter # 11700/50000	time:78.0	loss:5.38e-03, loss_r_u:4.95e-03, loss_d_u:4.23e-06
# Iter # 11800/50000	time:78.7	loss:1.19e-03, loss_r_u:8.04e-04, loss_d_u:3.88e-06
# Iter # 11900/50000	time:79.3	loss:3.39e-01, loss_r_u:3.38e-01, loss_d_u:8.76e-06
# Iter # 12000/50000	time:80.0	loss:5.93e-02, loss_r_u:5.73e-02, loss_d_u:1.97e-05
# Iter # 12100/50000	time:80.6	loss:5.80e-04, loss_r_u:2.97e-04, loss_d_u:2.83e-06
# Iter # 12200/50000	time:81.3	loss:2.21e-03, loss_r_u:1.46e-03, loss_d_u:7.47e-06
# Iter # 12300/50000	time:82.0	loss:2.18e-02, loss_r_u:2.13e-02, loss_d_u:4.03e-06
# Iter # 12400/50000	time:82.6	loss:2.50e-01, loss_r_u:2.47e-01, loss_d_u:2.77e-05
# Iter # 12500/50000	time:83.3	loss:7.24e-04, loss_r_u:4.41e-04, loss_d_u:2.83e-06
# Iter # 12600/50000	time:83.9	loss:1.29e-03, loss_r_u:9.01e-04, loss_d_u:3.91e-06
# Iter # 12700/50000	time:84.6	loss:5.08e-04, loss_r_u:2.55e-04, loss_d_u:2.54e-06
# Iter # 12800/50000	time:85.3	loss:9.42e-04, loss_r_u:6.21e-04, loss_d_u:3.21e-06
# Iter # 12900/50000	time:85.9	loss:5.16e-04, loss_r_u:2.79e-04, loss_d_u:2.36e-06
# Iter # 13000/50000	time:86.6	loss:9.44e-04, loss_r_u:5.33e-04, loss_d_u:4.11e-06
# Iter # 13100/50000	time:87.2	loss:1.56e-03, loss_r_u:1.20e-03, loss_d_u:3.59e-06
# Iter # 13200/50000	time:87.9	loss:5.03e-02, loss_r_u:4.91e-02, loss_d_u:1.14e-05
# Iter # 13300/50000	time:88.5	loss:4.98e-04, loss_r_u:2.21e-04, loss_d_u:2.78e-06
# Iter # 13400/50000	time:89.2	loss:3.73e-03, loss_r_u:3.35e-03, loss_d_u:3.75e-06
# Iter # 13500/50000	time:89.8	loss:1.59e-03, loss_r_u:1.24e-03, loss_d_u:3.56e-06
# Iter # 13600/50000	time:90.5	loss:4.24e-04, loss_r_u:2.08e-04, loss_d_u:2.16e-06
# Iter # 13700/50000	time:91.2	loss:4.97e-04, loss_r_u:2.55e-04, loss_d_u:2.42e-06
# Iter # 13800/50000	time:91.8	loss:6.49e-04, loss_r_u:4.37e-04, loss_d_u:2.12e-06
# Iter # 13900/50000	time:92.5	loss:4.78e-04, loss_r_u:2.51e-04, loss_d_u:2.27e-06
# Iter # 14000/50000	time:93.1	loss:6.71e-03, loss_r_u:4.32e-03, loss_d_u:2.39e-05
# Iter # 14100/50000	time:93.8	loss:1.06e-03, loss_r_u:8.24e-04, loss_d_u:2.41e-06
# Iter # 14200/50000	time:94.4	loss:3.44e-03, loss_r_u:3.16e-03, loss_d_u:2.80e-06
# Iter # 14300/50000	time:95.1	loss:5.82e-02, loss_r_u:5.80e-02, loss_d_u:2.14e-06
# Iter # 14400/50000	time:95.8	loss:9.06e-03, loss_r_u:8.82e-03, loss_d_u:2.33e-06
# Iter # 14500/50000	time:96.4	loss:1.90e-02, loss_r_u:1.58e-02, loss_d_u:3.22e-05
# Iter # 14600/50000	time:97.1	loss:5.52e-02, loss_r_u:5.46e-02, loss_d_u:5.86e-06
# Iter # 14700/50000	time:97.7	loss:7.09e-04, loss_r_u:5.40e-04, loss_d_u:1.69e-06
# Epoch 00147: reducing learning rate of group 0 to 7.0000e-04.
# Iter # 14800/50000	time:98.4	loss:2.91e-04, loss_r_u:1.69e-04, loss_d_u:1.22e-06
# Iter # 14900/50000	time:99.1	loss:2.65e-04, loss_r_u:1.71e-04, loss_d_u:9.40e-07
# Iter # 15000/50000	time:99.7	loss:2.46e-04, loss_r_u:1.72e-04, loss_d_u:7.35e-07
# Iter # 15100/50000	time:100.4	loss:2.31e-04, loss_r_u:1.72e-04, loss_d_u:5.84e-07
# Iter # 15200/50000	time:101.1	loss:2.19e-04, loss_r_u:1.71e-04, loss_d_u:4.73e-07
# Iter # 15300/50000	time:101.8	loss:2.08e-04, loss_r_u:1.69e-04, loss_d_u:3.90e-07
# Iter # 15400/50000	time:102.4	loss:4.53e-02, loss_r_u:4.50e-02, loss_d_u:3.53e-06
# Iter # 15500/50000	time:103.1	loss:9.73e-02, loss_r_u:9.63e-02, loss_d_u:9.87e-06
# Iter # 15600/50000	time:103.8	loss:2.65e-04, loss_r_u:1.99e-04, loss_d_u:6.59e-07
# Iter # 15700/50000	time:104.4	loss:2.22e-04, loss_r_u:1.62e-04, loss_d_u:5.96e-07
# Iter # 15800/50000	time:105.1	loss:1.24e-03, loss_r_u:1.08e-03, loss_d_u:1.58e-06
# Iter # 15900/50000	time:105.7	loss:4.20e-04, loss_r_u:3.48e-04, loss_d_u:7.13e-07
# Iter # 16000/50000	time:106.4	loss:4.73e-03, loss_r_u:4.63e-03, loss_d_u:9.41e-07
# Iter # 16100/50000	time:107.1	loss:1.82e-02, loss_r_u:6.43e-03, loss_d_u:1.18e-04
# Iter # 16200/50000	time:107.8	loss:7.18e-03, loss_r_u:7.07e-03, loss_d_u:1.12e-06
# Iter # 16300/50000	time:108.4	loss:2.05e-03, loss_r_u:1.97e-03, loss_d_u:8.90e-07
# Iter # 16400/50000	time:109.1	loss:2.15e-04, loss_r_u:1.61e-04, loss_d_u:5.39e-07
# Epoch 00164: reducing learning rate of group 0 to 4.9000e-04.
# Iter # 16500/50000	time:109.7	loss:1.70e-04, loss_r_u:1.28e-04, loss_d_u:4.18e-07
# Iter # 16600/50000	time:110.4	loss:1.62e-04, loss_r_u:1.28e-04, loss_d_u:3.35e-07
# Iter # 16700/50000	time:111.1	loss:1.55e-04, loss_r_u:1.28e-04, loss_d_u:2.73e-07
# Iter # 16800/50000	time:111.7	loss:1.49e-04, loss_r_u:1.27e-04, loss_d_u:2.27e-07
# Iter # 16900/50000	time:112.4	loss:1.44e-04, loss_r_u:1.25e-04, loss_d_u:1.91e-07
# Iter # 17000/50000	time:113.1	loss:1.40e-04, loss_r_u:1.23e-04, loss_d_u:1.64e-07
# Iter # 17100/50000	time:113.8	loss:4.46e-04, loss_r_u:4.30e-04, loss_d_u:1.60e-07
# Iter # 17200/50000	time:114.4	loss:2.42e-03, loss_r_u:2.38e-03, loss_d_u:4.71e-07
# Iter # 17300/50000	time:115.1	loss:1.37e-04, loss_r_u:1.14e-04, loss_d_u:2.34e-07
# Iter # 17400/50000	time:115.8	loss:2.52e-04, loss_r_u:2.24e-04, loss_d_u:2.80e-07
# Iter # 17500/50000	time:116.5	loss:4.42e-04, loss_r_u:3.83e-04, loss_d_u:5.93e-07
# Iter # 17600/50000	time:117.1	loss:5.42e-04, loss_r_u:4.92e-04, loss_d_u:4.99e-07
# Iter # 17700/50000	time:117.8	loss:4.11e-03, loss_r_u:1.73e-03, loss_d_u:2.38e-05
# Iter # 17800/50000	time:118.5	loss:1.35e-03, loss_r_u:1.30e-03, loss_d_u:5.24e-07
# Iter # 17900/50000	time:119.1	loss:3.05e-04, loss_r_u:2.67e-04, loss_d_u:3.75e-07
# Iter # 18000/50000	time:119.7	loss:1.62e-04, loss_r_u:1.36e-04, loss_d_u:2.59e-07
# Iter # 18100/50000	time:120.4	loss:1.08e-03, loss_r_u:8.98e-04, loss_d_u:1.86e-06
# Iter # 18200/50000	time:121.0	loss:6.80e-02, loss_r_u:6.05e-02, loss_d_u:7.47e-05
# Iter # 18300/50000	time:121.7	loss:8.89e-03, loss_r_u:8.74e-03, loss_d_u:1.44e-06
# Iter # 18400/50000	time:122.3	loss:1.14e-04, loss_r_u:9.37e-05, loss_d_u:2.01e-07
# Iter # 18500/50000	time:123.0	loss:7.14e-04, loss_r_u:6.82e-04, loss_d_u:3.12e-07
# Iter # 18600/50000	time:123.6	loss:7.47e-04, loss_r_u:7.18e-04, loss_d_u:2.86e-07
# Iter # 18700/50000	time:124.2	loss:3.33e-02, loss_r_u:3.20e-02, loss_d_u:1.26e-05
# Iter # 18800/50000	time:124.9	loss:1.78e-03, loss_r_u:1.50e-03, loss_d_u:2.71e-06
# Iter # 18900/50000	time:125.5	loss:8.15e-03, loss_r_u:7.72e-03, loss_d_u:4.29e-06
# Iter # 19000/50000	time:126.2	loss:1.60e-03, loss_r_u:1.57e-03, loss_d_u:3.25e-07
# Iter # 19100/50000	time:126.8	loss:4.18e-04, loss_r_u:3.83e-04, loss_d_u:3.42e-07
# Iter # 19200/50000	time:127.5	loss:1.30e-02, loss_r_u:1.29e-02, loss_d_u:5.03e-07
# Iter # 19300/50000	time:128.1	loss:5.26e-03, loss_r_u:3.96e-03, loss_d_u:1.31e-05
# Iter # 19400/50000	time:128.7	loss:4.65e-04, loss_r_u:4.47e-04, loss_d_u:1.71e-07
# Iter # 19500/50000	time:129.4	loss:2.71e-02, loss_r_u:2.66e-02, loss_d_u:5.18e-06
# Epoch 00195: reducing learning rate of group 0 to 3.4300e-04.
# Iter # 19600/50000	time:130.0	loss:9.52e-05, loss_r_u:7.82e-05, loss_d_u:1.70e-07
# Iter # 19700/50000	time:130.6	loss:9.17e-05, loss_r_u:7.78e-05, loss_d_u:1.39e-07
# Iter # 19800/50000	time:131.3	loss:8.90e-05, loss_r_u:7.74e-05, loss_d_u:1.16e-07
# Iter # 19900/50000	time:131.9	loss:8.66e-05, loss_r_u:7.68e-05, loss_d_u:9.89e-08
# Iter # 20000/50000	time:132.5	loss:8.46e-05, loss_r_u:7.60e-05, loss_d_u:8.60e-08
# Iter # 20100/50000	time:133.1	loss:8.27e-05, loss_r_u:7.51e-05, loss_d_u:7.63e-08
# Iter # 20200/50000	time:133.7	loss:8.09e-05, loss_r_u:7.40e-05, loss_d_u:6.89e-08
# Iter # 20300/50000	time:134.4	loss:1.06e-04, loss_r_u:9.76e-05, loss_d_u:8.65e-08
# Iter # 20400/50000	time:135.0	loss:9.19e-05, loss_r_u:8.24e-05, loss_d_u:9.42e-08
# Iter # 20500/50000	time:135.6	loss:8.39e-05, loss_r_u:7.57e-05, loss_d_u:8.15e-08
# Iter # 20600/50000	time:136.3	loss:4.07e-04, loss_r_u:3.92e-04, loss_d_u:1.54e-07
# Iter # 20700/50000	time:136.9	loss:4.45e-03, loss_r_u:4.42e-03, loss_d_u:3.26e-07
# Iter # 20800/50000	time:137.5	loss:7.47e-05, loss_r_u:6.66e-05, loss_d_u:8.16e-08
# Iter # 20900/50000	time:138.1	loss:1.35e-04, loss_r_u:1.00e-04, loss_d_u:3.52e-07
# Iter # 21000/50000	time:138.8	loss:1.58e-04, loss_r_u:1.50e-04, loss_d_u:8.68e-08
# Iter # 21100/50000	time:139.4	loss:3.88e-02, loss_r_u:3.52e-02, loss_d_u:3.55e-05
# Iter # 21200/50000	time:140.0	loss:1.79e-03, loss_r_u:1.77e-03, loss_d_u:1.97e-07
# Iter # 21300/50000	time:140.6	loss:1.05e-04, loss_r_u:9.68e-05, loss_d_u:7.89e-08
# Iter # 21400/50000	time:141.3	loss:9.16e-04, loss_r_u:8.58e-04, loss_d_u:5.82e-07
# Iter # 21500/50000	time:141.9	loss:6.89e-05, loss_r_u:6.04e-05, loss_d_u:8.51e-08
# Iter # 21600/50000	time:142.5	loss:6.87e-04, loss_r_u:6.44e-04, loss_d_u:4.28e-07
# Iter # 21700/50000	time:143.2	loss:1.09e-03, loss_r_u:1.07e-03, loss_d_u:2.40e-07
# Iter # 21800/50000	time:143.8	loss:8.21e-05, loss_r_u:7.35e-05, loss_d_u:8.55e-08
# Iter # 21900/50000	time:144.4	loss:7.28e-05, loss_r_u:6.49e-05, loss_d_u:7.93e-08
# Iter # 22000/50000	time:145.0	loss:6.81e-05, loss_r_u:5.69e-05, loss_d_u:1.12e-07
# Iter # 22100/50000	time:145.7	loss:7.96e-04, loss_r_u:7.85e-04, loss_d_u:1.07e-07
# Iter # 22200/50000	time:146.3	loss:2.87e-04, loss_r_u:2.51e-04, loss_d_u:3.62e-07
# Iter # 22300/50000	time:146.9	loss:9.66e-03, loss_r_u:3.69e-03, loss_d_u:5.96e-05
# Iter # 22400/50000	time:147.5	loss:4.10e-04, loss_r_u:4.01e-04, loss_d_u:8.33e-08
# Iter # 22500/50000	time:148.2	loss:6.28e-05, loss_r_u:5.49e-05, loss_d_u:7.87e-08
# Iter # 22600/50000	time:148.8	loss:1.97e-02, loss_r_u:1.96e-02, loss_d_u:3.07e-07
# Iter # 22700/50000	time:149.4	loss:2.04e-03, loss_r_u:1.99e-03, loss_d_u:4.23e-07
# Iter # 22800/50000	time:150.0	loss:7.04e-04, loss_r_u:3.36e-04, loss_d_u:3.68e-06
# Iter # 22900/50000	time:150.7	loss:1.48e-04, loss_r_u:1.40e-04, loss_d_u:7.96e-08
# Iter # 23000/50000	time:151.3	loss:2.33e-03, loss_r_u:2.32e-03, loss_d_u:1.21e-07
# Iter # 23100/50000	time:152.0	loss:3.63e-04, loss_r_u:2.85e-04, loss_d_u:7.79e-07
# Iter # 23200/50000	time:152.6	loss:2.21e-03, loss_r_u:1.87e-03, loss_d_u:3.34e-06
# Iter # 23300/50000	time:153.3	loss:6.22e-04, loss_r_u:6.15e-04, loss_d_u:6.84e-08
# Iter # 23400/50000	time:153.9	loss:6.04e-05, loss_r_u:5.31e-05, loss_d_u:7.29e-08
# Iter # 23500/50000	time:154.6	loss:6.04e-05, loss_r_u:5.17e-05, loss_d_u:8.76e-08
# Iter # 23600/50000	time:155.2	loss:6.75e-05, loss_r_u:5.36e-05, loss_d_u:1.39e-07
# Iter # 23700/50000	time:155.9	loss:1.52e-03, loss_r_u:1.18e-03, loss_d_u:3.32e-06
# Iter # 23800/50000	time:156.6	loss:1.05e-03, loss_r_u:1.03e-03, loss_d_u:1.73e-07
# Iter # 23900/50000	time:157.2	loss:8.08e-04, loss_r_u:7.97e-04, loss_d_u:1.08e-07
# Iter # 24000/50000	time:157.9	loss:5.53e-05, loss_r_u:4.74e-05, loss_d_u:7.91e-08
# Iter # 24100/50000	time:158.5	loss:6.02e-05, loss_r_u:5.31e-05, loss_d_u:7.13e-08
# Iter # 24200/50000	time:159.2	loss:1.85e-04, loss_r_u:1.67e-04, loss_d_u:1.76e-07
# Iter # 24300/50000	time:159.9	loss:7.06e-04, loss_r_u:5.97e-04, loss_d_u:1.08e-06
# Iter # 24400/50000	time:160.6	loss:1.86e-02, loss_r_u:1.84e-02, loss_d_u:1.30e-06
# Iter # 24500/50000	time:161.3	loss:6.77e-03, loss_r_u:6.75e-03, loss_d_u:1.44e-07
# Iter # 24600/50000	time:161.9	loss:4.89e-05, loss_r_u:4.17e-05, loss_d_u:7.24e-08
# Iter # 24700/50000	time:162.6	loss:3.07e-03, loss_r_u:3.05e-03, loss_d_u:2.10e-07
# Iter # 24800/50000	time:163.2	loss:4.81e-05, loss_r_u:4.07e-05, loss_d_u:7.43e-08
# Iter # 24900/50000	time:163.9	loss:6.47e-05, loss_r_u:5.69e-05, loss_d_u:7.74e-08
# Iter # 25000/50000	time:164.6	loss:4.56e-03, loss_r_u:3.72e-03, loss_d_u:8.42e-06
# Iter # 25100/50000	time:165.2	loss:4.71e-05, loss_r_u:4.03e-05, loss_d_u:6.77e-08
# Iter # 25200/50000	time:165.9	loss:8.88e-05, loss_r_u:7.97e-05, loss_d_u:9.14e-08
# Iter # 25300/50000	time:166.6	loss:9.13e-05, loss_r_u:7.25e-05, loss_d_u:1.88e-07
# Iter # 25400/50000	time:167.2	loss:5.15e-05, loss_r_u:4.11e-05, loss_d_u:1.03e-07
# Iter # 25500/50000	time:167.9	loss:1.50e-02, loss_r_u:1.34e-02, loss_d_u:1.62e-05
# Iter # 25600/50000	time:168.5	loss:1.99e-03, loss_r_u:1.93e-03, loss_d_u:6.46e-07
# Iter # 25700/50000	time:169.2	loss:4.48e-05, loss_r_u:3.78e-05, loss_d_u:7.05e-08
# Iter # 25800/50000	time:169.9	loss:2.96e-04, loss_r_u:2.72e-04, loss_d_u:2.42e-07
# Iter # 25900/50000	time:170.6	loss:4.47e-05, loss_r_u:3.73e-05, loss_d_u:7.39e-08
# Iter # 26000/50000	time:171.2	loss:3.82e-04, loss_r_u:3.71e-04, loss_d_u:1.12e-07
# Iter # 26100/50000	time:171.9	loss:1.69e-03, loss_r_u:1.65e-03, loss_d_u:4.29e-07
# Iter # 26200/50000	time:172.5	loss:1.01e-04, loss_r_u:5.12e-05, loss_d_u:5.00e-07
# Iter # 26300/50000	time:173.2	loss:1.17e-03, loss_r_u:7.68e-04, loss_d_u:4.03e-06
# Iter # 26400/50000	time:173.8	loss:7.82e-05, loss_r_u:7.09e-05, loss_d_u:7.24e-08
# Iter # 26500/50000	time:174.5	loss:7.08e-04, loss_r_u:6.92e-04, loss_d_u:1.53e-07
# Iter # 26600/50000	time:175.1	loss:3.93e-04, loss_r_u:2.68e-04, loss_d_u:1.25e-06
# Iter # 26700/50000	time:175.8	loss:4.11e-05, loss_r_u:3.39e-05, loss_d_u:7.13e-08
# Iter # 26800/50000	time:176.5	loss:1.15e-04, loss_r_u:1.08e-04, loss_d_u:7.28e-08
# Iter # 26900/50000	time:177.2	loss:3.17e-02, loss_r_u:2.80e-02, loss_d_u:3.75e-05
# Iter # 27000/50000	time:177.8	loss:4.14e-05, loss_r_u:3.38e-05, loss_d_u:7.67e-08
# Iter # 27100/50000	time:178.5	loss:1.99e-03, loss_r_u:1.93e-03, loss_d_u:6.60e-07
# Iter # 27200/50000	time:179.1	loss:2.58e-04, loss_r_u:2.46e-04, loss_d_u:1.20e-07
# Iter # 27300/50000	time:179.8	loss:4.37e-03, loss_r_u:4.25e-03, loss_d_u:1.25e-06
# Iter # 27400/50000	time:180.5	loss:1.26e-03, loss_r_u:1.15e-03, loss_d_u:1.05e-06
# Iter # 27500/50000	time:181.1	loss:3.18e-03, loss_r_u:3.17e-03, loss_d_u:7.61e-08
# Iter # 27600/50000	time:181.8	loss:3.55e-03, loss_r_u:3.32e-03, loss_d_u:2.34e-06
# Iter # 27700/50000	time:182.5	loss:3.37e-04, loss_r_u:3.03e-04, loss_d_u:3.49e-07
# Iter # 27800/50000	time:183.2	loss:6.82e-04, loss_r_u:6.75e-04, loss_d_u:7.05e-08
# Epoch 00278: reducing learning rate of group 0 to 2.4010e-04.
# Iter # 27900/50000	time:183.8	loss:3.65e-05, loss_r_u:3.07e-05, loss_d_u:5.76e-08
# Iter # 28000/50000	time:184.5	loss:3.59e-05, loss_r_u:3.06e-05, loss_d_u:5.23e-08
# Iter # 28100/50000	time:185.1	loss:3.53e-05, loss_r_u:3.05e-05, loss_d_u:4.82e-08
# Iter # 28200/50000	time:185.8	loss:3.48e-05, loss_r_u:3.03e-05, loss_d_u:4.52e-08
# Iter # 28300/50000	time:186.4	loss:3.44e-05, loss_r_u:3.01e-05, loss_d_u:4.29e-08
# Iter # 28400/50000	time:187.1	loss:3.40e-05, loss_r_u:2.99e-05, loss_d_u:4.11e-08
# Iter # 28500/50000	time:187.7	loss:3.36e-05, loss_r_u:2.96e-05, loss_d_u:3.98e-08
# Iter # 28600/50000	time:188.3	loss:4.62e-04, loss_r_u:4.46e-04, loss_d_u:1.66e-07
# Iter # 28700/50000	time:189.0	loss:3.01e-03, loss_r_u:2.98e-03, loss_d_u:3.02e-07
# Iter # 28800/50000	time:189.6	loss:3.31e-05, loss_r_u:2.86e-05, loss_d_u:4.44e-08
# Iter # 28900/50000	time:190.2	loss:1.27e-03, loss_r_u:1.26e-03, loss_d_u:1.09e-07
# Iter # 29000/50000	time:190.9	loss:1.07e-03, loss_r_u:1.07e-03, loss_d_u:4.97e-08
# Iter # 29100/50000	time:191.5	loss:1.73e-03, loss_r_u:1.70e-03, loss_d_u:2.49e-07
# Iter # 29200/50000	time:192.2	loss:3.92e-04, loss_r_u:3.06e-04, loss_d_u:8.57e-07
# Iter # 29300/50000	time:192.8	loss:1.23e-03, loss_r_u:9.01e-04, loss_d_u:3.24e-06
# Iter # 29400/50000	time:193.5	loss:1.42e-04, loss_r_u:1.37e-04, loss_d_u:4.62e-08
# Iter # 29500/50000	time:194.1	loss:2.89e-04, loss_r_u:2.83e-04, loss_d_u:5.51e-08
# Iter # 29600/50000	time:194.8	loss:2.81e-03, loss_r_u:2.75e-03, loss_d_u:5.61e-07
# Iter # 29700/50000	time:195.4	loss:1.22e-04, loss_r_u:5.44e-05, loss_d_u:6.79e-07
# Iter # 29800/50000	time:196.1	loss:6.19e-05, loss_r_u:5.65e-05, loss_d_u:5.35e-08
# Iter # 29900/50000	time:196.8	loss:3.77e-05, loss_r_u:3.25e-05, loss_d_u:5.14e-08
# Epoch 00299: reducing learning rate of group 0 to 1.6807e-04.
# Iter # 30000/50000	time:197.6	loss:3.00e-05, loss_r_u:2.57e-05, loss_d_u:4.36e-08
# Iter # 30100/50000	time:198.3	loss:2.97e-05, loss_r_u:2.55e-05, loss_d_u:4.16e-08
# Iter # 30200/50000	time:199.1	loss:2.94e-05, loss_r_u:2.54e-05, loss_d_u:4.00e-08
# Iter # 30300/50000	time:199.9	loss:2.91e-05, loss_r_u:2.52e-05, loss_d_u:3.88e-08
# Iter # 30400/50000	time:200.5	loss:2.88e-05, loss_r_u:2.51e-05, loss_d_u:3.78e-08
# Iter # 30500/50000	time:201.4	loss:2.86e-05, loss_r_u:2.49e-05, loss_d_u:3.70e-08
# Iter # 30600/50000	time:202.4	loss:2.83e-05, loss_r_u:2.47e-05, loss_d_u:3.65e-08
# Iter # 30700/50000	time:203.4	loss:1.50e-03, loss_r_u:1.11e-03, loss_d_u:3.96e-06
# Iter # 30800/50000	time:204.4	loss:2.80e-05, loss_r_u:2.43e-05, loss_d_u:3.69e-08
# Iter # 30900/50000	time:205.4	loss:5.97e-05, loss_r_u:5.58e-05, loss_d_u:3.84e-08
# Iter # 31000/50000	time:206.4	loss:5.53e-03, loss_r_u:5.43e-03, loss_d_u:9.80e-07
# Iter # 31100/50000	time:207.4	loss:2.74e-05, loss_r_u:2.37e-05, loss_d_u:3.73e-08
# Iter # 31200/50000	time:208.5	loss:7.25e-05, loss_r_u:6.64e-05, loss_d_u:6.12e-08
# Iter # 31300/50000	time:209.5	loss:2.70e-05, loss_r_u:2.32e-05, loss_d_u:3.78e-08
# Iter # 31400/50000	time:210.5	loss:3.88e-04, loss_r_u:3.48e-04, loss_d_u:3.97e-07
# Iter # 31500/50000	time:211.5	loss:3.38e-05, loss_r_u:2.91e-05, loss_d_u:4.67e-08
# Iter # 31600/50000	time:212.5	loss:4.19e-04, loss_r_u:3.31e-04, loss_d_u:8.85e-07
# Iter # 31700/50000	time:213.5	loss:3.42e-04, loss_r_u:3.38e-04, loss_d_u:3.98e-08
# Iter # 31800/50000	time:214.5	loss:2.22e-04, loss_r_u:2.16e-04, loss_d_u:5.73e-08
# Iter # 31900/50000	time:215.5	loss:1.65e-04, loss_r_u:1.59e-04, loss_d_u:6.00e-08
# Iter # 32000/50000	time:216.5	loss:6.75e-05, loss_r_u:5.75e-05, loss_d_u:1.00e-07
# Iter # 32100/50000	time:217.5	loss:2.51e-03, loss_r_u:2.33e-03, loss_d_u:1.76e-06
# Iter # 32200/50000	time:218.5	loss:6.87e-05, loss_r_u:5.38e-05, loss_d_u:1.49e-07
# Iter # 32300/50000	time:219.5	loss:2.26e-04, loss_r_u:8.76e-05, loss_d_u:1.38e-06
# Iter # 32400/50000	time:220.6	loss:2.58e-05, loss_r_u:2.19e-05, loss_d_u:3.82e-08
# Iter # 32500/50000	time:221.6	loss:1.00e-04, loss_r_u:9.55e-05, loss_d_u:4.93e-08
# Iter # 32600/50000	time:222.6	loss:2.48e-05, loss_r_u:2.11e-05, loss_d_u:3.77e-08
# Iter # 32700/50000	time:223.6	loss:5.85e-04, loss_r_u:5.74e-04, loss_d_u:1.10e-07
# Iter # 32800/50000	time:224.6	loss:4.52e-05, loss_r_u:4.09e-05, loss_d_u:4.30e-08
# Iter # 32900/50000	time:225.6	loss:3.10e-03, loss_r_u:2.93e-03, loss_d_u:1.73e-06
# Iter # 33000/50000	time:226.6	loss:6.01e-05, loss_r_u:5.63e-05, loss_d_u:3.79e-08
# Iter # 33100/50000	time:227.6	loss:4.16e-04, loss_r_u:4.12e-04, loss_d_u:4.22e-08
# Iter # 33200/50000	time:228.7	loss:2.39e-05, loss_r_u:2.01e-05, loss_d_u:3.73e-08
# Iter # 33300/50000	time:229.7	loss:4.86e-03, loss_r_u:4.85e-03, loss_d_u:9.09e-08
# Iter # 33400/50000	time:230.7	loss:2.37e-05, loss_r_u:1.99e-05, loss_d_u:3.78e-08
# Iter # 33500/50000	time:231.7	loss:3.44e-05, loss_r_u:2.68e-05, loss_d_u:7.61e-08
# Iter # 33600/50000	time:232.7	loss:1.02e-04, loss_r_u:9.75e-05, loss_d_u:4.52e-08
# Iter # 33700/50000	time:233.7	loss:5.47e-05, loss_r_u:5.08e-05, loss_d_u:3.90e-08
# Iter # 33800/50000	time:234.7	loss:2.85e-05, loss_r_u:2.18e-05, loss_d_u:6.74e-08
# Iter # 33900/50000	time:235.7	loss:4.80e-03, loss_r_u:4.79e-03, loss_d_u:9.31e-08
# Iter # 34000/50000	time:236.7	loss:2.25e-05, loss_r_u:1.88e-05, loss_d_u:3.69e-08
# Iter # 34100/50000	time:237.7	loss:2.82e-05, loss_r_u:2.17e-05, loss_d_u:6.54e-08
# Iter # 34200/50000	time:238.7	loss:1.96e-04, loss_r_u:1.86e-04, loss_d_u:9.86e-08
# Iter # 34300/50000	time:239.8	loss:2.38e-05, loss_r_u:2.02e-05, loss_d_u:3.64e-08
# Iter # 34400/50000	time:240.8	loss:2.26e-05, loss_r_u:1.85e-05, loss_d_u:4.12e-08
# Iter # 34500/50000	time:241.8	loss:8.79e-05, loss_r_u:7.62e-05, loss_d_u:1.17e-07
# Iter # 34600/50000	time:242.8	loss:2.24e-05, loss_r_u:1.82e-05, loss_d_u:4.15e-08
# Iter # 34700/50000	time:243.8	loss:2.15e-05, loss_r_u:1.79e-05, loss_d_u:3.65e-08
# Iter # 34800/50000	time:244.8	loss:3.37e-05, loss_r_u:2.95e-05, loss_d_u:4.22e-08
# Iter # 34900/50000	time:245.8	loss:9.83e-04, loss_r_u:9.72e-04, loss_d_u:1.09e-07
# Iter # 35000/50000	time:246.8	loss:2.18e-05, loss_r_u:1.81e-05, loss_d_u:3.69e-08
# Iter # 35100/50000	time:247.9	loss:2.56e-05, loss_r_u:2.18e-05, loss_d_u:3.81e-08
# Iter # 35200/50000	time:248.8	loss:8.71e-05, loss_r_u:8.17e-05, loss_d_u:5.34e-08
# Iter # 35300/50000	time:249.9	loss:2.24e-05, loss_r_u:1.87e-05, loss_d_u:3.71e-08
# Iter # 35400/50000	time:250.9	loss:1.27e-04, loss_r_u:1.23e-04, loss_d_u:4.17e-08
# Iter # 35500/50000	time:251.9	loss:2.24e-05, loss_r_u:1.86e-05, loss_d_u:3.81e-08
# Iter # 35600/50000	time:252.9	loss:7.41e-04, loss_r_u:7.29e-04, loss_d_u:1.20e-07
# Iter # 35700/50000	time:253.9	loss:2.83e-05, loss_r_u:2.43e-05, loss_d_u:4.00e-08
# Iter # 35800/50000	time:255.0	loss:1.71e-04, loss_r_u:5.96e-05, loss_d_u:1.11e-06
# Epoch 00358: reducing learning rate of group 0 to 1.1765e-04.
# Iter # 35900/50000	time:256.0	loss:2.02e-05, loss_r_u:1.66e-05, loss_d_u:3.59e-08
# Iter # 36000/50000	time:257.0	loss:2.01e-05, loss_r_u:1.66e-05, loss_d_u:3.53e-08
# Iter # 36100/50000	time:258.0	loss:2.00e-05, loss_r_u:1.65e-05, loss_d_u:3.49e-08
# Iter # 36200/50000	time:259.0	loss:1.99e-05, loss_r_u:1.64e-05, loss_d_u:3.45e-08
# Iter # 36300/50000	time:260.0	loss:1.98e-05, loss_r_u:1.63e-05, loss_d_u:3.43e-08
# Iter # 36400/50000	time:261.0	loss:1.96e-05, loss_r_u:1.62e-05, loss_d_u:3.40e-08
# Iter # 36500/50000	time:262.0	loss:1.95e-05, loss_r_u:1.61e-05, loss_d_u:3.39e-08
# Iter # 36600/50000	time:263.1	loss:6.88e-04, loss_r_u:6.71e-04, loss_d_u:1.68e-07
# Iter # 36700/50000	time:264.1	loss:6.19e-04, loss_r_u:6.14e-04, loss_d_u:4.98e-08
# Iter # 36800/50000	time:265.1	loss:2.05e-05, loss_r_u:1.71e-05, loss_d_u:3.40e-08
# Iter # 36900/50000	time:266.1	loss:7.65e-04, loss_r_u:7.61e-04, loss_d_u:4.40e-08
# Iter # 37000/50000	time:267.2	loss:1.91e-05, loss_r_u:1.56e-05, loss_d_u:3.46e-08
# Iter # 37100/50000	time:268.2	loss:2.28e-05, loss_r_u:1.91e-05, loss_d_u:3.68e-08
# Iter # 37200/50000	time:269.2	loss:3.65e-05, loss_r_u:3.23e-05, loss_d_u:4.17e-08
# Iter # 37300/50000	time:270.3	loss:2.19e-05, loss_r_u:1.84e-05, loss_d_u:3.52e-08
# Iter # 37400/50000	time:271.3	loss:3.13e-04, loss_r_u:2.79e-04, loss_d_u:3.43e-07
# Iter # 37500/50000	time:272.3	loss:3.23e-05, loss_r_u:2.62e-05, loss_d_u:6.08e-08
# Iter # 37600/50000	time:273.3	loss:3.57e-05, loss_r_u:3.14e-05, loss_d_u:4.29e-08
# Iter # 37700/50000	time:274.3	loss:2.72e-04, loss_r_u:2.66e-04, loss_d_u:6.21e-08
# Iter # 37800/50000	time:275.3	loss:5.73e-04, loss_r_u:5.45e-04, loss_d_u:2.80e-07
# Iter # 37900/50000	time:276.3	loss:8.67e-05, loss_r_u:6.27e-05, loss_d_u:2.41e-07
# Iter # 38000/50000	time:277.3	loss:1.09e-04, loss_r_u:9.13e-05, loss_d_u:1.76e-07
# Iter # 38100/50000	time:278.3	loss:3.00e-05, loss_r_u:2.65e-05, loss_d_u:3.44e-08
# Epoch 00381: reducing learning rate of group 0 to 8.2354e-05.
# Iter # 38200/50000	time:279.3	loss:1.80e-05, loss_r_u:1.46e-05, loss_d_u:3.40e-08
# Iter # 38300/50000	time:280.4	loss:1.79e-05, loss_r_u:1.45e-05, loss_d_u:3.38e-08
# Iter # 38400/50000	time:281.4	loss:1.78e-05, loss_r_u:1.45e-05, loss_d_u:3.37e-08
# Iter # 38500/50000	time:282.4	loss:1.78e-05, loss_r_u:1.44e-05, loss_d_u:3.35e-08
# Iter # 38600/50000	time:283.4	loss:1.77e-05, loss_r_u:1.44e-05, loss_d_u:3.34e-08
# Iter # 38700/50000	time:284.5	loss:1.76e-05, loss_r_u:1.43e-05, loss_d_u:3.33e-08
# Iter # 38800/50000	time:285.5	loss:1.75e-05, loss_r_u:1.42e-05, loss_d_u:3.32e-08
# Iter # 38900/50000	time:286.5	loss:2.77e-03, loss_r_u:2.47e-03, loss_d_u:2.93e-06
# Iter # 39000/50000	time:287.5	loss:1.74e-05, loss_r_u:1.41e-05, loss_d_u:3.33e-08
# Iter # 39100/50000	time:288.5	loss:2.17e-04, loss_r_u:2.04e-04, loss_d_u:1.28e-07
# Iter # 39200/50000	time:289.5	loss:1.73e-05, loss_r_u:1.39e-05, loss_d_u:3.33e-08
# Iter # 39300/50000	time:290.5	loss:2.59e-04, loss_r_u:2.52e-04, loss_d_u:7.02e-08
# Iter # 39400/50000	time:291.5	loss:1.04e-04, loss_r_u:1.00e-04, loss_d_u:3.44e-08
# Iter # 39500/50000	time:292.5	loss:1.71e-05, loss_r_u:1.37e-05, loss_d_u:3.33e-08
# Iter # 39600/50000	time:293.6	loss:6.55e-04, loss_r_u:6.48e-04, loss_d_u:7.36e-08
# Iter # 39700/50000	time:294.6	loss:1.69e-05, loss_r_u:1.36e-05, loss_d_u:3.34e-08
# Iter # 39800/50000	time:295.6	loss:5.74e-05, loss_r_u:3.12e-05, loss_d_u:2.62e-07
# Iter # 39900/50000	time:296.6	loss:1.92e-05, loss_r_u:1.59e-05, loss_d_u:3.33e-08
# Iter # 40000/50000	time:297.6	loss:8.92e-05, loss_r_u:5.98e-05, loss_d_u:2.94e-07
# Iter # 40100/50000	time:298.6	loss:1.84e-04, loss_r_u:1.80e-04, loss_d_u:3.93e-08
# Iter # 40200/50000	time:299.6	loss:1.94e-04, loss_r_u:1.38e-04, loss_d_u:5.65e-07
# Iter # 40300/50000	time:300.7	loss:2.10e-05, loss_r_u:1.76e-05, loss_d_u:3.41e-08
# Iter # 40400/50000	time:301.7	loss:1.45e-04, loss_r_u:1.41e-04, loss_d_u:3.37e-08
# Iter # 40500/50000	time:302.7	loss:1.64e-05, loss_r_u:1.31e-05, loss_d_u:3.33e-08
# Iter # 40600/50000	time:303.7	loss:1.88e-05, loss_r_u:1.40e-05, loss_d_u:4.72e-08
# Iter # 40700/50000	time:304.7	loss:1.22e-04, loss_r_u:1.17e-04, loss_d_u:4.56e-08
# Iter # 40800/50000	time:305.8	loss:1.64e-05, loss_r_u:1.31e-05, loss_d_u:3.32e-08
# Iter # 40900/50000	time:306.8	loss:3.84e-05, loss_r_u:3.51e-05, loss_d_u:3.32e-08
# Iter # 41000/50000	time:307.8	loss:1.61e-05, loss_r_u:1.27e-05, loss_d_u:3.38e-08
# Iter # 41100/50000	time:308.8	loss:3.50e-05, loss_r_u:3.14e-05, loss_d_u:3.62e-08
# Iter # 41200/50000	time:309.8	loss:1.84e-05, loss_r_u:1.50e-05, loss_d_u:3.30e-08
# Iter # 41300/50000	time:310.8	loss:2.09e-05, loss_r_u:1.74e-05, loss_d_u:3.51e-08
# Iter # 41400/50000	time:311.8	loss:6.90e-05, loss_r_u:5.93e-05, loss_d_u:9.70e-08
# Iter # 41500/50000	time:312.8	loss:1.25e-03, loss_r_u:1.24e-03, loss_d_u:5.44e-08
# Iter # 41600/50000	time:313.8	loss:1.62e-05, loss_r_u:1.29e-05, loss_d_u:3.32e-08
# Iter # 41700/50000	time:314.9	loss:1.59e-05, loss_r_u:1.26e-05, loss_d_u:3.30e-08
# Iter # 41800/50000	time:315.9	loss:1.86e-05, loss_r_u:1.43e-05, loss_d_u:4.29e-08
# Iter # 41900/50000	time:316.9	loss:2.63e-05, loss_r_u:2.28e-05, loss_d_u:3.51e-08
# Iter # 42000/50000	time:317.9	loss:2.36e-05, loss_r_u:2.00e-05, loss_d_u:3.60e-08
# Iter # 42100/50000	time:318.9	loss:1.60e-04, loss_r_u:1.56e-04, loss_d_u:4.20e-08
# Iter # 42200/50000	time:320.0	loss:1.79e-05, loss_r_u:1.33e-05, loss_d_u:4.54e-08
# Iter # 42300/50000	time:321.0	loss:1.75e-05, loss_r_u:1.41e-05, loss_d_u:3.46e-08
# Iter # 42400/50000	time:322.0	loss:1.78e-05, loss_r_u:1.45e-05, loss_d_u:3.30e-08
# Iter # 42500/50000	time:323.0	loss:1.81e-05, loss_r_u:1.48e-05, loss_d_u:3.36e-08
# Iter # 42600/50000	time:324.0	loss:5.89e-05, loss_r_u:3.86e-05, loss_d_u:2.03e-07
# Iter # 42700/50000	time:325.1	loss:1.09e-03, loss_r_u:1.08e-03, loss_d_u:1.48e-07
# Iter # 42800/50000	time:326.1	loss:4.44e-04, loss_r_u:4.36e-04, loss_d_u:7.35e-08
# Epoch 00428: reducing learning rate of group 0 to 5.7648e-05.
# Iter # 42900/50000	time:327.1	loss:1.50e-05, loss_r_u:1.17e-05, loss_d_u:3.29e-08
# Iter # 43000/50000	time:328.1	loss:1.50e-05, loss_r_u:1.17e-05, loss_d_u:3.28e-08
# Iter # 43100/50000	time:329.1	loss:1.49e-05, loss_r_u:1.16e-05, loss_d_u:3.28e-08
# Iter # 43200/50000	time:330.1	loss:1.49e-05, loss_r_u:1.16e-05, loss_d_u:3.27e-08
# Iter # 43300/50000	time:331.2	loss:1.48e-05, loss_r_u:1.16e-05, loss_d_u:3.27e-08
# Iter # 43400/50000	time:332.2	loss:1.48e-05, loss_r_u:1.15e-05, loss_d_u:3.26e-08
# Iter # 43500/50000	time:333.2	loss:1.47e-05, loss_r_u:1.15e-05, loss_d_u:3.26e-08
# Iter # 43600/50000	time:334.2	loss:1.47e-05, loss_r_u:1.14e-05, loss_d_u:3.26e-08
# Iter # 43700/50000	time:335.2	loss:2.17e-05, loss_r_u:1.84e-05, loss_d_u:3.31e-08
# Iter # 43800/50000	time:336.2	loss:1.46e-05, loss_r_u:1.14e-05, loss_d_u:3.26e-08
# Iter # 43900/50000	time:337.3	loss:1.84e-04, loss_r_u:1.48e-04, loss_d_u:3.57e-07
# Iter # 44000/50000	time:338.3	loss:1.45e-05, loss_r_u:1.13e-05, loss_d_u:3.26e-08
# Iter # 44100/50000	time:339.3	loss:1.45e-05, loss_r_u:1.12e-05, loss_d_u:3.26e-08
# Iter # 44200/50000	time:340.3	loss:3.09e-05, loss_r_u:2.75e-05, loss_d_u:3.37e-08
# Iter # 44300/50000	time:341.3	loss:1.44e-05, loss_r_u:1.11e-05, loss_d_u:3.28e-08
# Iter # 44400/50000	time:342.3	loss:1.44e-05, loss_r_u:1.11e-05, loss_d_u:3.27e-08
# Iter # 44500/50000	time:343.3	loss:1.43e-05, loss_r_u:1.11e-05, loss_d_u:3.26e-08
# Iter # 44600/50000	time:344.3	loss:1.43e-05, loss_r_u:1.10e-05, loss_d_u:3.26e-08
# Iter # 44700/50000	time:345.3	loss:2.14e-05, loss_r_u:1.70e-05, loss_d_u:4.42e-08
# Iter # 44800/50000	time:346.4	loss:1.42e-05, loss_r_u:1.10e-05, loss_d_u:3.26e-08
# Iter # 44900/50000	time:347.4	loss:1.42e-05, loss_r_u:1.09e-05, loss_d_u:3.25e-08
# Iter # 45000/50000	time:348.4	loss:1.41e-05, loss_r_u:1.09e-05, loss_d_u:3.25e-08
# Iter # 45100/50000	time:349.4	loss:1.45e-05, loss_r_u:1.12e-05, loss_d_u:3.29e-08
# Iter # 45200/50000	time:350.4	loss:1.41e-05, loss_r_u:1.08e-05, loss_d_u:3.25e-08
# Iter # 45300/50000	time:351.4	loss:1.40e-05, loss_r_u:1.08e-05, loss_d_u:3.25e-08
# Iter # 45400/50000	time:352.5	loss:1.57e-05, loss_r_u:1.20e-05, loss_d_u:3.76e-08
# Iter # 45500/50000	time:353.5	loss:1.40e-05, loss_r_u:1.07e-05, loss_d_u:3.25e-08
# Iter # 45600/50000	time:354.5	loss:1.39e-05, loss_r_u:1.07e-05, loss_d_u:3.24e-08
# Iter # 45700/50000	time:355.5	loss:1.39e-05, loss_r_u:1.06e-05, loss_d_u:3.24e-08
# Iter # 45800/50000	time:356.5	loss:1.43e-05, loss_r_u:1.09e-05, loss_d_u:3.38e-08
# Iter # 45900/50000	time:357.5	loss:1.38e-05, loss_r_u:1.06e-05, loss_d_u:3.25e-08
# Iter # 46000/50000	time:358.6	loss:1.38e-05, loss_r_u:1.05e-05, loss_d_u:3.24e-08
# Iter # 46100/50000	time:359.6	loss:1.50e-05, loss_r_u:1.17e-05, loss_d_u:3.26e-08
# Iter # 46200/50000	time:360.6	loss:1.37e-05, loss_r_u:1.05e-05, loss_d_u:3.25e-08
# Iter # 46300/50000	time:361.6	loss:1.37e-05, loss_r_u:1.04e-05, loss_d_u:3.25e-08
# Iter # 46400/50000	time:362.6	loss:1.37e-05, loss_r_u:1.04e-05, loss_d_u:3.24e-08
# Iter # 46500/50000	time:363.6	loss:2.14e-05, loss_r_u:1.36e-05, loss_d_u:7.78e-08
# Iter # 46600/50000	time:364.6	loss:4.32e-04, loss_r_u:4.27e-04, loss_d_u:4.83e-08
# Iter # 46700/50000	time:365.7	loss:1.36e-05, loss_r_u:1.03e-05, loss_d_u:3.25e-08
# Iter # 46800/50000	time:366.7	loss:1.35e-05, loss_r_u:1.03e-05, loss_d_u:3.24e-08
# Iter # 46900/50000	time:367.7	loss:1.08e-04, loss_r_u:1.03e-04, loss_d_u:4.69e-08
# Iter # 47000/50000	time:368.7	loss:1.35e-05, loss_r_u:1.02e-05, loss_d_u:3.25e-08
# Iter # 47100/50000	time:369.7	loss:1.34e-05, loss_r_u:1.02e-05, loss_d_u:3.24e-08
# Iter # 47200/50000	time:370.8	loss:4.26e-05, loss_r_u:3.92e-05, loss_d_u:3.39e-08
# Iter # 47300/50000	time:371.8	loss:1.34e-05, loss_r_u:1.01e-05, loss_d_u:3.25e-08
# Iter # 47400/50000	time:372.8	loss:1.33e-05, loss_r_u:1.01e-05, loss_d_u:3.24e-08
# Iter # 47500/50000	time:373.8	loss:1.33e-05, loss_r_u:1.01e-05, loss_d_u:3.24e-08
# Iter # 47600/50000	time:374.8	loss:1.33e-05, loss_r_u:1.01e-05, loss_d_u:3.23e-08
# Iter # 47700/50000	time:375.8	loss:1.38e-05, loss_r_u:1.05e-05, loss_d_u:3.30e-08
# Iter # 47800/50000	time:376.8	loss:1.32e-05, loss_r_u:1.00e-05, loss_d_u:3.23e-08
# Iter # 47900/50000	time:377.9	loss:1.32e-05, loss_r_u:9.98e-06, loss_d_u:3.23e-08
# Iter # 48000/50000	time:378.9	loss:1.32e-05, loss_r_u:9.95e-06, loss_d_u:3.23e-08
# Iter # 48100/50000	time:379.9	loss:1.69e-05, loss_r_u:1.25e-05, loss_d_u:4.41e-08
# Iter # 48200/50000	time:380.9	loss:4.84e-04, loss_r_u:4.74e-04, loss_d_u:1.08e-07
# Iter # 48300/50000	time:381.9	loss:1.31e-05, loss_r_u:9.88e-06, loss_d_u:3.23e-08
# Iter # 48400/50000	time:383.0	loss:1.49e-05, loss_r_u:1.17e-05, loss_d_u:3.25e-08
# Iter # 48500/50000	time:384.0	loss:1.33e-05, loss_r_u:1.01e-05, loss_d_u:3.25e-08
# Iter # 48600/50000	time:385.0	loss:1.38e-05, loss_r_u:1.05e-05, loss_d_u:3.25e-08
# Iter # 48700/50000	time:386.0	loss:1.30e-05, loss_r_u:9.75e-06, loss_d_u:3.23e-08
# Iter # 48800/50000	time:387.0	loss:1.30e-05, loss_r_u:9.73e-06, loss_d_u:3.23e-08
# Iter # 48900/50000	time:388.1	loss:1.51e-05, loss_r_u:1.14e-05, loss_d_u:3.67e-08
# Iter # 49000/50000	time:389.1	loss:1.29e-05, loss_r_u:9.67e-06, loss_d_u:3.23e-08
# Iter # 49100/50000	time:390.1	loss:1.29e-05, loss_r_u:9.64e-06, loss_d_u:3.23e-08
# Iter # 49200/50000	time:391.1	loss:1.57e-05, loss_r_u:1.13e-05, loss_d_u:4.44e-08
# Iter # 49300/50000	time:392.1	loss:1.28e-05, loss_r_u:9.61e-06, loss_d_u:3.23e-08
# Iter # 49400/50000	time:393.1	loss:1.28e-05, loss_r_u:9.60e-06, loss_d_u:3.23e-08
# Iter # 49500/50000	time:394.2	loss:1.28e-05, loss_r_u:9.57e-06, loss_d_u:3.22e-08
# Iter # 49600/50000	time:395.2	loss:1.28e-05, loss_r_u:9.54e-06, loss_d_u:3.22e-08
# Iter # 49700/50000	time:396.2	loss:1.39e-03, loss_r_u:1.31e-03, loss_d_u:7.35e-07
# Iter # 49800/50000	time:397.2	loss:1.27e-05, loss_r_u:9.49e-06, loss_d_u:3.23e-08
# Iter # 49900/50000	time:398.2	loss:1.27e-05, loss_r_u:9.47e-06, loss_d_u:3.22e-08
# Iter # 50000/50000	time:399.2	loss:1.27e-05, loss_r_u:9.45e-06, loss_d_u:3.22e-08

# %%
model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(),'nn_k_state': pinn.nn_k.state_dict()}
backbone_path = os.path.join(model_path, f'backbone_adam.pth')
torch.save(model_state, backbone_path)

np.save("./loss_logger_dict.npy", logger)

# %%
def used_time(start_time):
    seconds = time.time() - start_time
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print(f'used time: {hours:.0f}h {minutes:.0f}m {seconds:.0f}s')
    
used_time(start_time)
# Out:
# used time: 0h 6m 39s

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
# loss曲线
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res_u"]
        [::k], label=r"Re($\mathcal{L}_{r})$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_data_u"]
        [::k], label=r"Re($\mathcal{L}_{data})$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)
model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_k.load_state_dict(model_state['nn_k_state'])
# Out:
# <All keys matched successfully>

# %%
N = 2000
dataset = Dataset(N)
t_data, k_data, u_data = dataset.train_data(N)

# %%
# relative L2 误差
u_data = np.array(u_data).reshape(-1, 1)
t_data = np.array(t_data).reshape(-1, 1)
k_data = np.array(k_data).reshape(-1, 1)

t_data = torch.tensor(t_data).float().to(device)
u_pred = pinn.net_u(t_data).detach().cpu().numpy()
k_pred = pinn.k.detach().cpu().numpy()
k_pred = np.ones_like(u_pred)*k_pred
u3_pred = pinn.net_3u(t_data).detach().cpu().numpy()

t_data = t_data.detach().cpu().numpy()
error_u = np.linalg.norm(u_pred - u_data) / np.linalg.norm(u_data)
error_k = np.linalg.norm(k_pred - k_data) / np.linalg.norm(k_data)
print('u Relative l2 error: {:.3e}'.format(error_u))
print('k Relative l2 error: {:.3e}'.format(error_k))
# Out:
# u Relative l2 error: 5.052e-04
# k Relative l2 error: 2.364e-02

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t_data, u_data)
# cax = ax.plot(t_data, u_pred)

cax = ax.scatter(t_data, u_data)
# cax = ax.scatter(t_data, u_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
cax2 = ax2.scatter(t_data, u_pred)
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Predicted $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()

# %%
iter = np.array(loss_logger["iter"])
k = np.array(loss_logger["k"])
stander = np.ones_like(k)
plt.plot(iter, k, label=r"Re($\mathcal{L}_{r})$")
plt.plot(iter, stander)
plt.ylim(0.5,1.5)

plt.tight_layout()
plt.savefig('k.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

# cax = ax.plot(t_data, k_data)
# cax = ax.plot(t_data, k_pred)

cax = ax.scatter(t_data, k_data)
cax = ax.scatter(t_data, k_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $k(t)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(k_data - k_pred))
cax2 = ax2.scatter(t_data, np.abs(k_data - k_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error $k(t)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('K.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

cax = ax.scatter(t_data, u3_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $d3u(x,y)$')
ax.set_aspect(1./ax.get_data_ratio())

# cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Predicted $u(x,y)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('u.png')
plt.show()
