# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_399375/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy.io as io

import os
import time

# %% [markdown]
# ## 超参数设置

# %%
domain = (-1, 1, -1, 1)
xmin, xmax, ymin, ymax = domain
mlp_layers = [1] + [40]*4 + [1]
mlp_layers_k = [1] + [20]*2 + [1]
# n_iters = 200000
n_iters = 50000
learning_rate = 1e-3
gamma = 0.6

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %% [markdown]
# ## 数据集生成

# %%
import torch
import matplotlib.pyplot as plt
import pandas as pd
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# 生成x的数据点
x = torch.linspace(0, 1, 100)

# 计算对应的y值
#计算解析解，光滑刚度最小值为18750KN.m
y1 = (125*torch.arctan(torch.tensor(2)))/32 - (25*x)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x**2 - x + 5/16))/128 + (
    125*torch.arctan(4*x - 2))/32 + x*((25*x)/4 - (125*torch.arctan(4*x - 2))/16) - (25*x**2)/8

#计算解析解，光滑刚度最小值为31250KN.m
y2 = (45 * torch.log(x ** 2 - x + 3 / 8)) / 32 - (45 * torch.log(torch.tensor(3/8))) / 32 - (15 * x) / 4 + (
    45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 16 + (
    45 * 2 ** (1 / 2) * torch.arctan(torch.tensor(2 ** (1 / 2)))) / 16 + x * (
    (15 * x) / 2 - (45 * 2 ** (1 / 2) * torch.arctan(2 * 2 ** (1 / 2) * x - 2 ** (1 / 2))) / 8) - (
    15 * x ** 2) / 4

#计算解析解，光滑刚度最小值为62500KN.m
y3 = (45*torch.log(x**2 - x + 3/4))/8 - (45*torch.log(torch.tensor(3/4)))/8 - (15*x)/2 + (
    45*2**(1/2)*torch.arctan(2**(1/2)*x - 2**(1/2)/2))/8 + x*(15*x - (45*2**(1/2)*torch.arctan(2**(1/2)*x - 2**(1/2)/2))/4) - (
    15*x**2)/2 + (45*2**(1/2)*torch.arctan(torch.tensor(2**(1/2)/2)))/8

#计算解析解,刚度不变一直为93750KN.m
y4 = 5/3*x**4-10/3*x**3+5/3*x

# 创建一个数据框
data = pd.DataFrame({'x': x.numpy(), 'y1': y1.numpy()})

# 绘制图形
plt.figure(figsize=(8, 6))
plt.plot(x.numpy(), y1.numpy(), 'r-', label='Minimum with 5times')
plt.plot(x.numpy(), y2.numpy(), 'k-', label='Minimum with 3times')
plt.plot(x.numpy(), y3.numpy(), 'g-', label='Minimum with 1.5times')
plt.plot(x.numpy(), y4.numpy(), 'b-', label='unchange')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Analytic Solution')
plt.legend()
plt.grid(True)

# 保存数据到Excel文件
data.to_excel('output.xlsx', index=False)

# 显示图形
plt.show()

# %%
class Dataset:
    def __init__(self, N):
        self.x = torch.linspace(0, 1, N)

    def train_data(self, N, verbose=None):
        # 无量纲化
        t0 = 5
        K0 = 31250
        U0 = 0.001

        x = self.x
        x_1 = x[(x <= 1/3)]
        x_2 = x[(x > 1/3) & (x <= 2/3)]
        x_3 = x[(x > 2/3)]
        k_1 = self.k(x_1)
        k_2 = self.k(x_2)
        k_3 = self.k(x_3)
        y_1 = (125*torch.arctan(torch.tensor(2)))/32 - (25*x_1)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x_1**2 - x_1 + 5/16))/128 + (
            125*torch.arctan(4*x_1 - 2))/32 + x_1*((25*x_1)/4 - (125*torch.arctan(4*x_1 - 2))/16) - (25*x_1**2)/8

        y_2 = (125*torch.arctan(torch.tensor(2)))/32 - (25*x_2)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x_2**2 - x_2 + 5/16))/128 + (
            125*torch.arctan(4*x_2 - 2))/32 + x_2*((25*x_2)/4 - (125*torch.arctan(4*x_2 - 2))/16) - (25*x_2**2)/8

        y_3 = (125*torch.arctan(torch.tensor(2)))/32 - (25*x_3)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x_3**2 - x_3 + 5/16))/128 + (
            125*torch.arctan(4*x_3 - 2))/32 + x_3*((25*x_3)/4 - (125*torch.arctan(4*x_3 - 2))/16) - (25*x_3**2)/8

        # y = 5/3*x**4 - 10/3*x**3 + 5/3*x
        # print(self.x.shape)
        idx = np.random.randint(0, x_1.shape[0]-1, N)
        # return x.reshape(-1,1), k.reshape(-1,1), y.reshape(-1,1)
        # return x[idx].reshape(-1, 1), k[idx].reshape(-1,1), y[idx].reshape(-1,1)
        return x_1[idx].reshape(-1, 1), k_1[idx].reshape(-1, 1), y_1[idx].reshape(-1, 1), x_2[idx].reshape(-1, 1), k_2[idx].reshape(-1, 1), y_2[idx].reshape(-1, 1), x_3[idx].reshape(-1, 1), k_3[idx].reshape(-1, 1), y_3[idx].reshape(-1, 1)

    # k函数
    def k(self, t):
        return 16/5*t**2 - 16/3*t + 1
        # return 10000*(t*5-2.5)**2 + 31250


N = 10
dataset = Dataset(N)
t1_data, k1_data, u1_data, t2_data, k2_data, u2_data, t3_data, k3_data, u3_data = dataset.train_data(
    N)
# print(t_data.shape, k_data.shape, u_data.shape)
print(t1_data.shape, k1_data.shape, u1_data.shape)
# Out:
# torch.Size([10, 1]) torch.Size([10, 1]) torch.Size([10, 1])

# %%
# u_data
plt.scatter(t1_data, u1_data)

# %%
# k_data
plt.scatter(t1_data, k1_data)

# %% [markdown]
# ## PINN主干网络

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            self.model.add_module(f'fc{i+1}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            self.model.add_module(f'act{i+1}', nn.Tanh())
        self.model.add_module(f'fc{len(mlp_layers)-1})', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
    
    def forward(self, X):
        return self.model(X)
    
    
mlp = MLP(mlp_layers)
mlp_k = MLP(mlp_layers_k)
mlp.model
# Out:
# Sequential(
#   (fc1): Linear(in_features=1, out_features=40, bias=True)
#   (act1): Tanh()
#   (fc2): Linear(in_features=40, out_features=40, bias=True)
#   (act2): Tanh()
#   (fc3): Linear(in_features=40, out_features=40, bias=True)
#   (act3): Tanh()
#   (fc4): Linear(in_features=40, out_features=40, bias=True)
#   (act4): Tanh()
#   (fc5)): Linear(in_features=40, out_features=1, bias=False)
# )

# %% [markdown]
# ## PINN模型

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
class PINNHelmholtz(nn.Module):
    def __init__(self, backbone, nn_k):
        super(PINNHelmholtz, self).__init__()
        self.backbone = backbone
        self.nn_k = nn_k
        
    def forward(self, t1_data, t2_data, t3_data, u1_data, u2_data, u3_data):
        f1_res_pred = self.net_f(t1_data)
        f2_res_pred = self.net_f(t2_data)
        f3_res_pred = self.net_f(t3_data)
        u1_pred = self.net_u(t1_data)
        u2_pred = self.net_u(t2_data)
        u3_pred = self.net_u(t3_data)

        loss_res_u1 = torch.mean((f1_res_pred - 30) ** 2)
        loss_res_u2 = torch.mean((f2_res_pred - 30) ** 2)
        loss_res_u3 = torch.mean((f3_res_pred - 30) ** 2)
        loss_data_u1 = torch.mean((u1_pred - u1_data) ** 2)
        loss_data_u2 = torch.mean((u2_pred - u2_data) ** 2)
        loss_data_u3 = torch.mean((u3_pred - u3_data) ** 2)
        return loss_res_u1, loss_res_u2, loss_res_u3, loss_data_u1, loss_data_u2, loss_data_u3
    
    def net_u(self, X):
        return self.backbone(X)
        # return self.backbone(X)*(X*(X-1))
    
    def net_k(self, X):
        # return 8/3*X**2 - 8/3*X + 1
        return self.nn_k(X)*(X*(X-1))+1

    def net_3u(self, X):
        X.requires_grad_(True)
        u = self.net_u(X)

        # 求u的梯度
        du = grad(u, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        return d3u
    
    def net_f(self, X):
        X.requires_grad_(True)
        u_pred = self.net_u(X)
        
        # 求u的梯度
        du = grad(u_pred, X)[0]
        d2u = grad(du, X)[0]
        d3u = grad(d2u, X)[0]
        d4u = grad(d3u, X)[0]
        
        k_pred = self.net_k(X)
        dk = grad(k_pred, X)[0]
        d2k = grad(dk, X)[0]
        
        f_res_pred = 0.75*k_pred*d4u + 1.5*dk*d3u + 0.75*d2k*d2u
        
        return f_res_pred
    

pinn = PINNHelmholtz(mlp,mlp_k)

# %% [markdown]
# ## Adam训练

# %%
# 训练
N = 1000
dataset = Dataset(N)
t1_data, k1_data, u1_data, t2_data, k2_data, u2_data, t3_data, k3_data, u3_data = dataset.train_data(N)
t1_data = t1_data.float().to(device)
t2_data = t2_data.float().to(device)
t3_data = t3_data.float().to(device)
u1_data = u1_data.float().to(device)
u2_data = u2_data.float().to(device)
u3_data = u3_data.float().to(device)

backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=learning_rate)
optimizer_adam_k = optim.Adam(pinn.nn_k.parameters(), lr=learning_rate)

lr_sche = ReduceLROnPlateau(optimizer_adam, mode='min', factor=gamma, verbose=True)
lr_sche_k = ReduceLROnPlateau(optimizer_adam_k, mode='min', factor=gamma, verbose=True)
# lr_sche = ExponentialLR(optimizer_adam, gamma=gamma, verbose=True)
# lr_sche_k = ExponentialLR(optimizer_adam_k, gamma=gamma, verbose=True)

logger = {
    "loss": [],
    "loss_res_u1": [],
    "loss_res_u2": [],
    "loss_res_u3": [],
    "loss_data_u1": [],
    "loss_data_u2": [],
    "loss_data_u3": [],
    "iter": []
}
with open(train_info_path + 'train_info.txt', 'w') as f:
    f.write('Training by Adam:\n')
start_time = time.time()

for it in range(n_iters):
    pinn.zero_grad()
    loss_res_u1, loss_res_u2, loss_res_u3, loss_data_u1, loss_data_u2, loss_data_u3 = pinn(
        t1_data, t2_data, t3_data, u1_data, u2_data, u3_data)
    # loss = 1*(loss_res_u) + 1e2*(loss_data_u)
    loss = (1e2*loss_res_u1 + 1*loss_res_u2 + 1e2*loss_res_u3) + \
        (1e7*loss_data_u1 + 1e4*loss_data_u2 + 1e7*loss_data_u3)
    loss_res_u = 1*loss_res_u1 + 1*loss_res_u2 + 1*loss_res_u3
    loss_data_u = 1*loss_data_u1 + 1*loss_data_u2 + 1*loss_data_u3
    loss.backward()
    optimizer_adam.step()
    optimizer_adam_k.step()
    
    # 保存训练信息 -------
    logger["loss"].append(loss.item())
    logger["loss_res_u1"].append(loss_res_u1.item())
    logger["loss_res_u2"].append(loss_res_u2.item())
    logger["loss_res_u3"].append(loss_res_u3.item())
    logger["loss_data_u1"].append(loss_data_u1.item())
    logger["loss_data_u2"].append(loss_data_u2.item())
    logger["loss_data_u3"].append(loss_data_u3.item())
    logger["iter"].append(it + 1)
    
    if (it + 1) % 100 == 0:  # 打印训练信息 -------
        info = f'Iter # {it+1:4d}/{n_iters}\ttime:{time.time()-start_time:.1f}\t' + f'loss:{loss.item():.2e}, loss_r_u:{loss_res_u.item():.2e}, loss_d_u:{loss_data_u.item():.2e}'
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write(info + '\n')
        print(info)
        
    if (it + 1) % 100 == 0:  # 学习率衰减 -------
        lr_sche.step(loss)
        lr_sche_k.step(loss)
# Out:
# Iter #  100/50000	time:3.4	loss:4.43e+06, loss_r_u:2.03e+03, loss_d_u:1.30e+00
# Iter #  200/50000	time:6.1	loss:1.12e+06, loss_r_u:4.96e+03, loss_d_u:2.51e-01
# Iter #  300/50000	time:8.7	loss:2.13e+04, loss_r_u:1.30e+04, loss_d_u:4.77e-04
# Iter #  400/50000	time:11.3	loss:1.53e+04, loss_r_u:1.02e+04, loss_d_u:5.05e-04
# Iter #  500/50000	time:13.9	loss:1.11e+04, loss_r_u:7.69e+03, loss_d_u:6.00e-04
# Iter #  600/50000	time:16.4	loss:9.87e+03, loss_r_u:6.10e+03, loss_d_u:5.34e-04
# Iter #  700/50000	time:19.0	loss:6.93e+03, loss_r_u:4.85e+03, loss_d_u:6.85e-04
# Iter #  800/50000	time:21.6	loss:1.07e+04, loss_r_u:4.06e+03, loss_d_u:6.85e-04
# Iter #  900/50000	time:24.2	loss:5.09e+03, loss_r_u:3.40e+03, loss_d_u:5.86e-04
# Iter # 1000/50000	time:26.7	loss:4.36e+03, loss_r_u:2.85e+03, loss_d_u:5.01e-04
# Iter # 1100/50000	time:29.4	loss:3.99e+03, loss_r_u:2.50e+03, loss_d_u:5.59e-04
# Iter # 1200/50000	time:31.9	loss:3.44e+03, loss_r_u:2.09e+03, loss_d_u:4.60e-04
# Iter # 1300/50000	time:34.5	loss:4.12e+03, loss_r_u:1.63e+03, loss_d_u:7.54e-04
# Iter # 1400/50000	time:37.1	loss:2.77e+03, loss_r_u:1.48e+03, loss_d_u:5.04e-04
# Iter # 1500/50000	time:39.7	loss:2.40e+03, loss_r_u:1.20e+03, loss_d_u:4.70e-04
# Iter # 1600/50000	time:42.3	loss:3.02e+04, loss_r_u:1.00e+03, loss_d_u:3.56e-03
# Iter # 1700/50000	time:45.2	loss:2.03e+03, loss_r_u:8.53e+02, loss_d_u:5.06e-04
# Iter # 1800/50000	time:48.0	loss:1.79e+03, loss_r_u:7.15e+02, loss_d_u:4.28e-04
# Iter # 1900/50000	time:50.5	loss:4.79e+04, loss_r_u:6.89e+02, loss_d_u:6.05e-03
# Iter # 2000/50000	time:53.3	loss:1.59e+03, loss_r_u:5.62e+02, loss_d_u:4.39e-04
# Iter # 2100/50000	time:55.9	loss:1.41e+03, loss_r_u:4.88e+02, loss_d_u:3.39e-04
# Iter # 2200/50000	time:58.7	loss:1.26e+03, loss_r_u:4.15e+02, loss_d_u:2.80e-04
# Iter # 2300/50000	time:61.5	loss:1.38e+03, loss_r_u:3.94e+02, loss_d_u:4.02e-04
# Iter # 2400/50000	time:65.3	loss:1.13e+03, loss_r_u:3.50e+02, loss_d_u:2.59e-04
# Iter # 2500/50000	time:69.0	loss:1.01e+03, loss_r_u:2.99e+02, loss_d_u:2.13e-04
# Iter # 2600/50000	time:72.7	loss:1.11e+03, loss_r_u:2.88e+02, loss_d_u:3.47e-04
# Iter # 2700/50000	time:76.5	loss:9.19e+02, loss_r_u:2.55e+02, loss_d_u:1.99e-04
# Iter # 2800/50000	time:80.3	loss:8.20e+02, loss_r_u:2.17e+02, loss_d_u:1.61e-04
# Iter # 2900/50000	time:84.1	loss:1.22e+03, loss_r_u:2.13e+02, loss_d_u:4.05e-04
# Iter # 3000/50000	time:87.9	loss:7.84e+02, loss_r_u:2.01e+02, loss_d_u:1.66e-04
# Iter # 3100/50000	time:91.7	loss:9.74e+02, loss_r_u:1.72e+02, loss_d_u:1.49e-04
# Iter # 3200/50000	time:95.4	loss:6.29e+02, loss_r_u:1.48e+02, loss_d_u:1.09e-04
# Iter # 3300/50000	time:99.2	loss:6.74e+02, loss_r_u:1.55e+02, loss_d_u:1.33e-04
# Iter # 3400/50000	time:103.0	loss:5.82e+02, loss_r_u:1.31e+02, loss_d_u:1.05e-04
# Iter # 3500/50000	time:106.7	loss:6.65e+03, loss_r_u:1.11e+02, loss_d_u:6.97e-04
# Iter # 3600/50000	time:110.5	loss:5.63e+02, loss_r_u:1.04e+02, loss_d_u:1.15e-04
# Iter # 3700/50000	time:114.2	loss:4.83e+02, loss_r_u:1.01e+02, loss_d_u:8.56e-05
# Iter # 3800/50000	time:118.0	loss:1.48e+04, loss_r_u:1.12e+02, loss_d_u:1.90e-03
# Iter # 3900/50000	time:121.9	loss:4.54e+02, loss_r_u:9.35e+01, loss_d_u:7.74e-05
# Iter # 4000/50000	time:125.7	loss:4.02e+02, loss_r_u:7.70e+01, loss_d_u:5.97e-05
# Iter # 4100/50000	time:129.5	loss:4.08e+02, loss_r_u:7.66e+01, loss_d_u:6.75e-05
# Iter # 4200/50000	time:133.3	loss:3.77e+02, loss_r_u:7.32e+01, loss_d_u:5.30e-05
# Iter # 4300/50000	time:137.0	loss:4.75e+02, loss_r_u:7.30e+01, loss_d_u:4.92e-05
# Iter # 4400/50000	time:140.9	loss:3.40e+02, loss_r_u:6.38e+01, loss_d_u:4.92e-05
# Iter # 4500/50000	time:144.7	loss:6.89e+04, loss_r_u:3.21e+01, loss_d_u:1.09e-02
# Iter # 4600/50000	time:148.5	loss:3.45e+02, loss_r_u:6.81e+01, loss_d_u:5.89e-05
# Iter # 4700/50000	time:152.3	loss:9.13e+02, loss_r_u:6.05e+01, loss_d_u:9.23e-05
# Iter # 4800/50000	time:156.1	loss:2.73e+02, loss_r_u:4.83e+01, loss_d_u:3.01e-05
# Iter # 4900/50000	time:159.9	loss:4.35e+02, loss_r_u:6.08e+01, loss_d_u:9.77e-05
# Iter # 5000/50000	time:163.7	loss:2.67e+02, loss_r_u:4.73e+01, loss_d_u:3.09e-05
# Iter # 5100/50000	time:167.5	loss:4.30e+03, loss_r_u:4.03e+01, loss_d_u:7.01e-04
# Iter # 5200/50000	time:171.3	loss:2.76e+02, loss_r_u:4.24e+01, loss_d_u:2.04e-05
# Iter # 5300/50000	time:175.1	loss:2.55e+02, loss_r_u:4.74e+01, loss_d_u:2.55e-05
# Iter # 5400/50000	time:178.9	loss:2.18e+02, loss_r_u:3.65e+01, loss_d_u:2.01e-05
# Iter # 5500/50000	time:182.7	loss:2.66e+02, loss_r_u:5.16e+01, loss_d_u:4.95e-05
# Iter # 5600/50000	time:186.5	loss:2.18e+02, loss_r_u:3.78e+01, loss_d_u:2.11e-05
# Iter # 5700/50000	time:190.3	loss:2.98e+02, loss_r_u:3.86e+01, loss_d_u:2.85e-05
# Iter # 5800/50000	time:194.1	loss:3.65e+02, loss_r_u:4.31e+01, loss_d_u:7.15e-05
# Iter # 5900/50000	time:197.9	loss:1.88e+02, loss_r_u:3.20e+01, loss_d_u:1.48e-05
# Iter # 6000/50000	time:201.7	loss:4.81e+02, loss_r_u:4.54e+01, loss_d_u:9.66e-05
# Iter # 6100/50000	time:205.5	loss:1.89e+02, loss_r_u:3.27e+01, loss_d_u:1.61e-05
# Iter # 6200/50000	time:209.3	loss:2.67e+02, loss_r_u:3.47e+01, loss_d_u:1.53e-05
# Iter # 6300/50000	time:213.1	loss:3.54e+02, loss_r_u:3.97e+01, loss_d_u:2.45e-05
# Iter # 6400/50000	time:216.9	loss:1.62e+02, loss_r_u:2.74e+01, loss_d_u:1.02e-05
# Iter # 6500/50000	time:220.7	loss:3.43e+02, loss_r_u:3.77e+01, loss_d_u:6.78e-05
# Iter # 6600/50000	time:224.5	loss:1.61e+02, loss_r_u:2.68e+01, loss_d_u:1.06e-05
# Iter # 6700/50000	time:228.3	loss:2.70e+02, loss_r_u:3.15e+01, loss_d_u:2.28e-05
# Iter # 6800/50000	time:232.2	loss:1.54e+02, loss_r_u:2.97e+01, loss_d_u:9.21e-06
# Iter # 6900/50000	time:236.0	loss:8.53e+03, loss_r_u:3.69e+01, loss_d_u:1.55e-03
# Iter # 7000/50000	time:239.8	loss:1.51e+02, loss_r_u:2.66e+01, loss_d_u:9.74e-06
# Iter # 7100/50000	time:243.6	loss:1.33e+02, loss_r_u:2.11e+01, loss_d_u:5.79e-06
# Iter # 7200/50000	time:247.4	loss:2.02e+02, loss_r_u:3.52e+01, loss_d_u:1.51e-05
# Iter # 7300/50000	time:251.2	loss:1.55e+02, loss_r_u:2.24e+01, loss_d_u:7.61e-06
# Iter # 7400/50000	time:255.0	loss:1.31e+02, loss_r_u:2.30e+01, loss_d_u:4.16e-06
# Iter # 7500/50000	time:258.8	loss:6.90e+02, loss_r_u:3.31e+01, loss_d_u:1.26e-04
# Iter # 7600/50000	time:262.6	loss:1.27e+02, loss_r_u:2.14e+01, loss_d_u:5.60e-06
# Iter # 7700/50000	time:266.4	loss:1.19e+04, loss_r_u:2.90e+01, loss_d_u:1.57e-03
# Iter # 7800/50000	time:270.2	loss:1.25e+02, loss_r_u:2.33e+01, loss_d_u:6.42e-06
# Iter # 7900/50000	time:274.0	loss:1.09e+02, loss_r_u:1.74e+01, loss_d_u:3.17e-06
# Iter # 8000/50000	time:277.8	loss:1.41e+02, loss_r_u:2.78e+01, loss_d_u:6.98e-06
# Iter # 8100/50000	time:281.6	loss:1.11e+02, loss_r_u:1.70e+01, loss_d_u:4.33e-06
# Iter # 8200/50000	time:285.3	loss:4.85e+04, loss_r_u:2.73e+01, loss_d_u:7.39e-03
# Iter # 8300/50000	time:289.1	loss:1.12e+02, loss_r_u:2.09e+01, loss_d_u:5.62e-06
# Iter # 8400/50000	time:292.8	loss:9.59e+01, loss_r_u:1.49e+01, loss_d_u:2.76e-06
# Iter # 8500/50000	time:296.6	loss:3.26e+02, loss_r_u:2.83e+01, loss_d_u:2.81e-05
# Iter # 8600/50000	time:300.4	loss:9.91e+01, loss_r_u:1.46e+01, loss_d_u:4.30e-06
# Iter # 8700/50000	time:304.1	loss:8.53e+01, loss_r_u:1.22e+01, loss_d_u:2.40e-06
# Iter # 8800/50000	time:307.8	loss:1.38e+02, loss_r_u:2.44e+01, loss_d_u:1.28e-05
# Iter # 8900/50000	time:311.6	loss:8.54e+01, loss_r_u:1.29e+01, loss_d_u:2.89e-06
# Iter # 9000/50000	time:315.4	loss:1.85e+03, loss_r_u:2.74e+01, loss_d_u:3.18e-04
# Iter # 9100/50000	time:319.2	loss:8.82e+01, loss_r_u:1.30e+01, loss_d_u:5.93e-06
# Iter # 9200/50000	time:322.9	loss:7.34e+01, loss_r_u:9.75e+00, loss_d_u:2.46e-06
# Iter # 9300/50000	time:326.8	loss:3.16e+03, loss_r_u:3.54e+01, loss_d_u:3.98e-04
# Iter # 9400/50000	time:330.5	loss:7.67e+01, loss_r_u:1.12e+01, loss_d_u:4.99e-06
# Iter # 9500/50000	time:334.4	loss:5.29e+02, loss_r_u:7.82e+00, loss_d_u:7.68e-05
# Iter # 9600/50000	time:338.2	loss:7.60e+01, loss_r_u:1.22e+01, loss_d_u:3.16e-06
# Iter # 9700/50000	time:341.9	loss:6.04e+01, loss_r_u:7.71e+00, loss_d_u:2.02e-06
# Iter # 9800/50000	time:345.7	loss:2.91e+03, loss_r_u:2.14e+01, loss_d_u:5.42e-04
# Iter # 9900/50000	time:349.4	loss:6.29e+01, loss_r_u:8.37e+00, loss_d_u:4.90e-06
# Iter # 10000/50000	time:353.2	loss:5.12e+01, loss_r_u:6.42e+00, loss_d_u:1.83e-06
# Iter # 10100/50000	time:357.0	loss:5.99e+01, loss_r_u:1.03e+01, loss_d_u:1.67e-06
# Iter # 10200/50000	time:360.7	loss:7.59e+01, loss_r_u:5.81e+00, loss_d_u:8.07e-06
# Iter # 10300/50000	time:364.4	loss:6.14e+01, loss_r_u:8.72e+00, loss_d_u:6.88e-06
# Iter # 10400/50000	time:368.2	loss:4.50e+01, loss_r_u:5.65e+00, loss_d_u:2.30e-06
# Iter # 10500/50000	time:372.0	loss:4.06e+04, loss_r_u:1.50e+01, loss_d_u:5.39e-03
# Iter # 10600/50000	time:375.8	loss:4.84e+01, loss_r_u:8.82e+00, loss_d_u:2.37e-06
# Iter # 10700/50000	time:379.5	loss:3.89e+01, loss_r_u:5.33e+00, loss_d_u:1.12e-06
# Iter # 10800/50000	time:383.3	loss:5.51e+01, loss_r_u:9.98e+00, loss_d_u:7.99e-06
# Iter # 10900/50000	time:387.1	loss:3.91e+01, loss_r_u:5.52e+00, loss_d_u:2.29e-06
# Iter # 11000/50000	time:390.9	loss:3.28e+01, loss_r_u:4.50e+00, loss_d_u:1.03e-06
# Iter # 11100/50000	time:394.8	loss:1.01e+02, loss_r_u:1.12e+01, loss_d_u:9.61e-06
# Iter # 11200/50000	time:398.5	loss:3.61e+01, loss_r_u:5.22e+00, loss_d_u:2.63e-06
# Iter # 11300/50000	time:402.3	loss:2.91e+02, loss_r_u:1.05e+01, loss_d_u:2.45e-05
# Iter # 11400/50000	time:406.1	loss:1.07e+04, loss_r_u:8.79e+00, loss_d_u:1.62e-03
# Iter # 11500/50000	time:409.9	loss:3.71e+01, loss_r_u:6.66e+00, loss_d_u:3.11e-06
# Iter # 11600/50000	time:413.7	loss:2.88e+01, loss_r_u:4.65e+00, loss_d_u:1.12e-06
# Iter # 11700/50000	time:417.5	loss:2.54e+02, loss_r_u:1.37e+01, loss_d_u:4.32e-05
# Iter # 11800/50000	time:421.3	loss:5.40e+02, loss_r_u:5.06e+00, loss_d_u:8.54e-05
# Iter # 11900/50000	time:425.0	loss:3.22e+01, loss_r_u:6.31e+00, loss_d_u:1.87e-06
# Iter # 12000/50000	time:428.8	loss:4.64e+01, loss_r_u:4.77e+00, loss_d_u:2.33e-06
# Iter # 12100/50000	time:432.5	loss:3.51e+01, loss_r_u:7.07e+00, loss_d_u:5.93e-06
# Iter # 12200/50000	time:436.2	loss:2.64e+01, loss_r_u:4.94e+00, loss_d_u:9.31e-07
# Iter # 12300/50000	time:439.9	loss:2.93e+03, loss_r_u:7.76e+00, loss_d_u:4.70e-04
# Iter # 12400/50000	time:443.7	loss:2.66e+01, loss_r_u:5.45e+00, loss_d_u:6.77e-07
# Iter # 12500/50000	time:447.5	loss:3.63e+01, loss_r_u:7.48e+00, loss_d_u:2.61e-06
# Iter # 12600/50000	time:451.3	loss:2.57e+01, loss_r_u:5.11e+00, loss_d_u:7.80e-07
# Iter # 12700/50000	time:455.1	loss:8.60e+01, loss_r_u:6.65e+00, loss_d_u:1.21e-05
# Iter # 12800/50000	time:458.9	loss:3.21e+01, loss_r_u:6.16e+00, loss_d_u:3.23e-06
# Iter # 12900/50000	time:462.7	loss:1.90e+02, loss_r_u:9.23e+00, loss_d_u:1.67e-05
# Iter # 13000/50000	time:466.5	loss:2.55e+01, loss_r_u:5.40e+00, loss_d_u:8.53e-07
# Iter # 13100/50000	time:470.3	loss:5.32e+01, loss_r_u:7.60e+00, loss_d_u:5.49e-06
# Iter # 13200/50000	time:474.1	loss:8.14e+01, loss_r_u:7.46e+00, loss_d_u:5.56e-06
# Iter # 13300/50000	time:477.9	loss:1.14e+03, loss_r_u:8.79e+00, loss_d_u:1.63e-04
# Iter # 13400/50000	time:481.8	loss:2.93e+01, loss_r_u:6.33e+00, loss_d_u:1.45e-06
# Iter # 13500/50000	time:485.6	loss:8.16e+02, loss_r_u:8.70e+00, loss_d_u:7.17e-05
# Iter # 13600/50000	time:489.5	loss:5.45e+01, loss_r_u:7.29e+00, loss_d_u:7.58e-06
# Iter # 13700/50000	time:493.2	loss:3.72e+03, loss_r_u:7.04e+00, loss_d_u:5.16e-04
# Iter # 13800/50000	time:497.0	loss:2.79e+01, loss_r_u:5.99e+00, loss_d_u:1.45e-06
# Iter # 13900/50000	time:500.9	loss:6.17e+02, loss_r_u:1.09e+01, loss_d_u:6.92e-05
# Iter # 14000/50000	time:504.6	loss:3.11e+02, loss_r_u:8.30e+00, loss_d_u:3.31e-05
# Iter # 14100/50000	time:508.4	loss:9.47e+02, loss_r_u:1.01e+01, loss_d_u:1.23e-04
# Epoch 00141: reducing learning rate of group 0 to 6.0000e-04.
# Epoch 00141: reducing learning rate of group 0 to 6.0000e-04.
# Iter # 14200/50000	time:512.2	loss:2.75e+01, loss_r_u:6.02e+00, loss_d_u:1.18e-06
# Iter # 14300/50000	time:516.0	loss:2.51e+01, loss_r_u:5.36e+00, loss_d_u:5.21e-07
# Iter # 14400/50000	time:519.9	loss:2.35e+01, loss_r_u:5.13e+00, loss_d_u:3.19e-07
# Iter # 14500/50000	time:523.7	loss:2.22e+01, loss_r_u:5.00e+00, loss_d_u:2.48e-07
# Iter # 14600/50000	time:527.4	loss:2.11e+01, loss_r_u:4.88e+00, loss_d_u:2.18e-07
# Iter # 14700/50000	time:531.3	loss:2.01e+01, loss_r_u:4.74e+00, loss_d_u:2.04e-07
# Iter # 14800/50000	time:535.1	loss:1.92e+01, loss_r_u:4.59e+00, loss_d_u:1.96e-07
# Iter # 14900/50000	time:538.9	loss:1.84e+01, loss_r_u:4.43e+00, loss_d_u:1.93e-07
# Iter # 15000/50000	time:542.7	loss:1.76e+01, loss_r_u:4.26e+00, loss_d_u:1.91e-07
# Iter # 15100/50000	time:546.5	loss:1.68e+01, loss_r_u:4.09e+00, loss_d_u:1.91e-07
# Iter # 15200/50000	time:550.3	loss:2.20e+01, loss_r_u:3.92e+00, loss_d_u:6.60e-07
# Iter # 15300/50000	time:554.1	loss:1.96e+01, loss_r_u:4.35e+00, loss_d_u:6.44e-07
# Iter # 15400/50000	time:557.9	loss:3.99e+01, loss_r_u:4.10e+00, loss_d_u:6.06e-07
# Iter # 15500/50000	time:561.7	loss:1.63e+01, loss_r_u:3.63e+00, loss_d_u:1.69e-07
# Iter # 15600/50000	time:565.5	loss:2.02e+01, loss_r_u:4.00e+00, loss_d_u:6.55e-07
# Iter # 15700/50000	time:569.3	loss:4.87e+02, loss_r_u:4.95e+00, loss_d_u:4.43e-05
# Iter # 15800/50000	time:573.2	loss:4.56e+02, loss_r_u:4.05e+00, loss_d_u:5.82e-05
# Iter # 15900/50000	time:577.0	loss:1.59e+01, loss_r_u:3.46e+00, loss_d_u:5.48e-07
# Iter # 16000/50000	time:580.7	loss:3.43e+01, loss_r_u:3.90e+00, loss_d_u:1.54e-06
# Iter # 16100/50000	time:584.5	loss:2.50e+03, loss_r_u:7.82e+00, loss_d_u:2.26e-04
# Iter # 16200/50000	time:588.3	loss:2.10e+03, loss_r_u:5.12e+00, loss_d_u:2.84e-04
# Iter # 16300/50000	time:592.2	loss:1.51e+01, loss_r_u:3.24e+00, loss_d_u:4.75e-07
# Iter # 16400/50000	time:596.0	loss:2.29e+03, loss_r_u:4.34e+00, loss_d_u:3.26e-04
# Iter # 16500/50000	time:599.8	loss:1.50e+01, loss_r_u:3.26e+00, loss_d_u:7.01e-07
# Iter # 16600/50000	time:603.5	loss:2.78e+01, loss_r_u:3.29e+00, loss_d_u:1.45e-06
# Iter # 16700/50000	time:607.0	loss:6.27e+01, loss_r_u:2.94e+00, loss_d_u:6.21e-06
# Iter # 16800/50000	time:610.6	loss:1.45e+01, loss_r_u:3.06e+00, loss_d_u:5.49e-07
# Iter # 16900/50000	time:614.3	loss:2.05e+01, loss_r_u:3.35e+00, loss_d_u:5.31e-07
# Iter # 17000/50000	time:617.9	loss:1.42e+01, loss_r_u:2.90e+00, loss_d_u:3.89e-07
# Iter # 17100/50000	time:621.4	loss:3.26e+01, loss_r_u:3.08e+00, loss_d_u:1.98e-06
# Iter # 17200/50000	time:625.0	loss:4.04e+02, loss_r_u:3.17e+00, loss_d_u:4.91e-05
# Iter # 17300/50000	time:628.6	loss:1.74e+01, loss_r_u:2.62e+00, loss_d_u:1.62e-06
# Iter # 17400/50000	time:632.1	loss:1.32e+01, loss_r_u:2.73e+00, loss_d_u:5.94e-07
# Iter # 17500/50000	time:635.7	loss:1.51e+02, loss_r_u:2.76e+00, loss_d_u:2.26e-05
# Iter # 17600/50000	time:639.3	loss:4.16e+02, loss_r_u:3.57e+00, loss_d_u:5.38e-05
# Iter # 17700/50000	time:642.8	loss:1.20e+01, loss_r_u:2.42e+00, loss_d_u:4.41e-07
# Iter # 17800/50000	time:646.4	loss:3.85e+01, loss_r_u:2.92e+00, loss_d_u:2.47e-06
# Iter # 17900/50000	time:650.0	loss:1.20e+01, loss_r_u:2.35e+00, loss_d_u:4.13e-07
# Iter # 18000/50000	time:653.6	loss:2.31e+03, loss_r_u:2.66e+00, loss_d_u:3.47e-04
# Iter # 18100/50000	time:657.2	loss:1.20e+01, loss_r_u:2.24e+00, loss_d_u:3.18e-07
# Iter # 18200/50000	time:660.8	loss:1.52e+01, loss_r_u:2.47e+00, loss_d_u:6.96e-07
# Iter # 18300/50000	time:664.4	loss:8.00e+02, loss_r_u:3.66e+00, loss_d_u:7.08e-05
# Iter # 18400/50000	time:668.0	loss:6.42e+01, loss_r_u:2.21e+00, loss_d_u:6.52e-06
# Iter # 18500/50000	time:671.6	loss:3.69e+01, loss_r_u:2.03e+00, loss_d_u:5.68e-06
# Iter # 18600/50000	time:675.2	loss:1.47e+01, loss_r_u:2.07e+00, loss_d_u:7.37e-07
# Iter # 18700/50000	time:678.8	loss:4.83e+01, loss_r_u:2.06e+00, loss_d_u:8.23e-06
# Iter # 18800/50000	time:682.4	loss:4.78e+02, loss_r_u:2.34e+00, loss_d_u:5.62e-05
# Iter # 18900/50000	time:686.0	loss:1.19e+01, loss_r_u:1.90e+00, loss_d_u:5.09e-07
# Iter # 19000/50000	time:689.6	loss:1.97e+02, loss_r_u:2.28e+00, loss_d_u:2.45e-05
# Iter # 19100/50000	time:693.1	loss:5.82e+03, loss_r_u:3.61e+00, loss_d_u:8.51e-04
# Iter # 19200/50000	time:696.7	loss:9.73e+00, loss_r_u:1.78e+00, loss_d_u:4.15e-07
# Iter # 19300/50000	time:700.4	loss:1.35e+02, loss_r_u:2.62e+00, loss_d_u:1.25e-05
# Iter # 19400/50000	time:703.9	loss:2.61e+01, loss_r_u:1.86e+00, loss_d_u:1.80e-06
# Iter # 19500/50000	time:707.5	loss:7.04e+01, loss_r_u:1.37e+00, loss_d_u:9.13e-06
# Iter # 19600/50000	time:711.1	loss:9.06e+00, loss_r_u:1.61e+00, loss_d_u:4.75e-07
# Iter # 19700/50000	time:714.7	loss:9.40e+01, loss_r_u:1.64e+00, loss_d_u:1.12e-05
# Iter # 19800/50000	time:718.3	loss:9.38e+00, loss_r_u:1.53e+00, loss_d_u:3.74e-07
# Iter # 19900/50000	time:721.9	loss:5.48e+02, loss_r_u:4.31e+00, loss_d_u:6.86e-05
# Iter # 20000/50000	time:725.5	loss:8.65e+00, loss_r_u:1.51e+00, loss_d_u:6.60e-07
# Iter # 20100/50000	time:729.1	loss:6.24e+01, loss_r_u:1.77e+00, loss_d_u:9.30e-06
# Iter # 20200/50000	time:732.7	loss:8.02e+00, loss_r_u:1.30e+00, loss_d_u:2.76e-07
# Iter # 20300/50000	time:736.3	loss:1.90e+02, loss_r_u:1.53e+00, loss_d_u:3.43e-05
# Iter # 20400/50000	time:739.9	loss:7.77e+00, loss_r_u:1.30e+00, loss_d_u:4.09e-07
# Iter # 20500/50000	time:743.5	loss:5.23e+01, loss_r_u:1.46e+00, loss_d_u:4.76e-06
# Iter # 20600/50000	time:747.1	loss:7.99e+00, loss_r_u:1.25e+00, loss_d_u:7.42e-07
# Iter # 20700/50000	time:750.6	loss:1.54e+03, loss_r_u:1.34e+00, loss_d_u:2.45e-04
# Iter # 20800/50000	time:754.2	loss:7.24e+00, loss_r_u:1.16e+00, loss_d_u:4.27e-07
# Iter # 20900/50000	time:757.8	loss:7.63e+02, loss_r_u:1.11e+00, loss_d_u:1.19e-04
# Iter # 21000/50000	time:761.4	loss:7.15e+00, loss_r_u:1.06e+00, loss_d_u:5.32e-07
# Iter # 21100/50000	time:765.0	loss:1.22e+01, loss_r_u:1.63e+00, loss_d_u:2.93e-06
# Iter # 21200/50000	time:768.6	loss:6.95e+00, loss_r_u:1.03e+00, loss_d_u:4.45e-07
# Iter # 21300/50000	time:772.2	loss:1.85e+02, loss_r_u:1.85e+00, loss_d_u:1.02e-05
# Iter # 21400/50000	time:775.8	loss:5.00e+01, loss_r_u:1.06e+00, loss_d_u:5.22e-06
# Iter # 21500/50000	time:779.4	loss:9.05e+00, loss_r_u:8.69e-01, loss_d_u:1.08e-06
# Iter # 21600/50000	time:782.9	loss:7.90e+00, loss_r_u:9.38e-01, loss_d_u:1.17e-06
# Iter # 21700/50000	time:786.5	loss:1.20e+01, loss_r_u:9.43e-01, loss_d_u:7.10e-07
# Iter # 21800/50000	time:790.0	loss:6.49e+00, loss_r_u:8.65e-01, loss_d_u:6.94e-07
# Iter # 21900/50000	time:793.6	loss:5.09e+02, loss_r_u:1.70e+00, loss_d_u:6.90e-05
# Iter # 22000/50000	time:797.2	loss:1.62e+03, loss_r_u:4.22e+00, loss_d_u:1.42e-04
# Iter # 22100/50000	time:800.8	loss:4.94e+02, loss_r_u:8.58e-01, loss_d_u:7.30e-05
# Iter # 22200/50000	time:804.4	loss:5.95e+00, loss_r_u:7.26e-01, loss_d_u:2.38e-07
# Iter # 22300/50000	time:808.0	loss:8.45e+00, loss_r_u:7.44e-01, loss_d_u:1.38e-06
# Iter # 22400/50000	time:811.6	loss:1.22e+01, loss_r_u:7.60e-01, loss_d_u:1.36e-06
# Iter # 22500/50000	time:815.2	loss:5.74e+00, loss_r_u:7.14e-01, loss_d_u:6.09e-07
# Iter # 22600/50000	time:818.8	loss:7.63e+02, loss_r_u:1.11e+00, loss_d_u:1.06e-04
# Iter # 22700/50000	time:822.4	loss:5.67e+00, loss_r_u:6.90e-01, loss_d_u:6.86e-07
# Iter # 22800/50000	time:826.0	loss:2.12e+01, loss_r_u:9.43e-01, loss_d_u:1.89e-06
# Iter # 22900/50000	time:829.6	loss:3.27e+02, loss_r_u:1.03e+00, loss_d_u:4.25e-05
# Iter # 23000/50000	time:833.2	loss:4.97e+00, loss_r_u:5.55e-01, loss_d_u:3.44e-07
# Iter # 23100/50000	time:836.8	loss:1.12e+01, loss_r_u:7.28e-01, loss_d_u:6.85e-07
# Iter # 23200/50000	time:840.4	loss:1.06e+01, loss_r_u:6.35e-01, loss_d_u:8.32e-07
# Iter # 23300/50000	time:844.0	loss:1.06e+01, loss_r_u:5.97e-01, loss_d_u:2.09e-06
# Iter # 23400/50000	time:847.6	loss:3.97e+03, loss_r_u:2.41e+00, loss_d_u:5.69e-04
# Iter # 23500/50000	time:851.2	loss:6.78e+00, loss_r_u:5.18e-01, loss_d_u:5.66e-07
# Iter # 23600/50000	time:854.8	loss:2.44e+03, loss_r_u:1.16e+00, loss_d_u:3.67e-04
# Iter # 23700/50000	time:858.4	loss:4.89e+00, loss_r_u:4.71e-01, loss_d_u:4.56e-07
# Iter # 23800/50000	time:861.9	loss:2.17e+03, loss_r_u:1.35e+00, loss_d_u:3.49e-04
# Iter # 23900/50000	time:865.5	loss:4.76e+00, loss_r_u:4.57e-01, loss_d_u:3.87e-07
# Iter # 24000/50000	time:869.1	loss:1.53e+01, loss_r_u:5.52e-01, loss_d_u:1.81e-06
# Iter # 24100/50000	time:872.7	loss:4.21e+00, loss_r_u:3.79e-01, loss_d_u:1.72e-07
# Iter # 24200/50000	time:876.3	loss:4.96e+01, loss_r_u:6.68e-01, loss_d_u:1.09e-05
# Iter # 24300/50000	time:879.9	loss:5.00e+00, loss_r_u:3.98e-01, loss_d_u:3.28e-07
# Iter # 24400/50000	time:883.4	loss:4.81e+00, loss_r_u:3.71e-01, loss_d_u:2.35e-07
# Iter # 24500/50000	time:887.0	loss:2.30e+01, loss_r_u:5.25e-01, loss_d_u:2.73e-06
# Iter # 24600/50000	time:890.7	loss:2.10e+02, loss_r_u:6.50e-01, loss_d_u:2.31e-05
# Iter # 24700/50000	time:894.2	loss:2.89e+02, loss_r_u:3.72e-01, loss_d_u:4.46e-05
# Iter # 24800/50000	time:897.9	loss:4.11e+00, loss_r_u:3.39e-01, loss_d_u:2.17e-07
# Iter # 24900/50000	time:901.5	loss:1.13e+01, loss_r_u:3.93e-01, loss_d_u:8.13e-07
# Iter # 25000/50000	time:905.1	loss:3.01e+01, loss_r_u:7.62e-01, loss_d_u:9.15e-07
# Iter # 25100/50000	time:908.7	loss:4.44e+00, loss_r_u:3.50e-01, loss_d_u:4.89e-07
# Iter # 25200/50000	time:912.3	loss:5.08e+03, loss_r_u:3.93e+00, loss_d_u:7.26e-04
# Iter # 25300/50000	time:915.9	loss:4.30e+00, loss_r_u:3.43e-01, loss_d_u:3.32e-07
# Iter # 25400/50000	time:919.5	loss:7.81e+00, loss_r_u:3.58e-01, loss_d_u:8.07e-07
# Iter # 25500/50000	time:923.1	loss:2.58e+01, loss_r_u:3.91e-01, loss_d_u:1.94e-06
# Iter # 25600/50000	time:926.6	loss:4.02e+00, loss_r_u:2.98e-01, loss_d_u:2.22e-07
# Iter # 25700/50000	time:930.2	loss:5.78e+02, loss_r_u:8.28e-01, loss_d_u:8.28e-05
# Iter # 25800/50000	time:933.8	loss:4.16e+00, loss_r_u:2.83e-01, loss_d_u:3.33e-07
# Iter # 25900/50000	time:937.4	loss:3.01e+02, loss_r_u:1.06e+00, loss_d_u:3.25e-05
# Iter # 26000/50000	time:941.0	loss:6.73e+00, loss_r_u:2.97e-01, loss_d_u:4.04e-07
# Iter # 26100/50000	time:944.6	loss:5.52e+02, loss_r_u:6.73e-01, loss_d_u:7.87e-05
# Iter # 26200/50000	time:948.2	loss:3.91e+00, loss_r_u:2.75e-01, loss_d_u:2.02e-07
# Iter # 26300/50000	time:951.8	loss:6.28e+00, loss_r_u:4.33e-01, loss_d_u:5.29e-07
# Iter # 26400/50000	time:955.4	loss:2.84e+02, loss_r_u:6.38e-01, loss_d_u:3.35e-05
# Iter # 26500/50000	time:959.0	loss:6.95e+02, loss_r_u:8.49e-01, loss_d_u:9.83e-05
# Iter # 26600/50000	time:962.6	loss:5.63e+00, loss_r_u:2.65e-01, loss_d_u:2.42e-07
# Iter # 26700/50000	time:966.2	loss:5.70e+00, loss_r_u:2.95e-01, loss_d_u:8.17e-07
# Iter # 26800/50000	time:969.8	loss:1.13e+01, loss_r_u:4.37e-01, loss_d_u:7.26e-07
# Iter # 26900/50000	time:973.4	loss:2.25e+01, loss_r_u:3.32e-01, loss_d_u:4.04e-06
# Iter # 27000/50000	time:977.0	loss:5.13e+00, loss_r_u:2.47e-01, loss_d_u:4.18e-07
# Iter # 27100/50000	time:980.6	loss:5.36e+00, loss_r_u:3.07e-01, loss_d_u:7.68e-07
# Iter # 27200/50000	time:984.1	loss:4.39e+01, loss_r_u:5.74e-01, loss_d_u:3.72e-06
# Iter # 27300/50000	time:987.7	loss:6.68e+00, loss_r_u:3.53e-01, loss_d_u:3.12e-07
# Epoch 00273: reducing learning rate of group 0 to 3.6000e-04.
# Epoch 00273: reducing learning rate of group 0 to 3.6000e-04.
# Iter # 27400/50000	time:991.3	loss:3.86e+00, loss_r_u:2.67e-01, loss_d_u:1.32e-07
# Iter # 27500/50000	time:994.9	loss:3.68e+00, loss_r_u:2.52e-01, loss_d_u:8.52e-08
# Iter # 27600/50000	time:998.5	loss:3.56e+00, loss_r_u:2.48e-01, loss_d_u:7.12e-08
# Iter # 27700/50000	time:1002.1	loss:3.45e+00, loss_r_u:2.47e-01, loss_d_u:6.50e-08
# Iter # 27800/50000	time:1005.7	loss:3.34e+00, loss_r_u:2.47e-01, loss_d_u:6.12e-08
# Iter # 27900/50000	time:1009.3	loss:3.25e+00, loss_r_u:2.48e-01, loss_d_u:5.76e-08
# Iter # 28000/50000	time:1012.9	loss:3.16e+00, loss_r_u:2.48e-01, loss_d_u:5.45e-08
# Iter # 28100/50000	time:1016.5	loss:3.08e+00, loss_r_u:2.50e-01, loss_d_u:5.18e-08
# Iter # 28200/50000	time:1020.1	loss:3.00e+00, loss_r_u:2.51e-01, loss_d_u:4.93e-08
# Iter # 28300/50000	time:1023.7	loss:2.93e+00, loss_r_u:2.53e-01, loss_d_u:4.70e-08
# Iter # 28400/50000	time:1027.2	loss:2.88e+00, loss_r_u:2.55e-01, loss_d_u:5.33e-08
# Iter # 28500/50000	time:1030.8	loss:3.80e+00, loss_r_u:3.12e-01, loss_d_u:2.52e-07
# Iter # 28600/50000	time:1034.4	loss:2.97e+00, loss_r_u:2.61e-01, loss_d_u:5.74e-08
# Iter # 28700/50000	time:1038.0	loss:3.46e+00, loss_r_u:2.76e-01, loss_d_u:1.16e-07
# Iter # 28800/50000	time:1041.6	loss:2.14e+02, loss_r_u:3.49e-01, loss_d_u:3.16e-05
# Iter # 28900/50000	time:1045.2	loss:2.91e+00, loss_r_u:2.70e-01, loss_d_u:5.05e-08
# Iter # 29000/50000	time:1048.8	loss:5.50e+02, loss_r_u:1.38e+00, loss_d_u:5.10e-05
# Iter # 29100/50000	time:1052.3	loss:2.93e+00, loss_r_u:2.82e-01, loss_d_u:7.43e-08
# Iter # 29200/50000	time:1055.9	loss:4.96e+00, loss_r_u:2.96e-01, loss_d_u:2.55e-07
# Iter # 29300/50000	time:1059.5	loss:3.30e+00, loss_r_u:2.73e-01, loss_d_u:8.90e-08
# Iter # 29400/50000	time:1063.0	loss:2.99e+00, loss_r_u:2.93e-01, loss_d_u:1.08e-07
# Iter # 29500/50000	time:1066.6	loss:8.95e+00, loss_r_u:4.08e-01, loss_d_u:7.45e-08
# Epoch 00295: reducing learning rate of group 0 to 2.1600e-04.
# Epoch 00295: reducing learning rate of group 0 to 2.1600e-04.
# Iter # 29600/50000	time:1070.2	loss:2.79e+00, loss_r_u:2.82e-01, loss_d_u:4.02e-08
# Iter # 29700/50000	time:1073.9	loss:2.75e+00, loss_r_u:2.77e-01, loss_d_u:3.68e-08
# Iter # 29800/50000	time:1077.5	loss:2.71e+00, loss_r_u:2.75e-01, loss_d_u:3.51e-08
# Iter # 29900/50000	time:1081.1	loss:2.67e+00, loss_r_u:2.76e-01, loss_d_u:3.40e-08
# Iter # 30000/50000	time:1084.7	loss:2.64e+00, loss_r_u:2.76e-01, loss_d_u:3.31e-08
# Iter # 30100/50000	time:1088.3	loss:2.60e+00, loss_r_u:2.78e-01, loss_d_u:3.22e-08
# Iter # 30200/50000	time:1091.9	loss:2.57e+00, loss_r_u:2.79e-01, loss_d_u:3.14e-08
# Iter # 30300/50000	time:1095.5	loss:2.53e+00, loss_r_u:2.81e-01, loss_d_u:3.06e-08
# Iter # 30400/50000	time:1099.1	loss:2.50e+00, loss_r_u:2.83e-01, loss_d_u:2.99e-08
# Iter # 30500/50000	time:1102.7	loss:2.46e+00, loss_r_u:2.84e-01, loss_d_u:2.91e-08
# Iter # 30600/50000	time:1106.3	loss:7.75e+02, loss_r_u:7.44e-01, loss_d_u:1.08e-04
# Iter # 30700/50000	time:1109.9	loss:2.48e+00, loss_r_u:2.92e-01, loss_d_u:3.13e-08
# Iter # 30800/50000	time:1113.5	loss:2.44e+00, loss_r_u:2.89e-01, loss_d_u:2.76e-08
# Iter # 30900/50000	time:1117.1	loss:1.22e+02, loss_r_u:5.73e-01, loss_d_u:1.17e-05
# Iter # 31000/50000	time:1120.7	loss:2.41e+00, loss_r_u:3.00e-01, loss_d_u:2.84e-08
# Iter # 31100/50000	time:1124.3	loss:3.32e+00, loss_r_u:3.02e-01, loss_d_u:1.91e-07
# Iter # 31200/50000	time:1127.9	loss:2.37e+00, loss_r_u:2.94e-01, loss_d_u:2.62e-08
# Iter # 31300/50000	time:1131.5	loss:1.06e+03, loss_r_u:1.05e+00, loss_d_u:1.50e-04
# Iter # 31400/50000	time:1135.1	loss:2.42e+00, loss_r_u:3.02e-01, loss_d_u:3.05e-08
# Iter # 31500/50000	time:1138.7	loss:2.36e+00, loss_r_u:2.94e-01, loss_d_u:2.47e-08
# Iter # 31600/50000	time:1142.3	loss:2.82e+00, loss_r_u:3.05e-01, loss_d_u:5.02e-08
# Iter # 31700/50000	time:1145.8	loss:1.83e+02, loss_r_u:6.49e-01, loss_d_u:1.86e-05
# Iter # 31800/50000	time:1149.4	loss:2.57e+01, loss_r_u:3.06e-01, loss_d_u:3.52e-06
# Iter # 31900/50000	time:1153.0	loss:5.10e+01, loss_r_u:3.44e-01, loss_d_u:6.71e-06
# Iter # 32000/50000	time:1156.6	loss:1.49e+01, loss_r_u:3.36e-01, loss_d_u:1.14e-06
# Iter # 32100/50000	time:1160.2	loss:3.40e+00, loss_r_u:3.01e-01, loss_d_u:1.60e-07
# Iter # 32200/50000	time:1163.4	loss:4.17e+02, loss_r_u:1.04e+00, loss_d_u:4.90e-05
# Iter # 32300/50000	time:1166.5	loss:2.26e+00, loss_r_u:3.02e-01, loss_d_u:2.25e-08
# Iter # 32400/50000	time:1169.6	loss:2.28e+00, loss_r_u:3.00e-01, loss_d_u:3.20e-08
# Iter # 32500/50000	time:1172.7	loss:2.23e+00, loss_r_u:2.94e-01, loss_d_u:2.04e-08
# Iter # 32600/50000	time:1175.9	loss:2.37e+00, loss_r_u:3.09e-01, loss_d_u:4.50e-08
# Iter # 32700/50000	time:1179.0	loss:2.80e+02, loss_r_u:5.38e-01, loss_d_u:3.87e-05
# Iter # 32800/50000	time:1182.2	loss:2.21e+00, loss_r_u:2.95e-01, loss_d_u:1.92e-08
# Iter # 32900/50000	time:1185.3	loss:1.38e+02, loss_r_u:8.57e-01, loss_d_u:1.57e-05
# Iter # 33000/50000	time:1188.5	loss:2.18e+00, loss_r_u:3.00e-01, loss_d_u:2.18e-08
# Iter # 33100/50000	time:1191.7	loss:3.08e+01, loss_r_u:3.53e-01, loss_d_u:2.88e-06
# Iter # 33200/50000	time:1194.8	loss:2.15e+00, loss_r_u:2.93e-01, loss_d_u:1.93e-08
# Iter # 33300/50000	time:1198.0	loss:7.53e+00, loss_r_u:3.22e-01, loss_d_u:6.52e-07
# Iter # 33400/50000	time:1201.1	loss:2.14e+00, loss_r_u:2.94e-01, loss_d_u:2.02e-08
# Iter # 33500/50000	time:1204.2	loss:2.52e+00, loss_r_u:2.97e-01, loss_d_u:7.14e-08
# Iter # 33600/50000	time:1207.4	loss:9.69e+00, loss_r_u:3.04e-01, loss_d_u:1.15e-06
# Iter # 33700/50000	time:1210.6	loss:2.11e+00, loss_r_u:2.92e-01, loss_d_u:1.84e-08
# Iter # 33800/50000	time:1213.7	loss:6.50e+01, loss_r_u:3.53e-01, loss_d_u:9.23e-06
# Iter # 33900/50000	time:1216.8	loss:4.27e+00, loss_r_u:2.94e-01, loss_d_u:3.14e-07
# Iter # 34000/50000	time:1220.0	loss:2.18e+00, loss_r_u:2.93e-01, loss_d_u:2.55e-08
# Iter # 34100/50000	time:1223.1	loss:1.44e+01, loss_r_u:2.98e-01, loss_d_u:1.94e-06
# Iter # 34200/50000	time:1226.2	loss:5.50e+01, loss_r_u:4.14e-01, loss_d_u:4.37e-06
# Iter # 34300/50000	time:1229.3	loss:3.42e+01, loss_r_u:3.28e-01, loss_d_u:4.37e-06
# Iter # 34400/50000	time:1232.4	loss:2.05e+00, loss_r_u:2.88e-01, loss_d_u:1.66e-08
# Iter # 34500/50000	time:1235.6	loss:8.47e+00, loss_r_u:3.02e-01, loss_d_u:8.96e-07
# Iter # 34600/50000	time:1238.7	loss:8.06e+00, loss_r_u:2.93e-01, loss_d_u:8.70e-07
# Iter # 34700/50000	time:1241.9	loss:2.12e+00, loss_r_u:2.91e-01, loss_d_u:2.05e-08
# Iter # 34800/50000	time:1245.0	loss:2.02e+00, loss_r_u:2.85e-01, loss_d_u:1.55e-08
# Iter # 34900/50000	time:1248.1	loss:4.75e+01, loss_r_u:3.46e-01, loss_d_u:6.48e-06
# Iter # 35000/50000	time:1251.2	loss:2.02e+00, loss_r_u:2.89e-01, loss_d_u:1.69e-08
# Iter # 35100/50000	time:1254.3	loss:1.57e+01, loss_r_u:2.97e-01, loss_d_u:1.95e-06
# Iter # 35200/50000	time:1257.4	loss:2.00e+00, loss_r_u:2.83e-01, loss_d_u:1.58e-08
# Iter # 35300/50000	time:1260.6	loss:1.10e+01, loss_r_u:3.10e-01, loss_d_u:1.13e-06
# Iter # 35400/50000	time:1263.7	loss:1.99e+00, loss_r_u:2.82e-01, loss_d_u:1.62e-08
# Iter # 35500/50000	time:1266.8	loss:3.78e+00, loss_r_u:2.99e-01, loss_d_u:1.86e-07
# Iter # 35600/50000	time:1269.9	loss:2.01e+00, loss_r_u:2.84e-01, loss_d_u:1.73e-08
# Iter # 35700/50000	time:1273.1	loss:2.30e+00, loss_r_u:2.88e-01, loss_d_u:8.31e-08
# Iter # 35800/50000	time:1276.3	loss:3.31e+01, loss_r_u:3.59e-01, loss_d_u:2.76e-06
# Iter # 35900/50000	time:1279.4	loss:2.76e+00, loss_r_u:2.86e-01, loss_d_u:7.25e-08
# Iter # 36000/50000	time:1282.5	loss:2.28e+00, loss_r_u:2.79e-01, loss_d_u:6.86e-08
# Iter # 36100/50000	time:1285.7	loss:1.96e+00, loss_r_u:2.86e-01, loss_d_u:2.15e-08
# Iter # 36200/50000	time:1288.8	loss:3.12e+00, loss_r_u:2.81e-01, loss_d_u:1.27e-07
# Iter # 36300/50000	time:1291.8	loss:2.93e+01, loss_r_u:2.93e-01, loss_d_u:3.97e-06
# Iter # 36400/50000	time:1295.0	loss:2.00e+00, loss_r_u:2.79e-01, loss_d_u:2.00e-08
# Iter # 36500/50000	time:1298.2	loss:4.77e+01, loss_r_u:3.40e-01, loss_d_u:4.67e-06
# Iter # 36600/50000	time:1301.2	loss:2.06e+02, loss_r_u:3.88e-01, loss_d_u:2.98e-05
# Iter # 36700/50000	time:1304.4	loss:2.39e+00, loss_r_u:2.75e-01, loss_d_u:9.55e-08
# Iter # 36800/50000	time:1307.5	loss:2.10e+00, loss_r_u:2.79e-01, loss_d_u:5.88e-08
# Iter # 36900/50000	time:1310.7	loss:2.10e+01, loss_r_u:3.59e-01, loss_d_u:1.54e-06
# Iter # 37000/50000	time:1313.9	loss:7.80e+02, loss_r_u:7.88e-01, loss_d_u:1.14e-04
# Iter # 37100/50000	time:1317.0	loss:1.89e+00, loss_r_u:2.73e-01, loss_d_u:1.72e-08
# Iter # 37200/50000	time:1320.1	loss:4.17e+01, loss_r_u:3.30e-01, loss_d_u:3.83e-06
# Iter # 37300/50000	time:1323.2	loss:1.97e+00, loss_r_u:2.76e-01, loss_d_u:2.10e-08
# Iter # 37400/50000	time:1326.4	loss:1.04e+02, loss_r_u:3.19e-01, loss_d_u:1.56e-05
# Iter # 37500/50000	time:1329.5	loss:1.86e+00, loss_r_u:2.70e-01, loss_d_u:1.36e-08
# Iter # 37600/50000	time:1332.6	loss:5.63e+01, loss_r_u:3.34e-01, loss_d_u:7.35e-06
# Iter # 37700/50000	time:1335.8	loss:5.58e+01, loss_r_u:3.04e-01, loss_d_u:7.77e-06
# Iter # 37800/50000	time:1338.9	loss:1.90e+00, loss_r_u:2.70e-01, loss_d_u:1.65e-08
# Iter # 37900/50000	time:1342.0	loss:1.32e+01, loss_r_u:2.91e-01, loss_d_u:1.39e-06
# Iter # 38000/50000	time:1345.2	loss:2.90e+00, loss_r_u:2.73e-01, loss_d_u:1.37e-07
# Iter # 38100/50000	time:1348.4	loss:3.37e+01, loss_r_u:2.79e-01, loss_d_u:4.88e-06
# Iter # 38200/50000	time:1351.5	loss:2.88e+00, loss_r_u:2.67e-01, loss_d_u:1.37e-07
# Iter # 38300/50000	time:1354.7	loss:1.29e+01, loss_r_u:2.71e-01, loss_d_u:1.71e-06
# Iter # 38400/50000	time:1357.8	loss:1.84e+00, loss_r_u:2.64e-01, loss_d_u:2.00e-08
# Iter # 38500/50000	time:1360.9	loss:2.29e+00, loss_r_u:2.70e-01, loss_d_u:6.14e-08
# Iter # 38600/50000	time:1364.1	loss:5.01e+00, loss_r_u:2.96e-01, loss_d_u:2.15e-07
# Iter # 38700/50000	time:1367.2	loss:3.90e+01, loss_r_u:4.74e-01, loss_d_u:3.63e-06
# Iter # 38800/50000	time:1370.3	loss:1.80e+00, loss_r_u:2.61e-01, loss_d_u:1.24e-08
# Iter # 38900/50000	time:1373.5	loss:1.19e+01, loss_r_u:2.79e-01, loss_d_u:1.21e-06
# Iter # 39000/50000	time:1376.7	loss:2.96e+00, loss_r_u:2.65e-01, loss_d_u:2.15e-07
# Iter # 39100/50000	time:1379.8	loss:2.87e+01, loss_r_u:3.01e-01, loss_d_u:3.59e-06
# Iter # 39200/50000	time:1382.9	loss:1.78e+00, loss_r_u:2.59e-01, loss_d_u:1.22e-08
# Iter # 39300/50000	time:1386.1	loss:5.19e+00, loss_r_u:2.61e-01, loss_d_u:5.60e-07
# Iter # 39400/50000	time:1389.2	loss:2.49e+01, loss_r_u:2.71e-01, loss_d_u:3.31e-06
# Iter # 39500/50000	time:1392.3	loss:1.89e+00, loss_r_u:2.59e-01, loss_d_u:2.58e-08
# Iter # 39600/50000	time:1395.5	loss:1.95e+00, loss_r_u:2.60e-01, loss_d_u:3.30e-08
# Iter # 39700/50000	time:1398.5	loss:1.80e+00, loss_r_u:2.58e-01, loss_d_u:1.76e-08
# Iter # 39800/50000	time:1401.6	loss:9.27e+01, loss_r_u:4.55e-01, loss_d_u:9.24e-06
# Iter # 39900/50000	time:1404.8	loss:3.63e+00, loss_r_u:2.63e-01, loss_d_u:2.48e-07
# Iter # 40000/50000	time:1407.9	loss:4.19e+00, loss_r_u:2.57e-01, loss_d_u:4.27e-07
# Iter # 40100/50000	time:1411.0	loss:2.56e+00, loss_r_u:2.71e-01, loss_d_u:8.09e-08
# Iter # 40200/50000	time:1414.1	loss:5.61e+00, loss_r_u:2.71e-01, loss_d_u:1.91e-07
# Iter # 40300/50000	time:1417.2	loss:3.85e+00, loss_r_u:2.62e-01, loss_d_u:2.38e-07
# Epoch 00403: reducing learning rate of group 0 to 1.2960e-04.
# Epoch 00403: reducing learning rate of group 0 to 1.2960e-04.
# Iter # 40400/50000	time:1420.4	loss:1.72e+00, loss_r_u:2.53e-01, loss_d_u:1.15e-08
# Iter # 40500/50000	time:1423.5	loss:1.71e+00, loss_r_u:2.50e-01, loss_d_u:1.05e-08
# Iter # 40600/50000	time:1426.6	loss:1.70e+00, loss_r_u:2.49e-01, loss_d_u:1.01e-08
# Iter # 40700/50000	time:1429.8	loss:1.69e+00, loss_r_u:2.48e-01, loss_d_u:9.97e-09
# Iter # 40800/50000	time:1433.0	loss:1.68e+00, loss_r_u:2.47e-01, loss_d_u:9.87e-09
# Iter # 40900/50000	time:1436.2	loss:1.67e+00, loss_r_u:2.47e-01, loss_d_u:9.76e-09
# Iter # 41000/50000	time:1439.3	loss:1.65e+00, loss_r_u:2.46e-01, loss_d_u:9.66e-09
# Iter # 41100/50000	time:1442.5	loss:1.64e+00, loss_r_u:2.46e-01, loss_d_u:9.56e-09
# Iter # 41200/50000	time:1445.6	loss:1.63e+00, loss_r_u:2.46e-01, loss_d_u:9.46e-09
# Iter # 41300/50000	time:1448.7	loss:1.62e+00, loss_r_u:2.45e-01, loss_d_u:9.34e-09
# Iter # 41400/50000	time:1451.8	loss:1.62e+00, loss_r_u:2.45e-01, loss_d_u:9.71e-09
# Iter # 41500/50000	time:1455.0	loss:1.68e+00, loss_r_u:2.43e-01, loss_d_u:2.24e-08
# Iter # 41600/50000	time:1458.2	loss:1.77e+00, loss_r_u:2.51e-01, loss_d_u:1.09e-08
# Iter # 41700/50000	time:1461.4	loss:4.39e+00, loss_r_u:2.45e-01, loss_d_u:3.40e-07
# Iter # 41800/50000	time:1464.5	loss:1.59e+00, loss_r_u:2.44e-01, loss_d_u:8.69e-09
# Iter # 41900/50000	time:1467.6	loss:1.67e+00, loss_r_u:2.47e-01, loss_d_u:2.47e-08
# Iter # 42000/50000	time:1470.8	loss:1.73e+00, loss_r_u:2.45e-01, loss_d_u:2.48e-08
# Iter # 42100/50000	time:1473.9	loss:2.57e+00, loss_r_u:2.44e-01, loss_d_u:1.41e-07
# Iter # 42200/50000	time:1477.0	loss:1.61e+00, loss_r_u:2.44e-01, loss_d_u:1.19e-08
# Iter # 42300/50000	time:1480.1	loss:1.57e+00, loss_r_u:2.44e-01, loss_d_u:9.17e-09
# Iter # 42400/50000	time:1483.2	loss:2.42e+00, loss_r_u:2.44e-01, loss_d_u:1.09e-07
# Iter # 42500/50000	time:1486.3	loss:1.86e+01, loss_r_u:2.79e-01, loss_d_u:1.68e-06
# Iter # 42600/50000	time:1489.5	loss:6.16e+00, loss_r_u:2.44e-01, loss_d_u:7.19e-07
# Iter # 42700/50000	time:1492.7	loss:2.09e+00, loss_r_u:2.42e-01, loss_d_u:7.52e-08
# Iter # 42800/50000	time:1495.9	loss:7.56e+01, loss_r_u:4.02e-01, loss_d_u:6.66e-06
# Iter # 42900/50000	time:1499.0	loss:6.00e+01, loss_r_u:2.77e-01, loss_d_u:8.47e-06
# Iter # 43000/50000	time:1502.1	loss:3.28e+00, loss_r_u:2.41e-01, loss_d_u:2.45e-07
# Iter # 43100/50000	time:1505.2	loss:8.42e+01, loss_r_u:3.81e-01, loss_d_u:7.51e-06
# Iter # 43200/50000	time:1508.3	loss:3.82e+02, loss_r_u:4.55e-01, loss_d_u:5.51e-05
# Iter # 43300/50000	time:1511.4	loss:1.50e+00, loss_r_u:2.38e-01, loss_d_u:9.57e-09
# Iter # 43400/50000	time:1514.6	loss:4.48e+00, loss_r_u:2.59e-01, loss_d_u:2.46e-07
# Iter # 43500/50000	time:1517.7	loss:1.71e+02, loss_r_u:3.31e-01, loss_d_u:2.49e-05
# Iter # 43600/50000	time:1520.8	loss:1.48e+00, loss_r_u:2.37e-01, loss_d_u:9.95e-09
# Iter # 43700/50000	time:1524.0	loss:1.79e+02, loss_r_u:4.94e-01, loss_d_u:2.05e-05
# Iter # 43800/50000	time:1527.1	loss:1.55e+00, loss_r_u:2.38e-01, loss_d_u:2.60e-08
# Iter # 43900/50000	time:1530.3	loss:1.56e+00, loss_r_u:2.36e-01, loss_d_u:2.80e-08
# Iter # 44000/50000	time:1533.5	loss:3.28e+01, loss_r_u:3.04e-01, loss_d_u:4.31e-06
# Iter # 44100/50000	time:1536.7	loss:1.44e+00, loss_r_u:2.34e-01, loss_d_u:9.33e-09
# Iter # 44200/50000	time:1539.8	loss:1.48e+00, loss_r_u:2.37e-01, loss_d_u:9.60e-09
# Iter # 44300/50000	time:1543.0	loss:1.50e+00, loss_r_u:2.34e-01, loss_d_u:1.90e-08
# Iter # 44400/50000	time:1546.1	loss:1.42e+00, loss_r_u:2.32e-01, loss_d_u:8.34e-09
# Iter # 44500/50000	time:1549.2	loss:3.24e+01, loss_r_u:2.53e-01, loss_d_u:4.08e-06
# Iter # 44600/50000	time:1552.4	loss:1.42e+00, loss_r_u:2.33e-01, loss_d_u:9.00e-09
# Iter # 44700/50000	time:1555.5	loss:1.85e+01, loss_r_u:2.48e-01, loss_d_u:2.44e-06
# Iter # 44800/50000	time:1558.7	loss:1.41e+00, loss_r_u:2.31e-01, loss_d_u:8.05e-09
# Iter # 44900/50000	time:1561.9	loss:2.87e+01, loss_r_u:2.44e-01, loss_d_u:4.15e-06
# Iter # 45000/50000	time:1565.1	loss:5.06e+00, loss_r_u:2.36e-01, loss_d_u:3.61e-07
# Iter # 45100/50000	time:1568.2	loss:3.84e+00, loss_r_u:2.30e-01, loss_d_u:2.81e-07
# Iter # 45200/50000	time:1571.3	loss:1.40e+00, loss_r_u:2.28e-01, loss_d_u:8.00e-09
# Iter # 45300/50000	time:1574.5	loss:7.90e+01, loss_r_u:2.81e-01, loss_d_u:1.13e-05
# Iter # 45400/50000	time:1577.7	loss:6.95e+01, loss_r_u:2.71e-01, loss_d_u:9.97e-06
# Iter # 45500/50000	time:1580.9	loss:5.20e+00, loss_r_u:2.55e-01, loss_d_u:4.56e-08
# Iter # 45600/50000	time:1584.0	loss:3.03e+01, loss_r_u:2.68e-01, loss_d_u:3.00e-06
# Iter # 45700/50000	time:1587.2	loss:1.54e+02, loss_r_u:3.12e-01, loss_d_u:2.22e-05
# Iter # 45800/50000	time:1590.3	loss:1.36e+00, loss_r_u:2.25e-01, loss_d_u:1.05e-08
# Iter # 45900/50000	time:1593.5	loss:2.10e+01, loss_r_u:2.36e-01, loss_d_u:2.96e-06
# Iter # 46000/50000	time:1596.6	loss:1.34e+00, loss_r_u:2.24e-01, loss_d_u:9.13e-09
# Iter # 46100/50000	time:1599.7	loss:1.57e+00, loss_r_u:2.26e-01, loss_d_u:4.87e-08
# Iter # 46200/50000	time:1602.9	loss:1.34e+00, loss_r_u:2.24e-01, loss_d_u:9.41e-09
# Iter # 46300/50000	time:1605.9	loss:1.36e+00, loss_r_u:2.24e-01, loss_d_u:1.05e-08
# Iter # 46400/50000	time:1608.9	loss:1.40e+00, loss_r_u:2.22e-01, loss_d_u:2.27e-08
# Iter # 46500/50000	time:1612.1	loss:6.18e+00, loss_r_u:2.30e-01, loss_d_u:4.42e-07
# Iter # 46600/50000	time:1615.1	loss:1.66e+02, loss_r_u:3.19e-01, loss_d_u:2.41e-05
# Iter # 46700/50000	time:1618.2	loss:1.31e+00, loss_r_u:2.21e-01, loss_d_u:7.80e-09
# Iter # 46800/50000	time:1621.4	loss:9.31e+00, loss_r_u:2.26e-01, loss_d_u:1.04e-06
# Iter # 46900/50000	time:1624.5	loss:1.32e+01, loss_r_u:2.71e-01, loss_d_u:7.13e-07
# Iter # 47000/50000	time:1627.7	loss:4.42e+01, loss_r_u:2.41e-01, loss_d_u:6.45e-06
# Iter # 47100/50000	time:1630.9	loss:1.29e+00, loss_r_u:2.19e-01, loss_d_u:8.57e-09
# Iter # 47200/50000	time:1634.0	loss:3.70e+01, loss_r_u:2.35e-01, loss_d_u:5.37e-06
# Iter # 47300/50000	time:1637.2	loss:1.86e+01, loss_r_u:2.58e-01, loss_d_u:1.69e-06
# Iter # 47400/50000	time:1640.2	loss:6.59e+01, loss_r_u:2.57e-01, loss_d_u:9.41e-06
# Iter # 47500/50000	time:1643.4	loss:1.29e+00, loss_r_u:2.16e-01, loss_d_u:7.38e-09
# Iter # 47600/50000	time:1646.6	loss:5.56e+01, loss_r_u:2.49e-01, loss_d_u:7.85e-06
# Iter # 47700/50000	time:1649.8	loss:4.77e+01, loss_r_u:2.44e-01, loss_d_u:6.90e-06
# Iter # 47800/50000	time:1652.9	loss:1.82e+01, loss_r_u:2.46e-01, loss_d_u:1.50e-06
# Iter # 47900/50000	time:1656.1	loss:1.66e+00, loss_r_u:2.14e-01, loss_d_u:2.81e-08
# Iter # 48000/50000	time:1659.2	loss:1.64e+00, loss_r_u:2.17e-01, loss_d_u:4.78e-08
# Iter # 48100/50000	time:1662.3	loss:1.21e+02, loss_r_u:2.84e-01, loss_d_u:1.75e-05
# Iter # 48200/50000	time:1665.5	loss:1.26e+00, loss_r_u:2.13e-01, loss_d_u:1.35e-08
# Iter # 48300/50000	time:1668.5	loss:1.25e+00, loss_r_u:2.13e-01, loss_d_u:8.05e-09
# Iter # 48400/50000	time:1671.7	loss:1.75e+00, loss_r_u:2.19e-01, loss_d_u:6.10e-08
# Iter # 48500/50000	time:1674.8	loss:1.29e+00, loss_r_u:2.12e-01, loss_d_u:1.54e-08
# Iter # 48600/50000	time:1678.0	loss:7.18e+00, loss_r_u:2.18e-01, loss_d_u:6.79e-07
# Iter # 48700/50000	time:1681.1	loss:4.77e+00, loss_r_u:2.13e-01, loss_d_u:4.94e-07
# Iter # 48800/50000	time:1684.2	loss:1.23e+00, loss_r_u:2.11e-01, loss_d_u:1.01e-08
# Iter # 48900/50000	time:1687.3	loss:1.33e+00, loss_r_u:2.10e-01, loss_d_u:1.34e-08
# Iter # 49000/50000	time:1690.5	loss:1.96e+00, loss_r_u:2.12e-01, loss_d_u:1.02e-07
# Iter # 49100/50000	time:1693.6	loss:1.22e+00, loss_r_u:2.09e-01, loss_d_u:1.22e-08
# Iter # 49200/50000	time:1696.8	loss:8.38e+00, loss_r_u:2.25e-01, loss_d_u:6.47e-07
# Iter # 49300/50000	time:1699.9	loss:1.23e+00, loss_r_u:2.09e-01, loss_d_u:1.33e-08
# Iter # 49400/50000	time:1703.0	loss:1.26e+00, loss_r_u:2.06e-01, loss_d_u:1.62e-08
# Iter # 49500/50000	time:1706.1	loss:3.46e+00, loss_r_u:2.14e-01, loss_d_u:1.73e-07
# Iter # 49600/50000	time:1709.3	loss:4.98e+00, loss_r_u:2.11e-01, loss_d_u:5.69e-07
# Iter # 49700/50000	time:1712.4	loss:3.19e+00, loss_r_u:2.08e-01, loss_d_u:3.20e-07
# Iter # 49800/50000	time:1715.6	loss:1.23e+00, loss_r_u:2.08e-01, loss_d_u:9.51e-09
# Iter # 49900/50000	time:1718.7	loss:1.21e+00, loss_r_u:2.05e-01, loss_d_u:1.04e-08
# Iter # 50000/50000	time:1721.8	loss:1.61e+00, loss_r_u:2.05e-01, loss_d_u:7.27e-08

# %%
model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict(),'nn_k_state': pinn.nn_k.state_dict()}
backbone_path = os.path.join(model_path, f'backbone_adam.pth')
torch.save(model_state, backbone_path)

np.save("./loss_logger_dict.npy", logger)

# %%
def used_time(start_time):
    seconds = time.time() - start_time
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print(f'used time: {hours:.0f}h {minutes:.0f}m {seconds:.0f}s')
    
used_time(start_time)
# Out:
# used time: 0h 28m 42s

# %% [markdown]
# ## 结果可视化

# %%
plt.rcParams.update({'font.size':18})

# %%
# loss曲线
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res_u1"]
        [::k], label=r"Re($\mathcal{L}_{r})$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_data_u1"]
        [::k], label=r"Re($\mathcal{L}_{data})$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
backbone = MLP(mlp_layers)
nn_k = MLP(mlp_layers_k)
pinn = PINNHelmholtz(backbone, nn_k)
pinn = pinn.to(device)
model_state = torch.load(os.path.join(model_path, 'backbone_adam.pth'))
pinn.backbone.load_state_dict(model_state['backbone_state'])
pinn.nn_k.load_state_dict(model_state['nn_k_state'])
# Out:
# <All keys matched successfully>

# %%
x = torch.linspace(0, 1, 2000)
k_data = 16/5*x**2 - 16/5*x + 1
u_data = (125*torch.arctan(torch.tensor(2)))/32 - (25*x)/8 - 125*torch.log(torch.tensor(5/16))/128 + (125*torch.log(x**2 - x + 5/16))/128 + (
    125*torch.arctan(4*x - 2))/32 + x*((25*x)/4 - (125*torch.arctan(4*x - 2))/16) - (25*x**2)/8
t_data = x

# %%
t_data = torch.tensor(t_data.reshape(-1,1)).float().to(device)
u_pred = pinn.net_u(t_data).detach().cpu().numpy()
k_pred = pinn.net_k(t_data).detach().cpu().numpy()
t_data = t_data.detach().cpu().numpy()
u_data = u_data.detach().cpu().numpy()
k_data = k_data.detach().cpu().numpy()
# Out:
# /tmp/ipykernel_399375/683095614.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t_data = torch.tensor(t_data.reshape(-1,1)).float().to(device)

# %%
error_u = np.linalg.norm(u_pred - u_data.reshape(-1, 1)) / np.linalg.norm(u_data.reshape(-1, 1))
error_k = np.linalg.norm(k_pred - k_data.reshape(-1, 1)) / np.linalg.norm(k_data.reshape(-1, 1))
print('u Relative l2 error: {:.3e}'.format(error_u))
print('k Relative l2 error: {:.3e}'.format(error_k))
# Out:
# u Relative l2 error: 1.426e-04
# k Relative l2 error: 1.548e-02
# ((2000, 1), (2000,))

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

u_data = u_data.reshape(-1, 1)
k_data = k_data.reshape(-1, 1)

cax = ax.plot(t_data, u_data)
cax = ax.plot(t_data, u_pred)

# cax = ax.scatter(t_data, k_data)
# cax = ax.scatter(t_data, k_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $k(t)$')
ax.set_aspect(1./ax.get_data_ratio())

cax2 = ax2.plot(t_data, np.abs(u_data - u_pred))
# cax2 = ax2.scatter(t_data, np.abs(k_data - k_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error $k(t)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('K.png')
plt.show()

# %%
fig = plt.figure(figsize=(14, 5), dpi=64)
[ax, ax2] = fig.subplots(1, 2)

k_data = k_data.reshape(-1, 1)

cax = ax.plot(t_data, k_data)
cax = ax.plot(t_data, k_pred)

# cax = ax.scatter(t_data, k_data)
# cax = ax.scatter(t_data, k_pred)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_title(r'Reference $k(t)$')
ax.set_aspect(1./ax.get_data_ratio())

cax2 = ax2.plot(t_data, np.abs(k_data - k_pred))
# cax2 = ax2.scatter(t_data, np.abs(k_data - k_pred))
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')
ax2.set_title(r'Error $k(t)$')
ax2.set_aspect(1./ax2.get_data_ratio())

plt.tight_layout()
plt.savefig('K.png')
plt.show()
