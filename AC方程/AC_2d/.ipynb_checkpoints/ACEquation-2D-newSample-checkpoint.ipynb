# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import seaborn as sns
from pyDOE import lhs
import random
import os
import time

plt.rcParams.update({'font.size':18})

# %%
def seed_torch(seed=1024):
    #     random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)  # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %%
domain = (0, 10, 0, 1,0, 1)
tmin, tmax, xmin, xmax, ymin, ymax = domain
mlp_layers = [3] + [20]*4 + [1]
# adam_iters = 40000
adam_iters = 20000
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_path = r'./model'
train_info_path = r'./'
if not os.path.exists(model_path):
    os.mkdir(model_path)

# %%
class Dataset:
    def __init__(self, domain):
        self.domain = domain
        self.lb = np.array([tmin, xmin, ymin])
        self.ub = np.array([tmax, xmax, ymax])
        self.N_max = 100000
        self.x_range = (xmin, xmax)
        self.y_range = (ymin, ymax)
        self.t_range = (tmin, tmax)

    def train_data(self, verbose=None):
        tmin, tmax, xmin, xmax, ymin, ymax = self.domain
        # 内部点采样
        t_res = np.linspace(tmin, tmax, 50)
        x_res = np.linspace(xmin, xmax, 40)
        y_res = np.linspace(ymin, ymax, 40)
        X_res = self.sample_xy(x_res, y_res)
        
        N = X_res.shape[0]  # N=1600
        T = t_res.shape[0]  # T=50
        
        XX = np.tile(X_res[:,0:1], (1,T))  # N,T
        YY = np.tile(X_res[:,1:2], (1,T))  # N,T
        TT = np.tile(t_res.T, (N,1))  # N,T
        
        x = XX.flatten()[:, None]  # NT x 1
        y = YY.flatten()[:, None]  # NT x 1
        t = TT.flatten()[:, None]  # NT x 1
        
        X_res = np.concatenate([t.reshape((-1, 1)), x.reshape((-1, 1)), y.reshape((-1, 1))], axis=1)
# #         print(X_res.shape)
        
#         # 新的采样方法
#         X = torch.Tensor(self.N_max, 1).uniform_(*self.x_range)
#         Y = torch.Tensor(self.N_max, 1).uniform_(*self.y_range)
#         T = torch.Tensor(self.N_max, 1).uniform_(*self.t_range)
        
#         idx = torch.randperm(self.N_max)
#         idx = idx[:50000]
#         X_res = torch.cat([T[idx], X[idx], Y[idx]], dim=1)

        # 初始点采样
        t_ics = np.ones((10,1))*tmin
        x_ics = np.linspace(xmin, xmax, 20)
        y_ics = np.linspace(ymin, ymax, 20)
        X_ics = self.sample_xy(x_ics, y_ics)
        
        N = X_ics.shape[0]  # N=1600
        T = t_ics.shape[0]  # T=50
        
        XX = np.tile(X_ics[:,0:1], (1,T))  # N,T
        YY = np.tile(X_ics[:,1:2], (1,T))  # N,T
        TT = np.tile(t_ics.T, (N,1))  # N,T
        
        x = XX.flatten()[:, None]  # NT x 1
        y = YY.flatten()[:, None]  # NT x 1
        t = TT.flatten()[:, None]  # NT x 1
        
        X_ics = np.concatenate([t.reshape((-1, 1)), x.reshape((-1, 1)), y.reshape((-1, 1))], axis=1)

#         # 新的采样方法
#         X = torch.Tensor(self.N_max, 1).uniform_(*self.x_range)
#         Y = torch.Tensor(self.N_max, 1).uniform_(*self.y_range)
#         T = torch.Tensor(self.N_max, 1).fill_(0)
        
#         idx = torch.randperm(self.N_max)
#         idx = idx[:5000]
#         X_ics = torch.cat([T[idx], X[idx], Y[idx]], dim=1)
        
        
        # X_ics = np.concatenate([t_ics.reshape((-1,1)), x_ics.reshape((-1, 1)), y_ics.reshape((-1, 1))], axis=1)
        u_ics = self.u_ics_sol(X_ics)
        
#         # 降低一维
#         X_res = np.squeeze(X_res)
#         X_ics = np.squeeze(X_ics)
#         u_ics = np.squeeze(u_ics)

        return X_res, X_ics, u_ics


    def sample_xy(self, x, y):
        xx, yy = np.meshgrid(x, y)
        X = np.concatenate([xx.reshape((-1, 1)), yy.reshape((-1, 1))], axis=1)
        return X
    
#     def sample_xyz(self, t,x,y):
#         tt, xx, yy = np.meshgrid(t,x,y)
#         X = np.concatenate([tt[:,:,:,None],xx[:,:,:,None],yy[:,:,:,None]], axis=1)
#         return X
    
    def u_ics_sol(self, X):
        return np.tanh((0.35-np.sqrt((X[:,[1]]-0.5)**2 + (X[:,[2]]-0.5)**2))/(2*0.025))
    
    def lhs_sample_xy(self, n=200):
        X = (self.ub - self.lb) * lhs(3, n) + self.lb
        print(X.shape)
        return X
    
dataset = Dataset(domain)
# 内部点与边界点
X_res, X_ics, u_ics = dataset.train_data()
print(X_res.shape, X_ics.shape,u_ics.shape)
# dataset.lhs_sample_xy()
# Out:
# (80000, 3) (4000, 3) (4000, 1)

# %%
X_res
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [ 0.20408163,  0.        ,  0.        ],
#        [ 0.40816327,  0.        ,  0.        ],
#        ...,
#        [ 9.59183673,  1.        ,  1.        ],
#        [ 9.79591837,  1.        ,  1.        ],
#        [10.        ,  1.        ,  1.        ]])

# %% [markdown]
# ## DNN

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
        for param in self.parameters():
            if len(param.shape) > 1:
                nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

    
    
backbone = MLP(mlp_layers)
# nn_lam = MLP(nn_lam_layers)

# %% [markdown]
# ## 主干网络

# %%
def grad(outputs, inputs):
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True, 
                               retain_graph=True)

# %%
class PINN(nn.Module):
    def __init__(self, backbone, mu=None, sigma=None):
        super(PINN, self).__init__()
        self.backbone = backbone

    def forward(self, X_res, X_ics, u_ics):
        
        loss_res = torch.mean(self.net_f(X_res) ** 2)
        # print((self.net_u(X_ics)-u_ics).shape)
        loss_ics = torch.mean((self.net_u(X_ics)-u_ics) ** 2)
        return loss_res, loss_ics
    
    def net_u(self, X):
        return self.backbone(X)
    
    def net_u_x(self,X):
        X.requires_grad_(True)
        u = self.net_u(X)
        
        # 求梯度
        grad_u = grad(u, X)[0]
        u_x = grad_u[:, [1]]
        return u_x

    def net_f(self, X):
        X.requires_grad_(True)

        u = self.net_u(X)
#         print(u.shape)
        # 求梯度
        grad_u = grad(u, X)[0]
        u_t = grad_u[:, [0]]
        u_x = grad_u[:, [1]]
        u_y = grad_u[:, [2]]
        
        # u_tt = grad(u_t, X)[0][:, [0]]
        u_xx = grad(u_x, X)[0][:, [1]]
        u_yy = grad(u_y, X)[0][:, [2]]
        
        eps = 0.025
        lam = 10
        
        f = u_t - (eps**2 * (u_xx + u_yy) - u**3 + u) * lam
        return f

pinn = PINN(mlp_layers)

# %% [markdown]
# ## Resample策略

# %%
def easy_resample(dataset, net_f, device=torch.device('cuda'), n_total_points=4000, n_added_points=100):
    # 生成待采样的点集
    X_resam = dataset.lhs_sample_xy(n=n_total_points)
    X_resam = torch.from_numpy(X_resam).float().to(device)
    # 获得residule
    f = net_f(X_resam)
    f = f.detach().cpu().numpy()
    # 依loss_res的值排序得到索引
    idx = np.argsort(abs(f).flatten())[-n_added_points:]
    return X_resam[idx].detach()

# %% [markdown]
# ## Adam

# %%
dataset = Dataset(domain)
X_res, X_ics, u_ics = dataset.train_data()

X_res = torch.from_numpy(X_res).float().to(device)
# X_bcs_l = torch.from_numpy(X_bcs_l).float().to(device)
# X_bcs_u = torch.from_numpy(X_bcs_u).float().to(device)
X_ics = torch.from_numpy(X_ics).float().to(device)
u_ics = torch.from_numpy(u_ics).float().to(device)

mu = X_res.mean(dim=0)
sigma = X_res.std(dim=0)  # 求样本标准差

backbone = MLP(mlp_layers)  # 主干网络
pinn = PINN(backbone, mu, sigma).to(device)

optimizer_adam = optim.Adam(pinn.backbone.parameters(), lr=1e-3)

lr_sche = optim.lr_scheduler.ExponentialLR(optimizer_adam, gamma=0.8)  # 指数衰减学习率

logger = {
    "loss": [], 
    "loss_res": [],
    "loss_ics": [],
    "loss_bcs": [],
    "loss_bcs_t": [],
    "iter": [],
    "mu": mu,
    "sigma": sigma
}
best_loss = 1e9

# 训练
start_time = time.time()
for it in range(adam_iters):
    pinn.train()
    pinn.zero_grad()
    
    loss_res, loss_ics = pinn(X_res, X_ics, u_ics)
    loss = loss_res + loss_ics
    
    loss.backward()
    optimizer_adam.step()
    
    if (it + 1) % 100 == 0:
        # 保存loss信息
        pinn.train(False)
        loss_res_valid, loss_ics_valid = pinn(X_res, X_ics, u_ics)
        loss_valid = loss_res_valid + loss_ics_valid 
        
        logger["loss"].append(loss_valid.item())
        logger["loss_res"].append(loss_res_valid.item())
        logger["loss_ics"].append(loss_ics_valid.item())
        logger["iter"].append(it+1)
        
        
        if (it + 1) % 500 == 0:
            # 保存并打印训练日志
            info = f'Iter # {it+1:6d}/{adam_iters}\t' + \
                f'loss:{loss.item():.2e}, loss_r:{loss_res.item():.2e}, loss_i:{loss_ics.item():.2e}  ' + \
                f'Valid # loss:{loss_valid.item():.2e}, loss_r:{loss_res_valid.item():.2e}, loss_i:{loss_ics_valid.item():.2e}'
            with open(train_info_path + 'train_info.txt', 'a') as f:
                f.write(info + '\n')
            print(info)
            
        # 衰减学习率
        if (it + 1) % 4000 == 0:
            lr_sche.step()
    
    if (it + 1) % 1000 == 0:  # 每1000次adam后采用BFGS优化并重采样

        optimizer_lbfgs = optim.LBFGS(pinn.parameters(), max_iter=50000, history_size=50000,  # 调大history_size等价于BFGS
                                      tolerance_grad=1.e-6, tolerance_change=1.e-10, line_search_fn="strong_wolfe")
        it = 0  # BFGS迭代次数
        with open(train_info_path + 'train_info.txt', 'a') as f:
            f.write('Training by LBFGS:\n')

        def closure():
            global it
            pinn.zero_grad()
            loss_res, loss_ics = pinn(X_res, X_ics, u_ics)
            loss = loss_res + loss_ics
            loss.backward()
            # logger["loss"].append(loss.item())
            # logger["loss_res"].append(loss_res.item())
            # logger["loss_ics"].append(loss_ics.item())
            # logger["iter"].append(it+1)
            if (it + 1) % 100 == 0:
                info = f'Iter # {it+1:4d}\ttime:{time.time()-start_time:.1e}\t' + f'loss:{loss.item():.2e}, loss_res:{loss_res.item():.2e}, loss_ics:{loss_ics.item():.2e}'
                with open(train_info_path + 'train_info.txt', 'a') as f:
                    f.write(info + '\n')
                print(info)
            it = it + 1
            return loss
        optimizer_lbfgs.step(closure)

        model_state = {'state_dict': pinn.state_dict()}
        backbone_path = os.path.join(model_path, f'pinn_lbfgs_{it+1}.pth')
        torch.save(model_state, backbone_path)
        
        # 进行重采样
        pinn.zero_grad()
        pinn.eval()
#         print(X_res.shape)
        X_resam1 = easy_resample(dataset, pinn.net_f, device = device).float()
        # 拼接数据
        X_res = torch.cat([X_res, X_resam1], dim=0)
        # print(X_res.shape)
        
        pinn.zero_grad()
        pinn.eval()
        # 保存训练loss最低的模型
        if loss_valid.item() < best_loss:
            model_state = {'iter': it+1, 'backbone_state': pinn.backbone.state_dict()}
            torch.save(model_state, os.path.join(model_path, 'pinn_adam.pth'))
            best_loss = loss_valid.item()
# Out:
# Iter #    500/20000	loss:6.79e-01, loss_r:7.44e-02, loss_i:6.05e-01  Valid # loss:6.79e-01, loss_r:7.45e-02, loss_i:6.04e-01
# Iter #   1000/20000	loss:6.05e-01, loss_r:1.04e-01, loss_i:5.01e-01  Valid # loss:6.05e-01, loss_r:1.04e-01, loss_i:5.01e-01
# Iter #  100	time:2.0e+01	loss:1.20e-01, loss_res:3.45e-02, loss_ics:8.58e-02
# Iter #  200	time:2.4e+01	loss:3.66e-02, loss_res:9.23e-03, loss_ics:2.74e-02
# Iter #  300	time:3.1e+01	loss:9.81e-03, loss_res:3.97e-03, loss_ics:5.84e-03
# Iter #  400	time:3.8e+01	loss:2.58e-03, loss_res:1.37e-03, loss_ics:1.22e-03
# Iter #  500	time:4.8e+01	loss:1.23e-03, loss_res:6.86e-04, loss_ics:5.48e-04
# Iter #  600	time:5.9e+01	loss:7.48e-04, loss_res:4.47e-04, loss_ics:3.02e-04
# Iter #  700	time:7.3e+01	loss:3.88e-04, loss_res:2.17e-04, loss_ics:1.71e-04
# Iter #  800	time:8.6e+01	loss:2.26e-04, loss_res:1.25e-04, loss_ics:1.02e-04
# Iter #  900	time:1.0e+02	loss:1.62e-04, loss_res:9.31e-05, loss_ics:6.86e-05
# Iter # 1000	time:1.2e+02	loss:1.13e-04, loss_res:5.88e-05, loss_ics:5.40e-05
# Iter # 1100	time:1.3e+02	loss:7.91e-05, loss_res:3.73e-05, loss_ics:4.17e-05
# Iter # 1200	time:1.5e+02	loss:6.08e-05, loss_res:2.91e-05, loss_ics:3.17e-05
# Iter # 1300	time:1.7e+02	loss:4.44e-05, loss_res:2.27e-05, loss_ics:2.18e-05
# Iter # 1400	time:1.9e+02	loss:3.56e-05, loss_res:1.87e-05, loss_ics:1.70e-05
# Iter # 1500	time:2.1e+02	loss:2.71e-05, loss_res:1.38e-05, loss_ics:1.33e-05
# Iter # 1600	time:2.3e+02	loss:2.27e-05, loss_res:1.20e-05, loss_ics:1.07e-05
# Iter # 1700	time:2.6e+02	loss:1.88e-05, loss_res:9.42e-06, loss_ics:9.39e-06
# Iter # 1800	time:2.8e+02	loss:1.62e-05, loss_res:7.12e-06, loss_ics:9.04e-06
# Iter # 1900	time:3.1e+02	loss:1.40e-05, loss_res:5.90e-06, loss_ics:8.13e-06
# Iter # 2000	time:3.4e+02	loss:1.21e-05, loss_res:5.32e-06, loss_ics:6.81e-06
# Iter # 2100	time:3.7e+02	loss:1.10e-05, loss_res:4.94e-06, loss_ics:6.05e-06
# Iter # 2200	time:4.0e+02	loss:9.63e-06, loss_res:4.58e-06, loss_ics:5.06e-06
# (4000, 3)
# Iter #   1500/20000	loss:1.99e-02, loss_r:1.86e-02, loss_i:1.38e-03  Valid # loss:1.99e-02, loss_r:1.85e-02, loss_i:1.38e-03
# Iter #   2000/20000	loss:1.21e-02, loss_r:1.10e-02, loss_i:1.08e-03  Valid # loss:1.21e-02, loss_r:1.10e-02, loss_i:1.08e-03
# Iter #  100	time:4.4e+02	loss:1.53e-03, loss_res:1.07e-03, loss_ics:4.61e-04
# Iter #  200	time:4.4e+02	loss:3.85e-04, loss_res:2.87e-04, loss_ics:9.74e-05
# Iter #  300	time:4.5e+02	loss:1.76e-04, loss_res:1.17e-04, loss_ics:5.92e-05
# Iter #  400	time:4.6e+02	loss:9.64e-05, loss_res:6.10e-05, loss_ics:3.54e-05
# Iter #  500	time:4.6e+02	loss:5.58e-05, loss_res:3.37e-05, loss_ics:2.21e-05
# Iter #  600	time:4.8e+02	loss:3.91e-05, loss_res:2.31e-05, loss_ics:1.59e-05
# Iter #  700	time:4.9e+02	loss:2.93e-05, loss_res:1.67e-05, loss_ics:1.27e-05
# Iter #  800	time:5.0e+02	loss:2.26e-05, loss_res:1.37e-05, loss_ics:8.86e-06
# (4000, 3)
# Iter #   2500/20000	loss:9.26e-03, loss_r:8.42e-03, loss_i:8.33e-04  Valid # loss:9.24e-03, loss_r:8.41e-03, loss_i:8.33e-04
# Iter #   3000/20000	loss:4.94e-03, loss_r:4.34e-03, loss_i:5.95e-04  Valid # loss:4.93e-03, loss_r:4.34e-03, loss_i:5.95e-04
# Iter #  100	time:5.3e+02	loss:6.98e-04, loss_res:5.58e-04, loss_ics:1.40e-04
# Iter #  200	time:5.3e+02	loss:2.72e-04, loss_res:2.10e-04, loss_ics:6.18e-05
# Iter #  300	time:5.4e+02	loss:1.55e-04, loss_res:1.20e-04, loss_ics:3.43e-05
# Iter #  400	time:5.5e+02	loss:9.76e-05, loss_res:7.19e-05, loss_ics:2.57e-05
# Iter #  500	time:5.6e+02	loss:7.13e-05, loss_res:5.04e-05, loss_ics:2.10e-05
# Iter #  600	time:5.7e+02	loss:5.27e-05, loss_res:3.72e-05, loss_ics:1.55e-05
# Iter #  700	time:5.8e+02	loss:3.92e-05, loss_res:2.80e-05, loss_ics:1.13e-05
# Iter #  800	time:5.9e+02	loss:3.17e-05, loss_res:2.26e-05, loss_ics:9.11e-06
# Iter #  900	time:6.1e+02	loss:2.59e-05, loss_res:1.79e-05, loss_ics:7.97e-06
# Iter # 1000	time:6.2e+02	loss:2.17e-05, loss_res:1.49e-05, loss_ics:6.79e-06
# Iter # 1100	time:6.4e+02	loss:1.76e-05, loss_res:1.18e-05, loss_ics:5.78e-06
# (4000, 3)
# Iter #   3500/20000	loss:7.20e-03, loss_r:6.63e-03, loss_i:5.68e-04  Valid # loss:7.18e-03, loss_r:6.61e-03, loss_i:5.66e-04
# Iter #   4000/20000	loss:3.47e-03, loss_r:3.19e-03, loss_i:2.79e-04  Valid # loss:3.47e-03, loss_r:3.19e-03, loss_i:2.79e-04
# Iter #  100	time:6.6e+02	loss:9.51e-04, loss_res:8.30e-04, loss_ics:1.21e-04
# Iter #  200	time:6.7e+02	loss:2.97e-04, loss_res:2.60e-04, loss_ics:3.75e-05
# Iter #  300	time:6.7e+02	loss:1.35e-04, loss_res:1.12e-04, loss_ics:2.32e-05
# Iter #  400	time:6.8e+02	loss:8.27e-05, loss_res:6.62e-05, loss_ics:1.65e-05
# Iter #  500	time:6.9e+02	loss:5.81e-05, loss_res:4.80e-05, loss_ics:1.01e-05
# Iter #  600	time:7.0e+02	loss:4.45e-05, loss_res:3.54e-05, loss_ics:9.07e-06
# Iter #  700	time:7.1e+02	loss:3.40e-05, loss_res:2.62e-05, loss_ics:7.78e-06
# Iter #  800	time:7.2e+02	loss:2.78e-05, loss_res:2.08e-05, loss_ics:7.02e-06
# Iter #  900	time:7.4e+02	loss:2.47e-05, loss_res:1.82e-05, loss_ics:6.50e-06
# Iter # 1000	time:7.5e+02	loss:2.24e-05, loss_res:1.62e-05, loss_ics:6.15e-06
# Iter # 1100	time:7.6e+02	loss:2.06e-05, loss_res:1.48e-05, loss_ics:5.78e-06
# Iter # 1200	time:7.8e+02	loss:1.83e-05, loss_res:1.28e-05, loss_ics:5.51e-06
# Iter # 1300	time:8.0e+02	loss:1.57e-05, loss_res:1.07e-05, loss_ics:5.00e-06
# Iter # 1400	time:8.2e+02	loss:1.39e-05, loss_res:9.06e-06, loss_ics:4.84e-06
# (4000, 3)
# Iter #   4500/20000	loss:1.69e-03, loss_r:1.53e-03, loss_i:1.56e-04  Valid # loss:1.68e-03, loss_r:1.53e-03, loss_i:1.56e-04
# Iter #   5000/20000	loss:1.00e-03, loss_r:9.12e-04, loss_i:9.05e-05  Valid # loss:1.00e-03, loss_r:9.14e-04, loss_i:9.01e-05
# Iter #  100	time:8.4e+02	loss:4.30e-04, loss_res:3.64e-04, loss_ics:6.60e-05
# Iter #  200	time:8.5e+02	loss:2.41e-04, loss_res:1.99e-04, loss_ics:4.23e-05
# Iter #  300	time:8.5e+02	loss:1.44e-04, loss_res:1.21e-04, loss_ics:2.34e-05
# Iter #  400	time:8.6e+02	loss:9.66e-05, loss_res:7.85e-05, loss_ics:1.81e-05
# Iter #  500	time:8.7e+02	loss:6.67e-05, loss_res:5.23e-05, loss_ics:1.44e-05
# Iter #  600	time:8.8e+02	loss:4.89e-05, loss_res:3.67e-05, loss_ics:1.22e-05
# (4000, 3)
# Iter #   5500/20000	loss:1.35e-02, loss_r:1.19e-02, loss_i:1.58e-03  Valid # loss:1.34e-02, loss_r:1.19e-02, loss_i:1.57e-03
# Iter #   6000/20000	loss:5.91e-03, loss_r:5.34e-03, loss_i:5.73e-04  Valid # loss:5.90e-03, loss_r:5.33e-03, loss_i:5.72e-04
# Iter #  100	time:9.1e+02	loss:2.62e-03, loss_res:2.30e-03, loss_ics:3.22e-04
# Iter #  200	time:9.1e+02	loss:1.46e-03, loss_res:1.27e-03, loss_ics:1.86e-04
# Iter #  300	time:9.2e+02	loss:1.01e-03, loss_res:8.57e-04, loss_ics:1.49e-04
# Iter #  400	time:9.3e+02	loss:6.78e-04, loss_res:5.74e-04, loss_ics:1.05e-04
# Iter #  500	time:9.4e+02	loss:5.05e-04, loss_res:4.17e-04, loss_ics:8.81e-05
# Iter #  600	time:9.5e+02	loss:3.85e-04, loss_res:3.15e-04, loss_ics:6.96e-05
# Iter #  700	time:9.6e+02	loss:3.06e-04, loss_res:2.43e-04, loss_ics:6.29e-05
# Iter #  800	time:9.7e+02	loss:2.33e-04, loss_res:1.78e-04, loss_ics:5.47e-05
# (4000, 3)
# Iter #   6500/20000	loss:8.37e-03, loss_r:6.26e-03, loss_i:2.11e-03  Valid # loss:8.36e-03, loss_r:6.25e-03, loss_i:2.11e-03
# Iter #   7000/20000	loss:4.76e-03, loss_r:3.68e-03, loss_i:1.08e-03  Valid # loss:4.75e-03, loss_r:3.68e-03, loss_i:1.08e-03
# Iter #  100	time:1.0e+03	loss:2.28e-03, loss_res:1.85e-03, loss_ics:4.24e-04
# Iter #  200	time:1.0e+03	loss:1.30e-03, loss_res:1.06e-03, loss_ics:2.36e-04
# Iter #  300	time:1.0e+03	loss:8.13e-04, loss_res:6.41e-04, loss_ics:1.72e-04
# Iter #  400	time:1.0e+03	loss:5.12e-04, loss_res:3.95e-04, loss_ics:1.17e-04

# %%
X_res

# %%
np.save("./logger.npy", logger)

# %%
logger = np.load("./logger.npy", allow_pickle=True).item()
k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_ics"][::k], label=r"$\mathcal{L}_{ics}$", linewidth=3)
    plt.legend()
    plt.xticks([0, 5000, 10000, 15000, 20000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('loss.png', dpi=100)
    plt.show()

# %%
fig = plt.figure(figsize=(25, 5))

t_res = np.linspace(tmin, tmax, 101)
x_res = np.linspace(xmin, xmax, 100)
y_res = np.linspace(ymin, ymax, 100)
xx, yy = np.meshgrid(x_res,y_res)
X_res = dataset.sample_xy(x_res, y_res)


N = X_res.shape[0]  # N=1600
T = t_res.shape[0]  # T=50

XX = np.tile(X_res[:,0:1], (1,T))  # N,T
YY = np.tile(X_res[:,1:2], (1,T))  # N,T
TT = np.tile(t_res.T, (N,1))  # N,T

snap1 = np.array([0])
snap2 = np.array([25])
snap3 = np.array([50])
snap4 = np.array([100])

x_star = X_res[:,0:1]
y_star = X_res[:,1:2]

t_1 = TT[:,snap1]
t_2 = TT[:,snap2]
t_3 = TT[:,snap3]
t_4 = TT[:,snap4]


x_star = torch.tensor(x_star)
y_star = torch.tensor(y_star)
t_1 = torch.tensor(t_1)
t_2 = torch.tensor(t_2)
t_3 = torch.tensor(t_3)
t_4 = torch.tensor(t_4)

X_1 = torch.cat([t_1, x_star,y_star], dim=1)
X_2 = torch.cat([t_2, x_star,y_star], dim=1)
X_3 = torch.cat([t_3, x_star,y_star], dim=1)
X_4 = torch.cat([t_4, x_star,y_star], dim=1)
X_1 = X_1.float().to(device)
X_2 = X_2.float().to(device)
X_3 = X_3.float().to(device)
X_4 = X_4.float().to(device)
print(X_1)
print(X_2)

u_pred_1 = pinn.net_u(X_1).detach().cpu().numpy()
u_pred_2 = pinn.net_u(X_2).detach().cpu().numpy()
u_pred_3 = pinn.net_u(X_3).detach().cpu().numpy()
u_pred_4 = pinn.net_u(X_4).detach().cpu().numpy()

print(u_pred_1.max())
print(u_pred_2.max())
# print(u_pred_1.shape)

axes = fig.subplots(1, 4)
plt.subplot(1,4,1)
plt.pcolor(xx, yy, u_pred_1.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()

plt.subplot(1,4,2)
plt.pcolor(xx, yy, u_pred_2.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()

plt.subplot(1,4,3)
plt.pcolor(xx, yy, u_pred_3.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()

plt.subplot(1,4,4)
plt.pcolor(xx, yy, u_pred_4.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()

# %%
t_1 = np.array([2.5])
x = np.linspace(0, 1, 101)
y = np.linspace(0, 1, 101)
xx, yy = np.meshgrid(x, y)


X_1 = np.concatenate([t_1*np.ones_like(xx.reshape(-1, 1)), xx.reshape(-1, 1), yy.reshape(-1, 1)], axis=1)

X_1 = torch.from_numpy(X_1).float().to(device)

u_pred_1 = pinn.net_u(X_1).detach().cpu().numpy()

print(u_pred_1.max())

# %%
fig = plt.figure(figsize=(25, 5))
ax = plt.subplot(1, 4, 1)
plt.pcolor(xx, yy, u_pred_1.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()
# plt.clim([-1., 1.])
plt.xlabel('$x$')
plt.ylabel('$y$')
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.set_xticks(np.linspace(0, 1, 5))
ax.set_yticks(np.linspace(0, 1, 5))
plt.title(r'Predicted $u(t,x)$')
ax.set_aspect(1./ax.get_data_ratio())

# ax = plt.subplot(1, 4, 2)
# plt.pcolor(xx, yy, u_pred_2.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
# plt.colorbar()
# # plt.clim([-1., 1.])
# plt.xlabel('$x$')
# plt.ylabel('$y$')
# ax.set_xlim([0, 1])
# ax.set_ylim([0, 1])
# ax.set_xticks(np.linspace(0, 1, 5))
# ax.set_yticks(np.linspace(0, 1, 5))
# plt.title(r'Predicted $u(t,x)$')
# ax.set_aspect(1./ax.get_data_ratio())

# ax = plt.subplot(1, 4, 3)
# plt.pcolor(xx, yy, u_pred_3.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
# plt.colorbar()
# # plt.clim([-1., 1.])
# plt.xlabel('$x$')
# plt.ylabel('$y$')
# ax.set_xlim([0, 1])
# ax.set_ylim([0, 1])
# ax.set_xticks(np.linspace(0, 1, 5))
# ax.set_yticks(np.linspace(0, 1, 5))
# plt.title(r'Predicted $u(t,x)$')
# ax.set_aspect(1./ax.get_data_ratio())

# ax = plt.subplot(1, 4, 4)
# plt.pcolor(xx, yy, u_pred_4.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
# plt.colorbar()
# # plt.clim([-1., 1.])
# plt.xlabel('$x$')
# plt.ylabel('$y$')
# ax.set_xlim([0, 1])
# ax.set_ylim([0, 1])
# ax.set_xticks(np.linspace(0, 1, 5))
# ax.set_yticks(np.linspace(0, 1, 5))
# plt.title(r'Predicted $u(t,x)$')
# ax.set_aspect(1./ax.get_data_ratio())

plt.tight_layout()
plt.savefig('AC_pred.png', dpi=100)

# %% [markdown]
# # 初始条件

# %%
t_res = np.linspace(tmin, tmax, 100)
x_res = np.linspace(xmin, xmax, 100)
y_res = np.linspace(ymin, ymax, 100)
xx, yy = np.meshgrid(x_res,y_res)
X_res = dataset.sample_xy(x_res, y_res)


N = X_res.shape[0]  # N=1600
T = t_res.shape[0]  # T=50

XX = np.tile(X_res[:,0:1], (1,T))  # N,T
YY = np.tile(X_res[:,1:2], (1,T))  # N,T
TT = np.tile(t_res.T, (N,1))  # N,T

snap = np.array([0])

x_star = X_res[:,0:1]
y_star = X_res[:,1:2]
t_star = TT[:,snap]

x_star = torch.tensor(x_star)
y_star = torch.tensor(y_star)
t_star = torch.tensor(t_star)

X = torch.cat([t_star, x_star,y_star], dim=1)
X = X.float().to(device).cpu().numpy()

u0 = dataset.u_ics_sol(X)
print(u0.shape)
print()

plt.pcolor(xx, yy, u0.reshape(xx.shape), cmap='jet', vmin = -1, vmax =1)
plt.colorbar()
