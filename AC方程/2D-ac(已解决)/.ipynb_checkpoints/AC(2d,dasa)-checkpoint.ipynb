# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import time
from pyDOE import lhs
import matplotlib
# matplotlib.use('Agg')
# import imageio
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import shutil
import pickle
import scipy.io
import random
import math
from scipy.interpolate import griddata

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.optim import lr_scheduler

import warnings
warnings.filterwarnings("ignore")

# %%
import argparse
class Options_AC(object):
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--use_subnet', default=True, help=' use subnet or not')
        parser.add_argument('--no_cuda', action='store_true', default=False, help='disable CUDA or not')
        parser.add_argument('--dim_hidden', type=int, default=128, help='neurons in hidden layers')
        parser.add_argument('--hidden_layers', type=int, default=6, help='number of hidden layers')
        parser.add_argument('--lr', type=float, default=1e-3, help='initial learning rate')
        parser.add_argument('--epochs_Adam', type=int, default=100000, help='epochs for Adam optimizer')
        parser.add_argument('--epochs_LBFGS', type=int, default=0, help='epochs for LBFGS optimizer')
        parser.add_argument('--newton_iter', type=int, default=100, help='newton_iter for LBFGS optimizer')
        parser.add_argument('--step_size', type=int, default=5000, help='step size in lr_scheduler for Adam optimizer')
        parser.add_argument('--gamma', type=float, default=0.9, help='gamma in lr_scheduler for Adam optimizer')
        
        self.parser = parser

    def parse(self):
        arg = self.parser.parse_args(args=[])
        # arg.cuda = False
        # arg.device = torch.device('cpu')
        arg.cuda = not arg.no_cuda and torch.cuda.is_available()
        arg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        return arg

args = Options_AC().parse()
print(args.hidden_layers)

def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)
# Out:
# 6

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

def activation(name):
    if name in ['tanh', 'Tanh']:
        return nn.Tanh()
    elif name in ['relu', 'ReLU']:
        return nn.ReLU(inplace=True)
    elif name in ['leaky_relu', 'LeakyReLU']:
        return nn.LeakyReLU(inplace=True)
    elif name in ['sigmoid', 'Sigmoid']:
        return nn.Sigmoid()
    elif name in ['softplus', 'Softplus']:
        return nn.Softplus()
    else:
        raise ValueError(f'unknown activation function: {name}')

# %%
seed_torch(42)

# %%
class Modified_MLP(nn.Module):
    def __init__(self, dim_in, dim_out, dim_hidden, hidden_layers,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        self.hidden_layers = hidden_layers

        encoder_U = nn.Sequential()
        encoder_U.add_module('fc', nn.Linear(dim_in, dim_hidden, bias=True))
        encoder_U.add_module('act', activation(act_name))
        self.encoder_U = encoder_U

        encoder_V = nn.Sequential()
        encoder_V.add_module('fc', nn.Linear(dim_in, dim_hidden, bias=True))
        encoder_V.add_module('act', activation(act_name))
        self.encoder_V = encoder_V

        model = nn.Sequential()
        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))

        self.model = model
        if init_name is not None:
            self.init_weight(init_name)

        self.size = self.model_size()

    def init_weight(self, name):
        """初始化网络参数"""

        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
    
    def forward(self, x):
        """模型的正向传播"""
        U = self.encoder_U(x)
        V = self.encoder_V(x)
        for i in range(self.hidden_layers):
            x = self.model[2 * i](x)      # 调用线性层
            x = self.model[2 * i + 1](x)  # 调用激活层
            x = (1 - x) * U + x * V       # 特征融合
        x = self.model[-1](x)             # 调用最后一个线性层得到输出
        return x

    def model_size(self):
        """模型大小"""
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %% [markdown]
# ## 网络模型(DNN)

# %%
class MLP(nn.Module):
    """Deep Neural Network"""

    def __init__(self, L_x, L_y, M_t, M_x, M_y, dim_hidden, hidden_layers, dim_out,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        
#         dim_in = M_x * M_y * 4 + (M_x+M_y) * 2 + (M_t+1) + 1
        dim_in = (M_x+M_y) * 2 + (M_t+1) + 1
        
        model = DNN(dim_in, dim_out, dim_hidden, hidden_layers)
        self.model = model
        if init_name is not None:
            self.init_weight(init_name)
            
        self.M_t = M_t
        self.M_x = M_x
        self.M_y = M_y

        self.w_x = 2.0 * math.pi / L_x
        self.w_y = 2.0 * math.pi / L_y
        
        self.k_t = 10.0**torch.arange(0, M_t + 1)
        self.k_x = torch.arange(1, M_x+1).float()
        self.k_y = torch.arange(1, M_y+1).float()
        
        self.k_xx, self.k_yy = torch.meshgrid(self.k_x, self.k_y)
        self.k_xx = self.k_xx.reshape(-1)
        self.k_yy = self.k_yy.reshape(-1)
        
        self.k_t = nn.Parameter(self.k_t.float())
        self.k_x = nn.Parameter(self.k_x.float())
        self.k_y = nn.Parameter(self.k_y.float())
        self.k_xx = nn.Parameter(self.k_xx.float())
        self.k_yy = nn.Parameter(self.k_yy.float())
        
        
    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
                
                           
    def input_encoding(self, t, x, y):
#         out = torch.hstack([torch.ones_like(t), self.k_t*t,
#                             torch.cos(self.k_x * self.w_x * x), torch.cos(self.k_y * self.w_y * y),
#                             torch.sin(self.k_x * self.w_x * x), torch.sin(self.k_y * self.w_y * y),
#                             torch.cos(self.k_xx * self.w_x * x) * torch.cos(self.k_yy * self.w_y * y),
#                             torch.cos(self.k_xx * self.w_x * x) * torch.sin(self.k_yy * self.w_y * y),
#                             torch.sin(self.k_xx * self.w_x * x) * torch.cos(self.k_yy * self.w_y * y),
#                             torch.sin(self.k_xx * self.w_x * x) * torch.sin(self.k_yy * self.w_y * y)])
        
        out = torch.hstack([torch.ones_like(t), self.k_t*t,
                            torch.cos(self.k_x * self.w_x * x), torch.cos(self.k_y * self.w_y * y),
                            torch.sin(self.k_x * self.w_x * x), torch.sin(self.k_y * self.w_y * y)])
        
        return out    
            
                           
    def forward(self, H):
        t = H[:, 0:1]
        x = H[:, 1:2]
        y = H[:, 2:3]
    
        # embedding
        H = self.input_encoding(t, x, y)
        
        # 特征融合
        H = self.model(H)
        return H
    
    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %%
class DNN(nn.Module):
    """Deep Neural Network"""

    def __init__(self, dim_in, dim_out, dim_hidden, hidden_layers,
                 act_name='tanh', init_name=None):
        super().__init__()
        model = nn.Sequential()

        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))

        self.model = model
        if init_name is not None:
            self.init_weight(init_name)

    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)

    def forward(self, x):
        return self.model(x)

    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params

# %%
model = MLP(L_x=1, L_y=1, M_t=2, M_x=5, M_y=5, dim_hidden=128, hidden_layers=6, dim_out=1)
# model = DNN(dim_in=3, dim_out=1, dim_hidden=128, hidden_layers=6)
model.cuda()
args.model=model

# %% [markdown]
# ## 数据集生成

# %%
class Trainset_AC():
    def __init__(self, *args):
        self.args = args
        self.shape = (self.args[1], self.args[0])
        
    def __call__(self):
        return self.data()
    
    def data(self):
        
        Nsd = self.args[0]
        n_ics = self.args[1]
        
        lb = np.array([0.0, 0.0, 0.0])
        ub = np.array([10, 1, 1])
        txy = (ub-lb)*lhs(3, Nsd)+lb
        
        lb_ics = np.array([0.0, 0.0, 0.0])
        ub_ics = np.array([0.0, 1, 1]) 
        txy_ics = (ub_ics-lb_ics)*lhs(3, n_ics)+lb_ics
        
        u_ics = np.tanh((0.35-np.sqrt((txy_ics[:,[1]]-0.5)**2 + (txy_ics[:,[2]]-0.5)**2))/(2*0.025))
        
        txy = torch.from_numpy(txy).float().cuda()
        txy_ics = torch.from_numpy(txy_ics).float().cuda()
        u_ics = torch.from_numpy(u_ics).float().cuda()
        
        return txy, txy_ics, u_ics

# %%
trainset = Trainset_AC(25600, 1024)
args.trainset = trainset
txy, txy_ics, u_ics = trainset()

# %% [markdown]
# ## 训练

# %%
class Unet(DNN):
    """Physics Constrained Neural Networks
    """
    def __init__(self, dim_in=3, dim_out=1, dim_hidden=20, hidden_layers=5,
                 act_name='sigmoid', init_name=None):
        super().__init__(dim_in, dim_out, dim_hidden, hidden_layers,
                         act_name=act_name, init_name=init_name)
        self.model.fc5.bias.requires_grad = False
    def minmaxscaler(self, data):
        mmin = torch.min(data,dim=0)[0]
        mmax = torch.max(data,dim=0)[0]
        data = (data - mmin)/(mmax-mmin)
        output = data/torch.sum(data) * len(data)
        
        return output
    def forward(self, x):
        u = super().forward(x)
        u = self.minmaxscaler(u)
        return u

# %%
class Trainer_AC(object):
    def __init__(self, args):
        self.model = args.model
        self.lr = args.lr
        self.gamma = args.gamma

        self.newton_iter = args.newton_iter
        self.step_size = args.step_size
        
        self.model_name = self.model.__class__.__name__
        self.model_path = self._model_path()
        
        self.epochs_Adam = args.epochs_Adam
        self.epochs_LBFGS = args.epochs_LBFGS
        self.optimizer_Adam = optim.Adam(self.model.parameters(), lr=self.lr, betas=(0.9, 0.999))
        self.optimizer_LBFGS = optim.LBFGS(self.model.parameters(),
                                            lr=0.8,
                                            max_iter=self.newton_iter,
                                            tolerance_grad=1.e-5,
                                            tolerance_change=1.e-9)
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        
        # subnet(Unet)
        self.use_subnet = args.use_subnet
        self.Unet = args.Unet
        self.Unet.cuda()
        self.Unet.zero_grad()
        self.optimizer_Adam_Unet = optim.Adam(filter(lambda p: p.requires_grad==True, self.Unet.parameters()), lr=args.lr)    
        self.scheduler_Unet = lr_scheduler.ExponentialLR(self.optimizer_Adam_Unet, gamma=self.gamma, verbose=True)
        
        # data
        self.txy, self.txy_ics, self.u_ics = args.trainset()
 
        # Logger
        self.loss_log = []
        self.loss_b_log = []
        self.loss_r_log = []
        self.epoch_log = []
        
        self.loss_lbfgs_log = []
        self.loss_b_lbfgs_log = []
        self.loss_r_lbfgs_log = []
        self.epoch_lbfgs_log = []
        
        
    def _model_path(self):
        """Path to save the model"""
        if not os.path.exists('checkpoint'):
            os.mkdir('checkpoint')
        
        path = os.path.join('checkpoint', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path

    
    def net_r(self, txy):
        txy.requires_grad_(True)

        u = self.model(txy)

        grad_u = grad(u, txy)[0]
        u_t = grad_u[:,[0]]
        
        u_x = grad_u[:,[1]]
        u_y = grad_u[:,[2]]
        
        u_xx = grad(u_x, txy)[0][:,[1]]
        u_yy = grad(u_y, txy)[0][:,[2]]
        
        eps = 0.025
        lam = 10.
        
        residual = u_t - lam * (eps**2 * (u_xx + u_yy) - u**3 + u)

        return residual

    
    def net_u(self, txy):
        u = self.model(txy)
        
        return u
    
    
    def loss(self, use_ad=False):
        self.r_pred = self.net_r(self.txy)
        self.g_pred = self.net_u(self.txy_ics)

        if use_ad:

            self.r_weights = self.Unet(self.txy)
            loss_r = torch.mean(self.r_weights * self.r_pred**2)
            loss_b = torch.mean((self.g_pred-self.u_ics)**2)
            loss = loss_r + 100*loss_b

        else:
            loss_r = torch.mean(self.r_pred**2)
            loss_b = torch.mean((self.g_pred-self.u_ics)**2)
            loss = loss_r + 100*loss_b

        return loss, loss_r, loss_b


    def train_Adam(self, mode='0'):
        """
        mode='0'：subnet参与计算，只训练主网络
        mode='1'：subnet参与计算，只训练subnet
        mode='2'：subnet参与计算，主网络和subnet对抗训练
        mode='3'：subnet不参与计算，只训练主网络
        """
        if mode == '0':
            self.optimizer_Adam.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()
            self.optimizer_Adam.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()
        
        elif mode == '1':
            self.optimizer_Adam_Unet.zero_grad()
            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()

            for name, parms in self.Unet.named_parameters():
                if parms.requires_grad==True:
                    parms.grad *= -1

            self.optimizer_Adam_Unet.step()        

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()

        elif mode == '2':
            self.optimizer_Adam.zero_grad()
            self.optimizer_Adam_Unet.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=True)
            loss_value.backward()
            self.optimizer_Adam.step()

            for name, parms in self.Unet.named_parameters():
                if parms.requires_grad==True:
                    parms.grad *= -1

            self.optimizer_Adam_Unet.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()

        else:
            self.optimizer_Adam.zero_grad()

            loss_value, loss_r_value, loss_b_value = self.loss(use_ad=False)
            loss_value.backward()
            self.optimizer_Adam.step()

            return loss_value.item(), loss_r_value.item(), loss_b_value.item()
        

    def train_LBFGS(self):
        loss_value, loss_r_value, loss_b_value = self.loss()
        
        def closure():
            loss_value, loss_r_value, loss_b_value = self.loss()

            self.optimizer_LBFGS.zero_grad()
            loss_value.backward()

            return loss_value

        self.optimizer_LBFGS.step(closure)
        loss_value = closure()
        
        return loss_value.item(), loss_r_value.item(), loss_b_value.item()
    
    
    def validate(self, epoch):
        self.model.eval()
        loss_value, loss_r_value, loss_b_value = self.loss()
        
        infos = 'Valid   ' + \
                f'Loss:{loss_value:.4e}  ' + \
                f'Loss_r:{loss_r_value:.4e} '
        print(infos)
        self.model.train()
        return loss_value.item()
    
    
    def save_both_model(self, step, epoch):
        # save backbone
        model_state = {
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
        }
        backbone = os.path.join(self.model_path, 'backbone_%s_%d.pth' % (step, epoch))
        torch.save(model_state, backbone)

        # save subnet
        subnet_state = {
            'epoch': epoch,
            'state_dict': self.Unet.state_dict(),
        }    
        subnet = os.path.join(self.model_path, 'subnet_%s_%d.pth' % (step, epoch))
        torch.save(subnet_state, subnet)

    
    def train(self):
        start = time.time()
        best_loss = 1.e10
        
        # 1.只训练主网络
        for epoch in range(10000):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='3')    
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 100 == 0:          
                # data
                self.txy, self.txy_ics, self.u_ics = args.trainset()
                
        # 2.只训练subnet      
        for epoch in range(5000):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='1')      
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 100 == 0:      
                # data
                self.txy, self.txy_ics, self.u_ics = args.trainset()
                
                
        # 3.主网络和subnet对抗，一起训练      
        for epoch in range(self.epochs_Adam):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='2')
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()
                self.scheduler_Unet.step()
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)  
                
            if (epoch+1) % 100 == 0:      
                # data
                self.txy, self.txy_ics, self.u_ics = args.trainset()
         
        
        # 使用最好的模型
        state_dict = torch.load(f'{self.model_path}/best_model.pth')
        self.model.load_state_dict(state_dict['state_dict'])
            
        # 4.只训练主网络主网络
        for epoch in range(self.epochs_Adam):
            loss_value, loss_r_value, loss_b_value = self.train_Adam(mode='3')
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)
            
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()         
            
            if (epoch+1) % 100 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)  
                
            if (epoch+1) % 100 == 0:
                # data
                self.txy, self.txy_ics, self.u_ics = args.trainset()

        # 5.lbfgs只训练主网络主网络    
        for epoch in range(self.epochs_LBFGS):
            loss_value, loss_r_value, loss_b_value = self.train_LBFGS()
            
            self.loss_log.append(loss_value)
            self.loss_r_log.append(loss_r_value)
            self.loss_b_log.append(loss_b_value)
            self.epoch_log.append(epoch)         
            
            if (epoch+1) % 1 == 0:
                running_time = time.time() - start
                start = time.time()
                
                print(f'Epoch #  {epoch+1}/{self.epochs_Adam + self.epochs_LBFGS}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_r:{loss_r_value:.2e}, loss_b:{loss_b_value:.2e},')  
                
                valid_loss = self.validate(epoch)
                is_best = valid_loss < best_loss
                state = {
                    'epoch': epoch,
                    'state_dict': self.model.state_dict(),
                    'best_loss': best_loss
                }
                save_model(state, is_best, save_dir=self.model_path)
                
            if (epoch+1) % 100 == 0:
                # data
                self.txy, self.txy_ics, self.u_ics = args.trainset()

# %%
args.Unet = Unet(dim_in=3)
trainer = Trainer_AC(args)
trainer.train()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch #  100/100000    time:3.39
# loss:1.15e+01, loss_r:9.38e-01, loss_b:1.05e-01,
# Valid   Loss:1.1298e+01  Loss_r:9.4284e-01
# Epoch #  200/100000    time:3.43
# loss:4.59e+00, loss_r:9.80e-01, loss_b:3.61e-02,
# Valid   Loss:4.5574e+00  Loss_r:9.7995e-01
# Epoch #  300/100000    time:3.38
# loss:2.81e+00, loss_r:9.92e-01, loss_b:1.81e-02,
# Valid   Loss:2.7905e+00  Loss_r:9.9082e-01
# Epoch #  400/100000    time:3.39
# loss:1.72e+00, loss_r:8.78e-01, loss_b:8.39e-03,
# Valid   Loss:1.7098e+00  Loss_r:8.7772e-01
# Epoch #  500/100000    time:3.44
# loss:1.30e+00, loss_r:9.43e-01, loss_b:3.62e-03,
# Valid   Loss:1.3005e+00  Loss_r:9.4202e-01
# Epoch #  600/100000    time:3.34
# loss:9.90e-01, loss_r:8.30e-01, loss_b:1.60e-03,
# Valid   Loss:9.8864e-01  Loss_r:8.2959e-01
# Epoch #  700/100000    time:3.39
# loss:9.66e-01, loss_r:8.76e-01, loss_b:9.03e-04,
# Valid   Loss:9.6491e-01  Loss_r:8.7512e-01
# Epoch #  800/100000    time:3.36
# loss:8.66e-01, loss_r:8.08e-01, loss_b:5.82e-04,
# Valid   Loss:8.6555e-01  Loss_r:8.0763e-01
# Epoch #  900/100000    time:3.38
# loss:8.59e-01, loss_r:8.24e-01, loss_b:3.55e-04,
# Valid   Loss:8.5841e-01  Loss_r:8.2304e-01
# Epoch #  1000/100000    time:3.40
# loss:8.01e-01, loss_r:7.72e-01, loss_b:2.88e-04,
# Valid   Loss:7.9996e-01  Loss_r:7.7122e-01
# Epoch #  1100/100000    time:3.38
# loss:8.39e-01, loss_r:8.17e-01, loss_b:2.26e-04,
# Valid   Loss:8.3867e-01  Loss_r:8.1614e-01
# Epoch #  1200/100000    time:3.41
# loss:7.60e-01, loss_r:7.43e-01, loss_b:1.71e-04,
# Valid   Loss:7.5972e-01  Loss_r:7.4269e-01
# Epoch #  1300/100000    time:3.38
# loss:7.65e-01, loss_r:7.51e-01, loss_b:1.45e-04,
# Valid   Loss:7.6492e-01  Loss_r:7.5044e-01
# Epoch #  1400/100000    time:3.40
# loss:7.83e-01, loss_r:7.70e-01, loss_b:1.35e-04,
# Valid   Loss:7.8258e-01  Loss_r:7.6913e-01
# Epoch #  1500/100000    time:3.42
# loss:7.64e-01, loss_r:7.52e-01, loss_b:1.18e-04,
# Valid   Loss:7.6351e-01  Loss_r:7.5171e-01
# Epoch #  1600/100000    time:3.49
# loss:7.74e-01, loss_r:7.64e-01, loss_b:1.07e-04,
# Valid   Loss:7.7381e-01  Loss_r:7.6315e-01
# Epoch #  1700/100000    time:3.42
# loss:7.36e-01, loss_r:7.25e-01, loss_b:1.05e-04,
# Valid   Loss:7.3525e-01  Loss_r:7.2479e-01
# Epoch #  1800/100000    time:3.34
# loss:7.61e-01, loss_r:7.51e-01, loss_b:9.51e-05,
# Valid   Loss:7.6050e-01  Loss_r:7.5099e-01
# Epoch #  1900/100000    time:3.35
# loss:7.71e-01, loss_r:7.62e-01, loss_b:8.61e-05,
# Valid   Loss:7.7039e-01  Loss_r:7.6178e-01
# Epoch #  2000/100000    time:3.38
# loss:7.06e-01, loss_r:6.98e-01, loss_b:8.60e-05,
# Valid   Loss:7.0578e-01  Loss_r:6.9719e-01
# Epoch #  2100/100000    time:3.34
# loss:7.48e-01, loss_r:7.41e-01, loss_b:7.12e-05,
# Valid   Loss:7.4765e-01  Loss_r:7.4053e-01
# Epoch #  2200/100000    time:3.36
# loss:7.12e-01, loss_r:7.05e-01, loss_b:7.65e-05,
# Valid   Loss:7.1191e-01  Loss_r:7.0426e-01
# Epoch #  2300/100000    time:3.35
# loss:7.31e-01, loss_r:7.24e-01, loss_b:6.85e-05,
# Valid   Loss:7.3070e-01  Loss_r:7.2385e-01
# Epoch #  2400/100000    time:3.37
# loss:7.31e-01, loss_r:7.24e-01, loss_b:6.56e-05,
# Valid   Loss:7.3027e-01  Loss_r:7.2371e-01
# Epoch #  2500/100000    time:3.41
# loss:6.94e-01, loss_r:6.87e-01, loss_b:6.79e-05,
# Valid   Loss:6.9348e-01  Loss_r:6.8670e-01
# Epoch #  2600/100000    time:3.28
# loss:6.83e-01, loss_r:6.76e-01, loss_b:6.87e-05,
# Valid   Loss:6.8278e-01  Loss_r:6.7590e-01
# Epoch #  2700/100000    time:3.28
# loss:7.27e-01, loss_r:7.20e-01, loss_b:7.41e-05,
# Valid   Loss:7.2686e-01  Loss_r:7.1944e-01
# Epoch #  2800/100000    time:3.32
# loss:6.66e-01, loss_r:6.59e-01, loss_b:6.86e-05,
# Valid   Loss:6.6554e-01  Loss_r:6.5868e-01
# Epoch #  2900/100000    time:3.26
# loss:7.11e-01, loss_r:7.03e-01, loss_b:7.70e-05,
# Valid   Loss:7.1008e-01  Loss_r:7.0237e-01
# Epoch #  3000/100000    time:3.24
# loss:6.84e-01, loss_r:6.76e-01, loss_b:7.99e-05,
# Valid   Loss:6.8335e-01  Loss_r:6.7535e-01
# Epoch #  3100/100000    time:3.25
# loss:6.70e-01, loss_r:6.62e-01, loss_b:7.18e-05,
# Valid   Loss:6.6908e-01  Loss_r:6.6190e-01
# Epoch #  3200/100000    time:3.30
# loss:6.74e-01, loss_r:6.64e-01, loss_b:9.26e-05,
# Valid   Loss:6.7294e-01  Loss_r:6.6367e-01
# Epoch #  3300/100000    time:3.42
# loss:6.39e-01, loss_r:6.29e-01, loss_b:9.32e-05,
# Valid   Loss:6.3805e-01  Loss_r:6.2872e-01
# Epoch #  3400/100000    time:3.32
# loss:6.42e-01, loss_r:6.34e-01, loss_b:8.54e-05,
# Valid   Loss:6.4181e-01  Loss_r:6.3327e-01
# Epoch #  3500/100000    time:3.23
# loss:6.43e-01, loss_r:6.35e-01, loss_b:8.19e-05,
# Valid   Loss:6.4271e-01  Loss_r:6.3453e-01
# Epoch #  3600/100000    time:3.26
# loss:5.88e-01, loss_r:5.79e-01, loss_b:8.83e-05,
# Valid   Loss:5.8761e-01  Loss_r:5.7877e-01
# Epoch #  3700/100000    time:3.26
# loss:5.75e-01, loss_r:5.66e-01, loss_b:8.81e-05,
# Valid   Loss:5.7398e-01  Loss_r:5.6517e-01
# Epoch #  3800/100000    time:3.35
# loss:6.28e-01, loss_r:6.19e-01, loss_b:8.91e-05,
# Valid   Loss:6.2745e-01  Loss_r:6.1853e-01
# Epoch #  3900/100000    time:3.27
# loss:5.75e-01, loss_r:5.67e-01, loss_b:7.86e-05,
# Valid   Loss:5.7435e-01  Loss_r:5.6649e-01
# Epoch #  4000/100000    time:3.27
# loss:5.87e-01, loss_r:5.80e-01, loss_b:6.92e-05,
# Valid   Loss:5.8631e-01  Loss_r:5.7939e-01
# Epoch #  4100/100000    time:3.27
# loss:5.96e-01, loss_r:5.88e-01, loss_b:8.09e-05,
# Valid   Loss:5.9495e-01  Loss_r:5.8685e-01
# Epoch #  4200/100000    time:3.27
# loss:5.50e-01, loss_r:5.43e-01, loss_b:7.87e-05,
# Valid   Loss:5.4959e-01  Loss_r:5.4173e-01
# Epoch #  4300/100000    time:3.23
# loss:5.37e-01, loss_r:5.29e-01, loss_b:8.41e-05,
# Valid   Loss:5.3666e-01  Loss_r:5.2825e-01
# Epoch #  4400/100000    time:3.23
# loss:5.33e-01, loss_r:5.26e-01, loss_b:7.09e-05,
# Valid   Loss:5.3273e-01  Loss_r:5.2564e-01
# Epoch #  4500/100000    time:3.23
# loss:4.98e-01, loss_r:4.90e-01, loss_b:7.93e-05,
# Valid   Loss:4.9736e-01  Loss_r:4.8943e-01
# Epoch #  4600/100000    time:3.23
# loss:4.57e-01, loss_r:4.49e-01, loss_b:8.47e-05,
# Valid   Loss:4.5633e-01  Loss_r:4.4786e-01
# Epoch #  4700/100000    time:3.25
# loss:4.91e-01, loss_r:4.82e-01, loss_b:8.52e-05,
# Valid   Loss:4.8994e-01  Loss_r:4.8142e-01
# Epoch #  4800/100000    time:3.24
# loss:4.31e-01, loss_r:4.23e-01, loss_b:7.44e-05,
# Valid   Loss:4.2993e-01  Loss_r:4.2249e-01
# Epoch #  4900/100000    time:3.23
# loss:4.69e-01, loss_r:4.60e-01, loss_b:9.23e-05,
# Valid   Loss:4.6799e-01  Loss_r:4.5876e-01
# Epoch #  5000/100000    time:3.26
# loss:4.69e-01, loss_r:4.60e-01, loss_b:8.83e-05,
# Valid   Loss:4.6811e-01  Loss_r:4.5928e-01
# Epoch #  5100/100000    time:3.26
# loss:4.86e-01, loss_r:4.76e-01, loss_b:1.01e-04,
# Valid   Loss:4.8487e-01  Loss_r:4.7480e-01
# Epoch #  5200/100000    time:3.30
# loss:4.94e-01, loss_r:4.85e-01, loss_b:9.04e-05,
# Valid   Loss:4.9364e-01  Loss_r:4.8460e-01
# Epoch #  5300/100000    time:3.26
# loss:4.13e-01, loss_r:4.05e-01, loss_b:8.63e-05,
# Valid   Loss:4.1237e-01  Loss_r:4.0374e-01
# Epoch #  5400/100000    time:3.27
# loss:4.30e-01, loss_r:4.22e-01, loss_b:8.20e-05,
# Valid   Loss:4.2936e-01  Loss_r:4.2114e-01
# Epoch #  5500/100000    time:3.27
# loss:4.49e-01, loss_r:4.42e-01, loss_b:7.66e-05,
# Valid   Loss:4.4841e-01  Loss_r:4.4075e-01
# Epoch #  5600/100000    time:3.26
# loss:3.92e-01, loss_r:3.84e-01, loss_b:7.07e-05,
# Valid   Loss:3.9080e-01  Loss_r:3.8373e-01
# Epoch #  5700/100000    time:3.23
# loss:4.17e-01, loss_r:4.09e-01, loss_b:7.41e-05,
# Valid   Loss:4.1595e-01  Loss_r:4.0854e-01
# Epoch #  5800/100000    time:3.23
# loss:3.68e-01, loss_r:3.60e-01, loss_b:8.73e-05,
# Valid   Loss:3.6738e-01  Loss_r:3.5864e-01
# Epoch #  5900/100000    time:3.23
# loss:3.60e-01, loss_r:3.51e-01, loss_b:9.15e-05,
# Valid   Loss:3.5920e-01  Loss_r:3.5005e-01
# Epoch #  6000/100000    time:3.24
# loss:3.76e-01, loss_r:3.66e-01, loss_b:9.51e-05,
# Valid   Loss:3.7477e-01  Loss_r:3.6526e-01
# Epoch #  6100/100000    time:3.27
# loss:3.82e-01, loss_r:3.73e-01, loss_b:8.78e-05,
# Valid   Loss:3.8123e-01  Loss_r:3.7245e-01
# Epoch #  6200/100000    time:3.27
# loss:3.43e-01, loss_r:3.33e-01, loss_b:9.95e-05,
# Valid   Loss:3.4183e-01  Loss_r:3.3189e-01
# Epoch #  6300/100000    time:3.25
# loss:3.53e-01, loss_r:3.44e-01, loss_b:8.83e-05,
# Valid   Loss:3.5179e-01  Loss_r:3.4301e-01
# Epoch #  6400/100000    time:3.27
# loss:3.52e-01, loss_r:3.42e-01, loss_b:1.08e-04,
# Valid   Loss:3.4708e-01  Loss_r:3.3654e-01
# Epoch #  6500/100000    time:3.27
# loss:3.30e-01, loss_r:3.19e-01, loss_b:1.03e-04,
# Valid   Loss:3.1955e-01  Loss_r:3.0971e-01
# Epoch #  6600/100000    time:3.34
# loss:3.23e-01, loss_r:3.12e-01, loss_b:1.15e-04,
# Valid   Loss:3.2138e-01  Loss_r:3.0996e-01
# Epoch #  6700/100000    time:3.28
# loss:3.10e-01, loss_r:2.98e-01, loss_b:1.13e-04,
# Valid   Loss:3.0823e-01  Loss_r:2.9691e-01
# Epoch #  6800/100000    time:3.31
# loss:5.49e-01, loss_r:5.28e-01, loss_b:2.13e-04,
# Valid   Loss:5.0123e-01  Loss_r:4.7906e-01
# Epoch #  6900/100000    time:3.28
# loss:2.95e-01, loss_r:2.85e-01, loss_b:1.08e-04,
# Valid   Loss:2.9407e-01  Loss_r:2.8333e-01
# Epoch #  7000/100000    time:3.26
# loss:2.86e-01, loss_r:2.74e-01, loss_b:1.19e-04,
# Valid   Loss:2.8653e-01  Loss_r:2.7453e-01
# Epoch #  7100/100000    time:3.26
# loss:2.71e-01, loss_r:2.60e-01, loss_b:1.17e-04,
# Valid   Loss:2.7026e-01  Loss_r:2.5862e-01
# Epoch #  7200/100000    time:3.28
# loss:4.08e-01, loss_r:3.88e-01, loss_b:2.03e-04,
# Valid   Loss:4.2941e-01  Loss_r:4.0543e-01
# Epoch #  7300/100000    time:3.23
# loss:2.36e-01, loss_r:2.24e-01, loss_b:1.20e-04,
# Valid   Loss:2.3486e-01  Loss_r:2.2293e-01
# Epoch #  7400/100000    time:3.24
# loss:3.02e-01, loss_r:2.89e-01, loss_b:1.35e-04,
# Valid   Loss:3.0107e-01  Loss_r:2.8764e-01
# Epoch #  7500/100000    time:3.24
# loss:2.60e-01, loss_r:2.51e-01, loss_b:9.76e-05,
# Valid   Loss:2.5937e-01  Loss_r:2.4969e-01
# Epoch #  7600/100000    time:3.24
# loss:2.60e-01, loss_r:2.49e-01, loss_b:1.12e-04,
# Valid   Loss:2.6066e-01  Loss_r:2.4946e-01
# Epoch #  7700/100000    time:3.30
# loss:3.18e-01, loss_r:3.01e-01, loss_b:1.75e-04,
# Valid   Loss:3.9612e-01  Loss_r:3.7386e-01
# Epoch #  7800/100000    time:3.31
# loss:2.73e-01, loss_r:2.60e-01, loss_b:1.30e-04,
# Valid   Loss:2.7175e-01  Loss_r:2.5884e-01
# Epoch #  7900/100000    time:3.30
# loss:2.70e-01, loss_r:2.59e-01, loss_b:1.07e-04,
# Valid   Loss:2.6828e-01  Loss_r:2.5757e-01
# Epoch #  8000/100000    time:3.30
# loss:3.17e-01, loss_r:3.06e-01, loss_b:1.08e-04,
# Valid   Loss:3.2259e-01  Loss_r:3.1038e-01
# Epoch #  8100/100000    time:3.28
# loss:2.95e-01, loss_r:2.87e-01, loss_b:7.95e-05,
# Valid   Loss:2.9371e-01  Loss_r:2.8576e-01
# Epoch #  8200/100000    time:3.28
# loss:3.43e-01, loss_r:3.31e-01, loss_b:1.18e-04,
# Valid   Loss:3.3750e-01  Loss_r:3.2569e-01
# Epoch #  8300/100000    time:3.32
# loss:5.64e-01, loss_r:5.30e-01, loss_b:3.42e-04,
# Valid   Loss:7.3795e-01  Loss_r:6.9460e-01
# Epoch #  8400/100000    time:3.25
# loss:2.47e-01, loss_r:2.39e-01, loss_b:7.52e-05,
# Valid   Loss:2.4596e-01  Loss_r:2.3847e-01
# Epoch #  8500/100000    time:3.24
# loss:2.57e-01, loss_r:2.47e-01, loss_b:1.04e-04,
# Valid   Loss:2.5216e-01  Loss_r:2.4271e-01
# Epoch #  8600/100000    time:3.23
# loss:2.55e-01, loss_r:2.44e-01, loss_b:1.14e-04,
# Valid   Loss:2.6531e-01  Loss_r:2.5384e-01
# Epoch #  8700/100000    time:3.24
# loss:2.12e-01, loss_r:2.03e-01, loss_b:8.94e-05,
# Valid   Loss:2.1149e-01  Loss_r:2.0267e-01
# Epoch #  8800/100000    time:3.26
# loss:2.70e-01, loss_r:2.59e-01, loss_b:1.08e-04,
# Valid   Loss:2.6897e-01  Loss_r:2.5821e-01
# Epoch #  8900/100000    time:3.25
# loss:2.48e-01, loss_r:2.40e-01, loss_b:8.36e-05,
# Valid   Loss:2.5198e-01  Loss_r:2.4273e-01
# Epoch #  9000/100000    time:3.29
# loss:2.67e-01, loss_r:2.59e-01, loss_b:7.85e-05,
# Valid   Loss:2.6531e-01  Loss_r:2.5749e-01
# Epoch #  9100/100000    time:3.28
# loss:2.47e-01, loss_r:2.39e-01, loss_b:8.10e-05,
# Valid   Loss:2.4583e-01  Loss_r:2.3775e-01
# Epoch #  9200/100000    time:3.29
# loss:2.34e-01, loss_r:2.23e-01, loss_b:1.05e-04,
# Valid   Loss:2.2137e-01  Loss_r:2.1240e-01
# Epoch #  9300/100000    time:3.28
# loss:3.16e-01, loss_r:3.03e-01, loss_b:1.35e-04,
# Valid   Loss:2.7702e-01  Loss_r:2.6736e-01
# Epoch #  9400/100000    time:3.35
# loss:2.27e-01, loss_r:2.18e-01, loss_b:8.24e-05,
# Valid   Loss:2.2552e-01  Loss_r:2.1731e-01
# Epoch #  9500/100000    time:3.32
# loss:2.14e-01, loss_r:2.03e-01, loss_b:1.19e-04,
# Valid   Loss:2.9359e-01  Loss_r:2.7356e-01
# Epoch #  9600/100000    time:3.30
# loss:2.31e-01, loss_r:2.23e-01, loss_b:8.23e-05,
# Valid   Loss:2.3050e-01  Loss_r:2.2222e-01
# Epoch #  9700/100000    time:3.31
# loss:3.11e-01, loss_r:2.88e-01, loss_b:2.30e-04,
# Valid   Loss:2.3530e-01  Loss_r:2.2066e-01
# Epoch #  9800/100000    time:3.26
# loss:2.13e-01, loss_r:2.06e-01, loss_b:7.55e-05,
# Valid   Loss:2.1657e-01  Loss_r:2.0915e-01
# Epoch #  9900/100000    time:3.26
# loss:2.17e-01, loss_r:2.09e-01, loss_b:7.92e-05,
# Valid   Loss:2.1381e-01  Loss_r:2.0582e-01
# Epoch #  10000/100000    time:3.26
# loss:2.07e-01, loss_r:1.98e-01, loss_b:9.16e-05,
# Valid   Loss:2.0097e-01  Loss_r:1.9195e-01
# Epoch #  100/100000    time:3.39
# loss:6.86e+00, loss_r:6.84e+00, loss_b:1.65e-04,
# Valid   Loss:1.1274e+00  Loss_r:1.1109e+00
# Epoch #  200/100000    time:3.38
# loss:1.04e+01, loss_r:1.04e+01, loss_b:1.59e-04,
# Valid   Loss:1.3802e+00  Loss_r:1.3643e+00
# Epoch #  300/100000    time:3.38
# loss:8.16e+00, loss_r:8.14e+00, loss_b:1.83e-04,
# Valid   Loss:1.0528e+00  Loss_r:1.0345e+00
# Epoch #  400/100000    time:3.40
# loss:2.17e+01, loss_r:2.16e+01, loss_b:1.79e-04,
# Valid   Loss:2.2882e+00  Loss_r:2.2704e+00
# Epoch #  500/100000    time:3.41
# loss:1.57e+01, loss_r:1.56e+01, loss_b:1.83e-04,
# Valid   Loss:1.7068e+00  Loss_r:1.6885e+00
# Epoch #  600/100000    time:3.41
# loss:9.40e+00, loss_r:9.38e+00, loss_b:1.94e-04,
# Valid   Loss:8.8810e-01  Loss_r:8.6871e-01
# Epoch #  700/100000    time:3.43
# loss:1.97e+01, loss_r:1.97e+01, loss_b:1.96e-04,
# Valid   Loss:1.8019e+00  Loss_r:1.7823e+00
# Epoch #  800/100000    time:3.43
# loss:1.75e+01, loss_r:1.75e+01, loss_b:1.68e-04,
# Valid   Loss:1.5955e+00  Loss_r:1.5787e+00
# Epoch #  900/100000    time:3.44
# loss:9.85e+00, loss_r:9.84e+00, loss_b:1.73e-04,
# Valid   Loss:8.5438e-01  Loss_r:8.3704e-01
# Epoch #  1000/100000    time:3.43
# loss:1.40e+01, loss_r:1.40e+01, loss_b:1.80e-04,
# Valid   Loss:1.1535e+00  Loss_r:1.1355e+00
# Epoch #  1100/100000    time:3.40
# loss:1.27e+01, loss_r:1.27e+01, loss_b:1.69e-04,
# Valid   Loss:1.0549e+00  Loss_r:1.0380e+00
# Epoch #  1200/100000    time:3.39
# loss:1.57e+01, loss_r:1.57e+01, loss_b:1.87e-04,
# Valid   Loss:1.2659e+00  Loss_r:1.2472e+00
# Epoch #  1300/100000    time:3.38
# loss:1.85e+01, loss_r:1.84e+01, loss_b:1.93e-04,
# Valid   Loss:1.3813e+00  Loss_r:1.3620e+00
# Epoch #  1400/100000    time:3.40
# loss:8.62e+00, loss_r:8.60e+00, loss_b:2.05e-04,
# Valid   Loss:6.9697e-01  Loss_r:6.7643e-01
# Epoch #  1500/100000    time:3.38
# loss:1.53e+01, loss_r:1.53e+01, loss_b:2.00e-04,
# Valid   Loss:1.1185e+00  Loss_r:1.0984e+00
# Epoch #  1600/100000    time:3.42
# loss:2.10e+01, loss_r:2.09e+01, loss_b:1.63e-04,
# Valid   Loss:1.6435e+00  Loss_r:1.6272e+00
# Epoch #  1700/100000    time:3.38
# loss:1.88e+01, loss_r:1.88e+01, loss_b:1.84e-04,
# Valid   Loss:1.2806e+00  Loss_r:1.2622e+00
# Epoch #  1800/100000    time:3.40
# loss:2.52e+01, loss_r:2.52e+01, loss_b:2.09e-04,
# Valid   Loss:1.8088e+00  Loss_r:1.7879e+00
# Epoch #  1900/100000    time:3.41
# loss:1.21e+01, loss_r:1.21e+01, loss_b:1.53e-04,
# Valid   Loss:8.5690e-01  Loss_r:8.4165e-01
# Epoch #  2000/100000    time:3.43
# loss:2.58e+01, loss_r:2.58e+01, loss_b:1.73e-04,
# Valid   Loss:1.7390e+00  Loss_r:1.7218e+00
# Epoch #  2100/100000    time:3.42
# loss:2.52e+01, loss_r:2.51e+01, loss_b:1.83e-04,
# Valid   Loss:1.6298e+00  Loss_r:1.6115e+00
# Epoch #  2200/100000    time:3.40
# loss:1.17e+01, loss_r:1.17e+01, loss_b:1.84e-04,
# Valid   Loss:8.5873e-01  Loss_r:8.4029e-01
# Epoch #  2300/100000    time:3.44
# loss:3.67e+01, loss_r:3.67e+01, loss_b:1.78e-04,
# Valid   Loss:2.6317e+00  Loss_r:2.6139e+00
# Epoch #  2400/100000    time:3.41
# loss:1.40e+01, loss_r:1.40e+01, loss_b:1.87e-04,
# Valid   Loss:9.6889e-01  Loss_r:9.5023e-01
# Epoch #  2500/100000    time:3.38
# loss:3.89e+01, loss_r:3.89e+01, loss_b:1.98e-04,
# Valid   Loss:2.2581e+00  Loss_r:2.2383e+00
# Epoch #  2600/100000    time:3.37
# loss:1.76e+01, loss_r:1.76e+01, loss_b:1.65e-04,
# Valid   Loss:1.1154e+00  Loss_r:1.0989e+00
# Epoch #  2700/100000    time:3.40
# loss:2.31e+01, loss_r:2.31e+01, loss_b:1.76e-04,
# Valid   Loss:1.3956e+00  Loss_r:1.3780e+00
# Epoch #  2800/100000    time:3.39
# loss:9.55e+00, loss_r:9.53e+00, loss_b:1.75e-04,
# Valid   Loss:6.3371e-01  Loss_r:6.1617e-01
# Epoch #  2900/100000    time:3.39
# loss:1.16e+01, loss_r:1.16e+01, loss_b:1.71e-04,
# Valid   Loss:7.8118e-01  Loss_r:7.6403e-01
# Epoch #  3000/100000    time:3.41
# loss:1.21e+01, loss_r:1.21e+01, loss_b:1.86e-04,
# Valid   Loss:7.6980e-01  Loss_r:7.5122e-01
# Epoch #  3100/100000    time:3.39
# loss:2.71e+01, loss_r:2.71e+01, loss_b:1.87e-04,
# Valid   Loss:1.5896e+00  Loss_r:1.5709e+00
# Epoch #  3200/100000    time:3.43
# loss:2.18e+01, loss_r:2.17e+01, loss_b:1.68e-04,
# Valid   Loss:1.3062e+00  Loss_r:1.2894e+00
# Epoch #  3300/100000    time:3.44
# loss:2.81e+01, loss_r:2.81e+01, loss_b:1.82e-04,
# Valid   Loss:1.5116e+00  Loss_r:1.4934e+00
# Epoch #  3400/100000    time:3.42
# loss:2.17e+01, loss_r:2.17e+01, loss_b:1.87e-04,
# Valid   Loss:1.2886e+00  Loss_r:1.2700e+00
# Epoch #  3500/100000    time:3.41
# loss:1.69e+01, loss_r:1.69e+01, loss_b:1.91e-04,
# Valid   Loss:9.7385e-01  Loss_r:9.5478e-01
# Epoch #  3600/100000    time:3.41
# loss:2.06e+01, loss_r:2.06e+01, loss_b:1.87e-04,
# Valid   Loss:1.1695e+00  Loss_r:1.1507e+00
# Epoch #  3700/100000    time:3.41
# loss:1.91e+01, loss_r:1.91e+01, loss_b:1.93e-04,
# Valid   Loss:1.1446e+00  Loss_r:1.1253e+00
# Epoch #  3800/100000    time:3.37
# loss:1.43e+01, loss_r:1.43e+01, loss_b:2.00e-04,
# Valid   Loss:8.6577e-01  Loss_r:8.4580e-01
# Epoch #  3900/100000    time:3.40
# loss:1.39e+01, loss_r:1.39e+01, loss_b:1.79e-04,
# Valid   Loss:8.1299e-01  Loss_r:7.9506e-01
# Epoch #  4000/100000    time:3.38
# loss:3.44e+01, loss_r:3.44e+01, loss_b:1.78e-04,
# Valid   Loss:1.7312e+00  Loss_r:1.7134e+00
# Epoch #  4100/100000    time:3.38
# loss:4.72e+01, loss_r:4.72e+01, loss_b:1.65e-04,
# Valid   Loss:2.4982e+00  Loss_r:2.4817e+00
# Epoch #  4200/100000    time:3.43
# loss:1.74e+01, loss_r:1.74e+01, loss_b:1.88e-04,
# Valid   Loss:9.1420e-01  Loss_r:8.9544e-01
# Epoch #  4300/100000    time:3.38
# loss:3.84e+01, loss_r:3.84e+01, loss_b:1.72e-04,
# Valid   Loss:1.9085e+00  Loss_r:1.8913e+00
# Epoch #  4400/100000    time:3.37
# loss:2.06e+01, loss_r:2.05e+01, loss_b:1.90e-04,
# Valid   Loss:1.0413e+00  Loss_r:1.0224e+00
# Epoch #  4500/100000    time:3.43
# loss:2.24e+01, loss_r:2.24e+01, loss_b:1.71e-04,
# Valid   Loss:1.1324e+00  Loss_r:1.1153e+00
# Epoch #  4600/100000    time:3.41
# loss:1.86e+01, loss_r:1.86e+01, loss_b:1.74e-04,
# Valid   Loss:9.6620e-01  Loss_r:9.4876e-01
# Epoch #  4700/100000    time:3.44
# loss:3.90e+01, loss_r:3.89e+01, loss_b:1.87e-04,
# Valid   Loss:2.0959e+00  Loss_r:2.0772e+00
# Epoch #  4800/100000    time:3.45
# loss:1.93e+01, loss_r:1.93e+01, loss_b:1.80e-04,
# Valid   Loss:9.5730e-01  Loss_r:9.3932e-01
# Epoch #  4900/100000    time:3.44
# loss:2.27e+01, loss_r:2.26e+01, loss_b:1.72e-04,
# Valid   Loss:1.1035e+00  Loss_r:1.0864e+00
# Epoch #  5000/100000    time:3.43
# loss:1.44e+01, loss_r:1.43e+01, loss_b:2.10e-04,
# Valid   Loss:7.7321e-01  Loss_r:7.5221e-01
# Epoch #  100/100000    time:3.46
# loss:1.05e+00, loss_r:1.02e+00, loss_b:3.37e-04,
# Valid   Loss:8.0021e-01  Loss_r:7.6677e-01
# Epoch #  200/100000    time:3.48
# loss:3.38e-01, loss_r:3.06e-01, loss_b:3.18e-04,
# Valid   Loss:5.1459e-01  Loss_r:4.8322e-01
# Epoch #  300/100000    time:3.42
# loss:1.37e-01, loss_r:1.20e-01, loss_b:1.68e-04,
# Valid   Loss:1.7344e-01  Loss_r:1.5686e-01
# Epoch #  400/100000    time:3.44
# loss:7.04e-02, loss_r:5.94e-02, loss_b:1.10e-04,
# Valid   Loss:9.8874e-02  Loss_r:8.7922e-02
# Epoch #  500/100000    time:3.44
# loss:6.59e-02, loss_r:5.51e-02, loss_b:1.08e-04,
# Valid   Loss:1.0004e-01  Loss_r:8.7638e-02
# Epoch #  600/100000    time:3.44
# loss:4.40e-02, loss_r:3.73e-02, loss_b:6.74e-05,
# Valid   Loss:6.5691e-02  Loss_r:5.8964e-02
# Epoch #  700/100000    time:3.45
# loss:3.43e-02, loss_r:2.85e-02, loss_b:5.74e-05,
# Valid   Loss:5.4248e-02  Loss_r:4.8441e-02
# Epoch #  800/100000    time:3.49
# loss:4.16e-02, loss_r:3.48e-02, loss_b:6.84e-05,
# Valid   Loss:6.9078e-02  Loss_r:6.1012e-02
# Epoch #  900/100000    time:3.48
# loss:1.70e-01, loss_r:1.36e-01, loss_b:3.41e-04,
# Valid   Loss:3.1028e-01  Loss_r:2.5555e-01
# Epoch #  1000/100000    time:3.50
# loss:2.05e-01, loss_r:1.63e-01, loss_b:4.16e-04,
# Valid   Loss:2.0879e-01  Loss_r:1.7148e-01
# Epoch #  1100/100000    time:3.54
# loss:5.19e-02, loss_r:4.20e-02, loss_b:9.91e-05,
# Valid   Loss:8.0806e-02  Loss_r:6.9865e-02
# Epoch #  1200/100000    time:3.49
# loss:3.46e-02, loss_r:2.86e-02, loss_b:6.01e-05,
# Valid   Loss:5.7263e-02  Loss_r:5.1119e-02
# Epoch #  1300/100000    time:3.49
# loss:1.27e-01, loss_r:1.00e-01, loss_b:2.66e-04,
# Valid   Loss:1.8101e-01  Loss_r:1.5111e-01
# Epoch #  1400/100000    time:3.45
# loss:2.18e-02, loss_r:1.85e-02, loss_b:3.25e-05,
# Valid   Loss:4.2461e-02  Loss_r:3.8673e-02
# Epoch #  1500/100000    time:3.46
# loss:1.51e-02, loss_r:1.33e-02, loss_b:1.83e-05,
# Valid   Loss:3.0046e-02  Loss_r:2.8211e-02
# Epoch #  1600/100000    time:3.43
# loss:1.48e-02, loss_r:1.29e-02, loss_b:1.87e-05,
# Valid   Loss:3.0162e-02  Loss_r:2.8279e-02
# Epoch #  1700/100000    time:3.44
# loss:1.51e-02, loss_r:1.33e-02, loss_b:1.82e-05,
# Valid   Loss:2.9397e-02  Loss_r:2.7649e-02
# Epoch #  1800/100000    time:3.47
# loss:4.53e-02, loss_r:3.67e-02, loss_b:8.52e-05,
# Valid   Loss:6.5124e-02  Loss_r:5.5757e-02
# Epoch #  1900/100000    time:3.46
# loss:5.97e-02, loss_r:4.85e-02, loss_b:1.12e-04,
# Valid   Loss:7.0290e-02  Loss_r:5.9963e-02
# Epoch #  2000/100000    time:3.48
# loss:1.20e-02, loss_r:1.07e-02, loss_b:1.27e-05,
# Valid   Loss:2.6236e-02  Loss_r:2.4893e-02
# Epoch #  2100/100000    time:3.49
# loss:1.04e-02, loss_r:9.30e-03, loss_b:1.10e-05,
# Valid   Loss:2.2466e-02  Loss_r:2.1368e-02
# Epoch #  2200/100000    time:3.47
# loss:1.20e-02, loss_r:1.06e-02, loss_b:1.41e-05,
# Valid   Loss:2.3765e-02  Loss_r:2.2373e-02
# Epoch #  2300/100000    time:3.49
# loss:2.12e-02, loss_r:1.80e-02, loss_b:3.18e-05,
# Valid   Loss:3.0775e-02  Loss_r:2.7808e-02
# Epoch #  2400/100000    time:3.49
# loss:2.25e-02, loss_r:1.84e-02, loss_b:4.03e-05,
# Valid   Loss:2.8962e-02  Loss_r:2.6866e-02
# Epoch #  2500/100000    time:3.50
# loss:1.23e-02, loss_r:1.07e-02, loss_b:1.56e-05,
# Valid   Loss:2.3239e-02  Loss_r:2.2100e-02
# Epoch #  2600/100000    time:3.49
# loss:3.28e-02, loss_r:2.68e-02, loss_b:6.06e-05,
# Valid   Loss:5.8519e-02  Loss_r:5.1082e-02
# Epoch #  2700/100000    time:3.45
# loss:1.12e-02, loss_r:9.84e-03, loss_b:1.33e-05,
# Valid   Loss:2.0504e-02  Loss_r:1.9317e-02
# Epoch #  2800/100000    time:3.43
# loss:6.20e-02, loss_r:4.98e-02, loss_b:1.22e-04,
# Valid   Loss:8.5910e-02  Loss_r:7.1594e-02
# Epoch #  2900/100000    time:3.46
# loss:7.07e-03, loss_r:6.49e-03, loss_b:5.79e-06,
# Valid   Loss:1.7053e-02  Loss_r:1.6462e-02
# Epoch #  3000/100000    time:3.43
# loss:2.04e-02, loss_r:1.69e-02, loss_b:3.50e-05,
# Valid   Loss:3.3892e-02  Loss_r:2.9701e-02
# Epoch #  3100/100000    time:3.46
# loss:3.13e-02, loss_r:2.57e-02, loss_b:5.63e-05,
# Valid   Loss:3.8945e-02  Loss_r:3.3490e-02
# Epoch #  3200/100000    time:3.46
# loss:1.38e-02, loss_r:1.16e-02, loss_b:2.12e-05,
# Valid   Loss:2.7166e-02  Loss_r:2.4686e-02
# Epoch #  3300/100000    time:3.45
# loss:1.82e-02, loss_r:1.50e-02, loss_b:3.25e-05,
# Valid   Loss:3.0307e-02  Loss_r:2.7100e-02
# Epoch #  3400/100000    time:3.50
# loss:4.63e-02, loss_r:3.66e-02, loss_b:9.65e-05,
# Valid   Loss:6.0413e-02  Loss_r:5.1811e-02
# Epoch #  3500/100000    time:3.46
# loss:7.91e-02, loss_r:6.19e-02, loss_b:1.71e-04,
# Valid   Loss:8.1355e-02  Loss_r:6.6569e-02
# Epoch #  3600/100000    time:3.49
# loss:2.65e-02, loss_r:2.11e-02, loss_b:5.38e-05,
# Valid   Loss:3.3617e-02  Loss_r:2.9555e-02
# Epoch #  3700/100000    time:3.49
# loss:1.30e-02, loss_r:1.09e-02, loss_b:2.13e-05,
# Valid   Loss:2.2416e-02  Loss_r:2.0201e-02
# Epoch #  3800/100000    time:3.54
# loss:4.87e-03, loss_r:4.46e-03, loss_b:4.11e-06,
# Valid   Loss:1.1368e-02  Loss_r:1.1020e-02
# Epoch #  3900/100000    time:3.48
# loss:1.84e-02, loss_r:1.51e-02, loss_b:3.32e-05,
# Valid   Loss:3.1243e-02  Loss_r:2.6601e-02
# Epoch #  4000/100000    time:3.43
# loss:4.01e-03, loss_r:3.72e-03, loss_b:2.97e-06,
# Valid   Loss:9.3411e-03  Loss_r:9.0440e-03
# Epoch #  4100/100000    time:3.43
# loss:3.82e-03, loss_r:3.54e-03, loss_b:2.84e-06,
# Valid   Loss:8.9954e-03  Loss_r:8.7103e-03
# Epoch #  4200/100000    time:3.43
# loss:6.06e-02, loss_r:4.69e-02, loss_b:1.38e-04,
# Valid   Loss:4.9383e-02  Loss_r:4.3141e-02
# Epoch #  4300/100000    time:3.43
# loss:4.08e-03, loss_r:3.66e-03, loss_b:4.18e-06,
# Valid   Loss:9.9869e-03  Loss_r:9.4213e-03
# Epoch #  4400/100000    time:3.44
# loss:7.52e-03, loss_r:6.39e-03, loss_b:1.13e-05,
# Valid   Loss:1.1779e-02  Loss_r:1.0603e-02
# Epoch #  4500/100000    time:3.46
# loss:1.90e-02, loss_r:1.52e-02, loss_b:3.81e-05,
# Valid   Loss:2.1716e-02  Loss_r:1.8186e-02
# Epoch #  4600/100000    time:3.45
# loss:1.88e-02, loss_r:1.46e-02, loss_b:4.15e-05,
# Valid   Loss:1.8305e-02  Loss_r:1.5728e-02
# Epoch #  4700/100000    time:3.54
# loss:4.27e-03, loss_r:3.77e-03, loss_b:4.96e-06,
# Valid   Loss:8.5358e-03  Loss_r:8.0717e-03
# Epoch #  4800/100000    time:3.47
# loss:5.69e-02, loss_r:4.37e-02, loss_b:1.32e-04,
# Valid   Loss:8.5307e-02  Loss_r:6.9093e-02
# Epoch #  4900/100000    time:3.50
# loss:5.15e-03, loss_r:4.43e-03, loss_b:7.19e-06,
# Valid   Loss:7.9393e-03  Loss_r:7.4114e-03
# Adjusting learning rate of group 0 to 9.0000e-04.
# Adjusting learning rate of group 0 to 9.0000e-04.
# Epoch #  5000/100000    time:3.52
# loss:1.62e-01, loss_r:1.24e-01, loss_b:3.77e-04,
# Valid   Loss:2.0567e-01  Loss_r:1.5944e-01
# Epoch #  5100/100000    time:3.52
# loss:2.46e-03, loss_r:2.29e-03, loss_b:1.70e-06,
# Valid   Loss:5.6027e-03  Loss_r:5.4328e-03
# Epoch #  5200/100000    time:3.50
# loss:2.26e-03, loss_r:2.10e-03, loss_b:1.57e-06,
# Valid   Loss:5.0356e-03  Loss_r:4.8793e-03
# Epoch #  5300/100000    time:3.47
# loss:2.91e-03, loss_r:2.56e-03, loss_b:3.52e-06,
# Valid   Loss:6.0334e-03  Loss_r:5.6551e-03
# Epoch #  5400/100000    time:3.43
# loss:1.02e-01, loss_r:7.88e-02, loss_b:2.27e-04,
# Valid   Loss:9.3104e-02  Loss_r:7.1995e-02
# Epoch #  5500/100000    time:3.43
# loss:6.01e-02, loss_r:4.55e-02, loss_b:1.46e-04,
# Valid   Loss:6.9474e-02  Loss_r:5.5842e-02
# Epoch #  5600/100000    time:3.51
# loss:1.01e-02, loss_r:8.01e-03, loss_b:2.13e-05,
# Valid   Loss:1.5239e-02  Loss_r:1.2807e-02
# Epoch #  5700/100000    time:3.45
# loss:1.51e-01, loss_r:1.16e-01, loss_b:3.46e-04,
# Valid   Loss:1.1258e-01  Loss_r:8.3856e-02
# Epoch #  5800/100000    time:3.45
# loss:1.04e-02, loss_r:8.31e-03, loss_b:2.04e-05,
# Valid   Loss:2.2103e-02  Loss_r:1.8139e-02
# Epoch #  5900/100000    time:3.45
# loss:7.28e-03, loss_r:5.85e-03, loss_b:1.43e-05,
# Valid   Loss:1.1188e-02  Loss_r:9.6576e-03
# Epoch #  6000/100000    time:3.52
# loss:2.49e-02, loss_r:1.88e-02, loss_b:6.18e-05,
# Valid   Loss:2.5987e-02  Loss_r:2.0963e-02
# Epoch #  6100/100000    time:3.48
# loss:8.04e-02, loss_r:6.69e-02, loss_b:1.35e-04,
# Valid   Loss:1.5237e-01  Loss_r:1.3092e-01
# Epoch #  6200/100000    time:3.52
# loss:1.92e-03, loss_r:1.78e-03, loss_b:1.35e-06,
# Valid   Loss:3.8231e-03  Loss_r:3.6876e-03
# Epoch #  6300/100000    time:3.51
# loss:1.53e-03, loss_r:1.43e-03, loss_b:1.00e-06,
# Valid   Loss:3.1497e-03  Loss_r:3.0497e-03
# Epoch #  6400/100000    time:3.55
# loss:1.63e-03, loss_r:1.51e-03, loss_b:1.23e-06,
# Valid   Loss:3.4029e-03  Loss_r:3.2734e-03
# Epoch #  6500/100000    time:3.50
# loss:1.83e-03, loss_r:1.65e-03, loss_b:1.72e-06,
# Valid   Loss:3.2695e-03  Loss_r:3.1508e-03
# Epoch #  6600/100000    time:3.42
# loss:1.95e-02, loss_r:1.49e-02, loss_b:4.58e-05,
# Valid   Loss:2.5902e-02  Loss_r:2.0695e-02
# Epoch #  6700/100000    time:3.43
# loss:1.25e-01, loss_r:9.56e-02, loss_b:2.97e-04,
# Valid   Loss:1.8197e-01  Loss_r:1.5178e-01
# Epoch #  6800/100000    time:3.44
# loss:4.03e-03, loss_r:3.27e-03, loss_b:7.55e-06,
# Valid   Loss:6.3551e-03  Loss_r:5.3763e-03
# Epoch #  6900/100000    time:3.49
# loss:7.65e-03, loss_r:6.08e-03, loss_b:1.57e-05,
# Valid   Loss:1.1707e-02  Loss_r:9.6272e-03
# Epoch #  7000/100000    time:3.45
# loss:1.31e-03, loss_r:1.22e-03, loss_b:8.49e-07,
# Valid   Loss:2.3780e-03  Loss_r:2.2931e-03
# Epoch #  7100/100000    time:3.43
# loss:6.96e-03, loss_r:5.51e-03, loss_b:1.45e-05,
# Valid   Loss:6.7082e-03  Loss_r:5.8060e-03
# Epoch #  7200/100000    time:3.42
# loss:1.88e+02, loss_r:1.40e+02, loss_b:4.74e-01,
# Valid   Loss:5.9438e+01  Loss_r:1.0953e+01
# Epoch #  7300/100000    time:3.52
# loss:3.05e+01, loss_r:1.08e+01, loss_b:1.97e-01,
# Valid   Loss:2.0436e+01  Loss_r:9.9535e-01
# Epoch #  7400/100000    time:3.49
# loss:1.64e+01, loss_r:1.10e+01, loss_b:5.34e-02,
# Valid   Loss:6.0400e+00  Loss_r:7.5674e-01
# Epoch #  7500/100000    time:3.49
# loss:6.81e+00, loss_r:4.55e+00, loss_b:2.26e-02,
# Valid   Loss:5.1781e+00  Loss_r:2.9376e+00
# Epoch #  7600/100000    time:3.48
# loss:3.78e+00, loss_r:2.63e+00, loss_b:1.15e-02,
# Valid   Loss:1.5856e+00  Loss_r:4.4704e-01
# Epoch #  7700/100000    time:3.50
# loss:3.63e+00, loss_r:2.37e+00, loss_b:1.25e-02,
# Valid   Loss:2.2847e+00  Loss_r:1.0404e+00
# Epoch #  7800/100000    time:3.50
# loss:4.24e+00, loss_r:2.64e+00, loss_b:1.60e-02,
# Valid   Loss:2.5230e+00  Loss_r:9.3530e-01
# Epoch #  7900/100000    time:3.44
# loss:2.55e+00, loss_r:1.70e+00, loss_b:8.55e-03,
# Valid   Loss:1.6581e+00  Loss_r:8.0748e-01
# Epoch #  8000/100000    time:3.43
# loss:2.17e+00, loss_r:1.48e+00, loss_b:6.89e-03,
# Valid   Loss:1.5489e+00  Loss_r:8.6260e-01
# Epoch #  8100/100000    time:3.43
# loss:1.92e+00, loss_r:1.32e+00, loss_b:5.96e-03,
# Valid   Loss:1.4639e+00  Loss_r:8.6950e-01
# Epoch #  8200/100000    time:3.49
# loss:1.60e+00, loss_r:1.18e+00, loss_b:4.27e-03,
# Valid   Loss:1.2777e+00  Loss_r:8.5181e-01
# Epoch #  8300/100000    time:3.44
# loss:1.26e+00, loss_r:8.99e-01, loss_b:3.65e-03,
# Valid   Loss:1.0369e+00  Loss_r:6.7336e-01
# Epoch #  8400/100000    time:3.47
# loss:1.31e+00, loss_r:9.60e-01, loss_b:3.48e-03,
# Valid   Loss:9.8332e-01  Loss_r:6.3674e-01
# Epoch #  8500/100000    time:3.45
# loss:1.28e+00, loss_r:9.13e-01, loss_b:3.63e-03,
# Valid   Loss:1.0018e+00  Loss_r:6.4001e-01
# Epoch #  8600/100000    time:3.53
# loss:1.04e+00, loss_r:7.76e-01, loss_b:2.62e-03,
# Valid   Loss:8.8314e-01  Loss_r:6.2199e-01
# Epoch #  8700/100000    time:3.50
# loss:9.22e-01, loss_r:7.14e-01, loss_b:2.08e-03,
# Valid   Loss:7.2324e-01  Loss_r:5.1613e-01
# Epoch #  8800/100000    time:3.56
# loss:9.03e-01, loss_r:6.80e-01, loss_b:2.23e-03,
# Valid   Loss:8.6783e-01  Loss_r:6.4518e-01
# Epoch #  8900/100000    time:3.48
# loss:8.09e-01, loss_r:6.27e-01, loss_b:1.81e-03,
# Valid   Loss:9.8355e-01  Loss_r:8.0270e-01
# Epoch #  9000/100000    time:3.48
# loss:6.01e-01, loss_r:4.51e-01, loss_b:1.50e-03,
# Valid   Loss:6.4488e-01  Loss_r:4.9511e-01
# Epoch #  9100/100000    time:3.52
# loss:5.53e-01, loss_r:4.04e-01, loss_b:1.49e-03,
# Valid   Loss:5.4206e-01  Loss_r:3.9338e-01
# Epoch #  9200/100000    time:3.48
# loss:4.53e-01, loss_r:3.17e-01, loss_b:1.35e-03,
# Valid   Loss:5.0214e-01  Loss_r:3.6730e-01
# Epoch #  9300/100000    time:3.44
# loss:5.10e-01, loss_r:3.70e-01, loss_b:1.40e-03,
# Valid   Loss:4.8519e-01  Loss_r:3.4557e-01
# Epoch #  9400/100000    time:3.45
# loss:4.30e-01, loss_r:3.12e-01, loss_b:1.18e-03,
# Valid   Loss:4.2144e-01  Loss_r:3.0412e-01
# Epoch #  9500/100000    time:3.44
# loss:4.29e-01, loss_r:2.97e-01, loss_b:1.32e-03,
# Valid   Loss:4.3002e-01  Loss_r:2.9882e-01
# Epoch #  9600/100000    time:3.43
# loss:3.75e-01, loss_r:2.69e-01, loss_b:1.06e-03,
# Valid   Loss:3.6760e-01  Loss_r:2.6154e-01
# Epoch #  9700/100000    time:3.44
# loss:3.53e-01, loss_r:2.53e-01, loss_b:1.00e-03,
# Valid   Loss:3.5566e-01  Loss_r:2.5583e-01
# Epoch #  9800/100000    time:3.44
# loss:3.19e-01, loss_r:2.41e-01, loss_b:7.74e-04,
# Valid   Loss:3.1043e-01  Loss_r:2.3323e-01
# Epoch #  9900/100000    time:3.49
# loss:2.92e-01, loss_r:2.13e-01, loss_b:7.83e-04,
# Valid   Loss:2.9773e-01  Loss_r:2.1960e-01
# Adjusting learning rate of group 0 to 8.1000e-04.
# Adjusting learning rate of group 0 to 8.1000e-04.
# Epoch #  10000/100000    time:3.51
# loss:2.71e-01, loss_r:1.90e-01, loss_b:8.07e-04,
# Valid   Loss:2.9133e-01  Loss_r:2.1083e-01
# Epoch #  10100/100000    time:3.51
# loss:2.55e-01, loss_r:1.81e-01, loss_b:7.38e-04,
# Valid   Loss:2.9300e-01  Loss_r:2.1933e-01
# Epoch #  10200/100000    time:3.52
# loss:2.20e-01, loss_r:1.58e-01, loss_b:6.17e-04,
# Valid   Loss:2.4336e-01  Loss_r:1.8173e-01
# Epoch #  10300/100000    time:3.49
# loss:2.41e-01, loss_r:1.84e-01, loss_b:5.67e-04,
# Valid   Loss:2.6201e-01  Loss_r:2.0543e-01
# Epoch #  10400/100000    time:3.51
# loss:2.06e-01, loss_r:1.57e-01, loss_b:4.84e-04,
# Valid   Loss:2.2012e-01  Loss_r:1.7178e-01
# Epoch #  10500/100000    time:3.47
# loss:2.13e-01, loss_r:1.60e-01, loss_b:5.30e-04,
# Valid   Loss:2.2332e-01  Loss_r:1.7041e-01
# Epoch #  10600/100000    time:3.48
# loss:1.66e-01, loss_r:1.25e-01, loss_b:4.12e-04,
# Valid   Loss:1.8704e-01  Loss_r:1.4598e-01
# Epoch #  10700/100000    time:3.43
# loss:1.86e-01, loss_r:1.44e-01, loss_b:4.13e-04,
# Valid   Loss:1.9386e-01  Loss_r:1.5258e-01
# Epoch #  10800/100000    time:3.44
# loss:1.83e-01, loss_r:1.39e-01, loss_b:4.39e-04,
# Valid   Loss:1.8930e-01  Loss_r:1.4548e-01
# Epoch #  10900/100000    time:3.50
# loss:1.50e-01, loss_r:1.10e-01, loss_b:4.06e-04,
# Valid   Loss:1.7676e-01  Loss_r:1.3623e-01
# Epoch #  11000/100000    time:3.43
# loss:1.49e-01, loss_r:1.08e-01, loss_b:4.10e-04,
# Valid   Loss:1.9084e-01  Loss_r:1.4996e-01
# Epoch #  11100/100000    time:3.45
# loss:1.43e-01, loss_r:1.08e-01, loss_b:3.43e-04,
# Valid   Loss:1.6163e-01  Loss_r:1.2740e-01
# Epoch #  11200/100000    time:3.50
# loss:1.34e-01, loss_r:1.01e-01, loss_b:3.28e-04,
# Valid   Loss:1.7068e-01  Loss_r:1.3793e-01
# Epoch #  11300/100000    time:3.59
# loss:1.38e-01, loss_r:1.10e-01, loss_b:2.88e-04,
# Valid   Loss:1.5502e-01  Loss_r:1.2630e-01
# Epoch #  11400/100000    time:3.50
# loss:1.26e-01, loss_r:9.40e-02, loss_b:3.22e-04,
# Valid   Loss:1.5947e-01  Loss_r:1.2735e-01
# Epoch #  11500/100000    time:3.48
# loss:1.24e-01, loss_r:9.91e-02, loss_b:2.54e-04,
# Valid   Loss:1.4494e-01  Loss_r:1.1959e-01
# Epoch #  11600/100000    time:3.50
# loss:1.05e-01, loss_r:8.00e-02, loss_b:2.54e-04,
# Valid   Loss:1.4130e-01  Loss_r:1.1600e-01
# Epoch #  11700/100000    time:3.56
# loss:1.05e-01, loss_r:8.18e-02, loss_b:2.33e-04,
# Valid   Loss:1.2892e-01  Loss_r:1.0562e-01
# Epoch #  11800/100000    time:3.50
# loss:1.12e-01, loss_r:8.78e-02, loss_b:2.38e-04,
# Valid   Loss:1.2071e-01  Loss_r:9.6970e-02
# Epoch #  11900/100000    time:3.43
# loss:9.65e-02, loss_r:7.53e-02, loss_b:2.11e-04,
# Valid   Loss:1.1572e-01  Loss_r:9.4634e-02
# Epoch #  12000/100000    time:3.43
# loss:8.80e-02, loss_r:6.93e-02, loss_b:1.86e-04,
# Valid   Loss:1.1603e-01  Loss_r:9.7462e-02
# Epoch #  12100/100000    time:3.45
# loss:9.44e-02, loss_r:7.45e-02, loss_b:1.98e-04,
# Valid   Loss:1.1057e-01  Loss_r:9.0752e-02
# Epoch #  12200/100000    time:3.45
# loss:8.91e-02, loss_r:7.09e-02, loss_b:1.82e-04,
# Valid   Loss:1.0782e-01  Loss_r:8.9700e-02
# Epoch #  12300/100000    time:3.47
# loss:9.24e-02, loss_r:7.39e-02, loss_b:1.86e-04,
# Valid   Loss:1.3945e-01  Loss_r:1.1911e-01
# Epoch #  12400/100000    time:3.46
# loss:8.38e-02, loss_r:6.57e-02, loss_b:1.81e-04,
# Valid   Loss:9.9574e-02  Loss_r:8.1484e-02
# Epoch #  12500/100000    time:3.50
# loss:2.27e-01, loss_r:1.99e-01, loss_b:2.72e-04,
# Valid   Loss:3.5441e-01  Loss_r:3.3060e-01
# Epoch #  12600/100000    time:3.51
# loss:3.45e-01, loss_r:3.30e-01, loss_b:1.53e-04,
# Valid   Loss:3.4959e-01  Loss_r:3.3436e-01
# Epoch #  12700/100000    time:3.57
# loss:3.23e-01, loss_r:3.09e-01, loss_b:1.43e-04,
# Valid   Loss:2.5244e-01  Loss_r:2.3814e-01
# Epoch #  12800/100000    time:3.49
# loss:3.02e-01, loss_r:2.89e-01, loss_b:1.31e-04,
# Valid   Loss:2.6050e-01  Loss_r:2.4742e-01
# Epoch #  12900/100000    time:3.50
# loss:2.88e-01, loss_r:2.76e-01, loss_b:1.24e-04,
# Valid   Loss:2.9404e-01  Loss_r:2.8165e-01
# Epoch #  13000/100000    time:3.51
# loss:2.08e-01, loss_r:1.25e-01, loss_b:8.35e-04,
# Valid   Loss:2.3065e-01  Loss_r:1.4797e-01
# Epoch #  13100/100000    time:3.46
# loss:1.32e-01, loss_r:8.22e-02, loss_b:4.96e-04,
# Valid   Loss:1.3424e-01  Loss_r:8.4880e-02
# Epoch #  13200/100000    time:3.47
# loss:9.80e-02, loss_r:6.28e-02, loss_b:3.52e-04,
# Valid   Loss:1.0758e-01  Loss_r:7.2558e-02
# Epoch #  13300/100000    time:3.43
# loss:9.21e-02, loss_r:6.42e-02, loss_b:2.79e-04,
# Valid   Loss:9.6523e-02  Loss_r:6.8738e-02
# Epoch #  13400/100000    time:3.44
# loss:7.44e-02, loss_r:5.19e-02, loss_b:2.25e-04,
# Valid   Loss:8.5393e-02  Loss_r:6.2936e-02
# Epoch #  13500/100000    time:3.43
# loss:7.14e-02, loss_r:5.12e-02, loss_b:2.01e-04,
# Valid   Loss:7.6720e-02  Loss_r:5.6667e-02
# Epoch #  13600/100000    time:3.51
# loss:6.29e-02, loss_r:4.53e-02, loss_b:1.76e-04,
# Valid   Loss:7.4488e-02  Loss_r:5.6945e-02
# Epoch #  13700/100000    time:3.45
# loss:5.68e-02, loss_r:4.25e-02, loss_b:1.43e-04,
# Valid   Loss:6.5230e-02  Loss_r:5.0929e-02
# Epoch #  13800/100000    time:3.50
# loss:5.48e-02, loss_r:4.10e-02, loss_b:1.39e-04,
# Valid   Loss:6.2941e-02  Loss_r:4.9109e-02
# Epoch #  13900/100000    time:3.50
# loss:5.07e-02, loss_r:3.79e-02, loss_b:1.28e-04,
# Valid   Loss:6.2899e-02  Loss_r:5.0126e-02
# Epoch #  14000/100000    time:3.54
# loss:4.96e-02, loss_r:3.90e-02, loss_b:1.06e-04,
# Valid   Loss:5.7584e-02  Loss_r:4.7031e-02
# Epoch #  14100/100000    time:3.53
# loss:4.56e-02, loss_r:3.55e-02, loss_b:1.01e-04,
# Valid   Loss:5.3927e-02  Loss_r:4.3850e-02
# Epoch #  14200/100000    time:3.52
# loss:3.74e-02, loss_r:2.83e-02, loss_b:9.11e-05,
# Valid   Loss:5.3843e-02  Loss_r:4.4753e-02
# Epoch #  14300/100000    time:3.47
# loss:3.78e-02, loss_r:2.91e-02, loss_b:8.68e-05,
# Valid   Loss:5.2876e-02  Loss_r:4.4221e-02
# Epoch #  14400/100000    time:3.48
# loss:4.20e-02, loss_r:3.39e-02, loss_b:8.08e-05,
# Valid   Loss:5.0815e-02  Loss_r:4.2750e-02
# Epoch #  14500/100000    time:3.47
# loss:1.10e-01, loss_r:7.69e-02, loss_b:3.28e-04,
# Valid   Loss:1.5247e-01  Loss_r:1.2007e-01
# Epoch #  14600/100000    time:3.47
# loss:6.63e-02, loss_r:4.60e-02, loss_b:2.03e-04,
# Valid   Loss:9.3305e-02  Loss_r:7.3079e-02
# Epoch #  14700/100000    time:3.47
# loss:5.05e-02, loss_r:3.55e-02, loss_b:1.50e-04,
# Valid   Loss:7.9040e-02  Loss_r:6.4096e-02
# Epoch #  14800/100000    time:3.44
# loss:4.20e-02, loss_r:3.06e-02, loss_b:1.14e-04,
# Valid   Loss:6.1562e-02  Loss_r:5.0167e-02
# Epoch #  14900/100000    time:3.47
# loss:3.97e-02, loss_r:2.95e-02, loss_b:1.02e-04,
# Valid   Loss:5.6652e-02  Loss_r:4.6475e-02
# Adjusting learning rate of group 0 to 7.2900e-04.
# Adjusting learning rate of group 0 to 7.2900e-04.
# Epoch #  15000/100000    time:3.46
# loss:3.75e-02, loss_r:2.76e-02, loss_b:9.93e-05,
# Valid   Loss:5.2063e-02  Loss_r:4.2164e-02
# Epoch #  15100/100000    time:3.49
# loss:3.61e-02, loss_r:2.79e-02, loss_b:8.20e-05,
# Valid   Loss:5.0101e-02  Loss_r:4.1920e-02
# Epoch #  15200/100000    time:3.48
# loss:3.41e-02, loss_r:2.64e-02, loss_b:7.70e-05,
# Valid   Loss:4.6119e-02  Loss_r:3.8441e-02
# Epoch #  15300/100000    time:3.56
# loss:2.96e-02, loss_r:2.35e-02, loss_b:6.07e-05,
# Valid   Loss:4.2329e-02  Loss_r:3.6271e-02
# Epoch #  15400/100000    time:3.52
# loss:3.00e-02, loss_r:2.35e-02, loss_b:6.53e-05,
# Valid   Loss:4.3023e-02  Loss_r:3.6505e-02
# Epoch #  15500/100000    time:3.48
# loss:2.73e-02, loss_r:2.11e-02, loss_b:6.20e-05,
# Valid   Loss:4.1900e-02  Loss_r:3.5711e-02
# Epoch #  15600/100000    time:3.48
# loss:2.58e-02, loss_r:2.04e-02, loss_b:5.47e-05,
# Valid   Loss:3.6494e-02  Loss_r:3.1042e-02
# Epoch #  15700/100000    time:3.46
# loss:2.66e-02, loss_r:2.08e-02, loss_b:5.83e-05,
# Valid   Loss:3.5218e-02  Loss_r:2.9444e-02
# Epoch #  15800/100000    time:3.58
# loss:2.46e-02, loss_r:1.96e-02, loss_b:4.98e-05,
# Valid   Loss:3.4236e-02  Loss_r:2.9261e-02
# Epoch #  15900/100000    time:3.45
# loss:3.19e-02, loss_r:2.48e-02, loss_b:7.02e-05,
# Valid   Loss:3.5117e-02  Loss_r:2.9484e-02
# Epoch #  16000/100000    time:3.44
# loss:2.46e-02, loss_r:1.95e-02, loss_b:5.06e-05,
# Valid   Loss:3.3056e-02  Loss_r:2.8249e-02
# Epoch #  16100/100000    time:3.45
# loss:2.14e-02, loss_r:1.72e-02, loss_b:4.18e-05,
# Valid   Loss:2.8953e-02  Loss_r:2.4800e-02
# Epoch #  16200/100000    time:3.45
# loss:2.02e-02, loss_r:1.59e-02, loss_b:4.26e-05,
# Valid   Loss:2.7930e-02  Loss_r:2.3672e-02
# Epoch #  16300/100000    time:3.47
# loss:2.92e-02, loss_r:2.21e-02, loss_b:7.15e-05,
# Valid   Loss:3.9735e-02  Loss_r:3.1916e-02
# Epoch #  16400/100000    time:3.49
# loss:1.89e-02, loss_r:1.55e-02, loss_b:3.38e-05,
# Valid   Loss:2.5516e-02  Loss_r:2.2145e-02
# Epoch #  16500/100000    time:3.50
# loss:4.66e-02, loss_r:3.56e-02, loss_b:1.10e-04,
# Valid   Loss:3.4944e-02  Loss_r:2.7288e-02
# Epoch #  16600/100000    time:3.56
# loss:1.92e-02, loss_r:1.60e-02, loss_b:3.20e-05,
# Valid   Loss:2.4463e-02  Loss_r:2.1267e-02
# Epoch #  16700/100000    time:3.52
# loss:1.78e-02, loss_r:1.50e-02, loss_b:2.78e-05,
# Valid   Loss:2.3178e-02  Loss_r:2.0433e-02
# Epoch #  16800/100000    time:3.52
# loss:5.28e-02, loss_r:3.74e-02, loss_b:1.54e-04,
# Valid   Loss:6.9797e-02  Loss_r:5.0823e-02
# Epoch #  16900/100000    time:3.47
# loss:1.81e-02, loss_r:1.56e-02, loss_b:2.50e-05,
# Valid   Loss:2.4332e-02  Loss_r:2.1704e-02
# Epoch #  17000/100000    time:3.44
# loss:4.56e-01, loss_r:4.22e-01, loss_b:3.38e-04,
# Valid   Loss:3.5538e-01  Loss_r:3.0130e-01
# Epoch #  17100/100000    time:3.43
# loss:3.83e-02, loss_r:3.57e-02, loss_b:2.60e-05,
# Valid   Loss:7.8578e-02  Loss_r:7.6000e-02
# Epoch #  17200/100000    time:3.45
# loss:2.75e-02, loss_r:2.50e-02, loss_b:2.47e-05,
# Valid   Loss:5.0018e-02  Loss_r:4.7553e-02
# Epoch #  17300/100000    time:3.43
# loss:2.35e-02, loss_r:2.16e-02, loss_b:1.98e-05,
# Valid   Loss:3.9492e-02  Loss_r:3.7518e-02
# Epoch #  17400/100000    time:3.49
# loss:2.30e-02, loss_r:2.10e-02, loss_b:2.04e-05,
# Valid   Loss:3.5685e-02  Loss_r:3.3471e-02
# Epoch #  17500/100000    time:3.45
# loss:2.81e-02, loss_r:2.35e-02, loss_b:4.64e-05,
# Valid   Loss:4.6512e-02  Loss_r:3.7185e-02
# Epoch #  17600/100000    time:3.47
# loss:4.57e-02, loss_r:3.34e-02, loss_b:1.24e-04,
# Valid   Loss:6.3416e-02  Loss_r:4.9534e-02
# Epoch #  17700/100000    time:3.49
# loss:2.13e-02, loss_r:1.98e-02, loss_b:1.55e-05,
# Valid   Loss:2.9606e-02  Loss_r:2.8062e-02
# Epoch #  17800/100000    time:3.49
# loss:2.13e-02, loss_r:1.92e-02, loss_b:2.10e-05,
# Valid   Loss:2.9480e-02  Loss_r:2.7495e-02
# Epoch #  17900/100000    time:3.52
# loss:1.73e-02, loss_r:1.55e-02, loss_b:1.88e-05,
# Valid   Loss:2.2706e-02  Loss_r:2.0827e-02
# Epoch #  18000/100000    time:3.50
# loss:1.81e-02, loss_r:1.66e-02, loss_b:1.52e-05,
# Valid   Loss:2.5101e-02  Loss_r:2.3582e-02
# Epoch #  18100/100000    time:3.48
# loss:2.02e-02, loss_r:1.87e-02, loss_b:1.46e-05,
# Valid   Loss:2.6625e-02  Loss_r:2.5170e-02
# Epoch #  18200/100000    time:3.48
# loss:2.16e-02, loss_r:1.92e-02, loss_b:2.37e-05,
# Valid   Loss:2.6679e-02  Loss_r:2.4128e-02
# Epoch #  18300/100000    time:3.45
# loss:1.71e-02, loss_r:1.57e-02, loss_b:1.37e-05,
# Valid   Loss:2.0882e-02  Loss_r:1.9521e-02
# Epoch #  18400/100000    time:3.45
# loss:1.95e-02, loss_r:1.83e-02, loss_b:1.27e-05,
# Valid   Loss:2.3001e-02  Loss_r:2.1771e-02
# Epoch #  18500/100000    time:3.46
# loss:1.64e-02, loss_r:1.52e-02, loss_b:1.15e-05,
# Valid   Loss:1.8482e-02  Loss_r:1.7319e-02
# Epoch #  18600/100000    time:3.48
# loss:1.83e-02, loss_r:1.66e-02, loss_b:1.76e-05,
# Valid   Loss:2.0838e-02  Loss_r:1.9035e-02
# Epoch #  18700/100000    time:3.45
# loss:1.53e-02, loss_r:1.40e-02, loss_b:1.27e-05,
# Valid   Loss:1.7076e-02  Loss_r:1.5807e-02
# Epoch #  18800/100000    time:3.46
# loss:4.58e-02, loss_r:4.03e-02, loss_b:5.48e-05,
# Valid   Loss:4.4498e-02  Loss_r:4.0930e-02
# Epoch #  18900/100000    time:3.46
# loss:2.43e-02, loss_r:2.31e-02, loss_b:1.16e-05,
# Valid   Loss:2.2199e-02  Loss_r:2.1041e-02
# Epoch #  19000/100000    time:3.54
# loss:1.57e-02, loss_r:1.45e-02, loss_b:1.14e-05,
# Valid   Loss:1.7940e-02  Loss_r:1.6803e-02
# Epoch #  19100/100000    time:3.50
# loss:1.68e-02, loss_r:1.58e-02, loss_b:9.90e-06,
# Valid   Loss:1.5743e-02  Loss_r:1.4707e-02
# Epoch #  19200/100000    time:3.56
# loss:3.13e-02, loss_r:2.46e-02, loss_b:6.79e-05,
# Valid   Loss:2.8931e-02  Loss_r:2.3666e-02
# Epoch #  19300/100000    time:3.49
# loss:2.88e-02, loss_r:2.43e-02, loss_b:4.50e-05,
# Valid   Loss:3.1987e-02  Loss_r:2.5371e-02
# Epoch #  19400/100000    time:3.52
# loss:7.58e+00, loss_r:4.17e+00, loss_b:3.41e-02,
# Valid   Loss:6.9206e+00  Loss_r:2.5245e+00
# Epoch #  19500/100000    time:3.51
# loss:6.45e-02, loss_r:5.04e-02, loss_b:1.41e-04,
# Valid   Loss:1.0160e-01  Loss_r:8.7704e-02
# Epoch #  19600/100000    time:3.44
# loss:3.17e-02, loss_r:2.58e-02, loss_b:5.90e-05,
# Valid   Loss:4.3315e-02  Loss_r:3.7447e-02
# Epoch #  19700/100000    time:3.45
# loss:2.22e-02, loss_r:1.87e-02, loss_b:3.49e-05,
# Valid   Loss:3.3101e-02  Loss_r:2.9616e-02
# Epoch #  19800/100000    time:3.45
# loss:1.68e-02, loss_r:1.40e-02, loss_b:2.85e-05,
# Valid   Loss:2.7082e-02  Loss_r:2.4251e-02
# Epoch #  19900/100000    time:3.44
# loss:1.50e-02, loss_r:1.27e-02, loss_b:2.30e-05,
# Valid   Loss:2.3988e-02  Loss_r:2.1700e-02
# Adjusting learning rate of group 0 to 6.5610e-04.
# Adjusting learning rate of group 0 to 6.5610e-04.
# Epoch #  20000/100000    time:3.45
# loss:1.33e-02, loss_r:1.12e-02, loss_b:2.05e-05,
# Valid   Loss:2.3140e-02  Loss_r:2.1097e-02
# Epoch #  20100/100000    time:3.47
# loss:1.25e-02, loss_r:1.05e-02, loss_b:1.96e-05,
# Valid   Loss:2.0192e-02  Loss_r:1.8242e-02
# Epoch #  20200/100000    time:3.55
# loss:1.14e-02, loss_r:9.68e-03, loss_b:1.69e-05,
# Valid   Loss:1.8372e-02  Loss_r:1.6687e-02
# Epoch #  20300/100000    time:3.49
# loss:1.01e-02, loss_r:8.51e-03, loss_b:1.57e-05,
# Valid   Loss:1.7456e-02  Loss_r:1.5893e-02
# Epoch #  20400/100000    time:3.53
# loss:8.63e-03, loss_r:7.48e-03, loss_b:1.15e-05,
# Valid   Loss:1.5293e-02  Loss_r:1.4145e-02
# Epoch #  20500/100000    time:3.49
# loss:8.84e-03, loss_r:7.44e-03, loss_b:1.40e-05,
# Valid   Loss:1.4936e-02  Loss_r:1.3538e-02
# Epoch #  20600/100000    time:3.48
# loss:7.80e-03, loss_r:6.72e-03, loss_b:1.08e-05,
# Valid   Loss:1.4167e-02  Loss_r:1.3088e-02
# Epoch #  20700/100000    time:3.49
# loss:7.14e-03, loss_r:6.14e-03, loss_b:1.00e-05,
# Valid   Loss:1.3590e-02  Loss_r:1.2591e-02
# Epoch #  20800/100000    time:3.47
# loss:6.68e-03, loss_r:5.77e-03, loss_b:9.15e-06,
# Valid   Loss:1.1999e-02  Loss_r:1.1082e-02
# Epoch #  20900/100000    time:3.48
# loss:6.51e-03, loss_r:5.57e-03, loss_b:9.32e-06,
# Valid   Loss:1.2253e-02  Loss_r:1.1332e-02
# Epoch #  21000/100000    time:3.43
# loss:7.10e-03, loss_r:5.95e-03, loss_b:1.15e-05,
# Valid   Loss:1.2437e-02  Loss_r:1.1170e-02
# Epoch #  21100/100000    time:3.43
# loss:5.56e-03, loss_r:4.73e-03, loss_b:8.25e-06,
# Valid   Loss:1.0782e-02  Loss_r:9.9552e-03
# Epoch #  21200/100000    time:3.44
# loss:5.00e-03, loss_r:4.36e-03, loss_b:6.45e-06,
# Valid   Loss:9.8505e-03  Loss_r:9.2069e-03
# Epoch #  21300/100000    time:3.44
# loss:5.18e-03, loss_r:4.49e-03, loss_b:6.88e-06,
# Valid   Loss:9.4868e-03  Loss_r:8.8000e-03
# Epoch #  21400/100000    time:3.46
# loss:6.65e-03, loss_r:5.55e-03, loss_b:1.10e-05,
# Valid   Loss:9.2853e-03  Loss_r:8.6699e-03
# Epoch #  21500/100000    time:3.54
# loss:4.59e-03, loss_r:4.05e-03, loss_b:5.38e-06,
# Valid   Loss:8.5947e-03  Loss_r:8.0568e-03
# Epoch #  21600/100000    time:3.47
# loss:4.55e-03, loss_r:3.97e-03, loss_b:5.76e-06,
# Valid   Loss:8.2280e-03  Loss_r:7.6499e-03
# Epoch #  21700/100000    time:3.50
# loss:4.55e-03, loss_r:4.02e-03, loss_b:5.32e-06,
# Valid   Loss:8.0108e-03  Loss_r:7.4800e-03
# Epoch #  21800/100000    time:3.48
# loss:1.20e-01, loss_r:1.16e-01, loss_b:3.87e-05,
# Valid   Loss:1.2347e-01  Loss_r:1.1890e-01
# Epoch #  21900/100000    time:3.60
# loss:2.25e-02, loss_r:2.18e-02, loss_b:6.93e-06,
# Valid   Loss:3.7782e-02  Loss_r:3.7093e-02
# Epoch #  22000/100000    time:3.51
# loss:1.64e-02, loss_r:1.57e-02, loss_b:6.29e-06,
# Valid   Loss:2.6426e-02  Loss_r:2.5798e-02
# Epoch #  22100/100000    time:3.52
# loss:1.63e-02, loss_r:1.57e-02, loss_b:5.26e-06,
# Valid   Loss:2.8287e-02  Loss_r:2.7762e-02
# Epoch #  22200/100000    time:3.43
# loss:1.56e-02, loss_r:1.50e-02, loss_b:5.53e-06,
# Valid   Loss:2.4286e-02  Loss_r:2.3745e-02
# Epoch #  22300/100000    time:3.43
# loss:5.92e-03, loss_r:5.43e-03, loss_b:4.82e-06,
# Valid   Loss:7.7091e-03  Loss_r:7.2410e-03
# ...
# Epoch #  99100/100000    time:3.44
# loss:3.82e-05, loss_r:3.59e-05, loss_b:2.27e-08,
# Valid   Loss:3.5038e-05  Loss_r:3.2769e-05
# Epoch #  99200/100000    time:3.43
# loss:3.51e-05, loss_r:3.27e-05, loss_b:2.40e-08,
# Valid   Loss:3.1876e-05  Loss_r:2.9484e-05
# Epoch #  99300/100000    time:3.44
# loss:3.27e-05, loss_r:3.03e-05, loss_b:2.35e-08,
# Valid   Loss:2.8970e-05  Loss_r:2.6621e-05
# Epoch #  99400/100000    time:3.42
# loss:2.88e-05, loss_r:2.68e-05, loss_b:1.99e-08,
# Valid   Loss:2.5668e-05  Loss_r:2.3680e-05
# Epoch #  99500/100000    time:3.42
# loss:8.38e-05, loss_r:6.75e-05, loss_b:1.63e-07,
# Valid   Loss:1.1064e-04  Loss_r:8.7092e-05
# Epoch #  99600/100000    time:3.45
# loss:2.63e-05, loss_r:2.42e-05, loss_b:2.17e-08,
# Valid   Loss:2.3462e-05  Loss_r:2.1296e-05
# Epoch #  99700/100000    time:3.44
# loss:2.68e-05, loss_r:2.45e-05, loss_b:2.28e-08,
# Valid   Loss:2.3193e-05  Loss_r:2.0922e-05
# Epoch #  99800/100000    time:3.40
# loss:2.61e-05, loss_r:2.37e-05, loss_b:2.36e-08,
# Valid   Loss:2.2589e-05  Loss_r:2.0381e-05
# Epoch #  99900/100000    time:3.41
# loss:6.15e-04, loss_r:4.09e-04, loss_b:2.06e-06,
# Valid   Loss:4.3988e-04  Loss_r:2.9649e-04
# Adjusting learning rate of group 0 to 1.2158e-04.
# Adjusting learning rate of group 0 to 1.2158e-04.
# Epoch #  100000/100000    time:3.43
# loss:2.24e-05, loss_r:2.03e-05, loss_b:2.12e-08,
# Valid   Loss:1.9682e-05  Loss_r:1.7577e-05
# Epoch #  100/100000    time:3.25
# loss:2.03e-05, loss_r:1.85e-05, loss_b:1.85e-08,
# Valid   Loss:2.0310e-05  Loss_r:1.8460e-05
# Epoch #  200/100000    time:3.31
# loss:1.89e-05, loss_r:1.71e-05, loss_b:1.77e-08,
# Valid   Loss:1.9010e-05  Loss_r:1.7235e-05
# Epoch #  300/100000    time:3.28
# loss:2.18e-05, loss_r:1.97e-05, loss_b:2.17e-08,
# Valid   Loss:2.4368e-05  Loss_r:2.1065e-05
# Epoch #  400/100000    time:3.27
# loss:1.89e-05, loss_r:1.71e-05, loss_b:1.82e-08,
# Valid   Loss:1.8879e-05  Loss_r:1.7063e-05
# Epoch #  500/100000    time:3.25
# loss:8.98e-05, loss_r:8.35e-05, loss_b:6.24e-08,
# Valid   Loss:1.3817e-04  Loss_r:1.2865e-04
# Epoch #  600/100000    time:3.27
# loss:1.73e-05, loss_r:1.55e-05, loss_b:1.76e-08,
# Valid   Loss:1.7043e-05  Loss_r:1.5402e-05
# Epoch #  700/100000    time:3.28
# loss:1.86e-05, loss_r:1.60e-05, loss_b:2.52e-08,
# Valid   Loss:1.8282e-05  Loss_r:1.6356e-05
# Epoch #  800/100000    time:3.24
# loss:4.19e-05, loss_r:3.66e-05, loss_b:5.28e-08,
# Valid   Loss:5.3408e-05  Loss_r:4.6327e-05
# Epoch #  900/100000    time:3.25
# loss:1.28e-04, loss_r:7.35e-05, loss_b:5.46e-07,
# Valid   Loss:1.6965e-04  Loss_r:8.9407e-05
# Epoch #  1000/100000    time:3.24
# loss:1.05e-04, loss_r:5.73e-05, loss_b:4.73e-07,
# Valid   Loss:2.2742e-04  Loss_r:1.1547e-04
# Epoch #  1100/100000    time:3.25
# loss:1.93e-05, loss_r:1.74e-05, loss_b:1.90e-08,
# Valid   Loss:1.9306e-05  Loss_r:1.7621e-05
# Epoch #  1200/100000    time:3.27
# loss:1.68e-05, loss_r:1.52e-05, loss_b:1.57e-08,
# Valid   Loss:1.6742e-05  Loss_r:1.5179e-05
# Epoch #  1300/100000    time:3.27
# loss:2.18e-04, loss_r:1.35e-04, loss_b:8.23e-07,
# Valid   Loss:5.9756e-05  Loss_r:4.0648e-05
# Epoch #  1400/100000    time:3.26
# loss:1.63e-05, loss_r:1.47e-05, loss_b:1.57e-08,
# Valid   Loss:1.6263e-05  Loss_r:1.4691e-05
# Epoch #  1500/100000    time:3.26
# loss:6.73e-05, loss_r:4.53e-05, loss_b:2.21e-07,
# Valid   Loss:9.7924e-05  Loss_r:6.3998e-05
# Epoch #  1600/100000    time:3.25
# loss:1.58e-05, loss_r:1.41e-05, loss_b:1.67e-08,
# Valid   Loss:1.5828e-05  Loss_r:1.4161e-05
# Epoch #  1700/100000    time:3.26
# loss:1.58e-05, loss_r:1.41e-05, loss_b:1.69e-08,
# Valid   Loss:1.5791e-05  Loss_r:1.4089e-05
# Epoch #  1800/100000    time:3.24
# loss:1.65e-05, loss_r:1.44e-05, loss_b:2.07e-08,
# Valid   Loss:1.6543e-05  Loss_r:1.4519e-05
# Epoch #  1900/100000    time:3.25
# loss:4.95e-04, loss_r:2.48e-04, loss_b:2.47e-06,
# Valid   Loss:7.4205e-04  Loss_r:3.6726e-04
# Epoch #  2000/100000    time:3.30
# loss:1.48e-05, loss_r:1.30e-05, loss_b:1.70e-08,
# Valid   Loss:1.4693e-05  Loss_r:1.3014e-05
# Epoch #  2100/100000    time:3.26
# loss:1.53e-05, loss_r:1.37e-05, loss_b:1.60e-08,
# Valid   Loss:1.5473e-05  Loss_r:1.3841e-05
# Epoch #  2200/100000    time:3.26
# loss:1.43e-05, loss_r:1.26e-05, loss_b:1.67e-08,
# Valid   Loss:1.4299e-05  Loss_r:1.2631e-05
# Epoch #  2300/100000    time:3.27
# loss:1.77e-05, loss_r:1.43e-05, loss_b:3.46e-08,
# Valid   Loss:1.7947e-05  Loss_r:1.4310e-05
# Epoch #  2400/100000    time:3.24
# loss:1.53e-05, loss_r:1.35e-05, loss_b:1.74e-08,
# Valid   Loss:1.5373e-05  Loss_r:1.3588e-05
# Epoch #  2500/100000    time:3.26
# loss:1.58e-05, loss_r:1.38e-05, loss_b:1.93e-08,
# Valid   Loss:1.6108e-05  Loss_r:1.4115e-05
# Epoch #  2600/100000    time:3.26
# loss:1.47e-05, loss_r:1.31e-05, loss_b:1.67e-08,
# Valid   Loss:1.4889e-05  Loss_r:1.3128e-05
# Epoch #  2700/100000    time:3.24
# loss:1.47e-05, loss_r:1.26e-05, loss_b:2.07e-08,
# Valid   Loss:1.4843e-05  Loss_r:1.2725e-05
# Epoch #  2800/100000    time:3.24
# loss:1.66e-05, loss_r:1.48e-05, loss_b:1.86e-08,
# Valid   Loss:1.6806e-05  Loss_r:1.5028e-05
# Epoch #  2900/100000    time:3.25
# loss:7.53e-05, loss_r:4.72e-05, loss_b:2.81e-07,
# Valid   Loss:7.5907e-05  Loss_r:4.4896e-05
# Epoch #  3000/100000    time:3.25
# loss:2.50e-05, loss_r:2.06e-05, loss_b:4.39e-08,
# Valid   Loss:2.7240e-05  Loss_r:2.2498e-05
# Epoch #  3100/100000    time:3.24
# loss:1.68e-05, loss_r:1.50e-05, loss_b:1.77e-08,
# Valid   Loss:1.5791e-05  Loss_r:1.4083e-05
# Epoch #  3200/100000    time:3.32
# loss:1.60e-05, loss_r:1.38e-05, loss_b:2.16e-08,
# Valid   Loss:1.5599e-05  Loss_r:1.3598e-05
# Epoch #  3300/100000    time:3.31
# loss:1.34e-05, loss_r:1.20e-05, loss_b:1.43e-08,
# Valid   Loss:1.3373e-05  Loss_r:1.1948e-05
# Epoch #  3400/100000    time:3.26
# loss:5.65e-05, loss_r:3.85e-05, loss_b:1.80e-07,
# Valid   Loss:8.4260e-05  Loss_r:5.5559e-05
# Epoch #  3500/100000    time:3.26
# loss:1.65e-05, loss_r:1.48e-05, loss_b:1.70e-08,
# Valid   Loss:1.7312e-05  Loss_r:1.5531e-05
# Epoch #  3600/100000    time:3.25
# loss:1.38e-05, loss_r:1.22e-05, loss_b:1.58e-08,
# Valid   Loss:1.3897e-05  Loss_r:1.2287e-05
# Epoch #  3700/100000    time:3.26
# loss:1.71e-03, loss_r:1.20e-03, loss_b:5.06e-06,
# Valid   Loss:1.7245e-03  Loss_r:1.1763e-03
# Epoch #  3800/100000    time:3.25
# loss:1.27e-05, loss_r:1.12e-05, loss_b:1.49e-08,
# Valid   Loss:1.2698e-05  Loss_r:1.1218e-05
# Epoch #  3900/100000    time:3.30
# loss:2.76e-04, loss_r:2.51e-04, loss_b:2.44e-07,
# Valid   Loss:2.5623e-04  Loss_r:2.3183e-04
# Epoch #  4000/100000    time:3.25
# loss:1.53e-05, loss_r:1.26e-05, loss_b:2.75e-08,
# Valid   Loss:2.0973e-05  Loss_r:1.5288e-05
# Epoch #  4100/100000    time:3.25
# loss:1.96e-05, loss_r:1.75e-05, loss_b:2.09e-08,
# Valid   Loss:1.7354e-05  Loss_r:1.5476e-05
# Epoch #  4200/100000    time:3.26
# loss:1.75e-05, loss_r:1.54e-05, loss_b:2.19e-08,
# Valid   Loss:1.7376e-05  Loss_r:1.5134e-05
# Epoch #  4300/100000    time:3.27
# loss:1.34e-04, loss_r:8.75e-05, loss_b:4.63e-07,
# Valid   Loss:1.9294e-04  Loss_r:1.2480e-04
# Epoch #  4400/100000    time:3.26
# loss:1.47e-05, loss_r:1.31e-05, loss_b:1.60e-08,
# Valid   Loss:1.4815e-05  Loss_r:1.3137e-05
# Epoch #  4500/100000    time:3.24
# loss:1.32e-05, loss_r:1.17e-05, loss_b:1.57e-08,
# Valid   Loss:1.3294e-05  Loss_r:1.1681e-05
# Epoch #  4600/100000    time:3.24
# loss:1.30e-05, loss_r:1.14e-05, loss_b:1.59e-08,
# Valid   Loss:1.2988e-05  Loss_r:1.1404e-05
# Epoch #  4700/100000    time:3.23
# loss:1.38e-05, loss_r:1.19e-05, loss_b:1.92e-08,
# Valid   Loss:1.4462e-05  Loss_r:1.2367e-05
# Epoch #  4800/100000    time:3.24
# loss:7.61e-05, loss_r:5.25e-05, loss_b:2.35e-07,
# Valid   Loss:5.1895e-05  Loss_r:3.6439e-05
# Epoch #  4900/100000    time:3.25
# loss:1.40e-04, loss_r:9.82e-05, loss_b:4.13e-07,
# Valid   Loss:1.1034e-04  Loss_r:8.7811e-05
# Adjusting learning rate of group 0 to 1.0942e-04.
# Epoch #  5000/100000    time:3.23
# loss:2.19e-04, loss_r:1.20e-04, loss_b:9.82e-07,
# Valid   Loss:7.9451e-05  Loss_r:4.6336e-05
# Epoch #  5100/100000    time:3.24
# loss:1.33e-05, loss_r:1.16e-05, loss_b:1.64e-08,
# Valid   Loss:1.3232e-05  Loss_r:1.1596e-05
# Epoch #  5200/100000    time:3.26
# loss:1.22e-05, loss_r:1.05e-05, loss_b:1.67e-08,
# Valid   Loss:1.2166e-05  Loss_r:1.0499e-05
# Epoch #  5300/100000    time:3.24
# loss:1.24e-05, loss_r:1.08e-05, loss_b:1.59e-08,
# Valid   Loss:1.2393e-05  Loss_r:1.0801e-05
# Epoch #  5400/100000    time:3.25
# loss:1.38e-05, loss_r:1.20e-05, loss_b:1.86e-08,
# Valid   Loss:1.3152e-05  Loss_r:1.1550e-05
# Epoch #  5500/100000    time:3.24
# loss:7.84e-04, loss_r:5.20e-04, loss_b:2.64e-06,
# Valid   Loss:1.0078e-03  Loss_r:6.6779e-04
# Epoch #  5600/100000    time:3.25
# loss:1.27e-05, loss_r:1.11e-05, loss_b:1.62e-08,
# Valid   Loss:1.2692e-05  Loss_r:1.1065e-05
# Epoch #  5700/100000    time:3.25
# loss:1.26e-05, loss_r:1.12e-05, loss_b:1.44e-08,
# Valid   Loss:1.2621e-05  Loss_r:1.1184e-05
# Epoch #  5800/100000    time:3.24
# loss:1.25e-05, loss_r:1.08e-05, loss_b:1.62e-08,
# Valid   Loss:1.2457e-05  Loss_r:1.0837e-05
# Epoch #  5900/100000    time:3.24
# loss:1.19e-05, loss_r:1.06e-05, loss_b:1.37e-08,
# Valid   Loss:1.1928e-05  Loss_r:1.0557e-05
# Epoch #  6000/100000    time:3.25
# loss:1.26e-05, loss_r:1.12e-05, loss_b:1.39e-08,
# Valid   Loss:1.2283e-05  Loss_r:1.0876e-05
# Epoch #  6100/100000    time:3.27
# loss:1.20e-05, loss_r:1.05e-05, loss_b:1.50e-08,
# Valid   Loss:1.1964e-05  Loss_r:1.0464e-05
# Epoch #  6200/100000    time:3.30
# loss:1.29e-05, loss_r:1.12e-05, loss_b:1.65e-08,
# Valid   Loss:1.2591e-05  Loss_r:1.1038e-05
# Epoch #  6300/100000    time:3.24
# loss:2.60e-05, loss_r:2.34e-05, loss_b:2.52e-08,
# Valid   Loss:1.9993e-05  Loss_r:1.8067e-05
# Epoch #  6400/100000    time:3.28
# loss:6.23e-05, loss_r:4.01e-05, loss_b:2.22e-07,
# Valid   Loss:8.9471e-05  Loss_r:4.5844e-05
# Epoch #  6500/100000    time:3.26
# loss:1.66e-05, loss_r:1.44e-05, loss_b:2.22e-08,
# Valid   Loss:1.7655e-05  Loss_r:1.5710e-05
# Epoch #  6600/100000    time:3.25
# loss:8.19e-05, loss_r:4.97e-05, loss_b:3.22e-07,
# Valid   Loss:4.6703e-05  Loss_r:3.1031e-05
# Epoch #  6700/100000    time:3.27
# loss:8.18e-04, loss_r:4.10e-04, loss_b:4.09e-06,
# Valid   Loss:5.3903e-04  Loss_r:2.6178e-04
# Epoch #  6800/100000    time:3.25
# loss:1.22e-05, loss_r:1.08e-05, loss_b:1.42e-08,
# Valid   Loss:1.2201e-05  Loss_r:1.0780e-05
# Epoch #  6900/100000    time:3.24
# loss:1.25e-05, loss_r:1.07e-05, loss_b:1.79e-08,
# Valid   Loss:1.3299e-05  Loss_r:1.1351e-05
# Epoch #  7000/100000    time:3.25
# loss:2.32e-05, loss_r:1.67e-05, loss_b:6.52e-08,
# Valid   Loss:2.6130e-05  Loss_r:1.7692e-05
# Epoch #  7100/100000    time:3.25
# loss:1.64e-05, loss_r:1.22e-05, loss_b:4.11e-08,
# Valid   Loss:1.2894e-05  Loss_r:1.0557e-05
# Epoch #  7200/100000    time:3.26
# loss:4.39e-05, loss_r:2.89e-05, loss_b:1.50e-07,
# Valid   Loss:5.1316e-05  Loss_r:3.2216e-05
# Epoch #  7300/100000    time:3.24
# loss:1.35e-05, loss_r:1.19e-05, loss_b:1.62e-08,
# Valid   Loss:1.3483e-05  Loss_r:1.1858e-05
# Epoch #  7400/100000    time:3.25
# loss:1.60e-05, loss_r:1.27e-05, loss_b:3.35e-08,
# Valid   Loss:5.1982e-05  Loss_r:3.1258e-05
# Epoch #  7500/100000    time:3.25
# loss:1.16e-05, loss_r:1.01e-05, loss_b:1.52e-08,
# Valid   Loss:1.1597e-05  Loss_r:1.0083e-05
# Epoch #  7600/100000    time:3.24
# loss:1.34e-04, loss_r:7.88e-05, loss_b:5.49e-07,
# Valid   Loss:1.7227e-05  Loss_r:1.3433e-05
# Epoch #  7700/100000    time:3.23
# loss:1.19e-05, loss_r:1.04e-05, loss_b:1.48e-08,
# Valid   Loss:1.1870e-05  Loss_r:1.0393e-05
# Epoch #  7800/100000    time:3.24
# loss:8.67e-05, loss_r:5.04e-05, loss_b:3.63e-07,
# Valid   Loss:4.6380e-05  Loss_r:2.8561e-05
# Epoch #  7900/100000    time:3.27
# loss:8.26e-04, loss_r:4.56e-04, loss_b:3.70e-06,
# Valid   Loss:5.6080e-04  Loss_r:3.0747e-04
# Epoch #  8000/100000    time:3.26
# loss:1.13e-04, loss_r:9.38e-05, loss_b:1.88e-07,
# Valid   Loss:1.4129e-04  Loss_r:7.9237e-05
# Epoch #  8100/100000    time:3.27
# loss:5.55e-04, loss_r:3.14e-04, loss_b:2.42e-06,
# Valid   Loss:4.3809e-04  Loss_r:2.4701e-04
# Epoch #  8200/100000    time:3.26
# loss:1.28e-05, loss_r:1.13e-05, loss_b:1.52e-08,
# Valid   Loss:1.3940e-05  Loss_r:1.2282e-05
# Epoch #  8300/100000    time:3.27
# loss:1.09e-05, loss_r:9.43e-06, loss_b:1.50e-08,
# Valid   Loss:1.0971e-05  Loss_r:9.4459e-06
# Epoch #  8400/100000    time:3.24
# loss:1.19e-05, loss_r:1.03e-05, loss_b:1.66e-08,
# Valid   Loss:1.1642e-05  Loss_r:1.0145e-05
# Epoch #  8500/100000    time:3.25
# loss:3.75e-05, loss_r:3.43e-05, loss_b:3.23e-08,
# Valid   Loss:1.4731e-05  Loss_r:1.3113e-05
# Epoch #  8600/100000    time:3.26
# loss:1.08e-05, loss_r:9.49e-06, loss_b:1.28e-08,
# Valid   Loss:1.0732e-05  Loss_r:9.4609e-06
# Epoch #  8700/100000    time:3.26
# loss:1.12e-05, loss_r:9.71e-06, loss_b:1.50e-08,
# Valid   Loss:1.1208e-05  Loss_r:9.7073e-06
# Epoch #  8800/100000    time:3.24
# loss:1.61e-05, loss_r:1.44e-05, loss_b:1.65e-08,
# Valid   Loss:1.7958e-05  Loss_r:1.6131e-05
# Epoch #  8900/100000    time:3.26
# loss:1.18e-05, loss_r:1.01e-05, loss_b:1.70e-08,
# Valid   Loss:1.1517e-05  Loss_r:9.9489e-06
# Epoch #  9000/100000    time:3.27
# loss:1.08e-05, loss_r:9.50e-06, loss_b:1.33e-08,
# Valid   Loss:1.0816e-05  Loss_r:9.4901e-06
# Epoch #  9100/100000    time:3.24
# loss:1.07e-05, loss_r:9.31e-06, loss_b:1.35e-08,
# Valid   Loss:1.0644e-05  Loss_r:9.3002e-06
# Epoch #  9200/100000    time:3.26
# loss:1.05e-05, loss_r:9.26e-06, loss_b:1.27e-08,
# Valid   Loss:1.0513e-05  Loss_r:9.2460e-06
# Epoch #  9300/100000    time:3.26
# loss:1.19e-05, loss_r:1.00e-05, loss_b:1.83e-08,
# Valid   Loss:1.1520e-05  Loss_r:9.8726e-06
# Epoch #  9400/100000    time:3.25
# loss:5.82e-05, loss_r:5.00e-05, loss_b:8.23e-08,
# Valid   Loss:4.0102e-05  Loss_r:3.3601e-05
# Epoch #  9500/100000    time:3.26
# loss:1.05e-05, loss_r:9.25e-06, loss_b:1.26e-08,
# Valid   Loss:1.0502e-05  Loss_r:9.2400e-06
# Epoch #  9600/100000    time:3.25
# loss:1.15e-05, loss_r:1.02e-05, loss_b:1.27e-08,
# Valid   Loss:1.1315e-05  Loss_r:1.0035e-05
# Epoch #  9700/100000    time:3.29
# loss:3.08e-05, loss_r:2.00e-05, loss_b:1.07e-07,
# Valid   Loss:4.6567e-05  Loss_r:3.2504e-05
# Epoch #  9800/100000    time:3.27
# loss:1.12e-05, loss_r:9.64e-06, loss_b:1.55e-08,
# Valid   Loss:1.1107e-05  Loss_r:9.5990e-06
# Epoch #  9900/100000    time:3.25
# loss:2.56e-05, loss_r:1.55e-05, loss_b:1.02e-07,
# Valid   Loss:2.4558e-05  Loss_r:1.4580e-05
# Adjusting learning rate of group 0 to 9.8477e-05.
# Epoch #  10000/100000    time:3.24
# loss:1.05e-05, loss_r:9.21e-06, loss_b:1.25e-08,
# Valid   Loss:1.0452e-05  Loss_r:9.2014e-06
# Epoch #  10100/100000    time:3.25
# loss:1.09e-05, loss_r:9.58e-06, loss_b:1.35e-08,
# Valid   Loss:1.0912e-05  Loss_r:9.5683e-06
# Epoch #  10200/100000    time:3.24
# loss:1.12e-05, loss_r:9.55e-06, loss_b:1.65e-08,
# Valid   Loss:1.0864e-05  Loss_r:9.3472e-06
# Epoch #  10300/100000    time:3.24
# loss:4.25e-05, loss_r:2.84e-05, loss_b:1.40e-07,
# Valid   Loss:2.6636e-05  Loss_r:1.8670e-05
# Epoch #  10400/100000    time:3.24
# loss:1.04e-05, loss_r:9.14e-06, loss_b:1.24e-08,
# Valid   Loss:1.0489e-05  Loss_r:9.2091e-06
# Epoch #  10500/100000    time:3.25
# loss:1.06e-05, loss_r:8.99e-06, loss_b:1.65e-08,
# Valid   Loss:1.0532e-05  Loss_r:8.9283e-06
# Epoch #  10600/100000    time:3.25
# loss:1.27e-04, loss_r:6.42e-05, loss_b:6.31e-07,
# Valid   Loss:6.8546e-05  Loss_r:3.0395e-05
# Epoch #  10700/100000    time:3.30
# loss:1.11e-05, loss_r:9.86e-06, loss_b:1.22e-08,
# Valid   Loss:1.1348e-05  Loss_r:1.0063e-05
# Epoch #  10800/100000    time:3.27
# loss:9.91e-06, loss_r:8.81e-06, loss_b:1.10e-08,
# Valid   Loss:9.8929e-06  Loss_r:8.7964e-06
# Epoch #  10900/100000    time:3.25
# loss:3.05e-05, loss_r:2.78e-05, loss_b:2.75e-08,
# Valid   Loss:2.9295e-05  Loss_r:2.6318e-05
# Epoch #  11000/100000    time:3.26
# loss:1.14e-05, loss_r:1.02e-05, loss_b:1.21e-08,
# Valid   Loss:1.1393e-05  Loss_r:1.0189e-05
# Epoch #  11100/100000    time:3.26
# loss:1.10e-05, loss_r:9.71e-06, loss_b:1.33e-08,
# Valid   Loss:1.1026e-05  Loss_r:9.6961e-06
# Epoch #  11200/100000    time:3.25
# loss:1.14e-05, loss_r:9.73e-06, loss_b:1.63e-08,
# Valid   Loss:1.1656e-05  Loss_r:9.9241e-06
# Epoch #  11300/100000    time:3.27
# loss:9.90e-06, loss_r:8.64e-06, loss_b:1.26e-08,
# Valid   Loss:9.8826e-06  Loss_r:8.6238e-06
# Epoch #  11400/100000    time:3.26
# loss:1.02e-05, loss_r:9.05e-06, loss_b:1.12e-08,
# Valid   Loss:1.0158e-05  Loss_r:9.0424e-06

# %%
# 使用最好的模型
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
model.load_state_dict(state_dict['state_dict'])
# Out:
# <All keys matched successfully>

# %%
file = f'checkpoint/subnet,{args.epochs_Adam}Adam,{args.epochs_LBFGS}LBFGS'
if os.path.exists(file)==False:
    os.mkdir(file)

# %%
np.save(f'{file}/loss_r_log.npy',np.array(trainer.loss_r_log))
np.save(f'{file}/loss_b_log.npy',np.array(trainer.loss_b_log))

# %%
trainer.loss_r_log = np.load(f'{file}/loss_r_log.npy')
trainer.loss_b_log = np.load(f'{file}/loss_b_log.npy')

# %%
import seaborn as sns
with sns.axes_style("darkgrid"):
    fig = plt.figure(figsize=(6, 5))
    plt.rcParams.update({'font.size':16})
    plt.plot(np.arange(len(trainer.loss_r_log)), trainer.loss_r_log, label='$ \mathcal{L}_r$')
    plt.plot(np.arange(len(trainer.loss_b_log)), trainer.loss_b_log, label='$ \mathcal{L}_{ic}$')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.legend()

# %% [markdown]
# ## 预测

# %%
trainer.model.cpu().double();
trainer.Unet.cpu();

# %%
x = np.linspace(0, 1, 51)
y = np.linspace(0, 1, 51)
t = np.linspace(0, 10, 11)
U_star = np.zeros((11, 51, 51))
# t = np.array([0,2.5,5,10])
# U_star = np.zeros((4, 51, 51))

# %%
XX, YY = np.meshgrid(x, y)
XX = torch.from_numpy(XX).double()
YY = torch.from_numpy(YY).double()
nt = 11

U_pred_torch = torch.zeros([nt,XX.shape[0],XX.shape[1]]).double()

for i in range(nt):
    time = torch.ones([len(XX[0]), 1]) * t[i]
    for j in range(XX.shape[1]):
        txy = torch.hstack([time, YY[:,[j]], XX[:,[j]]])
        u_pred = trainer.net_u(txy)
        U_pred_torch[i][:,[j]] = u_pred.detach()

XX = XX.numpy()
YY = YY.numpy()
U_pred = U_pred_torch.numpy()

# error_u = np.linalg.norm(U_pred - U_star) / np.linalg.norm(U_star)
# print('u Relative l2 error: {:.3e}'.format(error_u))

# %%
fig = plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(XX, YY, U_pred[0], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=0$')
plt.colorbar()
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.pcolor(XX, YY, U_pred[1], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=1$')
plt.colorbar()
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.pcolor(XX, YY, U_pred[2], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=2$')
plt.colorbar()
plt.tight_layout()

plt.show()

# %%
x = np.linspace(0, 1, 51)
y = np.linspace(0, 1, 51)
t = np.array([0,2.5,5,10])
U_star = np.zeros((4, 51, 51))

# %%
XX, YY = np.meshgrid(x, y)
XX = torch.from_numpy(XX).double()
YY = torch.from_numpy(YY).double()
nt = 4

U_pred_torch = torch.zeros([nt,XX.shape[0],XX.shape[1]]).double()

for i in range(nt):
    time = torch.ones([len(XX[0]), 1]) * t[i]
    for j in range(XX.shape[1]):
        txy = torch.hstack([time, YY[:,[j]], XX[:,[j]]])
        u_pred = trainer.net_u(txy)
        U_pred_torch[i][:,[j]] = u_pred.detach()

XX = XX.numpy()
YY = YY.numpy()
U_pred = U_pred_torch.numpy()

# error_u = np.linalg.norm(U_pred - U_star) / np.linalg.norm(U_star)
# print('u Relative l2 error: {:.3e}'.format(error_u))

# %%
fig = plt.figure(figsize=(24, 5))
plt.subplot(1, 4, 1)
plt.pcolor(XX, YY, U_pred[0], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=0$')
plt.colorbar()
plt.tight_layout()

plt.subplot(1, 4, 2)
plt.pcolor(XX, YY, U_pred[1], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=2.5$')
plt.colorbar()
plt.tight_layout()

plt.subplot(1, 4, 3)
plt.pcolor(XX, YY, U_pred[2], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=5$')
plt.colorbar()
plt.tight_layout()

plt.subplot(1, 4, 4)
plt.pcolor(XX, YY, U_pred[3], vmin = -1, vmax =1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('$t=10$')
plt.colorbar()
plt.tight_layout()

plt.show()
